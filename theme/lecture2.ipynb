# %% [markdown]
# # Lecture 2: Data types, filtering, functions
#
# ## Announcements
#
# ### About labs
# - Lab 1 this week. For the deadline, check MDS calendar.
# - ***Make sure everyone at least gets your database (with data loaded) and environment ready before coming to the lab*** so that you can start working on the lab questions and be more productive during lab. Utilize lab hours and OH to get help.
# - Watch the video [here](important) if you want to see how to create and load database. I mentioned 1 video as a must watch, and please watch it.
# - Remember to check [slack etiquette](https://pages.github.ubc.ca/MDS-2024-25/DSCI_513_database-data-retr_students/README.html#slack-etiquette)
#
# ```{important}
# You might not be getting responses to your questions during the weekends, holidays, and off hours. ***So please make sure you start working on it early***. Make use of lab hours and office hours.
# ```
#
# ### Other announcements
# - Lecture notes have more information. Make sure you read them. Themes are just a summary of what we did in the lecture (there could be things that I haven't added to the themes). You can ignore things that are mentioned as optional in lecture notes.
# - [For all timelines, please check here](https://pages.github.ubc.ca/MDS-2024-25/DSCI_513_database-data-retr_students/README.html#timelines). If you don't see anything within the timeline I mentioned there, please post in slack.
#
# ```{margin}
# <img src="img/recap.png" width="400px">
# ```
#
# ## Recap
# - WHY and WHEN to use databases. It's benefits.
# - Relational databases. Breaking the table to reduce redundancy (we don't want anomalies).
# - Recipe for a table: Name of relation + Attributes (name and domain)
# - DDL vs DML
# - Basic keywords: `SELECT`, `FROM`, `DISTINCT`, `WHERE`, `ORDER BY`, `LIMIT`

# %% [markdown]
# ```{admonition} Recap iclicker: Following is a "student" table.
#
# | student_id | name   | age |
# |------------|--------|-----|
# | 1          | Emily   | 20  |
# | 4          | Emily  | 19  |
# | 8          | Emily  | 19  |
# | 2          | Jane   | 22  |
# | 3          | Tom    | 21  |
# | 5          | Alex   | 23  |
# | 6          | Alex    | 23  |
# | 7          | Alice  | 40  |
#
#
# What is the output of the following query?
#
#     SELECT DISTINCT name, age
#     FROM student
#     ORDER BY age
#     LIMIT 2;
#
# A.
# | name   | age |
# |--------|-----|
# | Emily   | 19  |
# | Emily    | 20  |
#
# B.
# | name   | age |
# |--------|-----|
# | Emily   | 19  |
# | Tom    | 21 |
#
# C.
# | name   | age |
# |--------|-----|
# | Emily   | 19  |
# | Emily    | 19  |
#
# D.
# | name   | age |
# |--------|-----|
# | Alice   | 40  |
# | Alex    | 23  |
#
# ```

# %% [markdown]
# ```{toggle}
# > A
#
# - Brush up on `DISTINCT` and `LIMIT` keywords.
# - By default, `ORDER BY` is ascending.
# ```

# %% [markdown]
# ## ***Todays theme:***
# - Data types (go quickly through them)
# - Filtering data (using `WHERE`)
#     - Use of `LIKE`,`ILIKE`, `IN`, `BETWEEN`, `IS NULL` (you can also prefix it with `NOT`)
#     - Combining conditions using `AND`, `OR`, `NOT` - also use of `()` to group conditions, and order of precedence
# - Column aliases using `AS`
# - Derived columns
# - Use of `CASE` keyword
# - Some inbuilt functions (go quickly through them)

# %%
# %load_ext sql
# %config SqlMagic.displaylimit = 20

# %%
# This is how you deal with credentials in a notebook
import json
import urllib.parse
## replace with your own credentials
with open('../lectures/data/credentials.json') as f:
    login = json.load(f)
    
username = login['user']
password = urllib.parse.quote(login['password'])
host = login['host']
port = login['port']
# Just printing the logo information to see I am getting the correct file and 
# information
login
# Out:
# {'host': 'localhost', 'port': 5432, 'user': 'postgres', 'password': 'postgres'}

# %% [markdown]
# This time I am connecting to the `imdb` database

# %%
# %sql postgresql://{username}:{password}@{host}:{port}/imdb

# %% [markdown]
# ## Data types (go quickly through them)
#
# >This is mostly used when creating a table, which typically follows the database design and modeling phase. As data scientists, you might not often create tables, but you will query them. However, it is beneficial to know the data types available in the database you are working with.
#
# Postgres supports
#
# - boolean
# - character
# - number
# - datetime
# - binary

# %% [markdown]
# ###  Why do I need to know about datatypes?
#
# - Of course, we want it to create a table, and that is part of our schema ( remember the recipe and Powerpuff Girls??). The database designers decide them.
#
# <img src="../lectures/img/lecture1/table_anatomy.png" width="600">
#
# ```{margin}
# <img src="img/lecture4.png" width="600">
# ```
#
# Like in the above example, we have a table called Students with 5 columns. Each column has a name and a datatype. Following how a database admin would create a table in Postgresql. (***We will learn more about DDL in lecture 4. You will know about constraints like "PRIMARY KEY"***)
#
# ```sql
# CREATE TABLE Students (
#     sid VARCHAR(255) PRIMARY KEY,
#     name VARCHAR(255),
#     login VARCHAR(255),
#     age INTEGER,
#     gpa REAL
# );
# ```
# > Since our focus is more on data retrieval. Should we need to know about data types?
#
# YES!! Sometimes, we want to apply `casting` to some columns to perform certain operations. Many of these castings are performed implicitly by the Postgres engine (remember the `DBMS` engine). But there might be a few that we need to explicitly specify. So, if we want to explicitly convert a datatype, we use the syntax below.
#
# ```sql
# CAST(<column> AS <data_type>)
#
# # specific to Postgres
#
# <column>::<data_type>
# ```
#
# For example, see a couple of cases below. DON'T WORRY IF YOU DON'T GET IT NOW. We will learn about it in this lecture and revisit this code at the end.

# %%
# %%sql
#
# SELECT
#
# -- 555 ilike '5%',
# 555::TEXT ilike '5%',
#
# -- '5' + '55', -- fails, since it doesn't do implicit casting
#
# '5'::INTEGER + '55'::INTEGER,
#
# 5/2, -- NO implicit casting, and gives integer result 2
#
# 5/2::float, -- explicit casting to float gives 2.5, so make sure you do this
#
# lower(SUBSTR('5555555', LENGTH('5555555'), 1)) IN ('5', 'a')
#
# -- lower(SUBSTR(5555555, LENGTH('5555555'), 1)) IN ('5', 'a') -- need explicit casting with substr
#
# -- lower(SUBSTR('5555555', LENGTH(5555555), 1)) IN ('5', 'a') -- need explicit casting with length
# ;
# Out:
#  * postgresql://postgres:***@localhost:5432/imdb
# 1 rows affected.
# [(True, 60, 2, 2.5, True)]

# %% [markdown]
# From the above example, it is clear that we want to know about datatypes and how to cast them. So, let us get started.
#
# So, let's learn about each of these datatypes.

# %% [markdown]
# ### Boolean

# %%
# %%sql
# SELECT
#     'TRUE'::BOOLEAN,
#     'T'::BOOLEAN,
#     '0'::BOOLEAN,
#     'NO'::BOOLEAN
# ;
# Out:
#  * postgresql://postgres:***@localhost:5432/imdb
# 1 rows affected.
# [(True, True, False, False)]

# %% [markdown]
# ### Characters
#
# The character data type is used to represent fixed-length and variable-length character strings. This type can be defined using the following keywords:
#
# - `CHAR(n)`: a string of exactly n characters padded with spaces
# - `VARCHAR(n)`: a variable set of n characters
# - `TEXT`, which is a Postgres-specific type for which there is practically no limit on the number of characters.

# %%
# %%sql
#
# SELECT
#     'Arman'::CHAR(50),
#     'Arman'::VARCHAR(50),
#     'Arman'::VARCHAR(2), -- mostly used
#     'Arman'::TEXT
# ;
# Out:
#  * postgresql://postgres:***@localhost:5432/imdb
# 1 rows affected.
# [('Arman                                             ', 'Arman', 'Ar', 'Arman')]

# %% [markdown]
# ```{seealso}
# Wanna know more about the difference between CHAR and VARCHAR? Check out this [link](https://www.geeksforgeeks.org/char-vs-varchar-in-sql/)
# ```

# %% [markdown]
# ```{admonition} Optional discussion: What is the difference between CHAR and VARCHAR?
# <img src="img/discuss.png" width="120">
# ```

# %% [markdown]
# ```{toggle}
# - Char
#     - Used to store character string value of fixed length.
#     - faster than Varchar
#     - static memory allocation
#
# - Varchar
#     - Used to store character string value of variable length.
#     - slower than char
#     - dynamic memory allocation
# ```

# %% [markdown]
# ### Numbers
#
# Numerical values in Postgres belong to the following general categories:
# - Integers
# - Floating-point numbers
# - Arbitrary precision numbers
#
# ```{note}
# Don't want to memorize these ranges.
# ```
# **Integers:**
#
# | Name     | Storage Size | Description                | Range                                        |
# |----------|--------------|----------------------------|----------------------------------------------|
# | `smallint` | 2 bytes      | small-range integer        | -32768 to +32767                             |
# | `integer`  | 4 bytes      | typical choice for integer | -2147483648 to +2147483647                   |
# | `bigint`   | 8 bytes      | large-range integer        | -9223372036854775808 to +9223372036854775807 |
# | `serial`      | 4 bytes | auto-incrementing integer       | 1 to 2147483647          |
# | `bigserial`   | 8 bytes | large auto-incrementing integer | 1 to 9223372036854775807 |
#
# **Floating-point numbers:**
#
# | Name     | Storage Size | Description                | Range                                        |
# |----------|--------------|----------------------------|----------------------------------------------|
# | `real`             | 4 bytes  | variable-precision, inexact     | at least 6 decimal digits (implementation dependent) |
# | `double precision` | 8 bytes  | variable-precision, inexact     | at least 15 decimal digits (implementation dependent) |
#
# **Arbitrary precision numbers**
#
# | Name     | Storage Size | Description                | Range                                        |
# |----------|--------------|----------------------------|----------------------------------------------|
# | `numeric`          | variable | user-specified precision, exact | 131072 digits before and 16383 digits after the decimal point |
# | `decimal`          | variable | user-specified precision, exact | 131072 digits before and 16383 digits after the decimal point |

# %%
# %%sql
# SELECT 44.7874::SMALLINT,
# 44.7874::INT,
# 5/2, -- missing precision
# 5/2::real,
# '183.123456789'::real,
# '183.123456789659986566656'::double precision,
# '183.123456789659986566656'::numeric(25, 22); -- Total number of digits is 25 and 22 digits after decimal
# Out:
#  * postgresql://postgres:***@localhost:5432/imdb
# 1 rows affected.
# [(45, 45, 2, 2.5, 183.12346, 183.12345678966, Decimal('183.1234567896599865666560'))]

# %% [markdown]
# ```{admonition} Discussion: Why do we want to use numeric over float (real and double precision)?
# <img src="img/discuss.png" width="120">
# ```

# %% [markdown]
# ```{toggle}
# - Numeric values have a much larger range than floats.
# ```

# %% [markdown]
# ```{admonition} Discussion: Why do we want to use float (real and double precision) over numeric?
# <img src="img/discuss.png" width="120">
# ```

# %% [markdown]
# ```{toggle}
# - If the number's precision is within the float's range, then floating-point values will be faster to work with.
# ```

# %% [markdown]
# ### Date and time

# %%
# %%sql
# SELECT
#     '1/23/2021'::DATE,
#     'today'::DATE,
#     'tomorrow'::DATE,
#     '2:24pm'::TIME,
#     '2:24 PM PST'::TIME WITH TIME ZONE,
#         'now'::TIME WITH TIME ZONE,
#         '2021-11-18 8:30:00'::TIMESTAMP,
#          '2021-11-18 8:30:00'::TIMESTAMPTZ;
# Out:
#  * postgresql://postgres:***@localhost:5432/imdb
# 1 rows affected.
# [(datetime.date(2021, 1, 23), datetime.date(2024, 11, 19), datetime.date(2024, 11, 20), datetime.time(14, 24), datetime.time(14, 24, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=57600))), datetime.time(15, 13, 11, 778485, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=57600))), datetime.datetime(2021, 11, 18, 8, 30), datetime.datetime(2021, 11, 18, 8, 30, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=57600))))]

# %%
# %sql SHOW TIMEZONE;
# Out:
#  * postgresql://postgres:***@localhost:5432/imdb
# 1 rows affected.
# [('America/Vancouver',)]

# %% [markdown]
# ```{admonition} As you can see, the timezone value here is "America/Vancouver". From where do you think we are getting this timezone value?
#
# <img src="img/discuss.png" width="120">
# ```

# %% [markdown]
# ```{toggle}
# The local server timezone is what it is getting
# ```
#
# Now, let us explicitly set a timezone and see what happens.

# %%
# %sql SET timezone = 'America/New_York';
# -- SET timezone = 'America/Los_Angeles'';
# Out:
#  * postgresql://postgres:***@localhost:5432/imdb
# Done.
# []

# %%
# %sql SHOW TIMEZONE;
# Out:
#  * postgresql://postgres:***@localhost:5432/imdb
# 1 rows affected.
# [('America/New_York',)]

# %%
# %%sql
#
# SELECT
#     '1/23/2021'::DATE,
#     'today'::DATE,
#     'tomorrow'::DATE,
#     '2:24pm'::TIME,
#     '2:24 PM PST'::TIME WITH TIME ZONE,
#         'now'::TIME WITH TIME ZONE,
#         '2021-11-18 8:30:00'::TIMESTAMP,
#          '2021-11-18 8:30:00'::TIMESTAMPTZ;
# Out:
#  * postgresql://postgres:***@localhost:5432/imdb
# 1 rows affected.
# [(datetime.date(2021, 1, 23), datetime.date(2024, 11, 19), datetime.date(2024, 11, 20), datetime.time(14, 24), datetime.time(14, 24, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=57600))), datetime.time(18, 13, 11, 867711, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))), datetime.datetime(2021, 11, 18, 8, 30), datetime.datetime(2021, 11, 18, 8, 30, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))))]

# %% [markdown]
# ```{important}
# Postgres does not store timezone information. It always internally stores TIMESTAMPTZ in UTC value and does the back-conversion using the local time zone of the database server or the timezone specified by the user.
# ```

# %% [markdown]
# ```{margin}
# <img src="img/null.gif" width="600">
# ```
# ### Nulls
#
# ```{note}
# You will see how to filter NULL values in the next section.
# ```
#
# A null is a marker indicating that a column's value is unknown or not entered yet. A null is not equal to 0 or an empty string. In fact, a null is not even equal to another null!!!
#
# How different environments show nulls:
#
# - ipython-sql -> None
# - psql -> blank space
# - pgAdmin -> [null]

# %% [markdown]
# ## More SQL keywords
#
# >Following topics are quite important for Data scientists. Let's look into some common traps new SQL programmers can fall into.
#
# ```{margin}
# <img src="img/trap.gif" width="400px">
# ```

# %% [markdown]
# ### WHERE (Filtering rows)

# %%
# %%sql
#
# SELECT * -- * returns all columns
# FROM movies
# WHERE title = 'Lost Highway' ;
# Out:
#  * postgresql://postgres:***@localhost:5432/imdb
# 1 rows affected.
# [(10116922, 'Lost Highway', None, 1997, None, 134, 7.6, 120549)]

# %% [markdown]
# ```{admonition} iclicker: Based on the below 3 queries, answer the following options:
#
# ***Query 1:***
#
#     SELECT *
#     FROM movies
#     WHERE title = 'Lost Highway' ;
#
# ***Query 2:***
#
#     SELECT *
#     FROM movies
#     WHERE title = 'lost highway' ;
#
# ***Query 3:***
#
#     SELECT *
#     FROM movies
#     WHERE title = "Lost Highway" ;
#
#
# The following are options (select the best that apply):
#
# A) Only Query 1 and Query 2 will return the same result
#
# B) Only Query 1 and Query 3 will return the same result
#
# C) Queries 1, 2, and 3 will return the same result
#
# D) None of the queries will return the same result
#
# ```

# %% [markdown]
# ```{toggle}
# Answer: D
#
# ```{important}
# - Having "Lost Highway" instead of 'Lost Highway' won't work. So, it is a single quote that you want to use.
# - Be careful. Whatever in the WHERE clause is case sensitive. So 'Lost Highway' is not equal to 'lost highway'
# ```

# %% [markdown]
# Here are things that usually go into a where clause
#
# - ***Condition and operator***
#
# | Condition        | Operator                        |
# |------------------|---------------------------------|
# | Comparison       | `=`, `<>`, `<`, `<=`, `>`, `>=` |
# | Pattern matching | `LIKE`                          |
# | Range            | `BETWEEN`                       |
# | List             | `IN`                            |
# | Null testing     | `IS NULL`                       |
#
# - ***Combining conditions with logical operators***
#
# We can combine multiple conditions logical/boolean operators AND, OR, and NOT.
#
# When there are multiple logical operators,
# - ***NOT is evaluated first***,
# - ***then AND*** and
# - ***finally OR***.
#
# ```{margin}
# <img src="img/notandor.png" >
# ```
# However, we can use parentheses to change the order of evaluation.
#
# ```{caution}
# Be extremely careful when using NOT, AND, and OR together in a single condition.
# ```

# %%
# %%sql
#
# SELECT * FROM movies
# WHERE start_year = 2015 OR start_year = 2018 AND rating > 8;
# Out:
#  * postgresql://postgres:***@localhost:5432/imdb
# 1048 rows affected.
# [(10369610, 'Jurassic World', None, 2015, None, 124, 7.0, 547391),
#  (10420293, 'The Stanford Prison Experiment', None, 2015, None, 122, 6.9, 33319),
#  (10478970, 'Ant-Man', None, 2015, None, 117, 7.3, 517941),
#  (10790770, 'Miles Ahead', None, 2015, None, 100, 6.4, 8650),
#  (10884732, 'The Wedding Ringer', None, 2015, None, 101, 6.6, 67575),
#  (11533089, 'Tab Hunter Confidential', None, 2015, None, 90, 7.8, 2852),
#  (11596363, 'The Big Short', None, 2015, None, 130, 7.8, 318033),
#  (11598642, 'Z for Zachariah', None, 2015, None, 98, 6.0, 25985),
#  (11618448, 'Racing Extinction', None, 2015, None, 90, 8.3, 7042),
#  (11638355, 'The Man from U.N.C.L.E.', None, 2015, None, 116, 7.3, 245184),
#  (11655441, 'The Age of Adaline', None, 2015, None, 112, 7.2, 141949),
#  (11658801, 'Freeheld', None, 2015, None, 103, 6.6, 10772),
#  (11663202, 'The Revenant', None, 2015, None, 156, 8.0, 636721),
#  (11666801, 'The Duff', None, 2015, None, 101, 6.5, 76639),
#  (11674771, 'Entourage', None, 2015, None, 104, 6.6, 72367),
#  (11683048, 'De Palma', None, 2015, None, 110, 7.4, 4202),
#  (11698654, 'Catching the Sun', None, 2015, None, 75, 6.8, 517),
#  (11702429, 'Eisenstein in Guanajuato', None, 2015, None, 105, 6.2, 2317),
#  (11708135, 'Elser', None, 2015, None, 114, 7.0, 7455),
#  (11727770, 'Absolutely Anything', None, 2015, None, 85, 6.0, 35659),
#  (11727776, 'Scouts Guide to the Zombie Apocalypse', None, 2015, None, 93, 6.3, 41246),
#  (11754656, 'The Little Prince', 'Le Petit Prince', 2015, None, 108, 7.7, 51035),
#  (11772288, 'Danny Collins', None, 2015, None, 106, 7.0, 27967),
#  (11781922, 'No Escape', None, 2015, None, 103, 6.8, 71442),
#  (11798684, 'Southpaw', None, 2015, None, 124, 7.4, 203336),
#  (11810683, 'Little Boy', None, 2015, None, 106, 7.4, 21183),
#  (11823672, 'Chappie', None, 2015, None, 120, 6.8, 216627),
#  (11837562, 'A Royal Night Out', None, 2015, None, 97, 6.5, 8488),
#  (11850457, 'Sisters', None, 2015, None, 118, 6.0, 59825),
#  (11856057, 'Phantom Boy', None, 2015, None, 84, 6.6, 1200),
#  (11918911, 'Un + une', None, 2015, None, 115, 6.2, 1548),
#  (11941478, 'The Portuguese Falcon', 'Capitão Falcão', 2015, None, 106, 7.1, 1625),
#  (11951266, 'The Hunger Games: Mockingjay - Part 2', None, 2015, None, 137, 6.5, 258722),
#  (11964418, 'Tomorrowland', None, 2015, None, 130, 6.4, 163382),
#  (11976009, 'Victor Frankenstein', None, 2015, None, 110, 6.0, 48443),
#  (12002868, 'Anegan', None, 2015, None, 154, 6.7, 2624),
#  (12006295, 'The 33', None, 2015, None, 127, 6.9, 32849),
#  (12056771, 'A Bigger Splash', None, 2015, None, 125, 6.4, 24068),
#  (12057392, 'Eye in the Sky', None, 2015, None, 102, 7.3, 73486),
#  (12084957, 'The Antwerp Dolls', None, 2015, None, 90, 6.2, 623),
#  (12091935, 'Mr. Right', None, 2015, None, 95, 6.3, 43023),
#  (12096673, 'Inside Out', None, 2015, None, 95, 8.2, 550606),
#  (12097331, 'The Family Fang', None, 2015, None, 105, 6.1, 7125),
#  (12097298, 'McFarland, USA', None, 2015, None, 129, 7.4, 32386),
#  (12118624, 'The Final Girls', None, 2015, None, 88, 6.6, 30921),
#  (12126355, 'San Andreas', None, 2015, None, 114, 6.0, 196468),
#  (12131532, 'Hidden', None, 2015, None, 84, 6.4, 17886),
#  (12133196, 'Born to Be Blue', None, 2015, None, 97, 6.9, 7260),
#  (12140379, 'Self/less', None, 2015, None, 117, 6.5, 82680),
#  (12168180, 'Nise: The Heart of Madness', 'Nise: O Coração da Loucura', 2015, None, 106, 7.7, 1897),
#  (12181282, 'A Patch of Fog', None, 2015, None, 92, 6.5, 1032),
#  (12186848, 'Landmine Goes Click', None, 2015, None, 105, 6.0, 4537),
#  (12191765, 'One Wild Moment', "Un moment d'égarement", 2015, None, 105, 6.3, 7092),
#  (12210769, 'Liza the Fox-Fairy', 'Liza, a rókatündér', 2015, None, 98, 7.6, 7534),
#  (12217859, 'Louder Than Bombs', None, 2015, None, 109, 6.6, 10919),
#  (12224026, 'Home', None, 2015, None, 94, 6.6, 86931),
#  (12226630, 'After Words', None, 2015, None, 91, 6.5, 675),
#  (12245003, 'Miss You Already', None, 2015, None, 112, 6.8, 15963),
#  (12248739, 'Departure', None, 2015, None, 109, 6.7, 1763),
#  (12262161, 'Sunset Song', None, 2015, None, 135, 6.4, 3033),
#  (12262345, 'Long Way North', 'Tout en haut du monde', 2015, None, 81, 7.3, 2149),
#  (12271563, 'Forsaken', None, 2015, None, 90, 6.3, 9414),
#  (12273657, 'True Story', None, 2015, None, 99, 6.3, 55358),
#  (12279373, 'The SpongeBob Movie: Sponge Out of Water', None, 2015, None, 92, 6.0, 44619),
#  (12290397, 'Alaska', None, 2015, None, 125, 6.8, 1526),
#  (12293640, 'Minions', None, 2015, None, 91, 6.4, 197815),
#  (12296747, 'Come What May', "En mai, fais ce qu'il te plaît", 2015, None, 114, 6.7, 812),
#  (12302966, 'I', None, 2015, None, 188, 7.3, 17694),
#  (12313306, 'The Real Miyagi', None, 2015, None, 80, 7.2, 659),
#  (12321502, 'Uncanny', None, 2015, None, 91, 6.3, 4793),
#  (12338424, 'Tumbledown', None, 2015, None, 105, 6.2, 6070),
#  (12349144, 'Mississippi Grind', None, 2015, None, 108, 6.4, 17751),
#  (12361509, 'The Intern', None, 2015, None, 121, 7.1, 195500),
#  (12361746, 'Haraamkhor', None, 2015, None, 90, 6.4, 3113),
#  (12378776, 'Man Up', None, 2015, None, 73, 6.0, 535),
#  (12378830, "Sommeren '92", None, 2015, None, 93, 6.9, 2535),
#  (12379713, 'Spectre', None, 2015, None, 148, 6.8, 357516),
#  (12381111, 'Brooklyn', None, 2015, None, 117, 7.5, 119408),
#  (12381249, 'Mission: Impossible - Rogue Nation', None, 2015, None, 131, 7.4, 317878),
#  (12381941, 'Focus', None, 2015, None, 105, 6.6, 195740),
#  (12385115, 'Jaco', None, 2015, None, 110, 7.6, 850),
#  (12394063, 'Too Late', None, 2015, None, 107, 6.7, 2571),
#  (12400463, 'The Invitation', None, 2015, None, 100, 6.6, 74170),
#  (12401878, 'Anomalisa', None, 2015, None, 90, 7.3, 59294),
#  (12402927, 'Carol', None, 2015, None, 118, 7.2, 103186),
#  (12415458, 'The Wolfpack', None, 2015, None, 90, 7.0, 11215),
#  (12424988, 'Gabbar is Back', None, 2015, None, 128, 7.1, 21345),
#  (12442080, 'Chuck Norris vs. Communism', None, 2015, None, 78, 7.5, 1842),
#  (12446980, 'Joy', None, 2015, None, 124, 6.6, 119814),
#  (12465308, 'Helen Keller vs. Nightwolves', None, 2015, None, 75, 6.6, 673),
#  (12473476, 'Be Here Now', None, 2015, None, 100, 8.7, 2863),
#  (12474958, 'Kill Your Friends', None, 2015, None, 103, 6.0, 8318),
#  (12488496, 'Star Wars: Episode VII - The Force Awakens', None, 2015, None, 138, 8.0, 795527),
#  (12494362, 'Bone Tomahawk', None, 2015, None, 132, 7.1, 73854),
#  (12503944, 'Burnt', None, 2015, None, 101, 6.6, 98061),
#  (12510894, 'Hotel Transylvania 2', None, 2015, None, 89, 6.7, 95446),
#  (12523832, 'A Girl Like Her', None, 2015, None, 91, 7.0, 6433),
#  (12534634, 'The Fencer', 'Miekkailija', 2015, None, 99, 7.1, 4135),
#  (12544766, 'Admiral', 'Michiel de Ruyter', 2015, None, 151, 7.0, 8165),
#  (12550858, 'Antikaci', None, 2015, None, 84, 6.1, 1017),
#  (12552394, 'Barney Thomson', 'The Legend of Barney Thomson', 2015, None, 96, 6.3, 4736),
#  (12555736, 'The Second Best Exotic Marigold Hotel', None, 2015, None, 122, 6.5, 29424),
#  (12556936, 'No Men Beyond This Point', None, 2015, None, 80, 6.3, 1371),
#  (12561572, 'Get Hard', None, 2015, None, 100, 6.0, 112972),
#  (12582496, 'Me and Earl and the Dying Girl', None, 2015, None, 105, 7.7, 114622),
#  (12585160, 'Son of Mine', 'Gluckauf', 2015, None, 102, 7.0, 695),
#  (12611652, 'Virgin Mountain', 'Fúsi', 2015, None, 94, 7.5, 6689),
#  (12631186, 'Baahubali: The Beginning', 'Bahubali: The Beginning', 2015, None, 159, 8.1, 94989),
#  (12637276, 'Ted 2', None, 2015, None, 115, 6.3, 169623),
#  (12654572, 'The Preppie Connection', None, 2015, None, 95, 6.1, 3305),
#  (12719848, 'Everest', None, 2015, None, 121, 7.1, 183746),
#  (12718440, 'Moonwalkers', None, 2015, None, 107, 6.1, 7907),
#  (12726560, 'The Longest Ride', None, 2015, None, 123, 7.1, 71490),
#  (12735996, 'Endless Night', 'Nadie quiere la noche', 2015, None, 104, 6.2, 1242),
#  (12749282, 'Papa Hemingway in Cuba', None, 2015, None, 110, 6.3, 1239),
#  (12815902, 'The Childhood of a Leader', None, 2015, None, 115, 6.1, 5106),
#  (12848292, 'Pitch Perfect 2', None, 2015, None, 115, 6.4, 133004),
#  (12848324, 'Touched with Fire', None, 2015, None, 106, 6.2, 2015),
#  (12865822, 'All the World in a Design School', None, 2015, None, 59, 8.4, 1270),
#  (12870648, 'Amy', None, 2015, None, 128, 7.8, 44660),
#  (12872462, 'Mistress America', None, 2015, None, 84, 6.7, 22928),
#  (12872750, 'Shaun the Sheep Movie', None, 2015, None, 85, 7.3, 33614),
#  (12886632, 'Enclave', 'Enklava', 2015, None, 92, 7.7, 1808),
#  (12888046, 'Ip Man 3', 'Yip Man 3', 2015, None, 105, 7.1, 39913),
#  (12904670, 'Chasing Robert Barker', None, 2015, None, 90, 6.7, 558),
#  (12909116, 'Wolf Totem', 'Le dernier loup', 2015, None, 121, 6.7, 5135),
#  (12910904, 'The Dressmaker', None, 2015, None, 119, 7.1, 48003),
#  (12917388, 'Kidnapping Mr. Heineken', None, 2015, None, 95, 6.1, 18039),
#  (12933794, 'Man vs Snake: The Long and Twisted Tale of Nibbler', None, 2015, None, 92, 7.0, 2241),
#  (12935476, 'Far from the Madding Crowd', None, 2015, None, 119, 7.1, 41700),
#  (12943352, 'November 10th', 'Battle of Surabaya', 2015, None, 99, 7.2, 2678),
#  (12948840, 'Life', None, 2015, None, 111, 6.0, 6756),
#  (12950052, 'Bravetown', 'Strings', 2015, None, 112, 6.2, 3386),
#  (12989350, 'Dare to Be Wild', None, 2015, None, 100, 6.4, 1143),
#  (12978576, 'Bill', None, 2015, None, 94, 6.5, 1708),
#  (12980554, 'The Girl in the Book', None, 2015, None, 86, 6.1, 3776),
#  (12980626, 'Twinsters', None, 2015, None, 89, 7.6, 4504),
#  (13014454, 'Hunter', None, 2015, None, 83, 7.6, 559),
#  (13013610, 'Mia Madre', 'Mia madre', 2015, None, 106, 6.8, 6297),
#  (13020666, 'Unbranded', None, 2015, None, 106, 7.4, 1278),
#  (13043252, 'Parched', None, 2015, None, 116, 7.6, 4256),
#  (13064298, 'Man Up', None, 2015, None, 88, 6.8, 45391),
#  (13065132, 'He Named Me Malala', None, 2015, None, 88, 6.9, 4237),
#  (13065978, 'Bucharest Non Stop', 'Bucuresti NonStop', 2015, None, 86, 7.4, 884),
#  (13072876, 'Queen Mimi', None, 2015, None, 75, 7.3, 520),
#  (13076658, 'Creed', None, 2015, None, 133, 7.6, 229625),
#  (13077214, 'Suffragette', None, 2015, None, 106, 6.9, 34865),
#  (13079380, 'Spy', None, 2015, None, 119, 7.0, 216783),
#  (13083008, 'The Program', None, 2015, None, 99, 6.5, 14783),
#  (13090670, 'Advantageous', None, 2015, None, 90, 6.2, 3996),
#  (13092790, 'Two Down', None, 2015, None, 92, 7.2, 1089),
#  (13108244, 'Capsule', None, 2015, None, 91, 6.2, 6753),
#  (13110770, 'Road Hard', None, 2015, None, 98, 6.1, 1693),
#  (13118452, 'Circle', None, 2015, None, 87, 6.0, 32437),
#  (13117504, 'Argo 2', None, 2015, None, 91, 6.9, 1709),
#  (13113456, "Doomed: The Untold Story of Roger Corman's the Fantastic Four", None, 2015, None, 85, 6.9, 679),
#  (13118874, 'Back in Time', None, 2015, None, 95, 6.3, 3730),
#  (13127698, 'Sanctuary', 'Freistatt', 2015, None, 104, 7.2, 1237),
#  (13132632, 'Misery Loves Comedy', None, 2015, None, 94, 6.3, 1034),
#  (13136646, 'Soulless 2', 'Dukhless 2', 2015, None, 103, 6.3, 1446),
#  (13147312, 'Desierto', None, 2015, None, 88, 6.0, 8419),
#  (13141498, 'The Nightmare', 'Der Nachtmahr', 2015, None, 92, 6.6, 2327),
#  (13142366, 'Take Me to the River', None, 2015, None, 84, 6.3, 1640),
#  (13148502, 'Tamasha', None, 2015, None, 139, 7.2, 20427),
#  (13152624, 'Trainwreck', None, 2015, None, 125, 6.2, 123342),
#  (13153532, 'Violence', None, 2015, None, 84, 7.3, 1141),
#  (13162938, 'The True Cost', None, 2015, None, 92, 7.7, 6042),
#  (13165612, 'Sleeping with Other People', None, 2015, None, 101, 6.5, 36900),
#  (13163336, 'Uncle Nick', None, 2015, None, 93, 6.9, 3027),
#  (13168230, 'Mr. Holmes', None, 2015, None, 104, 6.9, 58775),
#  (13169770, 'Retribution', 'El desconocido', 2015, None, 102, 6.6, 7799),
#  (13170900, 'Idealisten', None, 2015, None, 114, 6.9, 1245),
#  (13170832, 'Room', None, 2015, None, 118, 8.2, 326042),
#  (13172532, 'The Diary of a Teenage Girl', None, 2015, None, 102, 6.9, 27489),
#  (13176980, 'Be My Cat: A Film for Anne', None, 2015, None, 87, 6.3, 835),
#  (13185602, 'Front Cover', None, 2015, None, 87, 6.3, 817),
#  (13202202, 'Palm Trees in the Snow', 'Palmeras en la nieve', 2015, None, 163, 7.4, 8511),
#  (13203606, 'Trumbo', None, 2015, None, 124, 7.5, 69862),
#  (13197766, 'Kill Zone 2', 'Saat po long 2', 2015, None, 120, 6.8, 5523),
#  (13212408, 'Beautiful Something', None, 2015, None, 97, 6.2, 646),
#  (13211400, 'Nothing in Return', 'A cambio de nada', 2015, None, 93, 6.5, 2155),
#  (13213684, '1944', None, 2015, None, 100, 7.1, 4386),
#  (13219194, 'Uncle John', None, 2015, None, 113, 6.2, 1561),
#  (13233418, 'Spare Parts', None, 2015, None, 114, 7.3, 9811),
#  (13240784, 'Sneakerheadz', None, 2015, None, 73, 6.4, 656),
#  (13253624, 'Soaked in Bleach', None, 2015, None, 90, 7.4, 10906),
#  (13252998, 'About Scout', None, 2015, None, 109, 6.5, 648),
#  (13255826, 'Drawers', None, 2015, None, 120, 7.2, 932),
#  (13270538, 'Requiem for the American Dream', None, 2015, None, 73, 8.1, 8061),
#  (13276924, 'Heist', None, 2015, None, 93, 6.1, 25236),
#  (13276944, 'The Midnight Orchestra', "L'orchestre de minuit", 2015, None, 114, 6.9, 547),
#  (13289728, 'Equals', None, 2015, None, 101, 6.1, 24782),
#  (13298600, 'The Midwife', 'Kätilö', 2015, None, 119, 6.0, 1032),
#  (13299704, 'The Babushkas of Chernobyl', None, 2015, None, 70, 7.9, 523),
#  (13300442, 'Paternity Leave', None, 2015, None, 90, 6.2, 1546),
#  (13302654, 'Jane Wants a Boyfriend', None, 2015, None, 101, 6.8, 1849),
#  (13312830, 'Youth', None, 2015, None, 124, 7.3, 65700),
#  (13306858, 'As We Were Dreaming', 'Als wir träumten', 2015, None, 117, 6.4, 1074),
#  (13312868, 'Deep Web', None, 2015, None, 90, 7.0, 8574),
#  (13317208, 'Anesthesia', None, 2015, None, 90, 6.1, 3861),
#  (13316948, 'American Ultra', None, 2015, None, 96, 6.1, 78127),
#  (13319018, 'My Name Is Emily', None, 2015, None, 94, 6.7, 789),
#  (13321300, 'MI-5', 'Spooks: The Greater Good', 2015, None, 104, 6.2, 19541),
#  (13322364, 'Concussion', None, 2015, None, 123, 7.1, 79153),
#  (13333980, 'Flytrap', None, 2015, None, 81, 7.5, 1455),
#  (13334374, 'Moor', None, 2015, None, 100, 7.7, 1122),
#  (13339354, 'A Year and Change', None, 2015, None, 93, 6.2, 627),
#  (13368222, 'Angry Indian Goddesses', None, 2015, None, 115, 7.1, 2469),
#  (13383262, 'Honeyglue', None, 2015, None, 107, 6.5, 523),
#  (13369806, 'Max', None, 2015, None, 111, 6.7, 24304),
#  (13397884, 'Sicario', None, 2015, None, 121, 7.6, 335975),
#  (13401748, 'Oddball', None, 2015, None, 95, 6.4, 2183),
#  (13409440, 'The Surprise', 'De surprise', 2015, None, 102, 6.7, 3558),
#  (13416744, 'The End of the Tour', None, 2015, None, 106, 7.3, 26457),
#  (13412684, 'Mr. Gaga', None, 2015, None, 100, 7.6, 744),
#  (13417854, 'Pocket Listing', None, 2015, None, 92, 6.7, 3917),
#  (13430416, 'Schneider vs. Bax', None, 2015, None, 96, 6.6, 2679),
#  (13450900, 'The Sea of Trees', None, 2015, None, 110, 6.1, 11851),
#  (13449292, 'Manjhi: The Mountain Man', None, 2015, None, 120, 8.0, 16530),
#  (13447364, 'Detective Byomkesh Bakshy!', None, 2015, None, 139, 7.6, 14587),
#  (13453052, '10 Days in a Madhouse', None, 2015, None, 111, 6.7, 1136),
#  (13460084, 'Jalaibee', None, 2015, None, 117, 6.6, 923),
#  (13474602, 'Little Forest: Winter/Spring', None, 2015, None, 120, 7.8, 1483),
#  (13531578, 'Traders', None, 2015, None, 90, 6.2, 2184),
#  (13471098, "Maggie's Plan", None, 2015, None, 98, 6.2, 14590),
#  (13464902, 'The Lobster', None, 2015, None, 119, 7.1, 188917),
#  (13475596, 'Anti-Social', None, 2015, None, 116, 6.1, 2134),
#  (13478962, 'My King', 'Mon roi', 2015, None, 124, 7.1, 9504),
#  (13479316, 'Parallels', None, 2015, None, 83, 6.1, 12921),
#  (13483612, 'Hamari Adhuri Kahani', None, 2015, None, 129, 6.7, 4763),
#  (13480446, 'Almost Mercy', None, 2015, None, 85, 6.0, 930),
#  (13486542, 'Mediterranea', None, 2015, None, 107, 6.5, 1252),
#  (13488710, 'The Walk', None, 2015, None, 123, 7.3, 111459),
#  (13492838, 'Next to Me', 'Pored mene', 2015, None, 95, 7.1, 1612),
#  (13495030, 'Dum Laga Ke Haisha', None, 2015, None, 110, 7.5, 15549),
#  (13501416, 'Assassination', 'Amsal', 2015, None, 140, 7.3, 5114),
#  (13504604, 'Steve McQueen: The Man & Le Mans', None, 2015, None, 102, 6.8, 1159),
#  (13508840, 'The Assassin', 'Ci ke Nie Yin Niang', 2015, None, 105, 6.3, 14406),
#  (13509426, 'Wasp', None, 2015, None, 72, 6.1, 1221),
#  (13510480, 'Spy Time', 'Anacleto: Agente secreto', 2015, None, 93, 6.1, 3461),
#  (13512072, 'Kainan 1890', None, 2015, None, 132, 7.3, 1854),
#  (13512160, 'S Is for Stanley', None, 2015, None, 78, 7.1, 712),
#  (13518012, 'Best of Enemies: Buckley vs. Vidal', 'Best of Enemies', 2015, None, 87, 7.6, 5600),
#  (13526706, 'Chevalier', None, 2015, None, 105, 6.3, 3667),
#  (13530002, 'The Night Before', None, 2015, None, 101, 6.4, 59474),
#  (13532278, 'Brothers of the Wind', None, 2015, None, 98, 6.8, 1724),
#  (13544082, '45 Years', None, 2015, None, 91, 7.1, 28429),
#  (13542188, 'April 9th', '9. april', 2015, None, 93, 6.6, 4042),
#  (13548962, 'Freeway: Crack in the System', None, 2015, None, 103, 7.1, 701),
#  (13549206, 'The Music of Strangers', None, 2015, None, 96, 7.7, 610),
#  (13564794, 'Welcome to Happiness', None, 2015, None, 108, 6.1, 555),
#  (13569230, 'Legend', None, 2015, None, 132, 6.9, 142349),
#  (13568002, 'The Witness', None, 2015, None, 89, 7.0, 3677),
#  (13587396, 'Only the Dead', None, 2015, None, 77, 7.7, 2973),
#  (13582040, 'Boomerang', None, 2015, None, 101, 6.6, 810),
#  (13577624, 'A Perfect Day', None, 2015, None, 106, 6.8, 18554),
#  (13591436, 'Night Owls', None, 2015, None, 90, 6.2, 2055),
#  (13615204, 'Harmony', 'Hâmonî', 2015, None, 119, 6.2, 652),
#  (13616916, 'The Wave', 'Bølgen', 2015, None, 105, 6.7, 29225),
#  (13627488, 'Burn Burn Burn', None, 2015, None, 106, 7.0, 1468),
#  (13638396, 'Closet Monster', None, 2015, None, 90, 7.0, 6757),
#  (13642618, 'Life Eternal', 'Das ewige Leben', 2015, None, 123, 7.2, 2090),
#  (13640682, 'I Smile Back', None, 2015, None, 85, 6.1, 4695),
#  (13646344, 'Sworn Virgin', 'Vergine giurata', 2015, None, 84, 6.4, 883),
#  (13646946, 'Attack on Titan: The Wings of Freedom', 'Gekijôban Shingeki no Kyojin Kôhen: Jiyû no tsubasa', 2015, None, 120, 7.7, 656),
#  (13661298, 'Septembers of Shiraz', None, 2015, None, 110, 6.1, 3423),
#  (13659388, 'The Martian', None, 2015, None, 144, 8.0, 695594),
#  (13667610, 'A Grain of Truth', 'Ziarno prawdy', 2015, None, 112, 6.7, 1044),
#  (13669520, 'Palio', None, 2015, None, 91, 7.3, 591),
#  (13671542, 'Holding the Man', None, 2015, None, 127, 7.4, 9006),
#  (13672742, 'Turbo Kid', None, 2015, None, 93, 6.7, 24337),
#  (13672840, 'Dragon Blade', 'Tian jiang xiong shi', 2015, None, 127, 6.0, 17020),
#  (13680410, 'Last Cab to Darwin', None, 2015, None, 123, 7.2, 3151),
#  (13682448, 'Bridge of Spies', None, 2015, None, 142, 7.6, 267242),
#  (13678192, 'Distractions', 'Häiriötekijä', 2015, None, 85, 6.8, 650),
#  (13678782, 'Badlapur', None, 2015, None, 134, 7.4, 19831),
#  (13681422, 'Uttama Villain', None, 2015, None, 171, 7.2, 2413),
#  (13686990, 'Road to La Paz', 'Camino a La Paz', 2015, None, 92, 7.1, 552),
#  (13689910, 'Miss Hokusai', 'Sarusuberi: Miss Hokusai', 2015, None, 93, 6.7, 2496),
#  (13702704, 'Bourek', None, 2015, None, 90, 7.4, 861),
#  (13697946, 'Lapland Odyssey 2', 'Napapiirin sankarit 2', 2015, None, 87, 6.0, 1483),
#  (13700804, 'Already Tomorrow in Hong Kong', None, 2015, None, 78, 6.5, 4671),
#  (13698118, 'Gangnam Blues', 'Gangnam 1970', 2015, None, 135, 6.2, 1318),
#  (13699692, 'Dude Bro Party Massacre III', None, 2015, None, 91, 6.1, 1537),
#  (13700392, 'Heidi', None, 2015, None, 111, 7.4, 3718),
#  (13702996, 'Suck Me Shakespeer 2', 'Fack ju Göhte 2', 2015, None, 115, 6.0, 10423),
#  (13705388, 'An Italian Name', 'Il nome del figlio', 2015, None, 94, 6.4, 1123),
#  (13704050, 'Remember', None, 2015, None, 94, 7.5, 19937),
#  (13707114, 'Janis: Little Girl Blue', None, 2015, None, 103, 7.4, 4595),
#  (13715122, "L'attesa", None, 2015, None, 100, 6.6, 1829),
#  (13715854, 'Bakuman', None, 2015, None, 119, 7.0, 1242),
#  (13715320, 'Irrational Man', None, 2015, None, 95, 6.6, 51599),
#  (13717510, 'The Drop Box', None, 2015, None, 79, 8.1, 604),
#  (13720724, 'Requirements to Be a Normal Person', 'Requisitos para ser una persona normal', 2015, None, 90, 6.5, 2372),
#  (13719896, 'My All-American', None, 2015, None, 118, 7.1, 5190),
#  (13722070, 'The Lady in the Van', None, 2015, None, 104, 6.7, 23673),
#  (13726252, 'Mr Calzaghe', None, 2015, None, 90, 8.0, 544),
#  (13726704, 'Experimenter', None, 2015, None, 98, 6.6, 16337),
#  (13734678, 'Them Who?', 'Loro chi?', 2015, None, 95, 6.5, 1179),
#  (13735246, 'Bajirao Mastani', None, 2015, None, 158, 7.2, 28978),
#  (13737650, 'Detective Conan: Sunflowers of Inferno', 'Meitantei Conan: Goka no himawari', 2015, None, 112, 6.3, 964),
#  (13735602, 'Latin Lover', None, 2015, None, 104, 6.0, 727),
#  (13740778, 'Mountains May Depart', 'Shan he gu ren', 2015, None, 126, 6.8, 4476),
#  (13737988, 'Wednesday 04:45', 'Tetarti 04:45', 2015, None, 116, 6.8, 1008),
#  (13742284, 'NH10', None, 2015, None, 115, 7.2, 11324),
#  (13744264, 'Pali Road', None, 2015, None, 92, 7.4, 4700),
#  (13742378, 'The Second Mother', 'Que Horas Ela Volta?', 2015, None, 112, 7.8, 11157),
#  (13754940, 'Truman', None, 2015, None, 108, 7.3, 10398),
#  (13746250, 'Sherpa', None, 2015, None, 96, 7.7, 2316),
#  (13748512, 'Hitchcock/Truffaut', None, 2015, None, 79, 7.4, 5104),
#  (13765088, 'Amongst Bees', 'Entre Abelhas', 2015, None, 100, 6.7, 1550),
#  (13756788, 'Our Little Sister', 'Umimachi Diary', 2015, None, 127, 7.5, 10109),
#  (13762974, 'A Faster Horse', None, 2015, None, 90, 6.8, 595),
#  (13763866, 'Zoom', None, 2015, None, 96, 6.1, 2419),
#  (13767372, 'Piku', None, 2015, None, 123, 7.6, 25493),
#  (13771626, 'The Brainwashing of My Dad', None, 2015, None, 90, 6.7, 682),
#  (13769594, "Jack's Apocalypse", None, 2015, None, 80, 6.3, 590),
#  (13774466, 'Ashby', None, 2015, None, 100, 6.4, 13755),
#  (13772576, 'Papeles en el viento', None, 2015, None, 98, 6.1, 852),
#  (13774694, 'Love', None, 2015, None, 135, 6.1, 38709),
#  (13775086, 'They Call Me Jeeg', 'Lo chiamavano Jeeg Robot', 2015, None, 112, 7.1, 11637),
#  (13775202, 'I Am a Hero', None, 2015, None, 126, 6.8, 4581),
#  (13779028, 'Inside Men', 'Nae-bu-ja-deul', 2015, None, 130, 7.0, 2335),
#  (13787590, 'We Are Your Friends', None, 2015, None, 96, 6.2, 33091),
#  (13791302, 'Standing Tall', 'La tête haute', 2015, None, 120, 7.0, 2993),
#  (13813310, 'Cop Car', None, 2015, None, 88, 6.3, 28099),
#  (13810760, 'Minimalism: A Documentary About the Important Things', None, 2015, None, 78, 6.7, 10081),
#  (13808342, 'Son of Saul', 'Saul fia', 2015, None, 107, 7.5, 40020),
#  (13814486, 'Bloed, Zweet & Tranen', None, 2015, None, 111, 7.1, 1452),
#  (13814316, 'The New Kid', 'Le nouveau', 2015, None, 81, 6.7, 1072),
#  (13817962, 'All About Them', 'À trois on y va', 2015, None, 86, 6.2, 927),
#  (13817652, 'Ranna', None, 2015, None, 152, 6.3, 509),
#  (13823018, 'Sparrows', 'Þrestir', 2015, None, 99, 6.8, 1349),
#  (13830162, 'A War', 'Krigen', 2015, None, 115, 7.1, 8831),
#  (13824458, 'Tangerine', None, 2015, None, 88, 7.1, 23678),
#  (13828488, 'Salam Neighbor', None, 2015, None, 75, 7.4, 543),
#  (13833746, 'The Visit: An Alien Encounter', 'The Visit', 2015, None, 83, 6.0, 671),
#  (13832914, 'War Room', None, 2015, None, 120, 6.4, 11996),
#  (13833822, 'Daft Punk Unchained', None, 2015, None, 85, 7.3, 2831),
#  (13836958, 'Shamitabh', None, 2015, None, 155, 6.8, 6531),
#  (13844362, 'The Overnight', None, 2015, None, 79, 6.1, 14987),
#  (13841866, 'Happy 140', 'Felices 140', 2015, None, 98, 6.0, 1654),
#  (13845822, 'The Little Gangster', "De Boskampi's", 2015, None, 102, 7.0, 701),
#  (13850590, 'Krampus', None, 2015, None, 98, 6.1, 56234),
#  (13848892, 'Baby', None, 2015, None, 159, 8.0, 49158),
#  (13850214, 'Dope', None, 2015, None, 103, 7.2, 77372),
#  (13852066, 'Manny Lewis', None, 2015, None, 89, 6.0, 666),
#  (13855240, 'Clean Hands', 'Schone handen', 2015, None, 108, 6.3, 1220),
#  (13859304, 'The Bronze', None, 2015, None, 100, 6.0, 9216),
#  (13859076, 'Truth', None, 2015, None, 125, 6.8, 17329),
#  (13863484, 'King Jack', None, 2015, None, 81, 7.0, 2632),
#  (13863552, 'Bajrangi Bhaijaan', None, 2015, None, 163, 8.0, 65384),
#  (13872958, 'Strobe Edge', 'Sutorobo ejji', 2015, None, 115, 6.2, 592),
#  (13865286, 'My Lonely Me', None, 2015, None, 95, 8.2, 671),
#  (13881680, 'Waffle Street', None, 2015, None, 86, 6.2, 4751),
#  (13877674, 'Men & Chicken', 'Mænd & høns', 2015, None, 104, 6.7, 9353),
#  (13879200, 'Driving While Black', None, 2015, None, 94, 7.7, 1394),
#  (13898028, 'Gayby Baby', None, 2015, None, 85, 6.5, 704),
#  (13899932, 'Call Me Lucky', None, 2015, None, 106, 7.6, 1861),
#  (13899516, 'Those People', None, 2015, None, 89, 6.5, 4959),
#  (13903322, 'The Birth of Saké', None, 2015, None, 90, 7.3, 841),
#  (13907858, 'Ever Been to the Moon?', 'Sei mai stata sulla luna?', 2015, None, 90, 6.1, 880),
#  (13908598, 'Lamb', None, 2015, None, 97, 6.3, 1729),
#  (13909336, 'Worlds Apart', 'Enas allos kosmos', 2015, None, 113, 7.4, 7243),
#  (13914324, 'Eternal Summer', 'Odödliga', 2015, None, 106, 6.4, 562),
#  (13910602, 'I Am Chris Farley', None, 2015, None, 96, 7.5, 3024),
#  (13917118, 'Hector', None, 2015, None, 87, 6.9, 1390),
#  (13952226, 'Prophecy', 'Yokokuhan', 2015, None, 119, 6.5, 517),
#  (13955894, 'Girl Asleep', None, 2015, None, 77, 6.2, 2294),
#  (13962848, 'Welcome to Leith', None, 2015, None, 85, 7.0, 3590),
#  (13977462, 'Full Out', None, 2015, None, 90, 6.4, 1739),
#  (13978720, '4th Man Out', 'Fourth Man Out', 2015, None, 86, 6.7, 8551),
#  (13982482, 'Press 1 for Tamil', 'Tamiluku En Ondrai Aluthavum', 2015, None, 141, 7.0, 803),
#  (13986532, 'Tig', None, 2015, None, 95, 7.4, 2222),
#  (14000670, 'Mifune: The Last Samurai', None, 2015, None, 80, 7.2, 726),
#  (14008758, 'Black', None, 2015, None, 95, 7.1, 3620),
#  (14010918, 'The Throne', 'Sado', 2015, None, 125, 7.0, 1659),
#  (14016226, 'The Resurrection of Jake the Snake', None, 2015, None, 93, 7.9, 2552),
#  (14016994, 'Why Me?', 'De ce eu?', 2015, None, 125, 7.5, 1954),
#  (14024944, 'Main Aur Charles', None, 2015, None, 119, 6.3, 1485),
#  (14022440, '21 Nights with Pattie', 'Vingt et une nuits avec Pattie', 2015, None, 115, 6.2, 519),
#  (14025514, 'Suburra', None, 2015, None, 130, 7.4, 15349),
#  (14027270, 'The Crossing 2', None, 2015, None, 131, 6.0, 627),
#  (14034452, 'Hyena Road', None, 2015, None, 120, 6.5, 6364),
#  (14047104, 'Enakkul Oruvan', None, 2015, None, 136, 7.8, 1367),
#  (14046784, 'Maze Runner: The Scorch Trials', None, 2015, None, 131, 6.3, 205043),
#  (14048668, 'Band of Robbers', None, 2015, None, 95, 6.0, 3708),
#  (14056738, 'Do You Believe?', None, 2015, None, 120, 6.0, 6579),
#  (14058210, 'Operações Especiais', None, 2015, None, 99, 6.4, 1292),
#  (14062536, 'Green Room', None, 2015, None, 95, 7.0, 93748),
#  (14058500, 'A Perfect Man', 'Un homme idéal', 2015, None, 104, 6.7, 2883),
#  (14065414, 'A Good American', None, 2015, None, 100, 7.3, 822),
#  (14072352, 'Magallanes', None, 2015, None, 109, 7.4, 799),
#  (14071498, 'Life in Color', None, 2015, None, 86, 6.5, 933),
#  (14075520, 'Ventoux', None, 2015, None, 108, 6.4, 1099),
#  (14076756, 'Being Evel', None, 2015, None, 99, 7.1, 829),
#  (14080386, 'Sardaar Ji', None, 2015, None, 141, 6.4, 1219),
#  (14082596, 'The Russian Woodpecker', None, 2015, None, 80, 6.9, 1213),
#  (14080768, 'Summertime', 'La belle saison', 2015, None, 105, 6.7, 3236),
#  (14082068, 'Dheepan', None, 2015, None, 115, 7.2, 12630),
#  (14083850, 'Belle & Sebastian: The Adventure Continues', "Belle et Sébastien, l'aventure continue", 2015, None, 97, 6.6, 958),
#  (14085502, 'Sum of Histories', 'Terug Naar Morgen', 2015, None, 86, 6.8, 679),
#  (14085084, 'Disorder', 'Maryland', 2015, None, 98, 6.2, 5143),
#  (14093680, 'My Skinny Sister', 'Min lilla syster', 2015, None, 95, 6.7, 1320),
#  (14112208, 'Kuttram Kadithal', None, 2015, None, 120, 8.1, 638),
#  (14104022, 'People Places Things', None, 2015, None, 85, 6.9, 7616),
#  (14117066, 'Meeruthiya Gangsters', None, 2015, None, 129, 7.2, 523),
#  (14119590, 'Initiation Love', 'Inishiêshon rabu', 2015, None, 110, 7.1, 759),
#  (14125856, 'For Grace', None, 2015, None, 92, 7.4, 716),
#  (14116116, 'My Internship in Canada', "Guibord s'en va-t-en guerre", 2015, None, 108, 6.9, 730),
#  (14126304, 'Cartel Land', None, 2015, None, 100, 7.4, 16880),
#  (14126312, '3½ Minutes, Ten Bullets', None, 2015, None, 98, 7.2, 1616),
#  (14131686, 'I Want to Live', None, 2015, None, 106, 6.6, 2016),
#  (14135844, 'Ixcanul', None, 2015, None, 93, 7.1, 2410),
#  (14137902, 'Dark Horse', None, 2015, None, 85, 7.3, 925),
#  (14145178, 'Listen to Me Marlon', None, 2015, None, 103, 8.2, 6447),
#  (14142022, 'Italiano medio', None, 2015, None, 90, 6.1, 2296),
#  (14153324, 'Tjuvheder', None, 2015, None, 92, 7.0, 1356),
#  (14154756, 'Avengers: Infinity War', None, 2018, None, 149, 8.5, 711500),
#  (14158834, '8 Seconds', None, 2015, None, 120, 6.5, 1704),
#  (14161074, 'Presenting Princess Shaw', None, 2015, None, 83, 6.8, 501),
#  (14161932, 'Prince', 'Prins', 2015, None, 78, 6.5, 1186),
#  (14163264, 'Sperm Whale', None, 2015, None, 87, 6.3, 3097),
#  (14168502, 'French Blood', 'Un Français', 2015, None, 98, 6.2, 911),
#  (14163636, 'Florida', 'Floride', 2015, None, 110, 6.5, 567),
#  (14163644, 'The Sweet Escape', 'Comme un avion', 2015, None, 105, 6.4, 1121),
#  (14173478, 'Journey to the Shore', 'Kishibe no tabi', 2015, None, 127, 6.2, 1201),
#  (14176826, "Look Who's Back", 'Er ist wieder da', 2015, None, 116, 7.1, 36631),
#  (14176556, 'Two Friends', 'Les deux amis', 2015, None, 100, 6.0, 1278),
#  (14178092, 'The Gift', None, 2015, None, 108, 7.0, 126061),
#  (14187590, 'Battalion', 'Batalon', 2015, None, 120, 6.5, 1132),
#  (14188202, "Prophet's Prey", None, 2015, None, 90, 7.3, 1305),
#  (14192656, 'Chuye Dile Mon', None, 2015, None, 156, 7.2, 1370),
#  (14192740, 'Limonata', None, 2015, None, 110, 7.5, 9386),
#  (14195278, 'Telling Tales', 'Bana Masal Anlatma', 2015, None, 103, 7.6, 13283),
#  (14195368, 'Flying Colors', 'Birigyaru', 2015, None, 117, 7.4, 2143),
#  (14206218, 'The Propaganda Game', None, 2015, None, 98, 6.8, 4176),
#  (14208868, 'Ja, ik wil!', None, 2015, None, 96, 6.2, 669),
#  (14209900, 'Fresh Dressed', None, 2015, None, 90, 6.5, 804),
#  (14215810, 'River', None, 2015, None, 89, 6.0, 1891),
#  (14211516, 'The Thread', None, 2015, None, 61, 6.2, 580),
#  (14216908, 'Courted', "L'hermine", 2015, None, 98, 6.6, 1882),
#  (14216934, 'Frau Müller muss weg!', None, 2015, None, 83, 6.2, 1398),
#  (14228816, 'In Harmony', 'En équilibre', 2015, None, 87, 6.3, 609),
#  (14223366, 'Parisienne', 'Peur de rien', 2015, None, 119, 6.6, 568),
#  (14226388, 'Victoria', None, 2015, None, 138, 7.7, 45948),
#  (14228294, 'Les Cowboys', 'Les cowboys', 2015, None, 104, 6.7, 1829),
#  (14235644, 'The Empire of Corpses', 'Shisha no teikoku', 2015, None, 120, 6.0, 845),
#  (14239726, 'Tanna', None, 2015, None, 104, 6.9, 3714),
#  (14246854, 'Coconut Hero', None, 2015, None, 97, 6.3, 866),
#  (14246894, 'The Paradise Suite', None, 2015, None, 123, 7.2, 1384),
#  (14238858, 'The Fits', None, 2015, None, 72, 6.7, 4103),
#  (14247428, 'Endorphine', None, 2015, None, 84, 6.2, 599),
#  (14253360, 'The Himalayas', 'Himalaya', 2015, None, 124, 6.4, 815),
#  (14258292, 'Yennai Arindhaal', None, 2015, None, 168, 7.3, 7414),
#  (14266638, 'Krisha', None, 2015, None, 83, 7.2, 6156),
#  (14267026, 'Hell House LLC', None, 2015, None, 93, 6.4, 6136),
#  (14276752, 'Mojin - The Lost Legend', 'Xun long jue', 2015, None, 127, 6.0, 3130),
#  (14270516, 'Grandma', None, 2015, None, 79, 6.7, 13870),
#  (14275910, 'The Complexity of Happiness', 'La felicità è un sistema complesso', 2015, None, 117, 6.1, 652),
#  (14279684, 'Mili', None, 2015, None, 114, 6.0, 613),
#  (14283358, 'Seasons', 'Les saisons', 2015, None, 96, 7.3, 1333),
#  (14285198, 'Under Electric Clouds', 'Pod elektricheskimi oblakami', 2015, None, 138, 6.3, 677),
#  (14288636, 'James White', None, 2015, None, 85, 7.1, 5391),
#  (14291066, 'B-Movie: Lust & Sound in West-Berlin 1979-1989', None, 2015, None, 92, 7.9, 1616),
#  (14292420, 'Ville-Marie', None, 2015, None, 101, 6.1, 643),
#  (14292554, 'Journey to Space', None, 2015, None, 45, 6.4, 597),
#  (14293752, 'Gascoigne', None, 2015, None, 90, 7.1, 2084),
#  (14298958, 'Sweet Bean', 'An', 2015, None, 113, 7.3, 7411),
#  (14306116, '3 Bahadur', None, 2015, None, 94, 7.4, 513),
#  (14316236, 'The Black Panthers: Vanguard of the Revolution', None, 2015, None, 115, 7.3, 1537),
#  (14315956, 'Oneului yeonae', None, 2015, None, 118, 6.2, 1007),
#  (14307880, 'Digimon Adventure tri: Reunion', 'Digimon Adventure tri. Saikai', 2015, None, 96, 7.6, 1238),
#  (14323536, "The Emperor's New Clothes", None, 2015, None, 101, 7.1, 1248),
#  (14328756, 'Ebar Shabor', None, 2015, None, 160, 7.3, 1086),
#  (14328798, 'Masss', None, 2015, None, 151, 6.0, 3172),
#  (14333674, 'Hunterrr', None, 2015, None, 141, 7.0, 5174),
#  (14357170, 'A la mala', None, 2015, None, 99, 6.3, 2182),
#  (14344878, 'Miss Granny', 'Zhong fan 20 sui', 2015, None, 131, 6.6, 983),
#  (14334482, 'Viva', None, 2015, None, 100, 7.2, 1506),
#  (14337414, 'Gopala Gopala', None, 2015, None, 153, 7.4, 3317),
#  (14338276, 'Ponte Aérea', None, 2015, None, 106, 6.5, 530),
#  (14341806, 'El Bosque de Karadima', None, 2015, None, 98, 7.0, 804),
#  (14341864, 'The Memory of Water', 'La Memoria del Agua', 2015, None, 88, 6.1, 572),
#  (14357368, 'Macadam Stories', 'Asphalte', 2015, None, 100, 7.1, 2492),
#  (14370256, 'How to Win at Checkers (Every Time)', None, 2015, None, 80, 7.1, 727),
#  (14358230, 'Body', 'Cialo', 2015, None, 90, 6.5, 1601),
#  (14365506, 'Open Tee Bioscope', None, 2015, None, 135, 7.7, 860),
#  (14370922, '(T)ERROR', None, 2015, None, 84, 6.6, 727),
#  (14374460, 'Aferim!', None, 2015, None, 108, 7.6, 5876),
#  (14377918, 'Crazy Beautiful You', None, 2015, None, 114, 7.2, 618),
#  (14375438, 'The Club', 'El club', 2015, None, 98, 7.2, 8388),
#  (14377952, 'Rattle the Cage', 'Zinzana', 2015, None, 96, 6.7, 567),
#  (14391852, 'Içimdeki Ses', None, 2015, None, 93, 6.0, 2763),
#  (14382552, 'Hot Girls Wanted', None, 2015, None, 84, 6.1, 14073),
#  (14384350, 'Picket 43', None, 2015, None, 104, 7.1, 989),
#  (14396042, 'Heroine Disqualified', 'Hiroin shikkaku', 2015, None, 112, 6.6, 882),
#  (14393514, 'Bitter Lake', None, 2015, None, 136, 8.2, 2356),
#  (14397346, 'Bikes vs Cars', None, 2015, None, 90, 7.2, 581),
#  (14400174, 'As I Open My Eyes', "À Peine J'ouvre Les Yeux", 2015, None, 102, 6.8, 1101),
#  (14401884, 'Isai', None, 2015, None, 190, 6.4, 554),
#  (14411504, 'The Clan', 'El Clan', 2015, None, 108, 7.0, 10978),
#  (14400028, 'No Kids', 'Sin hijos', 2015, None, 90, 6.4, 1639),
#  (14400058, 'Babysitting 2', None, 2015, None, 93, 6.4, 4480),
#  (14401704, 'Everything Before Us', None, 2015, None, 99, 7.0, 948),
#  (14425064, 'Steve Jobs: The Man in the Machine', None, 2015, None, 128, 6.9, 5465),
#  (14417522, 'Port of Call', 'Dap huet cam mui', 2015, None, 126, 6.7, 1794),
#  (14418168, 'Ice Age', 'Asre Yakhbandan', 2015, None, 106, 6.1, 793),
#  (14425138, 'Sugar Coated', None, 2015, None, 90, 7.4, 753),
#  (14425152, 'Girls Lost', 'Pojkarna', 2015, None, 106, 6.0, 951),
#  (14428788, 'Marguerite', None, 2015, None, 129, 7.0, 4551),
#  (14427076, '14+', None, 2015, None, 102, 7.0, 1237),
#  (14428728, 'The Crew', 'Braqueurs', 2015, None, 81, 6.3, 3221),
#  (14426656, 'Neither Heaven Nor Earth', 'Ni le ciel ni la terre', 2015, None, 100, 6.3, 896),
#  (14428814, 'The Measure of a Man', 'La loi du marché', 2015, None, 91, 6.8, 5193),
#  (14430212, 'Drishyam', None, 2015, None, 163, 8.3, 57527),
#  (14429128, 'Papanasam', None, 2015, None, 179, 8.4, 4802),
#  (14431392, 'Malli Malli Idhi Rani Roju', None, 2015, None, 161, 7.5, 761),
#  (14440036, 'Lost and Love', 'Shi gu', 2015, None, 108, 6.4, 508),
#  (14442758, 'Temper', None, 2015, None, 147, 7.4, 5213),
#  (14447076, 'Rosalie Blum', None, 2015, None, 95, 6.8, 1111),
#  (14450706, 'Husband Factor', 'Kocan Kadar Konus', 2015, None, 108, 6.3, 4020),
#  (14449576, 'Tomorrow', 'Demain', 2015, None, 118, 8.1, 2887),
#  (14457020, 'El Jeremías', None, 2015, None, 95, 7.2, 567),
#  (14465220, 'My Friend Rockefeller', None, 2015, None, 86, 6.2, 655),
#  (14466544, 'Fatima', None, 2015, None, 79, 6.3, 1264),
#  (14466872, 'Les ogres', None, 2015, None, 142, 7.0, 592),
#  (14466936, 'Blind Date', 'Un peu, beaucoup, aveuglément!', 2015, None, 90, 6.6, 5130),
#  (14476736, 'Hamlet', 'National Theatre Live: Hamlet', 2015, None, 217, 8.6, 1670),
#  (14480568, "That's Not Us", None, 2015, None, 98, 6.6, 510),
#  (14485246, 'Danny Says', None, 2015, None, 105, 6.7, 669),
#  (14501454, 'The Meddler', None, 2015, None, 103, 6.3, 10952),
#  (14504040, "A Ballerina's Tale", None, 2015, None, 85, 6.4, 592),
#  (14511200, 'Manifesto', None, 2015, None, 95, 6.6, 4978),
#  (14508712, 'Cloudy Sunday', 'Ouzeri Tsitsanis', 2015, None, 116, 6.5, 1190),
#  (14505666, 'Prescription Thugs', None, 2015, None, 86, 7.0, 1910),
#  (14508986, "What's Left of You", 'Senden Bana Kalan', 2015, None, 117, 6.6, 1979),
#  (14515684, 'The Treasure', 'Comoara', 2015, None, 89, 6.7, 2393),
#  (14511460, 'Aadu', None, 2015, None, 142, 6.8, 937),
#  (14523112, 'Selam: Bahara Yolculuk', None, 2015, None, 126, 7.9, 4066),
#  (14519488, 'Mudras Calling', None, 2018, None, 95, 8.7, 1196),
#  (14532634, 'Califórnia', None, 2015, None, 85, 7.0, 528),
#  (14532764, 'Crazy Rook', 'Rokhe Divaneh', 2015, None, 110, 6.9, 1414),
#  (14559932, 'Prizrak', None, 2015, None, 90, 6.5, 695),
#  (14569240, 'A Monster with a Thousand Heads', 'Un monstruo de mil cabezas', 2015, None, 74, 6.5, 827),
#  (14572998, 'Food and Shelter', 'Techo y comida', 2015, None, 93, 6.8, 757),
#  (14593108, 'The High Sun', 'Zvizdan', 2015, None, 123, 7.1, 3006),
#  (14576612, "Comment c'est loin", None, 2015, None, 90, 7.0, 1350),
#  (14589628, 'Kunjiramayanam', None, 2015, None, 122, 6.3, 881),
#  (14590482, 'Karachi se Lahore', None, 2015, None, 143, 6.5, 1219),
#  (14596814, 'S/O Satyamurthy', None, 2015, None, 162, 6.8, 2713),
#  (14601102, 'Made in France', None, 2015, None, 89, 6.2, 1883),
#  (14610244, 'The Other Side', None, 2015, None, 92, 6.8, 937),
#  (14618398, 'Boruto: Naruto the Movie', None, 2015, None, 95, 8.0, 7305),
#  (14613272, 'Kaili Blues', 'Lu bian ye can', 2015, None, 113, 7.3, 2305),
#  (14621016, 'Ingrid Bergman: In Her Own Words', 'Jag är Ingrid', 2015, None, 114, 7.3, 1787),
#  (14619940, 'Chronicles of Evil', 'Ak-ui yeon-dae-gi', 2015, None, 102, 6.7, 1103),
#  (14630444, 'Being Charlie', None, 2015, None, 97, 6.3, 3650),
#  (14629032, 'The Dawns Here Are Quiet...', 'A zori zdes tikhie...', 2015, None, 120, 6.7, 1073),
#  (14635548, 'Wrong No.', None, 2015, None, 133, 6.7, 1689),
#  (14635372, 'Masaan', None, 2015, None, 109, 8.1, 19638),
#  (14633694, 'Spider-Man: Into the Spider-Verse', None, 2018, None, 117, 8.4, 262505),
#  (14636042, 'The Chosen Ones', 'Las elegidas', 2015, None, 105, 6.7, 1503),
#  (14636046, 'Nahid', None, 2015, None, 105, 6.4, 1325),
#  (14643400, 'Filosofi Kopi', None, 2015, None, 117, 7.1, 524),
#  (14644302, 'Bin Roye', None, 2015, None, 116, 7.0, 1506),
#  (14643844, 'God Willing', 'Se Dio vuole', 2015, None, 87, 6.7, 3025),
#  (14647788, 'Coin Locker Girl', 'Cha-i-na-ta-un', 2015, None, 110, 6.7, 1256),
#  (14648304, 'Chandrettan Evideya', None, 2015, None, 124, 6.0, 513),
#  (14658770, 'Belaseshe', None, 2015, None, 141, 8.5, 1745),
#  (14654328, 'All Work All Play', None, 2015, None, 94, 6.1, 788),
#  (14663992, 'Land and Shade', 'La tierra y la sombra', 2015, None, 97, 7.1, 1498),
#  (14682562, 'Office', 'Opiseu', 2015, None, 111, 6.0, 1734),
#  (14679210, 'Premam', None, 2015, None, 156, 8.3, 14257),
#  (14684410, 'A Syrian Love Story', None, 2015, None, 76, 7.0, 618),
#  (14684258, '36 Vayadhinile', None, 2015, None, 115, 7.1, 594),
#  (14684710, 'Le mirage', None, 2015, None, 101, 6.7, 711),
#  (14686692, 'The Idol', 'Ya tayr el tayer', 2015, None, 100, 6.7, 1477),
#  (14692368, 'Jawani Phir Nahi Ani', None, 2015, None, 156, 7.6, 2794),
#  (14692242, 'Arabian Nights: Volume 3 - The Enchanted One', 'As Mil e Uma Noites: Volume 3, O Encantado', 2015, None, 125, 6.5, 984),
#  (14701630, 'Mosagallaku Mosagadu', None, 2015, None, 127, 6.5, 621),
#  (14697076, 'Dynamite', None, 2015, None, 142, 6.7, 794),
#  (14696222, 'Northern Limit Line', 'Yeonpyeong haejeon', 2015, None, 130, 6.5, 888),
#  (14699254, 'Dongata', None, 2015, None, 140, 6.5, 788),
#  (14701688, 'Demonte Colony', None, 2015, None, 116, 6.9, 1605),
#  (14701702, 'Mr. Six', 'Lao pao er', 2015, None, 134, 7.0, 2918),
#  (14703676, 'Me, Myself & Her', 'Io e lei', 2015, None, 102, 6.1, 633),
#  (14721400, 'From Afar', 'Desde allá', 2015, None, 93, 6.6, 3088),
#  (14718500, 'The Piper', 'Sonnim', 2015, None, 119, 6.3, 987),
#  (14727512, 'Srimanthudu', None, 2015, None, 158, 7.5, 10129),
#  (14730224, 'An Hour to Kill', None, 2018, None, 96, 8.6, 2325),
#  (14733736, 'Double Daddy', None, 2015, None, 85, 6.1, 809),
#  (14768764, 'Veteran', 'Beterang', 2015, None, 123, 7.0, 4279),
#  (14799426, 'Pentatonix: On My Way Home', None, 2015, None, 90, 6.5, 531),
#  (14806232, 'Indru Netru Naalai', None, 2015, None, 146, 8.0, 3065),
#  (14818930, 'Waiting', None, 2015, None, 92, 7.2, 1480),
#  (14819514, 'Go Away Mr. Tumor', 'Gun dan ba! Zhong liu jun', 2015, None, 85, 6.6, 900),
#  (14819560, 'Saving Mr. Wu', 'Jie jiu Wu xian sheng', 2015, None, 105, 6.7, 1958),
#  (14833824, 'Uppi 2', None, 2015, None, 135, 8.1, 7748),
#  (14834762, 'These Daughters of Mine', 'Moje córki krowy', 2015, None, 88, 6.7, 813),
#  (14840206, 'Sons of Rizk', 'Welad Rizq', 2015, None, 103, 7.4, 2986),
#  (14844288, 'The Treacherous', 'Gansin', 2015, None, 133, 6.1, 953),
#  (14859246, 'Maari', None, 2015, None, 138, 6.2, 2717),
#  (14869678, 'Superstar Kidnap', None, 2015, None, 120, 7.0, 621),
#  (14881362, 'Thithi', None, 2015, None, 123, 8.3, 2104),
#  (14881016, 'No Home Movie', None, 2015, None, 115, 6.6, 563),
#  (14911656, 'A Copy of My Mind', None, 2015, None, 116, 7.3, 543),
#  (14888834, 'Ennu Ninte Moideen', None, 2015, None, 166, 8.0, 4211),
#  (14895740, 'Frenzy', 'Abluka', 2015, None, 119, 7.3, 2627),
#  (14902012, 'Hurricane of Fun: The Making of Wet Hot', None, 2015, None, 64, 7.0, 1409),
#  (14908644, "Winter on Fire: Ukraine's Fight for Freedom", None, 2015, None, 102, 8.4, 10970),
#  (14909982, 'Losers', 'Karatsi', 2015, None, 97, 7.5, 625),
#  (14899406, 'Neon Bull', 'Boi Neon', 2015, None, 101, 6.8, 2383),
#  (14921860, 'MSG 2 the Messenger', None, 2015, None, 134, 6.8, 8386),
#  (14927574, 'Sijjin 2', 'Siccin 2', 2015, None, 86, 6.6, 1931),
#  (14935158, 'Demon', None, 2015, None, 94, 6.1, 4403),
#  (14934950, 'Talvar', None, 2015, None, 132, 8.2, 26337),
#  (14928620, 'Pathemari', None, 2015, None, 118, 8.4, 3328),
#  (14935372, "The Devil's Candy", None, 2015, None, 79, 6.4, 14804),
#  (14935480, 'Miss Sharon Jones!', None, 2015, None, 93, 7.3, 503),
#  (14939436, 'CT Fletcher: My Magnificent Obsession', None, 2015, None, 101, 7.6, 526),
#  (14943992, 'Manto', None, 2015, None, 127, 8.5, 1079),
#  (14937812, 'Thoongaavanam', None, 2015, None, 128, 7.1, 1650),
#  (14944352, 'Heneral Luna', None, 2015, None, 118, 7.7, 1703),
#  (14944924, 'Wednesday, May 9', 'Chaharshanbeh, 19 Ordibehesht', 2015, None, 102, 6.6, 559),
#  (14948632, 'Rajkahini', None, 2015, None, 160, 7.2, 1203),
#  (14949324, 'Mohalla Assi', None, 2015, None, 150, 6.9, 1354),
#  (14957538, 'The Whispering Star', 'Hiso hiso boshi', 2015, None, 100, 6.3, 651),
#  (14957446, 'Paths of the Soul', 'Kang rinpoche', 2015, None, 115, 7.5, 657),
#  (14961334, 'Two Countries', None, 2015, None, 154, 6.7, 1451),
#  (14967094, 'Our Times', None, 2015, None, 134, 7.4, 4005),
#  (14964598, 'Heart Attack', 'Freelance: Ham puay... Ham phak... Ham rak mor', 2015, None, 130, 7.8, 1880),
#  (14971824, 'Very Big Shot', 'Film Kteer Kbeer', 2015, None, 107, 7.3, 1148),
#  (14973112, 'Hitting the Apex', None, 2015, None, 138, 8.4, 2573),
#  (14972904, 'The Violin Teacher', 'Tudo Que Aprendemos Juntos', 2015, None, 102, 6.8, 645),
#  (14974396, 'Stretch and Bobbito: Radio That Changed Lives', None, 2015, None, 99, 8.0, 819),
#  (14995590, 'Junun', None, 2015, None, 54, 7.4, 1294),
#  (14987556, 'Thani Oruvan', None, 2015, None, 160, 8.5, 14218),
#  (15000250, 'Deep in the Wood', 'In fondo al bosco', 2015, None, 92, 6.3, 921),
#  (15001576, 'Barça Dreams', None, 2015, None, 120, 7.3, 546),
#  (14995748, 'Paayum Puli', None, 2015, None, 135, 6.0, 666),
#  (15009236, 'King Candy', None, 2015, None, 46, 7.1, 1560),
#  (15005684, 'Nil Battey Sannata', None, 2015, None, 100, 8.4, 4492),
#  (15016442, 'Gujjubhai the Great', None, 2015, None, 145, 8.2, 1181),
#  (15021536, 'Kendasampige', None, 2015, None, 99, 8.4, 1662),
#  (15022424, 'Kohinoor', None, 2015, None, 139, 6.3, 537),
#  (15027202, 'Colombia magia salvaje', None, 2015, None, 94, 8.3, 1182),
#  (15031892, 'The Accidental Detective', 'Tam jeong deo bigining', 2015, None, 120, 6.7, 609),
#  (15037912, 'Maya', None, 2015, None, 141, 7.7, 1182),
#  (15046534, 'Felix Manalo', None, 2015, None, 178, 7.8, 3883),
#  (15049636, 'Karbala', None, 2015, None, 115, 6.2, 1039),
#  (15053508, 'Rammstein in Amerika', None, 2015, None, 91, 8.3, 830),
#  (15058114, 'Wonderful Nightmare', 'Misseu waipeu', 2015, None, 125, 7.1, 522),
#  (15061126, 'Rocky Horror Show Live', None, 2015, None, 106, 7.9, 614),
#  (15061814, 'Goodbye Mr. Loser', 'Xia Luo te fan nao', 2015, None, 104, 6.7, 1843),
#  (15065790, 'Nadide Hayat', None, 2015, None, 118, 6.5, 2649),
#  (15065822, 'Ronaldo', None, 2015, None, 102, 6.4, 13365),
#  (15079382, 'Froning: The Fittest Man in History', None, 2015, None, 99, 6.7, 1084),
#  (15082014, 'Charlie', None, 2015, None, 130, 7.9, 5630),
#  (15082670, 'Amar Akbar Anthony', None, 2015, None, 140, 6.5, 1914),
#  (15084388, 'May Who?', 'May nai fai rang frer', 2015, None, 117, 7.1, 896),
#  (15111874, 'My Scientology Movie', None, 2015, None, 99, 6.7, 11088),
#  (15114588, 'Dügün Dernek 2: Sünnet', None, 2015, None, 112, 6.5, 7703),
#  (15121000, 'Aligarh', None, 2015, None, 114, 7.8, 4819),
#  (15124096, 'Thanga Magan', None, 2015, None, 122, 6.0, 1567),
#  (15128328, 'Naanum Rowdydhaan', None, 2015, None, 139, 7.3, 3049),
#  (15141042, 'Shudhu Tomari Jonyo', None, 2015, None, 149, 6.7, 551),
#  (15159734, 'Ouija: Game Never Ends', None, 2015, None, 119, 7.7, 1389),
#  (15161502, 'SOMM: Into the Bottle', None, 2015, None, 90, 7.3, 1415),
#  (15169582, 'Single', None, 2015, None, 127, 6.8, 573),
#  (15177824, 'Kumari 21F', None, 2015, None, 134, 7.7, 1438),
#  (15178278, 'Vedalam', None, 2015, None, 148, 6.3, 5375),
#  (15190958, 'Katyar Kaljat Ghusali', None, 2015, None, 162, 8.8, 1637),
#  (15207166, 'Requiem for Mrs. J', 'Rekvijem za gospodju J', 2015, None, 93, 7.2, 516),
#  (15199588, 'View from a Blue Moon', None, 2015, None, 58, 6.7, 781),
#  (15241760, 'Eating You Alive', None, 2018, None, 108, 8.2, 510),
#  (15269560, 'Ten Years', 'Sap nin', 2015, None, 104, 6.7, 1013),
#  (15271432, 'Adi Kapyare Kootamani', None, 2015, None, 131, 6.3, 1027),
#  (15278832, 'The Lure', 'Córki dancingu', 2015, None, 92, 6.3, 5301),
#  (15278928, 'Sonita', None, 2015, None, 90, 7.7, 705),
#  (15280626, 'Becoming Zlatan', 'Den unge Zlatan', 2015, None, 100, 6.7, 2127),
#  (15290882, 'Detective Chinatown', 'Tang ren jie tan an', 2015, None, 136, 6.6, 1385),
#  (15304172, 'Har Har Byomkesh', None, 2015, None, 113, 6.7, 685),
#  (15364920, 'Master Piece', None, 2015, None, 158, 6.2, 547),
#  (15420878, 'The 11th Grade', 'XIa', 2015, None, 84, 7.2, 874),
#  (15461168, 'Nawara', None, 2015, None, 122, 7.3, 557),
#  (15575408, 'Mushi-Shi Zoku Shou: Suzu no Shizuku', None, 2015, None, 47, 8.6, 530),
#  (15581752, 'Ulysses: A Dark Odyssey', None, 2018, None, 110, 8.3, 1537),
#  (15665040, 'Suddenly Seventeen', '28 Suì Wèi Chéngnián', 2015, None, 107, 6.3, 552),
#  (15773402, 'Dominion', None, 2018, None, 120, 9.2, 1303),
#  (15959980, 'Vada Chennai', None, 2018, None, 164, 8.6, 6871),
#  (16058226, 'Ekvtime: Man of God', None, 2018, None, 132, 9.2, 2620),
#  (16226212, 'Sand Angels', None, 2018, None, 71, 8.2, 661),
#  (16256984, 'My Name is Batlir, not Butler', None, 2018, None, None, 8.3, 655),
#  (16332276, 'What We Left Behind: Looking Back at Deep Space Nine', None, 2018, None, 116, 8.5, 670),
#  (16394430, 'For Good Old Times', 'Za ona dobra stara vremena', 2018, None, 105, 8.5, 1622),
#  (16544940, "Cowboy's Heart", 'Coração de Cowboy', 2018, None, 120, 8.3, 586),
#  (16545212, 'Leera the Soulmate', None, 2018, None, 104, 9.1, 798),
#  (16628102, 'The Wild Pear Tree', 'Ahlat Agaci', 2018, None, 188, 8.1, 13577),
#  (16755366, 'Bad Poems', 'Rossz versek', 2018, None, 97, 8.1, 1007),
#  (16966692, 'Green Book', None, 2018, None, 130, 8.2, 245229),
# ...
#  (12632928, 'The Epic Journey', None, 2015, None, 100, 8.8, 612),
#  (12698966, 'The Debt', "Oliver's Deal", 2015, None, 99, 6.0, 629),
#  (12712154, "Backstreet Boys: Show 'Em What You're Made Of", None, 2015, None, 101, 7.6, 1388),
#  (12734566, 'The Bride', 'La novia', 2015, None, 96, 6.7, 2701),
#  (12753778, 'The Death of "Superman Lives": What Happened?', None, 2015, None, 104, 7.1, 4066),
#  (12818654, 'Cemetery of Splendor', 'Rak ti Khon Kaen', 2015, None, 122, 6.8, 3718),
#  (12820852, 'Furious 7', 'Furious Seven', 2015, None, 137, 7.2, 340286),
#  (12831414, 'Everything Is Copy', None, 2015, None, 89, 7.5, 624),
#  (12847438, 'Der Bunker', None, 2015, None, 85, 6.2, 1406),
#  (12898306, 'Harry & Snowman', None, 2015, None, 84, 7.6, 554),
#  (12884018, 'Macbeth', None, 2015, None, 113, 6.6, 49689),
#  (12883448, 'Cash Only', None, 2015, None, 91, 6.1, 1073),
#  (12908446, 'Insurgent', None, 2015, None, 119, 6.2, 202953),
#  (12922590, 'Blood of My Blood', 'Sangue del mio sangue', 2015, None, 106, 6.1, 889),
#  (12949296, 'I Am Your Father', None, 2015, None, 83, 6.5, 1725),
#  (12994832, 'The Summer of Sangaile', 'Sangailes vasara', 2015, None, 90, 6.4, 2368),
#  (13022458, "The Shamer's Daughter", 'Skammerens datter', 2015, None, 96, 6.0, 3037),
#  (13054798, 'Memories of the Sword', 'Hyeomnyeo: Kar-ui gi-eok', 2015, None, 120, 6.3, 1561),
#  (13066630, 'The Forbidden Room', None, 2015, None, 130, 6.1, 2724),
#  (13072482, 'Hardcore Henry', None, 2015, None, 96, 6.7, 79953),
#  (13122842, 'The Automatic Hate', None, 2015, None, 97, 6.3, 822),
#  (13138782, 'The Miracle', 'Mucize', 2015, None, 136, 7.7, 8287),
#  (13194622, 'Magnetic', None, 2015, None, 80, 6.3, 1134),
#  (13195644, 'Insidious: Chapter 3', None, 2015, None, 97, 6.1, 85111),
#  (13205376, 'Slow West', None, 2015, None, 84, 6.9, 39121),
#  (13199006, 'Ghost Mountaineer', 'Must alpinist', 2015, None, 100, 6.2, 754),
#  (13236120, "I'll See You in My Dreams", None, 2015, None, 92, 6.7, 6331),
#  (13262990, 'Brotherly Love', None, 2015, None, 89, 6.7, 1608),
#  (13272570, 'All Things Must Pass: The Rise and Fall of Tower Records', None, 2015, None, 94, 7.3, 2788),
#  (13278330, 'Tale of Tales', 'Il racconto dei racconti - Tale of Tales', 2015, None, 134, 6.4, 24520),
#  (13284178, 'Arabian Nights: Volume 1 - The Restless One', 'As Mil e Uma Noites: Volume 1, O Inquieto', 2015, None, 125, 7.0, 1890),
#  (13296658, 'Rams', 'Hrútar', 2015, None, 93, 7.3, 11254),
#  (13327994, 'Human', None, 2015, None, 190, 8.7, 6478),
#  (13345474, 'Parasyte: Part 2', 'Kiseijuu: Kanketsuhen', 2015, None, 117, 6.5, 2016),
#  (13337550, 'Rahasya', None, 2015, None, 123, 7.6, 3917),
#  (13377996, 'Winning: The Racing Life of Paul Newman', None, 2015, None, 83, 7.6, 674),
#  (13397948, 'Zombie Ninjas vs Black Ops', None, 2015, None, 94, 6.6, 1077),
#  (13422078, 'April and the Extraordinary World', 'Avril et le monde truqué', 2015, None, 105, 7.3, 5660),
#  (13422094, 'The Thin Yellow Line', 'La delgada línea amarilla', 2015, None, 95, 7.4, 1132),
#  (13438208, 'No Letting Go', None, 2015, None, 104, 6.8, 523),
#  (13451720, 'Francofonia', None, 2015, None, 88, 6.6, 2339),
#  (13460252, 'The Hateful Eight', None, 2015, None, 168, 7.8, 457960),
#  (13462002, 'Finders Keepers', None, 2015, None, 82, 6.9, 2178),
#  (13471472, 'Maharaja Gemunu', None, 2015, None, 150, 8.4, 822),
#  (13480886, 'Ma ma', None, 2015, None, 111, 6.4, 3421),
#  (13544014, 'Akron', None, 2015, None, 88, 6.6, 1367),
#  (13551954, 'Raiders!: The Story of the Greatest Fan Film Ever Made', None, 2015, None, 106, 6.9, 1758),
#  (13567288, 'The Visit', None, 2015, None, 94, 6.2, 104415),
#  (13566788, 'Songs My Brothers Taught Me', None, 2015, None, 98, 6.8, 664),
#  (13597510, 'The White Knights', 'Les chevaliers blancs', 2015, None, 112, 6.0, 519),
#  (13651326, 'In the Shadow of Women', "L'ombre des femmes", 2015, None, 73, 6.5, 1220),
#  (13660770, 'Monkey Kingdom', None, 2015, None, 81, 7.3, 3460),
#  (13576728, 'Bilal: A New Breed of Hero', None, 2015, None, 105, 8.0, 17110),
#  (13579808, 'The Land of Oz', 'Strana Oz', 2015, None, 100, 6.9, 1131),
#  (13593124, 'Jinkx Monsoon: Drag Becomes Him', 'Drag Becomes Him', 2015, None, 82, 6.7, 510),
#  (13622592, 'Paper Towns', None, 2015, None, 109, 6.3, 89254),
#  (13678656, "You're Ugly Too", None, 2015, None, 81, 6.7, 646),
#  (13703836, "Henry Gamble's Birthday Party", None, 2015, None, 87, 6.1, 2158),
#  (13705412, 'Deathgasm', None, 2015, None, 86, 6.3, 14306),
#  (13721072, 'The Beach of the Drowned', 'La playa de los ahogados', 2015, None, 96, 6.0, 674),
#  (13749338, 'Flocken', None, 2015, None, 110, 6.4, 586),
#  (13774092, 'Amnesia', None, 2015, None, 96, 6.1, 843),
#  (13766394, 'Hello, My Name Is Doris', None, 2015, None, 90, 6.6, 17714),
#  (13765078, 'A Noble Intention', 'Publieke werken', 2015, None, 115, 6.7, 1637),
#  (13778086, 'Sleeping Giant', None, 2015, None, 89, 6.6, 1493),
#  (13784222, 'Paulina', 'La patota', 2015, None, 103, 6.6, 1328),
#  (13802576, 'Brothers', None, 2015, None, 156, 6.5, 10829),
#  (13781476, 'Monster Hunt', 'Zhuo yao ji', 2015, None, 117, 6.1, 4276),
#  (13790720, 'Peggy Guggenheim: Art Addict', None, 2015, None, 96, 7.1, 614),
#  (13792960, 'The Brand New Testament', 'Le tout nouveau testament', 2015, None, 114, 7.1, 26444),
#  (13809308, 'The Legendary Giulia and Other Miracles', 'Noi e la Giulia', 2015, None, 115, 6.8, 1694),
#  (13819668, "Dragon Ball Z: Resurrection 'F'", "Dragon Ball Z: Doragon bôru Z - Fukkatsu no 'F'", 2015, None, 93, 7.3, 18703),
#  (13833520, 'Jack of the Red Hearts', None, 2015, None, 102, 7.2, 1730),
#  (13825698, 'Mom and Other Loonies in the Family', 'Anyám és más futóbolondok a családból', 2015, None, 110, 7.5, 552),
#  (13828796, '2 Nights Till Morning', '2 yötä aamuun', 2015, None, 84, 6.1, 601),
#  (13841424, 'Land of Mine', 'Under sandet', 2015, None, 100, 7.8, 29387),
#  (13849938, 'Ostwind 2', None, 2015, None, 103, 6.4, 598),
#  (13850496, 'Chronic', None, 2015, None, 93, 6.6, 2660),
#  (13853452, 'Assassination Classroom', 'Ansatsu kyôshitsu', 2015, None, 110, 6.3, 1493),
#  (13863870, "I'm Off Then", 'Ich bin dann mal weg', 2015, None, 92, 6.2, 1593),
#  (13882000, 'Microbe & Gasoline', 'Microbe et Gasoil', 2015, None, 105, 6.7, 2181),
#  (13884528, 'Batkid Begins', None, 2015, None, 87, 6.8, 1542),
#  (13917316, 'Barcelona Christmas Night', "Barcelona, nit d'hivern", 2015, None, 95, 6.5, 678),
#  (13949936, 'The Secret Society of Souptown', 'Supilinna Salaselts', 2015, None, 95, 6.7, 502),
#  (13921314, 'Muhammad: The Messenger of God', 'Mohammad Rasoolollah', 2015, None, 162, 7.6, 7664),
#  (13922816, 'The Daughter', None, 2015, None, 96, 6.6, 4045),
#  (13966404, 'Mustang', None, 2015, None, 97, 7.6, 31620),
#  (13983674, 'The Mask You Live In', None, 2015, None, 97, 7.6, 2087),
#  (14005402, 'Colonia', None, 2015, None, 110, 7.1, 42989),
#  (14002772, 'Once I Was a Beehive', None, 2015, None, 119, 6.2, 1010),
#  (13993894, 'Queen of Earth', None, 2015, None, 90, 6.3, 5296),
#  (13995348, '100 Days of Love', None, 2015, None, 153, 6.6, 1536),
#  (13995416, 'Toz Bezi', None, 2015, None, 99, 6.7, 551),
#  (14057376, 'I Am Dragon', 'On - drakon', 2015, None, 110, 6.9, 3343),
#  (14057632, 'All Three of Us', 'Nous trois ou rien', 2015, None, 102, 7.3, 1897),
#  (14048050, 'My Golden Days', 'Trois souvenirs de ma jeunesse', 2015, None, 123, 6.8, 2907),
#  (14048168, 'Coming Through the Rye', None, 2015, None, 97, 6.3, 754),
#  (14058426, "India's Daughter", None, 2015, None, 63, 8.2, 1851),
#  (14079152, 'The Dead End', 'Lie ri zhuo xin', 2015, None, 139, 7.2, 1079),
#  (14080672, 'Daddy or Mommy', 'Papa ou maman', 2015, None, 85, 6.0, 3686),
#  (14080728, 'A Man Called Ove', 'En man som heter Ove', 2015, None, 116, 7.7, 40659),
#  (14084056, 'The Sense of Wonder', 'Le goût des merveilles', 2015, None, 100, 6.8, 2184),
#  (14084744, 'Battle for Sevastopol', 'Bitva za Sevastopol', 2015, None, 110, 7.1, 8763),
#  (14088588, 'Rainbow', 'Dhanak', 2015, None, 106, 8.0, 3094),
#  (14114456, "You Can't Save Yourself Alone", 'Nessuno si salva da solo', 2015, None, 103, 6.5, 739),
#  (14107858, 'MSG: The Messenger of God', None, 2015, None, 197, 6.1, 11093),
#  (14097612, 'In the Grayscale', 'En la Gama de los Grises', 2015, None, 101, 6.5, 1723),
#  (14110568, 'Dil Dhadakne Do', None, 2015, None, 170, 6.8, 12979),
#  (14125300, 'The Murder Case of Hana & Alice', 'Hana to Arisu satsujin jiken', 2015, None, 100, 7.1, 1247),
#  (14126438, 'The Ones Below', None, 2015, None, 87, 6.1, 8236),
#  (14130944, 'Lamb', None, 2015, None, 94, 6.7, 519),
#  (14150494, 'The Here After', 'Efterskalv', 2015, None, 102, 6.4, 1212),
#  (14144504, 'How to Change the World', None, 2015, None, 110, 7.6, 953),
#  (14160726, 'We Will Be the World Champions', 'Bicemo prvaci sveta', 2015, None, 127, 6.5, 1054),
#  (14183692, 'Woodlawn', None, 2015, None, 123, 6.5, 6170),
#  (14173494, 'Love & Peace', 'Rabu & Pîsu', 2015, None, 117, 6.8, 806),
#  (14176776, 'Ryuzo and the Seven Henchmen', 'Ryûzô to 7 nin no kobun tachi', 2015, None, 125, 6.2, 1623),
#  (14185572, 'The Hunting Ground', None, 2015, None, 103, 7.4, 5656),
#  (14193400, 'The People vs. Fritz Bauer', 'Der Staat gegen Fritz Bauer', 2015, None, 105, 7.1, 3681),
#  (14219130, 'Psycho-Pass: The Movie', 'Gekijouban Psycho-Pass', 2015, None, 113, 7.2, 2501),
#  (14221602, 'O Leão da Estrela', None, 2015, None, 110, 6.1, 517),
#  (14229236, 'Cobain: Montage of Heck', None, 2015, None, 145, 7.5, 26444),
#  (14254838, 'Tyke Elephant Outlaw', None, 2015, None, 78, 7.4, 555),
#  (14247492, 'The Demons', 'Les démons', 2015, None, 118, 6.6, 962),
#  (14270878, 'Applesauce', None, 2015, None, 91, 6.4, 850),
#  (14257858, 'Going Clear: Scientology & the Prison of Belief', None, 2015, None, 119, 8.0, 34808),
#  (14273886, 'The Beauty Inside', 'Byuti insaideu', 2015, None, 127, 7.4, 4266),
#  (14263482, 'The Witch', 'The VVitch: A New-England Folktale', 2015, None, 92, 6.8, 161930),
#  (14271820, 'OK Kanmani', None, 2015, None, 139, 7.4, 4240),
#  (14272866, 'The Boy and the Beast', 'Bakemono no ko', 2015, None, 119, 7.7, 17339),
#  (14284010, 'What Happened, Miss Simone?', None, 2015, None, 101, 7.6, 10472),
#  (14285496, 'Embrace of the Serpent', 'El abrazo de la serpiente', 2015, None, 125, 7.9, 17963),
#  (14329800, 'Carte Blanche', None, 2015, None, 106, 6.9, 654),
#  (14306308, 'Cute & Dangerous', 'Sevimli Tehlikeli', 2015, None, 113, 6.1, 2660),
#  (14319698, 'Little Big Master', 'Ng goh siu hai dik hau jeung', 2015, None, 112, 7.3, 656),
#  (14292596, 'The Heroes of Evil', 'Los héroes del mal', 2015, None, 98, 6.2, 788),
#  (14309356, 'Ivy', 'Sarmasik', 2015, None, 104, 8.0, 6746),
#  (14334636, 'Eddie - Strongman', 'Eddie: Strongman', 2015, None, 98, 7.5, 865),
#  (14337072, 'Ghost in the Shell: The New Movie', 'Kôkaku Kidôtai', 2015, None, 100, 6.7, 3111),
#  (14354740, 'Dharam Sankat Mein', None, 2015, None, 129, 6.2, 1811),
#  (14365412, 'Nice People', 'Filip & Fredrik presenterar Trevligt folk', 2015, None, 100, 7.6, 1302),
#  (14359416, 'Taxi', None, 2015, None, 82, 7.3, 12156),
#  (14384242, 'Pataas', None, 2015, None, 127, 6.7, 681),
#  (14377864, 'The Pearl Button', 'El botón de nácar', 2015, None, 82, 7.6, 2032),
#  (14378694, 'Nirbaak', None, 2015, None, 107, 6.2, 555),
#  (14392726, 'Design for Living', 'Hua li shang ban zu', 2015, None, 119, 6.1, 748),
#  (14412362, 'My Big Night', 'Mi gran noche', 2015, None, 100, 6.0, 3439),
#  (14415016, 'Twenty', 'Seumool', 2015, None, 115, 6.8, 1526),
#  (14430136, 'Pyaar Ka Punchnama 2', None, 2015, None, 137, 7.3, 12988),
#  (14432480, 'RangiTaranga', None, 2015, None, 149, 8.4, 11383),
#  (14439120, 'Tag', 'Riaru onigokko', 2015, None, 85, 6.1, 4510),
#  (14446318, 'Rajathandhiram', None, 2015, None, 132, 7.7, 1075),
#  (14489416, 'The Anthem of the Heart', 'Kokoro ga sakebitagatterunda.', 2015, None, 119, 7.4, 3374),
#  (14456270, 'The Sunshine Makers', None, 2015, None, 101, 7.0, 1061),
#  (14448310, 'Orange Mittai', None, 2015, None, 102, 6.5, 546),
#  (14450396, 'My Little Pony: Equestria Girls - Friendship Games', None, 2015, None, 72, 6.6, 1333),
#  (14515070, 'Yevade Subramanyam', None, 2015, None, 150, 7.6, 1631),
#  (14503900, 'Thought Crimes: The Case of the Cannibal Cop', None, 2015, None, 81, 6.4, 1083),
#  (14503906, 'Pokémon the Movie: Hoopa and the Clash of Ages', 'Pokemon za mûbî XY: Ringu no choumajin Fûpa', 2015, None, 79, 6.0, 1080),
#  (14504626, 'Among the Believers', None, 2015, None, 84, 7.6, 582),
#  (14518234, 'Cold of Kalandar', 'Kalandar Sogugu', 2015, None, 130, 7.8, 1255),
#  (14519006, 'Abandoned', None, 2015, None, 86, 6.3, 1955),
#  (14585660, 'Klown Forever', 'Klovn Forever', 2015, None, 99, 6.3, 3574),
#  (14557014, 'Oru Vadakkan Selfie', None, 2015, None, 141, 6.7, 2280),
#  (14603150, 'LiveJustine', None, 2015, None, 80, 6.0, 1022),
#  (14598848, "Dennis Rodman's Big Bang in PyongYang", None, 2015, None, 93, 6.2, 542),
#  (14610372, 'Noma My Perfect Storm', None, 2015, None, 100, 6.2, 586),
#  (14620316, 'One Floor Below', 'Un etaj mai jos', 2015, None, 93, 6.4, 738),
#  (14636298, 'Orange', 'Orenji', 2015, None, 139, 7.1, 989),
#  (14654844, 'Bitcoin: The End of Money as We Know It', None, 2015, None, 60, 7.1, 813),
#  (14644382, 'Monkey King: Hero Is Back', 'Xi you ji zhi da sheng gui lai', 2015, None, 89, 6.9, 3283),
#  (14661358, 'Hellstorm', None, 2015, None, 90, 7.0, 2424),
#  (14692234, 'Arabian Nights: Volume 2 - The Desolate One', 'As Mil e Uma Noites: Volume 2, O Desolado', 2015, None, 131, 7.2, 1229),
#  (14681414, 'My Love Story!!', 'Ore Monogatari!!', 2015, None, 105, 6.9, 536),
#  (14683668, 'Harold and Lillian: A Hollywood Love Story', None, 2015, None, 94, 7.9, 552),
#  (14668808, 'What Our Fathers Did: A Nazi Legacy', 'My Nazi Legacy', 2015, None, 96, 7.0, 1062),
#  (14669954, 'Yellow Flowers on the Green Grass', 'Tôi thay hoa vàng trên co xanh', 2015, None, 103, 7.7, 979),
#  (14685750, 'Much Loved', None, 2015, None, 104, 6.2, 1937),
#  (14689268, 'Brothers in Blood: The Lions of Sabi Sand', None, 2015, None, 60, 8.6, 563),
#  (14693464, 'Sicilian Vampire', None, 2015, None, 124, 7.0, 6746),
#  (14707756, 'The World Is Mine', 'Lumea e a mea', 2015, None, 104, 6.3, 697),
#  (14715470, 'Murder Rap: Inside the Biggie and Tupac Murders', None, 2015, None, 113, 7.5, 722),
#  (14716560, 'The Swedish Theory of Love', None, 2015, None, 90, 6.6, 1272),
#  (14729766, 'The Last Will Be the Last', 'Gli ultimi saranno ultimi', 2015, None, 103, 6.6, 624),
#  (14765604, 'About Love', 'Pro lyubov', 2015, None, 115, 6.4, 784),
#  (14768776, 'Right Now, Wrong Then', 'Ji-geum-eun-mat-go-geu-ddae-neun-teul-li-da', 2015, None, 121, 7.2, 3001),
#  (14780662, 'Happy Hour', 'Happî awâ', 2015, None, 317, 6.9, 805),
#  (14788638, 'To the Fore', 'Po feng', 2015, None, 125, 6.3, 838),
#  (14789290, 'A Kind of Magic', None, 2015, None, 90, 6.3, 542),
#  (14791594, 'The Classified File', 'Geukbisusa', 2015, None, 108, 6.4, 588),
#  (14817256, 'The Red Spider', 'Czerwony pajak', 2015, None, 90, 6.0, 1225),
#  (14831682, 'Little Witch Academia: The Enchanted Parade', 'Ritoru wicchi akademia: Mahoujihikake no parêdo', 2015, None, 54, 7.3, 1269),
#  (14846952, 'Angrej', None, 2015, None, 130, 8.6, 2589),
#  (14851640, 'The Final Master', 'Shi fu', 2015, None, 109, 7.0, 1887),
#  (14863784, 'I Promise You Anarchy', 'Te prometo anarquía', 2015, None, 88, 6.4, 854),
#  (14897822, 'Where to Invade Next', None, 2015, None, 120, 7.5, 21934),
#  (14899880, 'Shah', None, 2015, None, 109, 8.5, 1349),
#  (14900018, 'Keith Richards: Under the Influence', None, 2015, None, 81, 7.2, 2483),
#  (14901304, 'Behemoth', 'Bei xi mo shou', 2015, None, 95, 7.6, 740),
#  (14920274, 'Regular Show: The Movie', None, 2015, None, 69, 7.4, 2408),
#  (14935446, 'Heart of a Dog', None, 2015, None, 75, 7.1, 1886),
#  (14937156, 'Our Last Tango', 'Un tango más', 2015, None, 85, 7.3, 542),
#  (14947084, 'Anarkali', None, 2015, None, 160, 6.8, 1487),
#  (14948452, 'The Student and Mister Henri', "L'étudiante et Monsieur Henri", 2015, None, 98, 6.7, 2962),
#  (14943594, 'The Search for Freedom', None, 2015, None, 92, 6.9, 716),
#  (14955162, "Barbie in Rock 'N Royals", None, 2015, None, 84, 6.0, 567),
#  ...]

# %% [markdown]
# Here is how the execution order is
#
# <img src="img/withoutpara.png" width="1200">

# %%
# %%sql
#
# SELECT * FROM movies
# WHERE (start_year = 2015 OR start_year = 2018) AND rating > 8;
# Out:
#  * postgresql://postgres:***@localhost:5432/imdb
# 119 rows affected.
# [(11618448, 'Racing Extinction', None, 2015, None, 90, 8.3, 7042),
#  (12096673, 'Inside Out', None, 2015, None, 95, 8.2, 550606),
#  (12473476, 'Be Here Now', None, 2015, None, 100, 8.7, 2863),
#  (12631186, 'Baahubali: The Beginning', 'Bahubali: The Beginning', 2015, None, 159, 8.1, 94989),
#  (12865822, 'All the World in a Design School', None, 2015, None, 59, 8.4, 1270),
#  (13170832, 'Room', None, 2015, None, 118, 8.2, 326042),
#  (13270538, 'Requiem for the American Dream', None, 2015, None, 73, 8.1, 8061),
#  (13717510, 'The Drop Box', None, 2015, None, 79, 8.1, 604),
#  (13865286, 'My Lonely Me', None, 2015, None, 95, 8.2, 671),
#  (14112208, 'Kuttram Kadithal', None, 2015, None, 120, 8.1, 638),
#  (14145178, 'Listen to Me Marlon', None, 2015, None, 103, 8.2, 6447),
#  (14154756, 'Avengers: Infinity War', None, 2018, None, 149, 8.5, 711500),
#  (14393514, 'Bitter Lake', None, 2015, None, 136, 8.2, 2356),
#  (14430212, 'Drishyam', None, 2015, None, 163, 8.3, 57527),
#  (14429128, 'Papanasam', None, 2015, None, 179, 8.4, 4802),
#  (14449576, 'Tomorrow', 'Demain', 2015, None, 118, 8.1, 2887),
#  (14476736, 'Hamlet', 'National Theatre Live: Hamlet', 2015, None, 217, 8.6, 1670),
#  (14519488, 'Mudras Calling', None, 2018, None, 95, 8.7, 1196),
#  (14635372, 'Masaan', None, 2015, None, 109, 8.1, 19638),
#  (14633694, 'Spider-Man: Into the Spider-Verse', None, 2018, None, 117, 8.4, 262505),
#  (14658770, 'Belaseshe', None, 2015, None, 141, 8.5, 1745),
#  (14679210, 'Premam', None, 2015, None, 156, 8.3, 14257),
#  (14730224, 'An Hour to Kill', None, 2018, None, 96, 8.6, 2325),
#  (14833824, 'Uppi 2', None, 2015, None, 135, 8.1, 7748),
#  (14881362, 'Thithi', None, 2015, None, 123, 8.3, 2104),
#  (14908644, "Winter on Fire: Ukraine's Fight for Freedom", None, 2015, None, 102, 8.4, 10970),
#  (14934950, 'Talvar', None, 2015, None, 132, 8.2, 26337),
#  (14928620, 'Pathemari', None, 2015, None, 118, 8.4, 3328),
#  (14943992, 'Manto', None, 2015, None, 127, 8.5, 1079),
#  (14973112, 'Hitting the Apex', None, 2015, None, 138, 8.4, 2573),
#  (14987556, 'Thani Oruvan', None, 2015, None, 160, 8.5, 14218),
#  (15005684, 'Nil Battey Sannata', None, 2015, None, 100, 8.4, 4492),
#  (15016442, 'Gujjubhai the Great', None, 2015, None, 145, 8.2, 1181),
#  (15021536, 'Kendasampige', None, 2015, None, 99, 8.4, 1662),
#  (15027202, 'Colombia magia salvaje', None, 2015, None, 94, 8.3, 1182),
#  (15053508, 'Rammstein in Amerika', None, 2015, None, 91, 8.3, 830),
#  (15190958, 'Katyar Kaljat Ghusali', None, 2015, None, 162, 8.8, 1637),
#  (15241760, 'Eating You Alive', None, 2018, None, 108, 8.2, 510),
#  (15575408, 'Mushi-Shi Zoku Shou: Suzu no Shizuku', None, 2015, None, 47, 8.6, 530),
#  (15581752, 'Ulysses: A Dark Odyssey', None, 2018, None, 110, 8.3, 1537),
#  (15773402, 'Dominion', None, 2018, None, 120, 9.2, 1303),
#  (15959980, 'Vada Chennai', None, 2018, None, 164, 8.6, 6871),
#  (16058226, 'Ekvtime: Man of God', None, 2018, None, 132, 9.2, 2620),
#  (16226212, 'Sand Angels', None, 2018, None, 71, 8.2, 661),
#  (16256984, 'My Name is Batlir, not Butler', None, 2018, None, None, 8.3, 655),
#  (16332276, 'What We Left Behind: Looking Back at Deep Space Nine', None, 2018, None, 116, 8.5, 670),
#  (16394430, 'For Good Old Times', 'Za ona dobra stara vremena', 2018, None, 105, 8.5, 1622),
#  (16544940, "Cowboy's Heart", 'Coração de Cowboy', 2018, None, 120, 8.3, 586),
#  (16545212, 'Leera the Soulmate', None, 2018, None, 104, 9.1, 798),
#  (16628102, 'The Wild Pear Tree', 'Ahlat Agaci', 2018, None, 188, 8.1, 13577),
#  (16755366, 'Bad Poems', 'Rossz versek', 2018, None, 97, 8.1, 1007),
#  (16966692, 'Green Book', None, 2018, None, 130, 8.2, 245229),
#  (17060344, 'Ratsasan', None, 2018, None, 170, 8.7, 12007),
#  (17231194, 'Ee. Ma. Yau', None, 2018, None, 120, 8.3, 1290),
#  (17455754, 'The Game Changers', None, 2018, None, 108, 8.7, 853),
#  (17465992, 'Mahanati', None, 2018, None, 177, 8.6, 7516),
#  (17476236, 'Minding the Gap', None, 2018, None, 93, 8.1, 5586),
#  (17479902, 'Gultoo', None, 2018, None, 128, 8.4, 649),
#  (17547158, 'Ghost Squad', 'Gôsuto sukuwaddo', 2018, None, 106, 8.4, 522),
#  (17581572, 'Sudani from Nigeria', None, 2018, None, 123, 8.2, 2200),
#  (17591430, 'Summer Survivors', None, 2018, None, 91, 8.2, 511),
#  (17675404, '1968', None, 2018, None, 93, 8.2, 1175),
#  (17681902, "Won't You Be My Neighbor?", None, 2018, None, 94, 8.4, 18041),
#  (17741602, 'Until Midnight', None, 2018, None, 78, 8.1, 680),
#  (17838252, 'K.G.F: Chapter 1', None, 2018, None, 156, 8.2, 26146),
#  (17912470, 'Deception: Oo Pel Dan Myin', None, 2018, None, 88, 8.3, 1419),
#  (17905466, 'They Shall Not Grow Old', None, 2018, None, 99, 8.3, 18668),
#  (18024712, 'Yowis Ben', None, 2018, None, 99, 8.6, 3021),
#  (18032912, 'Parwaaz Hai Junoon', None, 2018, None, 130, 8.3, 1276),
#  (18076222, 'Untamed Romania', 'România neîmblânzit&atilde', 2018, None, 92, 8.8, 532),
#  (18090628, 'Kinavally', None, 2018, None, 141, 8.2, 576),
#  (18106568, 'Momentum Generation', None, 2018, None, 103, 8.1, 624),
#  (18108198, 'Andhadhun', None, 2018, None, 139, 8.4, 49612),
#  (18176054, 'Pariyerum Perumal', None, 2018, None, 154, 8.9, 5438),
#  (18239946, 'Tumbbad', None, 2018, None, 104, 8.2, 15827),
#  (18267604, 'Capernaum', 'Capharnaüm', 2018, None, 126, 8.4, 28017),
#  (18561086, 'Joseph', None, 2018, None, 138, 8.2, 1692),
#  (18638420, 'Strokes of Genius', None, 2018, None, 98, 8.1, 692),
#  (18784906, 'Ani... Dr. Kashinath Ghanekar', None, 2018, None, 159, 8.6, 589),
#  (18969332, 'The Biggest Little Farm', None, 2018, None, 91, 8.1, 1568),
#  (19206562, 'Make Us Dream', None, 2018, None, 104, 8.2, 1458),
#  (19124428, 'Champion', 'Bizim Için Sampiyon', 2018, None, 130, 8.5, 4843),
#  (19130246, 'Naal', None, 2018, None, 117, 8.4, 610),
#  (19231140, 'A Man Called Ahok', None, 2018, None, 102, 8.9, 4187),
#  (19279362, '11 Days', None, 2018, None, 85, 8.7, 655),
#  (19343826, 'Ananthu V/S Nusrath', None, 2018, None, 149, 9.5, 818),
#  (11392190, 'Mad Max: Fury Road', None, 2015, None, 120, 8.1, 797452),
#  (11895587, 'Spotlight', None, 2015, None, 129, 8.1, 374689),
#  (12632928, 'The Epic Journey', None, 2015, None, 100, 8.8, 612),
#  (13327994, 'Human', None, 2015, None, 190, 8.7, 6478),
#  (13471472, 'Maharaja Gemunu', None, 2015, None, 150, 8.4, 822),
#  (14058426, "India's Daughter", None, 2015, None, 63, 8.2, 1851),
#  (14432480, 'RangiTaranga', None, 2015, None, 149, 8.4, 11383),
#  (14689268, 'Brothers in Blood: The Lions of Sabi Sand', None, 2015, None, 60, 8.6, 563),
#  (14846952, 'Angrej', None, 2015, None, 130, 8.6, 2589),
#  (14899880, 'Shah', None, 2015, None, 109, 8.5, 1349),
#  (14991384, 'Visaaranai', None, 2015, None, 117, 8.5, 4851),
#  (15066616, 'Crusty Demons 18: Twenty Years of Fear', None, 2015, None, 67, 8.2, 1469),
#  (15086104, 'Chhello Divas', None, 2015, None, 138, 8.2, 2214),
#  (15207158, 'South Wind', 'Juzni vetar', 2018, None, 130, 8.3, 7328),
#  (16023118, 'Word from a Gamer', None, 2018, None, 92, 8.7, 1232),
#  (16074834, 'Delaware Shore', None, 2018, None, 98, 9.0, 502),
#  (16864864, 'Bobby Robson: More Than a Manager', None, 2018, None, 104, 8.2, 1727),
#  (17019842, '96', None, 2018, None, 158, 8.7, 11836),
#  (17358598, 'Let Me Fall', 'Lof mér að falla', 2018, None, 136, 8.5, 545),
#  (17391996, 'Care of Kancharapalem', 'C/o Kancharapalem', 2018, None, 152, 9.1, 2624),
#  (17392212, 'Rangasthalam', None, 2018, None, 170, 8.4, 16067),
#  (17738784, 'Peranbu', None, 2018, None, 147, 9.2, 10452),
#  (17775622, 'Free Solo', None, 2018, None, 100, 8.2, 38773),
#  (17794052, 'Merku Thodarchi Malai', None, 2018, None, 122, 8.8, 1303),
#  (17953814, 'The Foundation of Criminal Excellence', 'Kriminalas ekselences fonds', 2018, None, 126, 8.2, 959),
#  (18368032, 'Miss Granny', None, 2018, None, 120, 8.1, 1575),
#  (18483296, 'Sense8: The Series Finale Official Trailer', None, 2018, None, 151, 8.8, 2055),
#  (18602654, 'Sarkari. Hi. Pra. Shale Kasaragodu, Koduge: Ramanna Rai', None, 2018, None, 147, 8.7, 776),
#  (18614536, 'Farmlands', None, 2018, None, 73, 8.6, 839),
#  (18665634, 'Qismat', None, 2018, None, 137, 8.6, 1515),
#  (18718580, 'Eghantham', None, 2018, None, 125, 9.4, 644),
#  (19151704, 'Burn the Stage: The Movie', None, 2018, None, 84, 8.8, 2265),
#  (19135854, 'Take the Ball Pass the Ball: The Making of the Greatest Team in the World', None, 2018, None, 109, 8.2, 1586)]

# %% [markdown]
# Here is how the execution order is
#
# <img src="img/withpara.png" width="1200">

# %% [markdown]
# ```{admonition} SQL query: Find the number of movies in the movie_genres table that are NOT listed as 'drama'?
#
# <img src="img/discuss.png" width="120">
#
# Here are the first few rows of the ***movie_genres*** table:
#
# | movieid | genre  |
# |---------|--------|
# |   100   | drama  |
# |   200   | comedy |
# |   300   | action |
# |   400   | drama  |
#
# ***Hint:*** "COUNT()" function to count the number of returned rows. Eg: ***COUNT(DISTINCT movie_id)***
# ```

# %% [markdown]
# ```{admonition} iclicker: Who thinks the below query is going to give what the question is asking for (Find the number of movies in the movie_genres table that are NOT listed as 'drama')?
#
#     SELECT COUNT(DISTINCT movie_id) -- COUNT() function to count the number of returned rows
#     FROM movie_genres
#     WHERE genre <> 'drama';
#
# A) YES
#
# B) NO
#
# ```{toggle}
# So here is an animation of this scenario with some sample rows.
#
# <img src="img/dramaquerysplit1.png" width="600">
# ```

# %% [markdown]
# ```{margin}
# <img src="img/5.png" width="600">
# <img src="img/edgecases.png" width="600">
# ```

# %% [markdown]
# ```{admonition} iclicker: Now, let's look at some more rows. After looking at the following rows, do you think the SQL query is giving exactly the same what is asked for (Find the number of movies in the movie_genres table that are NOT listed as 'drama'?)?
#
# | movieid | genre  |
# |---------|--------|
# |   100   | drama  |
# |   200   | comedy |
# |   300   | action |
# |   400   | drama  |
# |   400   | comedy |
#
#
#     SELECT COUNT(DISTINCT movie_id)
#     FROM movie_genres
#     WHERE genre <> 'drama';
#
# A) YES
#
# B) NO
#
# ```{toggle}
# <img src="img/dramaquerysplit2.png" width="600">
#
# ```{tip}
# Make sure you consider any edge cases when writing your SQL query. We will see how to deal with this issue in our upcoming lectures. We will learn how to do this in lecture 5 when we learn about subqueries. We will revisit this question then and do this using subqueries.
# ```

# %% [markdown]
# ### LIKE and ILIKE
#
# LIKE is used for string matching:
#
# - `_` stands for any one character and
# - `%` stands for 0 or more arbitrary characters
#
# LIKE is case sensitive and ILIKE case insensitive.

# %%
# %%sql
# SELECT
#     'Arman' LIKE 'A%',
#     'Gittu' NOT LIKE 'g%',
#     'Gittu' ILIKE 'g%',
#     'UBC' LIKE '_B_',
#     'MDS is Woohoo!' LIKE '%!_',
#     'Hello' LIKE '% %'; --looking for something before and after a space
# Out:
#  * postgresql://postgres:***@localhost:5432/imdb
# 1 rows affected.
# [(True, True, True, True, False, False)]

# %% [markdown]
# ### IN
# Something that is going to be pretty useful.

# %% [markdown]
# ---
#
# **Example:** Retrieve rows from the `movie` table that correspond to the movies `'Donnie Brasco'`, `'The Usual Suspects'`, `'Schindler''s List'`, `'Shutter Island'`, `'A Beautiful Mind'`.
#
# ---

# %%
# %%sql
# -- you can add NOT IN
# SELECT
#     *
# FROM
#     movies
# WHERE
#     title IN ('Donnie Brasco',
#               'The Usual Suspects',
#               'Schindler','s List',
#               'Shutter Island',
#               'A Beautiful Mind'
#                )
# ;
# Out:
#  * postgresql://postgres:***@localhost:5432/imdb
# 4 rows affected.
# [(10114814, 'The Usual Suspects', None, 1995, None, 106, 8.5, 922333),
#  (10119008, 'Donnie Brasco', None, 1997, None, 127, 7.7, 258120),
#  (10268978, 'A Beautiful Mind', None, 2001, None, 135, 8.2, 784095),
#  (11130884, 'Shutter Island', None, 2010, None, 138, 8.1, 1027318)]

# %% [markdown]
# ### BETWEEN (just a fancy keyword or use <= and >= )

# %%
# %%sql
#
# SELECT
#     5 BETWEEN 1 AND 10, -- Note: BETWEEN is inclusive of both ends of the interval.
#     DATE '2021-11-01' BETWEEN DATE '2021-01-01' AND DATE '2021-11-10',
#     'w' NOT BETWEEN 'e' AND 'm';
# Out:
#  * postgresql://postgres:***@localhost:5432/imdb
# 1 rows affected.
# [(True, True, True)]

# %% [markdown]
# `BETWEEN` query what we wrote above is pretty much same as what is written below.

# %%
# %%sql
# SELECT
#     5 >= 1 AND 5 <= 10,
#     DATE '2021-11-01' >= DATE '2021-01-01' AND  DATE '2021-11-01' <= '2021-11-10',
#     'w' >= 'e' AND 'w' <= 'm';
# Out:
#  * postgresql://postgres:***@localhost:5432/imdb
# 1 rows affected.
# [(True, True, False)]

# %% [markdown]
# ---
#
# **Example:** Retrieve the name, production year and rating of the top 5 movies from the movie table that are produced between 2018 and 2020, and have a rating of at least 8.5 with at least 100000 votes. Sort the results in descending order based on ratings.
#
# ---

# %%
# %%sql
#
# SELECT title, start_year, rating
# FROM movies
# WHERE
#     start_year BETWEEN 2018 AND 2020
#     AND
#     rating >= 8
#     AND
#     nvotes >= 100000
# ORDER BY rating
# LIMIT 5 ;
# Out:
#  * postgresql://postgres:***@localhost:5432/imdb
# 5 rows affected.
# [('Once Upon a Time... in Hollywood', 2019, 8.0),
#  ('Toy Story 4', 2019, 8.0),
#  ('Bohemian Rhapsody', 2018, 8.0),
#  ('Green Book', 2018, 8.2),
#  ('Spider-Man: Into the Spider-Verse', 2018, 8.4)]

# %% [markdown]
# ### IS NULL
#
# This doesn't work.

# %%
# %%sql
#
# SELECT *
# FROM movies
# WHERE orig_title = NULL ;-- this will not work
# Out:
#  * postgresql://postgres:***@localhost:5432/imdb
# 0 rows affected.
# []

# %% [markdown]
# This is to check if a column has null values.

# %%
# %%sql
#
# SELECT *
# FROM movies
# WHERE orig_title IS NULL; -- type with orig_title = NULL and see what happens
# Out:
#  * postgresql://postgres:***@localhost:5432/imdb
# 17788 rows affected.
# [(10035423, 'Kate & Leopold', None, 2001, None, 118, 6.4, 74982),
#  (10042742, 'Mister 880', None, 1950, None, 90, 7.1, 1171),
#  (10041181, 'Black Hand', None, 1950, None, 92, 6.4, 666),
#  (10041387, 'Francis', None, 1950, None, 91, 6.4, 979),
#  (10042052, 'Woman in Hiding', None, 1950, None, 92, 6.9, 553),
#  (10042179, 'Abbott and Costello in the Foreign Legion', None, 1950, None, 80, 6.6, 2573),
#  (10042200, 'Annie Get Your Gun', None, 1950, None, 107, 6.9, 4050),
#  (10042206, 'Armored Car Robbery', None, 1950, None, 67, 7.0, 2077),
#  (10042208, 'The Asphalt Jungle', None, 1950, None, 112, 7.9, 22106),
#  (10042211, 'Atom Man vs. Superman', None, 1950, None, 252, 7.0, 579),
#  (10042219, 'Backfire', None, 1950, None, 91, 6.6, 955),
#  (10042229, 'The Baron of Arizona', None, 1950, None, 97, 7.0, 1748),
#  (10042249, 'The Big Lift', None, 1950, None, 120, 6.5, 1266),
#  (10042256, 'The Black Rose', None, 1950, None, 120, 6.3, 1657),
#  (10042265, 'The Blue Lamp', None, 1950, None, 84, 6.9, 1426),
#  (10042274, 'Borderline', None, 1950, None, 88, 6.1, 996),
#  (10042275, 'Born to Be Bad', None, 1950, None, 94, 6.7, 1797),
#  (10042279, 'Branded', None, 1950, None, 104, 6.7, 702),
#  (10042285, 'Bright Leaf', None, 1950, None, 110, 6.6, 1033),
#  (10042296, 'Caged', None, 1950, None, 96, 7.7, 3195),
#  (10042315, 'The Cariboo Trail', None, 1950, None, 81, 6.0, 529),
#  (10042325, 'Champagne for Caesar', None, 1950, None, 99, 7.4, 924),
#  (10042332, 'Cinderella', None, 1950, None, 74, 7.3, 134235),
#  (10042333, 'The Clouded Yellow', None, 1950, None, 95, 6.9, 609),
#  (10042338, 'Colt .45', None, 1950, None, 74, 6.0, 758),
#  (10042343, 'Convicted', None, 1950, None, 91, 6.9, 643),
#  (10042344, 'Copper Canyon', None, 1950, None, 84, 6.3, 510),
#  (10042352, 'Crisis', None, 1950, None, 95, 6.7, 1395),
#  (10042367, 'Cyrano de Bergerac', None, 1950, None, 113, 7.5, 3375),
#  (10042372, 'Dallas', None, 1950, None, 94, 6.3, 1115),
#  (10042376, "The Damned Don't Cry", None, 1950, None, 103, 7.2, 2114),
#  (10042379, 'Dark City', None, 1950, None, 98, 6.8, 1650),
#  (10042393, 'Destination Moon', None, 1950, None, 92, 6.3, 3388),
#  (10042394, 'Destination Murder', None, 1950, None, 72, 6.0, 546),
#  (10042395, "Devil's Doorway", None, 1950, None, 84, 7.3, 1200),
#  (10042397, 'Dial 1119', None, 1950, None, 75, 6.7, 787),
#  (10042447, 'Fancy Pants', None, 1950, None, 92, 6.6, 1050),
#  (10042451, 'Father of the Bride', None, 1950, None, 92, 7.2, 9343),
#  (10042464, 'The Flame and the Arrow', None, 1950, None, 88, 7.0, 3133),
#  (10042488, 'The Fuller Brush Girl', None, 1950, None, 85, 6.7, 576),
#  (10042490, 'The Furies', None, 1950, None, 109, 7.3, 2504),
#  (10042509, 'The Glass Menagerie', None, 1950, None, 107, 7.1, 934),
#  (10042513, 'Gone to Earth', None, 1950, None, 110, 7.1, 921),
#  (10042524, 'The Great Rupert', None, 1950, None, 87, 6.6, 842),
#  (10042530, 'Gun Crazy', None, 1950, None, 87, 7.6, 10362),
#  (10042531, 'The Gunfighter', None, 1950, None, 85, 7.7, 8490),
#  (10042542, 'The Happy Years', None, 1950, None, 110, 6.8, 609),
#  (10042544, 'Harriet Craig', None, 1950, None, 94, 7.3, 1421),
#  (10042546, 'Harvey', None, 1950, None, 104, 7.9, 50544),
#  (10042579, 'House by the River', None, 1950, None, 83, 7.2, 2579),
#  (10042593, 'In a Lonely Place', None, 1950, None, 94, 8.0, 22965),
#  (10042609, 'The Jackie Robinson Story', None, 1950, None, 77, 6.4, 1004),
#  (10042610, 'The Jackpot', None, 1950, None, 85, 6.9, 821),
#  (10042634, 'Key to the City', None, 1950, None, 101, 6.4, 599),
#  (10042644, 'Kim', None, 1950, None, 113, 6.6, 1630),
#  (10042646, "King Solomon's Mines", None, 1950, None, 103, 6.8, 5301),
#  (10042648, 'Kiss Tomorrow Goodbye', None, 1950, None, 102, 7.1, 1587),
#  (10042650, 'Kon-Tiki', None, 1950, None, 77, 8.0, 2172),
#  (10042664, 'A Lady Without Passport', None, 1950, None, 74, 6.2, 698),
#  (10042665, 'Last Holiday', None, 1950, None, 88, 7.5, 1286),
#  (10042677, 'A Life of Her Own', None, 1950, None, 108, 6.3, 765),
#  (10042697, 'Ma and Pa Kettle Go to Town', None, 1950, None, 79, 6.9, 669),
#  (10042700, 'Madeleine', None, 1950, None, 114, 6.9, 1310),
#  (10042702, 'The Magnificent Yankee', None, 1950, None, 89, 6.8, 529),
#  (10042707, 'The Man Who Cheated Himself', None, 1950, None, 81, 6.8, 1473),
#  (10042727, 'The Men', None, 1950, None, 85, 7.1, 3920),
#  (10042735, 'The Miniver Story', None, 1950, None, 104, 6.5, 674),
#  (10042744, 'Montana', None, 1950, None, 76, 6.2, 983),
#  (10042752, 'Trio', None, 1950, None, 91, 7.2, 596),
#  (10042771, 'Mystery Street', None, 1950, None, 93, 7.2, 2495),
#  (10042782, 'The Nevadan', None, 1950, None, 81, 6.3, 657),
#  (10042786, 'The Next Voice You Hear...', None, 1950, None, 83, 6.3, 699),
#  (10042788, 'Night and the City', None, 1950, None, 101, 8.0, 10759),
#  (10042792, 'No Way Out', None, 1950, None, 106, 7.4, 3950),
#  (10042824, 'Outrage', None, 1950, None, 75, 6.7, 884),
#  (10042832, 'Panic in the Streets', None, 1950, None, 96, 7.3, 6458),
#  (10042869, 'Quicksand', None, 1950, None, 79, 6.6, 1800),
#  (10042895, 'Rio Grande', None, 1950, None, 105, 7.2, 12907),
#  (10042899, 'Rocky Mountain', None, 1950, None, 83, 6.8, 835),
#  (10042935, 'The Secret Fury', None, 1950, None, 85, 6.9, 537),
#  (10042947, 'September Affair', None, 1950, None, 104, 6.8, 666),
#  (10042949, 'Seven Days to Noon', None, 1950, None, 94, 7.1, 1277),
#  (10042952, 'Shadow on the Wall', None, 1950, None, 84, 6.7, 917),
#  (10042960, 'Side Street', None, 1950, None, 83, 7.1, 2297),
#  (10042963, 'Sierra', None, 1950, None, 83, 6.8, 590),
#  (10042994, 'Stage Fright', None, 1950, None, 110, 7.1, 11553),
#  (10042998, 'Stars in My Crown', None, 1950, None, 89, 7.4, 1614),
#  (10043014, 'Sunset Blvd.', None, 1950, None, 110, 8.4, 183282),
#  (10043018, 'Susana', None, 1951, None, 86, 7.3, 1663),
#  (10043030, 'Tea for Two', None, 1950, None, 98, 6.5, 1523),
#  (10043041, 'Three Came Home', None, 1950, None, 106, 7.3, 1531),
#  (10043044, 'Three Little Words', None, 1950, None, 102, 7.0, 1473),
#  (10043052, 'To Please a Lady', None, 1950, None, 91, 6.2, 761),
#  (10043053, 'The Toast of New Orleans', None, 1950, None, 97, 6.3, 518),
#  (10043067, 'Treasure Island', None, 1950, None, 96, 6.9, 6139),
#  (10043075, 'The Sound of Fury', None, 1950, None, 91, 7.2, 940),
#  (10043079, 'Two Flags West', None, 1950, None, 92, 6.7, 624),
#  (10043081, 'Two Weeks with Love', None, 1950, None, 90, 6.9, 719),
#  (10043088, 'The Underworld Story', None, 1950, None, 91, 7.0, 566),
#  (10043117, 'Wagon Master', None, 1950, None, 86, 7.1, 3805),
#  (10043118, 'Walk Softly, Stranger', None, 1950, None, 81, 6.5, 695),
#  (10043123, 'The West Point Story', None, 1950, None, 107, 6.2, 1066),
#  (10043129, 'When Willie Comes Marching Home', None, 1950, None, 82, 6.5, 576),
#  (10043132, 'Where the Sidewalk Ends', None, 1950, None, 95, 7.6, 7027),
#  (10043134, 'The White Tower', None, 1950, None, 98, 6.0, 662),
#  (10043137, "Winchester '73", None, 1950, None, 92, 7.7, 15365),
#  (10043142, 'Woman on the Run', None, 1950, None, 77, 7.3, 2440),
#  (10043147, 'The Wooden Horse', None, 1950, None, 101, 7.0, 1196),
#  (10046799, 'Boot Polish', None, 1954, None, 149, 8.2, 648),
#  (10043253, 'A.T.M.: ¡¡A toda máquina!!', None, 1951, None, 120, 7.9, 596),
#  (10043262, 'Across the Wide Missouri', None, 1951, None, 78, 6.2, 1675),
#  (10043265, 'The African Queen', None, 1951, None, 105, 7.8, 67356),
#  (10043274, 'Alice in Wonderland', None, 1951, None, 75, 7.4, 118726),
#  (10043278, 'An American in Paris', None, 1951, None, 114, 7.2, 27838),
#  (10043286, 'Angels in the Outfield', None, 1951, None, 99, 7.1, 1869),
#  (10043288, 'Anne of the Indies', None, 1951, None, 81, 6.7, 1084),
#  (10043292, 'Appointment with Danger', None, 1950, None, 90, 6.6, 930),
#  (10043299, 'As Young as You Feel', None, 1951, None, 77, 6.5, 959),
#  (10043306, 'Awaara', None, 1951, None, 193, 8.0, 3169),
#  (10043340, 'The Big Night', None, 1951, None, 75, 6.4, 531),
#  (10043361, 'Bright Victory', None, 1951, None, 97, 7.3, 739),
#  (10043362, 'The Browning Version', None, 1951, None, 90, 8.2, 4024),
#  (10043371, 'Callaway Went Thataway', None, 1951, None, 81, 6.6, 548),
#  (10043379, 'Captain Horatio Hornblower R.N.', None, 1951, None, 117, 7.4, 5685),
#  (10043408, 'The Cimarron Kid', None, 1952, None, 84, 6.4, 742),
#  (10043425, "Comin' Round the Mountain", None, 1951, None, 77, 6.6, 1135),
#  (10043435, 'Cry Danger', None, 1951, None, 79, 7.3, 1949),
#  (10043436, 'Cry, the Beloved Country', None, 1951, None, 103, 7.1, 505),
#  (10043455, 'David and Bathsheba', None, 1951, None, 116, 6.1, 1898),
#  (10043458, 'Death of a Salesman', None, 1951, None, 115, 7.2, 801),
#  (10043459, 'Decision Before Dawn', None, 1951, None, 119, 7.2, 2130),
#  (10043461, 'The Desert Fox: The Story of Rommel', None, 1951, None, 88, 6.9, 5219),
#  (10043465, 'Detective Story', None, 1951, None, 103, 7.6, 6413),
#  (10043539, 'Five', None, 1951, None, 93, 6.3, 1068),
#  (10043547, 'Flying Leathernecks', None, 1951, None, 102, 6.5, 4163),
#  (10043557, 'Fort Worth', None, 1951, None, 80, 6.3, 549),
#  (10043560, 'Fourteen Hours', None, 1951, None, 92, 7.1, 2045),
#  (10043565, 'The Frogmen', None, 1951, None, 96, 6.5, 997),
#  (10043599, 'The Great Caruso', None, 1951, None, 109, 6.6, 1100),
#  (10043606, 'Guardie e ladri', None, 1951, None, 105, 7.7, 1159),
#  (10043625, 'He Ran All the Way', None, 1951, None, 77, 7.0, 1680),
#  (10043633, 'Here Comes the Groom', None, 1951, None, 113, 6.5, 924),
#  (10043643, 'His Kind of Woman', None, 1951, None, 120, 7.1, 3577),
#  (10043655, 'The Hoodlum', None, 1951, None, 61, 6.3, 695),
#  (10043660, 'The House on Telegraph Hill', None, 1951, None, 93, 7.0, 2378),
#  (10043669, "I'll See You in My Dreams", None, 1951, None, 110, 6.7, 820),
#  (10043687, 'Jim Thorpe -- All-American', None, 1951, None, 107, 6.9, 1737),
#  (10043703, 'Kekec', None, 1951, None, 97, 8.0, 755),
#  (10043709, 'Kind Lady', None, 1951, None, 78, 7.0, 781),
#  (10043727, 'Laughter in Paradise', None, 1951, None, 93, 7.1, 1206),
#  (10043736, "Let's Make It Legal", None, 1951, None, 77, 6.3, 986),
#  (10043751, 'Lone Star', None, 1952, None, 94, 6.2, 808),
#  (10043759, 'Love Nest', None, 1951, None, 84, 6.3, 1001),
#  (10043766, 'M', None, 1951, None, 88, 6.8, 1462),
#  (10043769, 'The Magic Box', None, 1951, None, 118, 7.0, 1032),
#  (10043781, 'Man in the Saddle', None, 1951, None, 87, 6.3, 929),
#  (10043792, 'The Mating Season', None, 1951, None, 101, 7.4, 1450),
#  (10043801, 'Meshi', None, 1951, None, 97, 7.7, 1222),
#  (10043812, 'The Mob', None, 1951, None, 87, 7.0, 1040),
#  (10043827, 'My Favorite Spy', None, 1951, None, 93, 6.6, 968),
#  (10043861, 'No Questions Asked', None, 1951, None, 80, 6.7, 524),
#  (10043871, 'Odette', None, 1950, None, 124, 7.0, 582),
#  (10043873, 'Has Anybody Seen My Gal', None, 1952, None, 88, 7.1, 1183),
#  (10043879, 'On Dangerous Ground', None, 1951, None, 82, 7.3, 5718),
#  (10043880, 'On Moonlight Bay', None, 1951, None, 95, 7.1, 2125),
#  (10043882, 'On the Riviera', None, 1951, None, 89, 6.4, 756),
#  (10043885, 'Only the Valiant', None, 1951, None, 105, 6.5, 1120),
#  (10043899, 'Pandora and the Flying Dutchman', None, 1951, None, 122, 7.0, 2901),
#  (10043908, 'Pathala Bhairavi', None, 1951, None, 192, 8.4, 529),
#  (10043910, 'Payment on Demand', None, 1951, None, 90, 7.1, 1246),
#  (10043914, "The People Against O'Hara", None, 1951, None, 102, 6.8, 1068),
#  (10043924, 'A Place in the Sun', None, 1951, None, 122, 7.8, 18420),
#  (10043938, 'The Prowler', None, 1951, None, 92, 7.2, 2675),
#  (10043949, 'Quo Vadis', None, 1951, None, 171, 7.2, 12467),
#  (10043955, 'The Racket', None, 1951, None, 88, 6.7, 2360),
#  (10043959, 'Rawhide', None, 1951, None, 89, 7.2, 2094),
#  (10043961, 'The Red Badge of Courage', None, 1951, None, 69, 7.2, 3748),
#  (10043967, 'Rhubarb', None, 1951, None, 94, 6.9, 554),
#  (10043972, 'The River', None, 1951, None, 99, 7.5, 5115),
#  (10043973, 'Roadblock', None, 1951, None, 73, 6.7, 955),
#  (10043983, 'Royal Wedding', None, 1951, None, 93, 6.7, 4388),
#  (10043989, 'Sailor Beware', None, 1952, None, 108, 6.4, 1029),
#  (10043992, 'Santa Fe', None, 1951, None, 87, 6.2, 723),
#  (10044012, 'Sealed Cargo', None, 1951, None, 90, 6.8, 615),
#  (10044015, 'The Secret of Convict Lake', None, 1951, None, 83, 7.0, 690),
#  (10044030, 'Show Boat', None, 1951, None, 108, 6.9, 4193),
#  (10044040, 'Sirocco', None, 1951, None, 98, 6.3, 1726),
#  (10044072, 'The Steel Helmet', None, 1951, None, 85, 7.5, 3396),
#  (10044075, 'Storm Warning', None, 1951, None, 93, 7.2, 1304),
#  (10044078, 'The Strange Door', None, 1951, None, 81, 6.3, 726),
#  (10044081, 'A Streetcar Named Desire', None, 1951, None, 122, 8.0, 92834),
#  (10044083, 'The Strip', None, 1951, None, 85, 6.0, 520),
#  (10044105, 'The Tall Target', None, 1951, None, 78, 7.2, 1469),
#  (10044110, 'Ten Tall Men', None, 1951, None, 97, 6.2, 768),
#  (10044121, 'The Thing from Another World', None, 1951, None, 87, 7.2, 23411),
#  (10044125, 'Three Guys Named Mike', None, 1951, None, 90, 6.2, 574),
#  (10044128, 'Thunder on the Hill', None, 1951, None, 84, 6.8, 506),
#  (10044135, 'Tomahawk', None, 1951, None, 82, 6.3, 639),
#  (10044188, 'Der Verlorene', None, 1951, None, 98, 7.0, 831),
#  (10044202, 'The Well', None, 1951, None, 86, 7.2, 596),
#  (10044205, 'Westward the Women', None, 1951, None, 118, 7.6, 2532),
#  (10044223, 'You Never Can Tell', None, 1951, None, 78, 7.1, 507),
#  (10044314, '5 Fingers', None, 1952, None, 108, 7.7, 3896),
#  (10044324, 'Above and Beyond', None, 1952, None, 122, 6.9, 978),
#  (10044331, 'Affair in Trinidad', None, 1952, None, 98, 6.7, 1649),
#  (10044333, 'Against All Flags', None, 1952, None, 84, 6.6, 2081),
#  (10044355, 'Androcles and the Lion', None, 1952, None, 98, 6.2, 706),
#  (10044357, 'Angel Face', None, 1953, None, 91, 7.3, 6225),
#  (10044364, "Another Man's Poison", None, 1951, None, 90, 6.9, 1980),
#  (10044370, 'April in Paris', None, 1952, None, 100, 6.1, 1031),
#  (10044380, "At Sword's Point", None, 1952, None, 81, 6.0, 590),
#  (10044386, 'Robinson Crusoe', None, 1954, None, 90, 6.8, 3186),
#  (10044391, 'The Bad and the Beautiful', None, 1952, None, 118, 7.8, 11887),
#  (10044399, 'The Battle at Apache Pass', None, 1952, None, 85, 6.4, 523),
#  (10044408, 'The Belle of New York', None, 1952, None, 82, 6.2, 766),
#  (10044410, 'Belles on Their Toes', None, 1952, None, 89, 6.7, 797),
#  (10044413, 'Bend of the River', None, 1952, None, 91, 7.3, 7133),
#  (10044417, 'Beware, My Lovely', None, 1952, None, 77, 6.7, 1480),
#  (10044419, 'The Big Sky', None, 1952, None, 140, 7.0, 3600),
#  (10044423, 'The Black Castle', None, 1952, None, 82, 6.4, 910),
#  (10044426, 'Blackbeard, the Pirate', None, 1952, None, 99, 6.1, 1195),
#  (10044446, 'The Sound Barrier', None, 1952, None, 118, 6.7, 1536),
#  (10044453, 'El bruto', None, 1953, None, 81, 7.3, 1592),
#  (10044476, 'The Captive City', None, 1952, None, 91, 6.5, 668),
#  (10044480, 'Carbine Williams', None, 1952, None, 92, 7.0, 1633),
#  (10044486, 'Carrie', None, 1952, None, 118, 7.3, 1961),
#  (10044488, 'Carson City', None, 1952, None, 87, 6.4, 811),
#  (10044502, 'Clash by Night', None, 1952, None, 105, 7.1, 5066),
#  (10044533, 'Deadline - U.S.A.', None, 1952, None, 87, 7.2, 2723),
#  (10044552, 'Diplomatic Courier', None, 1952, None, 97, 6.9, 811),
#  (10044557, "Don't Bother to Knock", None, 1952, None, 76, 6.9, 5385),
#  (10044566, 'Dreamboat', None, 1952, None, 83, 6.8, 600),
#  (10044573, 'The Duel at Silver Creek', None, 1952, None, 77, 6.4, 1192),
#  (10044672, 'The Greatest Show on Earth', None, 1952, None, 152, 6.6, 11816),
#  (10044673, 'The Green Glove', None, 1952, None, 89, 6.2, 662),
#  (10044683, "Hangman's Knot", None, 1952, None, 81, 6.7, 1168),
#  (10044685, 'Hans Christian Andersen', None, 1952, None, 112, 6.9, 3142),
#  (10044706, 'High Noon', None, 1952, None, 85, 7.9, 91640),
#  (10044716, 'The Holly and the Ivy', None, 1952, None, 83, 7.6, 739),
#  (10044741, 'Ikiru', None, 1952, None, 143, 8.3, 60061),
#  (10044760, 'Ivanhoe', None, 1952, None, 106, 6.8, 7586),
#  (10044774, 'Jumping Jacks', None, 1952, None, 96, 6.4, 819),
#  (10044789, 'Kansas City Confidential', None, 1952, None, 99, 7.4, 5292),
#  (10044811, 'Kvinnors väntan', None, 1952, None, 107, 7.1, 1943),
#  (10044829, 'The Lavender Hill Mob', None, 1951, None, 78, 7.6, 11620),
#  (10044837, 'Limelight', None, 1952, None, 137, 8.1, 16445),
#  (10044849, 'The Long Memory', None, 1953, None, 96, 6.9, 873),
#  (10044851, 'Lost in Alaska', None, 1952, None, 76, 6.5, 1759),
#  (10044855, 'Lovely to Look At', None, 1952, None, 103, 6.3, 562),
#  (10044860, 'The Lusty Men', None, 1952, None, 113, 7.4, 2235),
#  (10044863, 'Macao', None, 1952, None, 81, 6.7, 2535),
#  (10044876, 'The Man in the White Suit', None, 1951, None, 85, 7.3, 8122),
#  (10044888, 'The Marrying Kind', None, 1952, None, 92, 7.1, 1100),
#  (10044896, 'The Member of the Wedding', None, 1952, None, 93, 6.8, 1170),
#  (10044905, 'The Miracle of Our Lady of Fatima', None, 1952, None, 102, 6.8, 929),
#  (10044907, 'Les Miserables', None, 1952, None, 105, 6.9, 843),
#  (10044916, 'Monkey Business', None, 1952, None, 97, 7.0, 12020),
#  (10044926, 'Moulin Rouge', None, 1952, None, 119, 7.1, 4599),
#  (10044937, 'My Cousin Rachel', None, 1952, None, 98, 7.1, 2190),
#  (10044953, 'The Naked Spur', None, 1953, None, 91, 7.4, 9264),
#  (10044954, 'The Narrow Margin', None, 1952, None, 71, 7.7, 6424),
#  (10045009, 'Park Row', None, 1952, None, 83, 7.3, 1295),
#  (10045012, 'Pat and Mike', None, 1952, None, 95, 7.0, 4759),
#  (10045039, 'Plymouth Adventure', None, 1952, None, 105, 6.3, 1073),
#  (10045041, 'Pony Soldier', None, 1952, None, 82, 6.0, 568),
#  (10045049, 'The Pride of St. Louis', None, 1952, None, 93, 6.6, 561),
#  (10045053, 'The Prisoner of Zenda', None, 1952, None, 96, 7.0, 3047),
#  (10045061, 'The Quiet Man', None, 1952, None, 129, 7.8, 32280),
#  (10045070, 'Rancho Notorious', None, 1952, None, 89, 7.0, 3568),
#  (10045091, 'The Ring', None, 1952, None, 79, 6.2, 635),
#  (10045102, 'Room for One More', None, 1952, None, 98, 7.1, 1752),
#  (10045109, 'Ruby Gentry', None, 1952, None, 82, 6.7, 1235),
#  (10045125, 'Scaramouche', None, 1952, None, 115, 7.5, 5190),
#  (10045152, "Singin' in the Rain", None, 1952, None, 103, 8.3, 201077),
#  (10045162, 'The Snows of Kilimanjaro', None, 1952, None, 114, 6.2, 4336),
#  (10045184, 'Springfield Rifle', None, 1952, None, 93, 6.7, 1570),
#  (10045186, 'The Star', None, 1952, None, 89, 7.0, 2969),
#  (10045190, 'The Steel Trap', None, 1952, None, 85, 6.9, 858),
#  (10045191, 'Stolen Face', None, 1952, None, 72, 6.1, 513),
#  (10045192, 'The Stooge', None, 1951, None, 100, 6.9, 1205),
#  (10045216, 'Talk About a Stranger', None, 1952, None, 65, 6.2, 560),
#  (10045230, 'The Thief', None, 1952, None, 86, 6.7, 804),
#  (10045274, 'Umberto D.', None, 1952, None, 89, 8.2, 20591),
#  (10045294, 'I vinti', None, 1953, None, 113, 6.6, 720),
#  (10045316, 'Way of a Gaucho', None, 1952, None, 87, 6.7, 507),
#  (10045317, "We're Not Married!", None, 1952, None, 86, 6.4, 1661),
#  (10045329, 'The Wild North', None, 1952, None, 97, 6.6, 654),
#  (10045333, 'With a Song in My Heart', None, 1952, None, 117, 6.8, 1149),
#  (10045339, 'The World in His Arms', None, 1952, None, 104, 6.9, 1593),
#  (10045361, 'El', None, 1953, None, 92, 8.0, 4781),
#  (10045464, 'The 5,000 Fingers of Dr. T.', None, 1953, None, 89, 6.8, 3495),
#  (10045468, 'Abbott and Costello Go to Mars', None, 1953, None, 77, 6.1, 2911),
#  (10045470, 'Die Geschichte vom kleinen Muck', None, 1953, None, 100, 6.9, 502),
#  (10045471, 'The Actress', None, 1953, None, 90, 6.5, 1064),
#  (10045479, 'The Affairs of Dobie Gillis', None, 1953, None, 72, 6.1, 534),
#  (10045492, 'All I Desire', None, 1953, None, 80, 7.1, 1537),
#  (10045518, 'Arrowhead', None, 1953, None, 105, 6.1, 1051),
#  (10045537, 'The Band Wagon', None, 1953, None, 112, 7.5, 9177),
#  (10045544, 'Battle Circus', None, 1953, None, 90, 6.0, 1215),
#  (10045546, 'The Beast from 20,000 Fathoms', None, 1953, None, 80, 6.7, 6291),
#  (10045555, 'The Big Heat', None, 1953, None, 89, 8.0, 21214),
#  (10045557, 'The Bigamist', None, 1953, None, 80, 6.7, 2418),
#  (10045563, 'Blowing Wild', None, 1953, None, 90, 6.5, 749),
#  (10045564, 'The Blue Gardenia', None, 1953, None, 85, 6.9, 4208),
#  (10045566, 'A Blueprint for Murder', None, 1953, None, 77, 6.8, 1218),
#  (10045589, 'The Caddy', None, 1953, None, 95, 6.5, 1674),
#  (10045591, 'Calamity Jane', None, 1953, None, 101, 7.3, 7855),
#  (10045592, 'Call Me Madam', None, 1953, None, 114, 6.8, 1083),
#  (10045607, "The Captain's Paradise", None, 1953, None, 94, 7.0, 1373),
#  (10045631, 'City That Never Sleeps', None, 1953, None, 90, 6.9, 1036),
#  (10045659, 'The Cruel Sea', None, 1953, None, 126, 7.5, 3712),
#  (10045669, 'Dangerous Crossing', None, 1953, None, 75, 7.1, 1564),
#  (10045679, 'The Desert Rats', None, 1953, None, 88, 6.8, 4299),
#  (10045682, 'Destination Gobi', None, 1953, None, 90, 6.3, 750),
#  (10045693, 'Do Bigha Zamin', None, 1953, None, 131, 8.4, 1523),
#  (10045699, "Donovan's Brain", None, 1953, None, 84, 6.0, 1299),
#  (10045706, 'Dream Wife', None, 1953, None, 100, 6.1, 1588),
#  (10045737, 'Escape from Fort Bravo', None, 1953, None, 99, 6.7, 2206),
#  (10045810, 'Gentlemen Prefer Blondes', None, 1953, None, 91, 7.2, 28587),
#  (10045824, 'The Glass Wall', None, 1953, None, 82, 6.8, 525),
#  (10045846, 'Gun Fury', None, 1953, None, 83, 6.0, 1169),
#  (10045876, "His Majesty O'Keefe", None, 1954, None, 91, 6.2, 1069),
#  (10045877, 'The Hitch-Hiker', None, 1953, None, 71, 7.0, 6037),
#  (10045883, 'Hondo', None, 1953, None, 83, 7.1, 8558),
#  (10045886, 'Houdini', None, 1953, None, 106, 6.9, 2757),
#  (10045888, 'House of Wax', None, 1953, None, 88, 7.1, 14782),
#  (10045891, 'How to Marry a Millionaire', None, 1953, None, 95, 6.9, 19091),
#  (10045897, 'I Confess', None, 1953, None, 95, 7.3, 17535),
#  (10045899, 'I Love Melvin', None, 1953, None, 77, 6.7, 641),
#  (10045911, 'Inferno', None, 1953, None, 83, 7.1, 1105),
#  (10045917, 'Invaders from Mars', None, 1953, None, 78, 6.4, 6559),
#  (10045919, 'Island in the Sky', None, 1953, None, 109, 6.9, 2926),
#  (10045920, 'It Came from Outer Space', None, 1953, None, 81, 6.5, 7722),
#  (10045932, 'Jeopardy', None, 1953, None, 69, 6.8, 1569),
#  (10045961, 'King of the Khyber Rifles', None, 1953, None, 100, 6.4, 619),
#  (10045963, 'Kiss Me Kate', None, 1953, None, 109, 7.1, 5190),
#  (10045966, 'Knights of the Round Table', None, 1953, None, 115, 6.3, 3014),
#  (10046076, 'Miss Sadie Thompson', None, 1953, None, 91, 6.0, 1248),
#  (10046080, 'The Mississippi Gambler', None, 1953, None, 99, 6.8, 569),
#  (10046085, 'Mogambo', None, 1953, None, 116, 6.7, 6959),
#  (10046087, 'Money from Home', None, 1953, None, 100, 6.3, 657),
#  (10046094, 'The Moon Is Blue', None, 1953, None, 99, 6.7, 1947),
#  (10046124, 'Never Let Me Go', None, 1953, None, 94, 6.2, 598),
#  (10046126, 'Niagara', None, 1953, None, 92, 7.0, 13590),
#  (10046183, 'Peter Pan', None, 1953, None, 77, 7.3, 115139),
#  (10046187, 'Pickup on South Street', None, 1953, None, 80, 7.7, 11639),
#  (10046196, 'Plunder of the Sun', None, 1953, None, 81, 6.5, 547),
#  (10046204, "The President's Lady", None, 1953, None, 96, 7.0, 625),
#  (10046247, 'The Robe', None, 1953, None, 135, 6.7, 8434),
#  (10046250, 'Roman Holiday', None, 1953, None, 118, 8.0, 119081),
#  (10046280, 'Scared Stiff', None, 1953, None, 108, 6.5, 1563),
#  (10046288, 'Second Chance', None, 1953, None, 82, 6.0, 809),
#  (10046294, 'Seminole', None, 1953, None, 87, 6.2, 871),
#  (10046303, 'Shane', None, 1953, None, 118, 7.6, 34029),
#  (10046330, 'Small Town Girl', None, 1953, None, 92, 6.3, 543),
#  (10046348, 'South Sea Woman', None, 1953, None, 99, 6.4, 609),
#  (10046353, 'Split Second', None, 1953, None, 85, 6.9, 1281),
#  (10046359, 'Stalag 17', None, 1953, None, 120, 8.0, 48564),
#  (10046374, 'The Story of Three Loves', None, 1953, None, 122, 7.0, 959),
#  (10046384, 'The Sun Shines Bright', None, 1953, None, 90, 7.0, 1186),
#  (10046414, 'Beat the Devil', None, 1953, None, 89, 6.5, 7546),
#  (10045992, 'The Lawless Breed', None, 1952, None, 83, 6.4, 954),
#  (10046000, 'Lili', None, 1953, None, 81, 7.4, 3008),
#  (10046002, 'A Lion Is in the Streets', None, 1953, None, 88, 6.2, 532),
#  (10046004, 'Little Fugitive', None, 1953, None, 80, 7.5, 2199),
#  (10046008, 'The Living Desert', None, 1953, None, 69, 7.5, 1094),
#  (10046029, 'Malta Story', None, 1953, None, 103, 6.5, 1297),
#  (10046031, 'The Man Between', None, 1953, None, 100, 7.1, 1410),
#  (10046035, 'The Man from the Alamo', None, 1953, None, 79, 6.5, 1487),
#  (10046040, 'Man on a Tightrope', None, 1953, None, 105, 7.1, 1000),
#  (10046425, 'Thunder Bay', None, 1953, None, 103, 6.5, 1420),
#  (10046426, 'Thunder Over the Plains', None, 1953, None, 82, 6.5, 634),
#  (10046435, 'Titanic', None, 1953, None, 98, 7.0, 5908),
#  (10046436, 'The Titfield Thunderbolt', None, 1953, None, 84, 7.1, 2340),
#  (10046463, 'Trouble Along the Way', None, 1953, None, 111, 6.9, 1476),
#  (10046464, 'Trouble in Store', None, 1953, None, 85, 6.8, 838),
#  (10046469, 'Tumbleweed', None, 1953, None, 79, 6.7, 572),
#  (10046564, 'Young Bess', None, 1953, None, 112, 6.7, 1298),
#  (10046504, 'Vesna', None, 1953, None, 96, 8.1, 512),
#  (10046754, 'The Barefoot Contessa', None, 1954, None, 128, 7.0, 8947),
#  (10046759, 'Beau Brummell', None, 1954, None, 113, 6.4, 1201),
#  (10046770, 'Betrayed', None, 1954, None, 108, 6.1, 990),
#  (10046791, 'Black Widow', None, 1954, None, 95, 6.7, 1989),
#  (10046672, '20,000 Leagues Under the Sea', None, 1954, None, 127, 7.2, 26451),
#  (10046676, 'About Mrs. Leslie', None, 1954, None, 104, 7.1, 530),
#  (10046806, 'The Bridges at Toko-Ri', None, 1954, None, 102, 6.7, 4903),
#  (10046712, 'Anatahan', None, 1953, None, 91, 7.2, 789),
#  (10046714, 'Angels One Five', None, 1952, None, 98, 6.5, 786),
#  (10046807, 'Brigadoon', None, 1954, None, 108, 6.8, 7010),
#  (10046808, 'Broken Lance', None, 1954, None, 96, 6.9, 3105),
#  (10046816, 'The Caine Mutiny', None, 1954, None, 124, 7.7, 22986),
#  (10046828, 'Carmen Jones', None, 1954, None, 105, 6.8, 4140),
#  (10046834, "Casanova's Big Night", None, 1954, None, 86, 6.9, 868),
#  (10046874, 'The Country Girl', None, 1954, None, 104, 7.3, 4960),
#  (10046878, 'Crime Wave', None, 1953, None, 73, 7.4, 2836),
#  (10046889, 'The Dam Busters', None, 1955, None, 124, 7.4, 8882),
#  (10046899, 'Demetrius and the Gladiators', None, 1954, None, 101, 6.6, 3117),
#  (10046903, 'Désirée', None, 1954, None, 110, 6.4, 2356),
#  (10046906, 'Destry', None, 1954, None, 95, 6.6, 1045),
#  (10046912, 'Dial M for Murder', None, 1954, None, 105, 8.2, 143268),
#  (10046921, 'Doctor in the House', None, 1954, None, 92, 6.6, 1165),
#  (10046928, 'Down Three Dark Streets', None, 1954, None, 85, 6.8, 701),
#  (10046931, 'Dragnet', None, 1954, None, 88, 6.7, 736),
#  (10046935, 'Drive a Crooked Road', None, 1954, None, 83, 7.0, 853),
#  (10046936, 'Drum Beat', None, 1954, None, 111, 6.4, 698),
#  (10046949, 'The Egyptian', None, 1954, None, 139, 6.6, 3271),
#  (10046963, 'Executive Suite', None, 1954, None, 104, 7.4, 3269),
#  (10046998, 'French Cancan', None, 1955, None, 102, 7.3, 3396),
#  (10047184, 'Living It Up', None, 1954, None, 95, 6.7, 1333),
#  (10047194, 'Lucky Me', None, 1954, None, 100, 6.0, 591),
#  (10047200, 'The Mad Magician', None, 1954, None, 72, 6.5, 1307),
#  (10047238, 'Miseria e nobiltà', None, 1954, None, 94, 7.8, 1268),
#  (10047263, 'Naked Alibi', None, 1954, None, 86, 6.5, 654),
#  (10047279, 'Night People', None, 1954, None, 93, 6.5, 953),
#  (10047040, 'The Good Die Young', None, 1954, None, 100, 6.7, 705),
#  (10047408, 'Rhapsody', None, 1954, None, 115, 6.2, 863),
#  (10047411, 'Ride Clear of Diablo', None, 1954, None, 81, 6.9, 866),
#  (10047296, 'On the Waterfront', None, 1954, None, 108, 8.1, 130916),
#  (10047413, 'Riding Shotgun', None, 1954, None, 73, 6.5, 813),
#  (10047417, 'Riot in Cell Block 11', None, 1954, None, 80, 7.0, 1466),
#  (10047422, 'River of No Return', None, 1954, None, 91, 6.6, 9563),
#  (10047349, 'Phffft', None, 1954, None, 88, 6.6, 1264),
#  (10047365, 'Prince Valiant', None, 1954, None, 100, 6.2, 2218),
#  (10047370, 'Private Hell 36', None, 1954, None, 81, 6.7, 1090),
#  (10047376, 'The Purple Plain', None, 1954, None, 97, 6.5, 1740),
#  (10047377, 'Pushover', None, 1954, None, 88, 7.1, 2221),
#  (10047424, 'Rogue Cop', None, 1954, None, 92, 6.7, 777),
#  (10047388, 'The Raid', None, 1954, None, 83, 6.8, 710),
#  (10047396, 'Rear Window', None, 1954, None, 112, 8.5, 407290),
#  (10047437, 'Sabrina', None, 1954, None, 113, 7.7, 54501),
#  (10047443, 'Salt of the Earth', None, 1954, None, 94, 7.4, 2702),
#  (10047449, 'Saskatchewan', None, 1954, None, 87, 6.4, 820),
#  (10047472, 'Seven Brides for Seven Brothers', None, 1954, None, 102, 7.4, 19769),
#  (10047522, 'A Star Is Born', None, 1954, None, 154, 7.6, 14340),
#  (10047479, 'Shield for Murder', None, 1954, None, 82, 6.9, 896),
#  (10047537, 'The Student Prince', None, 1954, None, 107, 6.6, 717),
#  (10047542, 'Suddenly', None, 1954, None, 77, 6.8, 5565),
#  (10047550, 'Susan Slept Here', None, 1954, None, 98, 6.5, 1370),
#  (10047573, 'Them!', None, 1954, None, 94, 7.2, 18325),
#  (10047574, "There's No Business Like Show Business", None, 1954, None, 117, 6.5, 5068),
#  (10047579, 'Three Cases of Murder', None, 1955, None, 99, 6.6, 691),
#  (10047581, 'Three Hours to Kill', None, 1954, None, 77, 6.4, 509),
#  (10047603, 'Track of the Cat', None, 1954, None, 102, 6.5, 1679),
#  (10047073, 'Hell and High Water', None, 1954, None, 103, 6.2, 1416),
#  (10047086, 'The High and the Mighty', None, 1954, None, 147, 6.8, 5067),
#  (10047094, "Hobson's Choice", None, 1954, None, 108, 7.7, 5990),
#  (10047101, 'Human Desire', None, 1954, None, 91, 7.2, 3717),
#  (10047119, 'An Inspector Calls', None, 1954, None, 80, 7.5, 2783),
#  (10047152, 'Knock on Wood', None, 1954, None, 103, 6.8, 849),
#  (10047495, 'Silver Lode', None, 1954, None, 81, 6.9, 1456),
#  (10047505, 'The Sleeping Tiger', None, 1954, None, 89, 6.5, 655),
#  (10047641, 'Valley of the Kings', None, 1954, None, 86, 6.0, 1140),
#  (10047849, 'Bad Day at Black Rock', None, 1955, None, 81, 7.7, 17674),
#  (10047673, 'White Christmas', None, 1954, None, 120, 7.6, 28623),
#  (10047677, 'The Wild One', None, 1953, None, 79, 6.8, 13594),
#  (10047679, 'Witness to Murder', None, 1954, None, 83, 6.7, 2170),
#  (10047688, 'Young at Heart', None, 1954, None, 117, 6.8, 2077),
#  (10047860, 'Battle Cry', None, 1955, None, 149, 6.5, 1962),
#  (10047873, 'The Benny Goodman Story', None, 1956, None, 116, 6.7, 1035),
#  (10047878, 'The Big Combo', None, 1955, None, 87, 7.4, 5852),
#  (10047795, 'Abbott and Costello Meet the Mummy', None, 1955, None, 79, 6.4, 4764),
#  (10047797, 'Above Us the Waves', None, 1955, None, 99, 6.6, 1116),
#  (10047879, 'Big House, U.S.A.', None, 1955, None, 83, 6.7, 632),
#  (10047834, 'Animal Farm', None, 1954, None, 72, 7.2, 13712),
#  (10047840, 'Artists and Models', None, 1955, None, 109, 6.6, 3190),
#  (10047880, 'The Big Knife', None, 1955, None, 111, 6.8, 2960),
#  (10047885, 'Blackboard Jungle', None, 1955, None, 101, 7.4, 7555),
#  (10047969, 'Daddy Long Legs', None, 1955, None, 126, 6.7, 3224),
#  (10047976, 'Dementia', None, 1955, None, 56, 6.8, 1603),
#  (10047977, 'Davy Crockett: King of the Wild Frontier', None, 1955, None, 93, 7.0, 3059),
#  (10047904, 'A Bullet for Joey', None, 1955, None, 85, 6.0, 824),
#  (10048028, 'East of Eden', None, 1955, None, 118, 7.9, 37463),
#  (10048055, 'The Far Country', None, 1954, None, 97, 7.2, 5988),
#  (10048056, 'The Far Horizons', None, 1955, None, 108, 6.1, 897),
#  (10048064, 'Female on the Beach', None, 1955, None, 97, 6.5, 924),
#  (10048087, 'Footsteps in the Fog', None, 1955, None, 90, 7.0, 1494),
#  (10048034, 'The End of the Affair', None, 1955, None, 105, 6.7, 973),
#  (10048124, 'The Glass Slipper', None, 1955, None, 93, 6.5, 1158),
#  (10048140, 'Guys and Dolls', None, 1955, None, 150, 7.2, 14327),
#  (10047919, 'Captain Lightfoot', None, 1955, None, 92, 6.2, 629),
#  (10047944, 'The Cobweb', None, 1955, None, 134, 6.4, 1351),
#  (10047945, 'The Colditz Story', None, 1955, None, 94, 7.0, 2057),
#  (10052696, 'City of Fear', None, 1959, None, 81, 6.4, 753),
#  (10048380, 'Mister Roberts', None, 1955, None, 123, 7.7, 14478),
#  (10048280, 'Lady and the Tramp', None, 1955, None, 76, 7.3, 111704),
#  (10048281, 'The Ladykillers', None, 1955, None, 91, 7.7, 24456),
#  (10048283, 'Land of the Pharaohs', None, 1955, None, 106, 6.6, 3365),
#  (10048287, 'The Last Command', None, 1955, None, 110, 6.4, 647),
#  (10048289, 'A Lawless Street', None, 1955, None, 78, 6.4, 996),
#  (10048291, 'The Left Hand of God', None, 1955, None, 87, 6.5, 2171),
#  (10048308, 'Lola Montès', None, 1955, None, 116, 7.3, 4460),
#  (10048312, 'The Long Gray Line', None, 1955, None, 138, 7.2, 2200),
#  (10048316, 'Love Is a Many-Splendored Thing', None, 1955, None, 102, 6.5, 4085),
#  (10048317, 'Love Me or Leave Me', None, 1955, None, 122, 7.1, 3443),
#  (10048336, 'A Man Alone', None, 1955, None, 96, 6.4, 735),
#  (10048337, 'A Man Called Peter', None, 1955, None, 119, 7.1, 885),
#  (10048339, 'Man with the Gun', None, 1955, None, 84, 6.7, 1280),
#  (10048340, 'Man Without a Star', None, 1955, None, 89, 6.9, 2638),
#  (10048342, 'The Man from Laramie', None, 1955, None, 103, 7.4, 8630),
#  (10048347, 'The Man with the Golden Arm', None, 1955, None, 119, 7.4, 8855),
#  (10048350, 'Many Rivers to Cross', None, 1955, None, 94, 6.3, 917),
#  (10048356, 'Marty', None, 1955, None, 90, 7.7, 19605),
#  (10048362, 'Maksim Perepelitsa', None, 1956, None, 94, 7.7, 820),
#  (10048171, 'Hit the Deck', None, 1955, None, 112, 6.6, 644),
#  (10048182, 'House of Bamboo', None, 1955, None, 102, 6.8, 2604),
#  (10048190, 'I Died a Thousand Times', None, 1955, None, 109, 6.4, 746),
#  (10048191, "I'll Cry Tomorrow", None, 1955, None, 117, 7.2, 1754),
#  (10048199, 'Illegal', None, 1955, None, 88, 7.0, 1443),
#  (10048204, 'The Indian Fighter', None, 1955, None, 88, 6.4, 1898),
#  (10048210, 'Interrupted Melody', None, 1955, None, 106, 6.7, 827),
#  (10048215, 'It Came from Beneath the Sea', None, 1955, None, 79, 6.0, 4450),
#  (10048216, "It's Always Fair Weather", None, 1955, None, 101, 7.0, 2687),
#  (10048233, 'Jubal', None, 1956, None, 100, 7.1, 3159),
#  (10048248, 'The Kentuckian', None, 1955, None, 104, 6.3, 2221),
#  (10048254, "Killer's Kiss", None, 1955, None, 67, 6.7, 19424),
#  (10048260, 'Kismet', None, 1955, None, 113, 6.3, 1262),
#  (10048261, 'Kiss Me Deadly', None, 1955, None, 106, 7.6, 17037),
#  (10048488, 'The Phenix City Story', None, 1955, None, 100, 7.2, 2054),
#  (10048512, 'The Prisoner', None, 1955, None, 95, 6.9, 744),
#  (10048513, 'The Private War of Major Benson', None, 1955, None, 105, 6.6, 691),
#  (10048527, 'Queen Bee', None, 1955, None, 95, 6.7, 1629),
#  (10048528, 'Quentin Durward', None, 1955, None, 103, 6.5, 829),
#  (10048535, 'Rage at Dawn', None, 1955, None, 87, 6.0, 895),
#  (10048545, 'Rebel Without a Cause', None, 1955, None, 111, 7.7, 77083),
#  (10048563, 'The Rose Tattoo', None, 1955, None, 117, 7.1, 3212),
#  (10048570, 'Run for Cover', None, 1955, None, 93, 6.7, 1170),
#  (10048588, 'The Scarlet Coat', None, 1955, None, 101, 6.3, 524),
#  (10048593, 'The Sea Chase', None, 1955, None, 117, 6.5, 2601),
#  (10048605, 'The Seven Year Itch', None, 1955, None, 105, 7.1, 31362),
#  (10048607, 'Shack Out on 101', None, 1955, None, 80, 6.4, 554),
#  (10048613, 'Shree 420', None, 1955, None, 168, 8.1, 2282),
#  (10048624, 'Sissi', None, 1955, None, 102, 7.0, 7085),
#  (10048640, 'Soldier of Fortune', None, 1955, None, 96, 6.2, 1105),
#  (10048657, 'Stella', None, 1955, None, 90, 8.0, 2227),
#  (10048673, 'Summertime', None, 1955, None, 99, 7.2, 7061),
#  (10048690, 'Tall Man Riding', None, 1955, None, 83, 6.4, 603),
#  (10048691, 'The Tall Men', None, 1955, None, 122, 6.7, 1936),
#  (10048696, 'Tarantula', None, 1955, None, 80, 6.5, 7899),
#  (10048387, 'Moonfleet', None, 1955, None, 84, 6.7, 2990),
#  (10048393, 'Mr. Arkadin', None, 1955, None, 93, 7.3, 7006),
#  (10048411, 'The Naked Dawn', None, 1955, None, 82, 6.7, 534),
#  (10048412, 'The Naked Street', None, 1955, None, 84, 6.5, 626),
#  (10048703, 'Ten Wanted Men', None, 1955, None, 80, 6.0, 918),
#  (10048432, 'Not as a Stranger', None, 1955, None, 135, 6.7, 1566),
#  (10048724, 'Tight Spot', None, 1955, None, 97, 6.6, 1227),
#  (10048728, 'To Catch a Thief', None, 1955, None, 106, 7.4, 57671),
#  (10048729, 'To Hell and Back', None, 1955, None, 106, 7.2, 4532),
#  (10048748, 'Trial', None, 1955, None, 105, 6.8, 859),
#  (10048750, 'The Trouble with Harry', None, 1955, None, 99, 7.1, 30900),
#  (10048767, 'Untamed', None, 1955, None, 111, 6.2, 594),
#  (10048806, 'Wichita', None, 1955, None, 81, 6.9, 1432),
#  (10048789, 'The Violent Men', None, 1955, None, 96, 7.0, 2133),
#  (10048790, 'Violent Saturday', None, 1955, None, 90, 6.9, 1862),
#  (10048791, 'The Virgin Queen', None, 1955, None, 92, 6.8, 2310),
#  (10048801, "We're No Angels", None, 1955, None, 106, 7.5, 7359),
#  (10048452, 'Ordet', None, 1955, None, 126, 8.4, 12481),
#  (10048459, 'Our Miss Brooks', None, 1956, None, 85, 6.6, 505),
#  (10048473, 'Pather Panchali', None, 1955, None, 125, 8.6, 19761),
#  (10049147, 'Dobrý voják Svejk', None, 1957, None, 108, 7.6, 980),
#  (10048918, '1984', None, 1956, None, 90, 7.0, 2837),
#  (10048919, '23 Paces to Baker Street', None, 1956, None, 103, 6.9, 1752),
#  (10048944, "The Ambassador's Daughter", None, 1956, None, 103, 6.0, 545),
#  (10048947, 'Anastasia', None, 1956, None, 105, 7.1, 7036),
#  (10048954, 'Anything Goes', None, 1956, None, 106, 6.2, 797),
#  (10048956, 'Aparajito', None, 1956, None, 110, 8.3, 9857),
#  (10048966, 'Attack', None, 1956, None, 107, 7.4, 4338),
#  (10048967, 'Autumn Leaves', None, 1956, None, 107, 6.8, 1974),
#  (10048971, 'Away All Boats', None, 1956, None, 114, 6.3, 1116),
#  (10048975, 'Back from Eternity', None, 1956, None, 97, 6.6, 1154),
#  (10048976, 'Backlash', None, 1956, None, 84, 6.6, 1243),
#  (10048983, 'Bandido!', None, 1956, None, 92, 6.2, 838),
#  (10049006, 'Beyond a Reasonable Doubt', None, 1956, None, 80, 7.0, 4151),
#  (10049007, 'Bhowani Junction', None, 1956, None, 110, 6.4, 1524),
#  (10049010, 'Bigger Than Life', None, 1956, None, 95, 7.6, 6208),
#  (10049013, 'The Black Sleep', None, 1956, None, 82, 6.1, 1276),
#  (10049030, 'The Brave One', None, 1956, None, 100, 6.6, 669),
#  (10049034, 'Bundle of Joy', None, 1956, None, 98, 6.2, 921),
#  (10049035, 'The Burglar', None, 1957, None, 90, 6.6, 1037),
#  (10049038, 'Bus Stop', None, 1956, None, 96, 6.5, 9997),
#  (10049041, 'C.I.D.', None, 1956, None, 146, 7.5, 551),
#  (10049055, 'Carousel', None, 1956, None, 128, 6.6, 5383),
#  (10049061, 'The Catered Affair', None, 1956, None, 94, 7.5, 2640),
#  (10049083, 'The Cockleshell Heroes', None, 1955, None, 97, 6.6, 1501),
#  (10049096, 'The Court Jester', None, 1955, None, 101, 7.9, 10618),
#  (10049107, 'Crime in the Streets', None, 1956, None, 91, 6.6, 954),
#  (10049110, 'A Cry in the Night', None, 1956, None, 75, 6.1, 746),
#  (10049117, 'D-Day the Sixth of June', None, 1956, None, 106, 6.0, 1175),
#  (10049130, 'Death of a Scoundrel', None, 1956, None, 119, 6.9, 747),
#  (10049259, 'Gervaise', None, 1956, None, 112, 7.4, 1023),
#  (10049261, 'Giant', None, 1956, None, 201, 7.7, 31629),
#  (10049263, "The Girl Can't Help It", None, 1956, None, 99, 6.8, 2819),
#  (10049271, 'Good-bye, My Lady', None, 1956, None, 94, 7.2, 661),
#  (10049366, 'Invasion of the Body Snatchers', None, 1956, None, 80, 7.7, 41517),
#  (10049367, 'Invitation to the Dance', None, 1956, None, 93, 6.3, 726),
#  (10049388, 'Julie', None, 1956, None, 99, 6.1, 1272),
#  (10049405, 'The Killer Is Loose', None, 1956, None, 73, 6.6, 1419),
#  (10049406, 'The Killing', None, 1956, None, 84, 8.0, 74909),
#  (10049407, 'The King and Four Queens', None, 1956, None, 86, 6.1, 1260),
#  (10049408, 'The King and I', None, 1956, None, 133, 7.4, 22446),
#  (10049414, 'A Kiss Before Dying', None, 1956, None, 94, 6.7, 2835),
#  (10049431, 'The Last Frontier', None, 1955, None, 98, 6.5, 1267),
#  (10049432, 'The Last Hunt', None, 1956, None, 108, 6.8, 1275),
#  (10049434, 'The Last Wagon', None, 1956, None, 99, 7.0, 2552),
#  (10049452, 'Love Me Tender', None, 1956, None, 89, 6.2, 3321),
#  (10049291, 'The Harder They Fall', None, 1956, None, 109, 7.6, 6381),
#  (10049314, 'High Society', None, 1956, None, 111, 7.0, 12762),
#  (10049322, 'Hollywood or Bust', None, 1956, None, 95, 6.6, 1704),
#  (10049169, 'Earth vs. the Flying Saucers', None, 1956, None, 83, 6.4, 6453),
#  (10049470, 'The Man Who Knew Too Much', None, 1956, None, 120, 7.5, 52783),
#  (10049471, 'The Man Who Never Was', None, 1956, None, 103, 7.4, 3899),
#  (10049474, 'The Man in the Gray Flannel Suit', None, 1956, None, 153, 7.1, 3045),
#  (10049490, 'Meet Me in Las Vegas', None, 1956, None, 112, 6.1, 629),
#  (10049509, 'Miracle in the Rain', None, 1956, None, 108, 7.1, 1076),
#  (10049513, 'Moby Dick', None, 1956, None, 116, 7.3, 15841),
#  (10049523, 'The Mountain', None, 1956, None, 105, 6.8, 1665),
#  (10049552, 'Nightfall', None, 1956, None, 78, 7.2, 2788),
#  (10049593, 'Pardners', None, 1956, None, 90, 6.3, 1297),
#  (10049601, 'Patterns', None, 1956, None, 83, 7.8, 1902),
#  (10049621, 'Please Murder Me!', None, 1956, None, 78, 6.5, 850),
#  (10049637, "Private's Progress", None, 1956, None, 102, 6.6, 615),
#  (10049639, 'The Proud Ones', None, 1956, None, 94, 7.0, 984),
#  (10049646, 'The Quatermass Xperiment', None, 1955, None, 82, 6.7, 4992),
#  (10049652, 'The Rack', None, 1956, None, 100, 6.8, 1048),
#  (10049653, 'The Rainmaker', None, 1956, None, 121, 7.0, 3195),
#  (10049656, 'Ransom!', None, 1956, None, 109, 7.0, 1611),
#  (10049663, 'The Rawhide Years', None, 1956, None, 85, 6.3, 567),
#  (10049665, 'Reach for the Sky', None, 1956, None, 135, 7.2, 2115),
#  (10049674, 'Richard III', None, 1955, None, 161, 7.4, 3795),
#  (10049682, 'Rock Around the Clock', None, 1956, None, 77, 6.2, 944),
#  (10049696, 'Run for the Sun', None, 1956, None, 99, 6.4, 960),
#  (10049201, 'The Fastest Gun Alive', None, 1956, None, 89, 7.1, 2611),
#  (10049730, 'The Searchers', None, 1956, None, 119, 7.9, 74282),
#  (10049743, '7 Men from Now', None, 1956, None, 78, 7.5, 4171),
#  (10049207, 'Il ferroviere', None, 1956, None, 115, 7.8, 847),
#  (10049769, 'Slightly Scarlet', None, 1956, None, 99, 6.8, 759),
#  (10049778, 'Somebody Up There Likes Me', None, 1956, None, 113, 7.5, 6860),
#  (10049787, 'The Spanish Gardener', None, 1956, None, 97, 6.8, 687),
#  (10049800, 'Storm Center', None, 1956, None, 85, 6.7, 1044),
#  (10049815, 'The Swan', None, 1956, None, 104, 6.5, 2117),
#  (10049829, 'Tea and Sympathy', None, 1956, None, 122, 7.3, 2079),
#  (10049833, 'The Ten Commandments', None, 1956, None, 220, 7.8, 58315),
#  (10049844, 'These Wilder Years', None, 1956, None, 91, 6.8, 832),
#  (10049849, 'Three Violent People', None, 1956, None, 100, 6.3, 1117),
#  (10049856, 'Time Without Pity', None, 1957, None, 85, 6.8, 977),
#  (10049857, 'Time Table', None, 1956, None, 80, 6.7, 509),
#  (10049871, 'A Town Like Alice', None, 1956, None, 117, 7.2, 1242),
#  (10049875, 'Trapeze', None, 1956, None, 105, 6.8, 3863),
#  (10049881, 'Tribute to a Bad Man', None, 1956, None, 95, 6.6, 1232),
#  (10049906, 'Up in the World', None, 1956, None, 87, 6.7, 558),
#  (10049223, 'Forbidden Planet', None, 1956, None, 98, 7.6, 41995),
#  (10049917, 'Vesna na Zarechnoy ulitse', None, 1956, None, 96, 7.6, 1125),
#  (10049933, 'Walk the Proud Land', None, 1956, None, 88, 6.7, 657),
#  (10049934, 'War and Peace', None, 1956, None, 208, 6.8, 8332),
#  (10049944, 'The Werewolf', None, 1956, None, 79, 6.0, 1112),
#  (10049967, 'X the Unknown', None, 1956, None, 81, 6.1, 2359),
#  (10049225, 'Forever, Darling', None, 1956, None, 96, 6.4, 791),
#  (10049233, 'Friendly Persuasion', None, 1956, None, 137, 7.4, 5908),
#  (10050233, 'Cast a Dark Shadow', None, 1955, None, 82, 7.0, 1152),
#  (10050083, '12 Angry Men', None, 1957, None, 96, 8.9, 610724),
#  (10050084, '20 Million Miles to Earth', None, 1957, None, 82, 6.4, 5883),
#  (10050085, 'The 27th Day', None, 1957, None, 75, 6.2, 1026),
#  (10050086, '3:10 to Yuma', None, 1957, None, 92, 7.6, 16950),
#  (10050095, 'The Abominable Snowman', None, 1957, None, 91, 6.5, 3186),
#  (10050097, 'Across the Bridge', None, 1957, None, 103, 7.2, 568),
#  (10050243, 'The Chaplin Revue', None, 1959, None, 128, 7.8, 1047),
#  (10050126, 'Bitter Victory', None, 1957, None, 102, 6.8, 1629),
#  (10050155, 'Baby Face Nelson', None, 1957, None, 85, 6.5, 508),
#  (10050156, 'The Bachelor Party', None, 1957, None, 92, 6.7, 568),
#  (10050166, 'Band of Angels', None, 1957, None, 125, 6.6, 1914),
#  (10050171, 'Battle Hymn', None, 1957, None, 108, 6.4, 918),
#  (10050188, 'Mother India', None, 1957, None, 172, 8.1, 7813),
#  (10050246, 'Chase a Crooked Shadow', None, 1958, None, 88, 7.1, 1033),
#  (10050208, 'Boy on a Dolphin', None, 1957, None, 111, 6.2, 1252),
#  (10050213, 'The Brothers Rico', None, 1957, None, 92, 6.9, 702),
#  (10050225, "Campbell's Kingdom", None, 1957, None, 102, 6.3, 572),
#  (10050356, 'The Enemy Below', None, 1957, None, 98, 7.5, 9056),
#  (10050359, 'Eroica', None, 1958, None, 87, 7.5, 819),
#  (10050367, 'Les espions', None, 1957, None, 125, 6.8, 717),
#  (10050371, 'A Face in the Crowd', None, 1957, None, 126, 8.2, 12338),
#  (10050393, 'Fiend Without a Face', None, 1958, None, 75, 6.2, 3185),
#  (10050397, 'Fire Down Below', None, 1957, None, 116, 6.0, 1308),
#  (10050407, 'Forty Guns', None, 1957, None, 80, 7.0, 4187),
#  (10050419, 'Funny Face', None, 1957, None, 103, 7.0, 24475),
#  (10050252, 'China Gate', None, 1957, None, 97, 6.3, 615),
#  (10050454, 'La grande strada azzurra', None, 1957, None, 103, 6.9, 538),
#  (10050456, 'The Green Man', None, 1956, None, 80, 7.3, 1200),
#  (10050467, 'Gun Glory', None, 1957, None, 89, 6.2, 629),
#  (10050468, 'Gunfight at the O.K. Corral', None, 1957, None, 122, 7.2, 12720),
#  (10050470, 'The Guns of Fort Petticoat', None, 1957, None, 82, 6.4, 978),
#  (10050487, 'A Hatful of Rain', None, 1957, None, 109, 7.1, 995),
#  (10050490, 'Heaven Knows, Mr. Allison', None, 1957, None, 107, 7.3, 7298),
#  (10050494, 'The Helen Morgan Story', None, 1957, None, 118, 6.4, 671),
#  (10050271, 'Crime of Passion', None, 1956, None, 86, 6.5, 1762),
#  (10050549, 'Island in the Sun', None, 1957, None, 119, 6.0, 911),
#  (10050556, 'Jailhouse Rock', None, 1957, None, 96, 6.5, 7187),
#  (10050560, 'Jeanne Eagels', None, 1957, None, 108, 6.3, 589),
#  (10050567, 'Johnny Tremain', None, 1957, None, 80, 6.5, 1443),
#  (10050580, 'Just My Luck', None, 1957, None, 86, 6.3, 511),
#  (10050585, 'Kanal', None, 1957, None, 91, 7.9, 6038),
#  (10050598, 'A King in New York', None, 1957, None, 110, 7.1, 6631),
#  (10050539, 'The Incredible Shrinking Man', None, 1957, None, 81, 7.6, 14587),
#  (10050631, 'Les Girls', None, 1957, None, 114, 6.6, 2319),
#  (10050652, 'The Lonely Man', None, 1957, None, 88, 6.5, 593),
#  (10050658, 'Love in the Afternoon', None, 1957, None, 130, 7.2, 12706),
#  (10050659, 'Loving You', None, 1957, None, 101, 6.5, 1730),
#  (10050660, 'Lucky Jim', None, 1957, None, 95, 6.0, 544),
#  (10050665, 'Madhumati', None, 1958, None, 110, 8.0, 1064),
#  (10050280, 'The Curse of Frankenstein', None, 1957, None, 82, 7.1, 8433),
#  (10050681, 'Man of a Thousand Faces', None, 1957, None, 122, 7.2, 2123),
#  (10050283, 'The D.I.', None, 1957, None, 106, 7.3, 868),
#  (10050699, 'Men in War', None, 1957, None, 102, 7.2, 2242),
#  (10050720, 'The Monolith Monsters', None, 1957, None, 77, 6.4, 2569),
#  (10050296, 'Decision at Sundown', None, 1957, None, 77, 6.9, 2108),
#  (10050738, 'My Man Godfrey', None, 1957, None, 92, 6.3, 737),
#  (10050758, 'Naya Daur', None, 1957, None, 173, 8.1, 962),
#  (10050763, 'Night Passage', None, 1957, None, 90, 6.7, 3227),
#  (10050771, 'No Down Payment', None, 1957, None, 105, 7.1, 807),
#  (10050778, 'Not of This Earth', None, 1957, None, 67, 6.3, 1352),
#  (10050798, 'Old Yeller', None, 1957, None, 83, 7.3, 10695),
#  (10050803, 'The One That Got Away', None, 1957, None, 106, 7.2, 1673),
#  (10050805, 'Operation Mad Ball', None, 1957, None, 105, 6.6, 811),
#  (10050814, 'The Pajama Game', None, 1957, None, 101, 6.7, 2952),
#  (10050815, 'Pal Joey', None, 1957, None, 111, 6.7, 4306),
#  (10050825, 'Paths of Glory', None, 1957, None, 88, 8.4, 160459),
#  (10050301, 'The Delicate Delinquent', None, 1957, None, 101, 6.5, 1180),
#  (10050839, 'Peyton Place', None, 1957, None, 157, 7.2, 4846),
#  (10050847, 'Plunder Road', None, 1957, None, 72, 6.9, 840),
#  (10050870, 'Pyaasa', None, 1957, None, 146, 8.5, 4737),
#  (10050882, 'Raintree County', None, 1957, None, 160, 6.4, 3190),
#  (10050894, 'The Revenge of Frankenstein', None, 1958, None, 90, 6.8, 4145),
# ...
#  (10051201, 'Witness for the Prosecution', None, 1957, None, 116, 8.4, 95259),
#  (10051207, 'The Wrong Man', None, 1956, None, 105, 7.4, 23350),
#  (10050326, 'Don Kikhot', None, 1957, None, 110, 7.4, 718),
#  (10050327, "Don't Go Near the Water", None, 1957, None, 107, 6.2, 562),
#  (10051433, 'The Bravados', None, 1958, None, 98, 7.0, 4282),
#  (10051436, 'The Buccaneer', None, 1958, None, 119, 6.5, 2105),
#  (10051437, 'Buchanan Rides Alone', None, 1958, None, 80, 6.9, 2011),
#  (10051452, 'Carry on Nurse', None, 1959, None, 86, 6.3, 2280),
#  (10051453, 'Carry On Sergeant', None, 1958, None, 84, 6.3, 2070),
#  (10051459, 'Cat on a Hot Tin Roof', None, 1958, None, 108, 8.0, 41429),
#  (10051337, 'The 7th Voyage of Sinbad', None, 1958, None, 88, 7.1, 10723),
#  (10056850, 'Bandini', None, 1963, None, 157, 7.7, 692),
#  (10051477, 'Christine', None, 1958, None, 100, 6.4, 753),
#  (10051372, 'Araya', None, 1959, None, 90, 7.7, 541),
#  (10051383, 'Auntie Mame', None, 1958, None, 143, 7.9, 9628),
#  (10051393, 'The Badlanders', None, 1958, None, 85, 6.4, 1059),
#  (10051406, 'Bell Book and Candle', None, 1958, None, 106, 6.9, 8788),
#  (10051411, 'The Big Country', None, 1958, None, 166, 7.9, 14218),
#  (10051418, 'The Blob', None, 1958, None, 86, 6.4, 20775),
#  (10051423, "Blue Murder at St. Trinian's", None, 1957, None, 86, 6.5, 942),
#  (10051542, 'Corridors of Blood', None, 1958, None, 86, 6.5, 1550),
#  (10051565, 'Dunkirk', None, 1958, None, 135, 7.0, 2379),
#  (10051600, 'Fanfare', None, 1958, None, 86, 7.4, 709),
#  (10051605, 'The Fearmakers', None, 1958, None, 85, 6.1, 509),
#  (10051622, 'The Fly', None, 1958, None, 94, 7.1, 19245),
#  (10051628, 'Fort Dobbs', None, 1958, None, 93, 6.9, 584),
#  (10051629, 'Fort Massacre', None, 1958, None, 80, 6.2, 686),
#  (10051636, 'From Hell to Texas', None, 1958, None, 100, 6.9, 758),
#  (10052673, 'Career', None, 1959, None, 105, 6.9, 501),
#  (10051649, 'The Geisha Boy', None, 1958, None, 98, 6.5, 1668),
#  (10051496, 'Cowboy', None, 1958, None, 92, 6.7, 2381),
#  (10051658, 'Gigi', None, 1958, None, 115, 6.7, 18053),
#  (10051666, "God's Little Acre", None, 1958, None, 118, 6.6, 1553),
#  (10051667, 'The Goddess', None, 1958, None, 104, 6.7, 710),
#  (10051688, 'The Gunfight at Dodge City', None, 1959, None, 81, 6.2, 667),
#  (10051693, 'H-8...', None, 1958, None, 105, 8.5, 1085),
#  (10051713, 'Hell Drivers', None, 1957, None, 108, 7.2, 2523),
#  (10051732, 'Home Before Dark', None, 1958, None, 136, 7.0, 841),
#  (10051767, 'Imitation General', None, 1958, None, 88, 6.7, 530),
#  (10051773, 'Indiscreet', None, 1958, None, 100, 6.8, 7019),
#  (10051786, 'It! The Terror from Beyond Space', None, 1958, None, 69, 6.1, 4152),
#  (10051816, 'The Key', None, 1958, None, 134, 6.6, 1167),
#  (10051818, 'King Creole', None, 1958, None, 116, 7.0, 4054),
#  (10051819, 'Kings Go Forth', None, 1958, None, 109, 6.5, 1272),
#  (10051848, 'The Law and Jake Wade', None, 1958, None, 86, 6.8, 1915),
#  (10051739, "The Horse's Mouth", None, 1958, None, 97, 7.1, 3075),
#  (10051744, 'House on Haunted Hill', None, 1959, None, 75, 6.9, 20682),
#  (10051745, 'Houseboat', None, 1958, None, 110, 6.6, 6931),
#  (10051750, 'The Hunters', None, 1958, None, 108, 6.4, 1237),
#  (10051755, 'I Bury the Living', None, 1958, None, 77, 6.3, 2260),
#  (10051756, 'I Married a Monster from Outer Space', None, 1958, None, 78, 6.3, 2241),
#  (10051758, 'I Want to Live!', None, 1958, None, 120, 7.4, 5304),
#  (10051878, 'The Long, Hot Summer', None, 1958, None, 115, 7.4, 9118),
#  (10051879, 'Look Back in Anger', None, 1959, None, 98, 7.1, 3017),
#  (10051887, 'Machine-Gun Kelly', None, 1958, None, 80, 6.2, 1112),
#  (10051899, 'Man of the West', None, 1958, None, 100, 7.2, 6043),
#  (10051911, 'Marjorie Morningstar', None, 1958, None, 128, 6.2, 869),
#  (10051915, 'Me and the Colonel', None, 1958, None, 109, 7.0, 558),
#  (10051924, 'Merry Andrew', None, 1958, None, 103, 6.8, 671),
#  (10051942, 'Moi, un noir', None, 1958, None, 70, 7.4, 735),
#  (10051959, 'Murder by Contract', None, 1958, None, 81, 7.4, 2136),
#  (10051964, 'Mädchen in Uniform', None, 1958, None, 95, 7.1, 1155),
#  (10051978, 'The Naked and the Dead', None, 1958, None, 131, 6.4, 1115),
#  (10051994, 'A Night to Remember', None, 1958, None, 123, 7.9, 12518),
#  (10052002, 'No Name on the Bullet', None, 1959, None, 77, 7.3, 1804),
#  (10052005, 'No Time for Sergeants', None, 1958, None, 119, 7.6, 3419),
#  (10052050, 'Party Girl', None, 1958, None, 99, 7.1, 2530),
#  (10052059, 'The Perfect Furlough', None, 1958, None, 93, 6.4, 677),
#  (10051501, 'Cry Terror!', None, 1958, None, 96, 6.5, 840),
#  (10052097, 'The Proud Rebel', None, 1958, None, 103, 6.9, 1200),
#  (10052106, 'The Quiet American', None, 1958, None, 120, 6.7, 1531),
#  (10052117, "Rally 'Round the Flag, Boys!", None, 1958, None, 106, 6.0, 1061),
#  (10052126, 'The Reluctant Debutante', None, 1958, None, 94, 6.9, 1198),
#  (10052135, 'Ride a Crooked Trail', None, 1958, None, 88, 6.7, 712),
#  (10052141, 'Rock-a-Bye Baby', None, 1958, None, 103, 6.7, 1597),
#  (10052148, 'The Roots of Heaven', None, 1958, None, 126, 6.4, 786),
#  (10052151, 'Run Silent Run Deep', None, 1958, None, 93, 7.3, 9362),
#  (10052207, 'The Snorkel', None, 1958, None, 90, 6.8, 936),
#  (10052218, 'Some Came Running', None, 1958, None, 137, 7.4, 5263),
#  (10052225, 'South Pacific', None, 1958, None, 157, 6.8, 7494),
#  (10052233, 'The Square Peg', None, 1958, None, 85, 7.1, 1198),
#  (10052234, 'St. Louis Blues', None, 1958, None, 105, 7.2, 503),
#  (10052278, "Teacher's Pet", None, 1958, None, 120, 7.1, 3836),
#  (10052283, 'Ten North Frederick', None, 1958, None, 102, 6.9, 544),
#  (10052287, 'Terror in a Texas Town', None, 1958, None, 80, 6.8, 1599),
#  (10052293, 'Thunder Road', None, 1958, None, 92, 6.7, 2858),
#  (10052295, 'Der Tiger von Eschnapur', None, 1959, None, 101, 6.7, 2147),
#  (10052296, 'A Time to Love and a Time to Die', None, 1958, None, 132, 7.7, 2587),
#  (10052301, 'Too Many Crooks', None, 1959, None, 87, 7.0, 894),
#  (10052302, 'Too Much, Too Soon', None, 1958, None, 121, 6.6, 510),
#  (10052303, 'Torpedo Run', None, 1958, None, 98, 6.4, 1708),
#  (10052190, 'The Sheepman', None, 1958, None, 85, 6.9, 2185),
#  (10051516, 'Damn Yankees', None, 1958, None, 111, 7.1, 2258),
#  (10051519, "Darby's Rangers", None, 1958, None, 121, 6.4, 1100),
#  (10051525, 'The Defiant Ones', None, 1958, None, 96, 7.6, 12157),
#  (10052543, 'Al Capone', None, 1959, None, 104, 6.8, 1357),
#  (10052311, 'Touch of Evil', None, 1958, None, 95, 8.0, 93599),
#  (10052325, 'The Tunnel of Love', None, 1958, None, 98, 6.0, 1022),
#  (10052327, 'The Two-Headed Spy', None, 1958, None, 93, 7.0, 506),
#  (10052354, 'Verboten!', None, 1959, None, 93, 6.8, 736),
#  (10052357, 'Vertigo', None, 1958, None, 128, 8.3, 327884),
#  (10052365, 'The Vikings', None, 1958, None, 116, 7.1, 11609),
#  (10052415, 'The Young Lions', None, 1958, None, 167, 7.2, 6791),
#  (10052427, 'Tom Thumb', None, 1958, None, 98, 6.5, 2118),
#  (10052438, 'Édes Anna', None, 1958, None, 84, 7.3, 527),
#  (10052545, 'Alias Jesse James', None, 1959, None, 92, 6.5, 1104),
#  (10052560, 'Anari', None, 1959, None, 166, 8.0, 600),
#  (10052655, 'A Bucket of Blood', None, 1959, None, 66, 6.7, 5259),
#  (10052583, 'Ask Any Girl', None, 1959, None, 98, 6.5, 652),
#  (10052676, 'Carry on Teacher', None, 1959, None, 86, 6.3, 1864),
#  (10052680, 'Cash McCall', None, 1960, None, 102, 6.4, 1020),
#  (10052700, 'Compulsion', None, 1959, None, 103, 7.4, 5362),
#  (10052713, 'The Crimson Kimono', None, 1959, None, 82, 6.9, 1763),
#  (10052718, 'Curse of the Undead', None, 1959, None, 79, 6.1, 663),
#  (10052724, 'Day of the Outlaw', None, 1959, None, 92, 7.3, 2600),
#  (10052735, "The Devil's Disciple", None, 1959, None, 83, 7.2, 1945),
#  (10052738, 'The Diary of Anne Frank', None, 1959, None, 180, 7.4, 11181),
#  (10052749, "Don't Give Up the Ship", None, 1959, None, 89, 6.5, 620),
#  (10052771, 'Edge of Eternity', None, 1959, None, 80, 6.3, 607),
#  (10052792, 'The FBI Story', None, 1959, None, 149, 6.6, 2732),
#  (10052794, 'Face of a Fugitive', None, 1959, None, 81, 6.6, 545),
#  (10052809, 'The Five Pennies', None, 1959, None, 117, 7.3, 1503),
#  (10052811, 'The Flesh and the Fiends', None, 1960, None, 94, 7.0, 1362),
#  (10052837, 'The Gazebo', None, 1959, None, 100, 6.9, 1523),
#  (10052840, 'The Gene Krupa Story', None, 1959, None, 101, 6.8, 521),
#  (10052847, 'Gidget', None, 1959, None, 95, 6.7, 2843),
#  (10052602, 'The Bat', None, 1959, None, 80, 6.1, 3716),
#  (10052876, 'The Hanging Tree', None, 1959, None, 107, 7.1, 3300),
#  (10052877, 'The Hangman', None, 1959, None, 87, 6.6, 628),
#  (10052896, 'A Hole in the Head', None, 1959, None, 120, 6.3, 2151),
#  (10052901, 'Horrors of the Black Museum', None, 1959, None, 93, 6.0, 993),
#  (10052918, 'Imitation of Life', None, 1959, None, 125, 7.9, 13598),
#  (10052923, 'India: Matri Bhumi', None, 1959, None, 90, 7.3, 503),
#  (10052933, 'It Happened to Jane', None, 1959, None, 97, 6.6, 2183),
#  (10052934, 'It Started with a Kiss', None, 1959, None, 104, 6.1, 628),
#  (10052942, "Jazz on a Summer's Day", None, 1959, None, 85, 8.1, 867),
#  (10052948, 'Journey to the Center of the Earth', None, 1959, None, 129, 7.0, 14236),
#  (10052950, 'The Journey', None, 1959, None, 126, 6.9, 1295),
#  (10052954, 'Kaagaz Ke Phool', None, 1959, None, 148, 8.1, 1791),
#  (10052961, 'Kapò', None, 1960, None, 117, 7.7, 1709),
#  (10052990, 'The Last Angry Man', None, 1959, None, 100, 7.0, 667),
#  (10052997, 'The League of Gentlemen', None, 1960, None, 116, 7.3, 3373),
#  (10053001, "Li'l Abner", None, 1959, None, 114, 6.7, 1190),
#  (10053002, 'Les liaisons dangereuses', None, 1959, None, 106, 6.9, 1123),
#  (10053003, 'Libel', None, 1959, None, 100, 7.1, 906),
#  (10053017, 'Lonelyhearts', None, 1958, None, 100, 6.7, 1005),
#  (10053041, 'The Man Who Could Cheat Death', None, 1959, None, 83, 6.3, 1344),
#  (10053050, 'Marie-Octobre', None, 1959, None, 90, 7.4, 804),
#  (10053054, 'The Mating Game', None, 1959, None, 96, 7.0, 1261),
#  (10053065, 'Middle of the Night', None, 1959, None, 118, 7.2, 981),
#  (10052607, 'The Battle of the Sexes', None, 1960, None, 84, 6.7, 1054),
#  (10052617, 'Beloved Infidel', None, 1959, None, 123, 6.1, 870),
#  (10052618, 'Ben-Hur', None, 1959, None, 212, 8.1, 204418),
#  (10053084, 'The Mouse That Roared', None, 1959, None, 83, 7.0, 7646),
#  (10053085, 'The Mummy', None, 1959, None, 86, 6.8, 7239),
#  (10052619, 'The Best of Everything', None, 1959, None, 121, 6.6, 1599),
#  (10053126, 'North West Frontier', None, 1959, None, 129, 7.2, 2002),
#  (10053131, "The Nun's Story", None, 1959, None, 149, 7.6, 8645),
#  (10053133, 'Odds Against Tomorrow', None, 1959, None, 96, 7.4, 3246),
#  (10053137, 'On the Beach', None, 1959, None, 134, 7.2, 11108),
#  (10053140, 'Operation Amsterdam', None, 1959, None, 104, 6.4, 575),
#  (10053143, 'Operation Petticoat', None, 1959, None, 124, 7.3, 11444),
#  (10053168, 'Pickpocket', None, 1959, None, 76, 7.7, 17430),
#  (10053182, 'Porgy and Bess', None, 1959, None, 138, 7.2, 1396),
#  (10053183, 'Pork Chop Hill', None, 1959, None, 97, 7.1, 3947),
#  (10053221, 'Rio Bravo', None, 1959, None, 141, 8.0, 51827),
#  (10053226, 'Room at the Top', None, 1959, None, 117, 7.5, 4681),
#  (10053244, 'The Savage Innocents', None, 1960, None, 110, 6.9, 1561),
#  (10053247, 'The Scapegoat', None, 1959, None, 91, 6.9, 1531),
#  (10053271, 'The Shaggy Dog', None, 1959, None, 104, 6.5, 3894),
#  (10053272, 'Shake Hands with the Devil', None, 1959, None, 111, 7.0, 1061),
#  (10053279, 'Le signe du lion', None, 1962, None, 103, 7.3, 1503),
#  (10053285, 'Sleeping Beauty', None, 1959, None, 75, 7.2, 125009),
#  (10053290, 'Solomon and Sheba', None, 1959, None, 141, 6.2, 2667),
#  (10052626, 'The Big Circus', None, 1959, None, 109, 6.3, 580),
#  (10052631, 'The Black Orchid', None, 1958, None, 96, 6.5, 794),
#  (10053291, 'Some Like It Hot', None, 1959, None, 121, 8.2, 224857),
#  (10053298, 'The Sound and the Fury', None, 1959, None, 110, 6.3, 722),
#  (10053559, '13 Ghosts', None, 1960, None, 85, 6.1, 4781),
#  (10053334, "Tarzan's Greatest Adventure", None, 1959, None, 88, 6.6, 1068),
#  (10053341, 'Ten Seconds to Hell', None, 1959, None, 93, 6.5, 708),
#  (10053349, 'That Kind of Woman', None, 1959, None, 92, 6.3, 502),
#  (10053351, 'They Came to Cordura', None, 1959, None, 123, 6.4, 1744),
#  (10053352, 'Third Man on the Mountain', None, 1959, None, 107, 7.2, 732),
#  (10053354, 'The 39 Steps', None, 1959, None, 93, 6.6, 1651),
#  (10053361, 'Tiger Bay', None, 1959, None, 105, 7.5, 2097),
#  (10053399, 'Up Periscope', None, 1959, None, 112, 6.5, 1411),
#  (10053434, 'Warlock', None, 1959, None, 121, 7.2, 4923),
#  (10053441, 'Westbound', None, 1959, None, 72, 6.6, 954),
#  (10053445, 'The Wild and the Innocent', None, 1959, None, 84, 6.5, 613),
#  (10053454, 'The World, The Flesh and The Devil', None, 1959, None, 95, 6.9, 2257),
#  (10053455, 'The Wreck of the Mary Deare', None, 1959, None, 105, 6.8, 2103),
#  (10053457, 'Yellowstone Kelly', None, 1959, None, 91, 6.6, 852),
#  (10053458, "Yesterday's Enemy", None, 1959, None, 95, 7.1, 607),
#  (10053462, 'The Young Philadelphians', None, 1959, None, 136, 7.4, 2930),
#  (10053724, 'El cochecito', None, 1960, None, 85, 7.4, 804),
#  (10053729, 'Comanche Station', None, 1960, None, 73, 7.0, 2828),
#  (10053750, 'The Dark at the Top of the Stairs', None, 1960, None, 124, 7.1, 636),
#  (10053752, 'The Day They Robbed the Bank of England', None, 1960, None, 85, 6.6, 666),
#  (10053793, 'Elmer Gantry', None, 1960, None, 146, 7.8, 9414),
#  (10053804, 'Exodus', None, 1960, None, 208, 6.7, 8272),
#  (10053825, 'Flaming Star', None, 1960, None, 101, 6.5, 2760),
#  (10053622, 'BUtterfield 8', None, 1960, None, 109, 6.4, 5239),
#  (10053644, 'The Bellboy', None, 1960, None, 72, 6.5, 3533),
#  (10053645, 'Bells Are Ringing', None, 1960, None, 126, 7.0, 2602),
#  (10053677, 'The Brides of Dracula', None, 1960, None, 85, 6.7, 6042),
#  (10053683, 'The Bulldog Breed', None, 1960, None, 97, 6.3, 705),
#  (10053690, 'Can-Can', None, 1960, None, 131, 6.3, 1853),
#  (10053715, 'Cimarron', None, 1960, None, 147, 6.4, 2392),
#  (10053716, 'Cinderfella', None, 1960, None, 91, 6.0, 2767),
#  (10053719, 'The City of the Dead', None, 1960, None, 78, 6.8, 5351),
#  (10053848, 'G.I. Blues', None, 1960, None, 104, 6.3, 2971),
#  (10053849, 'The Gallant Hours', None, 1960, None, 115, 7.1, 1278),
#  (10053935, 'Ice Cold in Alex', None, 1958, None, 130, 7.8, 4633),
#  (10053946, 'Inherit the Wind', None, 1960, None, 128, 8.1, 25050),
#  (10053957, 'It Started in Naples', None, 1960, None, 100, 6.4, 2139),
#  (10053961, 'Jack the Ripper', None, 1959, None, 84, 6.2, 578),
#  (10053967, 'The Young One', None, 1960, None, 95, 7.4, 2267),
#  (10053994, 'Kidnapped', None, 1960, None, 97, 6.6, 1185),
#  (10054016, 'The Last Voyage', None, 1960, None, 91, 6.6, 1708),
#  (10054022, "Let's Make Love", None, 1960, None, 119, 6.5, 6150),
#  (10053877, 'The Grass Is Greener', None, 1960, None, 104, 6.5, 4150),
#  (10053879, 'The Great Impostor', None, 1960, None, 113, 7.0, 1040),
#  (10053882, 'The 3 Worlds of Gulliver', None, 1960, None, 99, 6.5, 2163),
#  (10053899, 'Hell Bent for Leather', None, 1960, None, 82, 6.8, 647),
#  (10053900, 'Hell Is a City', None, 1960, None, 98, 7.1, 848),
#  (10053901, 'Hell to Eternity', None, 1960, None, 131, 7.0, 944),
#  (10053912, 'High Time', None, 1960, None, 103, 6.2, 527),
#  (10053917, 'Home from the Hill', None, 1960, None, 150, 7.4, 2664),
#  (10053925, 'House of Usher', None, 1960, None, 79, 7.0, 10824),
#  (10054042, 'Macario', None, 1960, None, 91, 8.3, 2139),
#  (10054047, 'The Magnificent Seven', None, 1960, None, 128, 7.7, 82007),
#  (10054049, 'Make Mine Mink', None, 1960, None, 101, 7.1, 921),
#  (10054084, 'Midnight Lace', None, 1960, None, 103, 6.8, 4177),
#  (10054091, 'Moderato cantabile', None, 1960, None, 91, 6.8, 615),
#  (10054095, 'The Mountain Road', None, 1960, None, 102, 6.3, 662),
#  (10054098, 'Mughal-E-Azam', None, 1960, None, 197, 8.3, 6416),
#  (10054152, 'Our Man in Havana', None, 1959, None, 103, 7.2, 4423),
#  (10054102, 'Murder, Inc.', None, 1960, None, 103, 6.6, 1109),
#  (10054116, 'Never Take Sweets from a Stranger', None, 1960, None, 91, 7.3, 947),
#  (10054127, 'North to Alaska', None, 1960, None, 122, 7.0, 6466),
#  ...]

# %%
# %%sql
#
# SELECT * FROM movies
# WHERE orig_title IS NOT NULL ;
# Out:
#  * postgresql://postgres:***@localhost:5432/imdb
# 8270 rows affected.
# [(10041719, 'Orpheus', 'Orphée', 1950, None, 95, 8.0, 9346),
#  (10041931, 'Stromboli', 'Stromboli, terra di Dio', 1950, None, 107, 7.3, 5239),
#  (10042355, 'Story of a Love Affair', 'Cronaca di un amore', 1950, None, 98, 7.1, 2209),
#  (10042619, 'Diary of a Country Priest', "Journal d'un curé de campagne", 1951, None, 115, 8.0, 8621),
#  (10042692, 'Variety Lights', 'Luci del varietà', 1950, None, 97, 7.1, 2416),
#  (10042804, 'The Young and the Damned', 'Los olvidados', 1950, None, 85, 8.3, 16453),
#  (10042810, 'Operation Disaster', 'Morning Departure', 1950, None, 102, 7.0, 668),
#  (10042876, 'Rashomon', 'Rashômon', 1950, None, 88, 8.2, 138304),
#  (10042906, 'La Ronde', 'La ronde', 1950, None, 93, 7.6, 4456),
#  (10043048, 'To Joy', 'Till glädje', 1950, None, 98, 7.2, 2109),
#  (10043303, 'The Red Inn', "L'auberge rouge", 1951, None, 98, 7.4, 1201),
#  (10043313, 'Early Summer', 'Bakushû', 1951, None, 125, 8.2, 6349),
#  (10043386, "Casque d'Or", "Casque d'or", 1952, None, 96, 7.7, 4414),
#  (10043411, 'The Emperor and the Golem', 'Císaruv pekar - Pekaruv císar', 1952, None, 144, 8.1, 1069),
#  (10043511, "Europe '51", "Europa '51", 1952, None, 118, 7.5, 2874),
#  (10043567, 'Miss Julie', 'Fröken Julie', 1951, None, 90, 7.3, 1499),
#  (10043614, 'The Idiot', 'Hakuchi', 1951, None, 166, 7.3, 4110),
#  (10043652, 'One Summer of Happiness', 'Hon dansade en sommar', 1951, None, 103, 6.9, 623),
#  (10043668, "I'll Never Forget You", 'The House in the Square', 1951, None, 90, 7.1, 716),
#  (10043686, 'Forbidden Games', 'Jeux interdits', 1952, None, 86, 8.1, 10142),
#  (10043824, 'A Woman Without Love', 'Una mujer sin amor', 1952, None, 85, 6.5, 649),
#  (10043825, 'The Lady of Musashino', 'Musashino fujin', 1951, None, 88, 7.3, 547),
#  (10043892, 'Miss Oyu', 'Oyû-sama', 1951, None, 94, 7.6, 1194),
#  (10043918, 'The Little World of Don Camillo', 'Don Camillo', 1952, None, 107, 7.7, 3680),
#  (10043927, 'La Poison', 'La poison', 1951, None, 85, 7.5, 934),
#  (10044008, 'A Christmas Carol', 'Scrooge', 1951, None, 86, 8.1, 18209),
#  (10044060, 'Summer Interlude', 'Sommarlek', 1951, None, 96, 7.6, 4574),
#  (10044170, 'Man of Straw', 'Der Untertan', 1951, None, 109, 7.3, 715),
#  (10044409, 'Beauties of the Night', 'Les belles de nuit', 1952, None, 87, 6.9, 517),
#  (10044429, 'Struggle in the Valley', 'Siraa Fil-Wadi', 1954, None, 105, 7.6, 769),
#  (10044497, 'Children of Hiroshima', 'Genbaku no ko', 1952, None, 97, 7.8, 876),
#  (10044518, 'White Mane', 'Crin blanc: Le cheval sauvage', 1953, None, 47, 7.3, 1848),
#  (10044982, 'The Flavor of Green Tea Over Rice', 'Ochazuke no aji', 1952, None, 116, 7.8, 1938),
#  (10044986, 'Mother', 'Okaasan', 1952, None, 98, 7.6, 545),
#  (10045056, 'The Promoter', 'The Card', 1952, None, 85, 7.1, 1103),
#  (10045081, 'The Return of Don Camillo', 'Le retour de Don Camillo', 1953, None, 115, 7.3, 2100),
#  (10045201, 'The Stranger in Between', 'Hunted', 1952, None, 84, 7.4, 803),
#  (10045504, 'Love in the City', "L'amore in città", 1953, None, 115, 6.5, 827),
#  (10045654, 'Crash of Silence', 'Mandy', 1952, None, 93, 7.4, 603),
#  (10045814, 'A Geisha', 'Gion bayashi', 1953, None, 85, 7.6, 1563),
#  (10045848, 'Sawdust and Tinsel', 'Gycklarnas afton', 1953, None, 93, 7.6, 5414),
#  (10045935, 'Gate of Hell', 'Jigokumon', 1953, None, 89, 7.2, 2796),
#  (10046149, 'The Proud and the Beautiful', 'Les orgueilleux', 1953, None, 103, 7.4, 716),
#  (10046159, 'Bread, Love and Dreams', 'Pane, amore e fantasia', 1953, None, 93, 7.0, 1171),
#  (10046268, 'The Wages of Fear', 'Le salaire de la peur', 1953, None, 131, 8.1, 49244),
#  (10046366, 'Indiscretion of an American Wife', 'Stazione Termini', 1953, None, 90, 6.2, 2218),
#  (10046022, 'The Earrings of Madame De...', 'Madame de...', 1953, None, 105, 8.0, 8041),
#  (10046415, 'The Count of Monte Cristo', 'Le comte de Monte-Cristo', 1954, None, 183, 7.2, 706),
#  (10046429, 'The Adultress', 'Thérèse Raquin', 1953, None, 102, 7.3, 1037),
#  (10046511, 'Journey to Italy', 'Viaggio in Italia', 1954, None, 85, 7.4, 7742),
#  (10046521, 'I Vitelloni', 'I vitelloni', 1953, None, 107, 7.9, 13241),
#  (10046478, 'Ugetsu', 'Ugetsu monogatari', 1953, None, 96, 8.3, 18356),
#  (10046487, "Monsieur Hulot's Holiday", 'Les vacances de Monsieur Hulot', 1953, None, 114, 7.5, 15340),
#  (10046498, 'Skanderbeg', 'Velikiy voin Albanii Skanderbeg', 1953, None, 95, 7.9, 529),
#  (10046750, 'Late Chrysanthemums', 'Bangiku', 1954, None, 101, 7.4, 837),
#  (10046675, 'Wuthering Heights', 'Abismos de pasión', 1954, None, 91, 6.7, 1031),
#  (10046705, 'An American in Rome', 'Un americano a Roma', 1954, None, 94, 7.0, 1367),
#  (10046961, 'School for Tramps', 'Escuela de vagabundos', 1955, None, 99, 8.0, 517),
#  (10046911, 'Diabolique', 'Les diaboliques', 1955, None, 117, 8.0, 57720),
#  (10046970, 'The Detective', 'Father Brown', 1954, None, 91, 6.8, 1141),
#  (10047034, 'Godzilla', 'Gojira', 1954, None, 96, 7.6, 26077),
#  (10047216, 'The Miracle of Marcelino', 'Marcelino pan y vino', 1955, None, 91, 7.1, 1903),
#  (10047259, 'The Story of Vickie', 'Mädchenjahre einer Königin', 1954, None, 118, 6.5, 733),
#  (10047281, 'Twenty-Four Eyes', 'Nijûshi no hitomi', 1954, None, 156, 8.0, 2018),
#  (10047313, 'The Gold of Naples', "L'oro di Napoli", 1954, None, 138, 7.3, 1313),
#  (10047435, 'The River and Death', 'El río y la muerte', 1954, None, 91, 6.8, 637),
#  (10047445, 'Sansho the Bailiff', 'Sanshô dayû', 1954, None, 124, 8.4, 12852),
#  (10047572, "The Devil's General", 'Des Teufels General', 1955, None, 117, 7.3, 969),
#  (10047085, 'High and Dry', "The 'Maggie'", 1954, None, 92, 7.0, 1081),
#  (10047630, 'Ulysses', 'Ulisse', 1954, None, 117, 6.7, 3123),
#  (10047682, 'Sound of the Mountain', 'Yama no oto', 1954, None, 95, 7.8, 1353),
#  (10047821, 'Le Amiche', 'Le amiche', 1955, None, 104, 7.2, 2300),
#  (10047892, 'Bob le Flambeur', 'Bob le flambeur', 1956, None, 98, 7.7, 9596),
#  (10048021, 'Rififi', 'Du rififi chez les hommes', 1955, None, 118, 8.2, 23357),
#  (10048112, 'Wee Geordie', 'Geordie', 1955, None, 93, 6.9, 711),
#  (10048133, 'The Grand Maneuver', 'Les grandes manoeuvres', 1955, None, 106, 6.8, 812),
#  (10047925, 'That Is the Dawn', "Cela s'appelle l'aurore", 1956, None, 102, 6.8, 597),
#  (10047937, 'Bloody Spear at Mount Fuji', 'Chiyari Fuji', 1955, None, 94, 7.4, 568),
#  (10048272, 'Dreams', 'Kvinnodröm', 1955, None, 87, 7.1, 2219),
#  (10048275, 'Merry-Go-Round', 'Körhinta', 1956, None, 90, 7.8, 1104),
#  (10048198, 'I Live in Fear', 'Ikimono no kiroku', 1955, None, 103, 7.3, 3725),
#  (10048499, 'La Pointe Courte', 'La Pointe-Courte', 1955, None, 86, 7.1, 2103),
#  (10048500, 'A Generation', 'Pokolenie', 1955, None, 87, 7.1, 2181),
#  (10048641, 'Smiles of a Summer Night', 'Sommarnattens leende', 1955, None, 109, 7.8, 11281),
#  (10048752, 'The Unknown Soldier', 'Tuntematon sotilas', 1955, None, 177, 8.0, 6684),
#  (10048757, 'Floating Clouds', 'Ukigumo', 1955, None, 123, 7.7, 2099),
#  (10048820, 'Princess Yang Kwei-fei', 'Yôkihi', 1955, None, 98, 7.2, 1436),
#  (10048475, "Too Bad She's Bad", 'Peccato che sia una canaglia', 1954, None, 95, 6.8, 697),
#  (10048933, 'Street of Shame', 'Akasen chitai', 1956, None, 87, 7.9, 3288),
#  (10048981, 'The Band of Honest Men', 'La banda degli onesti', 1956, None, 106, 7.5, 1029),
#  (10049012, 'The Burmese Harp', 'Biruma no tategoto', 1956, None, 116, 8.1, 4989),
#  (10049023, "Raquel's Shoeshiner", 'El bolero de Raquel', 1957, None, 101, 7.3, 704),
#  (10049042, 'The Rocket from Calabuch', 'Calabuch', 1956, None, 93, 7.4, 758),
#  (10049043, 'Main Street', 'Calle Mayor', 1956, None, 99, 7.8, 1103),
#  (10049357, 'Night Ambush', 'Ill Met by Moonlight', 1957, None, 104, 6.6, 1297),
#  (10049378, 'Stay Alert', 'Jagte Raho', 1956, None, 153, 8.5, 771),
#  (10049419, 'A Girl in Black', 'To koritsi me ta mavra', 1956, None, 100, 7.7, 816),
#  (10049429, 'Lust of the Vampire', 'I vampiri', 1957, None, 82, 6.6, 1314),
#  (10049290, 'Professor Hannibal', 'Hannibál tanár úr', 1956, None, 89, 7.7, 555),
#  (10049293, 'The Captain from Köpenick', 'Der Hauptmann von Köpenick', 1956, None, 93, 7.2, 1396),
#  (10049189, '...And God Created Woman', 'Et Dieu... créa la femme', 1956, None, 95, 6.3, 6832),
#  (10049518, 'The Silent World', 'Le monde du silence', 1956, None, 86, 7.1, 1255),
#  (10049521, 'Death in the Garden', 'La mort en ce jardin', 1956, None, 104, 6.8, 1575),
#  (10049531, 'The Mystery of Picasso', 'Le mystère Picasso', 1956, None, 78, 7.7, 1820),
#  (10049537, 'Flowing', 'Nagareru', 1956, None, 117, 7.6, 784),
#  (10049762, 'Sissi: The Young Empress', 'Sissi - Die junge Kaiserin', 1956, None, 107, 6.7, 5460),
#  (10049783, 'The Forty-First', 'Sorok pervyy', 1956, None, 88, 7.6, 1261),
#  (10049784, 'Early Spring', 'Sôshun', 1956, None, 145, 7.9, 2401),
#  (10049794, 'The Flying Carpet', 'Starik Khottabych', 1957, None, 86, 7.2, 1016),
#  (10049845, 'The Third Key', 'The Long Arm', 1956, None, 96, 7.1, 532),
#  (10049877, 'Four Bags Full', 'La traversée de Paris', 1956, None, 80, 7.4, 3078),
#  (10049902, 'A Man Escaped', "Un condamné à mort s'est échappé ou Le vent souffle où il veut", 1956, None, 101, 8.3, 16396),
#  (10050091, 'Seven Days from Now', 'Seven Waves Away', 1957, None, 100, 7.5, 1365),
#  (10050100, 'Paradise Lagoon', 'The Admirable Crichton', 1957, None, 94, 7.0, 1172),
#  (10050123, 'Montparnasse 19', 'Les amants de Montparnasse', 1958, None, 108, 7.4, 990),
#  (10050162, 'The Sun Legend of the End of the Tokugawa Era', 'Bakumatsu taiyôden', 1957, None, 110, 7.4, 565),
#  (10050398, 'Fools in the Mountains', 'Fjols til fjells', 1957, None, 90, 7.4, 1021),
#  (10050251, 'The Mysterians', 'Chikyû Bôeigun', 1957, None, 89, 6.1, 1235),
#  (10050613, 'Throne of Blood', 'Kumonosu-jô', 1957, None, 110, 8.1, 40639),
#  (10050634, 'The Cranes Are Flying', 'Letyat zhuravli', 1957, None, 95, 8.3, 13197),
#  (10050669, 'Inspector Maigret', 'Maigret tend un piège', 1958, None, 119, 7.2, 1323),
#  (10050706, 'Mon Oncle', 'Mon oncle', 1958, None, 116, 7.8, 17046),
#  (10050746, 'The Devil Strikes at Night', 'Nachts, wenn der Teufel kam', 1957, None, 105, 7.3, 882),
#  (10050762, 'Nine Lives', 'Ni liv', 1957, None, 96, 7.3, 1525),
#  (10050781, 'The Hunchback of Notre Dame', 'Notre-Dame de Paris', 1956, None, 115, 6.7, 2251),
#  (10050782, 'Le Notti Bianche', 'Le notti bianche', 1957, None, 102, 7.8, 6451),
#  (10050783, 'The Nights of Cabiria', 'Le notti di Cabiria', 1957, None, 110, 8.1, 39350),
#  (10050853, 'I Dutifully Report', 'Poslusne hlásím', 1958, None, 91, 7.4, 559),
#  (10050976, 'The Seventh Seal', 'Det sjunde inseglet', 1957, None, 96, 8.2, 146553),
#  (10050985, 'Big Time Operators', 'The Smallest Show on Earth', 1957, None, 80, 7.0, 1593),
#  (10050986, 'Wild Strawberries', 'Smultronstället', 1957, None, 91, 8.2, 85988),
#  (10051065, 'A Matter of Dignity', 'To teleftaio psemma', 1958, None, 112, 7.8, 514),
#  (10051093, 'Tokyo Twilight', 'Tôkyô boshoku', 1957, None, 140, 8.2, 2875),
#  (10051133, 'La Parisienne', 'Une parisienne', 1957, None, 86, 6.3, 757),
#  (10050330, 'The Lower Depths', 'Donzoko', 1957, None, 137, 7.4, 4373),
#  (10051378, 'Elevator to the Gallows', "Ascenseur pour l'échafaud", 1958, None, 91, 8.0, 18690),
#  (10051390, 'Cairo Station', 'Bab el hadid', 1958, None, 77, 7.7, 2684),
#  (10051413, 'The H-Man', 'Bijo to ekitai ningen', 1958, None, 87, 6.1, 1049),
#  (10051429, 'Bonjour Tristesse', 'Bonjour tristesse', 1958, None, 94, 6.9, 4018),
#  (10051554, 'Horror of Dracula', 'Dracula', 1958, None, 82, 7.3, 18977),
#  (10051569, 'Lake of the Dead', 'De dødes tjern', 1958, None, 76, 7.2, 1586),
#  (10051579, 'Love Is My Profession', 'En cas de malheur', 1958, None, 105, 6.7, 1096),
#  (10051584, 'Conflagration', 'Enjô', 1958, None, 99, 7.1, 649),
#  (10051655, 'Gideon of Scotland Yard', "Gideon's Day", 1958, None, 91, 6.5, 851),
#  (10051706, 'The Haunted Strangler', 'Grip of the Strangler', 1958, None, 78, 6.3, 1081),
#  (10051762, 'The Idiot', 'Idiot', 1958, None, 124, 7.6, 511),
#  (10051790, 'Ivan the Terrible, Part II', 'Ivan Groznyy. Skaz vtoroy: Boyarskiy zagovor', 1958, None, 88, 7.9, 6217),
#  (10051792, 'The Music Room', 'Jalsaghar', 1958, None, 100, 8.0, 4583),
#  (10051808, 'The Hidden Fortress', 'Kakushi-toride no san-akunin', 1958, None, 139, 8.1, 30431),
#  (10051851, 'The Law Is the Law', 'La legge è legge', 1958, None, 95, 7.5, 754),
#  (10051852, 'The Law', 'La legge', 1959, None, 126, 6.9, 615),
#  (10051927, 'We Only Live Once', 'Mia zoi tin ehoume', 1958, None, 111, 8.3, 1337),
#  (10051955, 'The Rickshaw Man', 'Muhomatsu no issho', 1958, None, 103, 7.6, 662),
#  (10051983, 'Nazarin', 'Nazarín', 1959, None, 94, 7.9, 4660),
#  (10051989, 'Neither Seen Nor Recognized', 'Ni vu, ni connu', 1958, None, 95, 7.2, 1274),
#  (10052017, 'Brink of Life', 'Nära livet', 1958, None, 84, 7.6, 2155),
#  (10052046, 'Paras-Pathar', 'Parash Pathar', 1958, None, 111, 7.7, 875),
#  (10052063, 'The Noose', 'Petla', 1958, None, 96, 7.7, 680),
#  (10052073, 'The Little Apartment', 'El pisito', 1958, None, 87, 7.3, 664),
#  (10052080, 'Ashes and Diamonds', 'Popiól i diament', 1958, None, 103, 7.9, 9464),
#  (10051532, 'Desert Patrol', 'Sea of Sand', 1958, None, 97, 6.7, 757),
#  (10052374, 'The Deadly Invention', 'Vynález zkázy', 1958, None, 78, 7.5, 1590),
#  (10052556, 'The Lovers', 'Les amants', 1958, None, 90, 7.2, 4336),
#  (10052634, 'Chance Meeting', 'Blind Date', 1959, None, 95, 6.7, 590),
#  (10052644, 'Le Bossu', 'Le bossu', 1959, None, 105, 6.9, 1027),
#  (10052687, "Charles' Aunt", 'Charles Tante', 1959, None, 101, 6.9, 694),
#  (10052708, 'Les Cousins', 'Les cousins', 1959, None, 112, 7.3, 2285),
#  (10052781, 'Escape by Night', 'Era notte a Roma', 1960, None, 138, 7.3, 506),
#  (10052786, 'Violent Summer', 'Estate violenta', 1959, None, 98, 7.5, 1076),
#  (10052829, 'Face of the Frog', 'Der Frosch mit der Maske', 1959, None, 89, 6.4, 810),
#  (10052589, 'Fiasco in Milan', 'Audace colpo dei soliti ignoti', 1959, None, 105, 7.1, 760),
#  (10052600, 'Ballad of a Soldier', 'Ballada o soldate', 1959, None, 88, 8.2, 8755),
#  (10052861, 'The Great War', 'La grande guerra', 1959, None, 137, 8.3, 3353),
#  (10052893, 'Hiroshima Mon Amour', 'Hiroshima mon amour', 1959, None, 90, 7.9, 25363),
#  (10052957, 'Odd Obsession', 'Kagi', 1959, None, 96, 6.9, 670),
#  (10053033, 'Maigret and the St. Fiacre Case', "Maigret et l'affaire Saint-Fiacre", 1959, None, 101, 7.1, 985),
#  (10053106, 'Letter Never Sent', 'Neotpravlennoe pismo', 1960, None, 96, 7.9, 2683),
#  (10053114, 'The Human Condition I: No Greater Love', 'Ningen no jôken', 1959, None, 208, 8.5, 5387),
#  (10053115, 'The Human Condition II: Road to Eternity', 'Ningen no jôken', 1959, None, 181, 8.5, 4246),
#  (10053134, 'Good Morning', 'Ohayô', 1959, None, 94, 7.9, 6620),
#  (10053146, 'Black Orpheus', 'Orfeu Negro', 1959, None, 100, 7.5, 8848),
#  (10053176, 'Night Train', 'Pociag', 1959, None, 99, 7.8, 2334),
#  (10053333, 'The Overtaxed', 'I tartassati', 1959, None, 105, 7.1, 627),
#  (10053390, 'Floating Weeds', 'Ukikusa', 1959, None, 119, 8.0, 6440),
#  (10053428, 'Come Dance with Me!', 'Voulez-vous danser avec moi', 1959, None, 91, 6.3, 505),
#  (10053472, 'Breathless', 'À bout de souffle', 1960, None, 90, 7.9, 65885),
#  (10053473, 'Leda', 'À double tour', 1959, None, 110, 6.7, 1037),
#  (10053740, 'The Concrete Jungle', 'The Criminal', 1960, None, 97, 6.9, 1083),
#  (10053746, 'The Lady with the Dog', 'Dama s sobachkoy', 1960, None, 83, 7.4, 843),
#  (10053765, 'The Goddess', 'Devi', 1960, None, 93, 7.8, 1683),
#  (10053772, "The Devil's Eye", 'Djävulens öga', 1960, None, 87, 7.2, 3154),
#  (10053779, 'La Dolce Vita', 'La dolce vita', 1960, None, 174, 8.0, 59952),
#  (10053802, 'Blood and Roses', 'Et mourir de plaisir', 1960, None, 87, 6.6, 1016),
#  (10053619, "L'Avventura", "L'avventura", 1960, None, 144, 7.9, 23445),
#  (10053638, 'The Battle of Austerlitz', 'Austerlitz', 1960, None, 166, 6.3, 505),
#  (10053643, "Bell' Antonio", "Il bell'Antonio", 1960, None, 105, 7.4, 1158),
#  (10053696, 'Captain Blood', 'Le capitan', 1960, None, 111, 6.3, 577),
#  (10053699, 'Carry On Constable', 'Carry on, Constable', 1960, None, 86, 6.3, 1957),
#  (10053856, 'Il Generale Della Rovere', 'Il generale Della Rovere', 1959, None, 132, 7.8, 2514),
#  (10053976, 'The Virgin Spring', 'Jungfrukällan', 1960, None, 89, 8.1, 24134),
#  (10054004, 'Black Cross', 'Krzyzacy', 1960, None, 166, 6.8, 1542),
#  (10054067, 'Black Sunday', 'La maschera del demonio', 1960, None, 87, 7.2, 12267),
#  (10054068, 'Love and Larceny', 'Il mattatore', 1960, None, 103, 7.2, 546),
#  (10054144, 'When a Woman Ascends the Stairs', 'Onna ga kaidan wo agaru toki', 1960, None, 111, 8.1, 3295),
#  (10054122, 'Night and Fog in Japan', 'Nihon no yoru to kiri', 1960, None, 107, 6.9, 537),
#  (10054130, 'La Notte', 'La notte', 1961, None, 122, 8.1, 15704),
#  (10054135, "Ocean's 11", "Ocean's Eleven", 1960, None, 127, 6.6, 18504),
#  (10054159, 'Passenger', 'Pasazerka', 1963, None, 62, 7.5, 1339),
#  (10054177, 'Le Petit Soldat', 'Le petit soldat', 1963, None, 88, 7.3, 5362),
#  (10054189, 'Purple Noon', 'Plein soleil', 1960, None, 118, 7.8, 12212),
#  (10054225, 'Girl with a Suitcase', 'La ragazza con la valigia', 1961, None, 121, 7.6, 1547),
#  (10054242, 'The Passionate Thief', 'Risate di gioia', 1960, None, 106, 7.3, 591),
#  (10054325, 'Take Aim at the Police Van', "'Jûsangô taihisen' yori: Sono gosôsha o nerae", 1960, None, 79, 6.7, 719),
#  (10054371, 'The 1,000 Eyes of Dr. Mabuse', 'Die 1000 Augen des Dr. Mabuse', 1960, None, 103, 7.0, 2591),
#  (10054389, 'Shoot the Piano Player', 'Tirez sur le pianiste', 1960, None, 81, 7.5, 15732),
#  (10054395, 'Dead Eyes of London', 'Die toten Augen von London', 1961, None, 104, 6.4, 844),
#  (10054413, 'Everybody Go Home!', 'Tutti a casa', 1960, None, 122, 7.7, 841),
#  (10054425, 'Taxi for Tobruk', 'Un taxi pour Tobrouk', 1961, None, 95, 7.3, 1394),
#  (10054451, 'Higher Principle', 'Vyssí princip', 1960, None, 104, 8.3, 517),
#  (10054494, 'Zazie dans le Métro', 'Zazie dans le métro', 1960, None, 93, 7.0, 4868),
#  (10054495, 'Bad Luck', 'Zezowate szczescie', 1960, None, 92, 7.6, 900),
#  (10054709, 'Pigs and Battleships', 'Buta to gunkan', 1961, None, 108, 7.5, 1768),
#  (10054734, 'The Counterfeiters of Paris', 'Le cave se rebiffe', 1961, None, 98, 7.1, 916),
#  (10054632, 'Last Year at Marienbad', "L'année dernière à Marienbad", 1961, None, 94, 7.8, 18356),
#  (10054640, 'The Assassin', "L'assassino", 1961, None, 97, 7.0, 802),
#  (10054665, 'The Outrageous Baron Munchausen', 'Baron Prásil', 1962, None, 83, 7.7, 1587),
#  (10054749, 'Two Women', 'La ciociara', 1960, None, 101, 7.8, 8277),
#  (10053579, 'Late Autumn', 'Akibiyori', 1960, None, 128, 8.1, 3887),
#  (10054803, 'Nine Days of One Year', 'Devyat dney odnogo goda', 1962, None, 111, 7.6, 880),
#  (10054949, 'War of the Buttons', 'La guerre des boutons', 1962, None, 90, 7.4, 2209),
#  (10054850, 'Hercules in the Haunted World', 'Ercole al centro della Terra', 1961, None, 91, 6.3, 1475),
#  (10054870, 'The Fascist', 'Il federale', 1961, None, 102, 7.4, 538),
#  (10055022, 'Erik the Conqueror', 'Gli invasori', 1961, None, 90, 6.2, 629),
#  (10055032, 'Jules and Jim', 'Jules et Jim', 1962, None, 105, 7.8, 33976),
#  (10055052, 'The End of Summer', 'Kohayagawa-ke no aki', 1961, None, 103, 7.9, 3194),
#  (10055082, 'Léon Morin, Priest', 'Léon Morin, prêtre', 1961, None, 117, 7.7, 3395),
#  (10055153, 'Mother Joan of the Angels', 'Matka Joanna od Aniolów', 1961, None, 110, 7.7, 2501),
#  (10055198, 'Mothra', 'Mosura', 1961, None, 101, 6.6, 3181),
#  (10055254, '101 Dalmatians', 'One Hundred and One Dalmatians', 1961, None, 79, 7.2, 140750),
#  (10055320, 'Il Posto', 'Il posto', 1961, None, 93, 8.0, 3978),
#  (10055361, 'Call Me Genius', 'The Rebel', 1961, None, 105, 7.0, 858),
#  (10055375, 'Antigone', 'Antigoni', 1961, None, 93, 7.2, 599),
#  (10055310, 'Placido', 'Plácido', 1961, None, 85, 8.0, 2306),
#  (10055505, 'Scream of Fear', 'Taste of Fear', 1961, None, 81, 7.4, 3368),
#  (10055747, 'Love at Twenty', "L'amour à vingt ans", 1962, None, 120, 7.3, 1835),
#  (10055779, 'Wild for Kicks', 'Beat Girl', 1960, None, 89, 6.0, 781),
#  (10055827, 'The Elusive Corporal', 'Le caporal épinglé', 1962, None, 90, 7.0, 660),
#  (10055844, 'Amphibian Man', 'Chelovek-Amfibiya', 1962, None, 96, 7.1, 1926),
#  (10055572, 'A Woman Is a Woman', 'Une femme est une femme', 1961, None, 85, 7.5, 13580),
#  (10055602, 'A Difficult Life', 'Una vita difficile', 1961, None, 118, 8.0, 1266),
#  (10055630, 'Yojimbo', 'Yôjinbô', 1961, None, 110, 8.2, 100387),
#  (10055852, 'Cleo from 5 to 7', 'Cléo de 5 à 7', 1962, None, 90, 7.9, 12998),
#  (10055858, 'The Grim Reaper', 'La commare secca', 1962, None, 88, 6.9, 1954),
#  (10055884, 'Damn the Defiant!', 'H.M.S. Defiant', 1962, None, 101, 7.1, 2149),
#  (10055894, 'Invasion of the Triffids', 'The Day of the Triffids', 1963, None, 93, 6.2, 6789),
#  (10055913, 'Divorce Italian Style', "Divorzio all'italiana", 1961, None, 105, 8.1, 10411),
#  (10055981, 'I Fidanzati', 'I fidanzati', 1963, None, 77, 7.6, 1594),
#  (10056014, 'The Gentleman from Epsom', "Le gentleman d'Epsom", 1962, None, 84, 6.3, 600),
#  (10056040, 'The Awful Dr. Orlof', 'Gritos en la noche', 1962, None, 90, 6.2, 1308),
#  (10056058, 'Harakiri', 'Seppuku', 1962, None, 133, 8.7, 26397),
#  (10056271, 'Naked Among Wolves', 'Nackt unter Wölfen', 1963, None, 124, 7.1, 654),
#  (10056389, 'The Four Days of Naples', 'Le quattro giornate di Napoli', 1962, None, 120, 7.6, 644),
#  (10056444, 'An Autumn Afternoon', 'Sanma no aji', 1962, None, 113, 8.1, 6894),
#  (10056111, "Ivan's Childhood", 'Ivanovo detstvo', 1962, None, 95, 8.1, 27073),
#  (10056135, 'The Inheritance', 'Karami-ai', 1962, None, 107, 7.4, 542),
#  (10056160, 'Two Half-Times in Hell', 'Két félidö a pokolban', 1961, None, 140, 8.1, 855),
#  (10056165, 'Bluebeard', 'Landru', 1963, None, 115, 6.5, 750),
#  (10056277, 'Night Creatures', 'Captain Clegg', 1962, None, 82, 6.7, 2433),
#  (10056279, 'Burn, Witch, Burn', 'Night of the Eagle', 1962, None, 90, 6.9, 2646),
#  (10056285, 'No Place Like Homicide!', 'What a Carve Up!', 1961, None, 87, 6.4, 672),
#  (10056291, 'Knife in the Water', 'Nóz w wodzie', 1962, None, 94, 7.5, 18202),
#  (10056315, 'The Horrible Dr. Hichcock', "L'orribile segreto del Dr. Hichcock", 1962, None, 88, 6.5, 1069),
#  (10056356, 'The Boys', 'Pojat', 1962, None, 106, 7.1, 785),
#  (10056357, 'Striped Trip', 'Polosatyy reys', 1961, None, 84, 7.5, 1924),
#  (10056371, 'Before the Revolution', 'Prima della rivoluzione', 1964, None, 115, 7.0, 2194),
#  (10056512, 'Il Sorpasso', 'Il sorpasso', 1962, None, 105, 8.3, 7941),
#  (10056576, 'These Are the Damned', 'The Damned', 1962, None, 87, 6.6, 2674),
#  (10056732, 'The Exterminating Angel', 'El ángel exterminador', 1962, None, 95, 8.2, 26116),
#  (10056736, "L'Eclisse", "L'eclisse", 1962, None, 126, 7.9, 15199),
#  (10056945, 'The Organizer', 'I compagni', 1963, None, 130, 8.0, 2137),
#  (10056957, 'Five Miles to Midnight', 'Le couteau dans la plaie', 1962, None, 112, 6.3, 824),
#  (10056989, 'Detective Bureau 2-3: Go to Hell Bastards!', 'Kutabare akutô-domo - Tantei jimusho 23', 1963, None, 88, 6.8, 580),
#  (10057006, 'The Ape Woman', 'La donna scimmia', 1964, None, 93, 7.4, 558),
#  (10056845, 'Magnet of Doom', "L'aîné des Ferchaux", 1963, None, 102, 6.6, 1108),
#  (10056846, 'Bay of Angels', 'La baie des anges', 1963, None, 90, 7.3, 2458),
#  (10056883, 'The Boom', 'Il boom', 1963, None, 88, 7.2, 655),
#  (10056905, 'Les Carabiniers', 'Les carabiniers', 1963, None, 75, 6.9, 2666),
#  (10056906, 'Carom Shots', 'Carambolages', 1963, None, 88, 6.2, 642),
#  (10056910, "Suzanne's Career", 'La carrière de Suzanne', 1963, None, 54, 7.1, 2540),
#  (10056919, 'Black Peter', 'Cerný Petr', 1964, None, 85, 7.1, 2085),
#  (10057058, 'The Fire Within', 'Le feu follet', 1963, None, 108, 8.0, 7188),
#  (10057091, 'The Leopard', 'Il gattopardo', 1963, None, 186, 8.0, 20663),
#  (10057277, 'The Big City', 'Mahanagar', 1963, None, 136, 8.3, 2841),
#  (10057286, 'Hands Over the City', 'Le mani sulla città', 1963, None, 101, 7.7, 2204),
#  (10057323, 'The Monsters', 'I mostri', 1963, None, 121, 7.5, 1907),
#  (10057344, 'Any Number Can Win', 'Mélodie en sous-sol', 1963, None, 118, 7.3, 2535),
#  (10057345, 'Contempt', 'Le mépris', 1963, None, 103, 7.6, 25374),
#  (10057687, 'Winnetou', 'Winnetou - 1. Teil', 1963, None, 101, 6.9, 3348),
#  (10057693, 'X: The Man with the X-Ray Eyes', 'X', 1963, None, 79, 6.7, 5577),
#  (10057694, 'Walking the Streets of Moscow', 'Ya shagayu po Moskve', 1964, None, 78, 7.9, 2181),
#  (10057695, 'Me, Grandma, Iliko and Ilarion', 'Me, bebia, Iliko da Ilarioni', 1962, None, 90, 8.6, 803),
#  (10057697, 'Youth of the Beast', 'Yajû no seishun', 1963, None, 92, 7.5, 2735),
#  (10057710, "An Actor's Revenge", 'Yukinojô henge', 1963, None, 115, 7.4, 1804),
#  (10057714, 'Zatoichi on the Road', 'Zatôichi kenka-tabi', 1963, None, 85, 7.2, 1357),
#  (10057715, 'Zatoichi the Fugitive', 'Zatôichi kyôjô-tabi', 1963, None, 86, 7.3, 1358),
#  (10057171, 'Yesterday, Today and Tomorrow', 'Ieri oggi domani', 1963, None, 118, 7.3, 6856),
#  (10057176, "L'Immortelle", "L'immortelle", 1963, None, 101, 7.3, 865),
#  (10057183, 'The Indian Scarf', 'Das indische Tuch', 1963, None, 93, 6.6, 762),
#  (10057215, 'Atragon', 'Kaitei gunkan', 1963, None, 94, 6.0, 792),
#  (10057229, 'The Red Lanterns', 'Ta kokkina fanaria', 1963, None, 132, 8.1, 1447),
#  (10057230, 'Audition', 'Konkurs', 1964, None, 47, 6.6, 603),
#  (10057238, 'The Warped Ones', 'Kyônetsu no kisetsu', 1960, None, 75, 7.0, 663),
#  (10057358, 'Winter Light', 'Nattvardsgästerna', 1963, None, 81, 8.2, 19163),
#  (10057363, 'The Insect Woman', 'Nippon konchûki', 1963, None, 123, 7.5, 1696),
#  (10057422, 'Squeak-squeak', 'Pouic-Pouic', 1963, None, 86, 6.5, 1315),
#  (10057427, 'The Trial', 'Le procès', 1962, None, 119, 7.8, 17570),
#  (10057565, 'High and Low', 'Tengoku to jigoku', 1963, None, 143, 8.5, 24377),
#  (10057591, 'Monsieur Gangster', 'Les tontons flingueurs', 1963, None, 105, 7.9, 4873),
#  (10057603, 'Black Sabbath', 'I tre volti della paura', 1963, None, 92, 7.1, 9247),
#  (10057611, 'The Silence', 'Tystnaden', 1963, None, 96, 7.9, 16014),
#  (10057637, 'The Night Before Christmas', 'Vechera na khutore bliz Dikanki', 1961, None, 68, 7.7, 1134),
#  (10057643, 'The Executioner', 'El verdugo', 1963, None, 87, 8.1, 4942),
#  (10057829, 'Intentions of Murder', 'Akai satsui', 1964, None, 150, 7.8, 1241),
#  (10057831, 'Zorba the Greek', 'Alexis Zorbas', 1964, None, 142, 7.7, 19032),
#  (10057842, 'This Special Friendship', 'Les amitiés particulières', 1964, None, 100, 7.7, 2449),
#  (10057870, 'The Great Spy Chase', 'Les Barbouzes', 1964, None, 109, 7.0, 1548),
#  (10057993, 'Castle of Blood', 'Danza macabra', 1964, None, 87, 6.9, 1850),
#  (10058001, 'Diamonds of the Night', 'Démanty noci', 1964, None, 67, 7.5, 1615),
#  (10058003, 'Red Desert', 'Il deserto rosso', 1964, None, 117, 7.7, 12276),
#  (10058006, 'Black God, White Devil', 'Deus e o Diabo na Terra do Sol', 1964, None, 120, 7.3, 3591),
#  (10058089, 'Fantomas', 'Fantômas', 1964, None, 100, 7.0, 8193),
#  (10058232, 'The Unvanquished', "L'insoumis", 1964, None, 115, 7.0, 582),
#  (10058277, 'The Peach Thief', 'Kradetzat na praskovi', 1964, None, 84, 7.9, 730),
#  (10058279, 'Kwaidan', 'Kaidan', 1964, None, 183, 8.0, 13194),
#  (10057892, 'Blood on the Land', 'To homa vaftike kokkino', 1965, None, 130, 7.5, 682),
#  (10057960, 'Love Meetings', "Comizi d'amore", 1964, None, 92, 7.5, 1150),
#  (10057967, 'The Sucker', 'Le corniaud', 1965, None, 111, 7.4, 5622),
#  (10057977, 'Chronicle of a Boy Alone', 'Crónica de un niño solo', 1965, None, 79, 7.4, 544),
#  (10058123, 'Joy House', 'Les félins', 1964, None, 97, 7.0, 1670),
#  (10058126, 'Hamlet', 'Gamlet', 1964, None, 140, 8.3, 2292),
#  (10058135, 'The Troops of St. Tropez', 'Le gendarme de Saint-Tropez', 1964, None, 90, 7.2, 10079),
#  (10058164, 'The Guest', 'The Caretaker', 1963, None, 105, 7.1, 586),
#  (10058191, 'The Mysterious Magician', 'Der Hexer', 1964, None, 95, 6.7, 1021),
#  (10058307, 'The Long Hair of Death', 'I lunghi capelli della morte', 1965, None, 96, 6.2, 1016),
#  (10058323, 'The Winston Affair', 'Man in the Middle', 1964, None, 94, 6.6, 528),
#  (10058326, 'Swastika', 'Manji', 1964, None, 91, 7.0, 742),
#  (10058335, 'Marriage Italian Style', "Matrimonio all'italiana", 1964, None, 102, 7.5, 7307),
#  (10058349, 'Yearning', 'Midareru', 1964, None, 98, 8.1, 953),
#  (10058361, 'I Am Twenty', 'Mne dvadtsat let', 1965, None, 189, 7.9, 942),
#  (10058365, 'Mondo Cane 2', 'Mondo cane n. 2', 1963, None, 102, 6.0, 708),
#  (10058374, 'Frosty', 'Morozko', 1965, None, 84, 6.5, 4106),
#  (10058379, 'Mothra vs. Godzilla', 'Mosura tai Gojira', 1964, None, 89, 6.5, 6519),
#  (10058541, 'Sallah', 'Sallah Shabati', 1964, None, 110, 7.4, 843),
#  (10058544, 'Ghidorah, the Three-Headed Monster', 'San daikaijû: Chikyû saidai no kessen', 1964, None, 93, 6.6, 4622),
#  (10058564, 'Seduced and Abandoned', 'Sedotta e abbandonata', 1964, None, 118, 8.0, 2613),
#  (10058567, 'Blood and Black Lace', "6 donne per l'assassino", 1964, None, 88, 7.2, 7643),
#  (10058600, 'Summer in Tyrol', 'Sommer i Tyrol', 1964, None, 99, 6.8, 801),
#  (10058604, 'I Am Cuba', 'Soy Cuba', 1964, None, 108, 8.2, 7330),
#  (10058740, 'Weekend at Dunkirk', 'Week-end à Zuydcoote', 1964, None, 119, 6.9, 1136),
#  (10058787, 'My Way Home', 'Így jöttem', 1965, None, 108, 7.6, 547),
#  (10058863, 'The 317th Platoon', 'La 317ème section', 1965, None, 100, 7.5, 839),
#  (10058888, 'Red Beard', 'Akahige', 1965, None, 185, 8.4, 14668),
#  (10058909, 'Angelique and the King', 'Angélique et le roy', 1966, None, 100, 6.7, 1359),
#  (10059049, 'Don Camillo in Moscow', 'Il compagno Don Camillo', 1965, None, 93, 7.0, 1577),
#  (10059051, 'Complexes', 'I complessi', 1965, None, 107, 7.2, 509),
#  (10058409, 'Gate of Flesh', 'Nikutai no mon', 1964, None, 90, 7.4, 2549),
#  (10058413, 'The Empty Canvas', 'La noia', 1963, None, 105, 7.0, 661),
#  (10058438, 'The Little Priest', 'El padrecito', 1964, None, 130, 7.1, 653),
#  (10058439, 'Forest of the Hanged', 'Padurea spânzuratilor', 1965, None, 154, 8.2, 1014),
#  (10058453, 'Paris When It Sizzles', 'Paris - When It Sizzles', 1964, None, 110, 6.4, 7054),
#  (10058461, 'A Fistful of Dollars', 'Per un pugno di dollari', 1964, None, 99, 8.0, 181334),
#  (10058625, 'Woman in the Dunes', 'Suna no onna', 1964, None, 123, 8.5, 15187),
#  (10058642, 'Shadows of Forgotten Ancestors', 'Tini zabutykh predkiv', 1964, None, 97, 8.0, 5321),
#  (10058692, 'The Black Tulip', 'La tulipe noire', 1964, None, 115, 6.7, 1832),
#  (10058715, 'The Gospel According to St. Matthew', 'Il vangelo secondo Matteo', 1964, None, 137, 7.8, 9776),
#  (10058985, 'Le Bonheur', 'Le bonheur', 1965, None, 79, 7.6, 4253),
#  (10059015, 'Casanova 70', "Casanova '70", 1965, None, 107, 6.4, 892),
#  (10064356, 'The Cow', 'Gaav', 1969, None, 104, 8.1, 5308),
#  (10059159, 'Pleasures of the Flesh', 'Etsuraku', 1965, None, 104, 7.0, 1370),
#  (10059229, 'Juliet of the Spirits', 'Giulietta degli spiriti', 1965, None, 137, 7.6, 10439),
#  (10059241, 'The Wise Guys', 'Les grandes gueules', 1965, None, 128, 7.1, 748),
#  (10059348, 'The Coward', 'Kapurush', 1965, None, 70, 7.8, 1167),
#  (10059373, 'Men and Banners', 'A köszívü ember fiai', 1965, None, 158, 7.0, 571),
#  (10059417, 'The Holy Man', 'Mahapurush', 1965, None, 65, 7.3, 912),
#  (10059440, "At Midnight I'll Take Your Soul", 'À Meia Noite Levarei Sua Alma', 1964, None, 84, 7.0, 2590),
#  (10059565, 'Six in Paris', 'Paris vu par...', 1965, None, 95, 6.9, 911),
#  (10059578, 'For a Few Dollars More', 'Per qualche dollaro in più', 1965, None, 132, 8.3, 211290),
#  (10059581, 'Pearls of the Deep', 'Perlicky na dne', 1965, None, 105, 6.6, 528),
#  (10059592, 'Pierrot le Fou', 'Pierrot le fou', 1965, None, 110, 7.6, 25709),
#  (10059601, 'A Pistol for Ringo', 'Una pistola per Ringo', 1965, None, 98, 6.5, 1331),
#  (10059619, 'Fists in the Pocket', 'I pugni in tasca', 1965, None, 105, 7.8, 3383),
#  (10059643, 'The Saragossa Manuscript', 'Rekopis znaleziony w Saragossie', 1965, None, 182, 7.9, 4401),
#  (10059095, 'The 10th Victim', 'La decima vittima', 1965, None, 92, 6.7, 3220),
#  (10059106, 'Die! Die! My Darling!', 'Fanatic', 1965, None, 97, 6.3, 1960),
#  (10059116, 'The Possessed', 'La donna del lago', 1965, None, 85, 7.0, 532),
#  (10059282, 'Agent 8 3/4', 'Hot Enough for June', 1964, None, 98, 6.1, 668),
#  (10059303, 'Samurai Spy', 'Ibun Sarutobi Sasuke', 1965, None, 100, 7.0, 1420),
#  (10059320, 'Tattooed Life', 'Irezumi ichidai', 1965, None, 87, 7.1, 835),
#  (10059501, 'Again the Ringer', 'Neues vom Hexer', 1965, None, 95, 6.3, 508),
#  (10059527, 'The Shop on Main Street', 'Obchod na korze', 1965, None, 128, 8.3, 7245),
#  (10059529, 'Triumph Over Violence', 'Obyknovennyy fashizm', 1965, None, 138, 8.2, 1357),
#  (10059673, 'Samurai Assassin', 'Samurai', 1965, None, 122, 7.5, 1760),
#  (10059715, 'Story of a Prostitute', 'Shunpu den', 1965, None, 96, 7.3, 1161),
#  (10059776, 'The Round-Up', 'Szegénylegények', 1966, None, 90, 7.7, 2259),
#  (10059915, 'Winnetou: The Last Shot', 'Winnetou - 3. Teil', 1965, None, 93, 6.7, 2115),
#  (10059942, 'Zatoichi and the Chess Expert', 'Zatôichi jigoku tabi', 1965, None, 87, 7.4, 1096),
#  (10060107, 'Andrei Rublev', 'Andrey Rublev', 1966, None, 205, 8.2, 40173),
#  (10060116, 'Father', 'Apa', 1966, None, 88, 7.5, 776),
#  (10060138, 'Balthazar', 'Au hasard Balthazar', 1966, None, 95, 7.9, 15663),
#  (10060143, 'Texas, Adios', 'Texas, addio', 1966, None, 93, 6.2, 1235),
#  (10060161, 'Beware of the Car', 'Beregis avtomobilya', 1966, None, 94, 8.2, 4145),
#  (10060176, 'Blow-Up', 'Blowup', 1966, None, 111, 7.6, 51610),
#  (10059792, 'Planet of the Vampires', 'Terrore nello spazio', 1965, None, 88, 6.3, 4744),
#  (10059817, 'Tokyo Olympiad', 'Tôkyô orinpikku', 1965, None, 170, 7.8, 1393),
#  (10059829, 'Three', 'Tri', 1965, None, 80, 7.8, 582),
#  (10059855, 'Havoc in Heaven', 'Da nao tian gong', 1963, None, 114, 8.1, 1510),
#  (10059856, 'Sandra', "Vaghe stelle dell'Orsa...", 1965, None, 105, 7.2, 1514),
#  (10060063, 'Yesterday Girl', 'Abschied von gestern - (Anita G.)', 1966, None, 88, 7.1, 804),
#  (10060073, 'Africa: Blood and Guts', 'Africa addio', 1966, None, 140, 7.0, 1173),
#  (10060196, 'The Good, the Bad and the Ugly', 'Il buono, il brutto, il cattivo', 1966, None, 161, 8.8, 635567),
#  (10060261, 'The Cruel Ones', 'I crudeli', 1967, None, 90, 6.8, 1056),
#  (10060450, 'The Troops in New York', 'Le gendarme à New York', 1965, None, 102, 6.5, 6192),
#  (10060461, 'The Girl-Getters', 'The System', 1964, None, 93, 6.5, 594),
#  (10060474, 'La Grande Vadrouille', 'La grande vadrouille', 1966, None, 132, 8.0, 14381),
#  (10060475, 'The Exchange Student', 'Les grandes vacances', 1967, None, 84, 6.6, 2613),
#  (10060481, 'The War Is Over', 'La guerre est finie', 1966, None, 121, 7.3, 1781),
#  (10060482, 'The Dacians', 'Dacii', 1966, None, 110, 7.9, 1656),
#  (10060486, 'Violence at Noon', 'Hakuchû no tôrima', 1966, None, 99, 7.1, 796),
#  (10060635, 'Dragon Inn', 'Long men kezhan', 1967, None, 111, 7.4, 1890),
#  (10060701, 'The Diabolical Dr. Z', 'Miss Muerte', 1966, None, 86, 6.8, 816),
#  (10060722, 'Death of a Bureaucrat', 'La muerte de un burócrata', 1966, None, 85, 7.7, 931),
#  (10060305, 'Le Deuxième Souffle', 'Le deuxième souffle', 1966, None, 150, 8.0, 4708),
#  (10060400, 'Fantomas vs. Scotland Yard', 'Fantômas contre Scotland Yard', 1967, None, 104, 6.8, 5525),
#  (10060401, 'Pharaoh', 'Faraon', 1966, None, 180, 7.5, 1519),
#  (10060529, 'Here Is Your Life', 'Här har du ditt liv', 1966, None, 169, 7.3, 737),
#  (10060538, 'Misunderstood', 'Incompreso (Vita col figlio)', 1967, None, 104, 7.7, 847),
#  (10060545, 'I Knew Her Well', 'Io la conoscevo bene', 1965, None, 115, 7.7, 1665),
#  (10060560, 'The Pornographers', 'Erogotoshi-tachi yori: Jinruigaku nyûmon', 1966, None, 128, 7.4, 1935),
#  (10060574, 'Young Törless', 'Der junge Törless', 1966, None, 87, 7.3, 1976),
#  (10060586, 'Fighting Elegy', 'Kenka erejî', 1966, None, 86, 7.0, 1226),
#  (10060597, 'Carriage to Vienna', 'Kocár do Vídne', 1966, None, 78, 7.7, 581),
#  (10060613, 'Skin, Skin', 'Käpy selän alla', 1966, None, 89, 6.8, 649),
#  (10060742, 'Nayak: The Hero', 'Nayak', 1966, None, 120, 8.3, 2698),
#  (10060758, 'Black Girl', 'La noire de...', 1966, None, 65, 7.4, 2709),
#  (10060777, 'The Ruthless Four', 'Ognuno per sé', 1968, None, 106, 6.7, 516),
#  (10060787, 'Woman of the Lake', 'Onna no mizûmi', 1966, None, 102, 7.3, 515),
#  (10060794, 'Kill, Baby... Kill!', 'Operazione paura', 1966, None, 85, 7.0, 5258),
#  (10060802, 'Closely Watched Trains', 'Ostre sledované vlaky', 1966, None, 92, 7.7, 10262),
#  (10060814, 'Is Paris Burning?', 'Paris brûle-t-il?', 1966, None, 175, 6.9, 3551),
#  (10060959, 'Daisies', 'Sedmikrásky', 1966, None, 74, 7.4, 8620),
#  (10060991, 'Strike First Freddy', 'Slå først Frede!', 1965, None, 100, 6.3, 651),
#  (10061037, 'The Witches', 'Le streghe', 1967, None, 121, 6.1, 1190),
#  (10060879, 'Who Are You, Polly Maggoo?', 'Qui êtes-vous, Polly Maggoo?', 1966, None, 102, 7.0, 937),
#  (10060891, 'The Nun', 'La religieuse', 1966, None, 140, 7.4, 1780),
#  (10060903, 'The Return of Ringo', 'Il ritorno di Ringo', 1965, None, 95, 6.8, 1206),
#  (10060908, 'King of Hearts', 'Le roi de coeur', 1966, None, 102, 7.5, 3377),
#  (10061042, 'Hunger', 'Sult', 1966, None, 112, 7.9, 2568),
#  (10061059, 'The Embryo Hunts in Secret', 'Taiji ga mitsuryô suru toki', 1966, None, 72, 7.2, 736),
#  (10061065, 'The Face of Another', 'Tanin no kao', 1966, None, 122, 8.0, 6293),
#  (10061069, 'Taro the Dragon Boy', 'Tatsu no ko Tarô', 1979, None, 75, 7.5, 709),
#  (10061074, 'The Brute and the Beast', 'Le colt cantarono la morte e fu... tempo di massacro', 1966, None, 92, 6.6, 1449),
#  (10061101, 'Tokyo Drifter', 'Tôkyô nagaremono', 1966, None, 89, 7.2, 6724),
#  (10061132, 'The Hawks and the Sparrows', 'Uccellacci e uccellini', 1966, None, 89, 7.4, 3791),
#  (10061138, 'A Man and a Woman', 'Un homme et une femme', 1966, None, 102, 7.6, 8674),
#  (10061320, 'We Still Kill the Old Way', 'A ciascuno il suo', 1967, None, 99, 7.1, 1032),
#  (10061343, 'Very Happy Alexander', 'Alexandre le bienheureux', 1968, None, 100, 7.4, 1799),
#  (10061357, 'Angelique and the Sultan', 'Angélique et le sultan', 1968, None, 105, 6.5, 1208),
#  (10061369, 'Asterix', 'Astérix le Gaulois', 1967, None, 68, 6.6, 8756),
#  (10061376, 'The Last Adventure', 'Les aventuriers', 1967, None, 112, 7.2, 2579),
#  (10061395, 'Belle de Jour', 'Belle de jour', 1967, None, 100, 7.7, 36534),
#  (10061429, 'A Bullet for the General', 'Quién sabe?', 1967, None, 118, 7.1, 3591),
#  (10061433, 'More Than a Miracle', "C'era una volta", 1967, None, 115, 6.2, 1041),
#  (10061589, 'Bob Dylan: Dont Look Back', 'Dont Look Back', 1967, None, 96, 8.0, 7731),
#  (10061597, 'The One-Armed Swordsman', 'Du bei dao', 1967, None, 111, 7.4, 2599),
#  (10061605, 'The Departure', 'Le départ', 1967, None, 93, 6.7, 611),
#  (10061636, 'Face to Face', 'Faccia a faccia', 1967, None, 111, 7.2, 2397),
#  (10061643, 'Fando and Lis', 'Fando y Lis', 1968, None, 93, 7.0, 4616),
#  (10061655, 'The Fearless Vampire Killers', 'Dance of the Vampires', 1967, None, 108, 7.2, 27433),
#  (10061474, 'The Zoo', 'Chiriyakhana', 1967, None, 125, 7.2, 629),
#  (10061537, 'The Red and the White', 'Csillagosok, katonák', 1967, None, 90, 7.7, 2953),
#  (10061709, 'Day of Anger', "I giorni dell'ira", 1967, None, 111, 7.1, 3564),
#  (10061728, 'The Restaurant', 'Le grand restaurant', 1966, None, 85, 6.8, 4534),
#  (10061752, 'Even the Wind Is afraid', 'Hasta el viento tiene miedo', 1968, None, 88, 7.5, 1133),
#  (10061781, "The Firemen's Ball", 'Horí, má panenko', 1967, None, 73, 7.6, 8308),
#  (10061802, 'I Was Nineteen', 'Ich war neunzehn', 1968, None, 115, 7.5, 769),
#  (10061819, 'Untamable Angelique', 'Indomptable Angélique', 1967, None, 95, 6.6, 1172),
#  (10061876, 'The Commissar', 'Komissar', 1967, None, 110, 7.4, 1247),
#  (10061994, 'Death Laid an Egg', "La morte ha fatto l'uovo", 1968, None, 86, 6.1, 955),
#  (10062022, 'The College Girl Murders', 'Der Mönch mit der Peitsche', 1967, None, 88, 6.2, 549),
#  (10062042, 'Sing a Song of Sex', 'Nihon shunka-kô', 1967, None, 103, 6.7, 605),
#  (10062043, 'A Man Vanishes', 'Ningen jôhatsu', 1967, None, 130, 7.3, 572),
#  (10061882, 'Branded to Kill', 'Koroshi no rakuin', 1967, None, 91, 7.4, 7138),
#  (10061912, 'Love Affair, or The Case of the Missing Switchboard Operator', 'Ljubavni slucaj ili tragedija sluzbenice P.T.T.', 1967, None, 79, 7.4, 1365),
#  (10061913, 'Far from Vietnam', 'Loin du Vietnam', 1967, None, 115, 7.4, 547),
#  (10061955, 'The Bride Wore Black', 'La mariée était en noir', 1968, None, 107, 7.3, 7745),
#  (10061971, 'Two in the Shadow', 'Midaregumo', 1967, None, 108, 7.9, 748),
#  (10062092, 'Pasha', 'Le pacha', 1968, None, 90, 6.7, 1044),
#  (10062120, 'The Little Bather', 'Le petit baigneur', 1968, None, 96, 6.6, 3251),
#  (10062060, 'Oh, Beautiful Istanbul', 'Ah Güzel Istanbul', 1966, None, 97, 8.1, 1487),
#  (10062069, 'Violated Angels', 'Okasareta hakui', 1967, None, 56, 7.3, 1349),
#  (10062080, 'The Treasure of San Gennaro', 'Operazione San Gennaro', 1966, None, 104, 7.1, 988),
#  (10062082, 'Django Kill... If You Live, Shoot!', 'Se sei vivo spara', 1967, None, 100, 6.4, 2093),
#  (10062228, 'Our Folks', 'Sami swoi', 1967, None, 81, 7.9, 2719),
#  (10062229, 'Le Samouraï', 'Le samouraï', 1967, None, 105, 8.1, 40258),
#  (10062271, 'The Birds, the Bees and the Italians', 'Signore & signori', 1966, None, 118, 7.6, 1073),
#  (10062277, 'I Even Met Happy Gypsies', 'Skupljaci perja', 1967, None, 94, 7.9, 1731),
#  (10062310, 'The Stranger', 'Lo straniero', 1967, None, 104, 7.3, 1994),
#  (10062151, 'Django, Prepare a Coffin', 'Preparati la bara!', 1968, None, 92, 6.5, 2115),
#  (10062322, 'Dry Summer', 'Susuz Yaz', 1963, None, 90, 8.0, 3236),
#  (10062352, 'Entranced Earth', 'Terra em Transe', 1967, None, 111, 7.5, 2273),
#  (10062429, 'Any Gun Can Play', "Vado... l'ammazzo e torno", 1967, None, 105, 6.0, 580),
#  (10062393, 'Three Poplars at Plyuschikha Street', 'Tri topolya na Plyushchikhe', 1968, None, 79, 7.8, 806),
#  (10062456, 'War and Peace, Part IV: Pierre Bezukhov', 'Voyna i mir IV: Pierre Bezukhov', 1967, None, 96, 8.2, 763),
#  (10062457, 'The Thief of Paris', 'Le voleur', 1967, None, 120, 7.0, 1480),
#  (10062480, 'Weekend', 'Week End', 1967, None, 105, 7.2, 12146),
#  (10062518, 'Zatoichi the Outlaw', 'Zatôichi rôyaburi', 1967, None, 96, 7.2, 932),
#  (10062636, 'Grand Slam', 'Ad ogni costo', 1967, None, 121, 7.0, 936),
#  (10062639, 'Farewell, Friend', "Adieu l'ami", 1968, None, 115, 6.9, 2640),
#  (10062673, 'Anzio', 'Lo sbarco di Anzio', 1968, None, 117, 6.0, 2777),
#  (10062690, 'Awakening of the Beast', 'O Ritual dos Sádicos', 1970, None, 93, 6.1, 992),
#  (10055732, 'Akitsu Springs', 'Akitsu onsen', 1962, None, 113, 7.5, 1002),
#  (10062759, 'The Diamond Arm', 'Brilliantovaya ruka', 1969, None, 100, 8.5, 11906),
#  (10062789, 'Heartbeat', 'La chamade', 1968, None, 103, 6.5, 652),
#  (10062804, 'The Chronicle of Anna Magdalena Bach', 'Chronik der Anna Magdalena Bach', 1968, None, 94, 6.9, 1188),
#  (10062825, 'Run, Man, Run', 'Corri uomo corri', 1968, None, 120, 6.9, 1427),
#  (10062851, 'Majin the Monster of Terror', 'Daimajin', 1966, None, 84, 6.7, 1055),
#  (10062863, 'Dark of the Sun', 'The Mercenaries', 1968, None, 100, 6.9, 2418),
#  (10062873, 'The Young Girls of Rochefort', 'Les demoiselles de Rochefort', 1967, None, 120, 7.6, 7215),
#  (10062893, 'Dillinger Is Dead', 'Dillinger è morto', 1969, None, 95, 7.1, 1966),
#  (10062925, 'Stars of Eger', 'Egri csillagok', 1968, None, 157, 7.4, 1935),
#  (10063105, 'Golden Swallow', 'Jin yan zi', 1968, None, 89, 6.8, 561),
#  (10063149, 'I Am Curious (Blue)', 'Jag är nyfiken - en film i blått', 1968, None, 107, 6.1, 1205),
#  (10062997, 'Le Gai Savoir', 'Le gai savoir', 1969, None, 95, 6.3, 697),
#  (10063005, 'The Troops get Married', 'Le gendarme se marie', 1968, None, 92, 6.8, 6377),
#  (10063010, 'Mafia', 'Il giorno della civetta', 1968, None, 108, 7.1, 1000),
#  (10063023, 'The Adventures of Goopy and Bagha', 'Goopy Gyne Bagha Byne', 1969, None, 132, 8.8, 1830),
#  (10063026, 'Goto, Island of Love', "Goto, l'île d'amour", 1969, None, 93, 6.7, 620),
#  (10063032, 'The Great Silence', 'Il grande silenzio', 1968, None, 105, 7.7, 12553),
#  (10063172, 'Destroy All Monsters', 'Kaijû sôshingeki', 1968, None, 89, 6.5, 4380),
#  (10063186, 'Kill!', 'Kiru', 1968, None, 115, 7.5, 2315),
#  (10063198, 'Death by Hanging', 'Kôshikei', 1968, None, 117, 7.6, 1901),
#  (10063206, 'Goke, Body Snatcher from Hell', 'Kyuketsuki Gokemidoro', 1968, None, 84, 6.2, 1257),
#  (10063218, 'Signs of Life', 'Lebenszeichen', 1968, None, 91, 7.2, 1772),
#  (10063288, "Be Sick... It's Free", 'Il medico della mutua', 1968, None, 98, 7.1, 1135),
#  (10063293, 'The Mercenary', 'Il mercenario', 1968, None, 110, 7.2, 3666),
#  (10063342, 'Innocence Unprotected', 'Nevinost bez zastite', 1968, None, 75, 7.3, 668),
#  (10063370, 'The Young, the Evil and the Savage', 'Nude... si muore', 1968, None, 98, 6.0, 519),
#  (10063380, 'Through Fire, Water and... Brass Pipes', 'Ogon, voda i... mednye truby', 1968, None, 86, 7.1, 617),
#  (10063386, 'The Olsen Gang', 'Olsen-banden', 1968, None, 80, 6.7, 1809),
#  (10063413, 'Paranoia', 'Orgasmo', 1969, None, 91, 6.1, 562),
#  (10063414, 'Partner', 'Partner.', 1968, None, 105, 6.4, 652),
#  (10063458, 'La Prisonnière', 'La prisonnière', 1968, None, 106, 7.1, 912),
#  (10063485, 'The Girl with a Pistol', 'La ragazza con la pistola', 1968, None, 103, 6.9, 887),
#  (10063493, 'Reconstruction', 'Reconstituirea', 1968, None, 100, 8.0, 1343),
#  (10063527, 'Capricious Summer', 'Rozmarné léto', 1968, None, 74, 7.1, 1131),
#  (10063611, 'Shame', 'Skammen', 1968, None, 103, 8.1, 10779),
#  (10063633, 'Cremator', 'Spalovac mrtvol', 1969, None, 95, 8.1, 6094),
#  (10063674, 'The Tattoo', 'Le tatoué', 1968, None, 90, 6.6, 2495),
#  (10063715, 'Spirits of the Dead', 'Histoires extraordinaires', 1968, None, 121, 6.6, 5100),
#  (10063759, 'Hour of the Wolf', 'Vargtimmen', 1968, None, 90, 7.7, 16382),
#  (10063771, 'The Two of Us', "Le vieil homme et l'enfant", 1967, None, 90, 7.7, 1781),
#  (10063791, 'All My Compatriots', 'Vsichni dobrí rodáci', 1969, None, 120, 7.7, 668),
#  (10063794, 'War and Peace', 'Voyna i mir', 1966, None, 422, 8.3, 5657),
#  (10063803, "Who's That Knocking at My Door", 'I Call First', 1967, None, 90, 6.7, 7378),
#  (10063818, 'The Valley of Death', 'Winnetou und Shatterhand im Tal der Toten', 1968, None, 89, 6.1, 1152),
#  (10063834, 'Zatoichi Challenged', 'Zatôichi chikemuri kaidô', 1967, None, 87, 7.6, 1011),
#  (10063835, 'Zatoichi and the Fugitives', 'Zatôichi hatashi-jô', 1968, None, 82, 7.4, 874),
#  (10063840, 'The Zigzag of Success', 'Zigzag udachi', 1968, None, 88, 7.3, 691),
#  (10063845, 'The Golden Calf', 'Zolotoy telyonok', 1968, None, 174, 8.4, 2163),
#  (10063876, 'Boy', 'Shônen', 1969, None, 105, 7.5, 1240),
#  (10063995, 'Red Lion', 'Akage', 1969, None, 115, 7.0, 604),
#  (10064225, 'Last Known Address', 'Dernier domicile connu', 1970, None, 105, 7.0, 1125),
#  (10064146, 'The Brain', 'Le cerveau', 1969, None, 115, 6.9, 3193),
#  (10064147, 'Jackal of Nahueltoro', 'El Chacal de Nahueltoro', 1969, None, 95, 7.7, 808),
#  (10064169, 'The Sicilian Clan', 'Le clan des Siciliens', 1969, None, 122, 7.4, 6378),
#  (10064208, 'Death Rides a Horse', 'Da uomo a uomo', 1967, None, 120, 7.1, 6408),
#  (10064019, 'Love and Anger', 'Amore e rabbia', 1969, None, 102, 6.0, 593),
#  (10064037, 'The Christmas Tree', "L'arbre de Noël", 1969, None, 110, 6.5, 501),
#  (10064038, 'The Land', 'Al-ard', 1970, None, 130, 8.2, 1133),
#  (10064040, 'Army of Shadows', "L'armée des ombres", 1969, None, 145, 8.2, 18354),
#  (10064067, 'Have Sword Will Travel', 'Bao biao', 1969, None, 101, 7.0, 507),
#  (10064091, 'The Battle of Neretva', 'Bitka na Neretvi', 1969, None, 175, 7.2, 2951),
#  (10064106, 'Le Boucher', 'Le boucher', 1970, None, 93, 7.5, 7024),
#  (10064118, 'The Damned', 'La caduta degli dei (Götterdämmerung)', 1969, None, 156, 7.6, 6819),
#  (10064353, 'Samurai Banners', 'Fûrin kazan', 1969, None, 165, 7.1, 604),
#  (10064387, 'Goyokin', 'Goyôkin', 1969, None, 124, 7.7, 1876),
#  (10064390, 'Le Grand Amour', 'Le grand amour', 1969, None, 87, 7.6, 938),
#  (10064498, 'The Toth Family', 'Isten hozta örnagy úr', 1969, None, 95, 8.1, 1565),
#  (10064519, 'Journey to the Far Side of the Sun', 'Doppelgänger', 1969, None, 101, 6.3, 3045),
#  (10064546, 'Witchhammer', 'Kladivo na carodejnice', 1970, None, 103, 7.9, 1496),
#  (10064553, 'King Lear', 'Korol Lir', 1970, None, 140, 8.2, 1297),
# ...
#  (10070506, 'Bread and Chocolate', 'Pane e cioccolata', 1974, None, 100, 7.6, 1433),
#  (10070592, 'Massacre in Rome', 'Rappresaglia', 1973, None, 110, 6.5, 1017),
#  (10070641, 'Slap the Monster on Page One', 'Sbatti il mostro in prima pagina', 1972, None, 86, 7.4, 788),
#  (10070758, 'The Battle of Sutjeska', 'Sutjeska', 1973, None, 130, 6.9, 1279),
#  (10070826, 'The Train', 'Le train', 1973, None, 95, 6.9, 1017),
#  (10070832, 'Three Wishes for Cinderella', 'Tri orísky pro Popelku', 1973, None, 75, 7.8, 7458),
#  (10070849, 'Last Tango in Paris', 'Ultimo tango a Parigi', 1972, None, 129, 7.0, 45857),
#  (10070861, 'Only Old Men Are Going to Battle', "V boy idut odni 'stariki'", 1974, None, 92, 8.4, 4100),
#  (10070957, 'Tenderness of the Wolves', 'Die Zärtlichkeit der Wölfe', 1973, None, 82, 6.4, 1119),
#  (10070959, 'State of Siege', 'État de siège', 1972, None, 120, 7.8, 3878),
#  (10064285, 'The Wild Child', "L'enfant sauvage", 1970, None, 83, 7.5, 6934),
#  (10070935, 'Procession of Memories', 'Yaadon Ki Baaraat', 1973, None, 164, 7.4, 1750),
#  (10064296, 'Eros + Massacre', 'Erosu purasu gyakusatsu', 1969, None, 202, 7.7, 1762),
#  (10064300, 'The 5-Man Army', 'Un esercito di 5 uomini', 1969, None, 105, 6.7, 1305),
#  (10071159, 'Friend', 'Arkadas', 1974, None, 105, 7.2, 1147),
#  (10064323, 'The Unfaithful Wife', 'La femme infidèle', 1969, None, 98, 7.4, 3545),
#  (10071141, 'Ali: Fear Eats the Soul', 'Angst essen Seele auf', 1974, None, 92, 8.1, 16855),
#  (10071145, 'Ankur: The Seedling', 'Ankur', 1974, None, 131, 8.2, 782),
#  (10071203, 'Belladonna of Sadness', 'Kanashimi no beradonna', 1973, None, 86, 7.4, 3100),
#  (10071275, 'Rabid Dogs', 'Cani arrabbiati', 1974, None, 96, 7.5, 3824),
#  (10071330, 'Street Law', 'Il cittadino si ribella', 1974, None, 105, 7.0, 1056),
#  (10071408, 'Deranged: Confessions of a Necrophile', 'Deranged', 1974, None, 84, 6.4, 4097),
#  (10071449, 'The Common Man', 'Dupont Lajoie', 1975, None, 100, 7.3, 697),
#  (10071458, 'Effi Briest', 'Fontane Effi Briest', 1974, None, 140, 6.9, 2050),
#  (10071585, 'Conversation Piece', 'Gruppo di famiglia in un interno', 1974, None, 121, 7.5, 3526),
#  (10071687, 'How to Drown Dr. Mracek, the Lawyer', 'Jak utopit dr. Mrácka aneb Konec vodníku v Cechách', 1975, None, 96, 7.6, 959),
#  (10071615, 'The Holy Mountain', 'La montaña sagrada', 1973, None, 114, 7.9, 32378),
#  (10071646, 'Here and Elsewhere', 'Ici et ailleurs', 1976, None, 53, 7.2, 538),
#  (10071483, 'Wrong Move', 'Falsche Bewegung', 1975, None, 103, 7.0, 2428),
#  (10071486, 'White Collar Blues', 'Fantozzi', 1975, None, 108, 8.0, 5058),
#  (10071502, 'Arabian Nights', 'Il fiore delle mille e una notte', 1974, None, 130, 6.8, 6419),
#  (10071512, 'The Flying Guillotine', 'Xue di zi', 1975, None, 111, 6.7, 911),
#  (10071550, 'The Slap', 'La gifle', 1974, None, 104, 6.3, 912),
#  (10071557, 'The Gypsy', 'Le Gitan', 1975, None, 102, 6.3, 705),
#  (10071908, 'A Jungle Book of Regulations', 'Nie ma rózy bez ognia', 1974, None, 91, 7.5, 860),
#  (10071939, 'The Last Exploits of the Olsen Gang', 'Olsen-bandens sidste bedrifter', 1974, None, 102, 7.1, 1494),
#  (10071949, 'Orderers', 'Les ordres', 1974, None, 109, 8.2, 912),
#  (10071950, 'Footprints on the Moon', 'Le orme', 1975, None, 96, 6.7, 1420),
#  (10071956, 'Written Off', 'Otpisani', 1974, None, 88, 8.2, 1033),
#  (10071800, 'Compulsed', 'Majboor', 1974, None, 155, 7.1, 576),
#  (10071833, 'Mes Petites Amoureuses', 'Mes petites amoureuses', 1974, None, 123, 7.5, 782),
#  (10071840, 'Almost Human', 'Milano odia: la polizia non può sparare', 1974, None, 99, 7.3, 1890),
#  (10071859, 'The Traveler', 'Mossafer', 1974, None, 83, 7.5, 1125),
#  (10071864, 'Love at the Top', 'Le mouton enragé', 1974, None, 105, 7.2, 1405),
#  (10071880, 'The Last 4 Days', 'Mussolini ultimo atto', 1974, None, 126, 6.5, 577),
#  (10071890, 'The Nada Gang', 'Nada', 1974, None, 133, 6.9, 884),
#  (10072010, 'Shoot First, Die Later', 'Il poliziotto è marcio', 1974, None, 94, 6.7, 501),
#  (10072012, 'Turn the Other Cheek', "Porgi l'altra guancia", 1974, None, 89, 6.5, 3568),
#  (10072021, 'The Deluge', 'Potop', 1974, None, 287, 7.7, 2036),
#  (10072037, 'Scent of a Woman', 'Profumo di donna', 1974, None, 103, 7.6, 3463),
#  (10072053, 'Let Joy Reign Supreme', 'Que la fête commence...', 1975, None, 114, 7.1, 1219),
#  (10072190, 'The Golden Fortress', 'Sonar Kella', 1974, None, 120, 8.4, 1655),
#  (10072205, 'Stephen the Great - Vaslui 1475', 'Stefan cel Mare - Vaslui 1475', 1975, None, 137, 8.0, 565),
#  (10072248, 'Still Life', 'Tabiate bijan', 1974, None, 93, 7.8, 690),
#  (10072342, 'Pleasure Party', 'Une partie de plaisir', 1975, None, 101, 6.5, 527),
#  (10072353, 'Going Places', 'Les valseuses', 1974, None, 150, 7.3, 7573),
#  (10072439, "Zatoichi's Conspiracy", 'Shin Zatôichi monogatari: Kasama no chimatsuri', 1973, None, 88, 7.2, 720),
#  (10071688, 'Jacob the Liar', 'Jakob, der Lügner', 1974, None, 100, 7.2, 1099),
#  (10071691, 'The Enigma of Kaspar Hauser', 'Jeder für sich und Gott gegen alle', 1974, None, 110, 7.8, 15223),
#  (10072603, 'The French Detective', 'Adieu poulet', 1975, None, 91, 6.9, 1251),
#  (10071696, 'Police Tactics', 'Jingi naki tatakai: Chôjô sakusen', 1974, None, 101, 7.5, 808),
#  (10072637, 'My Friends', 'Amici miei', 1975, None, 140, 8.1, 5980),
#  (10071733, 'Lacombe, Lucien', 'Lacombe Lucien', 1974, None, 138, 7.7, 5744),
#  (10072813, 'The Confessional', 'House of Mortal Sin', 1976, None, 104, 6.5, 647),
#  (10072884, 'Distracted', 'Le distrait', 1970, None, 85, 6.4, 1125),
#  (10072901, 'The Twelve Tasks of Asterix', "Les 12 travaux d'Astérix", 1976, None, 82, 7.7, 13651),
#  (10072991, '5 Masters of Death', 'Shao Lin wu zu', 1974, None, 105, 6.7, 890),
#  (10072993, 'Slade in Flame', 'Flame', 1975, None, 91, 6.9, 507),
#  (10072919, 'The Story of Sin', 'Dzieje grzechu', 1975, None, 130, 6.2, 505),
#  (10072931, 'Emil and the Piglet', 'Emil och griseknoen', 1973, None, 97, 7.2, 2285),
#  (10072934, 'A Pain in the Ass', "L'emmerdeur", 1973, None, 85, 7.1, 2583),
#  (10073012, "The Four Musketeers: Milady's Revenge", 'The Four Musketeers', 1974, None, 108, 7.0, 9174),
#  (10073028, 'Poachers', 'Furtivos', 1975, None, 82, 7.5, 644),
#  (10073051, 'Syndicate Sadists', 'Il giustiziere sfida la città', 1975, None, 90, 6.4, 586),
#  (10073206, 'Black Magic', 'Jiang tou', 1975, None, 93, 6.2, 554),
#  (10073207, 'Graveyard of Honor', 'Jingi no hakaba', 1975, None, 94, 7.3, 1250),
#  (10073219, 'The Judge and the Assassin', "Le juge et l'assassin", 1976, None, 128, 7.4, 1443),
#  (10073221, 'Just Before Nightfall', 'Juste avant la nuit', 1971, None, 106, 7.4, 1617),
#  (10073233, 'Katie Tippel', 'Keetje Tippel', 1975, None, 100, 6.6, 2140),
#  (10073152, 'Kings of the Road', 'Im Lauf der Zeit', 1976, None, 175, 7.8, 4511),
#  (10073163, 'Incorrigible', "L'incorrigible", 1975, None, 100, 6.7, 1184),
#  (10073168, 'Infra-Man', 'Zhong guo chao ren', 1975, None, 88, 6.3, 1673),
#  (10073324, 'Lips of Blood', 'Lèvres de sang', 1975, None, 88, 6.0, 1224),
#  (10073406, 'The Suspicious Death of a Minor', 'Morte sospetta di una minorenne', 1975, None, 100, 6.6, 625),
#  (10073424, 'Mother Küsters Goes to Heaven', "Mutter Küsters' Fahrt zum Himmel", 1975, None, 120, 7.6, 1625),
#  (10073442, "It Can't Be!", 'Ne mozhet byt!', 1975, None, 100, 7.7, 1503),
#  (10073343, 'The Dragon Flies', 'The Man from Hong Kong', 1975, None, 111, 6.6, 1104),
#  (10073363, 'Manila in the Claws of Light', 'Maynila sa mga kuko ng liwanag', 1975, None, 125, 7.8, 1156),
#  (10073373, 'Terror of Mechagodzilla', 'Mekagojira no gyakushu', 1975, None, 83, 6.3, 3600),
#  (10073488, 'They Fought for Their Country', 'Oni srazhalis za rodinu', 1975, None, 137, 8.0, 2032),
#  (10073623, 'Return of the Street Fighter', 'Satsujin ken 2', 1974, None, 88, 6.4, 1690),
#  (10073663, 'Le Sauvage', 'Le sauvage', 1975, None, 107, 6.7, 1373),
#  (10073541, 'Flatfoot in Hong Kong', 'Piedone a Hong Kong', 1975, None, 115, 6.5, 2667),
#  (10073580, 'The Passenger', 'Professione: reporter', 1975, None, 126, 7.6, 19007),
#  (10073582, 'Deep Red', 'Profondo rosso', 1975, None, 127, 7.6, 28249),
#  (10073594, 'The Four of the Apocalypse...', "I quattro dell'Apocalisse", 1975, None, 104, 6.4, 2104),
#  (10073755, "The Streetfighter's Last Revenge", 'Gyakushû! Satsujin ken', 1974, None, 83, 6.1, 1042),
#  (10073756, 'The Street Fighter', 'Gekitotsu! Satsujin ken', 1974, None, 91, 7.1, 4270),
#  (10073778, "Maggie's Stiletto Sisters", 'The Jezebels', 1975, None, 91, 6.6, 3034),
#  (10073781, 'Queen of the Gypsies', 'Tabor ukhodit v nebo', 1976, None, 101, 7.5, 1369),
#  (10073800, 'The Travelling Players', 'O thiasos', 1975, None, 230, 8.0, 3087),
#  (10073714, 'Sister Street Fighter', 'Onna hissatsu ken', 1974, None, 92, 6.3, 1076),
#  (10073841, 'Under the Blossoming Cherry Trees', 'Sakura no mori no mankai no shita', 1975, None, 95, 7.5, 654),
#  (10073858, 'The Lost Honor of Katharina Blum', 'Die verlorene Ehre der Katharina Blum', 1975, None, 106, 7.4, 3595),
#  (10073864, 'The Old Gun', 'Le vieux fusil', 1975, None, 103, 7.7, 3352),
#  (10073946, 'The Softening of the Egg', 'Ägget är löst! En hårdkokt saga', 1975, None, 107, 6.2, 757),
#  (10073948, 'Adoption', 'Örökbefogadás', 1975, None, 89, 7.3, 581),
#  (10074083, 'Strange Shadows in an Empty Room', 'Una Magnum Special per Tony Saitta', 1976, None, 100, 6.5, 529),
#  (10074084, '1900', 'Novecento', 1976, None, 317, 7.7, 20696),
#  (10071786, 'The Earth Is a Sinful Song', 'Maa on syntinen laulu', 1973, None, 108, 6.9, 690),
#  (10074102, 'In the Realm of the Senses', 'Ai no korîda', 1976, None, 109, 6.6, 16656),
#  (10074103, 'The Wing or The Thigh?', "L'aile ou la cuisse", 1976, None, 104, 7.3, 8858),
#  (10074114, 'Alice or The Last Escapade', 'Alice ou la dernière fugue', 1977, None, 93, 6.9, 824),
#  (10074123, 'Hunter Will Get You', "L'alpagueur", 1976, None, 110, 6.6, 1617),
#  (10074348, 'Body of My Enemy', 'Le corps de mon ennemi', 1976, None, 116, 6.7, 1219),
#  (10074252, 'Ugly, Dirty and Bad', 'Brutti, sporchi e cattivi', 1976, None, 115, 7.8, 6973),
#  (10074262, 'Illustrious Corpses', 'Cadaveri eccellenti', 1976, None, 120, 7.4, 1700),
#  (10074291, "Fellini's Casanova", 'Il Casanova di Federico Fellini', 1976, None, 155, 7.1, 6322),
#  (10074147, 'Face to Face', 'Ansikte mot ansikte', 1976, None, 114, 7.6, 4458),
#  (10074179, 'The Private Eyes', 'Ban jin ba liang', 1976, None, 94, 7.1, 575),
#  (10074220, 'The Scar', 'Blizna', 1976, None, 106, 6.7, 1419),
#  (10074487, 'The Inheritance', "L'eredità Ferramonti", 1976, None, 120, 7.2, 694),
#  (10074586, 'The Big Racket', 'Il grande racket', 1976, None, 104, 7.2, 972),
#  (10074611, 'The Haunting of Julia', 'Full Circle', 1977, None, 98, 6.3, 1597),
#  (10074626, 'Heart of Glass', 'Herz aus Glas', 1976, None, 94, 7.1, 4981),
#  (10074515, 'Coup de Grâce', 'Der Fangschuß', 1976, None, 97, 6.9, 1076),
#  (10074360, 'Cría Cuervos', 'Cría cuervos', 1976, None, 105, 8.0, 8219),
#  (10074398, 'The Disenchantment', 'El desencanto', 1976, None, 97, 8.1, 503),
#  (10074811, 'The Tenant', 'Le locataire', 1976, None, 126, 7.7, 35080),
#  (10074686, "L'Innocente", "L'innocente", 1976, None, 129, 7.4, 2958),
#  (10074691, 'The Inugami Family', 'Inugami-ke no ichizoku', 1976, None, 146, 7.3, 562),
#  (10074701, 'The Rat Savior', 'Izbavitelj', 1976, None, 80, 6.9, 644),
#  (10074710, 'The Middleman', 'Jana Aranya', 1975, None, 131, 8.3, 1141),
#  (10074720, 'The Toy', 'Le jouet', 1976, None, 95, 7.5, 4224),
#  (10074846, 'The Little Mermaid', 'Malá morská víla', 1976, None, 84, 7.2, 562),
#  (10074865, 'Marecku, Pass Me the Pen!', 'Marecku, podejte mi pero!', 1976, None, 91, 8.2, 1631),
#  (10074870, 'The Marquise of O', 'Die Marquise von O...', 1976, None, 102, 7.1, 2036),
#  (10075002, 'The Olsen Gang Sees Red', 'Olsen-banden ser rødt', 1976, None, 100, 7.6, 1864),
#  (10075007, 'The Seventh Company Has Been Found', 'On a retrouvé la 7ème compagnie !', 1975, None, 90, 6.7, 1292),
#  (10075008, "Now We've Seen It All!", 'On aura tout vu', 1976, None, 100, 6.3, 503),
#  (10075024, 'The Punishment', 'Osânda', 1976, None, 112, 8.1, 549),
#  (10075094, 'The Written Off Return', 'Povratak otpisanih', 1976, None, 95, 8.1, 860),
#  (10074921, 'The Bridge', 'Most', 1969, None, 105, 7.6, 869),
#  (10074972, 'Black and White in Color', 'La victoire en chantant', 1976, None, 90, 6.9, 1304),
#  (10075119, 'A Slave of Love', 'Raba lyubvi', 1976, None, 94, 7.3, 1290),
#  (10075140, 'Murder on the Bridge', 'Der Richter und sein Henker', 1975, None, 106, 6.1, 812),
#  (10075165, "Satan's Brew", 'Satansbraten', 1976, None, 112, 7.0, 1549),
#  (10075202, 'Shaolin Temple', 'Shao Lin si', 1976, None, 126, 6.9, 921),
#  (10075467, 'The Fifth Seal', 'Az ötödik pecsét', 1976, None, 111, 8.8, 3127),
#  (10075364, 'The Last Woman', 'La dernière femme', 1976, None, 112, 6.6, 971),
#  (10075375, 'Live Like a Cop, Die Like a Man', 'Uomini si nasce poliziotti si muore', 1976, None, 100, 6.6, 1040),
#  (10075404, 'The Ascent', 'Voskhozhdenie', 1977, None, 111, 8.3, 5419),
#  (10074442, 'Crime Busters', 'I due superpiedi quasi piatti', 1977, None, 115, 7.2, 9534),
#  (10074443, 'Duelle', 'Duelle (une quarantaine)', 1976, None, 121, 7.3, 1072),
#  (10074447, 'Twenty Days Without War', 'Dvadtsat dney bez voyny', 1977, None, 101, 7.8, 1038),
#  (10074451, 'Plot of Fear', 'E tanta paura', 1976, None, 98, 6.2, 512),
#  (10075633, "Adele's Dinner", 'Adéla jeste nevecerela', 1978, None, 102, 7.7, 1280),
#  (10075651, 'Shock', 'Schock', 1977, None, 95, 6.3, 2990),
#  (10075666, 'Alucarda', 'Alucarda, la hija de las tinieblas', 1977, None, 78, 6.3, 2584),
#  (10075703, 'Long Live Ghosts!', 'At zijí duchové!', 1977, None, 85, 7.6, 524),
#  (10075730, 'Camouflage', 'Barwy ochronne', 1977, None, 106, 7.5, 1062),
#  (10075740, 'Beast with a Gun', 'La belva col mitra', 1977, None, 91, 6.1, 818),
#  (10075983, 'Elisa, My Life', 'Elisa, vida mía', 1977, None, 125, 7.3, 561),
#  (10075999, "Satan's Blood", 'Escalofrío', 1978, None, 82, 6.0, 731),
#  (10075922, 'The House by the Lake', 'Death Weekend', 1976, None, 87, 6.1, 877),
#  (10075932, 'The Lacemaker', 'La dentellière', 1977, None, 107, 7.7, 2086),
#  (10075939, 'Peppermint Soda', 'Diabolo menthe', 1977, None, 101, 6.8, 859),
#  (10076085, 'A Special Day', 'Una giornata particolare', 1977, None, 106, 8.1, 10132),
#  (10076098, 'The Report', 'Gozaresh', 1977, None, 112, 7.0, 599),
#  (10076101, 'High Rollers', 'Bluff storia di truffe e di imbroglioni', 1976, None, 110, 7.5, 3028),
#  (10076150, 'Alice, Sweet Alice', 'Communion', 1976, None, 98, 6.5, 8246),
#  (10076207, 'I Am Self Sufficient', 'Io sono un autarchico', 1976, None, 95, 6.4, 729),
#  (10076208, 'Iphigenia', 'Ifigeneia', 1977, None, 127, 7.7, 1396),
#  (10076242, 'Judge Fayard Called the Sheriff', 'Le juge Fayard dit Le Shériff', 1977, None, 112, 7.2, 543),
#  (10076252, 'The Year of the Hare', 'Jäniksen vuosi', 1977, None, 129, 7.6, 1124),
#  (10076162, 'House', 'Hausu', 1977, None, 88, 7.3, 17287),
#  (10076168, 'Executioners from Shaolin', 'Hong Xi Guan', 1977, None, 98, 7.0, 1186),
#  (10076276, "Who's Singin' Over There?", 'Ko to tamo peva', 1980, None, 86, 8.9, 12696),
#  (10076280, 'The Consequence', 'Die Konsequenz', 1977, None, 100, 7.2, 643),
#  (10076286, 'The Hunters', 'Oi kynigoi', 1977, None, 168, 7.5, 654),
#  (10076313, 'Blood Relatives', 'Les liens de sang', 1978, None, 100, 6.3, 752),
#  (10076336, 'Hell Without Limits', 'El lugar sin límites', 1978, None, 110, 7.7, 887),
#  (10076348, 'Madame Rosa', 'La vie devant soi', 1977, None, 105, 7.2, 954),
#  (10076398, 'Operation Thunderbolt', 'Mivtsa Yonatan', 1977, None, 124, 6.7, 768),
#  (10076470, 'Pardon Mon Affaire, Too!', 'Nous irons tous au paradis', 1977, None, 110, 6.9, 875),
#  (10076360, 'A Man Called Blade', 'Mannaja', 1977, None, 101, 6.6, 1427),
#  (10075790, 'The Brothers Lionheart', 'Bröderna Lejonhjärta', 1977, None, 106, 7.2, 5702),
#  (10076495, 'The Olsen Gang Outta Sight', "Olsen-banden deruda'", 1977, None, 105, 6.7, 1288),
#  (10076517, 'Padre Padrone', 'Padre padrone', 1977, None, 113, 7.4, 3316),
#  (10076518, 'Rulers of the City', 'I padroni della città', 1976, None, 88, 6.0, 706),
#  ...]

# %% [markdown]
# ### Column Aliases with AS

# %%
# %%sql
#
# SELECT
#     title AS movieTitle,
#     orig_title AS 'original Title',
#     runtime AS Duration
#
# FROM movies AS m;
# Out:
#  * postgresql://postgres:***@localhost:5432/imdb
# (psycopg2.errors.SyntaxError) syntax error at or near "'original Title'"
# LINE 3:     orig_title AS 'original Title',
#                           ^
#
# [SQL: SELECT
#     title AS movieTitle,
#     orig_title AS 'original Title',
#     runtime AS Duration
#
# FROM movies AS m;]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %% [markdown]
# ```{note}
# The keyword AS is optional. I usually choose to use it because it makes the query more readable. So the below also works.
# ```

# %%
# %%sql
#
# SELECT
#     title movieTitle,
#     /*Only situation where we refer to a column with double quotes, as there is a white space*/
#     orig_title "original Title", -- See here we are using double quotes
#     runtime Duration
# FROM
#     movies m;
# Out:
#  * postgresql://postgres:***@localhost:5432/imdb
# 26058 rows affected.
# [('Kate & Leopold', None, 118),
#  ('Mister 880', None, 90),
#  ('Black Hand', None, 92),
#  ('Francis', None, 91),
#  ('Orpheus', 'Orphée', 95),
#  ('Stromboli', 'Stromboli, terra di Dio', 107),
#  ('Woman in Hiding', None, 92),
#  ('Abbott and Costello in the Foreign Legion', None, 80),
#  ('Annie Get Your Gun', None, 107),
#  ('Armored Car Robbery', None, 67),
#  ('The Asphalt Jungle', None, 112),
#  ('Atom Man vs. Superman', None, 252),
#  ('Backfire', None, 91),
#  ('The Baron of Arizona', None, 97),
#  ('The Big Lift', None, 120),
#  ('The Black Rose', None, 120),
#  ('The Blue Lamp', None, 84),
#  ('Borderline', None, 88),
#  ('Born to Be Bad', None, 94),
#  ('Branded', None, 104),
#  ('Bright Leaf', None, 110),
#  ('Caged', None, 96),
#  ('The Cariboo Trail', None, 81),
#  ('Champagne for Caesar', None, 99),
#  ('Cinderella', None, 74),
#  ('The Clouded Yellow', None, 95),
#  ('Colt .45', None, 74),
#  ('Convicted', None, 91),
#  ('Copper Canyon', None, 84),
#  ('Crisis', None, 95),
#  ('Story of a Love Affair', 'Cronaca di un amore', 98),
#  ('Cyrano de Bergerac', None, 113),
#  ('Dallas', None, 94),
#  ("The Damned Don't Cry", None, 103),
#  ('Dark City', None, 98),
#  ('Destination Moon', None, 92),
#  ('Destination Murder', None, 72),
#  ("Devil's Doorway", None, 84),
#  ('Dial 1119', None, 75),
#  ('Fancy Pants', None, 92),
#  ('Father of the Bride', None, 92),
#  ('The Flame and the Arrow', None, 88),
#  ('The Fuller Brush Girl', None, 85),
#  ('The Furies', None, 109),
#  ('The Glass Menagerie', None, 107),
#  ('Gone to Earth', None, 110),
#  ('The Great Rupert', None, 87),
#  ('Gun Crazy', None, 87),
#  ('The Gunfighter', None, 85),
#  ('The Happy Years', None, 110),
#  ('Harriet Craig', None, 94),
#  ('Harvey', None, 104),
#  ('House by the River', None, 83),
#  ('In a Lonely Place', None, 94),
#  ('The Jackie Robinson Story', None, 77),
#  ('The Jackpot', None, 85),
#  ('Diary of a Country Priest', "Journal d'un curé de campagne", 115),
#  ('Key to the City', None, 101),
#  ('Kim', None, 113),
#  ("King Solomon's Mines", None, 103),
#  ('Kiss Tomorrow Goodbye', None, 102),
#  ('Kon-Tiki', None, 77),
#  ('A Lady Without Passport', None, 74),
#  ('Last Holiday', None, 88),
#  ('A Life of Her Own', None, 108),
#  ('Variety Lights', 'Luci del varietà', 97),
#  ('Ma and Pa Kettle Go to Town', None, 79),
#  ('Madeleine', None, 114),
#  ('The Magnificent Yankee', None, 89),
#  ('The Man Who Cheated Himself', None, 81),
#  ('The Men', None, 85),
#  ('The Miniver Story', None, 104),
#  ('Montana', None, 76),
#  ('Trio', None, 91),
#  ('Mystery Street', None, 93),
#  ('The Nevadan', None, 81),
#  ('The Next Voice You Hear...', None, 83),
#  ('Night and the City', None, 101),
#  ('No Way Out', None, 106),
#  ('The Young and the Damned', 'Los olvidados', 85),
#  ('Operation Disaster', 'Morning Departure', 102),
#  ('Outrage', None, 75),
#  ('Panic in the Streets', None, 96),
#  ('Quicksand', None, 79),
#  ('Rashomon', 'Rashômon', 88),
#  ('Rio Grande', None, 105),
#  ('Rocky Mountain', None, 83),
#  ('La Ronde', 'La ronde', 93),
#  ('The Secret Fury', None, 85),
#  ('September Affair', None, 104),
#  ('Seven Days to Noon', None, 94),
#  ('Shadow on the Wall', None, 84),
#  ('Side Street', None, 83),
#  ('Sierra', None, 83),
#  ('Stage Fright', None, 110),
#  ('Stars in My Crown', None, 89),
#  ('Sunset Blvd.', None, 110),
#  ('Susana', None, 86),
#  ('Tea for Two', None, 98),
#  ('Three Came Home', None, 106),
#  ('Three Little Words', None, 102),
#  ('To Joy', 'Till glädje', 98),
#  ('To Please a Lady', None, 91),
#  ('The Toast of New Orleans', None, 97),
#  ('Treasure Island', None, 96),
#  ('The Sound of Fury', None, 91),
#  ('Two Flags West', None, 92),
#  ('Two Weeks with Love', None, 90),
#  ('The Underworld Story', None, 91),
#  ('Wagon Master', None, 86),
#  ('Walk Softly, Stranger', None, 81),
#  ('The West Point Story', None, 107),
#  ('When Willie Comes Marching Home', None, 82),
#  ('Where the Sidewalk Ends', None, 95),
#  ('The White Tower', None, 98),
#  ("Winchester '73", None, 92),
#  ('Woman on the Run', None, 77),
#  ('The Wooden Horse', None, 101),
#  ('Boot Polish', None, 149),
#  ('A.T.M.: ¡¡A toda máquina!!', None, 120),
#  ('Across the Wide Missouri', None, 78),
#  ('The African Queen', None, 105),
#  ('Alice in Wonderland', None, 75),
#  ('An American in Paris', None, 114),
#  ('Angels in the Outfield', None, 99),
#  ('Anne of the Indies', None, 81),
#  ('Appointment with Danger', None, 90),
#  ('As Young as You Feel', None, 77),
#  ('The Red Inn', "L'auberge rouge", 98),
#  ('Awaara', None, 193),
#  ('Early Summer', 'Bakushû', 125),
#  ('The Big Night', None, 75),
#  ('Bright Victory', None, 97),
#  ('The Browning Version', None, 90),
#  ('Callaway Went Thataway', None, 81),
#  ('Captain Horatio Hornblower R.N.', None, 117),
#  ("Casque d'Or", "Casque d'or", 96),
#  ('The Cimarron Kid', None, 84),
#  ('The Emperor and the Golem', 'Císaruv pekar - Pekaruv císar', 144),
#  ("Comin' Round the Mountain", None, 77),
#  ('Cry Danger', None, 79),
#  ('Cry, the Beloved Country', None, 103),
#  ('David and Bathsheba', None, 116),
#  ('Death of a Salesman', None, 115),
#  ('Decision Before Dawn', None, 119),
#  ('The Desert Fox: The Story of Rommel', None, 88),
#  ('Detective Story', None, 103),
#  ("Europe '51", "Europa '51", 118),
#  ('Five', None, 93),
#  ('Flying Leathernecks', None, 102),
#  ('Fort Worth', None, 80),
#  ('Fourteen Hours', None, 92),
#  ('The Frogmen', None, 96),
#  ('Miss Julie', 'Fröken Julie', 90),
#  ('The Great Caruso', None, 109),
#  ('Guardie e ladri', None, 105),
#  ('The Idiot', 'Hakuchi', 166),
#  ('He Ran All the Way', None, 77),
#  ('Here Comes the Groom', None, 113),
#  ('His Kind of Woman', None, 120),
#  ('One Summer of Happiness', 'Hon dansade en sommar', 103),
#  ('The Hoodlum', None, 61),
#  ('The House on Telegraph Hill', None, 93),
#  ("I'll Never Forget You", 'The House in the Square', 90),
#  ("I'll See You in My Dreams", None, 110),
#  ('Forbidden Games', 'Jeux interdits', 86),
#  ('Jim Thorpe -- All-American', None, 107),
#  ('Kekec', None, 97),
#  ('Kind Lady', None, 78),
#  ('Laughter in Paradise', None, 93),
#  ("Let's Make It Legal", None, 77),
#  ('Lone Star', None, 94),
#  ('Love Nest', None, 84),
#  ('M', None, 88),
#  ('The Magic Box', None, 118),
#  ('Man in the Saddle', None, 87),
#  ('The Mating Season', None, 101),
#  ('Meshi', None, 97),
#  ('The Mob', None, 87),
#  ('A Woman Without Love', 'Una mujer sin amor', 85),
#  ('The Lady of Musashino', 'Musashino fujin', 88),
#  ('My Favorite Spy', None, 93),
#  ('No Questions Asked', None, 80),
#  ('Odette', None, 124),
#  ('Has Anybody Seen My Gal', None, 88),
#  ('On Dangerous Ground', None, 82),
#  ('On Moonlight Bay', None, 95),
#  ('On the Riviera', None, 89),
#  ('Only the Valiant', None, 105),
#  ('Miss Oyu', 'Oyû-sama', 94),
#  ('Pandora and the Flying Dutchman', None, 122),
#  ('Pathala Bhairavi', None, 192),
#  ('Payment on Demand', None, 90),
#  ("The People Against O'Hara", None, 102),
#  ('The Little World of Don Camillo', 'Don Camillo', 107),
#  ('A Place in the Sun', None, 122),
#  ('La Poison', 'La poison', 85),
#  ('The Prowler', None, 92),
#  ('Quo Vadis', None, 171),
#  ('The Racket', None, 88),
#  ('Rawhide', None, 89),
#  ('The Red Badge of Courage', None, 69),
#  ('Rhubarb', None, 94),
#  ('The River', None, 99),
#  ('Roadblock', None, 73),
#  ('Royal Wedding', None, 93),
#  ('Sailor Beware', None, 108),
#  ('Santa Fe', None, 87),
#  ('A Christmas Carol', 'Scrooge', 86),
#  ('Sealed Cargo', None, 90),
#  ('The Secret of Convict Lake', None, 83),
#  ('Show Boat', None, 108),
#  ('Sirocco', None, 98),
#  ('Summer Interlude', 'Sommarlek', 96),
#  ('The Steel Helmet', None, 85),
#  ('Storm Warning', None, 93),
#  ('The Strange Door', None, 81),
#  ('A Streetcar Named Desire', None, 122),
#  ('The Strip', None, 85),
#  ('The Tall Target', None, 78),
#  ('Ten Tall Men', None, 97),
#  ('The Thing from Another World', None, 87),
#  ('Three Guys Named Mike', None, 90),
#  ('Thunder on the Hill', None, 84),
#  ('Tomahawk', None, 82),
#  ('Man of Straw', 'Der Untertan', 109),
#  ('Der Verlorene', None, 98),
#  ('The Well', None, 86),
#  ('Westward the Women', None, 118),
#  ('You Never Can Tell', None, 78),
#  ('5 Fingers', None, 108),
#  ('Above and Beyond', None, 122),
#  ('Affair in Trinidad', None, 98),
#  ('Against All Flags', None, 84),
#  ('Androcles and the Lion', None, 98),
#  ('Angel Face', None, 91),
#  ("Another Man's Poison", None, 90),
#  ('April in Paris', None, 100),
#  ("At Sword's Point", None, 81),
#  ('Robinson Crusoe', None, 90),
#  ('The Bad and the Beautiful', None, 118),
#  ('The Battle at Apache Pass', None, 85),
#  ('The Belle of New York', None, 82),
#  ('Beauties of the Night', 'Les belles de nuit', 87),
#  ('Belles on Their Toes', None, 89),
#  ('Bend of the River', None, 91),
#  ('Beware, My Lovely', None, 77),
#  ('The Big Sky', None, 140),
#  ('The Black Castle', None, 82),
#  ('Blackbeard, the Pirate', None, 99),
#  ('Struggle in the Valley', 'Siraa Fil-Wadi', 105),
#  ('The Sound Barrier', None, 118),
#  ('El bruto', None, 81),
#  ('The Captive City', None, 91),
#  ('Carbine Williams', None, 92),
#  ('Carrie', None, 118),
#  ('Carson City', None, 87),
#  ('Children of Hiroshima', 'Genbaku no ko', 97),
#  ('Clash by Night', None, 105),
#  ('White Mane', 'Crin blanc: Le cheval sauvage', 47),
#  ('Deadline - U.S.A.', None, 87),
#  ('Diplomatic Courier', None, 97),
#  ("Don't Bother to Knock", None, 76),
#  ('Dreamboat', None, 83),
#  ('The Duel at Silver Creek', None, 77),
#  ('The Greatest Show on Earth', None, 152),
#  ('The Green Glove', None, 89),
#  ("Hangman's Knot", None, 81),
#  ('Hans Christian Andersen', None, 112),
#  ('High Noon', None, 85),
#  ('The Holly and the Ivy', None, 83),
#  ('Ikiru', None, 143),
#  ('Ivanhoe', None, 106),
#  ('Jumping Jacks', None, 96),
#  ('Kansas City Confidential', None, 99),
#  ('Kvinnors väntan', None, 107),
#  ('The Lavender Hill Mob', None, 78),
#  ('Limelight', None, 137),
#  ('The Long Memory', None, 96),
#  ('Lost in Alaska', None, 76),
#  ('Lovely to Look At', None, 103),
#  ('The Lusty Men', None, 113),
#  ('Macao', None, 81),
#  ('The Man in the White Suit', None, 85),
#  ('The Marrying Kind', None, 92),
#  ('The Member of the Wedding', None, 93),
#  ('The Miracle of Our Lady of Fatima', None, 102),
#  ('Les Miserables', None, 105),
#  ('Monkey Business', None, 97),
#  ('Moulin Rouge', None, 119),
#  ('My Cousin Rachel', None, 98),
#  ('The Naked Spur', None, 91),
#  ('The Narrow Margin', None, 71),
#  ('The Flavor of Green Tea Over Rice', 'Ochazuke no aji', 116),
#  ('Mother', 'Okaasan', 98),
#  ('Park Row', None, 83),
#  ('Pat and Mike', None, 95),
#  ('Plymouth Adventure', None, 105),
#  ('Pony Soldier', None, 82),
#  ('The Pride of St. Louis', None, 93),
#  ('The Prisoner of Zenda', None, 96),
#  ('The Promoter', 'The Card', 85),
#  ('The Quiet Man', None, 129),
#  ('Rancho Notorious', None, 89),
#  ('The Return of Don Camillo', 'Le retour de Don Camillo', 115),
#  ('The Ring', None, 79),
#  ('Room for One More', None, 98),
#  ('Ruby Gentry', None, 82),
#  ('Scaramouche', None, 115),
#  ("Singin' in the Rain", None, 103),
#  ('The Snows of Kilimanjaro', None, 114),
#  ('Springfield Rifle', None, 93),
#  ('The Star', None, 89),
#  ('The Steel Trap', None, 85),
#  ('Stolen Face', None, 72),
#  ('The Stooge', None, 100),
#  ('The Stranger in Between', 'Hunted', 84),
#  ('Talk About a Stranger', None, 65),
#  ('The Thief', None, 86),
#  ('Umberto D.', None, 89),
#  ('I vinti', None, 113),
#  ('Way of a Gaucho', None, 87),
#  ("We're Not Married!", None, 86),
#  ('The Wild North', None, 97),
#  ('With a Song in My Heart', None, 117),
#  ('The World in His Arms', None, 104),
#  ('El', None, 92),
#  ('The 5,000 Fingers of Dr. T.', None, 89),
#  ('Abbott and Costello Go to Mars', None, 77),
#  ('Die Geschichte vom kleinen Muck', None, 100),
#  ('The Actress', None, 90),
#  ('The Affairs of Dobie Gillis', None, 72),
#  ('All I Desire', None, 80),
#  ('Love in the City', "L'amore in città", 115),
#  ('Arrowhead', None, 105),
#  ('The Band Wagon', None, 112),
#  ('Battle Circus', None, 90),
#  ('The Beast from 20,000 Fathoms', None, 80),
#  ('The Big Heat', None, 89),
#  ('The Bigamist', None, 80),
#  ('Blowing Wild', None, 90),
#  ('The Blue Gardenia', None, 85),
#  ('A Blueprint for Murder', None, 77),
#  ('The Caddy', None, 95),
#  ('Calamity Jane', None, 101),
#  ('Call Me Madam', None, 114),
#  ("The Captain's Paradise", None, 94),
#  ('City That Never Sleeps', None, 90),
#  ('Crash of Silence', 'Mandy', 93),
#  ('The Cruel Sea', None, 126),
#  ('Dangerous Crossing', None, 75),
#  ('The Desert Rats', None, 88),
#  ('Destination Gobi', None, 90),
#  ('Do Bigha Zamin', None, 131),
#  ("Donovan's Brain", None, 84),
#  ('Dream Wife', None, 100),
#  ('Escape from Fort Bravo', None, 99),
#  ('Gentlemen Prefer Blondes', None, 91),
#  ('A Geisha', 'Gion bayashi', 85),
#  ('The Glass Wall', None, 82),
#  ('Gun Fury', None, 83),
#  ('Sawdust and Tinsel', 'Gycklarnas afton', 93),
#  ("His Majesty O'Keefe", None, 91),
#  ('The Hitch-Hiker', None, 71),
#  ('Hondo', None, 83),
#  ('Houdini', None, 106),
#  ('House of Wax', None, 88),
#  ('How to Marry a Millionaire', None, 95),
#  ('I Confess', None, 95),
#  ('I Love Melvin', None, 77),
#  ('Inferno', None, 83),
#  ('Invaders from Mars', None, 78),
#  ('Island in the Sky', None, 109),
#  ('It Came from Outer Space', None, 81),
#  ('Jeopardy', None, 69),
#  ('Gate of Hell', 'Jigokumon', 89),
#  ('King of the Khyber Rifles', None, 100),
#  ('Kiss Me Kate', None, 109),
#  ('Knights of the Round Table', None, 115),
#  ('Miss Sadie Thompson', None, 91),
#  ('The Mississippi Gambler', None, 99),
#  ('Mogambo', None, 116),
#  ('Money from Home', None, 100),
#  ('The Moon Is Blue', None, 99),
#  ('Never Let Me Go', None, 94),
#  ('Niagara', None, 92),
#  ('The Proud and the Beautiful', 'Les orgueilleux', 103),
#  ('Bread, Love and Dreams', 'Pane, amore e fantasia', 93),
#  ('Peter Pan', None, 77),
#  ('Pickup on South Street', None, 80),
#  ('Plunder of the Sun', None, 81),
#  ("The President's Lady", None, 96),
#  ('The Robe', None, 135),
#  ('Roman Holiday', None, 118),
#  ('The Wages of Fear', 'Le salaire de la peur', 131),
#  ('Scared Stiff', None, 108),
#  ('Second Chance', None, 82),
#  ('Seminole', None, 87),
#  ('Shane', None, 118),
#  ('Small Town Girl', None, 92),
#  ('South Sea Woman', None, 99),
#  ('Split Second', None, 85),
#  ('Stalag 17', None, 120),
#  ('Indiscretion of an American Wife', 'Stazione Termini', 90),
#  ('The Story of Three Loves', None, 122),
#  ('The Sun Shines Bright', None, 90),
#  ('Beat the Devil', None, 89),
#  ('The Lawless Breed', None, 83),
#  ('Lili', None, 81),
#  ('A Lion Is in the Streets', None, 88),
#  ('Little Fugitive', None, 80),
#  ('The Living Desert', None, 69),
#  ('The Earrings of Madame De...', 'Madame de...', 105),
#  ('Malta Story', None, 103),
#  ('The Man Between', None, 100),
#  ('The Man from the Alamo', None, 79),
#  ('Man on a Tightrope', None, 105),
#  ('The Count of Monte Cristo', 'Le comte de Monte-Cristo', 183),
#  ('Thunder Bay', None, 103),
#  ('Thunder Over the Plains', None, 82),
#  ('The Adultress', 'Thérèse Raquin', 102),
#  ('Titanic', None, 98),
#  ('The Titfield Thunderbolt', None, 84),
#  ('Trouble Along the Way', None, 111),
#  ('Trouble in Store', None, 85),
#  ('Journey to Italy', 'Viaggio in Italia', 85),
#  ('I Vitelloni', 'I vitelloni', 107),
#  ('Tumbleweed', None, 79),
#  ('Ugetsu', 'Ugetsu monogatari', 96),
#  ('Young Bess', None, 112),
#  ("Monsieur Hulot's Holiday", 'Les vacances de Monsieur Hulot', 114),
#  ('Skanderbeg', 'Velikiy voin Albanii Skanderbeg', 95),
#  ('Vesna', None, 96),
#  ('Late Chrysanthemums', 'Bangiku', 101),
#  ('The Barefoot Contessa', None, 128),
#  ('Beau Brummell', None, 113),
#  ('Betrayed', None, 108),
#  ('Black Widow', None, 95),
#  ('20,000 Leagues Under the Sea', None, 127),
#  ('Wuthering Heights', 'Abismos de pasión', 91),
#  ('About Mrs. Leslie', None, 104),
#  ('The Bridges at Toko-Ri', None, 102),
#  ('An American in Rome', 'Un americano a Roma', 94),
#  ('Anatahan', None, 91),
#  ('Angels One Five', None, 98),
#  ('Brigadoon', None, 108),
#  ('Broken Lance', None, 96),
#  ('The Caine Mutiny', None, 124),
#  ('Carmen Jones', None, 105),
#  ("Casanova's Big Night", None, 86),
#  ('The Country Girl', None, 104),
#  ('Crime Wave', None, 73),
#  ('The Dam Busters', None, 124),
#  ('Demetrius and the Gladiators', None, 101),
#  ('Désirée', None, 110),
#  ('Destry', None, 95),
#  ('School for Tramps', 'Escuela de vagabundos', 99),
#  ('Diabolique', 'Les diaboliques', 117),
#  ('Dial M for Murder', None, 105),
#  ('Doctor in the House', None, 92),
#  ('Down Three Dark Streets', None, 85),
#  ('Dragnet', None, 88),
#  ('Drive a Crooked Road', None, 83),
#  ('Drum Beat', None, 111),
#  ('The Egyptian', None, 139),
#  ('Executive Suite', None, 104),
#  ('The Detective', 'Father Brown', 91),
#  ('French Cancan', None, 102),
#  ('Living It Up', None, 95),
#  ('Lucky Me', None, 100),
#  ('The Mad Magician', None, 72),
#  ('Godzilla', 'Gojira', 96),
#  ('The Miracle of Marcelino', 'Marcelino pan y vino', 91),
#  ('Miseria e nobiltà', None, 94),
#  ('The Story of Vickie', 'Mädchenjahre einer Königin', 118),
#  ('Naked Alibi', None, 86),
#  ('Night People', None, 93),
#  ('Twenty-Four Eyes', 'Nijûshi no hitomi', 156),
#  ('The Good Die Young', None, 100),
#  ('Rhapsody', None, 115),
#  ('Ride Clear of Diablo', None, 81),
#  ('On the Waterfront', None, 108),
#  ('The Gold of Naples', "L'oro di Napoli", 138),
#  ('Riding Shotgun', None, 73),
#  ('Riot in Cell Block 11', None, 80),
#  ('River of No Return', None, 91),
#  ('Phffft', None, 88),
#  ('Prince Valiant', None, 100),
#  ('Private Hell 36', None, 81),
#  ('The Purple Plain', None, 97),
#  ('Pushover', None, 88),
#  ('Rogue Cop', None, 92),
#  ('The Raid', None, 83),
#  ('Rear Window', None, 112),
#  ('The River and Death', 'El río y la muerte', 91),
#  ('Sabrina', None, 113),
#  ('Salt of the Earth', None, 94),
#  ('Sansho the Bailiff', 'Sanshô dayû', 124),
#  ('Saskatchewan', None, 87),
#  ('Seven Brides for Seven Brothers', None, 102),
#  ('A Star Is Born', None, 154),
#  ('Shield for Murder', None, 82),
#  ('The Student Prince', None, 107),
#  ('Suddenly', None, 77),
#  ('Susan Slept Here', None, 98),
#  ("The Devil's General", 'Des Teufels General', 117),
#  ('Them!', None, 94),
#  ("There's No Business Like Show Business", None, 117),
#  ('Three Cases of Murder', None, 99),
#  ('Three Hours to Kill', None, 77),
#  ('Track of the Cat', None, 102),
#  ('Hell and High Water', None, 103),
#  ('High and Dry', "The 'Maggie'", 92),
#  ('The High and the Mighty', None, 147),
#  ("Hobson's Choice", None, 108),
#  ('Human Desire', None, 91),
#  ('An Inspector Calls', None, 80),
#  ('Knock on Wood', None, 103),
#  ('Silver Lode', None, 81),
#  ('The Sleeping Tiger', None, 89),
#  ('Ulysses', 'Ulisse', 117),
#  ('Valley of the Kings', None, 86),
#  ('Bad Day at Black Rock', None, 81),
#  ('White Christmas', None, 120),
#  ('The Wild One', None, 79),
#  ('Witness to Murder', None, 83),
#  ('Sound of the Mountain', 'Yama no oto', 95),
#  ('Young at Heart', None, 117),
#  ('Battle Cry', None, 149),
#  ('The Benny Goodman Story', None, 116),
#  ('The Big Combo', None, 87),
#  ('Abbott and Costello Meet the Mummy', None, 79),
#  ('Above Us the Waves', None, 99),
#  ('Le Amiche', 'Le amiche', 104),
#  ('Big House, U.S.A.', None, 83),
#  ('Animal Farm', None, 72),
#  ('Artists and Models', None, 109),
#  ('The Big Knife', None, 111),
#  ('Blackboard Jungle', None, 101),
#  ('Daddy Long Legs', None, 126),
#  ('Dementia', None, 56),
#  ('Davy Crockett: King of the Wild Frontier', None, 93),
#  ('Bob le Flambeur', 'Bob le flambeur', 98),
#  ('A Bullet for Joey', None, 85),
#  ('Rififi', 'Du rififi chez les hommes', 118),
#  ('East of Eden', None, 118),
#  ('The Far Country', None, 97),
#  ('The Far Horizons', None, 108),
#  ('Female on the Beach', None, 97),
#  ('Footsteps in the Fog', None, 90),
#  ('The End of the Affair', None, 105),
#  ('Wee Geordie', 'Geordie', 93),
#  ('The Glass Slipper', None, 93),
#  ('The Grand Maneuver', 'Les grandes manoeuvres', 106),
#  ('Guys and Dolls', None, 150),
#  ('Captain Lightfoot', None, 92),
#  ('That Is the Dawn', "Cela s'appelle l'aurore", 102),
#  ('Bloody Spear at Mount Fuji', 'Chiyari Fuji', 94),
#  ('The Cobweb', None, 134),
#  ('The Colditz Story', None, 94),
#  ('City of Fear', None, 81),
#  ('Mister Roberts', None, 123),
#  ('Dreams', 'Kvinnodröm', 87),
#  ('Merry-Go-Round', 'Körhinta', 90),
#  ('Lady and the Tramp', None, 76),
#  ('The Ladykillers', None, 91),
#  ('Land of the Pharaohs', None, 106),
#  ('The Last Command', None, 110),
#  ('A Lawless Street', None, 78),
#  ('The Left Hand of God', None, 87),
#  ('Lola Montès', None, 116),
#  ('The Long Gray Line', None, 138),
#  ('Love Is a Many-Splendored Thing', None, 102),
#  ('Love Me or Leave Me', None, 122),
#  ('A Man Alone', None, 96),
#  ('A Man Called Peter', None, 119),
#  ('Man with the Gun', None, 84),
#  ('Man Without a Star', None, 89),
#  ('The Man from Laramie', None, 103),
#  ('The Man with the Golden Arm', None, 119),
#  ('Many Rivers to Cross', None, 94),
#  ('Marty', None, 90),
#  ('Maksim Perepelitsa', None, 94),
#  ('Hit the Deck', None, 112),
#  ('House of Bamboo', None, 102),
#  ('I Died a Thousand Times', None, 109),
#  ("I'll Cry Tomorrow", None, 117),
#  ('I Live in Fear', 'Ikimono no kiroku', 103),
#  ('Illegal', None, 88),
#  ('The Indian Fighter', None, 88),
#  ('Interrupted Melody', None, 106),
#  ('It Came from Beneath the Sea', None, 79),
#  ("It's Always Fair Weather", None, 101),
#  ('Jubal', None, 100),
#  ('The Kentuckian', None, 104),
#  ("Killer's Kiss", None, 67),
#  ('Kismet', None, 113),
#  ('Kiss Me Deadly', None, 106),
#  ('The Phenix City Story', None, 100),
#  ('La Pointe Courte', 'La Pointe-Courte', 86),
#  ('A Generation', 'Pokolenie', 87),
#  ('The Prisoner', None, 95),
#  ('The Private War of Major Benson', None, 105),
#  ('Queen Bee', None, 95),
#  ('Quentin Durward', None, 103),
#  ('Rage at Dawn', None, 87),
#  ('Rebel Without a Cause', None, 111),
#  ('The Rose Tattoo', None, 117),
#  ('Run for Cover', None, 93),
#  ('The Scarlet Coat', None, 101),
#  ('The Sea Chase', None, 117),
#  ('The Seven Year Itch', None, 105),
#  ('Shack Out on 101', None, 80),
#  ('Shree 420', None, 168),
#  ('Sissi', None, 102),
#  ('Soldier of Fortune', None, 96),
#  ('Smiles of a Summer Night', 'Sommarnattens leende', 109),
#  ('Stella', None, 90),
#  ('Summertime', None, 99),
#  ('Tall Man Riding', None, 83),
#  ('The Tall Men', None, 122),
#  ('Tarantula', None, 80),
#  ('Moonfleet', None, 84),
#  ('Mr. Arkadin', None, 93),
#  ('The Naked Dawn', None, 82),
#  ('The Naked Street', None, 84),
#  ('Ten Wanted Men', None, 80),
#  ('Not as a Stranger', None, 135),
#  ('Tight Spot', None, 97),
#  ('To Catch a Thief', None, 106),
#  ('To Hell and Back', None, 106),
#  ('Trial', None, 105),
#  ('The Trouble with Harry', None, 99),
#  ('The Unknown Soldier', 'Tuntematon sotilas', 177),
#  ('Floating Clouds', 'Ukigumo', 123),
#  ('Untamed', None, 111),
#  ('Wichita', None, 81),
#  ('Princess Yang Kwei-fei', 'Yôkihi', 98),
#  ('The Violent Men', None, 96),
#  ('Violent Saturday', None, 90),
#  ('The Virgin Queen', None, 92),
#  ("We're No Angels", None, 106),
#  ('Ordet', None, 126),
#  ('Our Miss Brooks', None, 85),
#  ('Pather Panchali', None, 125),
#  ("Too Bad She's Bad", 'Peccato che sia una canaglia', 95),
#  ('Dobrý voják Svejk', None, 108),
#  ('1984', None, 90),
#  ('23 Paces to Baker Street', None, 103),
#  ('Street of Shame', 'Akasen chitai', 87),
#  ("The Ambassador's Daughter", None, 103),
#  ('Anastasia', None, 105),
#  ('Anything Goes', None, 106),
#  ('Aparajito', None, 110),
#  ('Attack', None, 107),
#  ('Autumn Leaves', None, 107),
#  ('Away All Boats', None, 114),
#  ('Back from Eternity', None, 97),
#  ('Backlash', None, 84),
#  ('The Band of Honest Men', 'La banda degli onesti', 106),
#  ('Bandido!', None, 92),
#  ('Beyond a Reasonable Doubt', None, 80),
#  ('Bhowani Junction', None, 110),
#  ('Bigger Than Life', None, 95),
#  ('The Burmese Harp', 'Biruma no tategoto', 116),
#  ('The Black Sleep', None, 82),
#  ("Raquel's Shoeshiner", 'El bolero de Raquel', 101),
#  ('The Brave One', None, 100),
#  ('Bundle of Joy', None, 98),
#  ('The Burglar', None, 90),
#  ('Bus Stop', None, 96),
#  ('C.I.D.', None, 146),
#  ('The Rocket from Calabuch', 'Calabuch', 93),
#  ('Main Street', 'Calle Mayor', 99),
#  ('Carousel', None, 128),
#  ('The Catered Affair', None, 94),
#  ('The Cockleshell Heroes', None, 97),
#  ('The Court Jester', None, 101),
#  ('Crime in the Streets', None, 91),
#  ('A Cry in the Night', None, 75),
#  ('D-Day the Sixth of June', None, 106),
#  ('Death of a Scoundrel', None, 119),
#  ('Gervaise', None, 112),
#  ('Giant', None, 201),
#  ("The Girl Can't Help It", None, 99),
#  ('Good-bye, My Lady', None, 94),
#  ('Night Ambush', 'Ill Met by Moonlight', 104),
#  ('Invasion of the Body Snatchers', None, 80),
#  ('Invitation to the Dance', None, 93),
#  ('Stay Alert', 'Jagte Raho', 153),
#  ('Julie', None, 99),
#  ('The Killer Is Loose', None, 73),
#  ('The Killing', None, 84),
#  ('The King and Four Queens', None, 86),
#  ('The King and I', None, 133),
#  ('A Kiss Before Dying', None, 94),
#  ('A Girl in Black', 'To koritsi me ta mavra', 100),
#  ('Lust of the Vampire', 'I vampiri', 82),
#  ('The Last Frontier', None, 98),
#  ('The Last Hunt', None, 108),
#  ('The Last Wagon', None, 99),
#  ('Love Me Tender', None, 89),
#  ('Professor Hannibal', 'Hannibál tanár úr', 89),
#  ('The Harder They Fall', None, 109),
#  ('The Captain from Köpenick', 'Der Hauptmann von Köpenick', 93),
#  ('High Society', None, 111),
#  ('Hollywood or Bust', None, 95),
#  ('Earth vs. the Flying Saucers', None, 83),
#  ('The Man Who Knew Too Much', None, 120),
#  ('The Man Who Never Was', None, 103),
#  ('The Man in the Gray Flannel Suit', None, 153),
#  ('...And God Created Woman', 'Et Dieu... créa la femme', 95),
#  ('Meet Me in Las Vegas', None, 112),
#  ('Miracle in the Rain', None, 108),
#  ('Moby Dick', None, 116),
#  ('The Silent World', 'Le monde du silence', 86),
#  ('Death in the Garden', 'La mort en ce jardin', 104),
#  ('The Mountain', None, 105),
#  ('The Mystery of Picasso', 'Le mystère Picasso', 78),
#  ('Flowing', 'Nagareru', 117),
#  ('Nightfall', None, 78),
#  ('Pardners', None, 90),
#  ('Patterns', None, 83),
#  ('Please Murder Me!', None, 78),
#  ("Private's Progress", None, 102),
#  ('The Proud Ones', None, 94),
#  ('The Quatermass Xperiment', None, 82),
#  ('The Rack', None, 100),
#  ('The Rainmaker', None, 121),
#  ('Ransom!', None, 109),
#  ('The Rawhide Years', None, 85),
#  ('Reach for the Sky', None, 135),
#  ('Richard III', None, 161),
#  ('Rock Around the Clock', None, 77),
#  ('Run for the Sun', None, 99),
#  ('The Fastest Gun Alive', None, 89),
#  ('The Searchers', None, 119),
#  ('7 Men from Now', None, 78),
#  ('Il ferroviere', None, 115),
#  ('Sissi: The Young Empress', 'Sissi - Die junge Kaiserin', 107),
#  ('Slightly Scarlet', None, 99),
#  ('Somebody Up There Likes Me', None, 113),
#  ('The Forty-First', 'Sorok pervyy', 88),
#  ('Early Spring', 'Sôshun', 145),
#  ('The Spanish Gardener', None, 97),
#  ('The Flying Carpet', 'Starik Khottabych', 86),
#  ('Storm Center', None, 85),
#  ('The Swan', None, 104),
#  ('Tea and Sympathy', None, 122),
#  ('The Ten Commandments', None, 220),
#  ('These Wilder Years', None, 91),
#  ('The Third Key', 'The Long Arm', 96),
#  ('Three Violent People', None, 100),
#  ('Time Without Pity', None, 85),
#  ('Time Table', None, 80),
#  ('A Town Like Alice', None, 117),
#  ('Trapeze', None, 105),
#  ('Four Bags Full', 'La traversée de Paris', 80),
#  ('Tribute to a Bad Man', None, 95),
#  ('A Man Escaped', "Un condamné à mort s'est échappé ou Le vent souffle où il veut", 101),
#  ('Up in the World', None, 87),
#  ('Forbidden Planet', None, 98),
#  ('Vesna na Zarechnoy ulitse', None, 96),
#  ('Walk the Proud Land', None, 88),
#  ('War and Peace', None, 208),
#  ('The Werewolf', None, 79),
#  ('X the Unknown', None, 81),
#  ('Forever, Darling', None, 96),
#  ('Friendly Persuasion', None, 137),
#  ('Cast a Dark Shadow', None, 82),
#  ('12 Angry Men', None, 96),
#  ('20 Million Miles to Earth', None, 82),
#  ('The 27th Day', None, 75),
#  ('3:10 to Yuma', None, 92),
#  ('Seven Days from Now', 'Seven Waves Away', 100),
#  ('The Abominable Snowman', None, 91),
#  ('Across the Bridge', None, 103),
#  ('Paradise Lagoon', 'The Admirable Crichton', 94),
#  ('The Chaplin Revue', None, 128),
#  ('Montparnasse 19', 'Les amants de Montparnasse', 108),
#  ('Bitter Victory', None, 102),
#  ('Baby Face Nelson', None, 85),
#  ('The Bachelor Party', None, 92),
#  ('The Sun Legend of the End of the Tokugawa Era', 'Bakumatsu taiyôden', 110),
#  ('Band of Angels', None, 125),
#  ('Battle Hymn', None, 108),
#  ('Mother India', None, 172),
#  ('Chase a Crooked Shadow', None, 88),
#  ('Boy on a Dolphin', None, 111),
#  ('The Brothers Rico', None, 92),
#  ("Campbell's Kingdom", None, 102),
#  ('The Enemy Below', None, 98),
#  ('Eroica', None, 87),
#  ('Les espions', None, 125),
#  ('A Face in the Crowd', None, 126),
#  ('Fiend Without a Face', None, 75),
#  ('Fire Down Below', None, 116),
#  ('Fools in the Mountains', 'Fjols til fjells', 90),
#  ('Forty Guns', None, 80),
#  ('Funny Face', None, 103),
#  ('The Mysterians', 'Chikyû Bôeigun', 89),
#  ('China Gate', None, 97),
#  ('La grande strada azzurra', None, 103),
#  ('The Green Man', None, 80),
#  ('Gun Glory', None, 89),
#  ('Gunfight at the O.K. Corral', None, 122),
#  ('The Guns of Fort Petticoat', None, 82),
#  ('A Hatful of Rain', None, 109),
#  ('Heaven Knows, Mr. Allison', None, 107),
#  ('The Helen Morgan Story', None, 118),
#  ('Crime of Passion', None, 86),
#  ('Island in the Sun', None, 119),
#  ('Jailhouse Rock', None, 96),
#  ('Jeanne Eagels', None, 108),
#  ('Johnny Tremain', None, 80),
#  ('Just My Luck', None, 86),
#  ('Kanal', None, 91),
#  ('A King in New York', None, 110),
#  ('Throne of Blood', 'Kumonosu-jô', 110),
#  ('The Incredible Shrinking Man', None, 81),
#  ('Les Girls', None, 114),
#  ('The Cranes Are Flying', 'Letyat zhuravli', 95),
#  ('The Lonely Man', None, 88),
#  ('Love in the Afternoon', None, 130),
#  ('Loving You', None, 101),
#  ('Lucky Jim', None, 95),
#  ('Madhumati', None, 110),
#  ('The Curse of Frankenstein', None, 82),
#  ('Inspector Maigret', 'Maigret tend un piège', 119),
#  ('Man of a Thousand Faces', None, 122),
#  ('The D.I.', None, 106),
#  ('Men in War', None, 102),
#  ('Mon Oncle', 'Mon oncle', 116),
#  ('The Monolith Monsters', None, 77),
#  ('Decision at Sundown', None, 77),
#  ('My Man Godfrey', None, 92),
#  ('The Devil Strikes at Night', 'Nachts, wenn der Teufel kam', 105),
#  ('Naya Daur', None, 173),
#  ('Nine Lives', 'Ni liv', 96),
#  ('Night Passage', None, 90),
#  ('No Down Payment', None, 105),
#  ('Not of This Earth', None, 67),
#  ('The Hunchback of Notre Dame', 'Notre-Dame de Paris', 115),
#  ('Le Notti Bianche', 'Le notti bianche', 102),
#  ('The Nights of Cabiria', 'Le notti di Cabiria', 110),
#  ('Old Yeller', None, 83),
#  ('The One That Got Away', None, 106),
#  ('Operation Mad Ball', None, 105),
#  ('The Pajama Game', None, 101),
#  ('Pal Joey', None, 111),
#  ('Paths of Glory', None, 88),
#  ('The Delicate Delinquent', None, 101),
#  ('Peyton Place', None, 157),
#  ('Plunder Road', None, 72),
#  ('I Dutifully Report', 'Poslusne hlásím', 91),
#  ('Pyaasa', None, 146),
#  ('Raintree County', None, 160),
#  ('The Revenge of Frankenstein', None, 90),
#  ('The Ride Back', None, 79),
#  ("The River's Edge", None, 87),
#  ('Run of the Arrow', None, 86),
#  ('Designing Woman', None, 118),
#  ('Saddle the Wind', None, 84),
#  ('Sayonara', None, 147),
#  ('Desk Set', None, 103),
#  ('Do Ankhen Barah Haath', None, 143),
#  ('Silk Stockings', None, 117),
#  ('The Seventh Seal', 'Det sjunde inseglet', 96),
#  ('Big Time Operators', 'The Smallest Show on Earth', 80),
#  ('Wild Strawberries', 'Smultronstället', 91),
#  ('Something of Value', None, 113),
#  ('The Story of Esther Costello', None, 103),
#  ('The Sun Also Rises', None, 130),
#  ('Sweet Smell of Success', None, 96),
#  ('The Tall Stranger', None, 81),
#  ('Tammy and the Bachelor', None, 89),
#  ('The Tarnished Angels', None, 91),
#  ('A Matter of Dignity', 'To teleftaio psemma', 112),
#  ('The Three Faces of Eve', None, 91),
#  ('Tikhiy Don', None, 330),
#  ('Time Limit', None, 96),
#  ('The Tin Star', None, 93),
#  ('Tizoc (Amor indio)', None, 109),
#  ('Tokyo Twilight', 'Tôkyô boshoku', 140),
#  ('Trooper Hook', None, 81),
#  ('The True Story of Jesse James', None, 92),
#  ('La Parisienne', 'Une parisienne', 86),
#  ('Until They Sail', None, 94),
#  ('El vampiro', None, 95),
#  ('Doctor at Large', None, 104),
#  ('Wild Is the Wind', None, 114),
#  ('Will Success Spoil Rock Hunter?', None, 93),
#  ('Das Wirtshaus im Spessart', None, 99),
#  ('Witness for the Prosecution', None, 116),
#  ('The Wrong Man', None, 105),
#  ('Don Kikhot', None, 110),
#  ("Don't Go Near the Water", None, 107),
#  ('The Lower Depths', 'Donzoko', 137),
#  ('The Bravados', None, 98),
#  ('The Buccaneer', None, 119),
#  ('Buchanan Rides Alone', None, 80),
#  ('Carry on Nurse', None, 86),
#  ('Carry On Sergeant', None, 84),
#  ('Cat on a Hot Tin Roof', None, 108),
#  ('The 7th Voyage of Sinbad', None, 88),
#  ('Bandini', None, 157),
#  ('Christine', None, 100),
#  ('Araya', None, 90),
#  ('Elevator to the Gallows', "Ascenseur pour l'échafaud", 91),
#  ('Auntie Mame', None, 143),
#  ('Cairo Station', 'Bab el hadid', 77),
#  ('The Badlanders', None, 85),
#  ('Bell Book and Candle', None, 106),
#  ('The Big Country', None, 166),
#  ('The H-Man', 'Bijo to ekitai ningen', 87),
#  ('The Blob', None, 86),
#  ("Blue Murder at St. Trinian's", None, 86),
#  ('Bonjour Tristesse', 'Bonjour tristesse', 94),
#  ('Corridors of Blood', None, 86),
#  ('Horror of Dracula', 'Dracula', 82),
#  ('Dunkirk', None, 135),
#  ('Lake of the Dead', 'De dødes tjern', 76),
#  ('Love Is My Profession', 'En cas de malheur', 105),
#  ('Conflagration', 'Enjô', 99),
#  ('Fanfare', None, 86),
#  ('The Fearmakers', None, 85),
#  ('The Fly', None, 94),
#  ('Fort Dobbs', None, 93),
#  ('Fort Massacre', None, 80),
#  ('From Hell to Texas', None, 100),
#  ('Career', None, 105),
#  ('The Geisha Boy', None, 98),
#  ('Cowboy', None, 92),
#  ('Gideon of Scotland Yard', "Gideon's Day", 91),
#  ('Gigi', None, 115),
#  ("God's Little Acre", None, 118),
#  ('The Goddess', None, 104),
#  ('The Gunfight at Dodge City', None, 81),
#  ('H-8...', None, 105),
#  ('The Haunted Strangler', 'Grip of the Strangler', 78),
#  ('Hell Drivers', None, 108),
#  ('Home Before Dark', None, 136),
#  ('The Idiot', 'Idiot', 124),
#  ('Imitation General', None, 88),
#  ('Indiscreet', None, 100),
#  ('It! The Terror from Beyond Space', None, 69),
#  ('Ivan the Terrible, Part II', 'Ivan Groznyy. Skaz vtoroy: Boyarskiy zagovor', 88),
#  ('The Music Room', 'Jalsaghar', 100),
#  ('The Hidden Fortress', 'Kakushi-toride no san-akunin', 139),
#  ('The Key', None, 134),
#  ('King Creole', None, 116),
#  ('Kings Go Forth', None, 109),
#  ('The Law and Jake Wade', None, 86),
#  ('The Law Is the Law', 'La legge è legge', 95),
#  ('The Law', 'La legge', 126),
#  ("The Horse's Mouth", None, 97),
#  ('House on Haunted Hill', None, 75),
#  ('Houseboat', None, 110),
#  ('The Hunters', None, 108),
#  ('I Bury the Living', None, 77),
#  ('I Married a Monster from Outer Space', None, 78),
#  ('I Want to Live!', None, 120),
#  ('The Long, Hot Summer', None, 115),
#  ('Look Back in Anger', None, 98),
#  ('Machine-Gun Kelly', None, 80),
#  ('Man of the West', None, 100),
#  ('Marjorie Morningstar', None, 128),
#  ('Me and the Colonel', None, 109),
#  ('Merry Andrew', None, 103),
#  ('We Only Live Once', 'Mia zoi tin ehoume', 111),
#  ('Moi, un noir', None, 70),
#  ('The Rickshaw Man', 'Muhomatsu no issho', 103),
#  ('Murder by Contract', None, 81),
#  ('Mädchen in Uniform', None, 95),
#  ('The Naked and the Dead', None, 131),
#  ('Nazarin', 'Nazarín', 94),
#  ('Neither Seen Nor Recognized', 'Ni vu, ni connu', 95),
#  ('A Night to Remember', None, 123),
#  ('No Name on the Bullet', None, 77),
#  ('No Time for Sergeants', None, 119),
#  ('Brink of Life', 'Nära livet', 84),
#  ('Paras-Pathar', 'Parash Pathar', 111),
#  ('Party Girl', None, 99),
#  ('The Perfect Furlough', None, 93),
#  ('The Noose', 'Petla', 96),
#  ('The Little Apartment', 'El pisito', 87),
#  ('Cry Terror!', None, 96),
#  ('Ashes and Diamonds', 'Popiól i diament', 103),
#  ('The Proud Rebel', None, 103),
#  ('The Quiet American', None, 120),
#  ("Rally 'Round the Flag, Boys!", None, 106),
#  ('The Reluctant Debutante', None, 94),
#  ('Ride a Crooked Trail', None, 88),
#  ('Rock-a-Bye Baby', None, 103),
#  ('The Roots of Heaven', None, 126),
#  ('Run Silent Run Deep', None, 93),
#  ('The Snorkel', None, 90),
#  ('Some Came Running', None, 137),
#  ('South Pacific', None, 157),
#  ('The Square Peg', None, 85),
#  ...]

# %% [markdown]
# ```{margin}
# <img src="img/joinslec4.png" width="600">
# ```

# %% [markdown]
# ```{note}
# We will often use table aliases when we work on SQL joins in the upcoming lectures! You MUST use it in some cases, which we will see in lecture 3.
# ```

# %% [markdown]
# ```{admonition} iclicker: Does the below query execute with no issues ?
#
#     SELECT
#         title AS movieTitle,
#         orig_title AS "oringinal Title",
#         runtime AS Duration
#     FROM
#         movies
#     WHERE
#         Duration > 100;
#
# a) Yes
#
# b) No
# ```

# %% [markdown]
# ```{toggle}
# No. Check the order of execution. Next topic...
# ```

# %% [markdown]
# ## Order of execution/processing in SQL
#
# > Check the PrairieLearn question
#
# [https://us.prairielearn.com/pl/course_instance/167527/instructor/question/9265385/preview/?variant_id=108271439](https://us.prairielearn.com/pl/course_instance/167527/instructor/question/9265385/preview/?variant_id=108271439)
#
# ***VERY important:*** Keep the following in mind.
#
# Order of execution/processing in SQL:

# %% [markdown]
#     FROM and JOIN
#         |
#       WHERE
#         |
#     GROUP BY
#         |
#       HAVING
#         |
#       SELECT
#         |
#     DISTINCT
#         |
#     ORDER BY
#         |
#       LIMIT

# %% [markdown]
# Contrast this with the order of SQL clauses in a statement:
#
# [https://us.prairielearn.com/pl/course_instance/167527/instructor/question/9265384/preview](https://us.prairielearn.com/pl/course_instance/167527/instructor/question/9265384/preview)

# %% [markdown]
#       SELECT
#         |
#       FROM
#         |
#       JOIN
#         |
#       WHERE
#         |
#     GROUP BY
#         |
#       HAVING
#         |
#     ORDER BY
#         |
#       LIMIT

# %% [markdown]
# ## Derived columns

# %%
# %%sql
#
# SELECT
#     title,
#     /*Here we derive column runtime_hours from runtime*/
#     runtime / 60::REAL AS runtime_hours
# FROM
#     movies;
# Out:
#  * postgresql://postgres:***@localhost:5432/imdb
# 26058 rows affected.
# [('Kate & Leopold', 1.9666666666666666),
#  ('Mister 880', 1.5),
#  ('Black Hand', 1.5333333333333334),
#  ('Francis', 1.5166666666666666),
#  ('Orpheus', 1.5833333333333333),
#  ('Stromboli', 1.7833333333333334),
#  ('Woman in Hiding', 1.5333333333333334),
#  ('Abbott and Costello in the Foreign Legion', 1.3333333333333333),
#  ('Annie Get Your Gun', 1.7833333333333334),
#  ('Armored Car Robbery', 1.1166666666666667),
#  ('The Asphalt Jungle', 1.8666666666666667),
#  ('Atom Man vs. Superman', 4.2),
#  ('Backfire', 1.5166666666666666),
#  ('The Baron of Arizona', 1.6166666666666667),
#  ('The Big Lift', 2.0),
#  ('The Black Rose', 2.0),
#  ('The Blue Lamp', 1.4),
#  ('Borderline', 1.4666666666666666),
#  ('Born to Be Bad', 1.5666666666666667),
#  ('Branded', 1.7333333333333334),
#  ('Bright Leaf', 1.8333333333333333),
#  ('Caged', 1.6),
#  ('The Cariboo Trail', 1.35),
#  ('Champagne for Caesar', 1.65),
#  ('Cinderella', 1.2333333333333334),
#  ('The Clouded Yellow', 1.5833333333333333),
#  ('Colt .45', 1.2333333333333334),
#  ('Convicted', 1.5166666666666666),
#  ('Copper Canyon', 1.4),
#  ('Crisis', 1.5833333333333333),
#  ('Story of a Love Affair', 1.6333333333333333),
#  ('Cyrano de Bergerac', 1.8833333333333333),
#  ('Dallas', 1.5666666666666667),
#  ("The Damned Don't Cry", 1.7166666666666666),
#  ('Dark City', 1.6333333333333333),
#  ('Destination Moon', 1.5333333333333334),
#  ('Destination Murder', 1.2),
#  ("Devil's Doorway", 1.4),
#  ('Dial 1119', 1.25),
#  ('Fancy Pants', 1.5333333333333334),
#  ('Father of the Bride', 1.5333333333333334),
#  ('The Flame and the Arrow', 1.4666666666666666),
#  ('The Fuller Brush Girl', 1.4166666666666667),
#  ('The Furies', 1.8166666666666667),
#  ('The Glass Menagerie', 1.7833333333333334),
#  ('Gone to Earth', 1.8333333333333333),
#  ('The Great Rupert', 1.45),
#  ('Gun Crazy', 1.45),
#  ('The Gunfighter', 1.4166666666666667),
#  ('The Happy Years', 1.8333333333333333),
#  ('Harriet Craig', 1.5666666666666667),
#  ('Harvey', 1.7333333333333334),
#  ('House by the River', 1.3833333333333333),
#  ('In a Lonely Place', 1.5666666666666667),
#  ('The Jackie Robinson Story', 1.2833333333333334),
#  ('The Jackpot', 1.4166666666666667),
#  ('Diary of a Country Priest', 1.9166666666666667),
#  ('Key to the City', 1.6833333333333333),
#  ('Kim', 1.8833333333333333),
#  ("King Solomon's Mines", 1.7166666666666666),
#  ('Kiss Tomorrow Goodbye', 1.7),
#  ('Kon-Tiki', 1.2833333333333334),
#  ('A Lady Without Passport', 1.2333333333333334),
#  ('Last Holiday', 1.4666666666666666),
#  ('A Life of Her Own', 1.8),
#  ('Variety Lights', 1.6166666666666667),
#  ('Ma and Pa Kettle Go to Town', 1.3166666666666667),
#  ('Madeleine', 1.9),
#  ('The Magnificent Yankee', 1.4833333333333334),
#  ('The Man Who Cheated Himself', 1.35),
#  ('The Men', 1.4166666666666667),
#  ('The Miniver Story', 1.7333333333333334),
#  ('Montana', 1.2666666666666666),
#  ('Trio', 1.5166666666666666),
#  ('Mystery Street', 1.55),
#  ('The Nevadan', 1.35),
#  ('The Next Voice You Hear...', 1.3833333333333333),
#  ('Night and the City', 1.6833333333333333),
#  ('No Way Out', 1.7666666666666666),
#  ('The Young and the Damned', 1.4166666666666667),
#  ('Operation Disaster', 1.7),
#  ('Outrage', 1.25),
#  ('Panic in the Streets', 1.6),
#  ('Quicksand', 1.3166666666666667),
#  ('Rashomon', 1.4666666666666666),
#  ('Rio Grande', 1.75),
#  ('Rocky Mountain', 1.3833333333333333),
#  ('La Ronde', 1.55),
#  ('The Secret Fury', 1.4166666666666667),
#  ('September Affair', 1.7333333333333334),
#  ('Seven Days to Noon', 1.5666666666666667),
#  ('Shadow on the Wall', 1.4),
#  ('Side Street', 1.3833333333333333),
#  ('Sierra', 1.3833333333333333),
#  ('Stage Fright', 1.8333333333333333),
#  ('Stars in My Crown', 1.4833333333333334),
#  ('Sunset Blvd.', 1.8333333333333333),
#  ('Susana', 1.4333333333333333),
#  ('Tea for Two', 1.6333333333333333),
#  ('Three Came Home', 1.7666666666666666),
#  ('Three Little Words', 1.7),
#  ('To Joy', 1.6333333333333333),
#  ('To Please a Lady', 1.5166666666666666),
#  ('The Toast of New Orleans', 1.6166666666666667),
#  ('Treasure Island', 1.6),
#  ('The Sound of Fury', 1.5166666666666666),
#  ('Two Flags West', 1.5333333333333334),
#  ('Two Weeks with Love', 1.5),
#  ('The Underworld Story', 1.5166666666666666),
#  ('Wagon Master', 1.4333333333333333),
#  ('Walk Softly, Stranger', 1.35),
#  ('The West Point Story', 1.7833333333333334),
#  ('When Willie Comes Marching Home', 1.3666666666666667),
#  ('Where the Sidewalk Ends', 1.5833333333333333),
#  ('The White Tower', 1.6333333333333333),
#  ("Winchester '73", 1.5333333333333334),
#  ('Woman on the Run', 1.2833333333333334),
#  ('The Wooden Horse', 1.6833333333333333),
#  ('Boot Polish', 2.4833333333333334),
#  ('A.T.M.: ¡¡A toda máquina!!', 2.0),
#  ('Across the Wide Missouri', 1.3),
#  ('The African Queen', 1.75),
#  ('Alice in Wonderland', 1.25),
#  ('An American in Paris', 1.9),
#  ('Angels in the Outfield', 1.65),
#  ('Anne of the Indies', 1.35),
#  ('Appointment with Danger', 1.5),
#  ('As Young as You Feel', 1.2833333333333334),
#  ('The Red Inn', 1.6333333333333333),
#  ('Awaara', 3.216666666666667),
#  ('Early Summer', 2.0833333333333335),
#  ('The Big Night', 1.25),
#  ('Bright Victory', 1.6166666666666667),
#  ('The Browning Version', 1.5),
#  ('Callaway Went Thataway', 1.35),
#  ('Captain Horatio Hornblower R.N.', 1.95),
#  ("Casque d'Or", 1.6),
#  ('The Cimarron Kid', 1.4),
#  ('The Emperor and the Golem', 2.4),
#  ("Comin' Round the Mountain", 1.2833333333333334),
#  ('Cry Danger', 1.3166666666666667),
#  ('Cry, the Beloved Country', 1.7166666666666666),
#  ('David and Bathsheba', 1.9333333333333333),
#  ('Death of a Salesman', 1.9166666666666667),
#  ('Decision Before Dawn', 1.9833333333333334),
#  ('The Desert Fox: The Story of Rommel', 1.4666666666666666),
#  ('Detective Story', 1.7166666666666666),
#  ("Europe '51", 1.9666666666666666),
#  ('Five', 1.55),
#  ('Flying Leathernecks', 1.7),
#  ('Fort Worth', 1.3333333333333333),
#  ('Fourteen Hours', 1.5333333333333334),
#  ('The Frogmen', 1.6),
#  ('Miss Julie', 1.5),
#  ('The Great Caruso', 1.8166666666666667),
#  ('Guardie e ladri', 1.75),
#  ('The Idiot', 2.7666666666666666),
#  ('He Ran All the Way', 1.2833333333333334),
#  ('Here Comes the Groom', 1.8833333333333333),
#  ('His Kind of Woman', 2.0),
#  ('One Summer of Happiness', 1.7166666666666666),
#  ('The Hoodlum', 1.0166666666666666),
#  ('The House on Telegraph Hill', 1.55),
#  ("I'll Never Forget You", 1.5),
#  ("I'll See You in My Dreams", 1.8333333333333333),
#  ('Forbidden Games', 1.4333333333333333),
#  ('Jim Thorpe -- All-American', 1.7833333333333334),
#  ('Kekec', 1.6166666666666667),
#  ('Kind Lady', 1.3),
#  ('Laughter in Paradise', 1.55),
#  ("Let's Make It Legal", 1.2833333333333334),
#  ('Lone Star', 1.5666666666666667),
#  ('Love Nest', 1.4),
#  ('M', 1.4666666666666666),
#  ('The Magic Box', 1.9666666666666666),
#  ('Man in the Saddle', 1.45),
#  ('The Mating Season', 1.6833333333333333),
#  ('Meshi', 1.6166666666666667),
#  ('The Mob', 1.45),
#  ('A Woman Without Love', 1.4166666666666667),
#  ('The Lady of Musashino', 1.4666666666666666),
#  ('My Favorite Spy', 1.55),
#  ('No Questions Asked', 1.3333333333333333),
#  ('Odette', 2.066666666666667),
#  ('Has Anybody Seen My Gal', 1.4666666666666666),
#  ('On Dangerous Ground', 1.3666666666666667),
#  ('On Moonlight Bay', 1.5833333333333333),
#  ('On the Riviera', 1.4833333333333334),
#  ('Only the Valiant', 1.75),
#  ('Miss Oyu', 1.5666666666666667),
#  ('Pandora and the Flying Dutchman', 2.033333333333333),
#  ('Pathala Bhairavi', 3.2),
#  ('Payment on Demand', 1.5),
#  ("The People Against O'Hara", 1.7),
#  ('The Little World of Don Camillo', 1.7833333333333334),
#  ('A Place in the Sun', 2.033333333333333),
#  ('La Poison', 1.4166666666666667),
#  ('The Prowler', 1.5333333333333334),
#  ('Quo Vadis', 2.85),
#  ('The Racket', 1.4666666666666666),
#  ('Rawhide', 1.4833333333333334),
#  ('The Red Badge of Courage', 1.15),
#  ('Rhubarb', 1.5666666666666667),
#  ('The River', 1.65),
#  ('Roadblock', 1.2166666666666666),
#  ('Royal Wedding', 1.55),
#  ('Sailor Beware', 1.8),
#  ('Santa Fe', 1.45),
#  ('A Christmas Carol', 1.4333333333333333),
#  ('Sealed Cargo', 1.5),
#  ('The Secret of Convict Lake', 1.3833333333333333),
#  ('Show Boat', 1.8),
#  ('Sirocco', 1.6333333333333333),
#  ('Summer Interlude', 1.6),
#  ('The Steel Helmet', 1.4166666666666667),
#  ('Storm Warning', 1.55),
#  ('The Strange Door', 1.35),
#  ('A Streetcar Named Desire', 2.033333333333333),
#  ('The Strip', 1.4166666666666667),
#  ('The Tall Target', 1.3),
#  ('Ten Tall Men', 1.6166666666666667),
#  ('The Thing from Another World', 1.45),
#  ('Three Guys Named Mike', 1.5),
#  ('Thunder on the Hill', 1.4),
#  ('Tomahawk', 1.3666666666666667),
#  ('Man of Straw', 1.8166666666666667),
#  ('Der Verlorene', 1.6333333333333333),
#  ('The Well', 1.4333333333333333),
#  ('Westward the Women', 1.9666666666666666),
#  ('You Never Can Tell', 1.3),
#  ('5 Fingers', 1.8),
#  ('Above and Beyond', 2.033333333333333),
#  ('Affair in Trinidad', 1.6333333333333333),
#  ('Against All Flags', 1.4),
#  ('Androcles and the Lion', 1.6333333333333333),
#  ('Angel Face', 1.5166666666666666),
#  ("Another Man's Poison", 1.5),
#  ('April in Paris', 1.6666666666666667),
#  ("At Sword's Point", 1.35),
#  ('Robinson Crusoe', 1.5),
#  ('The Bad and the Beautiful', 1.9666666666666666),
#  ('The Battle at Apache Pass', 1.4166666666666667),
#  ('The Belle of New York', 1.3666666666666667),
#  ('Beauties of the Night', 1.45),
#  ('Belles on Their Toes', 1.4833333333333334),
#  ('Bend of the River', 1.5166666666666666),
#  ('Beware, My Lovely', 1.2833333333333334),
#  ('The Big Sky', 2.3333333333333335),
#  ('The Black Castle', 1.3666666666666667),
#  ('Blackbeard, the Pirate', 1.65),
#  ('Struggle in the Valley', 1.75),
#  ('The Sound Barrier', 1.9666666666666666),
#  ('El bruto', 1.35),
#  ('The Captive City', 1.5166666666666666),
#  ('Carbine Williams', 1.5333333333333334),
#  ('Carrie', 1.9666666666666666),
#  ('Carson City', 1.45),
#  ('Children of Hiroshima', 1.6166666666666667),
#  ('Clash by Night', 1.75),
#  ('White Mane', 0.7833333333333333),
#  ('Deadline - U.S.A.', 1.45),
#  ('Diplomatic Courier', 1.6166666666666667),
#  ("Don't Bother to Knock", 1.2666666666666666),
#  ('Dreamboat', 1.3833333333333333),
#  ('The Duel at Silver Creek', 1.2833333333333334),
#  ('The Greatest Show on Earth', 2.533333333333333),
#  ('The Green Glove', 1.4833333333333334),
#  ("Hangman's Knot", 1.35),
#  ('Hans Christian Andersen', 1.8666666666666667),
#  ('High Noon', 1.4166666666666667),
#  ('The Holly and the Ivy', 1.3833333333333333),
#  ('Ikiru', 2.3833333333333333),
#  ('Ivanhoe', 1.7666666666666666),
#  ('Jumping Jacks', 1.6),
#  ('Kansas City Confidential', 1.65),
#  ('Kvinnors väntan', 1.7833333333333334),
#  ('The Lavender Hill Mob', 1.3),
#  ('Limelight', 2.283333333333333),
#  ('The Long Memory', 1.6),
#  ('Lost in Alaska', 1.2666666666666666),
#  ('Lovely to Look At', 1.7166666666666666),
#  ('The Lusty Men', 1.8833333333333333),
#  ('Macao', 1.35),
#  ('The Man in the White Suit', 1.4166666666666667),
#  ('The Marrying Kind', 1.5333333333333334),
#  ('The Member of the Wedding', 1.55),
#  ('The Miracle of Our Lady of Fatima', 1.7),
#  ('Les Miserables', 1.75),
#  ('Monkey Business', 1.6166666666666667),
#  ('Moulin Rouge', 1.9833333333333334),
#  ('My Cousin Rachel', 1.6333333333333333),
#  ('The Naked Spur', 1.5166666666666666),
#  ('The Narrow Margin', 1.1833333333333333),
#  ('The Flavor of Green Tea Over Rice', 1.9333333333333333),
#  ('Mother', 1.6333333333333333),
#  ('Park Row', 1.3833333333333333),
#  ('Pat and Mike', 1.5833333333333333),
#  ('Plymouth Adventure', 1.75),
#  ('Pony Soldier', 1.3666666666666667),
#  ('The Pride of St. Louis', 1.55),
#  ('The Prisoner of Zenda', 1.6),
#  ('The Promoter', 1.4166666666666667),
#  ('The Quiet Man', 2.15),
#  ('Rancho Notorious', 1.4833333333333334),
#  ('The Return of Don Camillo', 1.9166666666666667),
#  ('The Ring', 1.3166666666666667),
#  ('Room for One More', 1.6333333333333333),
#  ('Ruby Gentry', 1.3666666666666667),
#  ('Scaramouche', 1.9166666666666667),
#  ("Singin' in the Rain", 1.7166666666666666),
#  ('The Snows of Kilimanjaro', 1.9),
#  ('Springfield Rifle', 1.55),
#  ('The Star', 1.4833333333333334),
#  ('The Steel Trap', 1.4166666666666667),
#  ('Stolen Face', 1.2),
#  ('The Stooge', 1.6666666666666667),
#  ('The Stranger in Between', 1.4),
#  ('Talk About a Stranger', 1.0833333333333333),
#  ('The Thief', 1.4333333333333333),
#  ('Umberto D.', 1.4833333333333334),
#  ('I vinti', 1.8833333333333333),
#  ('Way of a Gaucho', 1.45),
#  ("We're Not Married!", 1.4333333333333333),
#  ('The Wild North', 1.6166666666666667),
#  ('With a Song in My Heart', 1.95),
#  ('The World in His Arms', 1.7333333333333334),
#  ('El', 1.5333333333333334),
#  ('The 5,000 Fingers of Dr. T.', 1.4833333333333334),
#  ('Abbott and Costello Go to Mars', 1.2833333333333334),
#  ('Die Geschichte vom kleinen Muck', 1.6666666666666667),
#  ('The Actress', 1.5),
#  ('The Affairs of Dobie Gillis', 1.2),
#  ('All I Desire', 1.3333333333333333),
#  ('Love in the City', 1.9166666666666667),
#  ('Arrowhead', 1.75),
#  ('The Band Wagon', 1.8666666666666667),
#  ('Battle Circus', 1.5),
#  ('The Beast from 20,000 Fathoms', 1.3333333333333333),
#  ('The Big Heat', 1.4833333333333334),
#  ('The Bigamist', 1.3333333333333333),
#  ('Blowing Wild', 1.5),
#  ('The Blue Gardenia', 1.4166666666666667),
#  ('A Blueprint for Murder', 1.2833333333333334),
#  ('The Caddy', 1.5833333333333333),
#  ('Calamity Jane', 1.6833333333333333),
#  ('Call Me Madam', 1.9),
#  ("The Captain's Paradise", 1.5666666666666667),
#  ('City That Never Sleeps', 1.5),
#  ('Crash of Silence', 1.55),
#  ('The Cruel Sea', 2.1),
#  ('Dangerous Crossing', 1.25),
#  ('The Desert Rats', 1.4666666666666666),
#  ('Destination Gobi', 1.5),
#  ('Do Bigha Zamin', 2.183333333333333),
#  ("Donovan's Brain", 1.4),
#  ('Dream Wife', 1.6666666666666667),
#  ('Escape from Fort Bravo', 1.65),
#  ('Gentlemen Prefer Blondes', 1.5166666666666666),
#  ('A Geisha', 1.4166666666666667),
#  ('The Glass Wall', 1.3666666666666667),
#  ('Gun Fury', 1.3833333333333333),
#  ('Sawdust and Tinsel', 1.55),
#  ("His Majesty O'Keefe", 1.5166666666666666),
#  ('The Hitch-Hiker', 1.1833333333333333),
#  ('Hondo', 1.3833333333333333),
#  ('Houdini', 1.7666666666666666),
#  ('House of Wax', 1.4666666666666666),
#  ('How to Marry a Millionaire', 1.5833333333333333),
#  ('I Confess', 1.5833333333333333),
#  ('I Love Melvin', 1.2833333333333334),
#  ('Inferno', 1.3833333333333333),
#  ('Invaders from Mars', 1.3),
#  ('Island in the Sky', 1.8166666666666667),
#  ('It Came from Outer Space', 1.35),
#  ('Jeopardy', 1.15),
#  ('Gate of Hell', 1.4833333333333334),
#  ('King of the Khyber Rifles', 1.6666666666666667),
#  ('Kiss Me Kate', 1.8166666666666667),
#  ('Knights of the Round Table', 1.9166666666666667),
#  ('Miss Sadie Thompson', 1.5166666666666666),
#  ('The Mississippi Gambler', 1.65),
#  ('Mogambo', 1.9333333333333333),
#  ('Money from Home', 1.6666666666666667),
#  ('The Moon Is Blue', 1.65),
#  ('Never Let Me Go', 1.5666666666666667),
#  ('Niagara', 1.5333333333333334),
#  ('The Proud and the Beautiful', 1.7166666666666666),
#  ('Bread, Love and Dreams', 1.55),
#  ('Peter Pan', 1.2833333333333334),
#  ('Pickup on South Street', 1.3333333333333333),
#  ('Plunder of the Sun', 1.35),
#  ("The President's Lady", 1.6),
#  ('The Robe', 2.25),
#  ('Roman Holiday', 1.9666666666666666),
#  ('The Wages of Fear', 2.183333333333333),
#  ('Scared Stiff', 1.8),
#  ('Second Chance', 1.3666666666666667),
#  ('Seminole', 1.45),
#  ('Shane', 1.9666666666666666),
#  ('Small Town Girl', 1.5333333333333334),
#  ('South Sea Woman', 1.65),
#  ('Split Second', 1.4166666666666667),
#  ('Stalag 17', 2.0),
#  ('Indiscretion of an American Wife', 1.5),
#  ('The Story of Three Loves', 2.033333333333333),
#  ('The Sun Shines Bright', 1.5),
#  ('Beat the Devil', 1.4833333333333334),
#  ('The Lawless Breed', 1.3833333333333333),
#  ('Lili', 1.35),
#  ('A Lion Is in the Streets', 1.4666666666666666),
#  ('Little Fugitive', 1.3333333333333333),
#  ('The Living Desert', 1.15),
#  ('The Earrings of Madame De...', 1.75),
#  ('Malta Story', 1.7166666666666666),
#  ('The Man Between', 1.6666666666666667),
#  ('The Man from the Alamo', 1.3166666666666667),
#  ('Man on a Tightrope', 1.75),
#  ('The Count of Monte Cristo', 3.05),
#  ('Thunder Bay', 1.7166666666666666),
#  ('Thunder Over the Plains', 1.3666666666666667),
#  ('The Adultress', 1.7),
#  ('Titanic', 1.6333333333333333),
#  ('The Titfield Thunderbolt', 1.4),
#  ('Trouble Along the Way', 1.85),
#  ('Trouble in Store', 1.4166666666666667),
#  ('Journey to Italy', 1.4166666666666667),
#  ('I Vitelloni', 1.7833333333333334),
#  ('Tumbleweed', 1.3166666666666667),
#  ('Ugetsu', 1.6),
#  ('Young Bess', 1.8666666666666667),
#  ("Monsieur Hulot's Holiday", 1.9),
#  ('Skanderbeg', 1.5833333333333333),
#  ('Vesna', 1.6),
#  ('Late Chrysanthemums', 1.6833333333333333),
#  ('The Barefoot Contessa', 2.1333333333333333),
#  ('Beau Brummell', 1.8833333333333333),
#  ('Betrayed', 1.8),
#  ('Black Widow', 1.5833333333333333),
#  ('20,000 Leagues Under the Sea', 2.1166666666666667),
#  ('Wuthering Heights', 1.5166666666666666),
#  ('About Mrs. Leslie', 1.7333333333333334),
#  ('The Bridges at Toko-Ri', 1.7),
#  ('An American in Rome', 1.5666666666666667),
#  ('Anatahan', 1.5166666666666666),
#  ('Angels One Five', 1.6333333333333333),
#  ('Brigadoon', 1.8),
#  ('Broken Lance', 1.6),
#  ('The Caine Mutiny', 2.066666666666667),
#  ('Carmen Jones', 1.75),
#  ("Casanova's Big Night", 1.4333333333333333),
#  ('The Country Girl', 1.7333333333333334),
#  ('Crime Wave', 1.2166666666666666),
#  ('The Dam Busters', 2.066666666666667),
#  ('Demetrius and the Gladiators', 1.6833333333333333),
#  ('Désirée', 1.8333333333333333),
#  ('Destry', 1.5833333333333333),
#  ('School for Tramps', 1.65),
#  ('Diabolique', 1.95),
#  ('Dial M for Murder', 1.75),
#  ('Doctor in the House', 1.5333333333333334),
#  ('Down Three Dark Streets', 1.4166666666666667),
#  ('Dragnet', 1.4666666666666666),
#  ('Drive a Crooked Road', 1.3833333333333333),
#  ('Drum Beat', 1.85),
#  ('The Egyptian', 2.316666666666667),
#  ('Executive Suite', 1.7333333333333334),
#  ('The Detective', 1.5166666666666666),
#  ('French Cancan', 1.7),
#  ('Living It Up', 1.5833333333333333),
#  ('Lucky Me', 1.6666666666666667),
#  ('The Mad Magician', 1.2),
#  ('Godzilla', 1.6),
#  ('The Miracle of Marcelino', 1.5166666666666666),
#  ('Miseria e nobiltà', 1.5666666666666667),
#  ('The Story of Vickie', 1.9666666666666666),
#  ('Naked Alibi', 1.4333333333333333),
#  ('Night People', 1.55),
#  ('Twenty-Four Eyes', 2.6),
#  ('The Good Die Young', 1.6666666666666667),
#  ('Rhapsody', 1.9166666666666667),
#  ('Ride Clear of Diablo', 1.35),
#  ('On the Waterfront', 1.8),
#  ('The Gold of Naples', 2.3),
#  ('Riding Shotgun', 1.2166666666666666),
#  ('Riot in Cell Block 11', 1.3333333333333333),
#  ('River of No Return', 1.5166666666666666),
#  ('Phffft', 1.4666666666666666),
#  ('Prince Valiant', 1.6666666666666667),
#  ('Private Hell 36', 1.35),
#  ('The Purple Plain', 1.6166666666666667),
#  ('Pushover', 1.4666666666666666),
#  ('Rogue Cop', 1.5333333333333334),
#  ('The Raid', 1.3833333333333333),
#  ('Rear Window', 1.8666666666666667),
#  ('The River and Death', 1.5166666666666666),
#  ('Sabrina', 1.8833333333333333),
#  ('Salt of the Earth', 1.5666666666666667),
#  ('Sansho the Bailiff', 2.066666666666667),
#  ('Saskatchewan', 1.45),
#  ('Seven Brides for Seven Brothers', 1.7),
#  ('A Star Is Born', 2.566666666666667),
#  ('Shield for Murder', 1.3666666666666667),
#  ('The Student Prince', 1.7833333333333334),
#  ('Suddenly', 1.2833333333333334),
#  ('Susan Slept Here', 1.6333333333333333),
#  ("The Devil's General", 1.95),
#  ('Them!', 1.5666666666666667),
#  ("There's No Business Like Show Business", 1.95),
#  ('Three Cases of Murder', 1.65),
#  ('Three Hours to Kill', 1.2833333333333334),
#  ('Track of the Cat', 1.7),
#  ('Hell and High Water', 1.7166666666666666),
#  ('High and Dry', 1.5333333333333334),
#  ('The High and the Mighty', 2.45),
#  ("Hobson's Choice", 1.8),
#  ('Human Desire', 1.5166666666666666),
#  ('An Inspector Calls', 1.3333333333333333),
#  ('Knock on Wood', 1.7166666666666666),
#  ('Silver Lode', 1.35),
#  ('The Sleeping Tiger', 1.4833333333333334),
#  ('Ulysses', 1.95),
#  ('Valley of the Kings', 1.4333333333333333),
#  ('Bad Day at Black Rock', 1.35),
#  ('White Christmas', 2.0),
#  ('The Wild One', 1.3166666666666667),
#  ('Witness to Murder', 1.3833333333333333),
#  ('Sound of the Mountain', 1.5833333333333333),
#  ('Young at Heart', 1.95),
#  ('Battle Cry', 2.4833333333333334),
#  ('The Benny Goodman Story', 1.9333333333333333),
#  ('The Big Combo', 1.45),
#  ('Abbott and Costello Meet the Mummy', 1.3166666666666667),
#  ('Above Us the Waves', 1.65),
#  ('Le Amiche', 1.7333333333333334),
#  ('Big House, U.S.A.', 1.3833333333333333),
#  ('Animal Farm', 1.2),
#  ('Artists and Models', 1.8166666666666667),
#  ('The Big Knife', 1.85),
#  ('Blackboard Jungle', 1.6833333333333333),
#  ('Daddy Long Legs', 2.1),
#  ('Dementia', 0.9333333333333333),
#  ('Davy Crockett: King of the Wild Frontier', 1.55),
#  ('Bob le Flambeur', 1.6333333333333333),
#  ('A Bullet for Joey', 1.4166666666666667),
#  ('Rififi', 1.9666666666666666),
#  ('East of Eden', 1.9666666666666666),
#  ('The Far Country', 1.6166666666666667),
#  ('The Far Horizons', 1.8),
#  ('Female on the Beach', 1.6166666666666667),
#  ('Footsteps in the Fog', 1.5),
#  ('The End of the Affair', 1.75),
#  ('Wee Geordie', 1.55),
#  ('The Glass Slipper', 1.55),
#  ('The Grand Maneuver', 1.7666666666666666),
#  ('Guys and Dolls', 2.5),
#  ('Captain Lightfoot', 1.5333333333333334),
#  ('That Is the Dawn', 1.7),
#  ('Bloody Spear at Mount Fuji', 1.5666666666666667),
#  ('The Cobweb', 2.2333333333333334),
#  ('The Colditz Story', 1.5666666666666667),
#  ('City of Fear', 1.35),
#  ('Mister Roberts', 2.05),
#  ('Dreams', 1.45),
#  ('Merry-Go-Round', 1.5),
#  ('Lady and the Tramp', 1.2666666666666666),
#  ('The Ladykillers', 1.5166666666666666),
#  ('Land of the Pharaohs', 1.7666666666666666),
#  ('The Last Command', 1.8333333333333333),
#  ('A Lawless Street', 1.3),
#  ('The Left Hand of God', 1.45),
#  ('Lola Montès', 1.9333333333333333),
#  ('The Long Gray Line', 2.3),
#  ('Love Is a Many-Splendored Thing', 1.7),
#  ('Love Me or Leave Me', 2.033333333333333),
#  ('A Man Alone', 1.6),
#  ('A Man Called Peter', 1.9833333333333334),
#  ('Man with the Gun', 1.4),
#  ('Man Without a Star', 1.4833333333333334),
#  ('The Man from Laramie', 1.7166666666666666),
#  ('The Man with the Golden Arm', 1.9833333333333334),
#  ('Many Rivers to Cross', 1.5666666666666667),
#  ('Marty', 1.5),
#  ('Maksim Perepelitsa', 1.5666666666666667),
#  ('Hit the Deck', 1.8666666666666667),
#  ('House of Bamboo', 1.7),
#  ('I Died a Thousand Times', 1.8166666666666667),
#  ("I'll Cry Tomorrow", 1.95),
#  ('I Live in Fear', 1.7166666666666666),
#  ('Illegal', 1.4666666666666666),
#  ('The Indian Fighter', 1.4666666666666666),
#  ('Interrupted Melody', 1.7666666666666666),
#  ('It Came from Beneath the Sea', 1.3166666666666667),
#  ("It's Always Fair Weather", 1.6833333333333333),
#  ('Jubal', 1.6666666666666667),
#  ('The Kentuckian', 1.7333333333333334),
#  ("Killer's Kiss", 1.1166666666666667),
#  ('Kismet', 1.8833333333333333),
#  ('Kiss Me Deadly', 1.7666666666666666),
#  ('The Phenix City Story', 1.6666666666666667),
#  ('La Pointe Courte', 1.4333333333333333),
#  ('A Generation', 1.45),
#  ('The Prisoner', 1.5833333333333333),
#  ('The Private War of Major Benson', 1.75),
#  ('Queen Bee', 1.5833333333333333),
#  ('Quentin Durward', 1.7166666666666666),
#  ('Rage at Dawn', 1.45),
#  ('Rebel Without a Cause', 1.85),
#  ('The Rose Tattoo', 1.95),
#  ('Run for Cover', 1.55),
#  ('The Scarlet Coat', 1.6833333333333333),
#  ('The Sea Chase', 1.95),
#  ('The Seven Year Itch', 1.75),
#  ('Shack Out on 101', 1.3333333333333333),
#  ('Shree 420', 2.8),
#  ('Sissi', 1.7),
#  ('Soldier of Fortune', 1.6),
#  ('Smiles of a Summer Night', 1.8166666666666667),
#  ('Stella', 1.5),
#  ('Summertime', 1.65),
#  ('Tall Man Riding', 1.3833333333333333),
#  ('The Tall Men', 2.033333333333333),
#  ('Tarantula', 1.3333333333333333),
#  ('Moonfleet', 1.4),
#  ('Mr. Arkadin', 1.55),
#  ('The Naked Dawn', 1.3666666666666667),
#  ('The Naked Street', 1.4),
#  ('Ten Wanted Men', 1.3333333333333333),
#  ('Not as a Stranger', 2.25),
#  ('Tight Spot', 1.6166666666666667),
#  ('To Catch a Thief', 1.7666666666666666),
#  ('To Hell and Back', 1.7666666666666666),
#  ('Trial', 1.75),
#  ('The Trouble with Harry', 1.65),
#  ('The Unknown Soldier', 2.95),
#  ('Floating Clouds', 2.05),
#  ('Untamed', 1.85),
#  ('Wichita', 1.35),
#  ('Princess Yang Kwei-fei', 1.6333333333333333),
#  ('The Violent Men', 1.6),
#  ('Violent Saturday', 1.5),
#  ('The Virgin Queen', 1.5333333333333334),
#  ("We're No Angels", 1.7666666666666666),
#  ('Ordet', 2.1),
#  ('Our Miss Brooks', 1.4166666666666667),
#  ('Pather Panchali', 2.0833333333333335),
#  ("Too Bad She's Bad", 1.5833333333333333),
#  ('Dobrý voják Svejk', 1.8),
#  ('1984', 1.5),
#  ('23 Paces to Baker Street', 1.7166666666666666),
#  ('Street of Shame', 1.45),
#  ("The Ambassador's Daughter", 1.7166666666666666),
#  ('Anastasia', 1.75),
#  ('Anything Goes', 1.7666666666666666),
#  ('Aparajito', 1.8333333333333333),
#  ('Attack', 1.7833333333333334),
#  ('Autumn Leaves', 1.7833333333333334),
#  ('Away All Boats', 1.9),
#  ('Back from Eternity', 1.6166666666666667),
#  ('Backlash', 1.4),
#  ('The Band of Honest Men', 1.7666666666666666),
#  ('Bandido!', 1.5333333333333334),
#  ('Beyond a Reasonable Doubt', 1.3333333333333333),
#  ('Bhowani Junction', 1.8333333333333333),
#  ('Bigger Than Life', 1.5833333333333333),
#  ('The Burmese Harp', 1.9333333333333333),
#  ('The Black Sleep', 1.3666666666666667),
#  ("Raquel's Shoeshiner", 1.6833333333333333),
#  ('The Brave One', 1.6666666666666667),
#  ('Bundle of Joy', 1.6333333333333333),
#  ('The Burglar', 1.5),
#  ('Bus Stop', 1.6),
#  ('C.I.D.', 2.433333333333333),
#  ('The Rocket from Calabuch', 1.55),
#  ('Main Street', 1.65),
#  ('Carousel', 2.1333333333333333),
#  ('The Catered Affair', 1.5666666666666667),
#  ('The Cockleshell Heroes', 1.6166666666666667),
#  ('The Court Jester', 1.6833333333333333),
#  ('Crime in the Streets', 1.5166666666666666),
#  ('A Cry in the Night', 1.25),
#  ('D-Day the Sixth of June', 1.7666666666666666),
#  ('Death of a Scoundrel', 1.9833333333333334),
#  ('Gervaise', 1.8666666666666667),
#  ('Giant', 3.35),
#  ("The Girl Can't Help It", 1.65),
#  ('Good-bye, My Lady', 1.5666666666666667),
#  ('Night Ambush', 1.7333333333333334),
#  ('Invasion of the Body Snatchers', 1.3333333333333333),
#  ('Invitation to the Dance', 1.55),
#  ('Stay Alert', 2.55),
#  ('Julie', 1.65),
#  ('The Killer Is Loose', 1.2166666666666666),
#  ('The Killing', 1.4),
#  ('The King and Four Queens', 1.4333333333333333),
#  ('The King and I', 2.216666666666667),
#  ('A Kiss Before Dying', 1.5666666666666667),
#  ('A Girl in Black', 1.6666666666666667),
#  ('Lust of the Vampire', 1.3666666666666667),
#  ('The Last Frontier', 1.6333333333333333),
#  ('The Last Hunt', 1.8),
#  ('The Last Wagon', 1.65),
#  ('Love Me Tender', 1.4833333333333334),
#  ('Professor Hannibal', 1.4833333333333334),
#  ('The Harder They Fall', 1.8166666666666667),
#  ('The Captain from Köpenick', 1.55),
#  ('High Society', 1.85),
#  ('Hollywood or Bust', 1.5833333333333333),
#  ('Earth vs. the Flying Saucers', 1.3833333333333333),
#  ('The Man Who Knew Too Much', 2.0),
#  ('The Man Who Never Was', 1.7166666666666666),
#  ('The Man in the Gray Flannel Suit', 2.55),
#  ('...And God Created Woman', 1.5833333333333333),
#  ('Meet Me in Las Vegas', 1.8666666666666667),
#  ('Miracle in the Rain', 1.8),
#  ('Moby Dick', 1.9333333333333333),
#  ('The Silent World', 1.4333333333333333),
#  ('Death in the Garden', 1.7333333333333334),
#  ('The Mountain', 1.75),
#  ('The Mystery of Picasso', 1.3),
#  ('Flowing', 1.95),
#  ('Nightfall', 1.3),
#  ('Pardners', 1.5),
#  ('Patterns', 1.3833333333333333),
#  ('Please Murder Me!', 1.3),
#  ("Private's Progress", 1.7),
#  ('The Proud Ones', 1.5666666666666667),
#  ('The Quatermass Xperiment', 1.3666666666666667),
#  ('The Rack', 1.6666666666666667),
#  ('The Rainmaker', 2.0166666666666666),
#  ('Ransom!', 1.8166666666666667),
#  ('The Rawhide Years', 1.4166666666666667),
#  ('Reach for the Sky', 2.25),
#  ('Richard III', 2.683333333333333),
#  ('Rock Around the Clock', 1.2833333333333334),
#  ('Run for the Sun', 1.65),
#  ('The Fastest Gun Alive', 1.4833333333333334),
#  ('The Searchers', 1.9833333333333334),
#  ('7 Men from Now', 1.3),
#  ('Il ferroviere', 1.9166666666666667),
#  ('Sissi: The Young Empress', 1.7833333333333334),
#  ('Slightly Scarlet', 1.65),
#  ('Somebody Up There Likes Me', 1.8833333333333333),
#  ('The Forty-First', 1.4666666666666666),
#  ('Early Spring', 2.4166666666666665),
#  ('The Spanish Gardener', 1.6166666666666667),
#  ('The Flying Carpet', 1.4333333333333333),
#  ('Storm Center', 1.4166666666666667),
#  ('The Swan', 1.7333333333333334),
#  ('Tea and Sympathy', 2.033333333333333),
#  ('The Ten Commandments', 3.6666666666666665),
#  ('These Wilder Years', 1.5166666666666666),
#  ('The Third Key', 1.6),
#  ('Three Violent People', 1.6666666666666667),
#  ('Time Without Pity', 1.4166666666666667),
#  ('Time Table', 1.3333333333333333),
#  ('A Town Like Alice', 1.95),
#  ('Trapeze', 1.75),
#  ('Four Bags Full', 1.3333333333333333),
#  ('Tribute to a Bad Man', 1.5833333333333333),
#  ('A Man Escaped', 1.6833333333333333),
#  ('Up in the World', 1.45),
#  ('Forbidden Planet', 1.6333333333333333),
#  ('Vesna na Zarechnoy ulitse', 1.6),
#  ('Walk the Proud Land', 1.4666666666666666),
#  ('War and Peace', 3.466666666666667),
#  ('The Werewolf', 1.3166666666666667),
#  ('X the Unknown', 1.35),
#  ('Forever, Darling', 1.6),
#  ('Friendly Persuasion', 2.283333333333333),
#  ('Cast a Dark Shadow', 1.3666666666666667),
#  ('12 Angry Men', 1.6),
#  ('20 Million Miles to Earth', 1.3666666666666667),
#  ('The 27th Day', 1.25),
#  ('3:10 to Yuma', 1.5333333333333334),
#  ('Seven Days from Now', 1.6666666666666667),
#  ('The Abominable Snowman', 1.5166666666666666),
#  ('Across the Bridge', 1.7166666666666666),
#  ('Paradise Lagoon', 1.5666666666666667),
#  ('The Chaplin Revue', 2.1333333333333333),
#  ('Montparnasse 19', 1.8),
#  ('Bitter Victory', 1.7),
#  ('Baby Face Nelson', 1.4166666666666667),
#  ('The Bachelor Party', 1.5333333333333334),
#  ('The Sun Legend of the End of the Tokugawa Era', 1.8333333333333333),
#  ('Band of Angels', 2.0833333333333335),
#  ('Battle Hymn', 1.8),
#  ('Mother India', 2.8666666666666667),
#  ('Chase a Crooked Shadow', 1.4666666666666666),
#  ('Boy on a Dolphin', 1.85),
#  ('The Brothers Rico', 1.5333333333333334),
#  ("Campbell's Kingdom", 1.7),
#  ('The Enemy Below', 1.6333333333333333),
#  ('Eroica', 1.45),
#  ('Les espions', 2.0833333333333335),
#  ('A Face in the Crowd', 2.1),
#  ('Fiend Without a Face', 1.25),
#  ('Fire Down Below', 1.9333333333333333),
#  ('Fools in the Mountains', 1.5),
#  ('Forty Guns', 1.3333333333333333),
#  ('Funny Face', 1.7166666666666666),
#  ('The Mysterians', 1.4833333333333334),
#  ('China Gate', 1.6166666666666667),
#  ('La grande strada azzurra', 1.7166666666666666),
#  ('The Green Man', 1.3333333333333333),
#  ('Gun Glory', 1.4833333333333334),
#  ('Gunfight at the O.K. Corral', 2.033333333333333),
#  ('The Guns of Fort Petticoat', 1.3666666666666667),
#  ('A Hatful of Rain', 1.8166666666666667),
#  ('Heaven Knows, Mr. Allison', 1.7833333333333334),
#  ('The Helen Morgan Story', 1.9666666666666666),
#  ('Crime of Passion', 1.4333333333333333),
#  ('Island in the Sun', 1.9833333333333334),
#  ('Jailhouse Rock', 1.6),
#  ('Jeanne Eagels', 1.8),
#  ('Johnny Tremain', 1.3333333333333333),
#  ('Just My Luck', 1.4333333333333333),
#  ('Kanal', 1.5166666666666666),
#  ('A King in New York', 1.8333333333333333),
#  ('Throne of Blood', 1.8333333333333333),
#  ('The Incredible Shrinking Man', 1.35),
#  ('Les Girls', 1.9),
#  ('The Cranes Are Flying', 1.5833333333333333),
#  ('The Lonely Man', 1.4666666666666666),
#  ('Love in the Afternoon', 2.1666666666666665),
#  ('Loving You', 1.6833333333333333),
#  ('Lucky Jim', 1.5833333333333333),
#  ('Madhumati', 1.8333333333333333),
#  ('The Curse of Frankenstein', 1.3666666666666667),
#  ('Inspector Maigret', 1.9833333333333334),
#  ('Man of a Thousand Faces', 2.033333333333333),
#  ('The D.I.', 1.7666666666666666),
#  ('Men in War', 1.7),
#  ('Mon Oncle', 1.9333333333333333),
#  ('The Monolith Monsters', 1.2833333333333334),
#  ('Decision at Sundown', 1.2833333333333334),
#  ('My Man Godfrey', 1.5333333333333334),
#  ('The Devil Strikes at Night', 1.75),
#  ('Naya Daur', 2.8833333333333333),
#  ('Nine Lives', 1.6),
#  ('Night Passage', 1.5),
#  ('No Down Payment', 1.75),
#  ('Not of This Earth', 1.1166666666666667),
#  ('The Hunchback of Notre Dame', 1.9166666666666667),
#  ('Le Notti Bianche', 1.7),
#  ('The Nights of Cabiria', 1.8333333333333333),
#  ('Old Yeller', 1.3833333333333333),
#  ('The One That Got Away', 1.7666666666666666),
#  ('Operation Mad Ball', 1.75),
#  ('The Pajama Game', 1.6833333333333333),
#  ('Pal Joey', 1.85),
#  ('Paths of Glory', 1.4666666666666666),
#  ('The Delicate Delinquent', 1.6833333333333333),
#  ('Peyton Place', 2.6166666666666667),
#  ('Plunder Road', 1.2),
#  ('I Dutifully Report', 1.5166666666666666),
#  ('Pyaasa', 2.433333333333333),
#  ('Raintree County', 2.6666666666666665),
#  ('The Revenge of Frankenstein', 1.5),
#  ('The Ride Back', 1.3166666666666667),
#  ("The River's Edge", 1.45),
#  ('Run of the Arrow', 1.4333333333333333),
#  ('Designing Woman', 1.9666666666666666),
#  ('Saddle the Wind', 1.4),
#  ('Sayonara', 2.45),
#  ('Desk Set', 1.7166666666666666),
#  ('Do Ankhen Barah Haath', 2.3833333333333333),
#  ('Silk Stockings', 1.95),
#  ('The Seventh Seal', 1.6),
#  ('Big Time Operators', 1.3333333333333333),
#  ('Wild Strawberries', 1.5166666666666666),
#  ('Something of Value', 1.8833333333333333),
#  ('The Story of Esther Costello', 1.7166666666666666),
#  ('The Sun Also Rises', 2.1666666666666665),
#  ('Sweet Smell of Success', 1.6),
#  ('The Tall Stranger', 1.35),
#  ('Tammy and the Bachelor', 1.4833333333333334),
#  ('The Tarnished Angels', 1.5166666666666666),
#  ('A Matter of Dignity', 1.8666666666666667),
#  ('The Three Faces of Eve', 1.5166666666666666),
#  ('Tikhiy Don', 5.5),
#  ('Time Limit', 1.6),
#  ('The Tin Star', 1.55),
#  ('Tizoc (Amor indio)', 1.8166666666666667),
#  ('Tokyo Twilight', 2.3333333333333335),
#  ('Trooper Hook', 1.35),
#  ('The True Story of Jesse James', 1.5333333333333334),
#  ('La Parisienne', 1.4333333333333333),
#  ('Until They Sail', 1.5666666666666667),
#  ('El vampiro', 1.5833333333333333),
#  ('Doctor at Large', 1.7333333333333334),
#  ('Wild Is the Wind', 1.9),
#  ('Will Success Spoil Rock Hunter?', 1.55),
#  ('Das Wirtshaus im Spessart', 1.65),
#  ('Witness for the Prosecution', 1.9333333333333333),
#  ('The Wrong Man', 1.75),
#  ('Don Kikhot', 1.8333333333333333),
#  ("Don't Go Near the Water", 1.7833333333333334),
#  ('The Lower Depths', 2.283333333333333),
#  ('The Bravados', 1.6333333333333333),
#  ('The Buccaneer', 1.9833333333333334),
#  ('Buchanan Rides Alone', 1.3333333333333333),
#  ('Carry on Nurse', 1.4333333333333333),
#  ('Carry On Sergeant', 1.4),
#  ('Cat on a Hot Tin Roof', 1.8),
#  ('The 7th Voyage of Sinbad', 1.4666666666666666),
#  ('Bandini', 2.6166666666666667),
#  ('Christine', 1.6666666666666667),
#  ('Araya', 1.5),
#  ('Elevator to the Gallows', 1.5166666666666666),
#  ('Auntie Mame', 2.3833333333333333),
#  ('Cairo Station', 1.2833333333333334),
#  ('The Badlanders', 1.4166666666666667),
#  ('Bell Book and Candle', 1.7666666666666666),
#  ('The Big Country', 2.7666666666666666),
#  ('The H-Man', 1.45),
#  ('The Blob', 1.4333333333333333),
#  ("Blue Murder at St. Trinian's", 1.4333333333333333),
#  ('Bonjour Tristesse', 1.5666666666666667),
#  ('Corridors of Blood', 1.4333333333333333),
#  ('Horror of Dracula', 1.3666666666666667),
#  ('Dunkirk', 2.25),
#  ('Lake of the Dead', 1.2666666666666666),
#  ('Love Is My Profession', 1.75),
#  ('Conflagration', 1.65),
#  ('Fanfare', 1.4333333333333333),
#  ('The Fearmakers', 1.4166666666666667),
#  ('The Fly', 1.5666666666666667),
#  ('Fort Dobbs', 1.55),
#  ('Fort Massacre', 1.3333333333333333),
#  ('From Hell to Texas', 1.6666666666666667),
#  ('Career', 1.75),
#  ('The Geisha Boy', 1.6333333333333333),
#  ('Cowboy', 1.5333333333333334),
#  ('Gideon of Scotland Yard', 1.5166666666666666),
#  ('Gigi', 1.9166666666666667),
#  ("God's Little Acre", 1.9666666666666666),
#  ('The Goddess', 1.7333333333333334),
#  ('The Gunfight at Dodge City', 1.35),
#  ('H-8...', 1.75),
#  ('The Haunted Strangler', 1.3),
#  ('Hell Drivers', 1.8),
#  ('Home Before Dark', 2.2666666666666666),
#  ('The Idiot', 2.066666666666667),
#  ('Imitation General', 1.4666666666666666),
#  ('Indiscreet', 1.6666666666666667),
#  ('It! The Terror from Beyond Space', 1.15),
#  ('Ivan the Terrible, Part II', 1.4666666666666666),
#  ('The Music Room', 1.6666666666666667),
#  ('The Hidden Fortress', 2.316666666666667),
#  ('The Key', 2.2333333333333334),
#  ('King Creole', 1.9333333333333333),
#  ('Kings Go Forth', 1.8166666666666667),
#  ('The Law and Jake Wade', 1.4333333333333333),
#  ('The Law Is the Law', 1.5833333333333333),
#  ('The Law', 2.1),
#  ("The Horse's Mouth", 1.6166666666666667),
#  ('House on Haunted Hill', 1.25),
#  ('Houseboat', 1.8333333333333333),
#  ('The Hunters', 1.8),
#  ('I Bury the Living', 1.2833333333333334),
#  ('I Married a Monster from Outer Space', 1.3),
#  ('I Want to Live!', 2.0),
#  ('The Long, Hot Summer', 1.9166666666666667),
#  ('Look Back in Anger', 1.6333333333333333),
#  ('Machine-Gun Kelly', 1.3333333333333333),
#  ('Man of the West', 1.6666666666666667),
#  ('Marjorie Morningstar', 2.1333333333333333),
#  ('Me and the Colonel', 1.8166666666666667),
#  ('Merry Andrew', 1.7166666666666666),
#  ('We Only Live Once', 1.85),
#  ('Moi, un noir', 1.1666666666666667),
#  ('The Rickshaw Man', 1.7166666666666666),
#  ('Murder by Contract', 1.35),
#  ('Mädchen in Uniform', 1.5833333333333333),
#  ('The Naked and the Dead', 2.183333333333333),
#  ('Nazarin', 1.5666666666666667),
#  ('Neither Seen Nor Recognized', 1.5833333333333333),
#  ('A Night to Remember', 2.05),
#  ('No Name on the Bullet', 1.2833333333333334),
#  ('No Time for Sergeants', 1.9833333333333334),
#  ('Brink of Life', 1.4),
#  ('Paras-Pathar', 1.85),
#  ('Party Girl', 1.65),
#  ('The Perfect Furlough', 1.55),
#  ('The Noose', 1.6),
#  ('The Little Apartment', 1.45),
#  ('Cry Terror!', 1.6),
#  ('Ashes and Diamonds', 1.7166666666666666),
#  ('The Proud Rebel', 1.7166666666666666),
#  ('The Quiet American', 2.0),
#  ("Rally 'Round the Flag, Boys!", 1.7666666666666666),
#  ('The Reluctant Debutante', 1.5666666666666667),
#  ('Ride a Crooked Trail', 1.4666666666666666),
#  ('Rock-a-Bye Baby', 1.7166666666666666),
#  ('The Roots of Heaven', 2.1),
#  ('Run Silent Run Deep', 1.55),
#  ('The Snorkel', 1.5),
#  ('Some Came Running', 2.283333333333333),
#  ('South Pacific', 2.6166666666666667),
#  ('The Square Peg', 1.4166666666666667),
#  ...]

# %% [markdown]
# ```{admonition} iclicker: Will the following query work ?
#
#     SELECT
#         title,
#         runtime / 60::REAL AS runtime_hours
#     FROM
#         movies
#         where runtime_hours > 2;
#
# A) YES
#
# B) NO
#
# ```

# %% [markdown]
# ```{toggle}
# NO. Look at the order of execution.
#
# So explicitly specify the derived column name as runtime / 60::REAL in WHERE Clause. Check below:
#
# ```sql
# SELECT
#     title,
#     runtime / 60::REAL AS runtime_hours
# FROM
#     movies
#     where runtime / 60::REAL > 2;
# ```

# %% [markdown]
# ## Case statement
#
# Concept just like the case statement that you learned in R. But the syntax is quite different.

# %%
# %%sql
#
# SELECT
#     title,
#     runtime,
#     CASE
#         WHEN runtime > 90 THEN 'long'
#         WHEN runtime BETWEEN 30 AND 90 THEN 'normal'
#         ELSE 'short'
#     END AS duration
# FROM
#     movies
# ;
# Out:
#  * postgresql://postgres:***@localhost:5432/imdb
# 26058 rows affected.
# [('Kate & Leopold', 118, 'long'),
#  ('Mister 880', 90, 'normal'),
#  ('Black Hand', 92, 'long'),
#  ('Francis', 91, 'long'),
#  ('Orpheus', 95, 'long'),
#  ('Stromboli', 107, 'long'),
#  ('Woman in Hiding', 92, 'long'),
#  ('Abbott and Costello in the Foreign Legion', 80, 'normal'),
#  ('Annie Get Your Gun', 107, 'long'),
#  ('Armored Car Robbery', 67, 'normal'),
#  ('The Asphalt Jungle', 112, 'long'),
#  ('Atom Man vs. Superman', 252, 'long'),
#  ('Backfire', 91, 'long'),
#  ('The Baron of Arizona', 97, 'long'),
#  ('The Big Lift', 120, 'long'),
#  ('The Black Rose', 120, 'long'),
#  ('The Blue Lamp', 84, 'normal'),
#  ('Borderline', 88, 'normal'),
#  ('Born to Be Bad', 94, 'long'),
#  ('Branded', 104, 'long'),
#  ('Bright Leaf', 110, 'long'),
#  ('Caged', 96, 'long'),
#  ('The Cariboo Trail', 81, 'normal'),
#  ('Champagne for Caesar', 99, 'long'),
#  ('Cinderella', 74, 'normal'),
#  ('The Clouded Yellow', 95, 'long'),
#  ('Colt .45', 74, 'normal'),
#  ('Convicted', 91, 'long'),
#  ('Copper Canyon', 84, 'normal'),
#  ('Crisis', 95, 'long'),
#  ('Story of a Love Affair', 98, 'long'),
#  ('Cyrano de Bergerac', 113, 'long'),
#  ('Dallas', 94, 'long'),
#  ("The Damned Don't Cry", 103, 'long'),
#  ('Dark City', 98, 'long'),
#  ('Destination Moon', 92, 'long'),
#  ('Destination Murder', 72, 'normal'),
#  ("Devil's Doorway", 84, 'normal'),
#  ('Dial 1119', 75, 'normal'),
#  ('Fancy Pants', 92, 'long'),
#  ('Father of the Bride', 92, 'long'),
#  ('The Flame and the Arrow', 88, 'normal'),
#  ('The Fuller Brush Girl', 85, 'normal'),
#  ('The Furies', 109, 'long'),
#  ('The Glass Menagerie', 107, 'long'),
#  ('Gone to Earth', 110, 'long'),
#  ('The Great Rupert', 87, 'normal'),
#  ('Gun Crazy', 87, 'normal'),
#  ('The Gunfighter', 85, 'normal'),
#  ('The Happy Years', 110, 'long'),
#  ('Harriet Craig', 94, 'long'),
#  ('Harvey', 104, 'long'),
#  ('House by the River', 83, 'normal'),
#  ('In a Lonely Place', 94, 'long'),
#  ('The Jackie Robinson Story', 77, 'normal'),
#  ('The Jackpot', 85, 'normal'),
#  ('Diary of a Country Priest', 115, 'long'),
#  ('Key to the City', 101, 'long'),
#  ('Kim', 113, 'long'),
#  ("King Solomon's Mines", 103, 'long'),
#  ('Kiss Tomorrow Goodbye', 102, 'long'),
#  ('Kon-Tiki', 77, 'normal'),
#  ('A Lady Without Passport', 74, 'normal'),
#  ('Last Holiday', 88, 'normal'),
#  ('A Life of Her Own', 108, 'long'),
#  ('Variety Lights', 97, 'long'),
#  ('Ma and Pa Kettle Go to Town', 79, 'normal'),
#  ('Madeleine', 114, 'long'),
#  ('The Magnificent Yankee', 89, 'normal'),
#  ('The Man Who Cheated Himself', 81, 'normal'),
#  ('The Men', 85, 'normal'),
#  ('The Miniver Story', 104, 'long'),
#  ('Montana', 76, 'normal'),
#  ('Trio', 91, 'long'),
#  ('Mystery Street', 93, 'long'),
#  ('The Nevadan', 81, 'normal'),
#  ('The Next Voice You Hear...', 83, 'normal'),
#  ('Night and the City', 101, 'long'),
#  ('No Way Out', 106, 'long'),
#  ('The Young and the Damned', 85, 'normal'),
#  ('Operation Disaster', 102, 'long'),
#  ('Outrage', 75, 'normal'),
#  ('Panic in the Streets', 96, 'long'),
#  ('Quicksand', 79, 'normal'),
#  ('Rashomon', 88, 'normal'),
#  ('Rio Grande', 105, 'long'),
#  ('Rocky Mountain', 83, 'normal'),
#  ('La Ronde', 93, 'long'),
#  ('The Secret Fury', 85, 'normal'),
#  ('September Affair', 104, 'long'),
#  ('Seven Days to Noon', 94, 'long'),
#  ('Shadow on the Wall', 84, 'normal'),
#  ('Side Street', 83, 'normal'),
#  ('Sierra', 83, 'normal'),
#  ('Stage Fright', 110, 'long'),
#  ('Stars in My Crown', 89, 'normal'),
#  ('Sunset Blvd.', 110, 'long'),
#  ('Susana', 86, 'normal'),
#  ('Tea for Two', 98, 'long'),
#  ('Three Came Home', 106, 'long'),
#  ('Three Little Words', 102, 'long'),
#  ('To Joy', 98, 'long'),
#  ('To Please a Lady', 91, 'long'),
#  ('The Toast of New Orleans', 97, 'long'),
#  ('Treasure Island', 96, 'long'),
#  ('The Sound of Fury', 91, 'long'),
#  ('Two Flags West', 92, 'long'),
#  ('Two Weeks with Love', 90, 'normal'),
#  ('The Underworld Story', 91, 'long'),
#  ('Wagon Master', 86, 'normal'),
#  ('Walk Softly, Stranger', 81, 'normal'),
#  ('The West Point Story', 107, 'long'),
#  ('When Willie Comes Marching Home', 82, 'normal'),
#  ('Where the Sidewalk Ends', 95, 'long'),
#  ('The White Tower', 98, 'long'),
#  ("Winchester '73", 92, 'long'),
#  ('Woman on the Run', 77, 'normal'),
#  ('The Wooden Horse', 101, 'long'),
#  ('Boot Polish', 149, 'long'),
#  ('A.T.M.: ¡¡A toda máquina!!', 120, 'long'),
#  ('Across the Wide Missouri', 78, 'normal'),
#  ('The African Queen', 105, 'long'),
#  ('Alice in Wonderland', 75, 'normal'),
#  ('An American in Paris', 114, 'long'),
#  ('Angels in the Outfield', 99, 'long'),
#  ('Anne of the Indies', 81, 'normal'),
#  ('Appointment with Danger', 90, 'normal'),
#  ('As Young as You Feel', 77, 'normal'),
#  ('The Red Inn', 98, 'long'),
#  ('Awaara', 193, 'long'),
#  ('Early Summer', 125, 'long'),
#  ('The Big Night', 75, 'normal'),
#  ('Bright Victory', 97, 'long'),
#  ('The Browning Version', 90, 'normal'),
#  ('Callaway Went Thataway', 81, 'normal'),
#  ('Captain Horatio Hornblower R.N.', 117, 'long'),
#  ("Casque d'Or", 96, 'long'),
#  ('The Cimarron Kid', 84, 'normal'),
#  ('The Emperor and the Golem', 144, 'long'),
#  ("Comin' Round the Mountain", 77, 'normal'),
#  ('Cry Danger', 79, 'normal'),
#  ('Cry, the Beloved Country', 103, 'long'),
#  ('David and Bathsheba', 116, 'long'),
#  ('Death of a Salesman', 115, 'long'),
#  ('Decision Before Dawn', 119, 'long'),
#  ('The Desert Fox: The Story of Rommel', 88, 'normal'),
#  ('Detective Story', 103, 'long'),
#  ("Europe '51", 118, 'long'),
#  ('Five', 93, 'long'),
#  ('Flying Leathernecks', 102, 'long'),
#  ('Fort Worth', 80, 'normal'),
#  ('Fourteen Hours', 92, 'long'),
#  ('The Frogmen', 96, 'long'),
#  ('Miss Julie', 90, 'normal'),
#  ('The Great Caruso', 109, 'long'),
#  ('Guardie e ladri', 105, 'long'),
#  ('The Idiot', 166, 'long'),
#  ('He Ran All the Way', 77, 'normal'),
#  ('Here Comes the Groom', 113, 'long'),
#  ('His Kind of Woman', 120, 'long'),
#  ('One Summer of Happiness', 103, 'long'),
#  ('The Hoodlum', 61, 'normal'),
#  ('The House on Telegraph Hill', 93, 'long'),
#  ("I'll Never Forget You", 90, 'normal'),
#  ("I'll See You in My Dreams", 110, 'long'),
#  ('Forbidden Games', 86, 'normal'),
#  ('Jim Thorpe -- All-American', 107, 'long'),
#  ('Kekec', 97, 'long'),
#  ('Kind Lady', 78, 'normal'),
#  ('Laughter in Paradise', 93, 'long'),
#  ("Let's Make It Legal", 77, 'normal'),
#  ('Lone Star', 94, 'long'),
#  ('Love Nest', 84, 'normal'),
#  ('M', 88, 'normal'),
#  ('The Magic Box', 118, 'long'),
#  ('Man in the Saddle', 87, 'normal'),
#  ('The Mating Season', 101, 'long'),
#  ('Meshi', 97, 'long'),
#  ('The Mob', 87, 'normal'),
#  ('A Woman Without Love', 85, 'normal'),
#  ('The Lady of Musashino', 88, 'normal'),
#  ('My Favorite Spy', 93, 'long'),
#  ('No Questions Asked', 80, 'normal'),
#  ('Odette', 124, 'long'),
#  ('Has Anybody Seen My Gal', 88, 'normal'),
#  ('On Dangerous Ground', 82, 'normal'),
#  ('On Moonlight Bay', 95, 'long'),
#  ('On the Riviera', 89, 'normal'),
#  ('Only the Valiant', 105, 'long'),
#  ('Miss Oyu', 94, 'long'),
#  ('Pandora and the Flying Dutchman', 122, 'long'),
#  ('Pathala Bhairavi', 192, 'long'),
#  ('Payment on Demand', 90, 'normal'),
#  ("The People Against O'Hara", 102, 'long'),
#  ('The Little World of Don Camillo', 107, 'long'),
#  ('A Place in the Sun', 122, 'long'),
#  ('La Poison', 85, 'normal'),
#  ('The Prowler', 92, 'long'),
#  ('Quo Vadis', 171, 'long'),
#  ('The Racket', 88, 'normal'),
#  ('Rawhide', 89, 'normal'),
#  ('The Red Badge of Courage', 69, 'normal'),
#  ('Rhubarb', 94, 'long'),
#  ('The River', 99, 'long'),
#  ('Roadblock', 73, 'normal'),
#  ('Royal Wedding', 93, 'long'),
#  ('Sailor Beware', 108, 'long'),
#  ('Santa Fe', 87, 'normal'),
#  ('A Christmas Carol', 86, 'normal'),
#  ('Sealed Cargo', 90, 'normal'),
#  ('The Secret of Convict Lake', 83, 'normal'),
#  ('Show Boat', 108, 'long'),
#  ('Sirocco', 98, 'long'),
#  ('Summer Interlude', 96, 'long'),
#  ('The Steel Helmet', 85, 'normal'),
#  ('Storm Warning', 93, 'long'),
#  ('The Strange Door', 81, 'normal'),
#  ('A Streetcar Named Desire', 122, 'long'),
#  ('The Strip', 85, 'normal'),
#  ('The Tall Target', 78, 'normal'),
#  ('Ten Tall Men', 97, 'long'),
#  ('The Thing from Another World', 87, 'normal'),
#  ('Three Guys Named Mike', 90, 'normal'),
#  ('Thunder on the Hill', 84, 'normal'),
#  ('Tomahawk', 82, 'normal'),
#  ('Man of Straw', 109, 'long'),
#  ('Der Verlorene', 98, 'long'),
#  ('The Well', 86, 'normal'),
#  ('Westward the Women', 118, 'long'),
#  ('You Never Can Tell', 78, 'normal'),
#  ('5 Fingers', 108, 'long'),
#  ('Above and Beyond', 122, 'long'),
#  ('Affair in Trinidad', 98, 'long'),
#  ('Against All Flags', 84, 'normal'),
#  ('Androcles and the Lion', 98, 'long'),
#  ('Angel Face', 91, 'long'),
#  ("Another Man's Poison", 90, 'normal'),
#  ('April in Paris', 100, 'long'),
#  ("At Sword's Point", 81, 'normal'),
#  ('Robinson Crusoe', 90, 'normal'),
#  ('The Bad and the Beautiful', 118, 'long'),
#  ('The Battle at Apache Pass', 85, 'normal'),
#  ('The Belle of New York', 82, 'normal'),
#  ('Beauties of the Night', 87, 'normal'),
#  ('Belles on Their Toes', 89, 'normal'),
#  ('Bend of the River', 91, 'long'),
#  ('Beware, My Lovely', 77, 'normal'),
#  ('The Big Sky', 140, 'long'),
#  ('The Black Castle', 82, 'normal'),
#  ('Blackbeard, the Pirate', 99, 'long'),
#  ('Struggle in the Valley', 105, 'long'),
#  ('The Sound Barrier', 118, 'long'),
#  ('El bruto', 81, 'normal'),
#  ('The Captive City', 91, 'long'),
#  ('Carbine Williams', 92, 'long'),
#  ('Carrie', 118, 'long'),
#  ('Carson City', 87, 'normal'),
#  ('Children of Hiroshima', 97, 'long'),
#  ('Clash by Night', 105, 'long'),
#  ('White Mane', 47, 'normal'),
#  ('Deadline - U.S.A.', 87, 'normal'),
#  ('Diplomatic Courier', 97, 'long'),
#  ("Don't Bother to Knock", 76, 'normal'),
#  ('Dreamboat', 83, 'normal'),
#  ('The Duel at Silver Creek', 77, 'normal'),
#  ('The Greatest Show on Earth', 152, 'long'),
#  ('The Green Glove', 89, 'normal'),
#  ("Hangman's Knot", 81, 'normal'),
#  ('Hans Christian Andersen', 112, 'long'),
#  ('High Noon', 85, 'normal'),
#  ('The Holly and the Ivy', 83, 'normal'),
#  ('Ikiru', 143, 'long'),
#  ('Ivanhoe', 106, 'long'),
#  ('Jumping Jacks', 96, 'long'),
#  ('Kansas City Confidential', 99, 'long'),
#  ('Kvinnors väntan', 107, 'long'),
#  ('The Lavender Hill Mob', 78, 'normal'),
#  ('Limelight', 137, 'long'),
#  ('The Long Memory', 96, 'long'),
#  ('Lost in Alaska', 76, 'normal'),
#  ('Lovely to Look At', 103, 'long'),
#  ('The Lusty Men', 113, 'long'),
#  ('Macao', 81, 'normal'),
#  ('The Man in the White Suit', 85, 'normal'),
#  ('The Marrying Kind', 92, 'long'),
#  ('The Member of the Wedding', 93, 'long'),
#  ('The Miracle of Our Lady of Fatima', 102, 'long'),
#  ('Les Miserables', 105, 'long'),
#  ('Monkey Business', 97, 'long'),
#  ('Moulin Rouge', 119, 'long'),
#  ('My Cousin Rachel', 98, 'long'),
#  ('The Naked Spur', 91, 'long'),
#  ('The Narrow Margin', 71, 'normal'),
#  ('The Flavor of Green Tea Over Rice', 116, 'long'),
#  ('Mother', 98, 'long'),
#  ('Park Row', 83, 'normal'),
#  ('Pat and Mike', 95, 'long'),
#  ('Plymouth Adventure', 105, 'long'),
#  ('Pony Soldier', 82, 'normal'),
#  ('The Pride of St. Louis', 93, 'long'),
#  ('The Prisoner of Zenda', 96, 'long'),
#  ('The Promoter', 85, 'normal'),
#  ('The Quiet Man', 129, 'long'),
#  ('Rancho Notorious', 89, 'normal'),
#  ('The Return of Don Camillo', 115, 'long'),
#  ('The Ring', 79, 'normal'),
#  ('Room for One More', 98, 'long'),
#  ('Ruby Gentry', 82, 'normal'),
#  ('Scaramouche', 115, 'long'),
#  ("Singin' in the Rain", 103, 'long'),
#  ('The Snows of Kilimanjaro', 114, 'long'),
#  ('Springfield Rifle', 93, 'long'),
#  ('The Star', 89, 'normal'),
#  ('The Steel Trap', 85, 'normal'),
#  ('Stolen Face', 72, 'normal'),
#  ('The Stooge', 100, 'long'),
#  ('The Stranger in Between', 84, 'normal'),
#  ('Talk About a Stranger', 65, 'normal'),
#  ('The Thief', 86, 'normal'),
#  ('Umberto D.', 89, 'normal'),
#  ('I vinti', 113, 'long'),
#  ('Way of a Gaucho', 87, 'normal'),
#  ("We're Not Married!", 86, 'normal'),
#  ('The Wild North', 97, 'long'),
#  ('With a Song in My Heart', 117, 'long'),
#  ('The World in His Arms', 104, 'long'),
#  ('El', 92, 'long'),
#  ('The 5,000 Fingers of Dr. T.', 89, 'normal'),
#  ('Abbott and Costello Go to Mars', 77, 'normal'),
#  ('Die Geschichte vom kleinen Muck', 100, 'long'),
#  ('The Actress', 90, 'normal'),
#  ('The Affairs of Dobie Gillis', 72, 'normal'),
#  ('All I Desire', 80, 'normal'),
#  ('Love in the City', 115, 'long'),
#  ('Arrowhead', 105, 'long'),
#  ('The Band Wagon', 112, 'long'),
#  ('Battle Circus', 90, 'normal'),
#  ('The Beast from 20,000 Fathoms', 80, 'normal'),
#  ('The Big Heat', 89, 'normal'),
#  ('The Bigamist', 80, 'normal'),
#  ('Blowing Wild', 90, 'normal'),
#  ('The Blue Gardenia', 85, 'normal'),
#  ('A Blueprint for Murder', 77, 'normal'),
#  ('The Caddy', 95, 'long'),
#  ('Calamity Jane', 101, 'long'),
#  ('Call Me Madam', 114, 'long'),
#  ("The Captain's Paradise", 94, 'long'),
#  ('City That Never Sleeps', 90, 'normal'),
#  ('Crash of Silence', 93, 'long'),
#  ('The Cruel Sea', 126, 'long'),
#  ('Dangerous Crossing', 75, 'normal'),
#  ('The Desert Rats', 88, 'normal'),
#  ('Destination Gobi', 90, 'normal'),
#  ('Do Bigha Zamin', 131, 'long'),
#  ("Donovan's Brain", 84, 'normal'),
#  ('Dream Wife', 100, 'long'),
#  ('Escape from Fort Bravo', 99, 'long'),
#  ('Gentlemen Prefer Blondes', 91, 'long'),
#  ('A Geisha', 85, 'normal'),
#  ('The Glass Wall', 82, 'normal'),
#  ('Gun Fury', 83, 'normal'),
#  ('Sawdust and Tinsel', 93, 'long'),
#  ("His Majesty O'Keefe", 91, 'long'),
#  ('The Hitch-Hiker', 71, 'normal'),
#  ('Hondo', 83, 'normal'),
#  ('Houdini', 106, 'long'),
#  ('House of Wax', 88, 'normal'),
#  ('How to Marry a Millionaire', 95, 'long'),
#  ('I Confess', 95, 'long'),
#  ('I Love Melvin', 77, 'normal'),
#  ('Inferno', 83, 'normal'),
#  ('Invaders from Mars', 78, 'normal'),
#  ('Island in the Sky', 109, 'long'),
#  ('It Came from Outer Space', 81, 'normal'),
#  ('Jeopardy', 69, 'normal'),
#  ('Gate of Hell', 89, 'normal'),
#  ('King of the Khyber Rifles', 100, 'long'),
#  ('Kiss Me Kate', 109, 'long'),
#  ('Knights of the Round Table', 115, 'long'),
#  ('Miss Sadie Thompson', 91, 'long'),
#  ('The Mississippi Gambler', 99, 'long'),
#  ('Mogambo', 116, 'long'),
#  ('Money from Home', 100, 'long'),
#  ('The Moon Is Blue', 99, 'long'),
#  ('Never Let Me Go', 94, 'long'),
#  ('Niagara', 92, 'long'),
#  ('The Proud and the Beautiful', 103, 'long'),
#  ('Bread, Love and Dreams', 93, 'long'),
#  ('Peter Pan', 77, 'normal'),
#  ('Pickup on South Street', 80, 'normal'),
#  ('Plunder of the Sun', 81, 'normal'),
#  ("The President's Lady", 96, 'long'),
#  ('The Robe', 135, 'long'),
#  ('Roman Holiday', 118, 'long'),
#  ('The Wages of Fear', 131, 'long'),
#  ('Scared Stiff', 108, 'long'),
#  ('Second Chance', 82, 'normal'),
#  ('Seminole', 87, 'normal'),
#  ('Shane', 118, 'long'),
#  ('Small Town Girl', 92, 'long'),
#  ('South Sea Woman', 99, 'long'),
#  ('Split Second', 85, 'normal'),
#  ('Stalag 17', 120, 'long'),
#  ('Indiscretion of an American Wife', 90, 'normal'),
#  ('The Story of Three Loves', 122, 'long'),
#  ('The Sun Shines Bright', 90, 'normal'),
#  ('Beat the Devil', 89, 'normal'),
#  ('The Lawless Breed', 83, 'normal'),
#  ('Lili', 81, 'normal'),
#  ('A Lion Is in the Streets', 88, 'normal'),
#  ('Little Fugitive', 80, 'normal'),
#  ('The Living Desert', 69, 'normal'),
#  ('The Earrings of Madame De...', 105, 'long'),
#  ('Malta Story', 103, 'long'),
#  ('The Man Between', 100, 'long'),
#  ('The Man from the Alamo', 79, 'normal'),
#  ('Man on a Tightrope', 105, 'long'),
#  ('The Count of Monte Cristo', 183, 'long'),
#  ('Thunder Bay', 103, 'long'),
#  ('Thunder Over the Plains', 82, 'normal'),
#  ('The Adultress', 102, 'long'),
#  ('Titanic', 98, 'long'),
#  ('The Titfield Thunderbolt', 84, 'normal'),
#  ('Trouble Along the Way', 111, 'long'),
#  ('Trouble in Store', 85, 'normal'),
#  ('Journey to Italy', 85, 'normal'),
#  ('I Vitelloni', 107, 'long'),
#  ('Tumbleweed', 79, 'normal'),
#  ('Ugetsu', 96, 'long'),
#  ('Young Bess', 112, 'long'),
#  ("Monsieur Hulot's Holiday", 114, 'long'),
#  ('Skanderbeg', 95, 'long'),
#  ('Vesna', 96, 'long'),
#  ('Late Chrysanthemums', 101, 'long'),
#  ('The Barefoot Contessa', 128, 'long'),
#  ('Beau Brummell', 113, 'long'),
#  ('Betrayed', 108, 'long'),
#  ('Black Widow', 95, 'long'),
#  ('20,000 Leagues Under the Sea', 127, 'long'),
#  ('Wuthering Heights', 91, 'long'),
#  ('About Mrs. Leslie', 104, 'long'),
#  ('The Bridges at Toko-Ri', 102, 'long'),
#  ('An American in Rome', 94, 'long'),
#  ('Anatahan', 91, 'long'),
#  ('Angels One Five', 98, 'long'),
#  ('Brigadoon', 108, 'long'),
#  ('Broken Lance', 96, 'long'),
#  ('The Caine Mutiny', 124, 'long'),
#  ('Carmen Jones', 105, 'long'),
#  ("Casanova's Big Night", 86, 'normal'),
#  ('The Country Girl', 104, 'long'),
#  ('Crime Wave', 73, 'normal'),
#  ('The Dam Busters', 124, 'long'),
#  ('Demetrius and the Gladiators', 101, 'long'),
#  ('Désirée', 110, 'long'),
#  ('Destry', 95, 'long'),
#  ('School for Tramps', 99, 'long'),
#  ('Diabolique', 117, 'long'),
#  ('Dial M for Murder', 105, 'long'),
#  ('Doctor in the House', 92, 'long'),
#  ('Down Three Dark Streets', 85, 'normal'),
#  ('Dragnet', 88, 'normal'),
#  ('Drive a Crooked Road', 83, 'normal'),
#  ('Drum Beat', 111, 'long'),
#  ('The Egyptian', 139, 'long'),
#  ('Executive Suite', 104, 'long'),
#  ('The Detective', 91, 'long'),
#  ('French Cancan', 102, 'long'),
#  ('Living It Up', 95, 'long'),
#  ('Lucky Me', 100, 'long'),
#  ('The Mad Magician', 72, 'normal'),
#  ('Godzilla', 96, 'long'),
#  ('The Miracle of Marcelino', 91, 'long'),
#  ('Miseria e nobiltà', 94, 'long'),
#  ('The Story of Vickie', 118, 'long'),
#  ('Naked Alibi', 86, 'normal'),
#  ('Night People', 93, 'long'),
#  ('Twenty-Four Eyes', 156, 'long'),
#  ('The Good Die Young', 100, 'long'),
#  ('Rhapsody', 115, 'long'),
#  ('Ride Clear of Diablo', 81, 'normal'),
#  ('On the Waterfront', 108, 'long'),
#  ('The Gold of Naples', 138, 'long'),
#  ('Riding Shotgun', 73, 'normal'),
#  ('Riot in Cell Block 11', 80, 'normal'),
#  ('River of No Return', 91, 'long'),
#  ('Phffft', 88, 'normal'),
#  ('Prince Valiant', 100, 'long'),
#  ('Private Hell 36', 81, 'normal'),
#  ('The Purple Plain', 97, 'long'),
#  ('Pushover', 88, 'normal'),
#  ('Rogue Cop', 92, 'long'),
#  ('The Raid', 83, 'normal'),
#  ('Rear Window', 112, 'long'),
#  ('The River and Death', 91, 'long'),
#  ('Sabrina', 113, 'long'),
#  ('Salt of the Earth', 94, 'long'),
#  ('Sansho the Bailiff', 124, 'long'),
#  ('Saskatchewan', 87, 'normal'),
#  ('Seven Brides for Seven Brothers', 102, 'long'),
#  ('A Star Is Born', 154, 'long'),
#  ('Shield for Murder', 82, 'normal'),
#  ('The Student Prince', 107, 'long'),
#  ('Suddenly', 77, 'normal'),
#  ('Susan Slept Here', 98, 'long'),
#  ("The Devil's General", 117, 'long'),
#  ('Them!', 94, 'long'),
#  ("There's No Business Like Show Business", 117, 'long'),
#  ('Three Cases of Murder', 99, 'long'),
#  ('Three Hours to Kill', 77, 'normal'),
#  ('Track of the Cat', 102, 'long'),
#  ('Hell and High Water', 103, 'long'),
#  ('High and Dry', 92, 'long'),
#  ('The High and the Mighty', 147, 'long'),
#  ("Hobson's Choice", 108, 'long'),
#  ('Human Desire', 91, 'long'),
#  ('An Inspector Calls', 80, 'normal'),
#  ('Knock on Wood', 103, 'long'),
#  ('Silver Lode', 81, 'normal'),
#  ('The Sleeping Tiger', 89, 'normal'),
#  ('Ulysses', 117, 'long'),
#  ('Valley of the Kings', 86, 'normal'),
#  ('Bad Day at Black Rock', 81, 'normal'),
#  ('White Christmas', 120, 'long'),
#  ('The Wild One', 79, 'normal'),
#  ('Witness to Murder', 83, 'normal'),
#  ('Sound of the Mountain', 95, 'long'),
#  ('Young at Heart', 117, 'long'),
#  ('Battle Cry', 149, 'long'),
#  ('The Benny Goodman Story', 116, 'long'),
#  ('The Big Combo', 87, 'normal'),
#  ('Abbott and Costello Meet the Mummy', 79, 'normal'),
#  ('Above Us the Waves', 99, 'long'),
#  ('Le Amiche', 104, 'long'),
#  ('Big House, U.S.A.', 83, 'normal'),
#  ('Animal Farm', 72, 'normal'),
#  ('Artists and Models', 109, 'long'),
#  ('The Big Knife', 111, 'long'),
#  ('Blackboard Jungle', 101, 'long'),
#  ('Daddy Long Legs', 126, 'long'),
#  ('Dementia', 56, 'normal'),
#  ('Davy Crockett: King of the Wild Frontier', 93, 'long'),
#  ('Bob le Flambeur', 98, 'long'),
#  ('A Bullet for Joey', 85, 'normal'),
#  ('Rififi', 118, 'long'),
#  ('East of Eden', 118, 'long'),
#  ('The Far Country', 97, 'long'),
#  ('The Far Horizons', 108, 'long'),
#  ('Female on the Beach', 97, 'long'),
#  ('Footsteps in the Fog', 90, 'normal'),
#  ('The End of the Affair', 105, 'long'),
#  ('Wee Geordie', 93, 'long'),
#  ('The Glass Slipper', 93, 'long'),
#  ('The Grand Maneuver', 106, 'long'),
#  ('Guys and Dolls', 150, 'long'),
#  ('Captain Lightfoot', 92, 'long'),
#  ('That Is the Dawn', 102, 'long'),
#  ('Bloody Spear at Mount Fuji', 94, 'long'),
#  ('The Cobweb', 134, 'long'),
#  ('The Colditz Story', 94, 'long'),
#  ('City of Fear', 81, 'normal'),
#  ('Mister Roberts', 123, 'long'),
#  ('Dreams', 87, 'normal'),
#  ('Merry-Go-Round', 90, 'normal'),
#  ('Lady and the Tramp', 76, 'normal'),
#  ('The Ladykillers', 91, 'long'),
#  ('Land of the Pharaohs', 106, 'long'),
#  ('The Last Command', 110, 'long'),
#  ('A Lawless Street', 78, 'normal'),
#  ('The Left Hand of God', 87, 'normal'),
#  ('Lola Montès', 116, 'long'),
#  ('The Long Gray Line', 138, 'long'),
#  ('Love Is a Many-Splendored Thing', 102, 'long'),
#  ('Love Me or Leave Me', 122, 'long'),
#  ('A Man Alone', 96, 'long'),
#  ('A Man Called Peter', 119, 'long'),
#  ('Man with the Gun', 84, 'normal'),
#  ('Man Without a Star', 89, 'normal'),
#  ('The Man from Laramie', 103, 'long'),
#  ('The Man with the Golden Arm', 119, 'long'),
#  ('Many Rivers to Cross', 94, 'long'),
#  ('Marty', 90, 'normal'),
#  ('Maksim Perepelitsa', 94, 'long'),
#  ('Hit the Deck', 112, 'long'),
#  ('House of Bamboo', 102, 'long'),
#  ('I Died a Thousand Times', 109, 'long'),
#  ("I'll Cry Tomorrow", 117, 'long'),
#  ('I Live in Fear', 103, 'long'),
#  ('Illegal', 88, 'normal'),
#  ('The Indian Fighter', 88, 'normal'),
#  ('Interrupted Melody', 106, 'long'),
#  ('It Came from Beneath the Sea', 79, 'normal'),
#  ("It's Always Fair Weather", 101, 'long'),
#  ('Jubal', 100, 'long'),
#  ('The Kentuckian', 104, 'long'),
#  ("Killer's Kiss", 67, 'normal'),
#  ('Kismet', 113, 'long'),
#  ('Kiss Me Deadly', 106, 'long'),
#  ('The Phenix City Story', 100, 'long'),
#  ('La Pointe Courte', 86, 'normal'),
#  ('A Generation', 87, 'normal'),
#  ('The Prisoner', 95, 'long'),
#  ('The Private War of Major Benson', 105, 'long'),
#  ('Queen Bee', 95, 'long'),
#  ('Quentin Durward', 103, 'long'),
#  ('Rage at Dawn', 87, 'normal'),
#  ('Rebel Without a Cause', 111, 'long'),
#  ('The Rose Tattoo', 117, 'long'),
#  ('Run for Cover', 93, 'long'),
#  ('The Scarlet Coat', 101, 'long'),
#  ('The Sea Chase', 117, 'long'),
#  ('The Seven Year Itch', 105, 'long'),
#  ('Shack Out on 101', 80, 'normal'),
#  ('Shree 420', 168, 'long'),
#  ('Sissi', 102, 'long'),
#  ('Soldier of Fortune', 96, 'long'),
#  ('Smiles of a Summer Night', 109, 'long'),
#  ('Stella', 90, 'normal'),
#  ('Summertime', 99, 'long'),
#  ('Tall Man Riding', 83, 'normal'),
#  ('The Tall Men', 122, 'long'),
#  ('Tarantula', 80, 'normal'),
#  ('Moonfleet', 84, 'normal'),
#  ('Mr. Arkadin', 93, 'long'),
#  ('The Naked Dawn', 82, 'normal'),
#  ('The Naked Street', 84, 'normal'),
#  ('Ten Wanted Men', 80, 'normal'),
#  ('Not as a Stranger', 135, 'long'),
#  ('Tight Spot', 97, 'long'),
#  ('To Catch a Thief', 106, 'long'),
#  ('To Hell and Back', 106, 'long'),
#  ('Trial', 105, 'long'),
#  ('The Trouble with Harry', 99, 'long'),
#  ('The Unknown Soldier', 177, 'long'),
#  ('Floating Clouds', 123, 'long'),
#  ('Untamed', 111, 'long'),
#  ('Wichita', 81, 'normal'),
#  ('Princess Yang Kwei-fei', 98, 'long'),
#  ('The Violent Men', 96, 'long'),
#  ('Violent Saturday', 90, 'normal'),
#  ('The Virgin Queen', 92, 'long'),
#  ("We're No Angels", 106, 'long'),
#  ('Ordet', 126, 'long'),
#  ('Our Miss Brooks', 85, 'normal'),
#  ('Pather Panchali', 125, 'long'),
#  ("Too Bad She's Bad", 95, 'long'),
#  ('Dobrý voják Svejk', 108, 'long'),
#  ('1984', 90, 'normal'),
#  ('23 Paces to Baker Street', 103, 'long'),
#  ('Street of Shame', 87, 'normal'),
#  ("The Ambassador's Daughter", 103, 'long'),
#  ('Anastasia', 105, 'long'),
#  ('Anything Goes', 106, 'long'),
#  ('Aparajito', 110, 'long'),
#  ('Attack', 107, 'long'),
#  ('Autumn Leaves', 107, 'long'),
#  ('Away All Boats', 114, 'long'),
#  ('Back from Eternity', 97, 'long'),
#  ('Backlash', 84, 'normal'),
#  ('The Band of Honest Men', 106, 'long'),
#  ('Bandido!', 92, 'long'),
#  ('Beyond a Reasonable Doubt', 80, 'normal'),
#  ('Bhowani Junction', 110, 'long'),
#  ('Bigger Than Life', 95, 'long'),
#  ('The Burmese Harp', 116, 'long'),
#  ('The Black Sleep', 82, 'normal'),
#  ("Raquel's Shoeshiner", 101, 'long'),
#  ('The Brave One', 100, 'long'),
#  ('Bundle of Joy', 98, 'long'),
#  ('The Burglar', 90, 'normal'),
#  ('Bus Stop', 96, 'long'),
#  ('C.I.D.', 146, 'long'),
#  ('The Rocket from Calabuch', 93, 'long'),
#  ('Main Street', 99, 'long'),
#  ('Carousel', 128, 'long'),
#  ('The Catered Affair', 94, 'long'),
#  ('The Cockleshell Heroes', 97, 'long'),
#  ('The Court Jester', 101, 'long'),
#  ('Crime in the Streets', 91, 'long'),
#  ('A Cry in the Night', 75, 'normal'),
#  ('D-Day the Sixth of June', 106, 'long'),
#  ('Death of a Scoundrel', 119, 'long'),
#  ('Gervaise', 112, 'long'),
#  ('Giant', 201, 'long'),
#  ("The Girl Can't Help It", 99, 'long'),
#  ('Good-bye, My Lady', 94, 'long'),
#  ('Night Ambush', 104, 'long'),
#  ('Invasion of the Body Snatchers', 80, 'normal'),
#  ('Invitation to the Dance', 93, 'long'),
#  ('Stay Alert', 153, 'long'),
#  ('Julie', 99, 'long'),
#  ('The Killer Is Loose', 73, 'normal'),
#  ('The Killing', 84, 'normal'),
#  ('The King and Four Queens', 86, 'normal'),
#  ('The King and I', 133, 'long'),
#  ('A Kiss Before Dying', 94, 'long'),
#  ('A Girl in Black', 100, 'long'),
#  ('Lust of the Vampire', 82, 'normal'),
#  ('The Last Frontier', 98, 'long'),
#  ('The Last Hunt', 108, 'long'),
#  ('The Last Wagon', 99, 'long'),
#  ('Love Me Tender', 89, 'normal'),
#  ('Professor Hannibal', 89, 'normal'),
#  ('The Harder They Fall', 109, 'long'),
#  ('The Captain from Köpenick', 93, 'long'),
#  ('High Society', 111, 'long'),
#  ('Hollywood or Bust', 95, 'long'),
#  ('Earth vs. the Flying Saucers', 83, 'normal'),
#  ('The Man Who Knew Too Much', 120, 'long'),
#  ('The Man Who Never Was', 103, 'long'),
#  ('The Man in the Gray Flannel Suit', 153, 'long'),
#  ('...And God Created Woman', 95, 'long'),
#  ('Meet Me in Las Vegas', 112, 'long'),
#  ('Miracle in the Rain', 108, 'long'),
#  ('Moby Dick', 116, 'long'),
#  ('The Silent World', 86, 'normal'),
#  ('Death in the Garden', 104, 'long'),
#  ('The Mountain', 105, 'long'),
#  ('The Mystery of Picasso', 78, 'normal'),
#  ('Flowing', 117, 'long'),
#  ('Nightfall', 78, 'normal'),
#  ('Pardners', 90, 'normal'),
#  ('Patterns', 83, 'normal'),
#  ('Please Murder Me!', 78, 'normal'),
#  ("Private's Progress", 102, 'long'),
#  ('The Proud Ones', 94, 'long'),
#  ('The Quatermass Xperiment', 82, 'normal'),
#  ('The Rack', 100, 'long'),
#  ('The Rainmaker', 121, 'long'),
#  ('Ransom!', 109, 'long'),
#  ('The Rawhide Years', 85, 'normal'),
#  ('Reach for the Sky', 135, 'long'),
#  ('Richard III', 161, 'long'),
#  ('Rock Around the Clock', 77, 'normal'),
#  ('Run for the Sun', 99, 'long'),
#  ('The Fastest Gun Alive', 89, 'normal'),
#  ('The Searchers', 119, 'long'),
#  ('7 Men from Now', 78, 'normal'),
#  ('Il ferroviere', 115, 'long'),
#  ('Sissi: The Young Empress', 107, 'long'),
#  ('Slightly Scarlet', 99, 'long'),
#  ('Somebody Up There Likes Me', 113, 'long'),
#  ('The Forty-First', 88, 'normal'),
#  ('Early Spring', 145, 'long'),
#  ('The Spanish Gardener', 97, 'long'),
#  ('The Flying Carpet', 86, 'normal'),
#  ('Storm Center', 85, 'normal'),
#  ('The Swan', 104, 'long'),
#  ('Tea and Sympathy', 122, 'long'),
#  ('The Ten Commandments', 220, 'long'),
#  ('These Wilder Years', 91, 'long'),
#  ('The Third Key', 96, 'long'),
#  ('Three Violent People', 100, 'long'),
#  ('Time Without Pity', 85, 'normal'),
#  ('Time Table', 80, 'normal'),
#  ('A Town Like Alice', 117, 'long'),
#  ('Trapeze', 105, 'long'),
#  ('Four Bags Full', 80, 'normal'),
#  ('Tribute to a Bad Man', 95, 'long'),
#  ('A Man Escaped', 101, 'long'),
#  ('Up in the World', 87, 'normal'),
#  ('Forbidden Planet', 98, 'long'),
#  ('Vesna na Zarechnoy ulitse', 96, 'long'),
#  ('Walk the Proud Land', 88, 'normal'),
#  ('War and Peace', 208, 'long'),
#  ('The Werewolf', 79, 'normal'),
#  ('X the Unknown', 81, 'normal'),
#  ('Forever, Darling', 96, 'long'),
#  ('Friendly Persuasion', 137, 'long'),
#  ('Cast a Dark Shadow', 82, 'normal'),
#  ('12 Angry Men', 96, 'long'),
#  ('20 Million Miles to Earth', 82, 'normal'),
#  ('The 27th Day', 75, 'normal'),
#  ('3:10 to Yuma', 92, 'long'),
#  ('Seven Days from Now', 100, 'long'),
#  ('The Abominable Snowman', 91, 'long'),
#  ('Across the Bridge', 103, 'long'),
#  ('Paradise Lagoon', 94, 'long'),
#  ('The Chaplin Revue', 128, 'long'),
#  ('Montparnasse 19', 108, 'long'),
#  ('Bitter Victory', 102, 'long'),
#  ('Baby Face Nelson', 85, 'normal'),
#  ('The Bachelor Party', 92, 'long'),
#  ('The Sun Legend of the End of the Tokugawa Era', 110, 'long'),
#  ('Band of Angels', 125, 'long'),
#  ('Battle Hymn', 108, 'long'),
#  ('Mother India', 172, 'long'),
#  ('Chase a Crooked Shadow', 88, 'normal'),
#  ('Boy on a Dolphin', 111, 'long'),
#  ('The Brothers Rico', 92, 'long'),
#  ("Campbell's Kingdom", 102, 'long'),
#  ('The Enemy Below', 98, 'long'),
#  ('Eroica', 87, 'normal'),
#  ('Les espions', 125, 'long'),
#  ('A Face in the Crowd', 126, 'long'),
#  ('Fiend Without a Face', 75, 'normal'),
#  ('Fire Down Below', 116, 'long'),
#  ('Fools in the Mountains', 90, 'normal'),
#  ('Forty Guns', 80, 'normal'),
#  ('Funny Face', 103, 'long'),
#  ('The Mysterians', 89, 'normal'),
#  ('China Gate', 97, 'long'),
#  ('La grande strada azzurra', 103, 'long'),
#  ('The Green Man', 80, 'normal'),
#  ('Gun Glory', 89, 'normal'),
#  ('Gunfight at the O.K. Corral', 122, 'long'),
#  ('The Guns of Fort Petticoat', 82, 'normal'),
#  ('A Hatful of Rain', 109, 'long'),
#  ('Heaven Knows, Mr. Allison', 107, 'long'),
#  ('The Helen Morgan Story', 118, 'long'),
#  ('Crime of Passion', 86, 'normal'),
#  ('Island in the Sun', 119, 'long'),
#  ('Jailhouse Rock', 96, 'long'),
#  ('Jeanne Eagels', 108, 'long'),
#  ('Johnny Tremain', 80, 'normal'),
#  ('Just My Luck', 86, 'normal'),
#  ('Kanal', 91, 'long'),
#  ('A King in New York', 110, 'long'),
#  ('Throne of Blood', 110, 'long'),
#  ('The Incredible Shrinking Man', 81, 'normal'),
#  ('Les Girls', 114, 'long'),
#  ('The Cranes Are Flying', 95, 'long'),
#  ('The Lonely Man', 88, 'normal'),
#  ('Love in the Afternoon', 130, 'long'),
#  ('Loving You', 101, 'long'),
#  ('Lucky Jim', 95, 'long'),
#  ('Madhumati', 110, 'long'),
#  ('The Curse of Frankenstein', 82, 'normal'),
#  ('Inspector Maigret', 119, 'long'),
#  ('Man of a Thousand Faces', 122, 'long'),
#  ('The D.I.', 106, 'long'),
#  ('Men in War', 102, 'long'),
#  ('Mon Oncle', 116, 'long'),
#  ('The Monolith Monsters', 77, 'normal'),
#  ('Decision at Sundown', 77, 'normal'),
#  ('My Man Godfrey', 92, 'long'),
#  ('The Devil Strikes at Night', 105, 'long'),
#  ('Naya Daur', 173, 'long'),
#  ('Nine Lives', 96, 'long'),
#  ('Night Passage', 90, 'normal'),
#  ('No Down Payment', 105, 'long'),
#  ('Not of This Earth', 67, 'normal'),
#  ('The Hunchback of Notre Dame', 115, 'long'),
#  ('Le Notti Bianche', 102, 'long'),
#  ('The Nights of Cabiria', 110, 'long'),
#  ('Old Yeller', 83, 'normal'),
#  ('The One That Got Away', 106, 'long'),
#  ('Operation Mad Ball', 105, 'long'),
#  ('The Pajama Game', 101, 'long'),
#  ('Pal Joey', 111, 'long'),
#  ('Paths of Glory', 88, 'normal'),
#  ('The Delicate Delinquent', 101, 'long'),
#  ('Peyton Place', 157, 'long'),
#  ('Plunder Road', 72, 'normal'),
#  ('I Dutifully Report', 91, 'long'),
#  ('Pyaasa', 146, 'long'),
#  ('Raintree County', 160, 'long'),
#  ('The Revenge of Frankenstein', 90, 'normal'),
#  ('The Ride Back', 79, 'normal'),
#  ("The River's Edge", 87, 'normal'),
#  ('Run of the Arrow', 86, 'normal'),
#  ('Designing Woman', 118, 'long'),
#  ('Saddle the Wind', 84, 'normal'),
#  ('Sayonara', 147, 'long'),
#  ('Desk Set', 103, 'long'),
#  ('Do Ankhen Barah Haath', 143, 'long'),
#  ('Silk Stockings', 117, 'long'),
#  ('The Seventh Seal', 96, 'long'),
#  ('Big Time Operators', 80, 'normal'),
#  ('Wild Strawberries', 91, 'long'),
#  ('Something of Value', 113, 'long'),
#  ('The Story of Esther Costello', 103, 'long'),
#  ('The Sun Also Rises', 130, 'long'),
#  ('Sweet Smell of Success', 96, 'long'),
#  ('The Tall Stranger', 81, 'normal'),
#  ('Tammy and the Bachelor', 89, 'normal'),
#  ('The Tarnished Angels', 91, 'long'),
#  ('A Matter of Dignity', 112, 'long'),
#  ('The Three Faces of Eve', 91, 'long'),
#  ('Tikhiy Don', 330, 'long'),
#  ('Time Limit', 96, 'long'),
#  ('The Tin Star', 93, 'long'),
#  ('Tizoc (Amor indio)', 109, 'long'),
#  ('Tokyo Twilight', 140, 'long'),
#  ('Trooper Hook', 81, 'normal'),
#  ('The True Story of Jesse James', 92, 'long'),
#  ('La Parisienne', 86, 'normal'),
#  ('Until They Sail', 94, 'long'),
#  ('El vampiro', 95, 'long'),
#  ('Doctor at Large', 104, 'long'),
#  ('Wild Is the Wind', 114, 'long'),
#  ('Will Success Spoil Rock Hunter?', 93, 'long'),
#  ('Das Wirtshaus im Spessart', 99, 'long'),
#  ('Witness for the Prosecution', 116, 'long'),
#  ('The Wrong Man', 105, 'long'),
#  ('Don Kikhot', 110, 'long'),
#  ("Don't Go Near the Water", 107, 'long'),
#  ('The Lower Depths', 137, 'long'),
#  ('The Bravados', 98, 'long'),
#  ('The Buccaneer', 119, 'long'),
#  ('Buchanan Rides Alone', 80, 'normal'),
#  ('Carry on Nurse', 86, 'normal'),
#  ('Carry On Sergeant', 84, 'normal'),
#  ('Cat on a Hot Tin Roof', 108, 'long'),
#  ('The 7th Voyage of Sinbad', 88, 'normal'),
#  ('Bandini', 157, 'long'),
#  ('Christine', 100, 'long'),
#  ('Araya', 90, 'normal'),
#  ('Elevator to the Gallows', 91, 'long'),
#  ('Auntie Mame', 143, 'long'),
#  ('Cairo Station', 77, 'normal'),
#  ('The Badlanders', 85, 'normal'),
#  ('Bell Book and Candle', 106, 'long'),
#  ('The Big Country', 166, 'long'),
#  ('The H-Man', 87, 'normal'),
#  ('The Blob', 86, 'normal'),
#  ("Blue Murder at St. Trinian's", 86, 'normal'),
#  ('Bonjour Tristesse', 94, 'long'),
#  ('Corridors of Blood', 86, 'normal'),
#  ('Horror of Dracula', 82, 'normal'),
#  ('Dunkirk', 135, 'long'),
#  ('Lake of the Dead', 76, 'normal'),
#  ('Love Is My Profession', 105, 'long'),
#  ('Conflagration', 99, 'long'),
#  ('Fanfare', 86, 'normal'),
#  ('The Fearmakers', 85, 'normal'),
#  ('The Fly', 94, 'long'),
#  ('Fort Dobbs', 93, 'long'),
#  ('Fort Massacre', 80, 'normal'),
#  ('From Hell to Texas', 100, 'long'),
#  ('Career', 105, 'long'),
#  ('The Geisha Boy', 98, 'long'),
#  ('Cowboy', 92, 'long'),
#  ('Gideon of Scotland Yard', 91, 'long'),
#  ('Gigi', 115, 'long'),
#  ("God's Little Acre", 118, 'long'),
#  ('The Goddess', 104, 'long'),
#  ('The Gunfight at Dodge City', 81, 'normal'),
#  ('H-8...', 105, 'long'),
#  ('The Haunted Strangler', 78, 'normal'),
#  ('Hell Drivers', 108, 'long'),
#  ('Home Before Dark', 136, 'long'),
#  ('The Idiot', 124, 'long'),
#  ('Imitation General', 88, 'normal'),
#  ('Indiscreet', 100, 'long'),
#  ('It! The Terror from Beyond Space', 69, 'normal'),
#  ('Ivan the Terrible, Part II', 88, 'normal'),
#  ('The Music Room', 100, 'long'),
#  ('The Hidden Fortress', 139, 'long'),
#  ('The Key', 134, 'long'),
#  ('King Creole', 116, 'long'),
#  ('Kings Go Forth', 109, 'long'),
#  ('The Law and Jake Wade', 86, 'normal'),
#  ('The Law Is the Law', 95, 'long'),
#  ('The Law', 126, 'long'),
#  ("The Horse's Mouth", 97, 'long'),
#  ('House on Haunted Hill', 75, 'normal'),
#  ('Houseboat', 110, 'long'),
#  ('The Hunters', 108, 'long'),
#  ('I Bury the Living', 77, 'normal'),
#  ('I Married a Monster from Outer Space', 78, 'normal'),
#  ('I Want to Live!', 120, 'long'),
#  ('The Long, Hot Summer', 115, 'long'),
#  ('Look Back in Anger', 98, 'long'),
#  ('Machine-Gun Kelly', 80, 'normal'),
#  ('Man of the West', 100, 'long'),
#  ('Marjorie Morningstar', 128, 'long'),
#  ('Me and the Colonel', 109, 'long'),
#  ('Merry Andrew', 103, 'long'),
#  ('We Only Live Once', 111, 'long'),
#  ('Moi, un noir', 70, 'normal'),
#  ('The Rickshaw Man', 103, 'long'),
#  ('Murder by Contract', 81, 'normal'),
#  ('Mädchen in Uniform', 95, 'long'),
#  ('The Naked and the Dead', 131, 'long'),
#  ('Nazarin', 94, 'long'),
#  ('Neither Seen Nor Recognized', 95, 'long'),
#  ('A Night to Remember', 123, 'long'),
#  ('No Name on the Bullet', 77, 'normal'),
#  ('No Time for Sergeants', 119, 'long'),
#  ('Brink of Life', 84, 'normal'),
#  ('Paras-Pathar', 111, 'long'),
#  ('Party Girl', 99, 'long'),
#  ('The Perfect Furlough', 93, 'long'),
#  ('The Noose', 96, 'long'),
#  ('The Little Apartment', 87, 'normal'),
#  ('Cry Terror!', 96, 'long'),
#  ('Ashes and Diamonds', 103, 'long'),
#  ('The Proud Rebel', 103, 'long'),
#  ('The Quiet American', 120, 'long'),
#  ("Rally 'Round the Flag, Boys!", 106, 'long'),
#  ('The Reluctant Debutante', 94, 'long'),
#  ('Ride a Crooked Trail', 88, 'normal'),
#  ('Rock-a-Bye Baby', 103, 'long'),
#  ('The Roots of Heaven', 126, 'long'),
#  ('Run Silent Run Deep', 93, 'long'),
#  ('The Snorkel', 90, 'normal'),
#  ('Some Came Running', 137, 'long'),
#  ('South Pacific', 157, 'long'),
#  ('The Square Peg', 85, 'normal'),
#  ...]

# %% [markdown]
# ## Functions & operators (go quickly through them)
#
# >Only go through it if time permits, more like functions in R. Also these might be different in different databases. No no much use in memorizing them. Maybe worth putting them in cheatsheet.
#
# ```{note}
# - you might not need to memorize all things here.
# - that's why you have the cheatsheet so that you can follow them.
# ```
# > Going fast here! There are many! Listed a few here, but more in lecture notes.

# %% [markdown]
# ### Math

# %%
# %%sql
#
# SELECT
#     25 * 2,
#     ABS(-2^10),
#     ROUND(23.24545, 2),
#     SQRT(25),
#     PI()
# ;
# Out:
#  * postgresql://postgres:***@localhost:5432/imdb
# 1 rows affected.
# [(50, 1024.0, Decimal('23.25'), 5.0, 3.141592653589793)]

# %% [markdown]
# ### Strings
# >You will be using this in labs. So you will get practice.

# %%
# %%sql
# -- || is used for string concatenation
# SELECT
#     'Hello' || title || 'runtime is' || ROUND(runtime / 60., 1) || ' with rating '|| rating || ' / 10.',
#       SUBSTR(title, LENGTH(title) - 3, 3) AS "Last 3 characters"
# FROM
#     movies
# ;
# Out:
#  * postgresql://postgres:***@localhost:5432/imdb
# 26058 rows affected.
# [('HelloKate & Leopoldruntime is2.0 with rating 6.4 / 10.', 'pol'),
#  ('HelloMister 880runtime is1.5 with rating 7.1 / 10.', ' 88'),
#  ('HelloBlack Handruntime is1.5 with rating 6.4 / 10.', 'Han'),
#  ('HelloFrancisruntime is1.5 with rating 6.4 / 10.', 'nci'),
#  ('HelloOrpheusruntime is1.6 with rating 8 / 10.', 'heu'),
#  ('HelloStromboliruntime is1.8 with rating 7.3 / 10.', 'bol'),
#  ('HelloWoman in Hidingruntime is1.5 with rating 6.9 / 10.', 'din'),
#  ('HelloAbbott and Costello in the Foreign Legionruntime is1.3 with rating 6.6 / 10.', 'gio'),
#  ('HelloAnnie Get Your Gunruntime is1.8 with rating 6.9 / 10.', ' Gu'),
#  ('HelloArmored Car Robberyruntime is1.1 with rating 7 / 10.', 'ber'),
#  ('HelloThe Asphalt Jungleruntime is1.9 with rating 7.9 / 10.', 'ngl'),
#  ('HelloAtom Man vs. Supermanruntime is4.2 with rating 7 / 10.', 'rma'),
#  ('HelloBackfireruntime is1.5 with rating 6.6 / 10.', 'fir'),
#  ('HelloThe Baron of Arizonaruntime is1.6 with rating 7 / 10.', 'zon'),
#  ('HelloThe Big Liftruntime is2.0 with rating 6.5 / 10.', 'Lif'),
#  ('HelloThe Black Roseruntime is2.0 with rating 6.3 / 10.', 'Ros'),
#  ('HelloThe Blue Lampruntime is1.4 with rating 6.9 / 10.', 'Lam'),
#  ('HelloBorderlineruntime is1.5 with rating 6.1 / 10.', 'lin'),
#  ('HelloBorn to Be Badruntime is1.6 with rating 6.7 / 10.', ' Ba'),
#  ('HelloBrandedruntime is1.7 with rating 6.7 / 10.', 'nde'),
#  ('HelloBright Leafruntime is1.8 with rating 6.6 / 10.', 'Lea'),
#  ('HelloCagedruntime is1.6 with rating 7.7 / 10.', 'age'),
#  ('HelloThe Cariboo Trailruntime is1.4 with rating 6 / 10.', 'rai'),
#  ('HelloChampagne for Caesarruntime is1.7 with rating 7.4 / 10.', 'esa'),
#  ('HelloCinderellaruntime is1.2 with rating 7.3 / 10.', 'ell'),
#  ('HelloThe Clouded Yellowruntime is1.6 with rating 6.9 / 10.', 'llo'),
#  ('HelloColt .45runtime is1.2 with rating 6 / 10.', ' .4'),
#  ('HelloConvictedruntime is1.5 with rating 6.9 / 10.', 'cte'),
#  ('HelloCopper Canyonruntime is1.4 with rating 6.3 / 10.', 'nyo'),
#  ('HelloCrisisruntime is1.6 with rating 6.7 / 10.', 'isi'),
#  ('HelloStory of a Love Affairruntime is1.6 with rating 7.1 / 10.', 'fai'),
#  ('HelloCyrano de Bergeracruntime is1.9 with rating 7.5 / 10.', 'era'),
#  ('HelloDallasruntime is1.6 with rating 6.3 / 10.', 'lla'),
#  ("HelloThe Damned Don't Cryruntime is1.7 with rating 7.2 / 10.", ' Cr'),
#  ('HelloDark Cityruntime is1.6 with rating 6.8 / 10.', 'Cit'),
#  ('HelloDestination Moonruntime is1.5 with rating 6.3 / 10.', 'Moo'),
#  ('HelloDestination Murderruntime is1.2 with rating 6 / 10.', 'rde'),
#  ("HelloDevil's Doorwayruntime is1.4 with rating 7.3 / 10.", 'rwa'),
#  ('HelloDial 1119runtime is1.3 with rating 6.7 / 10.', '111'),
#  ('HelloFancy Pantsruntime is1.5 with rating 6.6 / 10.', 'ant'),
#  ('HelloFather of the Brideruntime is1.5 with rating 7.2 / 10.', 'rid'),
#  ('HelloThe Flame and the Arrowruntime is1.5 with rating 7 / 10.', 'rro'),
#  ('HelloThe Fuller Brush Girlruntime is1.4 with rating 6.7 / 10.', 'Gir'),
#  ('HelloThe Furiesruntime is1.8 with rating 7.3 / 10.', 'rie'),
#  ('HelloThe Glass Menagerieruntime is1.8 with rating 7.1 / 10.', 'eri'),
#  ('HelloGone to Earthruntime is1.8 with rating 7.1 / 10.', 'art'),
#  ('HelloThe Great Rupertruntime is1.5 with rating 6.6 / 10.', 'per'),
#  ('HelloGun Crazyruntime is1.5 with rating 7.6 / 10.', 'raz'),
#  ('HelloThe Gunfighterruntime is1.4 with rating 7.7 / 10.', 'hte'),
#  ('HelloThe Happy Yearsruntime is1.8 with rating 6.8 / 10.', 'ear'),
#  ('HelloHarriet Craigruntime is1.6 with rating 7.3 / 10.', 'rai'),
#  ('HelloHarveyruntime is1.7 with rating 7.9 / 10.', 'rve'),
#  ('HelloHouse by the Riverruntime is1.4 with rating 7.2 / 10.', 'ive'),
#  ('HelloIn a Lonely Placeruntime is1.6 with rating 8 / 10.', 'lac'),
#  ('HelloThe Jackie Robinson Storyruntime is1.3 with rating 6.4 / 10.', 'tor'),
#  ('HelloThe Jackpotruntime is1.4 with rating 6.9 / 10.', 'kpo'),
#  ('HelloDiary of a Country Priestruntime is1.9 with rating 8 / 10.', 'ies'),
#  ('HelloKey to the Cityruntime is1.7 with rating 6.4 / 10.', 'Cit'),
#  ('HelloKimruntime is1.9 with rating 6.6 / 10.', 'Ki'),
#  ("HelloKing Solomon's Minesruntime is1.7 with rating 6.8 / 10.", 'ine'),
#  ('HelloKiss Tomorrow Goodbyeruntime is1.7 with rating 7.1 / 10.', 'dby'),
#  ('HelloKon-Tikiruntime is1.3 with rating 8 / 10.', 'Tik'),
#  ('HelloA Lady Without Passportruntime is1.2 with rating 6.2 / 10.', 'por'),
#  ('HelloLast Holidayruntime is1.5 with rating 7.5 / 10.', 'ida'),
#  ('HelloA Life of Her Ownruntime is1.8 with rating 6.3 / 10.', ' Ow'),
#  ('HelloVariety Lightsruntime is1.6 with rating 7.1 / 10.', 'ght'),
#  ('HelloMa and Pa Kettle Go to Townruntime is1.3 with rating 6.9 / 10.', 'Tow'),
#  ('HelloMadeleineruntime is1.9 with rating 6.9 / 10.', 'ein'),
#  ('HelloThe Magnificent Yankeeruntime is1.5 with rating 6.8 / 10.', 'nke'),
#  ('HelloThe Man Who Cheated Himselfruntime is1.4 with rating 6.8 / 10.', 'sel'),
#  ('HelloThe Menruntime is1.4 with rating 7.1 / 10.', ' Me'),
#  ('HelloThe Miniver Storyruntime is1.7 with rating 6.5 / 10.', 'tor'),
#  ('HelloMontanaruntime is1.3 with rating 6.2 / 10.', 'tan'),
#  ('HelloTrioruntime is1.5 with rating 7.2 / 10.', 'Tri'),
#  ('HelloMystery Streetruntime is1.6 with rating 7.2 / 10.', 'ree'),
#  ('HelloThe Nevadanruntime is1.4 with rating 6.3 / 10.', 'ada'),
#  ('HelloThe Next Voice You Hear...runtime is1.4 with rating 6.3 / 10.', 'r..'),
#  ('HelloNight and the Cityruntime is1.7 with rating 8 / 10.', 'Cit'),
#  ('HelloNo Way Outruntime is1.8 with rating 7.4 / 10.', ' Ou'),
#  ('HelloThe Young and the Damnedruntime is1.4 with rating 8.3 / 10.', 'mne'),
#  ('HelloOperation Disasterruntime is1.7 with rating 7 / 10.', 'ste'),
#  ('HelloOutrageruntime is1.3 with rating 6.7 / 10.', 'rag'),
#  ('HelloPanic in the Streetsruntime is1.6 with rating 7.3 / 10.', 'eet'),
#  ('HelloQuicksandruntime is1.3 with rating 6.6 / 10.', 'san'),
#  ('HelloRashomonruntime is1.5 with rating 8.2 / 10.', 'omo'),
#  ('HelloRio Granderuntime is1.8 with rating 7.2 / 10.', 'and'),
#  ('HelloRocky Mountainruntime is1.4 with rating 6.8 / 10.', 'tai'),
#  ('HelloLa Ronderuntime is1.6 with rating 7.6 / 10.', 'ond'),
#  ('HelloThe Secret Furyruntime is1.4 with rating 6.9 / 10.', 'Fur'),
#  ('HelloSeptember Affairruntime is1.7 with rating 6.8 / 10.', 'fai'),
#  ('HelloSeven Days to Noonruntime is1.6 with rating 7.1 / 10.', 'Noo'),
#  ('HelloShadow on the Wallruntime is1.4 with rating 6.7 / 10.', 'Wal'),
#  ('HelloSide Streetruntime is1.4 with rating 7.1 / 10.', 'ree'),
#  ('HelloSierraruntime is1.4 with rating 6.8 / 10.', 'err'),
#  ('HelloStage Frightruntime is1.8 with rating 7.1 / 10.', 'igh'),
#  ('HelloStars in My Crownruntime is1.5 with rating 7.4 / 10.', 'row'),
#  ('HelloSunset Blvd.runtime is1.8 with rating 8.4 / 10.', 'lvd'),
#  ('HelloSusanaruntime is1.4 with rating 7.3 / 10.', 'san'),
#  ('HelloTea for Tworuntime is1.6 with rating 6.5 / 10.', ' Tw'),
#  ('HelloThree Came Homeruntime is1.8 with rating 7.3 / 10.', 'Hom'),
#  ('HelloThree Little Wordsruntime is1.7 with rating 7 / 10.', 'ord'),
#  ('HelloTo Joyruntime is1.6 with rating 7.2 / 10.', ' Jo'),
#  ('HelloTo Please a Ladyruntime is1.5 with rating 6.2 / 10.', 'Lad'),
#  ('HelloThe Toast of New Orleansruntime is1.6 with rating 6.3 / 10.', 'ean'),
#  ('HelloTreasure Islandruntime is1.6 with rating 6.9 / 10.', 'lan'),
#  ('HelloThe Sound of Furyruntime is1.5 with rating 7.2 / 10.', 'Fur'),
#  ('HelloTwo Flags Westruntime is1.5 with rating 6.7 / 10.', 'Wes'),
#  ('HelloTwo Weeks with Loveruntime is1.5 with rating 6.9 / 10.', 'Lov'),
#  ('HelloThe Underworld Storyruntime is1.5 with rating 7 / 10.', 'tor'),
#  ('HelloWagon Masterruntime is1.4 with rating 7.1 / 10.', 'ste'),
#  ('HelloWalk Softly, Strangerruntime is1.4 with rating 6.5 / 10.', 'nge'),
#  ('HelloThe West Point Storyruntime is1.8 with rating 6.2 / 10.', 'tor'),
#  ('HelloWhen Willie Comes Marching Homeruntime is1.4 with rating 6.5 / 10.', 'Hom'),
#  ('HelloWhere the Sidewalk Endsruntime is1.6 with rating 7.6 / 10.', 'End'),
#  ('HelloThe White Towerruntime is1.6 with rating 6 / 10.', 'owe'),
#  ("HelloWinchester '73runtime is1.5 with rating 7.7 / 10.", " '7"),
#  ('HelloWoman on the Runruntime is1.3 with rating 7.3 / 10.', ' Ru'),
#  ('HelloThe Wooden Horseruntime is1.7 with rating 7 / 10.', 'ors'),
#  ('HelloBoot Polishruntime is2.5 with rating 8.2 / 10.', 'lis'),
#  ('HelloA.T.M.: ¡¡A toda máquina!!runtime is2.0 with rating 7.9 / 10.', 'na!'),
#  ('HelloAcross the Wide Missouriruntime is1.3 with rating 6.2 / 10.', 'our'),
#  ('HelloThe African Queenruntime is1.8 with rating 7.8 / 10.', 'uee'),
#  ('HelloAlice in Wonderlandruntime is1.3 with rating 7.4 / 10.', 'lan'),
#  ('HelloAn American in Parisruntime is1.9 with rating 7.2 / 10.', 'ari'),
#  ('HelloAngels in the Outfieldruntime is1.7 with rating 7.1 / 10.', 'iel'),
#  ('HelloAnne of the Indiesruntime is1.4 with rating 6.7 / 10.', 'die'),
#  ('HelloAppointment with Dangerruntime is1.5 with rating 6.6 / 10.', 'nge'),
#  ('HelloAs Young as You Feelruntime is1.3 with rating 6.5 / 10.', 'Fee'),
#  ('HelloThe Red Innruntime is1.6 with rating 7.4 / 10.', ' In'),
#  ('HelloAwaararuntime is3.2 with rating 8 / 10.', 'aar'),
#  ('HelloEarly Summerruntime is2.1 with rating 8.2 / 10.', 'mme'),
#  ('HelloThe Big Nightruntime is1.3 with rating 6.4 / 10.', 'igh'),
#  ('HelloBright Victoryruntime is1.6 with rating 7.3 / 10.', 'tor'),
#  ('HelloThe Browning Versionruntime is1.5 with rating 8.2 / 10.', 'sio'),
#  ('HelloCallaway Went Thatawayruntime is1.4 with rating 6.6 / 10.', 'awa'),
#  ('HelloCaptain Horatio Hornblower R.N.runtime is2.0 with rating 7.4 / 10.', 'R.N'),
#  ("HelloCasque d'Orruntime is1.6 with rating 7.7 / 10.", "d'O"),
#  ('HelloThe Cimarron Kidruntime is1.4 with rating 6.4 / 10.', ' Ki'),
#  ('HelloThe Emperor and the Golemruntime is2.4 with rating 8.1 / 10.', 'ole'),
#  ("HelloComin' Round the Mountainruntime is1.3 with rating 6.6 / 10.", 'tai'),
#  ('HelloCry Dangerruntime is1.3 with rating 7.3 / 10.', 'nge'),
#  ('HelloCry, the Beloved Countryruntime is1.7 with rating 7.1 / 10.', 'ntr'),
#  ('HelloDavid and Bathshebaruntime is1.9 with rating 6.1 / 10.', 'heb'),
#  ('HelloDeath of a Salesmanruntime is1.9 with rating 7.2 / 10.', 'sma'),
#  ('HelloDecision Before Dawnruntime is2.0 with rating 7.2 / 10.', 'Daw'),
#  ('HelloThe Desert Fox: The Story of Rommelruntime is1.5 with rating 6.9 / 10.', 'mme'),
#  ('HelloDetective Storyruntime is1.7 with rating 7.6 / 10.', 'tor'),
#  ("HelloEurope '51runtime is2.0 with rating 7.5 / 10.", " '5"),
#  ('HelloFiveruntime is1.6 with rating 6.3 / 10.', 'Fiv'),
#  ('HelloFlying Leathernecksruntime is1.7 with rating 6.5 / 10.', 'eck'),
#  ('HelloFort Worthruntime is1.3 with rating 6.3 / 10.', 'ort'),
#  ('HelloFourteen Hoursruntime is1.5 with rating 7.1 / 10.', 'our'),
#  ('HelloThe Frogmenruntime is1.6 with rating 6.5 / 10.', 'gme'),
#  ('HelloMiss Julieruntime is1.5 with rating 7.3 / 10.', 'uli'),
#  ('HelloThe Great Carusoruntime is1.8 with rating 6.6 / 10.', 'rus'),
#  ('HelloGuardie e ladriruntime is1.8 with rating 7.7 / 10.', 'adr'),
#  ('HelloThe Idiotruntime is2.8 with rating 7.3 / 10.', 'dio'),
#  ('HelloHe Ran All the Wayruntime is1.3 with rating 7 / 10.', ' Wa'),
#  ('HelloHere Comes the Groomruntime is1.9 with rating 6.5 / 10.', 'roo'),
#  ('HelloHis Kind of Womanruntime is2.0 with rating 7.1 / 10.', 'oma'),
#  ('HelloOne Summer of Happinessruntime is1.7 with rating 6.9 / 10.', 'nes'),
#  ('HelloThe Hoodlumruntime is1.0 with rating 6.3 / 10.', 'dlu'),
#  ('HelloThe House on Telegraph Hillruntime is1.6 with rating 7 / 10.', 'Hil'),
#  ("HelloI'll Never Forget Youruntime is1.5 with rating 7.1 / 10.", ' Yo'),
#  ("HelloI'll See You in My Dreamsruntime is1.8 with rating 6.7 / 10.", 'eam'),
#  ('HelloForbidden Gamesruntime is1.4 with rating 8.1 / 10.', 'ame'),
#  ('HelloJim Thorpe -- All-Americanruntime is1.8 with rating 6.9 / 10.', 'ica'),
#  ('HelloKekecruntime is1.6 with rating 8 / 10.', 'eke'),
#  ('HelloKind Ladyruntime is1.3 with rating 7 / 10.', 'Lad'),
#  ('HelloLaughter in Paradiseruntime is1.6 with rating 7.1 / 10.', 'dis'),
#  ("HelloLet's Make It Legalruntime is1.3 with rating 6.3 / 10.", 'ega'),
#  ('HelloLone Starruntime is1.6 with rating 6.2 / 10.', 'Sta'),
#  ('HelloLove Nestruntime is1.4 with rating 6.3 / 10.', 'Nes'),
#  ('HelloMruntime is1.5 with rating 6.8 / 10.', ''),
#  ('HelloThe Magic Boxruntime is2.0 with rating 7 / 10.', ' Bo'),
#  ('HelloMan in the Saddleruntime is1.5 with rating 6.3 / 10.', 'ddl'),
#  ('HelloThe Mating Seasonruntime is1.7 with rating 7.4 / 10.', 'aso'),
#  ('HelloMeshiruntime is1.6 with rating 7.7 / 10.', 'esh'),
#  ('HelloThe Mobruntime is1.5 with rating 7 / 10.', ' Mo'),
#  ('HelloA Woman Without Loveruntime is1.4 with rating 6.5 / 10.', 'Lov'),
#  ('HelloThe Lady of Musashinoruntime is1.5 with rating 7.3 / 10.', 'hin'),
#  ('HelloMy Favorite Spyruntime is1.6 with rating 6.6 / 10.', ' Sp'),
#  ('HelloNo Questions Askedruntime is1.3 with rating 6.7 / 10.', 'ske'),
#  ('HelloOdetteruntime is2.1 with rating 7 / 10.', 'ett'),
#  ('HelloHas Anybody Seen My Galruntime is1.5 with rating 7.1 / 10.', ' Ga'),
#  ('HelloOn Dangerous Groundruntime is1.4 with rating 7.3 / 10.', 'oun'),
#  ('HelloOn Moonlight Bayruntime is1.6 with rating 7.1 / 10.', ' Ba'),
#  ('HelloOn the Rivieraruntime is1.5 with rating 6.4 / 10.', 'ier'),
#  ('HelloOnly the Valiantruntime is1.8 with rating 6.5 / 10.', 'ian'),
#  ('HelloMiss Oyuruntime is1.6 with rating 7.6 / 10.', ' Oy'),
#  ('HelloPandora and the Flying Dutchmanruntime is2.0 with rating 7 / 10.', 'hma'),
#  ('HelloPathala Bhairaviruntime is3.2 with rating 8.4 / 10.', 'rav'),
#  ('HelloPayment on Demandruntime is1.5 with rating 7.1 / 10.', 'man'),
#  ("HelloThe People Against O'Hararuntime is1.7 with rating 6.8 / 10.", 'Har'),
#  ('HelloThe Little World of Don Camilloruntime is1.8 with rating 7.7 / 10.', 'ill'),
#  ('HelloA Place in the Sunruntime is2.0 with rating 7.8 / 10.', ' Su'),
#  ('HelloLa Poisonruntime is1.4 with rating 7.5 / 10.', 'iso'),
#  ('HelloThe Prowlerruntime is1.5 with rating 7.2 / 10.', 'wle'),
#  ('HelloQuo Vadisruntime is2.9 with rating 7.2 / 10.', 'adi'),
#  ('HelloThe Racketruntime is1.5 with rating 6.7 / 10.', 'cke'),
#  ('HelloRawhideruntime is1.5 with rating 7.2 / 10.', 'hid'),
#  ('HelloThe Red Badge of Courageruntime is1.2 with rating 7.2 / 10.', 'rag'),
#  ('HelloRhubarbruntime is1.6 with rating 6.9 / 10.', 'bar'),
#  ('HelloThe Riverruntime is1.7 with rating 7.5 / 10.', 'ive'),
#  ('HelloRoadblockruntime is1.2 with rating 6.7 / 10.', 'loc'),
#  ('HelloRoyal Weddingruntime is1.6 with rating 6.7 / 10.', 'din'),
#  ('HelloSailor Bewareruntime is1.8 with rating 6.4 / 10.', 'war'),
#  ('HelloSanta Feruntime is1.5 with rating 6.2 / 10.', 'a F'),
#  ('HelloA Christmas Carolruntime is1.4 with rating 8.1 / 10.', 'aro'),
#  ('HelloSealed Cargoruntime is1.5 with rating 6.8 / 10.', 'arg'),
#  ('HelloThe Secret of Convict Lakeruntime is1.4 with rating 7 / 10.', 'Lak'),
#  ('HelloShow Boatruntime is1.8 with rating 6.9 / 10.', 'Boa'),
#  ('HelloSiroccoruntime is1.6 with rating 6.3 / 10.', 'occ'),
#  ('HelloSummer Interluderuntime is1.6 with rating 7.6 / 10.', 'lud'),
#  ('HelloThe Steel Helmetruntime is1.4 with rating 7.5 / 10.', 'lme'),
#  ('HelloStorm Warningruntime is1.6 with rating 7.2 / 10.', 'nin'),
#  ('HelloThe Strange Doorruntime is1.4 with rating 6.3 / 10.', 'Doo'),
#  ('HelloA Streetcar Named Desireruntime is2.0 with rating 8 / 10.', 'sir'),
#  ('HelloThe Stripruntime is1.4 with rating 6 / 10.', 'tri'),
#  ('HelloThe Tall Targetruntime is1.3 with rating 7.2 / 10.', 'rge'),
#  ('HelloTen Tall Menruntime is1.6 with rating 6.2 / 10.', ' Me'),
#  ('HelloThe Thing from Another Worldruntime is1.5 with rating 7.2 / 10.', 'orl'),
#  ('HelloThree Guys Named Mikeruntime is1.5 with rating 6.2 / 10.', 'Mik'),
#  ('HelloThunder on the Hillruntime is1.4 with rating 6.8 / 10.', 'Hil'),
#  ('HelloTomahawkruntime is1.4 with rating 6.3 / 10.', 'haw'),
#  ('HelloMan of Strawruntime is1.8 with rating 7.3 / 10.', 'tra'),
#  ('HelloDer Verloreneruntime is1.6 with rating 7 / 10.', 'ren'),
#  ('HelloThe Wellruntime is1.4 with rating 7.2 / 10.', 'Wel'),
#  ('HelloWestward the Womenruntime is2.0 with rating 7.6 / 10.', 'ome'),
#  ('HelloYou Never Can Tellruntime is1.3 with rating 7.1 / 10.', 'Tel'),
#  ('Hello5 Fingersruntime is1.8 with rating 7.7 / 10.', 'ger'),
#  ('HelloAbove and Beyondruntime is2.0 with rating 6.9 / 10.', 'yon'),
#  ('HelloAffair in Trinidadruntime is1.6 with rating 6.7 / 10.', 'ida'),
#  ('HelloAgainst All Flagsruntime is1.4 with rating 6.6 / 10.', 'lag'),
#  ('HelloAndrocles and the Lionruntime is1.6 with rating 6.2 / 10.', 'Lio'),
#  ('HelloAngel Faceruntime is1.5 with rating 7.3 / 10.', 'Fac'),
#  ("HelloAnother Man's Poisonruntime is1.5 with rating 6.9 / 10.", 'iso'),
#  ('HelloApril in Parisruntime is1.7 with rating 6.1 / 10.', 'ari'),
#  ("HelloAt Sword's Pointruntime is1.4 with rating 6 / 10.", 'oin'),
#  ('HelloRobinson Crusoeruntime is1.5 with rating 6.8 / 10.', 'uso'),
#  ('HelloThe Bad and the Beautifulruntime is2.0 with rating 7.8 / 10.', 'ifu'),
#  ('HelloThe Battle at Apache Passruntime is1.4 with rating 6.4 / 10.', 'Pas'),
#  ('HelloThe Belle of New Yorkruntime is1.4 with rating 6.2 / 10.', 'Yor'),
#  ('HelloBeauties of the Nightruntime is1.5 with rating 6.9 / 10.', 'igh'),
#  ('HelloBelles on Their Toesruntime is1.5 with rating 6.7 / 10.', 'Toe'),
#  ('HelloBend of the Riverruntime is1.5 with rating 7.3 / 10.', 'ive'),
#  ('HelloBeware, My Lovelyruntime is1.3 with rating 6.7 / 10.', 'vel'),
#  ('HelloThe Big Skyruntime is2.3 with rating 7 / 10.', ' Sk'),
#  ('HelloThe Black Castleruntime is1.4 with rating 6.4 / 10.', 'stl'),
#  ('HelloBlackbeard, the Pirateruntime is1.7 with rating 6.1 / 10.', 'rat'),
#  ('HelloStruggle in the Valleyruntime is1.8 with rating 7.6 / 10.', 'lle'),
#  ('HelloThe Sound Barrierruntime is2.0 with rating 6.7 / 10.', 'rie'),
#  ('HelloEl brutoruntime is1.4 with rating 7.3 / 10.', 'rut'),
#  ('HelloThe Captive Cityruntime is1.5 with rating 6.5 / 10.', 'Cit'),
#  ('HelloCarbine Williamsruntime is1.5 with rating 7 / 10.', 'iam'),
#  ('HelloCarrieruntime is2.0 with rating 7.3 / 10.', 'rri'),
#  ('HelloCarson Cityruntime is1.5 with rating 6.4 / 10.', 'Cit'),
#  ('HelloChildren of Hiroshimaruntime is1.6 with rating 7.8 / 10.', 'him'),
#  ('HelloClash by Nightruntime is1.8 with rating 7.1 / 10.', 'igh'),
#  ('HelloWhite Maneruntime is0.8 with rating 7.3 / 10.', 'Man'),
#  ('HelloDeadline - U.S.A.runtime is1.5 with rating 7.2 / 10.', 'S.A'),
#  ('HelloDiplomatic Courierruntime is1.6 with rating 6.9 / 10.', 'rie'),
#  ("HelloDon't Bother to Knockruntime is1.3 with rating 6.9 / 10.", 'noc'),
#  ('HelloDreamboatruntime is1.4 with rating 6.8 / 10.', 'boa'),
#  ('HelloThe Duel at Silver Creekruntime is1.3 with rating 6.4 / 10.', 'ree'),
#  ('HelloThe Greatest Show on Earthruntime is2.5 with rating 6.6 / 10.', 'art'),
#  ('HelloThe Green Gloveruntime is1.5 with rating 6.2 / 10.', 'lov'),
#  ("HelloHangman's Knotruntime is1.4 with rating 6.7 / 10.", 'Kno'),
#  ('HelloHans Christian Andersenruntime is1.9 with rating 6.9 / 10.', 'rse'),
#  ('HelloHigh Noonruntime is1.4 with rating 7.9 / 10.', 'Noo'),
#  ('HelloThe Holly and the Ivyruntime is1.4 with rating 7.6 / 10.', ' Iv'),
#  ('HelloIkiruruntime is2.4 with rating 8.3 / 10.', 'kir'),
#  ('HelloIvanhoeruntime is1.8 with rating 6.8 / 10.', 'nho'),
#  ('HelloJumping Jacksruntime is1.6 with rating 6.4 / 10.', 'ack'),
#  ('HelloKansas City Confidentialruntime is1.7 with rating 7.4 / 10.', 'tia'),
#  ('HelloKvinnors väntanruntime is1.8 with rating 7.1 / 10.', 'nta'),
#  ('HelloThe Lavender Hill Mobruntime is1.3 with rating 7.6 / 10.', ' Mo'),
#  ('HelloLimelightruntime is2.3 with rating 8.1 / 10.', 'igh'),
#  ('HelloThe Long Memoryruntime is1.6 with rating 6.9 / 10.', 'mor'),
#  ('HelloLost in Alaskaruntime is1.3 with rating 6.5 / 10.', 'ask'),
#  ('HelloLovely to Look Atruntime is1.7 with rating 6.3 / 10.', 'k A'),
#  ('HelloThe Lusty Menruntime is1.9 with rating 7.4 / 10.', ' Me'),
#  ('HelloMacaoruntime is1.4 with rating 6.7 / 10.', 'aca'),
#  ('HelloThe Man in the White Suitruntime is1.4 with rating 7.3 / 10.', 'Sui'),
#  ('HelloThe Marrying Kindruntime is1.5 with rating 7.1 / 10.', 'Kin'),
#  ('HelloThe Member of the Weddingruntime is1.6 with rating 6.8 / 10.', 'din'),
#  ('HelloThe Miracle of Our Lady of Fatimaruntime is1.7 with rating 6.8 / 10.', 'tim'),
#  ('HelloLes Miserablesruntime is1.8 with rating 6.9 / 10.', 'ble'),
#  ('HelloMonkey Businessruntime is1.6 with rating 7 / 10.', 'nes'),
#  ('HelloMoulin Rougeruntime is2.0 with rating 7.1 / 10.', 'oug'),
#  ('HelloMy Cousin Rachelruntime is1.6 with rating 7.1 / 10.', 'che'),
#  ('HelloThe Naked Spurruntime is1.5 with rating 7.4 / 10.', 'Spu'),
#  ('HelloThe Narrow Marginruntime is1.2 with rating 7.7 / 10.', 'rgi'),
#  ('HelloThe Flavor of Green Tea Over Riceruntime is1.9 with rating 7.8 / 10.', 'Ric'),
#  ('HelloMotherruntime is1.6 with rating 7.6 / 10.', 'the'),
#  ('HelloPark Rowruntime is1.4 with rating 7.3 / 10.', ' Ro'),
#  ('HelloPat and Mikeruntime is1.6 with rating 7 / 10.', 'Mik'),
#  ('HelloPlymouth Adventureruntime is1.8 with rating 6.3 / 10.', 'tur'),
#  ('HelloPony Soldierruntime is1.4 with rating 6 / 10.', 'die'),
#  ('HelloThe Pride of St. Louisruntime is1.6 with rating 6.6 / 10.', 'oui'),
#  ('HelloThe Prisoner of Zendaruntime is1.6 with rating 7 / 10.', 'end'),
#  ('HelloThe Promoterruntime is1.4 with rating 7.1 / 10.', 'ote'),
#  ('HelloThe Quiet Manruntime is2.2 with rating 7.8 / 10.', ' Ma'),
#  ('HelloRancho Notoriousruntime is1.5 with rating 7 / 10.', 'iou'),
#  ('HelloThe Return of Don Camilloruntime is1.9 with rating 7.3 / 10.', 'ill'),
#  ('HelloThe Ringruntime is1.3 with rating 6.2 / 10.', 'Rin'),
#  ('HelloRoom for One Moreruntime is1.6 with rating 7.1 / 10.', 'Mor'),
#  ('HelloRuby Gentryruntime is1.4 with rating 6.7 / 10.', 'ntr'),
#  ('HelloScaramoucheruntime is1.9 with rating 7.5 / 10.', 'uch'),
#  ("HelloSingin' in the Rainruntime is1.7 with rating 8.3 / 10.", 'Rai'),
#  ('HelloThe Snows of Kilimanjaroruntime is1.9 with rating 6.2 / 10.', 'jar'),
#  ('HelloSpringfield Rifleruntime is1.6 with rating 6.7 / 10.', 'ifl'),
#  ('HelloThe Starruntime is1.5 with rating 7 / 10.', 'Sta'),
#  ('HelloThe Steel Trapruntime is1.4 with rating 6.9 / 10.', 'Tra'),
#  ('HelloStolen Faceruntime is1.2 with rating 6.1 / 10.', 'Fac'),
#  ('HelloThe Stoogeruntime is1.7 with rating 6.9 / 10.', 'oog'),
#  ('HelloThe Stranger in Betweenruntime is1.4 with rating 7.4 / 10.', 'wee'),
#  ('HelloTalk About a Strangerruntime is1.1 with rating 6.2 / 10.', 'nge'),
#  ('HelloThe Thiefruntime is1.4 with rating 6.7 / 10.', 'hie'),
#  ('HelloUmberto D.runtime is1.5 with rating 8.2 / 10.', 'o D'),
#  ('HelloI vintiruntime is1.9 with rating 6.6 / 10.', 'int'),
#  ('HelloWay of a Gauchoruntime is1.5 with rating 6.7 / 10.', 'uch'),
#  ("HelloWe're Not Married!runtime is1.4 with rating 6.4 / 10.", 'ied'),
#  ('HelloThe Wild Northruntime is1.6 with rating 6.6 / 10.', 'ort'),
#  ('HelloWith a Song in My Heartruntime is2.0 with rating 6.8 / 10.', 'ear'),
#  ('HelloThe World in His Armsruntime is1.7 with rating 6.9 / 10.', 'Arm'),
#  ('HelloElruntime is1.5 with rating 8 / 10.', 'E'),
#  ('HelloThe 5,000 Fingers of Dr. T.runtime is1.5 with rating 6.8 / 10.', '. T'),
#  ('HelloAbbott and Costello Go to Marsruntime is1.3 with rating 6.1 / 10.', 'Mar'),
#  ('HelloDie Geschichte vom kleinen Muckruntime is1.7 with rating 6.9 / 10.', 'Muc'),
#  ('HelloThe Actressruntime is1.5 with rating 6.5 / 10.', 'res'),
#  ('HelloThe Affairs of Dobie Gillisruntime is1.2 with rating 6.1 / 10.', 'lli'),
#  ('HelloAll I Desireruntime is1.3 with rating 7.1 / 10.', 'sir'),
#  ('HelloLove in the Cityruntime is1.9 with rating 6.5 / 10.', 'Cit'),
#  ('HelloArrowheadruntime is1.8 with rating 6.1 / 10.', 'hea'),
#  ('HelloThe Band Wagonruntime is1.9 with rating 7.5 / 10.', 'ago'),
#  ('HelloBattle Circusruntime is1.5 with rating 6 / 10.', 'rcu'),
#  ('HelloThe Beast from 20,000 Fathomsruntime is1.3 with rating 6.7 / 10.', 'hom'),
#  ('HelloThe Big Heatruntime is1.5 with rating 8 / 10.', 'Hea'),
#  ('HelloThe Bigamistruntime is1.3 with rating 6.7 / 10.', 'mis'),
#  ('HelloBlowing Wildruntime is1.5 with rating 6.5 / 10.', 'Wil'),
#  ('HelloThe Blue Gardeniaruntime is1.4 with rating 6.9 / 10.', 'eni'),
#  ('HelloA Blueprint for Murderruntime is1.3 with rating 6.8 / 10.', 'rde'),
#  ('HelloThe Caddyruntime is1.6 with rating 6.5 / 10.', 'add'),
#  ('HelloCalamity Janeruntime is1.7 with rating 7.3 / 10.', 'Jan'),
#  ('HelloCall Me Madamruntime is1.9 with rating 6.8 / 10.', 'ada'),
#  ("HelloThe Captain's Paradiseruntime is1.6 with rating 7 / 10.", 'dis'),
#  ('HelloCity That Never Sleepsruntime is1.5 with rating 6.9 / 10.', 'eep'),
#  ('HelloCrash of Silenceruntime is1.6 with rating 7.4 / 10.', 'enc'),
#  ('HelloThe Cruel Searuntime is2.1 with rating 7.5 / 10.', ' Se'),
#  ('HelloDangerous Crossingruntime is1.3 with rating 7.1 / 10.', 'sin'),
#  ('HelloThe Desert Ratsruntime is1.5 with rating 6.8 / 10.', 'Rat'),
#  ('HelloDestination Gobiruntime is1.5 with rating 6.3 / 10.', 'Gob'),
#  ('HelloDo Bigha Zaminruntime is2.2 with rating 8.4 / 10.', 'ami'),
#  ("HelloDonovan's Brainruntime is1.4 with rating 6 / 10.", 'rai'),
#  ('HelloDream Wiferuntime is1.7 with rating 6.1 / 10.', 'Wif'),
#  ('HelloEscape from Fort Bravoruntime is1.7 with rating 6.7 / 10.', 'rav'),
#  ('HelloGentlemen Prefer Blondesruntime is1.5 with rating 7.2 / 10.', 'nde'),
#  ('HelloA Geisharuntime is1.4 with rating 7.6 / 10.', 'ish'),
#  ('HelloThe Glass Wallruntime is1.4 with rating 6.8 / 10.', 'Wal'),
#  ('HelloGun Furyruntime is1.4 with rating 6 / 10.', 'Fur'),
#  ('HelloSawdust and Tinselruntime is1.6 with rating 7.6 / 10.', 'nse'),
#  ("HelloHis Majesty O'Keeferuntime is1.5 with rating 6.2 / 10.", 'eef'),
#  ('HelloThe Hitch-Hikerruntime is1.2 with rating 7 / 10.', 'ike'),
#  ('HelloHondoruntime is1.4 with rating 7.1 / 10.', 'ond'),
#  ('HelloHoudiniruntime is1.8 with rating 6.9 / 10.', 'din'),
#  ('HelloHouse of Waxruntime is1.5 with rating 7.1 / 10.', ' Wa'),
#  ('HelloHow to Marry a Millionaireruntime is1.6 with rating 6.9 / 10.', 'air'),
#  ('HelloI Confessruntime is1.6 with rating 7.3 / 10.', 'fes'),
#  ('HelloI Love Melvinruntime is1.3 with rating 6.7 / 10.', 'lvi'),
#  ('HelloInfernoruntime is1.4 with rating 7.1 / 10.', 'ern'),
#  ('HelloInvaders from Marsruntime is1.3 with rating 6.4 / 10.', 'Mar'),
#  ('HelloIsland in the Skyruntime is1.8 with rating 6.9 / 10.', ' Sk'),
#  ('HelloIt Came from Outer Spaceruntime is1.4 with rating 6.5 / 10.', 'pac'),
#  ('HelloJeopardyruntime is1.2 with rating 6.8 / 10.', 'ard'),
#  ('HelloGate of Hellruntime is1.5 with rating 7.2 / 10.', 'Hel'),
#  ('HelloKing of the Khyber Riflesruntime is1.7 with rating 6.4 / 10.', 'fle'),
#  ('HelloKiss Me Kateruntime is1.8 with rating 7.1 / 10.', 'Kat'),
#  ('HelloKnights of the Round Tableruntime is1.9 with rating 6.3 / 10.', 'abl'),
#  ('HelloMiss Sadie Thompsonruntime is1.5 with rating 6 / 10.', 'pso'),
#  ('HelloThe Mississippi Gamblerruntime is1.7 with rating 6.8 / 10.', 'ble'),
#  ('HelloMogamboruntime is1.9 with rating 6.7 / 10.', 'amb'),
#  ('HelloMoney from Homeruntime is1.7 with rating 6.3 / 10.', 'Hom'),
#  ('HelloThe Moon Is Blueruntime is1.7 with rating 6.7 / 10.', 'Blu'),
#  ('HelloNever Let Me Goruntime is1.6 with rating 6.2 / 10.', 'e G'),
#  ('HelloNiagararuntime is1.5 with rating 7 / 10.', 'gar'),
#  ('HelloThe Proud and the Beautifulruntime is1.7 with rating 7.4 / 10.', 'ifu'),
#  ('HelloBread, Love and Dreamsruntime is1.6 with rating 7 / 10.', 'eam'),
#  ('HelloPeter Panruntime is1.3 with rating 7.3 / 10.', ' Pa'),
#  ('HelloPickup on South Streetruntime is1.3 with rating 7.7 / 10.', 'ree'),
#  ('HelloPlunder of the Sunruntime is1.4 with rating 6.5 / 10.', ' Su'),
#  ("HelloThe President's Ladyruntime is1.6 with rating 7 / 10.", 'Lad'),
#  ('HelloThe Roberuntime is2.3 with rating 6.7 / 10.', 'Rob'),
#  ('HelloRoman Holidayruntime is2.0 with rating 8 / 10.', 'ida'),
#  ('HelloThe Wages of Fearruntime is2.2 with rating 8.1 / 10.', 'Fea'),
#  ('HelloScared Stiffruntime is1.8 with rating 6.5 / 10.', 'tif'),
#  ('HelloSecond Chanceruntime is1.4 with rating 6 / 10.', 'anc'),
#  ('HelloSeminoleruntime is1.5 with rating 6.2 / 10.', 'nol'),
#  ('HelloShaneruntime is2.0 with rating 7.6 / 10.', 'han'),
#  ('HelloSmall Town Girlruntime is1.5 with rating 6.3 / 10.', 'Gir'),
#  ('HelloSouth Sea Womanruntime is1.7 with rating 6.4 / 10.', 'oma'),
#  ('HelloSplit Secondruntime is1.4 with rating 6.9 / 10.', 'con'),
#  ('HelloStalag 17runtime is2.0 with rating 8 / 10.', 'g 1'),
#  ('HelloIndiscretion of an American Wiferuntime is1.5 with rating 6.2 / 10.', 'Wif'),
#  ('HelloThe Story of Three Lovesruntime is2.0 with rating 7 / 10.', 'ove'),
#  ('HelloThe Sun Shines Brightruntime is1.5 with rating 7 / 10.', 'igh'),
#  ('HelloBeat the Devilruntime is1.5 with rating 6.5 / 10.', 'evi'),
#  ('HelloThe Lawless Breedruntime is1.4 with rating 6.4 / 10.', 'ree'),
#  ('HelloLiliruntime is1.4 with rating 7.4 / 10.', 'Lil'),
#  ('HelloA Lion Is in the Streetsruntime is1.5 with rating 6.2 / 10.', 'eet'),
#  ('HelloLittle Fugitiveruntime is1.3 with rating 7.5 / 10.', 'tiv'),
#  ('HelloThe Living Desertruntime is1.2 with rating 7.5 / 10.', 'ser'),
#  ('HelloThe Earrings of Madame De...runtime is1.8 with rating 8 / 10.', 'e..'),
#  ('HelloMalta Storyruntime is1.7 with rating 6.5 / 10.', 'tor'),
#  ('HelloThe Man Betweenruntime is1.7 with rating 7.1 / 10.', 'wee'),
#  ('HelloThe Man from the Alamoruntime is1.3 with rating 6.5 / 10.', 'lam'),
#  ('HelloMan on a Tightroperuntime is1.8 with rating 7.1 / 10.', 'rop'),
#  ('HelloThe Count of Monte Cristoruntime is3.1 with rating 7.2 / 10.', 'ist'),
#  ('HelloThunder Bayruntime is1.7 with rating 6.5 / 10.', ' Ba'),
#  ('HelloThunder Over the Plainsruntime is1.4 with rating 6.5 / 10.', 'ain'),
#  ('HelloThe Adultressruntime is1.7 with rating 7.3 / 10.', 'res'),
#  ('HelloTitanicruntime is1.6 with rating 7 / 10.', 'ani'),
#  ('HelloThe Titfield Thunderboltruntime is1.4 with rating 7.1 / 10.', 'bol'),
#  ('HelloTrouble Along the Wayruntime is1.9 with rating 6.9 / 10.', ' Wa'),
#  ('HelloTrouble in Storeruntime is1.4 with rating 6.8 / 10.', 'tor'),
#  ('HelloJourney to Italyruntime is1.4 with rating 7.4 / 10.', 'tal'),
#  ('HelloI Vitelloniruntime is1.8 with rating 7.9 / 10.', 'lon'),
#  ('HelloTumbleweedruntime is1.3 with rating 6.7 / 10.', 'wee'),
#  ('HelloUgetsuruntime is1.6 with rating 8.3 / 10.', 'ets'),
#  ('HelloYoung Bessruntime is1.9 with rating 6.7 / 10.', 'Bes'),
#  ("HelloMonsieur Hulot's Holidayruntime is1.9 with rating 7.5 / 10.", 'ida'),
#  ('HelloSkanderbegruntime is1.6 with rating 7.9 / 10.', 'rbe'),
#  ('HelloVesnaruntime is1.6 with rating 8.1 / 10.', 'esn'),
#  ('HelloLate Chrysanthemumsruntime is1.7 with rating 7.4 / 10.', 'mum'),
#  ('HelloThe Barefoot Contessaruntime is2.1 with rating 7 / 10.', 'ess'),
#  ('HelloBeau Brummellruntime is1.9 with rating 6.4 / 10.', 'mel'),
#  ('HelloBetrayedruntime is1.8 with rating 6.1 / 10.', 'aye'),
#  ('HelloBlack Widowruntime is1.6 with rating 6.7 / 10.', 'ido'),
#  ('Hello20,000 Leagues Under the Searuntime is2.1 with rating 7.2 / 10.', ' Se'),
#  ('HelloWuthering Heightsruntime is1.5 with rating 6.7 / 10.', 'ght'),
#  ('HelloAbout Mrs. Leslieruntime is1.7 with rating 7.1 / 10.', 'sli'),
#  ('HelloThe Bridges at Toko-Riruntime is1.7 with rating 6.7 / 10.', 'o-R'),
#  ('HelloAn American in Romeruntime is1.6 with rating 7 / 10.', 'Rom'),
#  ('HelloAnatahanruntime is1.5 with rating 7.2 / 10.', 'aha'),
#  ('HelloAngels One Fiveruntime is1.6 with rating 6.5 / 10.', 'Fiv'),
#  ('HelloBrigadoonruntime is1.8 with rating 6.8 / 10.', 'doo'),
#  ('HelloBroken Lanceruntime is1.6 with rating 6.9 / 10.', 'anc'),
#  ('HelloThe Caine Mutinyruntime is2.1 with rating 7.7 / 10.', 'tin'),
#  ('HelloCarmen Jonesruntime is1.8 with rating 6.8 / 10.', 'one'),
#  ("HelloCasanova's Big Nightruntime is1.4 with rating 6.9 / 10.", 'igh'),
#  ('HelloThe Country Girlruntime is1.7 with rating 7.3 / 10.', 'Gir'),
#  ('HelloCrime Waveruntime is1.2 with rating 7.4 / 10.', 'Wav'),
#  ('HelloThe Dam Bustersruntime is2.1 with rating 7.4 / 10.', 'ter'),
#  ('HelloDemetrius and the Gladiatorsruntime is1.7 with rating 6.6 / 10.', 'tor'),
#  ('HelloDésiréeruntime is1.8 with rating 6.4 / 10.', 'iré'),
#  ('HelloDestryruntime is1.6 with rating 6.6 / 10.', 'str'),
#  ('HelloSchool for Trampsruntime is1.7 with rating 8 / 10.', 'amp'),
#  ('HelloDiaboliqueruntime is2.0 with rating 8 / 10.', 'iqu'),
#  ('HelloDial M for Murderruntime is1.8 with rating 8.2 / 10.', 'rde'),
#  ('HelloDoctor in the Houseruntime is1.5 with rating 6.6 / 10.', 'ous'),
#  ('HelloDown Three Dark Streetsruntime is1.4 with rating 6.8 / 10.', 'eet'),
#  ('HelloDragnetruntime is1.5 with rating 6.7 / 10.', 'gne'),
#  ('HelloDrive a Crooked Roadruntime is1.4 with rating 7 / 10.', 'Roa'),
#  ('HelloDrum Beatruntime is1.9 with rating 6.4 / 10.', 'Bea'),
#  ('HelloThe Egyptianruntime is2.3 with rating 6.6 / 10.', 'tia'),
#  ('HelloExecutive Suiteruntime is1.7 with rating 7.4 / 10.', 'uit'),
#  ('HelloThe Detectiveruntime is1.5 with rating 6.8 / 10.', 'tiv'),
#  ('HelloFrench Cancanruntime is1.7 with rating 7.3 / 10.', 'nca'),
#  ('HelloLiving It Upruntime is1.6 with rating 6.7 / 10.', 't U'),
#  ('HelloLucky Meruntime is1.7 with rating 6 / 10.', 'y M'),
#  ('HelloThe Mad Magicianruntime is1.2 with rating 6.5 / 10.', 'cia'),
#  ('HelloGodzillaruntime is1.6 with rating 7.6 / 10.', 'ill'),
#  ('HelloThe Miracle of Marcelinoruntime is1.5 with rating 7.1 / 10.', 'lin'),
#  ('HelloMiseria e nobiltàruntime is1.6 with rating 7.8 / 10.', 'ilt'),
#  ('HelloThe Story of Vickieruntime is2.0 with rating 6.5 / 10.', 'cki'),
#  ('HelloNaked Alibiruntime is1.4 with rating 6.5 / 10.', 'lib'),
#  ('HelloNight Peopleruntime is1.6 with rating 6.5 / 10.', 'opl'),
#  ('HelloTwenty-Four Eyesruntime is2.6 with rating 8 / 10.', 'Eye'),
#  ('HelloThe Good Die Youngruntime is1.7 with rating 6.7 / 10.', 'oun'),
#  ('HelloRhapsodyruntime is1.9 with rating 6.2 / 10.', 'sod'),
#  ('HelloRide Clear of Diabloruntime is1.4 with rating 6.9 / 10.', 'abl'),
#  ('HelloOn the Waterfrontruntime is1.8 with rating 8.1 / 10.', 'ron'),
#  ('HelloThe Gold of Naplesruntime is2.3 with rating 7.3 / 10.', 'ple'),
#  ('HelloRiding Shotgunruntime is1.2 with rating 6.5 / 10.', 'tgu'),
#  ('HelloRiot in Cell Block 11runtime is1.3 with rating 7 / 10.', 'k 1'),
#  ('HelloRiver of No Returnruntime is1.5 with rating 6.6 / 10.', 'tur'),
#  ('HelloPhffftruntime is1.5 with rating 6.6 / 10.', 'fff'),
#  ('HelloPrince Valiantruntime is1.7 with rating 6.2 / 10.', 'ian'),
#  ('HelloPrivate Hell 36runtime is1.4 with rating 6.7 / 10.', 'l 3'),
#  ('HelloThe Purple Plainruntime is1.6 with rating 6.5 / 10.', 'lai'),
#  ('HelloPushoverruntime is1.5 with rating 7.1 / 10.', 'ove'),
#  ('HelloRogue Copruntime is1.5 with rating 6.7 / 10.', ' Co'),
#  ('HelloThe Raidruntime is1.4 with rating 6.8 / 10.', 'Rai'),
#  ('HelloRear Windowruntime is1.9 with rating 8.5 / 10.', 'ndo'),
#  ('HelloThe River and Deathruntime is1.5 with rating 6.8 / 10.', 'eat'),
#  ('HelloSabrinaruntime is1.9 with rating 7.7 / 10.', 'rin'),
#  ('HelloSalt of the Earthruntime is1.6 with rating 7.4 / 10.', 'art'),
#  ('HelloSansho the Bailiffruntime is2.1 with rating 8.4 / 10.', 'lif'),
#  ('HelloSaskatchewanruntime is1.5 with rating 6.4 / 10.', 'ewa'),
#  ('HelloSeven Brides for Seven Brothersruntime is1.7 with rating 7.4 / 10.', 'her'),
#  ('HelloA Star Is Bornruntime is2.6 with rating 7.6 / 10.', 'Bor'),
#  ('HelloShield for Murderruntime is1.4 with rating 6.9 / 10.', 'rde'),
#  ('HelloThe Student Princeruntime is1.8 with rating 6.6 / 10.', 'inc'),
#  ('HelloSuddenlyruntime is1.3 with rating 6.8 / 10.', 'enl'),
#  ('HelloSusan Slept Hereruntime is1.6 with rating 6.5 / 10.', 'Her'),
#  ("HelloThe Devil's Generalruntime is2.0 with rating 7.3 / 10.", 'era'),
#  ('HelloThem!runtime is1.6 with rating 7.2 / 10.', 'hem'),
#  ("HelloThere's No Business Like Show Businessruntime is2.0 with rating 6.5 / 10.", 'nes'),
#  ('HelloThree Cases of Murderruntime is1.7 with rating 6.6 / 10.', 'rde'),
#  ('HelloThree Hours to Killruntime is1.3 with rating 6.4 / 10.', 'Kil'),
#  ('HelloTrack of the Catruntime is1.7 with rating 6.5 / 10.', ' Ca'),
#  ('HelloHell and High Waterruntime is1.7 with rating 6.2 / 10.', 'ate'),
#  ('HelloHigh and Dryruntime is1.5 with rating 7 / 10.', ' Dr'),
#  ('HelloThe High and the Mightyruntime is2.5 with rating 6.8 / 10.', 'ght'),
#  ("HelloHobson's Choiceruntime is1.8 with rating 7.7 / 10.", 'oic'),
#  ('HelloHuman Desireruntime is1.5 with rating 7.2 / 10.', 'sir'),
#  ('HelloAn Inspector Callsruntime is1.3 with rating 7.5 / 10.', 'all'),
#  ('HelloKnock on Woodruntime is1.7 with rating 6.8 / 10.', 'Woo'),
#  ('HelloSilver Loderuntime is1.4 with rating 6.9 / 10.', 'Lod'),
#  ('HelloThe Sleeping Tigerruntime is1.5 with rating 6.5 / 10.', 'ige'),
#  ('HelloUlyssesruntime is2.0 with rating 6.7 / 10.', 'sse'),
#  ('HelloValley of the Kingsruntime is1.4 with rating 6 / 10.', 'ing'),
#  ('HelloBad Day at Black Rockruntime is1.4 with rating 7.7 / 10.', 'Roc'),
#  ('HelloWhite Christmasruntime is2.0 with rating 7.6 / 10.', 'tma'),
#  ('HelloThe Wild Oneruntime is1.3 with rating 6.8 / 10.', ' On'),
#  ('HelloWitness to Murderruntime is1.4 with rating 6.7 / 10.', 'rde'),
#  ('HelloSound of the Mountainruntime is1.6 with rating 7.8 / 10.', 'tai'),
#  ('HelloYoung at Heartruntime is2.0 with rating 6.8 / 10.', 'ear'),
#  ('HelloBattle Cryruntime is2.5 with rating 6.5 / 10.', ' Cr'),
#  ('HelloThe Benny Goodman Storyruntime is1.9 with rating 6.7 / 10.', 'tor'),
#  ('HelloThe Big Comboruntime is1.5 with rating 7.4 / 10.', 'omb'),
#  ('HelloAbbott and Costello Meet the Mummyruntime is1.3 with rating 6.4 / 10.', 'umm'),
#  ('HelloAbove Us the Wavesruntime is1.7 with rating 6.6 / 10.', 'ave'),
#  ('HelloLe Amicheruntime is1.7 with rating 7.2 / 10.', 'ich'),
#  ('HelloBig House, U.S.A.runtime is1.4 with rating 6.7 / 10.', 'S.A'),
#  ('HelloAnimal Farmruntime is1.2 with rating 7.2 / 10.', 'Far'),
#  ('HelloArtists and Modelsruntime is1.8 with rating 6.6 / 10.', 'del'),
#  ('HelloThe Big Kniferuntime is1.9 with rating 6.8 / 10.', 'nif'),
#  ('HelloBlackboard Jungleruntime is1.7 with rating 7.4 / 10.', 'ngl'),
#  ('HelloDaddy Long Legsruntime is2.1 with rating 6.7 / 10.', 'Leg'),
#  ('HelloDementiaruntime is0.9 with rating 6.8 / 10.', 'nti'),
#  ('HelloDavy Crockett: King of the Wild Frontierruntime is1.6 with rating 7 / 10.', 'tie'),
#  ('HelloBob le Flambeurruntime is1.6 with rating 7.7 / 10.', 'beu'),
#  ('HelloA Bullet for Joeyruntime is1.4 with rating 6 / 10.', 'Joe'),
#  ('HelloRififiruntime is2.0 with rating 8.2 / 10.', 'fif'),
#  ('HelloEast of Edenruntime is2.0 with rating 7.9 / 10.', 'Ede'),
#  ('HelloThe Far Countryruntime is1.6 with rating 7.2 / 10.', 'ntr'),
#  ('HelloThe Far Horizonsruntime is1.8 with rating 6.1 / 10.', 'zon'),
#  ('HelloFemale on the Beachruntime is1.6 with rating 6.5 / 10.', 'eac'),
#  ('HelloFootsteps in the Fogruntime is1.5 with rating 7 / 10.', ' Fo'),
#  ('HelloThe End of the Affairruntime is1.8 with rating 6.7 / 10.', 'fai'),
#  ('HelloWee Geordieruntime is1.6 with rating 6.9 / 10.', 'rdi'),
#  ('HelloThe Glass Slipperruntime is1.6 with rating 6.5 / 10.', 'ppe'),
#  ('HelloThe Grand Maneuverruntime is1.8 with rating 6.8 / 10.', 'uve'),
#  ('HelloGuys and Dollsruntime is2.5 with rating 7.2 / 10.', 'oll'),
#  ('HelloCaptain Lightfootruntime is1.5 with rating 6.2 / 10.', 'foo'),
#  ('HelloThat Is the Dawnruntime is1.7 with rating 6.8 / 10.', 'Daw'),
#  ('HelloBloody Spear at Mount Fujiruntime is1.6 with rating 7.4 / 10.', 'Fuj'),
#  ('HelloThe Cobwebruntime is2.2 with rating 6.4 / 10.', 'bwe'),
#  ('HelloThe Colditz Storyruntime is1.6 with rating 7 / 10.', 'tor'),
#  ('HelloCity of Fearruntime is1.4 with rating 6.4 / 10.', 'Fea'),
#  ('HelloMister Robertsruntime is2.1 with rating 7.7 / 10.', 'ert'),
#  ('HelloDreamsruntime is1.5 with rating 7.1 / 10.', 'eam'),
#  ('HelloMerry-Go-Roundruntime is1.5 with rating 7.8 / 10.', 'oun'),
#  ('HelloLady and the Trampruntime is1.3 with rating 7.3 / 10.', 'ram'),
#  ('HelloThe Ladykillersruntime is1.5 with rating 7.7 / 10.', 'ler'),
#  ('HelloLand of the Pharaohsruntime is1.8 with rating 6.6 / 10.', 'aoh'),
#  ('HelloThe Last Commandruntime is1.8 with rating 6.4 / 10.', 'man'),
#  ('HelloA Lawless Streetruntime is1.3 with rating 6.4 / 10.', 'ree'),
#  ('HelloThe Left Hand of Godruntime is1.5 with rating 6.5 / 10.', ' Go'),
#  ('HelloLola Montèsruntime is1.9 with rating 7.3 / 10.', 'ntè'),
#  ('HelloThe Long Gray Lineruntime is2.3 with rating 7.2 / 10.', 'Lin'),
#  ('HelloLove Is a Many-Splendored Thingruntime is1.7 with rating 6.5 / 10.', 'hin'),
#  ('HelloLove Me or Leave Meruntime is2.0 with rating 7.1 / 10.', 'e M'),
#  ('HelloA Man Aloneruntime is1.6 with rating 6.4 / 10.', 'lon'),
#  ('HelloA Man Called Peterruntime is2.0 with rating 7.1 / 10.', 'ete'),
#  ('HelloMan with the Gunruntime is1.4 with rating 6.7 / 10.', ' Gu'),
#  ('HelloMan Without a Starruntime is1.5 with rating 6.9 / 10.', 'Sta'),
#  ('HelloThe Man from Laramieruntime is1.7 with rating 7.4 / 10.', 'ami'),
#  ('HelloThe Man with the Golden Armruntime is2.0 with rating 7.4 / 10.', ' Ar'),
#  ('HelloMany Rivers to Crossruntime is1.6 with rating 6.3 / 10.', 'ros'),
#  ('HelloMartyruntime is1.5 with rating 7.7 / 10.', 'art'),
#  ('HelloMaksim Perepelitsaruntime is1.6 with rating 7.7 / 10.', 'its'),
#  ('HelloHit the Deckruntime is1.9 with rating 6.6 / 10.', 'Dec'),
#  ('HelloHouse of Bambooruntime is1.7 with rating 6.8 / 10.', 'mbo'),
#  ('HelloI Died a Thousand Timesruntime is1.8 with rating 6.4 / 10.', 'ime'),
#  ("HelloI'll Cry Tomorrowruntime is2.0 with rating 7.2 / 10.", 'rro'),
#  ('HelloI Live in Fearruntime is1.7 with rating 7.3 / 10.', 'Fea'),
#  ('HelloIllegalruntime is1.5 with rating 7 / 10.', 'ega'),
#  ('HelloThe Indian Fighterruntime is1.5 with rating 6.4 / 10.', 'hte'),
#  ('HelloInterrupted Melodyruntime is1.8 with rating 6.7 / 10.', 'lod'),
#  ('HelloIt Came from Beneath the Searuntime is1.3 with rating 6 / 10.', ' Se'),
#  ("HelloIt's Always Fair Weatherruntime is1.7 with rating 7 / 10.", 'the'),
#  ('HelloJubalruntime is1.7 with rating 7.1 / 10.', 'uba'),
#  ('HelloThe Kentuckianruntime is1.7 with rating 6.3 / 10.', 'kia'),
#  ("HelloKiller's Kissruntime is1.1 with rating 6.7 / 10.", 'Kis'),
#  ('HelloKismetruntime is1.9 with rating 6.3 / 10.', 'sme'),
#  ('HelloKiss Me Deadlyruntime is1.8 with rating 7.6 / 10.', 'adl'),
#  ('HelloThe Phenix City Storyruntime is1.7 with rating 7.2 / 10.', 'tor'),
#  ('HelloLa Pointe Courteruntime is1.4 with rating 7.1 / 10.', 'urt'),
#  ('HelloA Generationruntime is1.5 with rating 7.1 / 10.', 'tio'),
#  ('HelloThe Prisonerruntime is1.6 with rating 6.9 / 10.', 'one'),
#  ('HelloThe Private War of Major Bensonruntime is1.8 with rating 6.6 / 10.', 'nso'),
#  ('HelloQueen Beeruntime is1.6 with rating 6.7 / 10.', ' Be'),
#  ('HelloQuentin Durwardruntime is1.7 with rating 6.5 / 10.', 'war'),
#  ('HelloRage at Dawnruntime is1.5 with rating 6 / 10.', 'Daw'),
#  ('HelloRebel Without a Causeruntime is1.9 with rating 7.7 / 10.', 'aus'),
#  ('HelloThe Rose Tattooruntime is2.0 with rating 7.1 / 10.', 'tto'),
#  ('HelloRun for Coverruntime is1.6 with rating 6.7 / 10.', 'ove'),
#  ('HelloThe Scarlet Coatruntime is1.7 with rating 6.3 / 10.', 'Coa'),
#  ('HelloThe Sea Chaseruntime is2.0 with rating 6.5 / 10.', 'has'),
#  ('HelloThe Seven Year Itchruntime is1.8 with rating 7.1 / 10.', 'Itc'),
#  ('HelloShack Out on 101runtime is1.3 with rating 6.4 / 10.', ' 10'),
#  ('HelloShree 420runtime is2.8 with rating 8.1 / 10.', ' 42'),
#  ('HelloSissiruntime is1.7 with rating 7 / 10.', 'iss'),
#  ('HelloSoldier of Fortuneruntime is1.6 with rating 6.2 / 10.', 'tun'),
#  ('HelloSmiles of a Summer Nightruntime is1.8 with rating 7.8 / 10.', 'igh'),
#  ('HelloStellaruntime is1.5 with rating 8 / 10.', 'ell'),
#  ('HelloSummertimeruntime is1.7 with rating 7.2 / 10.', 'tim'),
#  ('HelloTall Man Ridingruntime is1.4 with rating 6.4 / 10.', 'din'),
#  ('HelloThe Tall Menruntime is2.0 with rating 6.7 / 10.', ' Me'),
#  ('HelloTarantularuntime is1.3 with rating 6.5 / 10.', 'tul'),
#  ('HelloMoonfleetruntime is1.4 with rating 6.7 / 10.', 'lee'),
#  ('HelloMr. Arkadinruntime is1.6 with rating 7.3 / 10.', 'adi'),
#  ('HelloThe Naked Dawnruntime is1.4 with rating 6.7 / 10.', 'Daw'),
#  ('HelloThe Naked Streetruntime is1.4 with rating 6.5 / 10.', 'ree'),
#  ('HelloTen Wanted Menruntime is1.3 with rating 6 / 10.', ' Me'),
#  ('HelloNot as a Strangerruntime is2.3 with rating 6.7 / 10.', 'nge'),
#  ('HelloTight Spotruntime is1.6 with rating 6.6 / 10.', 'Spo'),
#  ('HelloTo Catch a Thiefruntime is1.8 with rating 7.4 / 10.', 'hie'),
#  ('HelloTo Hell and Backruntime is1.8 with rating 7.2 / 10.', 'Bac'),
#  ('HelloTrialruntime is1.8 with rating 6.8 / 10.', 'ria'),
#  ('HelloThe Trouble with Harryruntime is1.7 with rating 7.1 / 10.', 'arr'),
#  ('HelloThe Unknown Soldierruntime is3.0 with rating 8 / 10.', 'die'),
#  ('HelloFloating Cloudsruntime is2.1 with rating 7.7 / 10.', 'oud'),
#  ('HelloUntamedruntime is1.9 with rating 6.2 / 10.', 'ame'),
#  ('HelloWichitaruntime is1.4 with rating 6.9 / 10.', 'hit'),
#  ('HelloPrincess Yang Kwei-feiruntime is1.6 with rating 7.2 / 10.', '-fe'),
#  ('HelloThe Violent Menruntime is1.6 with rating 7 / 10.', ' Me'),
#  ('HelloViolent Saturdayruntime is1.5 with rating 6.9 / 10.', 'rda'),
#  ('HelloThe Virgin Queenruntime is1.5 with rating 6.8 / 10.', 'uee'),
#  ("HelloWe're No Angelsruntime is1.8 with rating 7.5 / 10.", 'gel'),
#  ('HelloOrdetruntime is2.1 with rating 8.4 / 10.', 'rde'),
#  ('HelloOur Miss Brooksruntime is1.4 with rating 6.6 / 10.', 'ook'),
#  ('HelloPather Panchaliruntime is2.1 with rating 8.6 / 10.', 'hal'),
#  ("HelloToo Bad She's Badruntime is1.6 with rating 6.8 / 10.", ' Ba'),
#  ('HelloDobrý voják Svejkruntime is1.8 with rating 7.6 / 10.', 'vej'),
#  ('Hello1984runtime is1.5 with rating 7 / 10.', '198'),
#  ('Hello23 Paces to Baker Streetruntime is1.7 with rating 6.9 / 10.', 'ree'),
#  ('HelloStreet of Shameruntime is1.5 with rating 7.9 / 10.', 'ham'),
#  ("HelloThe Ambassador's Daughterruntime is1.7 with rating 6 / 10.", 'hte'),
#  ('HelloAnastasiaruntime is1.8 with rating 7.1 / 10.', 'asi'),
#  ('HelloAnything Goesruntime is1.8 with rating 6.2 / 10.', 'Goe'),
#  ('HelloAparajitoruntime is1.8 with rating 8.3 / 10.', 'jit'),
#  ('HelloAttackruntime is1.8 with rating 7.4 / 10.', 'tac'),
#  ('HelloAutumn Leavesruntime is1.8 with rating 6.8 / 10.', 'ave'),
#  ('HelloAway All Boatsruntime is1.9 with rating 6.3 / 10.', 'oat'),
#  ('HelloBack from Eternityruntime is1.6 with rating 6.6 / 10.', 'nit'),
#  ('HelloBacklashruntime is1.4 with rating 6.6 / 10.', 'las'),
#  ('HelloThe Band of Honest Menruntime is1.8 with rating 7.5 / 10.', ' Me'),
#  ('HelloBandido!runtime is1.5 with rating 6.2 / 10.', 'ido'),
#  ('HelloBeyond a Reasonable Doubtruntime is1.3 with rating 7 / 10.', 'oub'),
#  ('HelloBhowani Junctionruntime is1.8 with rating 6.4 / 10.', 'tio'),
#  ('HelloBigger Than Liferuntime is1.6 with rating 7.6 / 10.', 'Lif'),
#  ('HelloThe Burmese Harpruntime is1.9 with rating 8.1 / 10.', 'Har'),
#  ('HelloThe Black Sleepruntime is1.4 with rating 6.1 / 10.', 'lee'),
#  ("HelloRaquel's Shoeshinerruntime is1.7 with rating 7.3 / 10.", 'ine'),
#  ('HelloThe Brave Oneruntime is1.7 with rating 6.6 / 10.', ' On'),
#  ('HelloBundle of Joyruntime is1.6 with rating 6.2 / 10.', ' Jo'),
#  ('HelloThe Burglarruntime is1.5 with rating 6.6 / 10.', 'gla'),
#  ('HelloBus Stopruntime is1.6 with rating 6.5 / 10.', 'Sto'),
#  ('HelloC.I.D.runtime is2.4 with rating 7.5 / 10.', 'I.D'),
#  ('HelloThe Rocket from Calabuchruntime is1.6 with rating 7.4 / 10.', 'buc'),
#  ('HelloMain Streetruntime is1.7 with rating 7.8 / 10.', 'ree'),
#  ('HelloCarouselruntime is2.1 with rating 6.6 / 10.', 'use'),
#  ('HelloThe Catered Affairruntime is1.6 with rating 7.5 / 10.', 'fai'),
#  ('HelloThe Cockleshell Heroesruntime is1.6 with rating 6.6 / 10.', 'roe'),
#  ('HelloThe Court Jesterruntime is1.7 with rating 7.9 / 10.', 'ste'),
#  ('HelloCrime in the Streetsruntime is1.5 with rating 6.6 / 10.', 'eet'),
#  ('HelloA Cry in the Nightruntime is1.3 with rating 6.1 / 10.', 'igh'),
#  ('HelloD-Day the Sixth of Juneruntime is1.8 with rating 6 / 10.', 'Jun'),
#  ('HelloDeath of a Scoundrelruntime is2.0 with rating 6.9 / 10.', 'dre'),
#  ('HelloGervaiseruntime is1.9 with rating 7.4 / 10.', 'ais'),
#  ('HelloGiantruntime is3.4 with rating 7.7 / 10.', 'ian'),
#  ("HelloThe Girl Can't Help Itruntime is1.7 with rating 6.8 / 10.", 'p I'),
#  ('HelloGood-bye, My Ladyruntime is1.6 with rating 7.2 / 10.', 'Lad'),
#  ('HelloNight Ambushruntime is1.7 with rating 6.6 / 10.', 'bus'),
#  ('HelloInvasion of the Body Snatchersruntime is1.3 with rating 7.7 / 10.', 'her'),
#  ('HelloInvitation to the Danceruntime is1.6 with rating 6.3 / 10.', 'anc'),
#  ('HelloStay Alertruntime is2.6 with rating 8.5 / 10.', 'ler'),
#  ('HelloJulieruntime is1.7 with rating 6.1 / 10.', 'uli'),
#  ('HelloThe Killer Is Looseruntime is1.2 with rating 6.6 / 10.', 'oos'),
# ...
#  ('HelloThe 27th Dayruntime is1.3 with rating 6.2 / 10.', ' Da'),
#  ('Hello3:10 to Yumaruntime is1.5 with rating 7.6 / 10.', 'Yum'),
#  ('HelloSeven Days from Nowruntime is1.7 with rating 7.5 / 10.', ' No'),
#  ('HelloThe Abominable Snowmanruntime is1.5 with rating 6.5 / 10.', 'wma'),
#  ('HelloAcross the Bridgeruntime is1.7 with rating 7.2 / 10.', 'idg'),
#  ('HelloParadise Lagoonruntime is1.6 with rating 7 / 10.', 'goo'),
#  ('HelloThe Chaplin Revueruntime is2.1 with rating 7.8 / 10.', 'evu'),
#  ('HelloMontparnasse 19runtime is1.8 with rating 7.4 / 10.', 'e 1'),
#  ('HelloBitter Victoryruntime is1.7 with rating 6.8 / 10.', 'tor'),
#  ('HelloBaby Face Nelsonruntime is1.4 with rating 6.5 / 10.', 'lso'),
#  ('HelloThe Bachelor Partyruntime is1.5 with rating 6.7 / 10.', 'art'),
#  ('HelloThe Sun Legend of the End of the Tokugawa Eraruntime is1.8 with rating 7.4 / 10.', ' Er'),
#  ('HelloBand of Angelsruntime is2.1 with rating 6.6 / 10.', 'gel'),
#  ('HelloBattle Hymnruntime is1.8 with rating 6.4 / 10.', 'Hym'),
#  ('HelloMother Indiaruntime is2.9 with rating 8.1 / 10.', 'ndi'),
#  ('HelloChase a Crooked Shadowruntime is1.5 with rating 7.1 / 10.', 'ado'),
#  ('HelloBoy on a Dolphinruntime is1.9 with rating 6.2 / 10.', 'phi'),
#  ('HelloThe Brothers Ricoruntime is1.5 with rating 6.9 / 10.', 'Ric'),
#  ("HelloCampbell's Kingdomruntime is1.7 with rating 6.3 / 10.", 'gdo'),
#  ('HelloThe Enemy Belowruntime is1.6 with rating 7.5 / 10.', 'elo'),
#  ('HelloEroicaruntime is1.5 with rating 7.5 / 10.', 'oic'),
#  ('HelloLes espionsruntime is2.1 with rating 6.8 / 10.', 'ion'),
#  ('HelloA Face in the Crowdruntime is2.1 with rating 8.2 / 10.', 'row'),
#  ('HelloFiend Without a Faceruntime is1.3 with rating 6.2 / 10.', 'Fac'),
#  ('HelloFire Down Belowruntime is1.9 with rating 6 / 10.', 'elo'),
#  ('HelloFools in the Mountainsruntime is1.5 with rating 7.4 / 10.', 'ain'),
#  ('HelloForty Gunsruntime is1.3 with rating 7 / 10.', 'Gun'),
#  ('HelloFunny Faceruntime is1.7 with rating 7 / 10.', 'Fac'),
#  ('HelloThe Mysteriansruntime is1.5 with rating 6.1 / 10.', 'ian'),
#  ('HelloChina Gateruntime is1.6 with rating 6.3 / 10.', 'Gat'),
#  ('HelloLa grande strada azzurraruntime is1.7 with rating 6.9 / 10.', 'urr'),
#  ('HelloThe Green Manruntime is1.3 with rating 7.3 / 10.', ' Ma'),
#  ('HelloGun Gloryruntime is1.5 with rating 6.2 / 10.', 'lor'),
#  ('HelloGunfight at the O.K. Corralruntime is2.0 with rating 7.2 / 10.', 'rra'),
#  ('HelloThe Guns of Fort Petticoatruntime is1.4 with rating 6.4 / 10.', 'coa'),
#  ('HelloA Hatful of Rainruntime is1.8 with rating 7.1 / 10.', 'Rai'),
#  ('HelloHeaven Knows, Mr. Allisonruntime is1.8 with rating 7.3 / 10.', 'iso'),
#  ('HelloThe Helen Morgan Storyruntime is2.0 with rating 6.4 / 10.', 'tor'),
#  ('HelloCrime of Passionruntime is1.4 with rating 6.5 / 10.', 'sio'),
#  ('HelloIsland in the Sunruntime is2.0 with rating 6 / 10.', ' Su'),
#  ('HelloJailhouse Rockruntime is1.6 with rating 6.5 / 10.', 'Roc'),
#  ('HelloJeanne Eagelsruntime is1.8 with rating 6.3 / 10.', 'gel'),
#  ('HelloJohnny Tremainruntime is1.3 with rating 6.5 / 10.', 'mai'),
#  ('HelloJust My Luckruntime is1.4 with rating 6.3 / 10.', 'Luc'),
#  ('HelloKanalruntime is1.5 with rating 7.9 / 10.', 'ana'),
#  ('HelloA King in New Yorkruntime is1.8 with rating 7.1 / 10.', 'Yor'),
#  ('HelloThrone of Bloodruntime is1.8 with rating 8.1 / 10.', 'loo'),
#  ('HelloThe Incredible Shrinking Manruntime is1.4 with rating 7.6 / 10.', ' Ma'),
#  ('HelloLes Girlsruntime is1.9 with rating 6.6 / 10.', 'irl'),
#  ('HelloThe Cranes Are Flyingruntime is1.6 with rating 8.3 / 10.', 'yin'),
#  ('HelloThe Lonely Manruntime is1.5 with rating 6.5 / 10.', ' Ma'),
#  ('HelloLove in the Afternoonruntime is2.2 with rating 7.2 / 10.', 'noo'),
#  ('HelloLoving Youruntime is1.7 with rating 6.5 / 10.', ' Yo'),
#  ('HelloLucky Jimruntime is1.6 with rating 6 / 10.', ' Ji'),
#  ('HelloMadhumatiruntime is1.8 with rating 8 / 10.', 'mat'),
#  ('HelloThe Curse of Frankensteinruntime is1.4 with rating 7.1 / 10.', 'tei'),
#  ('HelloInspector Maigretruntime is2.0 with rating 7.2 / 10.', 'gre'),
#  ('HelloMan of a Thousand Facesruntime is2.0 with rating 7.2 / 10.', 'ace'),
#  ('HelloThe D.I.runtime is1.8 with rating 7.3 / 10.', 'D.I'),
#  ('HelloMen in Warruntime is1.7 with rating 7.2 / 10.', ' Wa'),
#  ('HelloMon Oncleruntime is1.9 with rating 7.8 / 10.', 'ncl'),
#  ('HelloThe Monolith Monstersruntime is1.3 with rating 6.4 / 10.', 'ter'),
#  ('HelloDecision at Sundownruntime is1.3 with rating 6.9 / 10.', 'dow'),
#  ('HelloMy Man Godfreyruntime is1.5 with rating 6.3 / 10.', 'fre'),
#  ('HelloThe Devil Strikes at Nightruntime is1.8 with rating 7.3 / 10.', 'igh'),
#  ('HelloNaya Daurruntime is2.9 with rating 8.1 / 10.', 'Dau'),
#  ('HelloNine Livesruntime is1.6 with rating 7.3 / 10.', 'ive'),
#  ('HelloNight Passageruntime is1.5 with rating 6.7 / 10.', 'sag'),
#  ('HelloNo Down Paymentruntime is1.8 with rating 7.1 / 10.', 'men'),
#  ('HelloNot of This Earthruntime is1.1 with rating 6.3 / 10.', 'art'),
#  ('HelloThe Hunchback of Notre Dameruntime is1.9 with rating 6.7 / 10.', 'Dam'),
#  ('HelloLe Notti Biancheruntime is1.7 with rating 7.8 / 10.', 'nch'),
#  ('HelloThe Nights of Cabiriaruntime is1.8 with rating 8.1 / 10.', 'iri'),
#  ('HelloOld Yellerruntime is1.4 with rating 7.3 / 10.', 'lle'),
#  ('HelloThe One That Got Awayruntime is1.8 with rating 7.2 / 10.', 'Awa'),
#  ('HelloOperation Mad Ballruntime is1.8 with rating 6.6 / 10.', 'Bal'),
#  ('HelloThe Pajama Gameruntime is1.7 with rating 6.7 / 10.', 'Gam'),
#  ('HelloPal Joeyruntime is1.9 with rating 6.7 / 10.', 'Joe'),
#  ('HelloPaths of Gloryruntime is1.5 with rating 8.4 / 10.', 'lor'),
#  ('HelloThe Delicate Delinquentruntime is1.7 with rating 6.5 / 10.', 'uen'),
#  ('HelloPeyton Placeruntime is2.6 with rating 7.2 / 10.', 'lac'),
#  ('HelloPlunder Roadruntime is1.2 with rating 6.9 / 10.', 'Roa'),
#  ('HelloI Dutifully Reportruntime is1.5 with rating 7.4 / 10.', 'por'),
#  ('HelloPyaasaruntime is2.4 with rating 8.5 / 10.', 'aas'),
#  ('HelloRaintree Countyruntime is2.7 with rating 6.4 / 10.', 'unt'),
#  ('HelloThe Revenge of Frankensteinruntime is1.5 with rating 6.8 / 10.', 'tei'),
#  ('HelloThe Ride Backruntime is1.3 with rating 6.7 / 10.', 'Bac'),
#  ("HelloThe River's Edgeruntime is1.5 with rating 6.4 / 10.", 'Edg'),
#  ('HelloRun of the Arrowruntime is1.4 with rating 6.7 / 10.', 'rro'),
#  ('HelloDesigning Womanruntime is2.0 with rating 6.8 / 10.', 'oma'),
#  ('HelloSaddle the Windruntime is1.4 with rating 6.6 / 10.', 'Win'),
#  ('HelloSayonararuntime is2.5 with rating 7.1 / 10.', 'nar'),
#  ('HelloDesk Setruntime is1.7 with rating 7.3 / 10.', ' Se'),
#  ('HelloDo Ankhen Barah Haathruntime is2.4 with rating 8.4 / 10.', 'aat'),
#  ('HelloSilk Stockingsruntime is2.0 with rating 6.8 / 10.', 'ing'),
#  ('HelloThe Seventh Sealruntime is1.6 with rating 8.2 / 10.', 'Sea'),
#  ('HelloBig Time Operatorsruntime is1.3 with rating 7 / 10.', 'tor'),
#  ('HelloWild Strawberriesruntime is1.5 with rating 8.2 / 10.', 'rie'),
#  ('HelloSomething of Valueruntime is1.9 with rating 6.5 / 10.', 'alu'),
#  ('HelloThe Story of Esther Costelloruntime is1.7 with rating 6.2 / 10.', 'ell'),
#  ('HelloThe Sun Also Risesruntime is2.2 with rating 6.3 / 10.', 'ise'),
#  ('HelloSweet Smell of Successruntime is1.6 with rating 8.1 / 10.', 'ces'),
#  ('HelloThe Tall Strangerruntime is1.4 with rating 6.4 / 10.', 'nge'),
#  ('HelloTammy and the Bachelorruntime is1.5 with rating 7 / 10.', 'elo'),
#  ('HelloThe Tarnished Angelsruntime is1.5 with rating 7.1 / 10.', 'gel'),
#  ('HelloA Matter of Dignityruntime is1.9 with rating 7.8 / 10.', 'nit'),
#  ('HelloThe Three Faces of Everuntime is1.5 with rating 7.2 / 10.', ' Ev'),
#  ('HelloTikhiy Donruntime is5.5 with rating 7.8 / 10.', ' Do'),
#  ('HelloTime Limitruntime is1.6 with rating 7.3 / 10.', 'imi'),
#  ('HelloThe Tin Starruntime is1.6 with rating 7.3 / 10.', 'Sta'),
#  ('HelloTizoc (Amor indio)runtime is1.8 with rating 7.5 / 10.', 'dio'),
#  ('HelloTokyo Twilightruntime is2.3 with rating 8.2 / 10.', 'igh'),
#  ('HelloTrooper Hookruntime is1.4 with rating 6.7 / 10.', 'Hoo'),
#  ('HelloThe True Story of Jesse Jamesruntime is1.5 with rating 6.3 / 10.', 'ame'),
#  ('HelloLa Parisienneruntime is1.4 with rating 6.3 / 10.', 'enn'),
#  ('HelloUntil They Sailruntime is1.6 with rating 6.5 / 10.', 'Sai'),
#  ('HelloEl vampiroruntime is1.6 with rating 7.1 / 10.', 'pir'),
#  ('HelloDoctor at Largeruntime is1.7 with rating 6 / 10.', 'arg'),
#  ('HelloWild Is the Windruntime is1.9 with rating 6.7 / 10.', 'Win'),
#  ('HelloWill Success Spoil Rock Hunter?runtime is1.6 with rating 7 / 10.', 'ter'),
#  ('HelloDas Wirtshaus im Spessartruntime is1.7 with rating 6.4 / 10.', 'sar'),
#  ('HelloWitness for the Prosecutionruntime is1.9 with rating 8.4 / 10.', 'tio'),
#  ('HelloThe Wrong Manruntime is1.8 with rating 7.4 / 10.', ' Ma'),
#  ('HelloDon Kikhotruntime is1.8 with rating 7.4 / 10.', 'kho'),
#  ("HelloDon't Go Near the Waterruntime is1.8 with rating 6.2 / 10.", 'ate'),
#  ('HelloThe Lower Depthsruntime is2.3 with rating 7.4 / 10.', 'pth'),
#  ('HelloThe Bravadosruntime is1.6 with rating 7 / 10.', 'ado'),
#  ('HelloThe Buccaneerruntime is2.0 with rating 6.5 / 10.', 'nee'),
#  ('HelloBuchanan Rides Aloneruntime is1.3 with rating 6.9 / 10.', 'lon'),
#  ('HelloCarry on Nurseruntime is1.4 with rating 6.3 / 10.', 'urs'),
#  ('HelloCarry On Sergeantruntime is1.4 with rating 6.3 / 10.', 'ean'),
#  ('HelloCat on a Hot Tin Roofruntime is1.8 with rating 8 / 10.', 'Roo'),
#  ('HelloThe 7th Voyage of Sinbadruntime is1.5 with rating 7.1 / 10.', 'nba'),
#  ('HelloBandiniruntime is2.6 with rating 7.7 / 10.', 'din'),
#  ('HelloChristineruntime is1.7 with rating 6.4 / 10.', 'tin'),
#  ('HelloArayaruntime is1.5 with rating 7.7 / 10.', 'ray'),
#  ('HelloElevator to the Gallowsruntime is1.5 with rating 8 / 10.', 'low'),
#  ('HelloAuntie Mameruntime is2.4 with rating 7.9 / 10.', 'Mam'),
#  ('HelloCairo Stationruntime is1.3 with rating 7.7 / 10.', 'tio'),
#  ('HelloThe Badlandersruntime is1.4 with rating 6.4 / 10.', 'der'),
#  ('HelloBell Book and Candleruntime is1.8 with rating 6.9 / 10.', 'ndl'),
#  ('HelloThe Big Countryruntime is2.8 with rating 7.9 / 10.', 'ntr'),
#  ('HelloThe H-Manruntime is1.5 with rating 6.1 / 10.', '-Ma'),
#  ('HelloThe Blobruntime is1.4 with rating 6.4 / 10.', 'Blo'),
#  ("HelloBlue Murder at St. Trinian'sruntime is1.4 with rating 6.5 / 10.", "an'"),
#  ('HelloBonjour Tristesseruntime is1.6 with rating 6.9 / 10.', 'ess'),
#  ('HelloCorridors of Bloodruntime is1.4 with rating 6.5 / 10.', 'loo'),
#  ('HelloHorror of Dracularuntime is1.4 with rating 7.3 / 10.', 'cul'),
#  ('HelloDunkirkruntime is2.3 with rating 7 / 10.', 'kir'),
#  ('HelloLake of the Deadruntime is1.3 with rating 7.2 / 10.', 'Dea'),
#  ('HelloLove Is My Professionruntime is1.8 with rating 6.7 / 10.', 'sio'),
#  ('HelloConflagrationruntime is1.7 with rating 7.1 / 10.', 'tio'),
#  ('HelloFanfareruntime is1.4 with rating 7.4 / 10.', 'far'),
#  ('HelloThe Fearmakersruntime is1.4 with rating 6.1 / 10.', 'ker'),
#  ('HelloThe Flyruntime is1.6 with rating 7.1 / 10.', ' Fl'),
#  ('HelloFort Dobbsruntime is1.6 with rating 6.9 / 10.', 'obb'),
#  ('HelloFort Massacreruntime is1.3 with rating 6.2 / 10.', 'acr'),
#  ('HelloFrom Hell to Texasruntime is1.7 with rating 6.9 / 10.', 'exa'),
#  ('HelloCareerruntime is1.8 with rating 6.9 / 10.', 'ree'),
#  ('HelloThe Geisha Boyruntime is1.6 with rating 6.5 / 10.', ' Bo'),
#  ('HelloCowboyruntime is1.5 with rating 6.7 / 10.', 'wbo'),
#  ('HelloGideon of Scotland Yardruntime is1.5 with rating 6.5 / 10.', 'Yar'),
#  ('HelloGigiruntime is1.9 with rating 6.7 / 10.', 'Gig'),
#  ("HelloGod's Little Acreruntime is2.0 with rating 6.6 / 10.", 'Acr'),
#  ('HelloThe Goddessruntime is1.7 with rating 6.7 / 10.', 'des'),
#  ('HelloThe Gunfight at Dodge Cityruntime is1.4 with rating 6.2 / 10.', 'Cit'),
#  ('HelloH-8...runtime is1.8 with rating 8.5 / 10.', '8..'),
#  ('HelloThe Haunted Stranglerruntime is1.3 with rating 6.3 / 10.', 'gle'),
#  ('HelloHell Driversruntime is1.8 with rating 7.2 / 10.', 'ver'),
#  ('HelloHome Before Darkruntime is2.3 with rating 7 / 10.', 'Dar'),
#  ('HelloThe Idiotruntime is2.1 with rating 7.6 / 10.', 'dio'),
#  ('HelloImitation Generalruntime is1.5 with rating 6.7 / 10.', 'era'),
#  ('HelloIndiscreetruntime is1.7 with rating 6.8 / 10.', 'ree'),
#  ('HelloIt! The Terror from Beyond Spaceruntime is1.2 with rating 6.1 / 10.', 'pac'),
#  ('HelloIvan the Terrible, Part IIruntime is1.5 with rating 7.9 / 10.', 't I'),
#  ('HelloThe Music Roomruntime is1.7 with rating 8 / 10.', 'Roo'),
#  ('HelloThe Hidden Fortressruntime is2.3 with rating 8.1 / 10.', 'res'),
#  ('HelloThe Keyruntime is2.2 with rating 6.6 / 10.', ' Ke'),
#  ('HelloKing Creoleruntime is1.9 with rating 7 / 10.', 'eol'),
#  ('HelloKings Go Forthruntime is1.8 with rating 6.5 / 10.', 'ort'),
#  ('HelloThe Law and Jake Waderuntime is1.4 with rating 6.8 / 10.', 'Wad'),
#  ('HelloThe Law Is the Lawruntime is1.6 with rating 7.5 / 10.', ' La'),
#  ('HelloThe Lawruntime is2.1 with rating 6.9 / 10.', ' La'),
#  ("HelloThe Horse's Mouthruntime is1.6 with rating 7.1 / 10.", 'out'),
#  ('HelloHouse on Haunted Hillruntime is1.3 with rating 6.9 / 10.', 'Hil'),
#  ('HelloHouseboatruntime is1.8 with rating 6.6 / 10.', 'boa'),
#  ('HelloThe Huntersruntime is1.8 with rating 6.4 / 10.', 'ter'),
#  ('HelloI Bury the Livingruntime is1.3 with rating 6.3 / 10.', 'vin'),
#  ('HelloI Married a Monster from Outer Spaceruntime is1.3 with rating 6.3 / 10.', 'pac'),
#  ('HelloI Want to Live!runtime is2.0 with rating 7.4 / 10.', 'ive'),
#  ('HelloThe Long, Hot Summerruntime is1.9 with rating 7.4 / 10.', 'mme'),
#  ('HelloLook Back in Angerruntime is1.6 with rating 7.1 / 10.', 'nge'),
#  ('HelloMachine-Gun Kellyruntime is1.3 with rating 6.2 / 10.', 'ell'),
#  ('HelloMan of the Westruntime is1.7 with rating 7.2 / 10.', 'Wes'),
#  ('HelloMarjorie Morningstarruntime is2.1 with rating 6.2 / 10.', 'sta'),
#  ('HelloMe and the Colonelruntime is1.8 with rating 7 / 10.', 'one'),
#  ('HelloMerry Andrewruntime is1.7 with rating 6.8 / 10.', 'dre'),
#  ('HelloWe Only Live Onceruntime is1.9 with rating 8.3 / 10.', 'Onc'),
#  ('HelloMoi, un noirruntime is1.2 with rating 7.4 / 10.', 'noi'),
#  ('HelloThe Rickshaw Manruntime is1.7 with rating 7.6 / 10.', ' Ma'),
#  ('HelloMurder by Contractruntime is1.4 with rating 7.4 / 10.', 'rac'),
#  ('HelloMädchen in Uniformruntime is1.6 with rating 7.1 / 10.', 'for'),
#  ('HelloThe Naked and the Deadruntime is2.2 with rating 6.4 / 10.', 'Dea'),
#  ('HelloNazarinruntime is1.6 with rating 7.9 / 10.', 'ari'),
#  ('HelloNeither Seen Nor Recognizedruntime is1.6 with rating 7.2 / 10.', 'ize'),
#  ('HelloA Night to Rememberruntime is2.1 with rating 7.9 / 10.', 'mbe'),
#  ('HelloNo Name on the Bulletruntime is1.3 with rating 7.3 / 10.', 'lle'),
#  ('HelloNo Time for Sergeantsruntime is2.0 with rating 7.6 / 10.', 'ant'),
#  ('HelloBrink of Liferuntime is1.4 with rating 7.6 / 10.', 'Lif'),
#  ('HelloParas-Patharruntime is1.9 with rating 7.7 / 10.', 'tha'),
#  ('HelloParty Girlruntime is1.7 with rating 7.1 / 10.', 'Gir'),
#  ('HelloThe Perfect Furloughruntime is1.6 with rating 6.4 / 10.', 'oug'),
#  ('HelloThe Nooseruntime is1.6 with rating 7.7 / 10.', 'oos'),
#  ('HelloThe Little Apartmentruntime is1.5 with rating 7.3 / 10.', 'men'),
#  ('HelloCry Terror!runtime is1.6 with rating 6.5 / 10.', 'ror'),
#  ('HelloAshes and Diamondsruntime is1.7 with rating 7.9 / 10.', 'ond'),
#  ('HelloThe Proud Rebelruntime is1.7 with rating 6.9 / 10.', 'ebe'),
#  ('HelloThe Quiet Americanruntime is2.0 with rating 6.7 / 10.', 'ica'),
#  ("HelloRally 'Round the Flag, Boys!runtime is1.8 with rating 6 / 10.", 'oys'),
#  ('HelloThe Reluctant Debutanteruntime is1.6 with rating 6.9 / 10.', 'ant'),
#  ('HelloRide a Crooked Trailruntime is1.5 with rating 6.7 / 10.', 'rai'),
#  ('HelloRock-a-Bye Babyruntime is1.7 with rating 6.7 / 10.', 'Bab'),
#  ('HelloThe Roots of Heavenruntime is2.1 with rating 6.4 / 10.', 'ave'),
#  ('HelloRun Silent Run Deepruntime is1.6 with rating 7.3 / 10.', 'Dee'),
#  ('HelloThe Snorkelruntime is1.5 with rating 6.8 / 10.', 'rke'),
#  ('HelloSome Came Runningruntime is2.3 with rating 7.4 / 10.', 'nin'),
#  ('HelloSouth Pacificruntime is2.6 with rating 6.8 / 10.', 'ifi'),
#  ('HelloThe Square Pegruntime is1.4 with rating 7.1 / 10.', ' Pe'),
#  ...]

# %% [markdown]
# Following sometimes comes useful when you want to convert a number to a readable format with commas.

# %%
# %%sql
# select to_char(10000000, '9,999,999,999');
# Out:
#  * postgresql://postgres:***@localhost:5432/imdb
# 1 rows affected.
# [('    10,000,000',)]

# %% [markdown]
# ### Date

# %%
# %%sql
#
# SELECT
#     CURRENT_DATE,
#     NOW(),
#     CURRENT_TIMESTAMP(0),
#     CURRENT_TIME(0),
#     LOCALTIMESTAMP(0),
#     LOCALTIME(2),
#     EXTRACT(year FROM '2021-11-15 8:00:00'::TIMESTAMP),
#     age(NOW(), '1987-01-05'::TIMESTAMP)
# ;
# Out:
#  * postgresql://postgres:***@localhost:5432/imdb
# 1 rows affected.
# [(datetime.date(2023, 11, 16), datetime.datetime(2023, 11, 16, 23, 57, 3, 44226, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))), datetime.datetime(2023, 11, 16, 23, 57, 3, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))), datetime.time(23, 57, 3, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=68400))), datetime.datetime(2023, 11, 16, 23, 57, 3), datetime.time(23, 57, 3, 40000), Decimal('2021'), datetime.timedelta(days=13451, seconds=86223, microseconds=44226))]

# %% [markdown]
# ## Wrap up

# %% [markdown]
# <img src="img/wrapup.gif" width="300">
#
# Now let's look again at the "Fully Loaded" SQL whatever we started this lecture with.
#
# ```{margin}
# <img src="img/loaded.png" width="600">
# ```

# %% [markdown]
# ```sql
# SET timezone = 'America/New_York';
# SELECT
# 44.7874::INT,
# -- 555 ilike '5%', - fails, since 555 is not a string, and it doesn't do implicit casting
# 555::TEXT ilike '5%',
# -- '5' + '55', -- fails, since it doesn't do implicit casting
# '5'::INTEGER + '55'::INTEGER,
# 5 + '55', -- Implicit casting
# '2' between 1 AND '3',
# '2021-11-01', -- Type character
# DATE '2021-11-01', -- type date
# '2021-11-01'::DATE, -- type date
# DATE '2021-11-01' BETWEEN DATE '2021-01-01' AND DATE '2021-11-10',
# '2021-11-01' BETWEEN '2021-01-01' AND '2021-11-10', --Implicit casting
# 'w' BETWEEN 'e' AND 'm',
# 5/2, -- NO implicit casting, and gives integer result 2
# 5/2::float, -- explicit casting to float gives 2.5, so make sure you do this
# round('1.333', 2), -- Implicit casting, of character '1.333' to float 1.333
# -- round('hello', 2), -- try implicit casting, fails since not possible
# CURRENT_DATE, -- this gives current date in date type, pg_typeof() to know type
# EXTRACT(year FROM CURRENT_DATE) - '1985', -- implicit casting with 1985 character to number 1985
# -- EXTRACT( year FROM CURRENT_DATE::VARCHAR) - '1985', --implicit casting doesn't happen with date in character type
# EXTRACT(year FROM CURRENT_DATE::VARCHAR::date)::INT - '1985'::INT, -- explicit casting
# 'today'::TIMESTAMPTZ,
# lower(SUBSTR('5555555', LENGTH('5555555'), 1)) IN ('5', 'a')
# -- lower(SUBSTR(5555555, LENGTH('5555555'), 1)) IN ('5', 'a') -- need explicit casting with substr
# -- lower(SUBSTR('5555555', LENGTH(5555555), 1)) IN ('5', 'a') -- need explicit casting with length
# ;
# ```

# %% [markdown]
# ```sql
# SELECT
#     'Title is ' || title AS "Title space", -- using || to concatenate, use of Alias, remember double quotes is used only in this situation
#     'w' NOT BETWEEN 'e' AND 'm', -- between and not between, inclusive of both ends of the interval
#     round(runtime / 60, 2) AS runtime_hours, -- derived column and use of some functions
#     CASE                                    -- CASE WHEN same like what we learned in 523
#         WHEN runtime > 90 THEN 'long'
#         WHEN runtime BETWEEN 30 AND 90 THEN 'normal'
#         ELSE 'short'
#     END AS duration
# FROM
#     movies m
# WHERE runtime / 60::REAL > 2 AND -- remember why we are not giving runtime_hours > 2, order of execution matters.
#      title IN ('Donnie Brasco',     -- IN operator
#               'The Usual Suspects',
#               'Schindler''s List',
#               'Shutter Island',
#               'A Beautiful Mind'
#                ) OR -- When multiple logical operators, then use () to make sure order of execution is correct, else NOT --> AND --> OR
#              title NOT ILIKE '% % %' AND -- asking not to include movies with more than 3 words
#              title ILIKE '% %' AND -- asking for movies with 2 parts (or 2 words), so single word movies are excluded
#              orig_title IS NOT NULL; -- NuLL is treated differently hence orig_tiltle = NULL will not work
# ```

# %% [markdown]
# what all should we recollect from the above code ?
#
# - Do we know how to use alias AS ? And where to use double quotes ?
# - Do you know how to use casting ?
# - Do we know how to use derived columns ?
# - Do we know how to use case statements ?
# - Do we know how to use logical operators ? And how to use them with parentheses, as you should be careful about the order of execution.
# - Why we used `WHERE runtime / 60::REAL > 2` instead of using `WHERE runtime_hours > 2`?

# %% [markdown]
# ## Moral of the story
#
# - Do we understand different datatypes and where they are used?
#     - boolean
#     - character
#     - number
#     - datetime
#     - binary
# - We looked into some casting functions.
# - We learned how to filter rows using `WHERE` clause.
# - Looked into logical operators `AND`, `OR`, `NOT`. Why the order operator is important?
# - We learned about `IN`, `BETWEEN`, `IS NULL` keywords and how to use it
# - We learned about column aliases and table aliases and why they are important (table aliases will be used a lot in the next lecture when we deal with JOINS)
# - We learned about order of execution - And why it is important
# - We learned about derived columns.
# - We learned about case statements.
