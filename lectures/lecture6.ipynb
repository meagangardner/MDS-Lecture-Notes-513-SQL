# %% [markdown]
# <img src="img/dsci513_header2.png" width="600">

# %% [markdown]
# # Lecture 6: Views, CTEs, window functions, indexing

# %% [markdown]
# ## Lecture outline
#
# - Views
# - Common Table Expressions (CTEs)
# - Window functions
# - indexing and performance

# %% [markdown]
# <br><br><br>

# %% [markdown]
# ## Views

# %% [markdown]
# In the last lecture, we tried to write a query for the following example:

# %% [markdown]
# ---
#
# **Example:** Which countries speak at least one language that is not spoken an any other country in their continent?
#
# ---

# %% [markdown]
# <br><br><br>

# %% [markdown]
# This query involves data both from the `country` table as well and the `countrylanguage` table.
#
# On the other hand, we also had to use an `EXISTS` subquery. This was why we first created an intermediate query to first store the results from joining the two tables, and then add the subquery part.
#
# While that solution worked, it might not always be ideal to store the data in another table (why?).

# %% [markdown]
# <br><br><br>

# %% [markdown]
# Although the separation of country data from language data makes sense from a logical point of view, it might happen that country + language data are the ones that are accessed the most by our users. Also it might be the case that our users only need names, continents, and population data from the `country` table, and language and percentage from the `countrylanguage` table. In this situation, we can create a **view** of the data that we have in our database.
#
# A view is a **named** result of a `SELECT` query that behaves just like a table; i.e. you can query it just like you query any other table in your database.

# %% [markdown]
# <br><br><br>

# %% [markdown]
# ### How to create and delete a view

# %% [markdown]
# ```sql
# CREATE VIEW view_name AS
#     select_statment
# ;
# ```
#
# <br>
#
# ```sql
# DROP VIEW [IF EXISTS] view_name;
# ```

# %% [markdown]
# <br><br><br>

# %% [markdown]
# ### Properties of a view

# %% [markdown]
# - A view acts as if it is a table, while it's actually only a way of looking at the data differently. This is why they're sometimes called **virtual tables**. As opposed to the temporary table approach, there is no duplication of data.

# %% [markdown]
# - A view is always **current and dynamic**. Whenever we access the view, the query that generates it is re-run and we will see an up-to-date version of the data. This may not be true with a temporary table.

# %% [markdown]
# - **Views persist.** You might argue that a temporary table only occupies space in the duration of a session, but it's not certain if that's truly an advantage. While it's good that the taken space is released after closing the connection, each time a user needs that particular query, the table also needs to be recreated.

# %% [markdown]
# - Views can **hide unnecessary details, or add details that are computed on demand**. Especially in complex databases, not every database user needs to, or wants to have access to all details of the dataset. Can you think of an example?

# %% [markdown]
# - With views we can also **manage what different users can see**. For example, in the database of a company not every department needs (or should) have access to all financial information of employees. But they may need their account and SIN numbers to be able to pay them for the job the do for that department. This can be easily managed with views.

# %% [markdown]
# - Views do not support constraints.

# %% [markdown]
# <br><br><br>

# %% [markdown]
# ### Materialized views: the best of both worlds

# %% [markdown]
# Sometimes the query underlying a view might be too slow to compute on the fly in a simple view. In this situation, there is a way to physically store a view. In other words, views can be **materialized**.
#
# A materialized view stores the results of the view query on the physical disk, instead of recomputing the entire query, which is why materialized views are much faster to use.

# %% [markdown]
# <br><br><br>

# %% [markdown]
# Here is the syntax for creating and dropping materialized views:
#
# ```sql
# CREATE MATERIALIZED VIEW my_mat_view AS
#     select_statement
# ;
#
# DROP MATERIALIZED VIEW my_mat_view;
# ```

# %% [markdown]
# <br><br><br>

# %% [markdown]
# Like almost anything in this world, you won't gain anything unless you lose something else. Same is true with materialized views. The **trade-offs** you need to be aware of when using materialized views:
#
# - Just like a temporary table, a materialized view occupies disk space
#
# - The data in a materialized view needs to be refreshed if the data in the related tables are modified.

# %% [markdown]
# <br><br><br>

# %% [markdown]
# Materialized views can be refreshed using the following syntax:
#
# ```sql
# REFRESH MATERIALIZED VIEW [CONCURRENTLY] my_mat_view;
# ```
#
# **Note:** If the keyword `CONCURRENTLY` is used, the view will be usable during the refresh process, but there's no guarantee that the data will be up to date.

# %% [markdown]
# <br><br><br>

# %% [markdown]
# **Takeaway:** Using a materialized view is justified if the query takes **a lot of time but little space**. A simple query, on the other hand, is best suited to a query that takes **a considerable amount of space, but relatively little time**.

# %% [markdown]
# <br><br><br>

# %% [markdown]
# ---
#
# **Question:** Can you think of two advantages of a temporary table over a simple view?
#
# ---

# %% [markdown]
# <br><br><br>

# %%
# %load_ext sql
# %config SqlMagic.displaylimit = 30

# %%
import json
import urllib.parse

with open('data/credentials.json') as f:
    login = json.load(f)
    
username = login['user']
password = urllib.parse.quote(login['password'])
host = login['host']
port = login['port']

# %%
# %sql postgresql://{username}:{password}@{host}/imdb
# Out:
# 'Connected: postgres@imdb'

# %% [markdown]
# In this example here, I have intentionally written a slow query (involving a correlated subquery) to find movies whose number of votes is higher than the average number of votes of all movies belonging to the same genre. Running this query will take some time:

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     movies m
# JOIN
#     movie_genres mg
# ON
#     m.id = mg.movie_id
# WHERE
#     rating > 8
#     AND
#     nvotes > (
#         SELECT
#             AVG(m2.nvotes)
#         FROM
#             movies m2
#         JOIN
#             movie_genres mg2
#         ON
#             m2.id = mg2.movie_id
#         WHERE
#             mg.genre = mg2.genre
#             AND
#             m.id <> m2.id
#     )
# ;
# Out:
#  * postgresql://postgres:***@localhost/imdb
# 795 rows affected.
# [(10042876, 'Rashomon', 'Rashômon', 1950, None, 88, 8.2, 138304, 10042876, 'crime'),
#  (10042876, 'Rashomon', 'Rashômon', 1950, None, 88, 8.2, 138304, 10042876, 'drama'),
#  (10042876, 'Rashomon', 'Rashômon', 1950, None, 88, 8.2, 138304, 10042876, 'mystery'),
#  (10043014, 'Sunset Blvd.', None, 1950, None, 110, 8.4, 183282, 10043014, 'drama'),
#  (10043014, 'Sunset Blvd.', None, 1950, None, 110, 8.4, 183282, 10043014, 'film-noir'),
#  (10044741, 'Ikiru', None, 1952, None, 143, 8.3, 60061, 10044741, 'drama'),
#  (10044837, 'Limelight', None, 1952, None, 137, 8.1, 16445, 10044837, 'music'),
#  (10045152, "Singin' in the Rain", None, 1952, None, 103, 8.3, 201077, 10045152, 'comedy'),
#  (10045152, "Singin' in the Rain", None, 1952, None, 103, 8.3, 201077, 10045152, 'musical'),
#  (10045152, "Singin' in the Rain", None, 1952, None, 103, 8.3, 201077, 10045152, 'romance'),
#  (10046268, 'The Wages of Fear', 'Le salaire de la peur', 1953, None, 131, 8.1, 49244, 10046268, 'drama'),
#  (10046268, 'The Wages of Fear', 'Le salaire de la peur', 1953, None, 131, 8.1, 49244, 10046268, 'thriller'),
#  (10046478, 'Ugetsu', 'Ugetsu monogatari', 1953, None, 96, 8.3, 18356, 10046478, 'war'),
#  (10046912, 'Dial M for Murder', None, 1954, None, 105, 8.2, 143268, 10046912, 'crime'),
#  (10046912, 'Dial M for Murder', None, 1954, None, 105, 8.2, 143268, 10046912, 'thriller'),
#  (10047296, 'On the Waterfront', None, 1954, None, 108, 8.1, 130916, 10047296, 'crime'),
#  (10047296, 'On the Waterfront', None, 1954, None, 108, 8.1, 130916, 10047296, 'drama'),
#  (10047296, 'On the Waterfront', None, 1954, None, 108, 8.1, 130916, 10047296, 'thriller'),
#  (10047396, 'Rear Window', None, 1954, None, 112, 8.5, 407290, 10047396, 'mystery'),
#  (10047396, 'Rear Window', None, 1954, None, 112, 8.5, 407290, 10047396, 'thriller'),
#  (10050083, '12 Angry Men', None, 1957, None, 96, 8.9, 610724, 10050083, 'drama'),
#  (10050613, 'Throne of Blood', 'Kumonosu-jô', 1957, None, 110, 8.1, 40639, 10050613, 'drama'),
#  (10050613, 'Throne of Blood', 'Kumonosu-jô', 1957, None, 110, 8.1, 40639, 10050613, 'history'),
#  (10050783, 'The Nights of Cabiria', 'Le notti di Cabiria', 1957, None, 110, 8.1, 39350, 10050783, 'drama'),
#  (10050825, 'Paths of Glory', None, 1957, None, 88, 8.4, 160459, 10050825, 'drama'),
#  (10050825, 'Paths of Glory', None, 1957, None, 88, 8.4, 160459, 10050825, 'war'),
#  (10050986, 'Wild Strawberries', 'Smultronstället', 1957, None, 91, 8.2, 85988, 10050986, 'drama'),
#  (10050986, 'Wild Strawberries', 'Smultronstället', 1957, None, 91, 8.2, 85988, 10050986, 'romance'),
#  (10051036, 'Sweet Smell of Success', None, 1957, None, 96, 8.1, 24897, 10051036, 'drama'),
#  (10051036, 'Sweet Smell of Success', None, 1957, None, 96, 8.1, 24897, 10051036, 'film-noir'),
#  (10050976, 'The Seventh Seal', 'Det sjunde inseglet', 1957, None, 96, 8.2, 146553, 10050976, 'drama'),
#  (10050976, 'The Seventh Seal', 'Det sjunde inseglet', 1957, None, 96, 8.2, 146553, 10050976, 'fantasy'),
#  (10051201, 'Witness for the Prosecution', None, 1957, None, 116, 8.4, 95259, 10051201, 'crime'),
#  (10051201, 'Witness for the Prosecution', None, 1957, None, 116, 8.4, 95259, 10051201, 'drama'),
#  (10051201, 'Witness for the Prosecution', None, 1957, None, 116, 8.4, 95259, 10051201, 'film-noir'),
#  (10051808, 'The Hidden Fortress', 'Kakushi-toride no san-akunin', 1958, None, 139, 8.1, 30431, 10051808, 'drama'),
#  (10052357, 'Vertigo', None, 1958, None, 128, 8.3, 327884, 10052357, 'mystery'),
#  (10052357, 'Vertigo', None, 1958, None, 128, 8.3, 327884, 10052357, 'romance'),
#  (10052357, 'Vertigo', None, 1958, None, 128, 8.3, 327884, 10052357, 'thriller'),
#  (10052618, 'Ben-Hur', None, 1959, None, 212, 8.1, 204418, 10052618, 'adventure'),
#  (10052618, 'Ben-Hur', None, 1959, None, 212, 8.1, 204418, 10052618, 'drama'),
#  (10052618, 'Ben-Hur', None, 1959, None, 212, 8.1, 204418, 10052618, 'history'),
#  (10053291, 'Some Like It Hot', None, 1959, None, 121, 8.2, 224857, 10053291, 'comedy'),
#  (10053291, 'Some Like It Hot', None, 1959, None, 121, 8.2, 224857, 10053291, 'music'),
#  (10053291, 'Some Like It Hot', None, 1959, None, 121, 8.2, 224857, 10053291, 'romance'),
#  (10053604, 'The Apartment', None, 1960, None, 125, 8.3, 147637, 10053604, 'comedy'),
#  (10053604, 'The Apartment', None, 1960, None, 125, 8.3, 147637, 10053604, 'drama'),
#  (10053604, 'The Apartment', None, 1960, None, 125, 8.3, 147637, 10053604, 'romance'),
#  (10053946, 'Inherit the Wind', None, 1960, None, 128, 8.1, 25050, 10053946, 'drama'),
#  (10053946, 'Inherit the Wind', None, 1960, None, 128, 8.1, 25050, 10053946, 'history'),
#  (10053976, 'The Virgin Spring', 'Jungfrukällan', 1960, None, 89, 8.1, 24134, 10053976, 'drama'),
#  (10054215, 'Psycho', None, 1960, None, 109, 8.5, 550103, 10054215, 'horror'),
#  (10054215, 'Psycho', None, 1960, None, 109, 8.5, 550103, 10054215, 'mystery'),
#  (10054215, 'Psycho', None, 1960, None, 109, 8.5, 550103, 10054215, 'thriller'),
#  (10055031, 'Judgment at Nuremberg', None, 1961, None, 179, 8.2, 63018, 10055031, 'drama'),
#  (10055031, 'Judgment at Nuremberg', None, 1961, None, 179, 8.2, 63018, 10055031, 'war'),
#  (10055630, 'Yojimbo', 'Yôjinbô', 1961, None, 110, 8.2, 100387, 10055630, 'action'),
#  (10055630, 'Yojimbo', 'Yôjinbô', 1961, None, 110, 8.2, 100387, 10055630, 'comedy'),
#  (10055630, 'Yojimbo', 'Yôjinbô', 1961, None, 110, 8.2, 100387, 10055630, 'crime'),
#  (10056058, 'Harakiri', 'Seppuku', 1962, None, 133, 8.7, 26397, 10056058, 'drama'),
#  (10056058, 'Harakiri', 'Seppuku', 1962, None, 133, 8.7, 26397, 10056058, 'history'),
#  (10056111, "Ivan's Childhood", 'Ivanovo detstvo', 1962, None, 95, 8.1, 27073, 10056111, 'drama'),
#  (10056111, "Ivan's Childhood", 'Ivanovo detstvo', 1962, None, 95, 8.1, 27073, 10056111, 'war'),
#  (10056172, 'Lawrence of Arabia', None, 1962, None, 228, 8.3, 247272, 10056172, 'adventure'),
#  (10056172, 'Lawrence of Arabia', None, 1962, None, 228, 8.3, 247272, 10056172, 'biography'),
#  (10056172, 'Lawrence of Arabia', None, 1962, None, 228, 8.3, 247272, 10056172, 'drama'),
#  (10056217, 'The Man Who Shot Liberty Valance', None, 1962, None, 123, 8.1, 63629, 10056217, 'drama'),
#  (10056217, 'The Man Who Shot Liberty Valance', None, 1962, None, 123, 8.1, 63629, 10056217, 'western'),
#  (10056732, 'The Exterminating Angel', 'El ángel exterminador', 1962, None, 95, 8.2, 26116, 10056732, 'drama'),
#  (10056687, 'What Ever Happened to Baby Jane?', None, 1962, None, 134, 8.1, 46059, 10056687, 'drama'),
#  (10056687, 'What Ever Happened to Baby Jane?', None, 1962, None, 134, 8.1, 46059, 10056687, 'horror'),
#  (10056687, 'What Ever Happened to Baby Jane?', None, 1962, None, 134, 8.1, 46059, 10056687, 'thriller'),
#  (10056592, 'To Kill a Mockingbird', None, 1962, None, 129, 8.3, 276602, 10056592, 'crime'),
#  (10056592, 'To Kill a Mockingbird', None, 1962, None, 129, 8.3, 276602, 10056592, 'drama'),
#  (10057115, 'The Great Escape', None, 1963, None, 172, 8.2, 208092, 10057115, 'adventure'),
#  (10057115, 'The Great Escape', None, 1963, None, 172, 8.2, 208092, 10057115, 'drama'),
#  (10057115, 'The Great Escape', None, 1963, None, 172, 8.2, 208092, 10057115, 'history'),
#  (10057565, 'High and Low', 'Tengoku to jigoku', 1963, None, 143, 8.5, 24377, 10057565, 'drama'),
#  (10059578, 'For a Few Dollars More', 'Per qualche dollaro in più', 1965, None, 132, 8.3, 211290, 10059578, 'western'),
#  (10060196, 'The Good, the Bad and the Ugly', 'Il buono, il brutto, il cattivo', 1966, None, 161, 8.8, 635567, 10060196, 'western'),
#  (10060107, 'Andrei Rublev', 'Andrey Rublev', 1966, None, 205, 8.2, 40173, 10060107, 'biography'),
#  (10060107, 'Andrei Rublev', 'Andrey Rublev', 1966, None, 205, 8.2, 40173, 10060107, 'drama'),
#  (10060107, 'Andrei Rublev', 'Andrey Rublev', 1966, None, 205, 8.2, 40173, 10060107, 'history'),
#  (10060827, 'Persona', None, 1966, None, 85, 8.1, 89411, 10060827, 'drama'),
#  (10060827, 'Persona', None, 1966, None, 85, 8.1, 89411, 10060827, 'thriller'),
#  (10062229, 'Le Samouraï', 'Le samouraï', 1967, None, 105, 8.1, 40258, 10062229, 'crime'),
#  (10062229, 'Le Samouraï', 'Le samouraï', 1967, None, 105, 8.1, 40258, 10062229, 'drama'),
#  (10062229, 'Le Samouraï', 'Le samouraï', 1967, None, 105, 8.1, 40258, 10062229, 'mystery'),
#  (10062622, '2001: A Space Odyssey', None, 1968, None, 149, 8.3, 553461, 10062622, 'adventure'),
#  (10062622, '2001: A Space Odyssey', None, 1968, None, 149, 8.3, 553461, 10062622, 'sci-fi'),
#  (10064040, 'Army of Shadows', "L'armée des ombres", 1969, None, 145, 8.2, 18354, 10064040, 'war'),
#  (10065234, 'Z', None, 1969, None, 127, 8.3, 21720, 10065234, 'drama'),
#  (10065234, 'Z', None, 1969, None, 127, 8.3, 21720, 10065234, 'history'),
#  (10066580, 'Woodstock', None, 1970, None, 184, 8.2, 15083, 10066580, 'documentary'),
#  (10066580, 'Woodstock', None, 1970, None, 184, 8.2, 15083, 10066580, 'music'),
#  (10066763, 'Anand', None, 1971, None, 122, 8.8, 23729, 10066763, 'drama'),
#  (10066763, 'Anand', None, 1971, None, 122, 8.8, 23729, 10066763, 'musical'),
#  (10066921, 'A Clockwork Orange', None, 1971, None, 136, 8.3, 702198, 10066921, 'crime'),
#  (10066921, 'A Clockwork Orange', None, 1971, None, 136, 8.3, 702198, 10066921, 'drama'),
#  (10066921, 'A Clockwork Orange', None, 1971, None, 136, 8.3, 702198, 10066921, 'sci-fi'),
#  (10068646, 'The Godfather', None, 1972, None, 175, 9.2, 1469175, 10068646, 'crime'),
#  (10068646, 'The Godfather', None, 1972, None, 175, 9.2, 1469175, 10068646, 'drama'),
#  (10069467, 'Cries & Whispers', 'Viskningar och rop', 1972, None, 91, 8.1, 26495, 10069467, 'drama'),
#  (10069293, 'Solaris', 'Solyaris', 1972, None, 167, 8.1, 71554, 10069293, 'drama'),
#  (10069293, 'Solaris', 'Solyaris', 1972, None, 167, 8.1, 71554, 10069293, 'mystery'),
#  (10070510, 'Paper Moon', None, 1973, None, 102, 8.1, 38662, 10070510, 'comedy'),
#  (10070510, 'Paper Moon', None, 1973, None, 102, 8.1, 38662, 10070510, 'drama'),
#  (10070735, 'The Sting', None, 1973, None, 129, 8.3, 224160, 10070735, 'comedy'),
#  (10070735, 'The Sting', None, 1973, None, 129, 8.3, 224160, 10070735, 'crime'),
#  (10070735, 'The Sting', None, 1973, None, 129, 8.3, 224160, 10070735, 'drama'),
#  (10071411, 'Dersu Uzala', None, 1975, None, 142, 8.3, 21473, 10071411, 'drama'),
#  (10071315, 'Chinatown', None, 1974, None, 130, 8.2, 270509, 10071315, 'drama'),
#  (10071315, 'Chinatown', None, 1974, None, 130, 8.2, 270509, 10071315, 'mystery'),
#  (10071315, 'Chinatown', None, 1974, None, 130, 8.2, 270509, 10071315, 'thriller'),
#  (10071562, 'The Godfather: Part II', None, 1974, None, 202, 9.0, 1022270, 10071562, 'crime'),
#  (10071562, 'The Godfather: Part II', None, 1974, None, 202, 9.0, 1022270, 10071562, 'drama'),
#  (10072417, 'A Woman Under the Influence', None, 1974, None, 155, 8.2, 18626, 10072417, 'romance'),
#  (10072684, 'Barry Lyndon', None, 1975, None, 185, 8.1, 135169, 10072684, 'adventure'),
#  (10072684, 'Barry Lyndon', None, 1975, None, 185, 8.1, 135169, 10072684, 'drama'),
#  (10072684, 'Barry Lyndon', None, 1975, None, 185, 8.1, 135169, 10072684, 'history'),
#  (10073486, "One Flew Over the Cuckoo's Nest", None, 1975, None, 133, 8.7, 846275, 10073486, 'drama'),
#  (10073707, 'Sholay', None, 1975, None, 198, 8.2, 47587, 10073707, 'comedy'),
#  (10074605, 'Harlan County U.S.A.', None, 1976, None, 103, 8.2, 4407, 10074605, 'documentary'),
#  (10074896, 'The Message', None, 1976, None, 177, 8.2, 40643, 10074896, 'biography'),
#  (10074896, 'The Message', None, 1976, None, 177, 8.2, 40643, 10074896, 'drama'),
#  (10074896, 'The Message', None, 1976, None, 177, 8.2, 40643, 10074896, 'history'),
#  (10074958, 'Network', None, 1976, None, 121, 8.1, 133964, 10074958, 'drama'),
#  (10075148, 'Rocky', None, 1976, None, 120, 8.1, 481096, 10075148, 'drama'),
#  (10075148, 'Rocky', None, 1976, None, 120, 8.1, 481096, 10075148, 'sport'),
#  (10075314, 'Taxi Driver', None, 1976, None, 114, 8.3, 651641, 10075314, 'crime'),
#  (10075314, 'Taxi Driver', None, 1976, None, 114, 8.3, 651641, 10075314, 'drama'),
#  (10077416, 'The Deer Hunter', None, 1978, None, 183, 8.1, 288780, 10077416, 'drama'),
#  (10077416, 'The Deer Hunter', None, 1978, None, 183, 8.1, 288780, 10077416, 'war'),
#  (10077711, 'Autumn Sonata', 'Höstsonaten', 1978, None, 99, 8.3, 21687, 10077711, 'drama'),
#  (10077711, 'Autumn Sonata', 'Höstsonaten', 1978, None, 99, 8.3, 21687, 10077711, 'music'),
#  (10077838, 'The Last Waltz', None, 1978, None, 117, 8.2, 14868, 10077838, 'documentary'),
#  (10077838, 'The Last Waltz', None, 1978, None, 117, 8.2, 14868, 10077838, 'music'),
#  (10078748, 'Alien', None, 1979, None, 117, 8.4, 727639, 10078748, 'horror'),
#  (10078748, 'Alien', None, 1979, None, 117, 8.4, 727639, 10078748, 'sci-fi'),
#  (10078788, 'Apocalypse Now', None, 1979, None, 147, 8.4, 559212, 10078788, 'drama'),
#  (10078788, 'Apocalypse Now', None, 1979, None, 147, 8.4, 559212, 10078788, 'mystery'),
#  (10078788, 'Apocalypse Now', None, 1979, None, 147, 8.4, 559212, 10078788, 'war'),
#  (10079470, "Monty Python's Life of Brian", 'Life of Brian', 1979, None, 94, 8.1, 340278, 10079470, 'comedy'),
#  (10079807, 'Richard Pryor: Live in Concert', None, 1979, None, 78, 8.2, 3984, 10079807, 'documentary'),
#  (10079944, 'Stalker', None, 1979, None, 162, 8.2, 100877, 10079944, 'drama'),
#  (10080678, 'The Elephant Man', None, 1980, None, 124, 8.1, 203388, 10080678, 'biography'),
#  (10080678, 'The Elephant Man', None, 1980, None, 124, 8.1, 203388, 10080678, 'drama'),
#  (10080684, 'Star Wars: Episode V - The Empire Strikes Back', None, 1980, None, 124, 8.7, 1070676, 10080684, 'action'),
#  (10080684, 'Star Wars: Episode V - The Empire Strikes Back', None, 1980, None, 124, 8.7, 1070676, 10080684, 'adventure'),
#  (10080684, 'Star Wars: Episode V - The Empire Strikes Back', None, 1980, None, 124, 8.7, 1070676, 10080684, 'fantasy'),
#  (10081398, 'Raging Bull', None, 1980, None, 129, 8.2, 293859, 10081398, 'biography'),
#  (10081398, 'Raging Bull', None, 1980, None, 129, 8.2, 293859, 10081398, 'drama'),
#  (10081398, 'Raging Bull', None, 1980, None, 129, 8.2, 293859, 10081398, 'sport'),
#  (10081505, 'The Shining', None, 1980, None, 146, 8.4, 800631, 10081505, 'drama'),
#  (10081505, 'The Shining', None, 1980, None, 146, 8.4, 800631, 10081505, 'horror'),
#  (10082096, 'Das Boot', None, 1981, None, 149, 8.3, 214299, 10082096, 'adventure'),
#  (10082096, 'Das Boot', None, 1981, None, 149, 8.3, 214299, 10082096, 'drama'),
#  (10082096, 'Das Boot', None, 1981, None, 149, 8.3, 214299, 10082096, 'thriller'),
#  (10082971, 'Raiders of the Lost Ark', None, 1981, None, 115, 8.4, 826087, 10082971, 'action'),
#  (10082971, 'Raiders of the Lost Ark', None, 1981, None, 115, 8.4, 826087, 10082971, 'adventure'),
#  (10083658, 'Blade Runner', None, 1982, None, 117, 8.1, 640079, 10083658, 'action'),
#  (10083658, 'Blade Runner', None, 1982, None, 117, 8.1, 640079, 10083658, 'sci-fi'),
#  (10083658, 'Blade Runner', None, 1982, None, 117, 8.1, 640079, 10083658, 'thriller'),
#  (10083922, 'Fanny and Alexander', 'Fanny och Alexander', 1982, None, 188, 8.1, 52916, 10083922, 'drama'),
#  (10083946, 'Fitzcarraldo', None, 1982, None, 158, 8.1, 28143, 10083946, 'drama'),
#  (10084503, 'Pink Floyd: The Wall', None, 1982, None, 95, 8.1, 71426, 10084503, 'animation'),
#  (10084503, 'Pink Floyd: The Wall', None, 1982, None, 95, 8.1, 71426, 10084503, 'drama'),
#  (10084503, 'Pink Floyd: The Wall', None, 1982, None, 95, 8.1, 71426, 10084503, 'fantasy'),
#  (10085809, 'Koyaanisqatsi', None, 1982, None, 86, 8.3, 32441, 10085809, 'documentary'),
#  (10085809, 'Koyaanisqatsi', None, 1982, None, 86, 8.3, 32441, 10085809, 'music'),
#  (10086250, 'Scarface', None, 1983, None, 170, 8.3, 677181, 10086250, 'crime'),
#  (10086250, 'Scarface', None, 1983, None, 170, 8.3, 677181, 10086250, 'drama'),
#  (10086879, 'Amadeus', None, 1984, None, 160, 8.3, 342773, 10086879, 'biography'),
#  (10086879, 'Amadeus', None, 1984, None, 160, 8.3, 342773, 10086879, 'drama'),
#  (10086879, 'Amadeus', None, 1984, None, 160, 8.3, 342773, 10086879, 'history'),
#  (10087843, 'Once Upon a Time in America', None, 1984, None, 229, 8.4, 283611, 10087843, 'crime'),
#  (10087843, 'Once Upon a Time in America', None, 1984, None, 229, 8.4, 283611, 10087843, 'drama'),
#  (10087884, 'Paris, Texas', None, 1984, None, 145, 8.1, 77012, 10087884, 'drama'),
#  (10088178, 'Stop Making Sense', None, 1984, None, 88, 8.6, 11128, 10088178, 'documentary'),
#  (10088275, 'The Times of Harvey Milk', None, 1984, None, 90, 8.3, 5283, 10088275, 'documentary'),
#  (10088763, 'Back to the Future', None, 1985, None, 116, 8.5, 957158, 10088763, 'adventure'),
#  (10088763, 'Back to the Future', None, 1985, None, 116, 8.5, 957158, 10088763, 'comedy'),
#  (10088763, 'Back to the Future', None, 1985, None, 116, 8.5, 957158, 10088763, 'sci-fi'),
#  (10089881, 'Ran', None, 1985, None, 162, 8.2, 101512, 10089881, 'action'),
#  (10089881, 'Ran', None, 1985, None, 162, 8.2, 101512, 10089881, 'drama'),
#  (10090015, 'Shoah', None, 1985, None, 566, 8.6, 7711, 10090015, 'documentary'),
#  (10090605, 'Aliens', None, 1986, None, 137, 8.4, 610318, 10090605, 'action'),
#  (10090605, 'Aliens', None, 1986, None, 137, 8.4, 610318, 10090605, 'adventure'),
#  (10090605, 'Aliens', None, 1986, None, 137, 8.4, 610318, 10090605, 'sci-fi'),
#  (10091251, 'Come and See', 'Idi i smotri', 1985, None, 142, 8.3, 45054, 10091251, 'drama'),
#  (10091251, 'Come and See', 'Idi i smotri', 1985, None, 142, 8.3, 45054, 10091251, 'war'),
#  (10091763, 'Platoon', None, 1986, None, 120, 8.1, 356821, 10091763, 'drama'),
#  (10091763, 'Platoon', None, 1986, None, 120, 8.1, 356821, 10091763, 'war'),
#  (10092005, 'Stand by Me', None, 1986, None, 89, 8.1, 339156, 10092005, 'adventure'),
#  (10092005, 'Stand by Me', None, 1986, None, 89, 8.1, 339156, 10092005, 'drama'),
#  (10093058, 'Full Metal Jacket', None, 1987, None, 116, 8.3, 621802, 10093058, 'drama'),
#  (10093058, 'Full Metal Jacket', None, 1987, None, 116, 8.3, 621802, 10093058, 'war'),
#  (10093779, 'The Princess Bride', None, 1987, None, 98, 8.1, 365917, 10093779, 'adventure'),
#  (10093779, 'The Princess Bride', None, 1987, None, 98, 8.1, 365917, 10093779, 'family'),
#  (10093779, 'The Princess Bride', None, 1987, None, 98, 8.1, 365917, 10093779, 'fantasy'),
#  (10094625, 'Akira', None, 1988, None, 124, 8.1, 144659, 10094625, 'animation'),
#  (10094625, 'Akira', None, 1988, None, 124, 8.1, 144659, 10094625, 'drama'),
#  (10094625, 'Akira', None, 1988, None, 124, 8.1, 144659, 10094625, 'sci-fi'),
#  (10095016, 'Die Hard', None, 1988, None, 132, 8.2, 730992, 10095016, 'action'),
#  (10095016, 'Die Hard', None, 1988, None, 132, 8.2, 730992, 10095016, 'thriller'),
#  (10095327, 'Grave of the Fireflies', 'Hotaru no haka', 1988, None, 89, 8.5, 203313, 10095327, 'animation'),
#  (10095327, 'Grave of the Fireflies', 'Hotaru no haka', 1988, None, 89, 8.5, 203313, 10095327, 'drama'),
#  (10095327, 'Grave of the Fireflies', 'Hotaru no haka', 1988, None, 89, 8.5, 203313, 10095327, 'war'),
#  (10097165, 'Dead Poets Society', None, 1989, None, 128, 8.1, 379490, 10097165, 'comedy'),
#  (10097165, 'Dead Poets Society', None, 1989, None, 128, 8.1, 379490, 10097165, 'drama'),
#  (10097223, 'Time of the Gypsies', 'Dom za vesanje', 1988, None, 142, 8.3, 22769, 10097223, 'comedy'),
#  (10097372, 'For All Mankind', None, 1989, None, 80, 8.2, 4680, 10097372, 'documentary'),
#  (10097223, 'Time of the Gypsies', 'Dom za vesanje', 1988, None, 142, 8.3, 22769, 10097223, 'drama'),
#  (10099685, 'Goodfellas', None, 1990, None, 146, 8.7, 924841, 10099685, 'biography'),
#  (10099685, 'Goodfellas', None, 1990, None, 146, 8.7, 924841, 10099685, 'crime'),
#  (10099685, 'Goodfellas', None, 1990, None, 146, 8.7, 924841, 10099685, 'drama'),
#  (10100332, 'Paris Is Burning', None, 1990, None, 71, 8.2, 9994, 10100332, 'documentary'),
#  (10101640, 'Raise the Red Lantern', 'Da hong deng long gao gao gua', 1991, None, 125, 8.1, 26855, 10101640, 'drama'),
#  (10101640, 'Raise the Red Lantern', 'Da hong deng long gao gao gua', 1991, None, 125, 8.1, 26855, 10101640, 'history'),
#  (10101640, 'Raise the Red Lantern', 'Da hong deng long gao gao gua', 1991, None, 125, 8.1, 26855, 10101640, 'romance'),
#  (10102015, "Hearts of Darkness: A Filmmaker's Apocalypse", None, 1991, None, 96, 8.1, 17171, 10102015, 'documentary'),
#  (10102926, 'The Silence of the Lambs', None, 1991, None, 118, 8.6, 1159171, 10102926, 'crime'),
#  (10102926, 'The Silence of the Lambs', None, 1991, None, 118, 8.6, 1159171, 10102926, 'drama'),
#  (10102926, 'The Silence of the Lambs', None, 1991, None, 118, 8.6, 1159171, 10102926, 'thriller'),
#  (10103064, 'Terminator 2: Judgment Day', None, 1991, None, 137, 8.5, 924601, 10103064, 'action'),
#  (10103064, 'Terminator 2: Judgment Day', None, 1991, None, 137, 8.5, 924601, 10103064, 'sci-fi'),
#  (10103767, 'Baraka', None, 1992, None, 96, 8.6, 33624, 10103767, 'documentary'),
#  (10104561, 'Jo Jeeta Wohi Sikandar', None, 1992, None, 174, 8.2, 20164, 10104561, 'romance'),
#  (10105236, 'Reservoir Dogs', None, 1992, None, 99, 8.3, 846335, 10105236, 'crime'),
#  (10105236, 'Reservoir Dogs', None, 1992, None, 99, 8.3, 846335, 10105236, 'drama'),
#  (10105236, 'Reservoir Dogs', None, 1992, None, 99, 8.3, 846335, 10105236, 'thriller'),
#  (10105695, 'Unforgiven', None, 1992, None, 130, 8.2, 347318, 10105695, 'drama'),
#  (10105695, 'Unforgiven', None, 1992, None, 130, 8.2, 347318, 10105695, 'western'),
#  (10107207, 'In the Name of the Father', None, 1993, None, 133, 8.1, 143913, 10107207, 'biography'),
#  (10107207, 'In the Name of the Father', None, 1993, None, 133, 8.1, 143913, 10107207, 'drama'),
#  (10108052, "Schindler's List", None, 1993, None, 195, 8.9, 1110590, 10108052, 'biography'),
#  (10108052, "Schindler's List", None, 1993, None, 195, 8.9, 1110590, 10108052, 'drama'),
#  (10108052, "Schindler's List", None, 1993, None, 195, 8.9, 1110590, 10108052, 'history'),
#  (10109117, 'Andaz Apna Apna', None, 1994, None, 160, 8.2, 46193, 10109117, 'comedy'),
#  (10109117, 'Andaz Apna Apna', None, 1994, None, 160, 8.2, 46193, 10109117, 'family'),
#  (10109117, 'Andaz Apna Apna', None, 1994, None, 160, 8.2, 46193, 10109117, 'romance'),
#  (10109424, 'Chungking Express', 'Chung Hing sam lam', 1994, None, 102, 8.1, 54467, 10109424, 'comedy'),
#  (10109424, 'Chungking Express', 'Chung Hing sam lam', 1994, None, 102, 8.1, 54467, 10109424, 'crime'),
#  (10109424, 'Chungking Express', 'Chung Hing sam lam', 1994, None, 102, 8.1, 54467, 10109424, 'drama'),
#  (10109830, 'Forrest Gump', None, 1994, None, 142, 8.8, 1647191, 10109830, 'drama'),
#  (10109830, 'Forrest Gump', None, 1994, None, 142, 8.8, 1647191, 10109830, 'romance'),
#  (10110057, 'Hoop Dreams', None, 1994, None, 170, 8.3, 22591, 10110057, 'documentary'),
#  (10110057, 'Hoop Dreams', None, 1994, None, 170, 8.3, 22591, 10110057, 'drama'),
#  (10110057, 'Hoop Dreams', None, 1994, None, 170, 8.3, 22591, 10110057, 'sport'),
#  (10110912, 'Pulp Fiction', None, 1994, None, 154, 8.9, 1679768, 10110912, 'crime'),
#  (10110912, 'Pulp Fiction', None, 1994, None, 154, 8.9, 1679768, 10110912, 'drama'),
#  (10112573, 'Braveheart', None, 1995, None, 178, 8.3, 903510, 10112573, 'biography'),
#  (10112573, 'Braveheart', None, 1995, None, 178, 8.3, 903510, 10112573, 'drama'),
#  (10112573, 'Braveheart', None, 1995, None, 178, 8.3, 903510, 10112573, 'history'),
#  (10112641, 'Casino', None, 1995, None, 178, 8.2, 421776, 10112641, 'crime'),
#  (10112641, 'Casino', None, 1995, None, 178, 8.2, 421776, 10112641, 'drama'),
#  (10112471, 'Before Sunrise', None, 1995, None, 101, 8.1, 243223, 10112471, 'drama'),
#  (10112471, 'Before Sunrise', None, 1995, None, 101, 8.1, 243223, 10112471, 'romance'),
#  (10113277, 'Heat', None, 1995, None, 170, 8.2, 532271, 10113277, 'crime'),
#  (10113277, 'Heat', None, 1995, None, 170, 8.2, 532271, 10113277, 'drama'),
#  (10113277, 'Heat', None, 1995, None, 170, 8.2, 532271, 10113277, 'thriller'),
#  (10114787, 'Underground', None, 1995, None, 170, 8.1, 51516, 10114787, 'comedy'),
#  (10114787, 'Underground', None, 1995, None, 170, 8.1, 51516, 10114787, 'drama'),
#  (10114787, 'Underground', None, 1995, None, 170, 8.1, 51516, 10114787, 'war'),
#  (10114709, 'Toy Story', None, 1995, None, 81, 8.3, 815598, 10114709, 'adventure'),
#  (10114709, 'Toy Story', None, 1995, None, 81, 8.3, 815598, 10114709, 'animation'),
#  (10114709, 'Toy Story', None, 1995, None, 81, 8.3, 815598, 10114709, 'comedy'),
#  (10114814, 'The Usual Suspects', None, 1995, None, 106, 8.5, 922333, 10114814, 'crime'),
#  (10114814, 'The Usual Suspects', None, 1995, None, 106, 8.5, 922333, 10114814, 'mystery'),
#  (10114814, 'The Usual Suspects', None, 1995, None, 106, 8.5, 922333, 10114814, 'thriller'),
#  (10116282, 'Fargo', None, 1996, None, 98, 8.1, 570681, 10116282, 'crime'),
#  (10116231, 'The Bandit', 'Eskiya', 1996, None, 128, 8.3, 56769, 10116231, 'crime'),
#  (10116231, 'The Bandit', 'Eskiya', 1996, None, 128, 8.3, 56769, 10116231, 'drama'),
#  (10116231, 'The Bandit', 'Eskiya', 1996, None, 128, 8.3, 56769, 10116231, 'thriller'),
#  (10116282, 'Fargo', None, 1996, None, 98, 8.1, 570681, 10116282, 'drama'),
#  (10116282, 'Fargo', None, 1996, None, 98, 8.1, 570681, 10116282, 'thriller'),
#  (10117293, 'Paradise Lost: The Child Murders at Robin Hood Hills', None, 1996, None, 150, 8.3, 14001, 10117293, 'documentary'),
#  (10117951, 'Trainspotting', None, 1996, None, 93, 8.1, 597357, 10117951, 'drama'),
#  (10118694, 'In the Mood for Love', 'Faa yeung nin wa', 2000, None, 98, 8.1, 108531, 10118694, 'drama'),
#  (10118694, 'In the Mood for Love', 'Faa yeung nin wa', 2000, None, 98, 8.1, 108531, 10118694, 'romance'),
#  (10118715, 'The Big Lebowski', None, 1998, None, 117, 8.1, 674570, 10118715, 'comedy'),
#  (10118715, 'The Big Lebowski', None, 1998, None, 117, 8.1, 674570, 10118715, 'crime'),
#  (10118843, 'Black Cat, White Cat', 'Crna macka, beli macor', 1998, None, 127, 8.1, 47683, 10118843, 'comedy'),
#  (10118843, 'Black Cat, White Cat', 'Crna macka, beli macor', 1998, None, 127, 8.1, 47683, 10118843, 'crime'),
#  (10118843, 'Black Cat, White Cat', 'Crna macka, beli macor', 1998, None, 127, 8.1, 47683, 10118843, 'romance'),
#  (10118849, 'Children of Heaven', 'Bacheha-Ye aseman', 1997, None, 89, 8.3, 55508, 10118849, 'drama'),
#  (10118849, 'Children of Heaven', 'Bacheha-Ye aseman', 1997, None, 89, 8.3, 55508, 10118849, 'family'),
#  (10119217, 'Good Will Hunting', None, 1997, None, 126, 8.3, 783158, 10119217, 'drama'),
#  (10119217, 'Good Will Hunting', None, 1997, None, 126, 8.3, 783158, 10119217, 'romance'),
#  (10120586, 'American History X', None, 1998, None, 119, 8.5, 966543, 10120586, 'drama'),
#  (10120815, 'Saving Private Ryan', None, 1998, None, 169, 8.6, 1134049, 10120815, 'drama'),
#  (10120815, 'Saving Private Ryan', None, 1998, None, 169, 8.6, 1134049, 10120815, 'war'),
#  (10120689, 'The Green Mile', None, 1999, None, 189, 8.6, 1039788, 10120689, 'crime'),
#  (10120689, 'The Green Mile', None, 1999, None, 189, 8.6, 1039788, 10120689, 'drama'),
#  (10120689, 'The Green Mile', None, 1999, None, 189, 8.6, 1039788, 10120689, 'fantasy'),
#  (10120731, 'The Legend of 1900', "La leggenda del pianista sull'oceano", 1998, None, 170, 8.1, 53451, 10120731, 'drama'),
#  (10120731, 'The Legend of 1900', "La leggenda del pianista sull'oceano", 1998, None, 170, 8.1, 53451, 10120731, 'music'),
#  (10120731, 'The Legend of 1900', "La leggenda del pianista sull'oceano", 1998, None, 170, 8.1, 53451, 10120731, 'romance'),
#  (10120737, 'The Lord of the Rings: The Fellowship of the Ring', None, 2001, None, 178, 8.8, 1537080, 10120737, 'adventure'),
#  (10120737, 'The Lord of the Rings: The Fellowship of the Ring', None, 2001, None, 178, 8.8, 1537080, 10120737, 'drama'),
#  (10120737, 'The Lord of the Rings: The Fellowship of the Ring', None, 2001, None, 178, 8.8, 1537080, 10120737, 'fantasy'),
#  (10133093, 'The Matrix', None, 1999, None, 136, 8.7, 1541080, 10133093, 'action'),
#  (10133093, 'The Matrix', None, 1999, None, 136, 8.7, 1541080, 10133093, 'sci-fi'),
#  (10137523, 'Fight Club', None, 1999, None, 139, 8.8, 1710654, 10137523, 'drama'),
#  (10167404, 'The Sixth Sense', None, 1999, None, 107, 8.1, 856620, 10167404, 'drama'),
#  (10167261, 'The Lord of the Rings: The Two Towers', None, 2002, None, 179, 8.7, 1376277, 10167261, 'adventure'),
#  (10167261, 'The Lord of the Rings: The Two Towers', None, 2002, None, 179, 8.7, 1376277, 10167261, 'drama'),
#  (10167261, 'The Lord of the Rings: The Two Towers', None, 2002, None, 179, 8.7, 1376277, 10167261, 'fantasy'),
#  (10167404, 'The Sixth Sense', None, 1999, None, 107, 8.1, 856620, 10167404, 'mystery'),
#  (10167404, 'The Sixth Sense', None, 1999, None, 107, 8.1, 856620, 10167404, 'thriller'),
#  (10169547, 'American Beauty', None, 1999, None, 122, 8.3, 1003490, 10169547, 'drama'),
#  (10172495, 'Gladiator', None, 2000, None, 155, 8.5, 1235197, 10172495, 'action'),
#  (10172495, 'Gladiator', None, 2000, None, 155, 8.5, 1235197, 10172495, 'adventure'),
#  (10172495, 'Gladiator', None, 2000, None, 155, 8.5, 1235197, 10172495, 'drama'),
#  (10180093, 'Requiem for a Dream', None, 2000, None, 102, 8.3, 711759, 10180093, 'drama'),
#  (10200087, 'Sarfarosh', None, 1999, None, 174, 8.1, 22628, 10200087, 'drama'),
#  (10209144, 'Memento', None, 2000, None, 113, 8.4, 1046008, 10209144, 'mystery'),
#  (10209144, 'Memento', None, 2000, None, 113, 8.4, 1046008, 10209144, 'thriller'),
#  (10242519, 'Hera Pheri', None, 2000, None, 156, 8.2, 49524, 10242519, 'comedy'),
#  (10242519, 'Hera Pheri', None, 2000, None, 156, 8.2, 49524, 10242519, 'crime'),
#  (10244316, 'Yi Yi', 'Yi yi', 2000, None, 173, 8.1, 17590, 10244316, 'romance'),
#  (10245429, 'Spirited Away', 'Sen to Chihiro no kamikakushi', 2001, None, 125, 8.6, 571447, 10245429, 'adventure'),
#  (10245429, 'Spirited Away', 'Sen to Chihiro no kamikakushi', 2001, None, 125, 8.6, 571447, 10245429, 'animation'),
#  (10245429, 'Spirited Away', 'Sen to Chihiro no kamikakushi', 2001, None, 125, 8.6, 571447, 10245429, 'family'),
#  (10245712, 'Amores Perros', 'Amores perros', 2000, None, 154, 8.1, 209490, 10245712, 'drama'),
#  (10245712, 'Amores Perros', 'Amores perros', 2000, None, 154, 8.1, 209490, 10245712, 'thriller'),
#  (10252487, 'The Chaos Class', 'Hababam Sinifi', 1975, None, 87, 9.4, 34299, 10252487, 'comedy'),
#  (10252487, 'The Chaos Class', 'Hababam Sinifi', 1975, None, 87, 9.4, 34299, 10252487, 'drama'),
#  (10253474, 'The Pianist', None, 2002, None, 150, 8.5, 658649, 10253474, 'biography'),
#  (10253474, 'The Pianist', None, 2002, None, 150, 8.5, 658649, 10253474, 'drama'),
#  (10253474, 'The Pianist', None, 2002, None, 150, 8.5, 658649, 10253474, 'music'),
#  (10253828, 'Tosun Pasa', None, 1976, None, 90, 9.0, 19491, 10253828, 'history'),
#  (10264464, 'Catch Me If You Can', None, 2002, None, 141, 8.1, 737626, 10264464, 'biography'),
#  (10264464, 'Catch Me If You Can', None, 2002, None, 141, 8.1, 737626, 10264464, 'crime'),
#  (10264464, 'Catch Me If You Can', None, 2002, None, 141, 8.1, 737626, 10264464, 'drama'),
#  (10266543, 'Finding Nemo', None, 2003, None, 100, 8.1, 883541, 10266543, 'adventure'),
#  (10266543, 'Finding Nemo', None, 2003, None, 100, 8.1, 883541, 10266543, 'animation'),
#  (10266543, 'Finding Nemo', None, 2003, None, 100, 8.1, 883541, 10266543, 'comedy'),
#  (10266697, 'Kill Bill: Vol. 1', None, 2003, None, 111, 8.1, 925586, 10266697, 'action'),
#  (10266697, 'Kill Bill: Vol. 1', None, 2003, None, 111, 8.1, 925586, 10266697, 'crime'),
#  (10266697, 'Kill Bill: Vol. 1', None, 2003, None, 111, 8.1, 925586, 10266697, 'thriller'),
#  (10292490, 'Dil Chahta Hai', None, 2001, None, 183, 8.1, 61984, 10292490, 'comedy'),
#  (10292490, 'Dil Chahta Hai', None, 2001, None, 183, 8.1, 61984, 10292490, 'drama'),
#  (10292490, 'Dil Chahta Hai', None, 2001, None, 183, 8.1, 61984, 10292490, 'romance'),
#  (10317248, 'City of God', 'Cidade de Deus', 2002, None, 130, 8.6, 654899, 10317248, 'crime'),
#  (10317248, 'City of God', 'Cidade de Deus', 2002, None, 130, 8.6, 654899, 10317248, 'drama'),
#  (10317910, 'The Fog of War: Eleven Lessons from the Life of Robert S. McNamara', None, 2003, None, 107, 8.1, 21924, 10317910, 'documentary'),
#  (10317910, 'The Fog of War: Eleven Lessons from the Life of Robert S. McNamara', None, 2003, None, 107, 8.1, 21924, 10317910, 'history'),
#  (10338013, 'Eternal Sunshine of the Spotless Mind', None, 2004, None, 108, 8.3, 838801, 10338013, 'drama'),
#  (10338013, 'Eternal Sunshine of the Spotless Mind', None, 2004, None, 108, 8.3, 838801, 10338013, 'romance'),
#  (10338013, 'Eternal Sunshine of the Spotless Mind', None, 2004, None, 108, 8.3, 838801, 10338013, 'sci-fi'),
#  (10338564, 'Infernal Affairs', 'Mou gaan dou', 2002, None, 101, 8.1, 112269, 10338564, 'crime'),
#  (10338564, 'Infernal Affairs', 'Mou gaan dou', 2002, None, 101, 8.1, 112269, 10338564, 'drama'),
#  (10338564, 'Infernal Affairs', 'Mou gaan dou', 2002, None, 101, 8.1, 112269, 10338564, 'mystery'),
#  (10346336, 'The Best of Youth', 'La meglio gioventù', 2003, None, 366, 8.5, 19261, 10346336, 'romance'),
#  (10347149, "Howl's Moving Castle", 'Hauru no ugoku shiro', 2004, None, 119, 8.2, 289126, 10347149, 'adventure'),
#  (10347149, "Howl's Moving Castle", 'Hauru no ugoku shiro', 2004, None, 119, 8.2, 289126, 10347149, 'animation'),
#  (10347149, "Howl's Moving Castle", 'Hauru no ugoku shiro', 2004, None, 119, 8.2, 289126, 10347149, 'family'),
#  (10353969, 'Memories of Murder', 'Salinui chueok', 2003, None, 131, 8.1, 105565, 10353969, 'action'),
#  (10353969, 'Memories of Murder', 'Salinui chueok', 2003, None, 131, 8.1, 105565, 10353969, 'crime'),
#  (10353969, 'Memories of Murder', 'Salinui chueok', 2003, None, 131, 8.1, 105565, 10353969, 'drama'),
#  (10361748, 'Inglourious Basterds', None, 2009, None, 153, 8.3, 1151901, 10361748, 'adventure'),
#  (10361748, 'Inglourious Basterds', None, 2009, None, 153, 8.3, 1151901, 10361748, 'drama'),
#  (10361748, 'Inglourious Basterds', None, 2009, None, 153, 8.3, 1151901, 10361748, 'war'),
#  (10363163, 'Downfall', 'Der Untergang', 2004, None, 156, 8.2, 310275, 10363163, 'biography'),
#  (10363163, 'Downfall', 'Der Untergang', 2004, None, 156, 8.2, 310275, 10363163, 'drama'),
#  (10363163, 'Downfall', 'Der Untergang', 2004, None, 156, 8.2, 310275, 10363163, 'history'),
#  (10364569, 'Oldboy', 'Oldeuboi', 2003, None, 120, 8.4, 468224, 10364569, 'action'),
#  (10364569, 'Oldboy', 'Oldeuboi', 2003, None, 120, 8.4, 468224, 10364569, 'drama'),
#  (10364569, 'Oldboy', 'Oldeuboi', 2003, None, 120, 8.4, 468224, 10364569, 'mystery'),
#  (10372784, 'Batman Begins', None, 2005, None, 140, 8.2, 1214415, 10372784, 'action'),
#  (10372784, 'Batman Begins', None, 2005, None, 140, 8.2, 1214415, 10372784, 'adventure'),
#  (10374887, 'Munna Bhai M.B.B.S.', None, 2003, None, 156, 8.2, 66341, 10374887, 'comedy'),
#  (10374887, 'Munna Bhai M.B.B.S.', None, 2003, None, 156, 8.2, 66341, 10374887, 'drama'),
#  (10374887, 'Munna Bhai M.B.B.S.', None, 2003, None, 156, 8.2, 66341, 10374887, 'musical'),
#  (10375611, 'Black', None, 2005, None, 122, 8.2, 31502, 10375611, 'drama'),
#  (10379225, 'The Corporation', None, 2003, None, 145, 8.1, 19719, 10379225, 'documentary'),
#  (10379225, 'The Corporation', None, 2003, None, 145, 8.1, 19719, 10379225, 'history'),
#  (10386064, 'Tae Guk Gi: The Brotherhood of War', 'Taegukgi hwinalrimyeo', 2004, None, 140, 8.1, 36056, 10386064, 'drama'),
#  (10386064, 'Tae Guk Gi: The Brotherhood of War', 'Taegukgi hwinalrimyeo', 2004, None, 140, 8.1, 36056, 10386064, 'war'),
#  (10395169, 'Hotel Rwanda', None, 2004, None, 121, 8.1, 317018, 10395169, 'biography'),
#  (10395169, 'Hotel Rwanda', None, 2004, None, 121, 8.1, 317018, 10395169, 'drama'),
#  (10395169, 'Hotel Rwanda', None, 2004, None, 121, 8.1, 317018, 10395169, 'history'),
#  (10405094, 'The Lives of Others', 'Das Leben der Anderen', 2006, None, 137, 8.4, 329053, 10405094, 'drama'),
#  (10405094, 'The Lives of Others', 'Das Leben der Anderen', 2006, None, 137, 8.4, 329053, 10405094, 'thriller'),
#  (10405508, 'Rang De Basanti', None, 2006, None, 167, 8.2, 102440, 10405508, 'comedy'),
#  (10405508, 'Rang De Basanti', None, 2006, None, 167, 8.2, 102440, 10405508, 'drama'),
#  (10407887, 'The Departed', None, 2006, None, 151, 8.5, 1095443, 10407887, 'crime'),
#  (10407887, 'The Departed', None, 2006, None, 151, 8.5, 1095443, 10407887, 'drama'),
#  (10407887, 'The Departed', None, 2006, None, 151, 8.5, 1095443, 10407887, 'thriller'),
#  (10424227, 'Turtles Can Fly', 'Lakposhtha parvaz mikonand', 2004, None, 98, 8.1, 16467, 10424227, 'war'),
#  (10434409, 'V for Vendetta', None, 2005, None, 132, 8.2, 964991, 10434409, 'action'),
#  (10434409, 'V for Vendetta', None, 2005, None, 132, 8.2, 964991, 10434409, 'drama'),
#  (10434409, 'V for Vendetta', None, 2005, None, 132, 8.2, 964991, 10434409, 'sci-fi'),
#  (10435761, 'Toy Story 3', None, 2010, None, 103, 8.3, 701340, 10435761, 'adventure'),
#  (10435761, 'Toy Story 3', None, 2010, None, 103, 8.3, 701340, 10435761, 'animation'),
#  (10435761, 'Toy Story 3', None, 2010, None, 103, 8.3, 701340, 10435761, 'comedy'),
#  (10456144, 'Carry On, Munna Bhai', 'Lage Raho Munna Bhai', 2006, None, 144, 8.1, 39180, 10456144, 'comedy'),
#  (10456144, 'Carry On, Munna Bhai', 'Lage Raho Munna Bhai', 2006, None, 144, 8.1, 39180, 10456144, 'drama'),
#  (10456144, 'Carry On, Munna Bhai', 'Lage Raho Munna Bhai', 2006, None, 144, 8.1, 39180, 10456144, 'romance'),
#  (10457430, "Pan's Labyrinth", 'El laberinto del fauno', 2006, None, 118, 8.2, 580517, 10457430, 'drama'),
#  (10457430, "Pan's Labyrinth", 'El laberinto del fauno', 2006, None, 118, 8.2, 580517, 10457430, 'fantasy'),
#  (10457430, "Pan's Labyrinth", 'El laberinto del fauno', 2006, None, 118, 8.2, 580517, 10457430, 'war'),
#  (10468569, 'The Dark Knight', None, 2008, None, 152, 9.0, 2104377, 10468569, 'action'),
#  (10468569, 'The Dark Knight', None, 2008, None, 152, 9.0, 2104377, 10468569, 'crime'),
#  (10468569, 'The Dark Knight', None, 2008, None, 152, 9.0, 2104377, 10468569, 'drama'),
#  (10477348, 'No Country for Old Men', None, 2007, None, 122, 8.1, 780586, 10477348, 'crime'),
#  (10477348, 'No Country for Old Men', None, 2007, None, 122, 8.1, 780586, 10477348, 'drama'),
#  (10477348, 'No Country for Old Men', None, 2007, None, 122, 8.1, 780586, 10477348, 'thriller'),
#  (10478209, "Metal: A Headbanger's Journey", None, 2005, None, 96, 8.1, 11187, 10478209, 'documentary'),
#  (10482571, 'The Prestige', None, 2006, None, 130, 8.5, 1086148, 10482571, 'drama'),
#  (10482571, 'The Prestige', None, 2006, None, 130, 8.5, 1086148, 10482571, 'mystery'),
#  (10482571, 'The Prestige', None, 2006, None, 130, 8.5, 1086148, 10482571, 'sci-fi'),
#  (10493393, 'Ashes and Snow', None, 2005, None, 62, 8.2, 3691, 10493393, 'documentary'),
#  (10758758, 'Into the Wild', None, 2007, None, 148, 8.1, 531970, 10758758, 'adventure'),
#  (10758758, 'Into the Wild', None, 2007, None, 148, 8.1, 531970, 10758758, 'biography'),
#  (10758758, 'Into the Wild', None, 2007, None, 148, 8.1, 531970, 10758758, 'drama'),
#  (10770802, 'Samsara', None, 2011, None, 102, 8.5, 30307, 10770802, 'documentary'),
#  (10770802, 'Samsara', None, 2011, None, 102, 8.5, 30307, 10770802, 'music'),
#  (10816692, 'Interstellar', None, 2014, None, 169, 8.6, 1333037, 10816692, 'adventure'),
#  (10816692, 'Interstellar', None, 2014, None, 169, 8.6, 1333037, 10816692, 'drama'),
#  (10816692, 'Interstellar', None, 2014, None, 169, 8.6, 1333037, 10816692, 'sci-fi'),
#  (10861739, 'Elite Squad', 'Tropa de Elite', 2007, None, 115, 8.1, 93302, 10861739, 'action'),
#  (10861739, 'Elite Squad', 'Tropa de Elite', 2007, None, 115, 8.1, 93302, 10861739, 'crime'),
#  (10861739, 'Elite Squad', 'Tropa de Elite', 2007, None, 115, 8.1, 93302, 10861739, 'drama'),
#  (10871510, 'Chak de! India', 'Chak De! India', 2007, None, 153, 8.2, 67881, 10871510, 'drama'),
#  (10871510, 'Chak de! India', 'Chak De! India', 2007, None, 153, 8.2, 67881, 10871510, 'family'),
#  (10871510, 'Chak de! India', 'Chak De! India', 2007, None, 153, 8.2, 67881, 10871510, 'sport'),
#  (10892769, 'How to Train Your Dragon', None, 2010, None, 98, 8.1, 621377, 10892769, 'action'),
#  (10892769, 'How to Train Your Dragon', None, 2010, None, 98, 8.1, 621377, 10892769, 'adventure'),
#  (10892769, 'How to Train Your Dragon', None, 2010, None, 98, 8.1, 621377, 10892769, 'animation'),
#  (11545103, 'Rush: Beyond the Lighted Stage', None, 2010, None, 107, 8.4, 3701, 11545103, 'documentary'),
#  (11562872, 'Zindagi Na Milegi Dobara', None, 2011, None, 155, 8.1, 60324, 11562872, 'comedy'),
#  (11562872, 'Zindagi Na Milegi Dobara', None, 2011, None, 155, 8.1, 60324, 11562872, 'drama'),
#  (11618448, 'Racing Extinction', None, 2015, None, 90, 8.3, 7042, 11618448, 'documentary'),
#  (11620933, 'Paan Singh Tomar', None, 2012, None, 135, 8.2, 29844, 11620933, 'biography'),
#  (11639426, 'Udaan', None, 2010, None, 134, 8.2, 39392, 11639426, 'drama'),
#  (11645089, 'Inside Job', None, 2010, None, 109, 8.2, 65999, 11645089, 'crime'),
#  (11645089, 'Inside Job', None, 2010, None, 109, 8.2, 65999, 11645089, 'documentary'),
#  (11646967, 'The Art of Flight', None, 2011, None, 80, 8.2, 7361, 11646967, 'documentary'),
#  (11675434, 'The Intouchables', 'Intouchables', 2011, None, 112, 8.5, 691774, 11675434, 'biography'),
#  (11675434, 'The Intouchables', 'Intouchables', 2011, None, 112, 8.5, 691774, 11675434, 'comedy'),
#  (11675434, 'The Intouchables', 'Intouchables', 2011, None, 112, 8.5, 691774, 11675434, 'drama'),
#  (11692928, 'The Last Lions', None, 2011, None, 88, 8.3, 3858, 11692928, 'documentary'),
#  (11778338, 'The Culture High', None, 2014, None, 120, 8.3, 3496, 11778338, 'documentary'),
#  (11781069, 'Zeitgeist: Moving Forward', None, 2011, None, 161, 8.2, 16980, 11781069, 'documentary'),
#  (11789083, 'The Weight of Chains', None, 2010, None, 125, 8.3, 3912, 11789083, 'documentary'),
#  (11821480, 'Kahaani', None, 2012, None, 122, 8.1, 52865, 11821480, 'mystery'),
#  (11821480, 'Kahaani', None, 2012, None, 122, 8.1, 52865, 11821480, 'thriller'),
#  (11853563, 'Foo Fighters: Back and Forth', None, 2011, None, 101, 8.3, 5721, 11853563, 'documentary'),
#  (11853728, 'Django Unchained', None, 2012, None, 165, 8.4, 1238760, 11853728, 'drama'),
#  (11853728, 'Django Unchained', None, 2012, None, 165, 8.4, 1238760, 11853728, 'western'),
#  (11865505, 'Song of the Sea', None, 2014, None, 93, 8.1, 45270, 11865505, 'animation'),
#  (11865505, 'Song of the Sea', None, 2014, None, 93, 8.1, 45270, 11865505, 'drama'),
#  (11935156, "Jodorowsky's Dune", None, 2013, None, 90, 8.1, 19402, 11935156, 'documentary'),
#  (11954470, 'Gangs of Wasseypur', None, 2012, None, 321, 8.2, 70912, 11954470, 'action'),
#  (11954470, 'Gangs of Wasseypur', None, 2012, None, 321, 8.2, 70912, 11954470, 'comedy'),
#  (11954470, 'Gangs of Wasseypur', None, 2012, None, 321, 8.2, 70912, 11954470, 'crime'),
#  (11979320, 'Rush', None, 2013, None, 123, 8.1, 399848, 11979320, 'biography'),
#  (11979320, 'Rush', None, 2013, None, 123, 8.1, 399848, 11979320, 'drama'),
#  (11979320, 'Rush', None, 2013, None, 123, 8.1, 399848, 11979320, 'sport'),
#  (12028530, 'Paradise Lost 3: Purgatory', None, 2011, None, 121, 8.1, 8508, 12028530, 'documentary'),
#  (12082197, 'Barfi!', None, 2012, None, 151, 8.1, 70069, 12082197, 'comedy'),
#  (12082197, 'Barfi!', None, 2012, None, 151, 8.1, 70069, 12082197, 'drama'),
#  (12082197, 'Barfi!', None, 2012, None, 151, 8.1, 70069, 12082197, 'romance'),
#  (12096673, 'Inside Out', None, 2015, None, 95, 8.2, 550606, 12096673, 'adventure'),
#  (12096673, 'Inside Out', None, 2015, None, 95, 8.2, 550606, 12096673, 'animation'),
#  (12096673, 'Inside Out', None, 2015, None, 95, 8.2, 550606, 12096673, 'comedy'),
#  (12106476, 'The Hunt', 'Jagten', 2012, None, 115, 8.3, 248198, 12106476, 'drama'),
#  (12125608, 'Searching for Sugar Man', None, 2012, None, 86, 8.2, 59398, 12125608, 'biography'),
#  (12125608, 'Searching for Sugar Man', None, 2012, None, 86, 8.2, 59398, 12125608, 'documentary'),
#  (12125608, 'Searching for Sugar Man', None, 2012, None, 86, 8.2, 59398, 12125608, 'music'),
#  (12278388, 'The Grand Budapest Hotel', None, 2014, None, 99, 8.1, 645456, 12278388, 'adventure'),
#  (12278388, 'The Grand Budapest Hotel', None, 2014, None, 99, 8.1, 645456, 12278388, 'comedy'),
#  (12278388, 'The Grand Budapest Hotel', None, 2014, None, 99, 8.1, 645456, 12278388, 'crime'),
#  (12338151, 'PK', None, 2014, None, 153, 8.2, 142007, 12338151, 'comedy'),
#  (12338151, 'PK', None, 2014, None, 153, 8.2, 142007, 12338151, 'drama'),
#  (12338151, 'PK', None, 2014, None, 153, 8.2, 142007, 12338151, 'fantasy'),
#  (12357788, 'Bridegroom', None, 2013, None, 80, 8.1, 4236, 12357788, 'documentary'),
#  (12370718, 'Artifact', None, 2012, None, 103, 8.1, 4424, 12370718, 'documentary'),
#  (12375559, '1 - Nenokkadine', None, 2014, None, 170, 8.2, 41529, 12375559, 'thriller'),
#  (12375605, 'The Act of Killing', None, 2012, None, 117, 8.2, 31728, 12375605, 'biography'),
#  (12375605, 'The Act of Killing', None, 2012, None, 117, 8.2, 31728, 12375605, 'crime'),
#  (12375605, 'The Act of Killing', None, 2012, None, 117, 8.2, 31728, 12375605, 'documentary'),
#  (12380307, 'Coco', None, 2017, None, 105, 8.4, 297001, 12380307, 'adventure'),
#  (12380307, 'Coco', None, 2017, None, 105, 8.4, 297001, 12380307, 'animation'),
#  (12380307, 'Coco', None, 2017, None, 105, 8.4, 297001, 12380307, 'family'),
#  (12395469, 'Gully Boy', None, 2019, None, 153, 8.3, 21340, 12395469, 'drama'),
#  (12395469, 'Gully Boy', None, 2019, None, 153, 8.3, 21340, 12395469, 'music'),
#  (12486682, 'The Square', 'Al midan', 2013, None, 108, 8.1, 8120, 12486682, 'documentary'),
#  (12499076, 'The Crash Reel', None, 2013, None, 108, 8.2, 4560, 12499076, 'documentary'),
#  (12545118, 'Blackfish', None, 2013, None, 83, 8.1, 57453, 12545118, 'documentary'),
#  (12545118, 'Blackfish', None, 2013, None, 83, 8.1, 57453, 12545118, 'news'),
#  (12582802, 'Whiplash', None, 2014, None, 106, 8.5, 633887, 12582802, 'drama'),
#  (12582802, 'Whiplash', None, 2014, None, 106, 8.5, 633887, 12582802, 'music'),
#  (12592910, 'CM101MMXI Fundamentals', None, 2013, None, 139, 9.2, 41955, 12592910, 'comedy'),
#  (12592910, 'CM101MMXI Fundamentals', None, 2013, None, 139, 9.2, 41955, 12592910, 'documentary'),
#  (12631186, 'Baahubali: The Beginning', 'Bahubali: The Beginning', 2015, None, 159, 8.1, 94989, 12631186, 'action'),
#  (12631186, 'Baahubali: The Beginning', 'Bahubali: The Beginning', 2015, None, 159, 8.1, 94989, 12631186, 'drama'),
#  (12758880, 'Winter Sleep', 'Kis Uykusu', 2014, None, 196, 8.2, 38489, 12758880, 'drama'),
#  (13011894, 'Wild Tales', 'Relatos salvajes', 2014, None, 122, 8.1, 155185, 13011894, 'comedy'),
#  (13011894, 'Wild Tales', 'Relatos salvajes', 2014, None, 122, 8.1, 155185, 13011894, 'drama'),
#  (13011894, 'Wild Tales', 'Relatos salvajes', 2014, None, 122, 8.1, 155185, 13011894, 'thriller'),
#  (13170832, 'Room', None, 2015, None, 118, 8.2, 326042, 13170832, 'drama'),
#  (13170832, 'Room', None, 2015, None, 118, 8.2, 326042, 13170832, 'thriller'),
#  (13270538, 'Requiem for the American Dream', None, 2015, None, 73, 8.1, 8061, 13270538, 'documentary'),
#  (13302820, 'Cowspiracy: The Sustainability Secret', None, 2014, None, 90, 8.3, 18298, 13302820, 'documentary'),
#  (13315342, 'Logan', None, 2017, None, 137, 8.1, 578747, 13315342, 'action'),
#  (13315342, 'Logan', None, 2017, None, 137, 8.1, 578747, 13315342, 'drama'),
#  (13315342, 'Logan', None, 2017, None, 137, 8.1, 578747, 13315342, 'sci-fi'),
#  (13322420, 'Queen', None, 2013, None, 146, 8.2, 56135, 13322420, 'comedy'),
#  (13322420, 'Queen', None, 2013, None, 146, 8.2, 56135, 13322420, 'drama'),
#  (13390572, 'Haider', None, 2014, None, 160, 8.1, 46692, 13390572, 'crime'),
#  (13390572, 'Haider', None, 2014, None, 160, 8.1, 46692, 13390572, 'drama'),
#  (13417422, 'Drishyam', None, 2013, None, 160, 8.7, 25759, 13417422, 'drama'),
#  (13455224, 'Virunga', None, 2014, None, 100, 8.3, 9167, 13455224, 'documentary'),
#  (13521134, 'The Look of Silence', None, 2014, None, 103, 8.3, 10420, 13521134, 'documentary'),
#  (13612616, 'Mommy', None, 2014, None, 139, 8.1, 44114, 13612616, 'drama'),
#  (13674140, 'The Salt of the Earth', None, 2014, None, 110, 8.5, 17604, 13674140, 'documentary'),
#  (13674140, 'The Salt of the Earth', None, 2014, None, 110, 8.5, 17604, 13674140, 'history'),
#  (13686998, 'The Red Pill', None, 2016, None, 108, 8.3, 9062, 13686998, 'documentary'),
#  (13784160, 'Valley Uprising', None, 2014, None, 103, 8.2, 4423, 13784160, 'documentary'),
#  (14016934, 'The Handmaiden', 'Ah-ga-ssi', 2016, None, 145, 8.1, 84126, 14016934, 'drama'),
#  (14016934, 'The Handmaiden', 'Ah-ga-ssi', 2016, None, 145, 8.1, 84126, 14016934, 'romance'),
# ...
#  (10107290, 'Jurassic Park', None, 1993, None, 127, 8.1, 796973, 10107290, 'action'),
#  (10107290, 'Jurassic Park', None, 1993, None, 127, 8.1, 796973, 10107290, 'adventure'),
#  (10107290, 'Jurassic Park', None, 1993, None, 127, 8.1, 796973, 10107290, 'sci-fi'),
#  (10110357, 'The Lion King', None, 1994, None, 88, 8.5, 863052, 10110357, 'adventure'),
#  (10110357, 'The Lion King', None, 1994, None, 88, 8.5, 863052, 10110357, 'animation'),
#  (10110357, 'The Lion King', None, 1994, None, 88, 8.5, 863052, 10110357, 'drama'),
#  (10110413, 'Léon: The Professional', 'Léon', 1994, None, 110, 8.5, 946439, 10110413, 'action'),
#  (10110413, 'Léon: The Professional', 'Léon', 1994, None, 110, 8.5, 946439, 10110413, 'crime'),
#  (10110413, 'Léon: The Professional', 'Léon', 1994, None, 110, 8.5, 946439, 10110413, 'drama'),
#  (10111495, 'Three Colors: Red', 'Trois couleurs: Rouge', 1994, None, 99, 8.1, 81732, 10111495, 'drama'),
#  (10111495, 'Three Colors: Red', 'Trois couleurs: Rouge', 1994, None, 99, 8.1, 81732, 10111495, 'mystery'),
#  (10111495, 'Three Colors: Red', 'Trois couleurs: Rouge', 1994, None, 99, 8.1, 81732, 10111495, 'romance'),
#  (10111161, 'The Shawshank Redemption', None, 1994, None, 142, 9.3, 2140249, 10111161, 'drama'),
#  (10112870, 'Dilwale Dulhania Le Jayenge', None, 1995, None, 189, 8.1, 58821, 10112870, 'drama'),
#  (10112870, 'Dilwale Dulhania Le Jayenge', None, 1995, None, 189, 8.1, 58821, 10112870, 'romance'),
#  (10113247, 'La Haine', 'La haine', 1995, None, 98, 8.1, 134219, 10113247, 'crime'),
#  (10113247, 'La Haine', 'La haine', 1995, None, 98, 8.1, 134219, 10113247, 'drama'),
#  (10114369, 'Se7en', None, 1995, None, 127, 8.6, 1315259, 10114369, 'crime'),
#  (10114369, 'Se7en', None, 1995, None, 127, 8.6, 1315259, 10114369, 'drama'),
#  (10114369, 'Se7en', None, 1995, None, 127, 8.6, 1315259, 10114369, 'mystery'),
#  (10119488, 'L.A. Confidential', None, 1997, None, 138, 8.2, 500362, 10119488, 'crime'),
#  (10119488, 'L.A. Confidential', None, 1997, None, 138, 8.2, 500362, 10119488, 'drama'),
#  (10119488, 'L.A. Confidential', None, 1997, None, 138, 8.2, 500362, 10119488, 'mystery'),
#  (10118799, 'Life Is Beautiful', 'La vita è bella', 1997, None, 116, 8.6, 565262, 10118799, 'comedy'),
#  (10119698, 'Princess Mononoke', 'Mononoke-hime', 1997, None, 134, 8.4, 301369, 10119698, 'adventure'),
#  (10119698, 'Princess Mononoke', 'Mononoke-hime', 1997, None, 134, 8.4, 301369, 10119698, 'animation'),
#  (10119698, 'Princess Mononoke', 'Mononoke-hime', 1997, None, 134, 8.4, 301369, 10119698, 'fantasy'),
#  (10118799, 'Life Is Beautiful', 'La vita è bella', 1997, None, 116, 8.6, 565262, 10118799, 'drama'),
#  (10118799, 'Life Is Beautiful', 'La vita è bella', 1997, None, 116, 8.6, 565262, 10118799, 'romance'),
#  (10120735, 'Lock, Stock and Two Smoking Barrels', None, 1998, None, 107, 8.2, 499852, 10120735, 'comedy'),
#  (10120382, 'The Truman Show', None, 1998, None, 103, 8.1, 854541, 10120382, 'comedy'),
#  (10120382, 'The Truman Show', None, 1998, None, 103, 8.1, 854541, 10120382, 'drama'),
#  (10120382, 'The Truman Show', None, 1998, None, 103, 8.1, 854541, 10120382, 'sci-fi'),
#  (10120735, 'Lock, Stock and Two Smoking Barrels', None, 1998, None, 107, 8.2, 499852, 10120735, 'crime'),
#  (10167260, 'The Lord of the Rings: The Return of the King', None, 2003, None, 201, 8.9, 1521525, 10167260, 'adventure'),
#  (10167260, 'The Lord of the Rings: The Return of the King', None, 2003, None, 201, 8.9, 1521525, 10167260, 'drama'),
#  (10167260, 'The Lord of the Rings: The Return of the King', None, 2003, None, 201, 8.9, 1521525, 10167260, 'fantasy'),
#  (10169102, 'Lagaan: Once Upon a Time in India', None, 2001, None, 224, 8.1, 94810, 10169102, 'adventure'),
#  (10169102, 'Lagaan: Once Upon a Time in India', None, 2001, None, 224, 8.1, 94810, 10169102, 'drama'),
#  (10169102, 'Lagaan: Once Upon a Time in India', None, 2001, None, 224, 8.1, 94810, 10169102, 'musical'),
#  (10169858, 'Neon Genesis Evangelion: The End of Evangelion', 'Shin seiki Evangelion Gekijô-ban: Air/Magokoro wo, kimi ni', 1997, None, 87, 8.2, 30842, 10169858, 'drama'),
#  (10208092, 'Snatch', None, 2000, None, 104, 8.3, 729929, 10208092, 'comedy'),
#  (10208092, 'Snatch', None, 2000, None, 104, 8.3, 729929, 10208092, 'crime'),
#  (10211915, 'Amélie', "Le fabuleux destin d'Amélie Poulain", 2001, None, 122, 8.3, 661634, 10211915, 'comedy'),
#  (10211915, 'Amélie', "Le fabuleux destin d'Amélie Poulain", 2001, None, 122, 8.3, 661634, 10211915, 'romance'),
#  (10268978, 'A Beautiful Mind', None, 2001, None, 135, 8.2, 784095, 10268978, 'biography'),
#  (10268978, 'A Beautiful Mind', None, 2001, None, 135, 8.2, 784095, 10268978, 'drama'),
#  (10351817, 'The Twilight Samurai', 'Tasogare Seibei', 2002, None, 129, 8.1, 20789, 10351817, 'history'),
#  (10351817, 'The Twilight Samurai', 'Tasogare Seibei', 2002, None, 129, 8.1, 20789, 10351817, 'romance'),
#  (10358456, 'Earthlings', None, 2005, None, 95, 8.7, 16350, 10358456, 'documentary'),
#  (10367110, 'Swades', 'Swades: We, the People', 2004, None, 210, 8.2, 76029, 10367110, 'drama'),
#  (10405159, 'Million Dollar Baby', None, 2004, None, 132, 8.1, 594368, 10405159, 'drama'),
#  (10405159, 'Million Dollar Baby', None, 2004, None, 132, 8.1, 594368, 10405159, 'sport'),
#  (10408664, 'Nobody Knows', 'Dare mo shiranai', 2004, None, 141, 8.1, 22069, 10408664, 'drama'),
#  (10428870, 'A Moment to Remember', 'Nae meorisokui jiwoogae', 2004, None, 117, 8.2, 19883, 10428870, 'romance'),
#  (10469494, 'There Will Be Blood', None, 2007, None, 158, 8.1, 471725, 10469494, 'drama'),
#  (10476735, 'My Father and My Son', 'Babam ve Oglum', 2005, None, 108, 8.3, 69729, 10476735, 'drama'),
#  (10476735, 'My Father and My Son', 'Babam ve Oglum', 2005, None, 108, 8.3, 69729, 10476735, 'family'),
#  (10912593, 'No End in Sight', None, 2007, None, 102, 8.2, 7928, 10912593, 'documentary'),
#  (10910970, 'WALL·E', None, 2008, None, 98, 8.4, 924055, 10910970, 'adventure'),
#  (10910970, 'WALL·E', None, 2008, None, 98, 8.4, 924055, 10910970, 'animation'),
#  (10910970, 'WALL·E', None, 2008, None, 98, 8.4, 924055, 10910970, 'family'),
#  (10923752, 'The King of Kong: A Fistful of Quarters', 'The King of Kong', 2007, None, 79, 8.1, 33490, 10923752, 'biography'),
#  (10923752, 'The King of Kong: A Fistful of Quarters', 'The King of Kong', 2007, None, 79, 8.1, 33490, 10923752, 'documentary'),
#  (10978762, 'Mary and Max', None, 2009, None, 92, 8.1, 153293, 10978762, 'animation'),
#  (10978762, 'Mary and Max', None, 2009, None, 92, 8.1, 153293, 10978762, 'comedy'),
#  (10978762, 'Mary and Max', None, 2009, None, 92, 8.1, 153293, 10978762, 'drama'),
#  (10986264, 'Like Stars on Earth', 'Taare Zameen Par', 2007, None, 165, 8.4, 146878, 10986264, 'drama'),
#  (10986264, 'Like Stars on Earth', 'Taare Zameen Par', 2007, None, 165, 8.4, 146878, 10986264, 'family'),
#  (10993846, 'The Wolf of Wall Street', None, 2013, None, 180, 8.2, 1059789, 10993846, 'biography'),
#  (10993846, 'The Wolf of Wall Street', None, 2013, None, 180, 8.2, 1059789, 10993846, 'crime'),
#  (10993846, 'The Wolf of Wall Street', None, 2013, None, 180, 8.2, 1059789, 10993846, 'drama'),
#  (11014762, 'Home', None, 2009, None, 120, 8.6, 20678, 11014762, 'documentary'),
#  (11028532, "Hachi: A Dog's Tale", None, 2009, None, 93, 8.1, 228495, 11028532, 'drama'),
#  (11028532, "Hachi: A Dog's Tale", None, 2009, None, 93, 8.1, 228495, 11028532, 'family'),
#  (11039647, 'The Union: The Business Behind Getting High', None, 2007, None, 104, 8.2, 7495, 11039647, 'documentary'),
#  (11049413, 'Up', None, 2009, None, 96, 8.2, 862862, 11049413, 'adventure'),
#  (11049413, 'Up', None, 2009, None, 96, 8.2, 862862, 11049413, 'animation'),
#  (11049413, 'Up', None, 2009, None, 96, 8.2, 862862, 11049413, 'comedy'),
#  (11069238, 'Departures', 'Okuribito', 2008, None, 130, 8.1, 45462, 11069238, 'drama'),
#  (11069238, 'Departures', 'Okuribito', 2008, None, 130, 8.1, 45462, 11069238, 'music'),
#  (11094594, 'Sigur Rós: Heima', None, 2007, None, 97, 8.6, 7571, 11094594, 'documentary'),
#  (11113829, 'George Harrison: Living in the Material World', None, 2011, None, 208, 8.2, 9739, 11113829, 'documentary'),
#  (11130884, 'Shutter Island', None, 2010, None, 138, 8.1, 1027318, 11130884, 'mystery'),
#  (11130884, 'Shutter Island', None, 2010, None, 138, 8.1, 1027318, 11130884, 'thriller'),
#  (11152758, 'Dear Zachary: A Letter to a Son About His Father', None, 2008, None, 95, 8.6, 29974, 11152758, 'biography'),
#  (11152758, 'Dear Zachary: A Letter to a Son About His Father', None, 2008, None, 95, 8.6, 29974, 11152758, 'documentary'),
#  (11187043, '3 Idiots', None, 2009, None, 170, 8.4, 307847, 11187043, 'comedy'),
#  (11187043, '3 Idiots', None, 2009, None, 170, 8.4, 307847, 11187043, 'drama'),
#  (11201607, 'Harry Potter and the Deathly Hallows: Part 2', None, 2011, None, 130, 8.1, 703657, 11201607, 'adventure'),
#  (11201607, 'Harry Potter and the Deathly Hallows: Part 2', None, 2011, None, 130, 8.1, 703657, 11201607, 'drama'),
#  (11201607, 'Harry Potter and the Deathly Hallows: Part 2', None, 2011, None, 130, 8.1, 703657, 11201607, 'fantasy'),
#  (11205489, 'Gran Torino', None, 2008, None, 116, 8.1, 678685, 11205489, 'drama'),
#  (11255953, 'Incendies', None, 2010, None, 131, 8.3, 127873, 11255953, 'drama'),
#  (11255953, 'Incendies', None, 2010, None, 131, 8.3, 127873, 11255953, 'mystery'),
#  (11255953, 'Incendies', None, 2010, None, 131, 8.3, 127873, 11255953, 'war'),
#  (11280558, 'A Wednesday', None, 2008, None, 104, 8.1, 69167, 11280558, 'crime'),
#  (11280558, 'A Wednesday', None, 2008, None, 104, 8.1, 69167, 11280558, 'drama'),
#  (11280558, 'A Wednesday', None, 2008, None, 104, 8.1, 69167, 11280558, 'mystery'),
#  (11291584, 'Warrior', None, 2011, None, 140, 8.2, 408842, 11291584, 'drama'),
#  (11291584, 'Warrior', None, 2011, None, 140, 8.2, 408842, 11291584, 'sport'),
#  (11305806, 'The Secret in Their Eyes', 'El secreto de sus ojos', 2009, None, 129, 8.2, 176141, 11305806, 'drama'),
#  (11305806, 'The Secret in Their Eyes', 'El secreto de sus ojos', 2009, None, 129, 8.2, 176141, 11305806, 'mystery'),
#  (11305806, 'The Secret in Their Eyes', 'El secreto de sus ojos', 2009, None, 129, 8.2, 176141, 11305806, 'romance'),
#  (11313104, 'The Cove', None, 2009, None, 92, 8.4, 45609, 11313104, 'crime'),
#  (11313104, 'The Cove', None, 2009, None, 92, 8.4, 45609, 11313104, 'documentary'),
#  (11345836, 'The Dark Knight Rises', None, 2012, None, 164, 8.4, 1409574, 11345836, 'action'),
#  (11345836, 'The Dark Knight Rises', None, 2012, None, 164, 8.4, 1409574, 11345836, 'thriller'),
#  (11361558, 'Iron Maiden: Flight 666', None, 2009, None, 112, 8.3, 5001, 11361558, 'documentary'),
#  (11375666, 'Inception', None, 2010, None, 148, 8.8, 1876770, 11375666, 'action'),
#  (11375666, 'Inception', None, 2010, None, 148, 8.8, 1876770, 11375666, 'adventure'),
#  (11375666, 'Inception', None, 2010, None, 148, 8.8, 1876770, 11375666, 'sci-fi'),
#  (11392190, 'Mad Max: Fury Road', None, 2015, None, 120, 8.1, 797452, 11392190, 'action'),
#  (11392190, 'Mad Max: Fury Road', None, 2015, None, 120, 8.1, 797452, 11392190, 'adventure'),
#  (11392190, 'Mad Max: Fury Road', None, 2015, None, 120, 8.1, 797452, 11392190, 'sci-fi'),
#  (11392214, 'Prisoners', None, 2013, None, 153, 8.1, 538469, 11392214, 'crime'),
#  (11392214, 'Prisoners', None, 2013, None, 153, 8.1, 538469, 11392214, 'drama'),
#  (11392214, 'Prisoners', None, 2013, None, 153, 8.1, 538469, 11392214, 'mystery'),
#  (11417592, 'Pearl Jam Twenty', None, 2011, None, 109, 8.3, 7352, 11417592, 'documentary'),
#  (11424432, 'Senna', None, 2010, None, 106, 8.6, 56396, 11424432, 'biography'),
#  (11424432, 'Senna', None, 2010, None, 106, 8.6, 56396, 11424432, 'documentary'),
#  (11424432, 'Senna', None, 2010, None, 106, 8.6, 56396, 11424432, 'sport'),
#  (11454029, 'The Help', None, 2011, None, 146, 8.1, 398389, 11454029, 'drama'),
#  (11832382, 'A Separation', 'Jodaeiye Nader az Simin', 2011, None, 123, 8.3, 201443, 11832382, 'drama'),
#  (11832382, 'A Separation', 'Jodaeiye Nader az Simin', 2011, None, 123, 8.3, 201443, 11832382, 'thriller'),
#  (11895587, 'Spotlight', None, 2015, None, 129, 8.1, 374689, 11895587, 'biography'),
#  (11895587, 'Spotlight', None, 2015, None, 129, 8.1, 374689, 11895587, 'crime'),
#  (11895587, 'Spotlight', None, 2015, None, 129, 8.1, 374689, 11895587, 'drama'),
#  (12024544, '12 Years a Slave', None, 2013, None, 134, 8.1, 587383, 12024544, 'biography'),
#  (12024544, '12 Years a Slave', None, 2013, None, 134, 8.1, 587383, 12024544, 'drama'),
#  (12024544, '12 Years a Slave', None, 2013, None, 134, 8.1, 587383, 12024544, 'history'),
#  (12119532, 'Hacksaw Ridge', None, 2016, None, 139, 8.1, 378757, 12119532, 'biography'),
#  (12119532, 'Hacksaw Ridge', None, 2016, None, 139, 8.1, 378757, 12119532, 'drama'),
#  (12119532, 'Hacksaw Ridge', None, 2016, None, 139, 8.1, 378757, 12119532, 'history'),
#  (12140203, 'Wolf Children', 'Ookami kodomo no Ame to Yuki', 2012, None, 117, 8.1, 32880, 12140203, 'drama'),
#  (12140203, 'Wolf Children', 'Ookami kodomo no Ame to Yuki', 2012, None, 117, 8.1, 32880, 12140203, 'family'),
#  (12267998, 'Gone Girl', None, 2014, None, 149, 8.1, 777852, 12267998, 'drama'),
#  (12267998, 'Gone Girl', None, 2014, None, 149, 8.1, 777852, 12267998, 'mystery'),
#  (12267998, 'Gone Girl', None, 2014, None, 149, 8.1, 777852, 12267998, 'thriller'),
#  (12283748, 'OMG: Oh My God!', None, 2012, None, 125, 8.2, 45664, 12283748, 'comedy'),
#  (12283748, 'OMG: Oh My God!', None, 2012, None, 125, 8.2, 45664, 12283748, 'drama'),
#  (12356180, 'Bhaag Milkha Bhaag', None, 2013, None, 186, 8.2, 55859, 12356180, 'biography'),
#  (12356180, 'Bhaag Milkha Bhaag', None, 2013, None, 186, 8.2, 55859, 12356180, 'drama'),
#  (12356180, 'Bhaag Milkha Bhaag', None, 2013, None, 186, 8.2, 55859, 12356180, 'sport'),
#  (12991224, 'Tangerines', 'Mandariinid', 2013, None, 87, 8.2, 34171, 12991224, 'drama'),
#  (12991224, 'Tangerines', 'Mandariinid', 2013, None, 87, 8.2, 34171, 12991224, 'war'),
#  (13268458, "The Internet's Own Boy: The Story of Aaron Swartz", None, 2014, None, 105, 8.1, 14608, 13268458, 'documentary'),
#  (13327994, 'Human', None, 2015, None, 190, 8.7, 6478, 13327994, 'documentary'),
#  (13461252, 'The Blue Elephant', None, 2014, None, 170, 8.1, 23363, 13461252, 'drama'),
#  (13970482, 'Roger Waters: The Wall', None, 2014, None, 132, 8.6, 4193, 13970482, 'documentary'),
#  (14857264, 'The Invisible Guest', 'Contratiempo', 2016, None, 106, 8.1, 91281, 14857264, 'crime'),
#  (14857264, 'The Invisible Guest', 'Contratiempo', 2016, None, 106, 8.1, 91281, 14857264, 'mystery'),
#  (14857264, 'The Invisible Guest', 'Contratiempo', 2016, None, 106, 8.1, 91281, 14857264, 'thriller'),
#  (15027774, 'Three Billboards Outside Ebbing, Missouri', None, 2017, None, 115, 8.2, 361146, 15027774, 'crime'),
#  (15027774, 'Three Billboards Outside Ebbing, Missouri', None, 2017, None, 115, 8.2, 361146, 15027774, 'drama'),
#  (15311514, 'Your Name.', 'Kimi no na wa.', 2016, None, 106, 8.4, 144361, 15311514, 'animation'),
#  (15311514, 'Your Name.', 'Kimi no na wa.', 2016, None, 106, 8.4, 144361, 15311514, 'drama'),
#  (15311514, 'Your Name.', 'Kimi no na wa.', 2016, None, 106, 8.4, 144361, 15311514, 'fantasy'),
#  (15323662, 'A Silent Voice', 'Koe no katachi', 2016, None, 130, 8.2, 29131, 15323662, 'drama'),
#  (15323662, 'A Silent Voice', 'Koe no katachi', 2016, None, 130, 8.2, 29131, 15323662, 'romance'),
#  (16156350, 'HyperNormalisation', None, 2016, None, 166, 8.3, 4178, 16156350, 'documentary'),
#  (16316138, 'Ayla: The Daughter of War', None, 2017, None, 125, 8.6, 27889, 16316138, 'biography'),
#  (16316138, 'Ayla: The Daughter of War', None, 2017, None, 125, 8.6, 27889, 16316138, 'drama'),
#  (16316138, 'Ayla: The Daughter of War', None, 2017, None, 125, 8.6, 27889, 16316138, 'history'),
#  (16751668, 'Parasite', 'Gisaengchung', 2019, None, 132, 8.5, 35616, 16751668, 'comedy'),
#  (16751668, 'Parasite', 'Gisaengchung', 2019, None, 132, 8.5, 35616, 16751668, 'drama'),
#  (17775622, 'Free Solo', None, 2018, None, 100, 8.2, 38773, 17775622, 'documentary'),
#  (17775622, 'Free Solo', None, 2018, None, 100, 8.2, 38773, 17775622, 'sport')]

# %% [markdown]
# Let's create a simple view for this query:

# %%
# %%sql
#
# CREATE VIEW
#     simple_view
# AS
#     SELECT
#         *
#     FROM
#         movies m
#     JOIN
#         movie_genres mg
#     ON
#         m.id = mg.movie_id
#     WHERE
#         rating > 8
#         AND
#         nvotes > (
#             SELECT
#                 AVG(m2.nvotes)
#             FROM
#                 movies m2
#             JOIN
#                 movie_genres mg2
#             ON
#                 m2.id = mg2.movie_id
#             WHERE
#                 mg.genre = mg2.genre
#                 AND
#                 m.id <> m2.id
#         )
#     ;
# Out:
#  * postgresql://postgres:***@localhost/imdb
# Done.
# []

# %% [markdown]
# Retrieving data from this view will be as slow as running the original query:

# %%
# %%timeit -r 1 -n 1
# %%sql

SELECT * FROM simple_view;
# Out:
#  * postgresql://postgres:***@localhost/imdb
# 795 rows affected.
# 13.6 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %% [markdown]
# <br><br><br>

# %% [markdown]
# The result of this query takes little space (only 795 rows), but it takes a long time to compute, which makes it a good candidate for a materialized view. Note that creating the materialized view will be slow the first time:

# %%
# %%timeit -r 1 -n 1
# %%sql

CREATE MATERIALIZED VIEW
    mat_view
AS
    SELECT
        *
    FROM
        movies m
    JOIN
        movie_genres mg
    ON
        m.id = mg.movie_id
    WHERE        
        rating > 8
        AND
        nvotes > (
            SELECT
                AVG(m2.nvotes)
            FROM
                movies m2
            JOIN
                movie_genres mg2
            ON
                m2.id = mg2.movie_id
            WHERE
                mg.genre = mg2.genre
                AND
                m.id <> m2.id
        )
;
# Out:
#  * postgresql://postgres:***@localhost/imdb
# 795 rows affected.
# 13.4 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %% [markdown]
# But retrieving data from the materialized view should be almost instantaneous:

# %%
# %%timeit -r 1 -n 1
# %%sql

SELECT * FROM mat_view;
# Out:
#  * postgresql://postgres:***@localhost/imdb
# 795 rows affected.
# 3.55 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %% [markdown]
# Let's not forget to clean up:

# %%
# %%sql
#
# DROP VIEW simple_view;
# DROP MATERIALIZED VIEW mat_view;
# Out:
#  * postgresql://postgres:***@localhost/imdb
# Done.
# Done.
# []

# %% [markdown]
# <br><br><br>

# %% [markdown]
# ## Common Table Expressions (CTEs)

# %% [markdown]
# It's not uncommon for our queries to become overly complex. For example, consider the following question:

# %% [markdown]
# ---
#
# **Example:** Which countries speak at least one language that is not spoken an any other country in their continent?
#
# ---

# %% [markdown]
# A query to answer the above question involves joining tables first to have both country and language data in the same place, and then use a subquery.
#
# To that end, we can create a temporary table first and then use the subquery on that table:

# %% [markdown]
# ```sql
# DROP TABLE IF EXISTS ccl;
#
# CREATE TEMPORARY TABLE ccl AS (
#     SELECT
#         co.name, co.continent, cl.language
#     FROM
#         country co
#     JOIN
#         countrylanguage cl
#     ON
#         co.code = cl.countrycode
# )
# ;
#
# SELECT
#     t1.*
# FROM
#     ccl t1
# WHERE
#     NOT EXISTS (
#         SELECT
#             *
#         FROM
#             ccl t2
#         WHERE
#             t1.name <> t2.name
#             AND
#             t1.continent = t2.continent
#             AND
#             t1.language = t2.language
#     )
# ;
# ```

# %% [markdown]
# <br><br><br>

# %% [markdown]
# For this situation, we may not want to create a **temporary table** because:
#
# - copying the data of two entire tables might create a disk space problem during a session
#
# - if the data is modified in anyways before another subsequent query, it won't be reflected in the temporary table
#
# - the temporary table has to be created each time a connection to the database is made

# %% [markdown]
# <br><br><br>

# %% [markdown]
# Creating a **view** looks like a nice alternative because it doesn't pose any of the above problems, but:
#
# - The purpose of a view is to provide a more or less permanent way of accessing the data or hiding details. It doesn't make sense to create a view that is intended just for a very specific query and useless otherwise. For example, do we really want a view in our database that shows countries and languages just in Asia and Europe, or is it just for the purpose of a special query?
#
# - Creating views requires special access privileges, which as a user we might not have!

# %% [markdown]
# <br><br><br>

# %% [markdown]
# Standard SQL has an elegant way of addressing this issue: **Common Table Expressions**
#
# A common table expression is a temporary intermediate result set that we can use within a `SELECT`, `INSERT`, `UPDATE`, or `DELETE` statement. The syntax for a CTE is:
#
# ```sql
# WITH
#     expression_name [(column_names, ...)]
# AS (
#     query
# )
# query
# ;
# ```

# %% [markdown]
# <br><br><br>

# %% [markdown]
# Let's take a look at a few examples:

# %%
# %sql postgresql://{username}:{password}@{host}:{port}/world
# Out:
# 'Connected: postgres@world'

# %% [markdown]
# The following CTE creates an intermediate result set from the `country` and `countrylanguage` tables:

# %%
# %%sql
#
# WITH my_cte AS (
#     SELECT
#         name, population, language
#     FROM
#         country co
#     JOIN
#         countrylanguage cl
#     ON
#         cl.countrycode = co.code
# )
# SELECT * FROM my_cte
# ;
# Out:
#    postgresql://postgres:***@localhost/imdb
#  * postgresql://postgres:***@localhost:5432/world
# 984 rows affected.
# [('Afghanistan', 22720000, 'Pashto'),
#  ('Netherlands', 15864000, 'Dutch'),
#  ('Netherlands Antilles', 217000, 'Papiamento'),
#  ('Albania', 3401200, 'Albaniana'),
#  ('Algeria', 31471000, 'Arabic'),
#  ('American Samoa', 68000, 'Samoan'),
#  ('Andorra', 78000, 'Spanish'),
#  ('Angola', 12878000, 'Ovimbundu'),
#  ('Anguilla', 8000, 'English'),
#  ('Antigua and Barbuda', 68000, 'Creole English'),
#  ('United Arab Emirates', 2441000, 'Arabic'),
#  ('Argentina', 37032000, 'Spanish'),
#  ('Armenia', 3520000, 'Armenian'),
#  ('Aruba', 103000, 'Papiamento'),
#  ('Australia', 18886000, 'English'),
#  ('Azerbaijan', 7734000, 'Azerbaijani'),
#  ('Bahamas', 307000, 'Creole English'),
#  ('Bahrain', 617000, 'Arabic'),
#  ('Bangladesh', 129155000, 'Bengali'),
#  ('Barbados', 270000, 'Bajan'),
#  ('Belgium', 10239000, 'Dutch'),
#  ('Belize', 241000, 'English'),
#  ('Benin', 6097000, 'Fon'),
#  ('Bermuda', 65000, 'English'),
#  ('Bhutan', 2124000, 'Dzongkha'),
#  ('Bolivia', 8329000, 'Spanish'),
#  ('Bosnia and Herzegovina', 3972000, 'Serbo-Croatian'),
#  ('Botswana', 1622000, 'Tswana'),
#  ('Brazil', 170115000, 'Portuguese'),
#  ('United Kingdom', 59623400, 'English'),
#  ('Virgin Islands, British', 21000, 'English'),
#  ('Brunei', 328000, 'Malay'),
#  ('Bulgaria', 8190900, 'Bulgariana'),
#  ('Burkina Faso', 11937000, 'Mossi'),
#  ('Burundi', 6695000, 'Kirundi'),
#  ('Cayman Islands', 38000, 'English'),
#  ('Chile', 15211000, 'Spanish'),
#  ('Cook Islands', 20000, 'Maori'),
#  ('Costa Rica', 4023000, 'Spanish'),
#  ('Djibouti', 638000, 'Somali'),
#  ('Dominica', 71000, 'Creole English'),
#  ('Dominican Republic', 8495000, 'Spanish'),
#  ('Ecuador', 12646000, 'Spanish'),
#  ('Egypt', 68470000, 'Arabic'),
#  ('El Salvador', 6276000, 'Spanish'),
#  ('Eritrea', 3850000, 'Tigrinja'),
#  ('Spain', 39441700, 'Spanish'),
#  ('South Africa', 40377000, 'Zulu'),
#  ('Ethiopia', 62565000, 'Oromo'),
#  ('Falkland Islands', 2000, 'English'),
#  ('Fiji Islands', 817000, 'Fijian'),
#  ('Philippines', 75967000, 'Pilipino'),
#  ('Faroe Islands', 43000, 'Faroese'),
#  ('Gabon', 1226000, 'Fang'),
#  ('Gambia', 1305000, 'Malinke'),
#  ('Georgia', 4968000, 'Georgiana'),
#  ('Ghana', 20212000, 'Akan'),
#  ('Gibraltar', 25000, 'English'),
#  ('Grenada', 94000, 'Creole English'),
#  ('Greenland', 56000, 'Greenlandic'),
#  ('Guadeloupe', 456000, 'Creole French'),
#  ('Guam', 168000, 'English'),
#  ('Guatemala', 11385000, 'Spanish'),
#  ('Guinea', 7430000, 'Ful'),
#  ('Guinea-Bissau', 1213000, 'Crioulo'),
#  ('Guyana', 861000, 'Creole English'),
#  ('Haiti', 8222000, 'Haiti Creole'),
#  ('Honduras', 6485000, 'Spanish'),
#  ('Hong Kong', 6782000, 'Canton Chinese'),
#  ('Svalbard and Jan Mayen', 3200, 'Norwegian'),
#  ('Indonesia', 212107000, 'Javanese'),
#  ('India', 1013662000, 'Hindi'),
#  ('Iraq', 23115000, 'Arabic'),
#  ('Iran', 67702000, 'Persian'),
#  ('Ireland', 3775100, 'English'),
#  ('Iceland', 279000, 'Icelandic'),
#  ('Israel', 6217000, 'Hebrew'),
#  ('Italy', 57680000, 'Italian'),
#  ('East Timor', 885000, 'Sunda'),
#  ('Austria', 8091800, 'German'),
#  ('Jamaica', 2583000, 'Creole English'),
#  ('Japan', 126714000, 'Japanese'),
#  ('Yemen', 18112000, 'Arabic'),
#  ('Jordan', 5083000, 'Arabic'),
#  ('Christmas Island', 2500, 'Chinese'),
#  ('Yugoslavia', 10640000, 'Serbo-Croatian'),
#  ('Cambodia', 11168000, 'Khmer'),
#  ('Cameroon', 15085000, 'Fang'),
#  ('Canada', 31147000, 'English'),
#  ('Cape Verde', 428000, 'Crioulo'),
#  ('Kazakstan', 16223000, 'Kazakh'),
#  ('Kenya', 30080000, 'Kikuyu'),
#  ('Central African Republic', 3615000, 'Gbaya'),
#  ('China', 1277558000, 'Chinese'),
#  ('Kyrgyzstan', 4699000, 'Kirgiz'),
#  ('Kiribati', 83000, 'Kiribati'),
#  ('Colombia', 42321000, 'Spanish'),
#  ('Comoros', 578000, 'Comorian'),
#  ('Congo', 2943000, 'Kongo'),
#  ('Congo, The Democratic Republic of the', 51654000, 'Luba'),
#  ('Cocos (Keeling) Islands', 600, 'Malay'),
#  ('North Korea', 24039000, 'Korean'),
#  ('South Korea', 46844000, 'Korean'),
#  ('Greece', 10545700, 'Greek'),
#  ('Croatia', 4473000, 'Serbo-Croatian'),
#  ('Cuba', 11201000, 'Spanish'),
#  ('Kuwait', 1972000, 'Arabic'),
#  ('Cyprus', 754700, 'Greek'),
#  ('Laos', 5433000, 'Lao'),
#  ('Latvia', 2424200, 'Latvian'),
#  ('Lesotho', 2153000, 'Sotho'),
#  ('Lebanon', 3282000, 'Arabic'),
#  ('Liberia', 3154000, 'Kpelle'),
#  ('Libyan Arab Jamahiriya', 5605000, 'Arabic'),
#  ('Liechtenstein', 32300, 'German'),
#  ('Lithuania', 3698500, 'Lithuanian'),
#  ('Luxembourg', 435700, 'Luxembourgish'),
#  ('Western Sahara', 293000, 'Arabic'),
#  ('Macao', 473000, 'Canton Chinese'),
#  ('Madagascar', 15942000, 'Malagasy'),
#  ('Macedonia', 2024000, 'Macedonian'),
#  ('Malawi', 10925000, 'Chichewa'),
#  ('Maldives', 286000, 'Dhivehi'),
#  ('Malaysia', 22244000, 'Malay'),
#  ('Mali', 11234000, 'Bambara'),
#  ('Malta', 380200, 'Maltese'),
#  ('Morocco', 28351000, 'Arabic'),
#  ('Marshall Islands', 64000, 'Marshallese'),
#  ('Martinique', 395000, 'Creole French'),
#  ('Mauritania', 2670000, 'Hassaniya'),
#  ('Mauritius', 1158000, 'Creole French'),
#  ('Mayotte', 149000, 'Mahoré'),
#  ('Mexico', 98881000, 'Spanish'),
#  ('Micronesia, Federated States of', 119000, 'Trukese'),
#  ('Moldova', 4380000, 'Romanian'),
#  ('Monaco', 34000, 'French'),
#  ('Mongolia', 2662000, 'Mongolian'),
#  ('Montserrat', 11000, 'English'),
#  ('Mozambique', 19680000, 'Makua'),
#  ('Myanmar', 45611000, 'Burmese'),
#  ('Namibia', 1726000, 'Ovambo'),
#  ('Nauru', 12000, 'Nauru'),
#  ('Nepal', 23930000, 'Nepali'),
#  ('Nicaragua', 5074000, 'Spanish'),
#  ('Niger', 10730000, 'Hausa'),
#  ('Nigeria', 111506000, 'Joruba'),
#  ('Niue', 2000, 'Niue'),
#  ('Norfolk Island', 2000, 'English'),
#  ('Norway', 4478500, 'Norwegian'),
#  ('Côte d\x92Ivoire', 14786000, 'Akan'),
#  ('Oman', 2542000, 'Arabic'),
#  ('Pakistan', 156483000, 'Punjabi'),
#  ('Palau', 19000, 'Palau'),
#  ('Panama', 2856000, 'Spanish'),
#  ('Papua New Guinea', 4807000, 'Papuan Languages'),
#  ('Paraguay', 5496000, 'Spanish'),
#  ('Peru', 25662000, 'Spanish'),
#  ('Pitcairn', 50, 'Pitcairnese'),
#  ('Northern Mariana Islands', 78000, 'Philippene Languages'),
#  ('Portugal', 9997600, 'Portuguese'),
#  ('Puerto Rico', 3869000, 'Spanish'),
#  ('Poland', 38653600, 'Polish'),
#  ('Equatorial Guinea', 453000, 'Fang'),
#  ('Qatar', 599000, 'Arabic'),
#  ('France', 59225700, 'French'),
#  ('French Guiana', 181000, 'Creole French'),
#  ('French Polynesia', 235000, 'Tahitian'),
#  ('Réunion', 699000, 'Creole French'),
#  ('Romania', 22455500, 'Romanian'),
#  ('Rwanda', 7733000, 'Rwanda'),
#  ('Sweden', 8861400, 'Swedish'),
#  ('Saint Helena', 6000, 'English'),
#  ('Saint Kitts and Nevis', 38000, 'Creole English'),
#  ('Saint Lucia', 154000, 'Creole French'),
#  ('Saint Vincent and the Grenadines', 114000, 'Creole English'),
#  ('Saint Pierre and Miquelon', 7000, 'French'),
#  ('Germany', 82164700, 'German'),
#  ('Solomon Islands', 444000, 'Malenasian Languages'),
#  ('Zambia', 9169000, 'Bemba'),
#  ('Samoa', 180000, 'Samoan-English'),
#  ('San Marino', 27000, 'Italian'),
#  ('Sao Tome and Principe', 147000, 'Crioulo'),
#  ('Saudi Arabia', 21607000, 'Arabic'),
#  ('Senegal', 9481000, 'Wolof'),
#  ('Seychelles', 77000, 'Seselwa'),
#  ('Sierra Leone', 4854000, 'Mende'),
#  ('Singapore', 3567000, 'Chinese'),
#  ('Slovakia', 5398700, 'Slovak'),
#  ('Slovenia', 1987800, 'Slovene'),
#  ('Somalia', 10097000, 'Somali'),
#  ('Sri Lanka', 18827000, 'Singali'),
#  ('Sudan', 29490000, 'Arabic'),
#  ('Finland', 5171300, 'Finnish'),
#  ('Suriname', 417000, 'Sranantonga'),
#  ('Swaziland', 1008000, 'Swazi'),
#  ('Switzerland', 7160400, 'German'),
#  ('Syria', 16125000, 'Arabic'),
#  ('Tajikistan', 6188000, 'Tadzhik'),
#  ('Taiwan', 22256000, 'Min'),
#  ('Tanzania', 33517000, 'Nyamwesi'),
#  ('Denmark', 5330000, 'Danish'),
#  ('Thailand', 61399000, 'Thai'),
#  ('Togo', 4629000, 'Ewe'),
#  ('Tokelau', 2000, 'Tokelau'),
#  ('Tonga', 99000, 'Tongan'),
#  ('Trinidad and Tobago', 1295000, 'English'),
#  ('Chad', 7651000, 'Sara'),
#  ('Czech Republic', 10278100, 'Czech'),
#  ('Tunisia', 9586000, 'Arabic'),
#  ('Turkey', 66591000, 'Turkish'),
#  ('Turkmenistan', 4459000, 'Turkmenian'),
#  ('Turks and Caicos Islands', 17000, 'English'),
#  ('Tuvalu', 12000, 'Tuvalu'),
#  ('Uganda', 21778000, 'Ganda'),
#  ('Ukraine', 50456000, 'Ukrainian'),
#  ('Hungary', 10043200, 'Hungarian'),
#  ('Uruguay', 3337000, 'Spanish'),
#  ('New Caledonia', 214000, 'Malenasian Languages'),
#  ('New Zealand', 3862000, 'English'),
#  ('Uzbekistan', 24318000, 'Uzbek'),
#  ('Belarus', 10236000, 'Belorussian'),
#  ('Wallis and Futuna', 15000, 'Wallis'),
#  ('Vanuatu', 190000, 'Bislama'),
#  ('Holy See (Vatican City State)', 1000, 'Italian'),
#  ('Venezuela', 24170000, 'Spanish'),
#  ('Russian Federation', 146934000, 'Russian'),
#  ('Vietnam', 79832000, 'Vietnamese'),
#  ('Estonia', 1439200, 'Estonian'),
#  ('United States', 278357000, 'English'),
#  ('Virgin Islands, U.S.', 93000, 'English'),
#  ('United States Minor Outlying Islands', 0, 'English'),
#  ('Zimbabwe', 11669000, 'Shona'),
#  ('Palestine', 3101000, 'Arabic'),
#  ('Afghanistan', 22720000, 'Dari'),
#  ('Netherlands', 15864000, 'Fries'),
#  ('Netherlands Antilles', 217000, 'English'),
#  ('Albania', 3401200, 'Greek'),
#  ('Algeria', 31471000, 'Berberi'),
#  ('American Samoa', 68000, 'English'),
#  ('Andorra', 78000, 'Catalan'),
#  ('Angola', 12878000, 'Mbundu'),
#  ('Antigua and Barbuda', 68000, 'English'),
#  ('United Arab Emirates', 2441000, 'Hindi'),
#  ('Argentina', 37032000, 'Italian'),
#  ('Armenia', 3520000, 'Azerbaijani'),
#  ('Aruba', 103000, 'English'),
#  ('Australia', 18886000, 'Italian'),
#  ('Azerbaijan', 7734000, 'Russian'),
#  ('Bahamas', 307000, 'Creole French'),
#  ('Bahrain', 617000, 'English'),
#  ('Bangladesh', 129155000, 'Chakma'),
#  ('Barbados', 270000, 'English'),
#  ('Belgium', 10239000, 'French'),
#  ('Belize', 241000, 'Spanish'),
#  ('Benin', 6097000, 'Joruba'),
#  ('Bhutan', 2124000, 'Nepali'),
#  ('Bolivia', 8329000, 'Ket\x9aua'),
#  ('Botswana', 1622000, 'Shona'),
#  ('Brazil', 170115000, 'German'),
#  ('United Kingdom', 59623400, 'Kymri'),
#  ('Brunei', 328000, 'Malay-English'),
#  ('Bulgaria', 8190900, 'Turkish'),
#  ('Burkina Faso', 11937000, 'Ful'),
#  ('Burundi', 6695000, 'French'),
#  ('Chile', 15211000, 'Araucan'),
#  ('Cook Islands', 20000, 'English'),
#  ('Costa Rica', 4023000, 'Creole English'),
#  ('Djibouti', 638000, 'Afar'),
#  ('Dominica', 71000, 'Creole French'),
#  ('Dominican Republic', 8495000, 'Creole French'),
#  ('Ecuador', 12646000, 'Ket\x9aua'),
#  ('Egypt', 68470000, 'Sinaberberi'),
#  ('El Salvador', 6276000, 'Nahua'),
#  ('Eritrea', 3850000, 'Tigre'),
#  ('Spain', 39441700, 'Catalan'),
#  ('South Africa', 40377000, 'Xhosa'),
#  ('Ethiopia', 62565000, 'Amhara'),
#  ('Fiji Islands', 817000, 'Hindi'),
#  ('Philippines', 75967000, 'Cebuano'),
#  ('Faroe Islands', 43000, 'Danish'),
#  ('Gabon', 1226000, 'Punu-sira-nzebi'),
#  ('Gambia', 1305000, 'Ful'),
#  ('Georgia', 4968000, 'Russian'),
#  ('Ghana', 20212000, 'Mossi'),
#  ('Gibraltar', 25000, 'Arabic'),
#  ('Greenland', 56000, 'Danish'),
#  ('Guadeloupe', 456000, 'French'),
#  ('Guam', 168000, 'Chamorro'),
#  ('Guatemala', 11385000, 'Quiché'),
#  ('Guinea', 7430000, 'Malinke'),
#  ('Guinea-Bissau', 1213000, 'Ful'),
#  ('Guyana', 861000, 'Caribbean'),
#  ('Haiti', 8222000, 'French'),
#  ('Honduras', 6485000, 'Garifuna'),
#  ('Hong Kong', 6782000, 'English'),
#  ('Svalbard and Jan Mayen', 3200, 'Russian'),
#  ('Indonesia', 212107000, 'Sunda'),
#  ('India', 1013662000, 'Bengali'),
#  ('Iraq', 23115000, 'Kurdish'),
#  ('Iran', 67702000, 'Azerbaijani'),
#  ('Ireland', 3775100, 'Irish'),
#  ('Iceland', 279000, 'English'),
#  ('Israel', 6217000, 'Arabic'),
#  ('Italy', 57680000, 'Sardinian'),
#  ('East Timor', 885000, 'Portuguese'),
#  ('Austria', 8091800, 'Serbo-Croatian'),
#  ('Jamaica', 2583000, 'Hindi'),
#  ('Japan', 126714000, 'Korean'),
#  ('Yemen', 18112000, 'Soqutri'),
#  ('Jordan', 5083000, 'Circassian'),
#  ('Christmas Island', 2500, 'English'),
#  ('Yugoslavia', 10640000, 'Albaniana'),
#  ('Cambodia', 11168000, 'Vietnamese'),
#  ('Cameroon', 15085000, 'Bamileke-bamum'),
#  ('Canada', 31147000, 'French'),
#  ('Cape Verde', 428000, 'Portuguese'),
#  ('Kazakstan', 16223000, 'Russian'),
#  ('Kenya', 30080000, 'Luhya'),
#  ('Central African Republic', 3615000, 'Banda'),
#  ('China', 1277558000, 'Zhuang'),
#  ('Kyrgyzstan', 4699000, 'Russian'),
#  ('Kiribati', 83000, 'Tuvalu'),
#  ('Colombia', 42321000, 'Chibcha'),
#  ('Comoros', 578000, 'Comorian-French'),
#  ('Congo', 2943000, 'Teke'),
#  ('Congo, The Democratic Republic of the', 51654000, 'Kongo'),
#  ('Cocos (Keeling) Islands', 600, 'English'),
#  ('North Korea', 24039000, 'Chinese'),
#  ('South Korea', 46844000, 'Chinese'),
#  ('Greece', 10545700, 'Turkish'),
#  ('Croatia', 4473000, 'Slovene'),
#  ('Kuwait', 1972000, 'English'),
#  ('Cyprus', 754700, 'Turkish'),
#  ('Laos', 5433000, 'Mon-khmer'),
#  ('Latvia', 2424200, 'Russian'),
#  ('Lesotho', 2153000, 'Zulu'),
#  ('Lebanon', 3282000, 'Armenian'),
#  ('Liberia', 3154000, 'Bassa'),
#  ('Libyan Arab Jamahiriya', 5605000, 'Berberi'),
#  ('Liechtenstein', 32300, 'Italian'),
#  ('Lithuania', 3698500, 'Russian'),
#  ('Luxembourg', 435700, 'Portuguese'),
#  ('Macao', 473000, 'Portuguese'),
#  ('Madagascar', 15942000, 'French'),
#  ('Macedonia', 2024000, 'Albaniana'),
#  ('Malawi', 10925000, 'Lomwe'),
#  ('Maldives', 286000, 'English'),
#  ('Malaysia', 22244000, 'Chinese'),
#  ('Mali', 11234000, 'Ful'),
#  ('Malta', 380200, 'English'),
#  ('Morocco', 28351000, 'Berberi'),
#  ('Marshall Islands', 64000, 'English'),
#  ('Martinique', 395000, 'French'),
#  ('Mauritania', 2670000, 'Wolof'),
#  ('Mauritius', 1158000, 'Bhojpuri'),
#  ('Mayotte', 149000, 'French'),
#  ('Mexico', 98881000, 'Náhuatl'),
#  ('Micronesia, Federated States of', 119000, 'Pohnpei'),
#  ('Moldova', 4380000, 'Russian'),
#  ('Monaco', 34000, 'Monegasque'),
#  ('Mongolia', 2662000, 'Kazakh'),
#  ('Mozambique', 19680000, 'Tsonga'),
#  ('Myanmar', 45611000, 'Shan'),
#  ('Namibia', 1726000, 'Nama'),
#  ('Nauru', 12000, 'Kiribati'),
#  ('Nepal', 23930000, 'Maithili'),
#  ('Nicaragua', 5074000, 'Miskito'),
#  ('Niger', 10730000, 'Songhai-zerma'),
#  ('Nigeria', 111506000, 'Hausa'),
#  ('Niue', 2000, 'English'),
#  ('Norway', 4478500, 'English'),
#  ('Côte d\x92Ivoire', 14786000, 'Gur'),
#  ('Oman', 2542000, 'Balochi'),
#  ('Pakistan', 156483000, 'Pashto'),
#  ('Palau', 19000, 'Philippene Languages'),
#  ('Panama', 2856000, 'Creole English'),
#  ('Papua New Guinea', 4807000, 'Malenasian Languages'),
#  ('Paraguay', 5496000, 'Guaraní'),
#  ('Peru', 25662000, 'Ket\x9aua'),
#  ('Northern Mariana Islands', 78000, 'Chamorro'),
#  ('Puerto Rico', 3869000, 'English'),
#  ('Poland', 38653600, 'German'),
#  ('Equatorial Guinea', 453000, 'Bubi'),
#  ('Qatar', 599000, 'Urdu'),
#  ('France', 59225700, 'Arabic'),
#  ('French Guiana', 181000, 'Indian Languages'),
#  ('French Polynesia', 235000, 'French'),
#  ('Réunion', 699000, 'Chinese'),
#  ('Romania', 22455500, 'Hungarian'),
#  ('Rwanda', 7733000, 'French'),
#  ('Sweden', 8861400, 'Finnish'),
#  ('Saint Kitts and Nevis', 38000, 'English'),
#  ('Saint Lucia', 154000, 'English'),
#  ('Saint Vincent and the Grenadines', 114000, 'English'),
#  ('Germany', 82164700, 'Turkish'),
#  ('Solomon Islands', 444000, 'Papuan Languages'),
#  ('Zambia', 9169000, 'Tongan'),
#  ('Samoa', 180000, 'Samoan'),
#  ('Sao Tome and Principe', 147000, 'French'),
#  ('Senegal', 9481000, 'Ful'),
#  ('Seychelles', 77000, 'English'),
#  ('Sierra Leone', 4854000, 'Temne'),
#  ('Singapore', 3567000, 'Malay'),
#  ('Slovakia', 5398700, 'Hungarian'),
#  ('Slovenia', 1987800, 'Serbo-Croatian'),
#  ('Somalia', 10097000, 'Arabic'),
#  ('Sri Lanka', 18827000, 'Tamil'),
#  ('Sudan', 29490000, 'Dinka'),
#  ('Finland', 5171300, 'Swedish'),
#  ('Suriname', 417000, 'Hindi'),
#  ('Swaziland', 1008000, 'Zulu'),
#  ('Switzerland', 7160400, 'French'),
#  ('Syria', 16125000, 'Kurdish'),
#  ('Tajikistan', 6188000, 'Uzbek'),
#  ('Taiwan', 22256000, 'Mandarin Chinese'),
#  ('Tanzania', 33517000, 'Swahili'),
#  ('Denmark', 5330000, 'Turkish'),
#  ('Thailand', 61399000, 'Lao'),
#  ('Togo', 4629000, 'Kabyé'),
#  ('Tokelau', 2000, 'English'),
#  ('Tonga', 99000, 'English'),
#  ('Trinidad and Tobago', 1295000, 'Hindi'),
#  ('Chad', 7651000, 'Arabic'),
#  ('Czech Republic', 10278100, 'Moravian'),
#  ('Tunisia', 9586000, 'Arabic-French'),
#  ('Turkey', 66591000, 'Kurdish'),
#  ('Turkmenistan', 4459000, 'Uzbek'),
#  ('Tuvalu', 12000, 'Kiribati'),
#  ('Uganda', 21778000, 'Nkole'),
#  ('Ukraine', 50456000, 'Russian'),
#  ('Hungary', 10043200, 'Romani'),
#  ('New Caledonia', 214000, 'French'),
#  ('New Zealand', 3862000, 'Maori'),
#  ('Uzbekistan', 24318000, 'Russian'),
#  ('Belarus', 10236000, 'Russian'),
#  ('Wallis and Futuna', 15000, 'Futuna'),
#  ('Vanuatu', 190000, 'English'),
#  ('Venezuela', 24170000, 'Goajiro'),
#  ('Russian Federation', 146934000, 'Tatar'),
#  ('Vietnam', 79832000, 'Tho'),
#  ('Estonia', 1439200, 'Russian'),
#  ('United States', 278357000, 'Spanish'),
#  ('Virgin Islands, U.S.', 93000, 'Spanish'),
#  ('Zimbabwe', 11669000, 'Ndebele'),
#  ('Palestine', 3101000, 'Hebrew'),
#  ('Afghanistan', 22720000, 'Uzbek'),
#  ('Netherlands', 15864000, 'Arabic'),
#  ('Netherlands Antilles', 217000, 'Dutch'),
#  ('Albania', 3401200, 'Macedonian'),
#  ('American Samoa', 68000, 'Tongan'),
#  ('Andorra', 78000, 'Portuguese'),
#  ('Angola', 12878000, 'Kongo'),
#  ('Argentina', 37032000, 'Indian Languages'),
#  ('Aruba', 103000, 'Spanish'),
#  ('Australia', 18886000, 'Greek'),
#  ('Azerbaijan', 7734000, 'Lezgian'),
#  ('Bangladesh', 129155000, 'Marma'),
#  ('Belgium', 10239000, 'Italian'),
#  ('Belize', 241000, 'Maya Languages'),
#  ('Benin', 6097000, 'Adja'),
#  ('Bhutan', 2124000, 'Asami'),
#  ('Bolivia', 8329000, 'Aimará'),
#  ('Botswana', 1622000, 'San'),
#  ('Brazil', 170115000, 'Italian'),
#  ('United Kingdom', 59623400, 'Gaeli'),
#  ('Brunei', 328000, 'Chinese'),
#  ('Bulgaria', 8190900, 'Romani'),
#  ('Burkina Faso', 11937000, 'Gurma'),
#  ('Burundi', 6695000, 'Swahili'),
#  ('Chile', 15211000, 'Aimará'),
#  ('Costa Rica', 4023000, 'Chibcha'),
#  ('Djibouti', 638000, 'Arabic'),
#  ('Eritrea', 3850000, 'Afar'),
#  ('Spain', 39441700, 'Galecian'),
#  ('South Africa', 40377000, 'Afrikaans'),
#  ('Ethiopia', 62565000, 'Tigrinja'),
#  ('Philippines', 75967000, 'Ilocano'),
#  ('Gabon', 1226000, 'Mpongwe'),
#  ('Gambia', 1305000, 'Wolof'),
#  ('Georgia', 4968000, 'Armenian'),
#  ('Ghana', 20212000, 'Ewe'),
#  ('Guam', 168000, 'Philippene Languages'),
#  ('Guatemala', 11385000, 'Cakchiquel'),
#  ('Guinea', 7430000, 'Susu'),
#  ('Guinea-Bissau', 1213000, 'Balante'),
#  ('Guyana', 861000, 'Arawakan'),
#  ('Honduras', 6485000, 'Creole English'),
#  ('Hong Kong', 6782000, 'Fukien'),
#  ('Indonesia', 212107000, 'Malay'),
#  ('India', 1013662000, 'Telugu'),
#  ('Iraq', 23115000, 'Azerbaijani'),
#  ('Iran', 67702000, 'Kurdish'),
#  ('Israel', 6217000, 'Russian'),
#  ('Italy', 57680000, 'Friuli'),
#  ('Austria', 8091800, 'Turkish'),
#  ('Japan', 126714000, 'Chinese'),
#  ('Jordan', 5083000, 'Armenian'),
#  ('Yugoslavia', 10640000, 'Hungarian'),
#  ('Cambodia', 11168000, 'Chinese'),
#  ('Cameroon', 15085000, 'Duala'),
#  ('Canada', 31147000, 'Chinese'),
#  ('Kazakstan', 16223000, 'Ukrainian'),
#  ('Kenya', 30080000, 'Luo'),
#  ('Central African Republic', 3615000, 'Mandjia'),
#  ('China', 1277558000, 'Mant\x9au'),
#  ('Kyrgyzstan', 4699000, 'Uzbek'),
#  ('Colombia', 42321000, 'Creole English'),
#  ('Comoros', 578000, 'Comorian-madagassi'),
#  ('Congo', 2943000, 'Mboshi'),
#  ('Congo, The Democratic Republic of the', 51654000, 'Mongo'),
#  ('Laos', 5433000, 'Thai'),
#  ('Latvia', 2424200, 'Belorussian'),
#  ('Lesotho', 2153000, 'English'),
#  ('Lebanon', 3282000, 'French'),
#  ('Liberia', 3154000, 'Grebo'),
#  ('Liechtenstein', 32300, 'Turkish'),
#  ('Lithuania', 3698500, 'Polish'),
#  ('Luxembourg', 435700, 'Italian'),
#  ('Macao', 473000, 'Mandarin Chinese'),
#  ('Macedonia', 2024000, 'Turkish'),
#  ('Malawi', 10925000, 'Yao'),
#  ('Malaysia', 22244000, 'Tamil'),
#  ('Mali', 11234000, 'Senufo and Minianka'),
#  ('Mauritania', 2670000, 'Tukulor'),
#  ('Mauritius', 1158000, 'French'),
#  ('Mayotte', 149000, 'Malagasy'),
#  ('Mexico', 98881000, 'Yucatec'),
#  ('Micronesia, Federated States of', 119000, 'Mortlock'),
#  ('Moldova', 4380000, 'Ukrainian'),
#  ('Monaco', 34000, 'Italian'),
#  ('Mongolia', 2662000, 'Dorbet'),
#  ('Mozambique', 19680000, 'Sena'),
#  ('Myanmar', 45611000, 'Karen'),
#  ('Namibia', 1726000, 'Kavango'),
#  ('Nauru', 12000, 'Chinese'),
#  ('Nepal', 23930000, 'Bhojpuri'),
#  ('Nicaragua', 5074000, 'Creole English'),
#  ('Niger', 10730000, 'Tamashek'),
#  ('Nigeria', 111506000, 'Ibo'),
#  ('Norway', 4478500, 'Danish'),
#  ('Côte d\x92Ivoire', 14786000, 'Malinke'),
#  ('Pakistan', 156483000, 'Sindhi'),
#  ('Palau', 19000, 'English'),
#  ('Panama', 2856000, 'Guaymí'),
#  ('Paraguay', 5496000, 'Portuguese'),
#  ('Peru', 25662000, 'Aimará'),
#  ('Northern Mariana Islands', 78000, 'Chinese'),
#  ('Poland', 38653600, 'Ukrainian'),
#  ('France', 59225700, 'Portuguese'),
#  ('French Polynesia', 235000, 'Chinese'),
#  ('Réunion', 699000, 'Comorian'),
#  ('Romania', 22455500, 'Romani'),
#  ('Sweden', 8861400, 'Southern Slavic Languages'),
#  ('Germany', 82164700, 'Southern Slavic Languages'),
#  ('Solomon Islands', 444000, 'Polynesian Languages'),
#  ('Zambia', 9169000, 'Nyanja'),
#  ('Samoa', 180000, 'English'),
#  ('Senegal', 9481000, 'Serer'),
#  ('Seychelles', 77000, 'French'),
#  ('Sierra Leone', 4854000, 'Limba'),
#  ('Singapore', 3567000, 'Tamil'),
#  ('Slovakia', 5398700, 'Romani'),
#  ('Slovenia', 1987800, 'Hungarian'),
#  ('Sri Lanka', 18827000, 'Mixed Languages'),
#  ('Sudan', 29490000, 'Nubian Languages'),
#  ('Finland', 5171300, 'Russian'),
#  ('Switzerland', 7160400, 'Italian'),
#  ('Tajikistan', 6188000, 'Russian'),
#  ('Taiwan', 22256000, 'Hakka'),
#  ('Tanzania', 33517000, 'Hehet'),
#  ('Denmark', 5330000, 'Arabic'),
#  ('Thailand', 61399000, 'Chinese'),
#  ('Togo', 4629000, 'Watyi'),
#  ('Trinidad and Tobago', 1295000, 'Creole English'),
#  ('Chad', 7651000, 'Mayo-kebbi'),
#  ('Czech Republic', 10278100, 'Slovak'),
#  ('Tunisia', 9586000, 'Arabic-French-English'),
#  ('Turkey', 66591000, 'Arabic'),
#  ('Turkmenistan', 4459000, 'Russian'),
#  ('Tuvalu', 12000, 'English'),
#  ('Uganda', 21778000, 'Kiga'),
#  ('Ukraine', 50456000, 'Romanian'),
#  ('Hungary', 10043200, 'German'),
#  ('New Caledonia', 214000, 'Polynesian Languages'),
#  ('Uzbekistan', 24318000, 'Tadzhik'),
#  ('Belarus', 10236000, 'Ukrainian'),
#  ('Vanuatu', 190000, 'French'),
#  ('Venezuela', 24170000, 'Warrau'),
#  ('Russian Federation', 146934000, 'Ukrainian'),
#  ('Vietnam', 79832000, 'Thai'),
#  ('Estonia', 1439200, 'Ukrainian'),
#  ('United States', 278357000, 'French'),
#  ('Virgin Islands, U.S.', 93000, 'French'),
#  ('Zimbabwe', 11669000, 'English'),
#  ('Afghanistan', 22720000, 'Turkmenian'),
#  ('Netherlands', 15864000, 'Turkish'),
#  ('Andorra', 78000, 'French'),
#  ('Angola', 12878000, 'Luimbe-nganguela'),
#  ('Aruba', 103000, 'Dutch'),
#  ('Australia', 18886000, 'Canton Chinese'),
#  ('Azerbaijan', 7734000, 'Armenian'),
#  ('Bangladesh', 129155000, 'Garo'),
#  ('Belgium', 10239000, 'Arabic'),
#  ('Belize', 241000, 'Garifuna'),
#  ('Benin', 6097000, 'Aizo'),
#  ('Bolivia', 8329000, 'Guaraní'),
#  ('Botswana', 1622000, 'Khoekhoe'),
#  ('Brazil', 170115000, 'Japanese'),
#  ('Brunei', 328000, 'English'),
#  ('Bulgaria', 8190900, 'Macedonian'),
#  ('Burkina Faso', 11937000, 'Busansi'),
#  ('Chile', 15211000, 'Rapa nui'),
#  ('Costa Rica', 4023000, 'Chinese'),
#  ('Eritrea', 3850000, 'Hadareb'),
#  ('Spain', 39441700, 'Basque'),
#  ('South Africa', 40377000, 'Northsotho'),
#  ('Ethiopia', 62565000, 'Gurage'),
#  ('Philippines', 75967000, 'Hiligaynon'),
#  ('Gabon', 1226000, 'Mbete'),
#  ('Gambia', 1305000, 'Diola'),
#  ('Georgia', 4968000, 'Azerbaijani'),
#  ('Ghana', 20212000, 'Ga-adangme'),
#  ('Guam', 168000, 'Korean'),
#  ('Guatemala', 11385000, 'Kekchí'),
#  ('Guinea', 7430000, 'Kissi'),
#  ('Guinea-Bissau', 1213000, 'Portuguese'),
#  ('Honduras', 6485000, 'Miskito'),
#  ('Hong Kong', 6782000, 'Hakka'),
#  ('Indonesia', 212107000, 'Madura'),
#  ('India', 1013662000, 'Marathi'),
#  ('Iraq', 23115000, 'Assyrian'),
#  ('Iran', 67702000, 'Gilaki'),
#  ('Italy', 57680000, 'French'),
#  ('Austria', 8091800, 'Hungarian'),
#  ('Japan', 126714000, 'English'),
#  ('Yugoslavia', 10640000, 'Romani'),
#  ('Cambodia', 11168000, 'T\x9aam'),
#  ('Cameroon', 15085000, 'Ful'),
#  ('Canada', 31147000, 'Italian'),
#  ('Kazakstan', 16223000, 'German'),
#  ('Kenya', 30080000, 'Kamba'),
#  ('Central African Republic', 3615000, 'Ngbaka'),
#  ('China', 1277558000, 'Hui'),
#  ('Kyrgyzstan', 4699000, 'Ukrainian'),
#  ('Colombia', 42321000, 'Arawakan'),
#  ('Comoros', 578000, 'Comorian-Arabic'),
#  ('Congo', 2943000, 'Mbete'),
#  ('Congo, The Democratic Republic of the', 51654000, 'Rwanda'),
#  ('Laos', 5433000, 'Lao-Soung'),
#  ('Latvia', 2424200, 'Ukrainian'),
#  ('Liberia', 3154000, 'Gio'),
#  ('Lithuania', 3698500, 'Belorussian'),
#  ('Luxembourg', 435700, 'French'),
#  ('Macao', 473000, 'English'),
#  ('Macedonia', 2024000, 'Romani'),
#  ('Malawi', 10925000, 'Ngoni'),
#  ('Malaysia', 22244000, 'Iban'),
#  ('Mali', 11234000, 'Soninke'),
#  ('Mauritania', 2670000, 'Soninke'),
#  ('Mauritius', 1158000, 'Hindi'),
#  ('Mexico', 98881000, 'Zapotec'),
#  ('Micronesia, Federated States of', 119000, 'Kosrean'),
#  ('Moldova', 4380000, 'Gagauzi'),
#  ('Monaco', 34000, 'English'),
#  ('Mongolia', 2662000, 'Bajad'),
#  ('Mozambique', 19680000, 'Lomwe'),
#  ('Myanmar', 45611000, 'Rakhine'),
#  ('Namibia', 1726000, 'Afrikaans'),
#  ('Nauru', 12000, 'Tuvalu'),
#  ('Nepal', 23930000, 'Tharu'),
#  ('Nicaragua', 5074000, 'Sumo'),
#  ('Niger', 10730000, 'Ful'),
#  ('Nigeria', 111506000, 'Ful'),
#  ('Norway', 4478500, 'Swedish'),
#  ('Côte d\x92Ivoire', 14786000, 'Kru'),
#  ('Pakistan', 156483000, 'Saraiki'),
#  ('Palau', 19000, 'Chinese'),
#  ('Panama', 2856000, 'Cuna'),
#  ('Paraguay', 5496000, 'German'),
#  ('Northern Mariana Islands', 78000, 'Korean'),
#  ('Poland', 38653600, 'Belorussian'),
#  ('France', 59225700, 'Italian'),
#  ('Réunion', 699000, 'Malagasy'),
#  ('Romania', 22455500, 'German'),
#  ('Sweden', 8861400, 'Arabic'),
#  ('Germany', 82164700, 'Italian'),
#  ('Zambia', 9169000, 'Lozi'),
#  ('Senegal', 9481000, 'Diola'),
#  ('Sierra Leone', 4854000, 'Kono-vai'),
#  ('Slovakia', 5398700, 'Czech and Moravian'),
#  ('Sudan', 29490000, 'Beja'),
#  ('Finland', 5171300, 'Estonian'),
#  ('Switzerland', 7160400, 'Romansh'),
#  ('Taiwan', 22256000, 'Ami'),
#  ('Tanzania', 33517000, 'Haya'),
#  ('Denmark', 5330000, 'German'),
#  ('Thailand', 61399000, 'Malay'),
#  ('Togo', 4629000, 'Kotokoli'),
#  ('Chad', 7651000, 'Kanem-bornu'),
#  ('Czech Republic', 10278100, 'Polish'),
#  ('Turkmenistan', 4459000, 'Kazakh'),
#  ('Uganda', 21778000, 'Soga'),
#  ('Ukraine', 50456000, 'Bulgariana'),
#  ('Hungary', 10043200, 'Serbo-Croatian'),
#  ('Uzbekistan', 24318000, 'Kazakh'),
#  ('Belarus', 10236000, 'Polish'),
#  ('Russian Federation', 146934000, 'Chuvash'),
#  ('Vietnam', 79832000, 'Muong'),
#  ('Estonia', 1439200, 'Belorussian'),
#  ('United States', 278357000, 'German'),
#  ('Zimbabwe', 11669000, 'Nyanja'),
#  ('Afghanistan', 22720000, 'Balochi'),
#  ('Angola', 12878000, 'Nyaneka-nkhumbi'),
#  ('Australia', 18886000, 'Arabic'),
#  ('Bangladesh', 129155000, 'Khasi'),
#  ('Belgium', 10239000, 'German'),
#  ('Benin', 6097000, 'Bariba'),
#  ('Botswana', 1622000, 'Ndebele'),
#  ('Brazil', 170115000, 'Indian Languages'),
#  ('Burkina Faso', 11937000, 'Dagara'),
#  ('Eritrea', 3850000, 'Bilin'),
#  ('South Africa', 40377000, 'English'),
#  ('Ethiopia', 62565000, 'Somali'),
#  ('Philippines', 75967000, 'Bicol'),
#  ('Gambia', 1305000, 'Soninke'),
#  ('Georgia', 4968000, 'Osseetti'),
#  ('Ghana', 20212000, 'Gurma'),
#  ('Guam', 168000, 'Japanese'),
#  ('Guatemala', 11385000, 'Mam'),
#  ('Guinea', 7430000, 'Kpelle'),
#  ('Guinea-Bissau', 1213000, 'Malinke'),
#  ('Hong Kong', 6782000, 'Chiu chau'),
#  ('Indonesia', 212107000, 'Minangkabau'),
#  ('India', 1013662000, 'Tamil'),
#  ('Iraq', 23115000, 'Persian'),
#  ('Iran', 67702000, 'Luri'),
#  ('Italy', 57680000, 'German'),
#  ('Austria', 8091800, 'Slovene'),
#  ('Japan', 126714000, 'Philippene Languages'),
#  ('Yugoslavia', 10640000, 'Slovak'),
#  ('Cameroon', 15085000, 'Tikar'),
#  ('Canada', 31147000, 'German'),
#  ('Kazakstan', 16223000, 'Uzbek'),
#  ('Kenya', 30080000, 'Kalenjin'),
#  ('Central African Republic', 3615000, 'Sara'),
#  ('China', 1277558000, 'Miao'),
#  ('Kyrgyzstan', 4699000, 'Tatar'),
#  ('Colombia', 42321000, 'Caribbean'),
#  ('Comoros', 578000, 'Comorian-Swahili'),
#  ('Congo', 2943000, 'Punu'),
#  ('Congo, The Democratic Republic of the', 51654000, 'Zande'),
#  ('Latvia', 2424200, 'Polish'),
#  ('Liberia', 3154000, 'Kru'),
#  ('Lithuania', 3698500, 'Ukrainian'),
#  ('Luxembourg', 435700, 'German'),
#  ('Macedonia', 2024000, 'Serbo-Croatian'),
#  ('Malaysia', 22244000, 'English'),
#  ('Mali', 11234000, 'Tamashek'),
#  ('Mauritania', 2670000, 'Ful'),
#  ('Mauritius', 1158000, 'Tamil'),
#  ('Mexico', 98881000, 'Mixtec'),
#  ('Micronesia, Federated States of', 119000, 'Yap'),
#  ('Moldova', 4380000, 'Bulgariana'),
#  ('Mongolia', 2662000, 'Buryat'),
#  ('Mozambique', 19680000, 'Shona'),
#  ('Myanmar', 45611000, 'Mon'),
#  ('Namibia', 1726000, 'Herero'),
#  ('Nauru', 12000, 'English'),
#  ('Nepal', 23930000, 'Tamang'),
#  ('Niger', 10730000, 'Kanuri'),
#  ('Nigeria', 111506000, 'Ibibio'),
#  ('Norway', 4478500, 'Saame'),
#  ('Côte d\x92Ivoire', 14786000, '[South]Mande'),
#  ('Pakistan', 156483000, 'Urdu'),
#  ('Panama', 2856000, 'Embera'),
#  ('Northern Mariana Islands', 78000, 'English'),
#  ('France', 59225700, 'Spanish'),
#  ('Réunion', 699000, 'Tamil'),
#  ('Romania', 22455500, 'Ukrainian'),
#  ('Sweden', 8861400, 'Spanish'),
#  ('Germany', 82164700, 'Greek'),
#  ('Zambia', 9169000, 'Chewa'),
#  ('Senegal', 9481000, 'Malinke'),
#  ('Sierra Leone', 4854000, 'Bullom-sherbro'),
#  ('Slovakia', 5398700, 'Ukrainian and Russian'),
#  ('Sudan', 29490000, 'Nuer'),
#  ('Finland', 5171300, 'Saame'),
#  ('Taiwan', 22256000, 'Atayal'),
#  ('Tanzania', 33517000, 'Makonde'),
#  ('Denmark', 5330000, 'English'),
#  ('Thailand', 61399000, 'Khmer'),
#  ('Togo', 4629000, 'Ane'),
#  ('Chad', 7651000, 'Ouaddai'),
#  ('Czech Republic', 10278100, 'German'),
#  ('Uganda', 21778000, 'Teso'),
#  ('Ukraine', 50456000, 'Hungarian'),
#  ('Hungary', 10043200, 'Romanian'),
#  ('Uzbekistan', 24318000, 'Karakalpak'),
#  ('Russian Federation', 146934000, 'Bashkir'),
#  ('Vietnam', 79832000, 'Chinese'),
#  ('Estonia', 1439200, 'Finnish'),
#  ('United States', 278357000, 'Italian'),
#  ('Angola', 12878000, 'Chokwe'),
#  ('Australia', 18886000, 'Vietnamese'),
#  ('Bangladesh', 129155000, 'Santhali'),
#  ('Belgium', 10239000, 'Turkish'),
#  ('Benin', 6097000, 'Somba'),
#  ('Burkina Faso', 11937000, 'Dyula'),
#  ('Eritrea', 3850000, 'Saho'),
#  ('South Africa', 40377000, 'Tswana'),
#  ('Ethiopia', 62565000, 'Sidamo'),
#  ('Philippines', 75967000, 'Waray-waray'),
#  ('Georgia', 4968000, 'Abhyasi'),
#  ('Ghana', 20212000, 'Joruba'),
#  ('Guinea', 7430000, 'Yalunka'),
#  ('Guinea-Bissau', 1213000, 'Mandyako'),
#  ('Indonesia', 212107000, 'Batakki'),
#  ('India', 1013662000, 'Urdu'),
#  ('Iran', 67702000, 'Mazandarani'),
#  ('Italy', 57680000, 'Albaniana'),
#  ('Austria', 8091800, 'Polish'),
#  ('Japan', 126714000, 'Ainu'),
#  ('Yugoslavia', 10640000, 'Macedonian'),
#  ('Cameroon', 15085000, 'Mandara'),
#  ('Canada', 31147000, 'Polish'),
#  ('Kazakstan', 16223000, 'Tatar'),
#  ('Kenya', 30080000, 'Gusii'),
#  ('Central African Republic', 3615000, 'Mbum'),
#  ('China', 1277558000, 'Uighur'),
#  ('Kyrgyzstan', 4699000, 'Kazakh'),
#  ('Congo', 2943000, 'Sango'),
#  ('Congo, The Democratic Republic of the', 51654000, 'Ngala and Bangi'),
#  ('Latvia', 2424200, 'Lithuanian'),
#  ('Liberia', 3154000, 'Mano'),
#  ('Malaysia', 22244000, 'Dusun'),
#  ('Mali', 11234000, 'Songhai'),
#  ('Mauritania', 2670000, 'Zenaga'),
#  ('Mauritius', 1158000, 'Marathi'),
#  ('Mexico', 98881000, 'Otomí'),
#  ('Micronesia, Federated States of', 119000, 'Wolea'),
#  ('Mongolia', 2662000, 'Dariganga'),
#  ('Mozambique', 19680000, 'Tswa'),
#  ('Myanmar', 45611000, 'Chin'),
#  ('Namibia', 1726000, 'Caprivi'),
#  ('Nepal', 23930000, 'Newari'),
#  ('Nigeria', 111506000, 'Kanuri'),
#  ('Pakistan', 156483000, 'Balochi'),
#  ('Panama', 2856000, 'Arabic'),
#  ('Northern Mariana Islands', 78000, 'Carolinian'),
#  ('France', 59225700, 'Turkish'),
#  ('Romania', 22455500, 'Serbo-Croatian'),
#  ('Sweden', 8861400, 'Norwegian'),
#  ('Germany', 82164700, 'Polish'),
#  ('Zambia', 9169000, 'Nsenga'),
#  ('Senegal', 9481000, 'Soninke'),
#  ('Sierra Leone', 4854000, 'Ful'),
#  ('Sudan', 29490000, 'Zande'),
#  ('Taiwan', 22256000, 'Paiwan'),
#  ('Tanzania', 33517000, 'Nyakusa'),
#  ('Denmark', 5330000, 'Swedish'),
#  ('Thailand', 61399000, 'Kuy'),
#  ('Togo', 4629000, 'Moba'),
#  ('Chad', 7651000, 'Hadjarai'),
#  ('Czech Republic', 10278100, 'Silesiana'),
#  ('Uganda', 21778000, 'Lango'),
#  ('Ukraine', 50456000, 'Belorussian'),
#  ('Hungary', 10043200, 'Slovak'),
#  ('Uzbekistan', 24318000, 'Tatar'),
#  ('Russian Federation', 146934000, 'Chechen'),
#  ('Vietnam', 79832000, 'Khmer'),
#  ('United States', 278357000, 'Chinese'),
#  ('Angola', 12878000, 'Luvale'),
#  ('Australia', 18886000, 'Serbo-Croatian'),
#  ('Bangladesh', 129155000, 'Tripuri'),
#  ('Benin', 6097000, 'Ful'),
#  ('South Africa', 40377000, 'Southsotho'),
#  ('Ethiopia', 62565000, 'Walaita'),
#  ('Philippines', 75967000, 'Pampango'),
#  ('Guinea', 7430000, 'Loma'),
#  ('Indonesia', 212107000, 'Bugi'),
#  ('India', 1013662000, 'Gujarati'),
#  ('Iran', 67702000, 'Balochi'),
#  ('Italy', 57680000, 'Slovene'),
#  ('Austria', 8091800, 'Czech'),
#  ('Cameroon', 15085000, 'Maka'),
#  ('Canada', 31147000, 'Spanish'),
#  ('Kenya', 30080000, 'Meru'),
#  ('China', 1277558000, 'Yi'),
#  ('Kyrgyzstan', 4699000, 'Tadzhik'),
#  ('Congo, The Democratic Republic of the', 51654000, 'Rundi'),
#  ('Liberia', 3154000, 'Loma'),
#  ('Mozambique', 19680000, 'Chuabo'),
#  ('Myanmar', 45611000, 'Kachin'),
#  ('Namibia', 1726000, 'San'),
#  ('Nepal', 23930000, 'Hindi'),
#  ('Nigeria', 111506000, 'Edo'),
#  ('Pakistan', 156483000, 'Hindko'),
#  ('Sierra Leone', 4854000, 'Kuranko'),
#  ('Sudan', 29490000, 'Bari'),
#  ('Tanzania', 33517000, 'Chaga and Pare'),
#  ('Denmark', 5330000, 'Norwegian'),
#  ('Togo', 4629000, 'Naudemba'),
#  ('Chad', 7651000, 'Tandjile'),
#  ('Czech Republic', 10278100, 'Romani'),
#  ('Uganda', 21778000, 'Lugbara'),
#  ('Ukraine', 50456000, 'Polish'),
#  ('Russian Federation', 146934000, 'Mordva'),
#  ('Vietnam', 79832000, 'Nung'),
#  ('United States', 278357000, 'Tagalog'),
#  ('Angola', 12878000, 'Ambo'),
#  ('Australia', 18886000, 'German'),
#  ('South Africa', 40377000, 'Tsonga'),
#  ('Philippines', 75967000, 'Pangasinan'),
#  ('Indonesia', 212107000, 'Banja'),
#  ('India', 1013662000, 'Kannada'),
#  ('Iran', 67702000, 'Arabic'),
#  ('Italy', 57680000, 'Romani'),
#  ('Austria', 8091800, 'Romanian'),
#  ('Cameroon', 15085000, 'Masana'),
#  ('Canada', 31147000, 'Portuguese'),
#  ('Kenya', 30080000, 'Nyika'),
#  ('China', 1277558000, 'Tujia'),
#  ('Congo, The Democratic Republic of the', 51654000, 'Teke'),
#  ('Liberia', 3154000, 'Malinke'),
#  ('Mozambique', 19680000, 'Ronga'),
#  ('Myanmar', 45611000, 'Kayah'),
#  ('Namibia', 1726000, 'German'),
#  ('Nigeria', 111506000, 'Tiv'),
#  ('Pakistan', 156483000, 'Brahui'),
#  ('Sierra Leone', 4854000, 'Yalunka'),
#  ('Sudan', 29490000, 'Fur'),
#  ('Tanzania', 33517000, 'Luguru'),
#  ('Togo', 4629000, 'Gurma'),
#  ('Chad', 7651000, 'Gorane'),
#  ('Czech Republic', 10278100, 'Hungarian'),
#  ('Uganda', 21778000, 'Gisu'),
#  ('Russian Federation', 146934000, 'Kazakh'),
#  ('Vietnam', 79832000, 'Miao'),
#  ('United States', 278357000, 'Polish'),
#  ('Angola', 12878000, 'Luchazi'),
#  ('South Africa', 40377000, 'Swazi'),
#  ('Philippines', 75967000, 'Maguindanao'),
#  ('Indonesia', 212107000, 'Bali'),
#  ('India', 1013662000, 'Malajalam'),
#  ('Iran', 67702000, 'Bakhtyari'),
#  ('Canada', 31147000, 'Punjabi'),
#  ('Kenya', 30080000, 'Masai'),
#  ('China', 1277558000, 'Mongolian'),
#  ('Congo, The Democratic Republic of the', 51654000, 'Boa'),
#  ('Mozambique', 19680000, 'Marendje'),
#  ('Nigeria', 111506000, 'Ijo'),
#  ('Sudan', 29490000, 'Chilluk'),
#  ('Tanzania', 33517000, 'Shambala'),
#  ('Uganda', 21778000, 'Acholi'),
#  ('Russian Federation', 146934000, 'Avarian'),
#  ('Vietnam', 79832000, 'Man'),
#  ('United States', 278357000, 'Korean'),
#  ('South Africa', 40377000, 'Venda'),
#  ('Philippines', 75967000, 'Maranao'),
#  ('India', 1013662000, 'Orija'),
#  ('Iran', 67702000, 'Turkmenian'),
#  ('Canada', 31147000, 'Ukrainian'),
#  ('Kenya', 30080000, 'Turkana'),
#  ('China', 1277558000, 'Tibetan'),
#  ('Congo, The Democratic Republic of the', 51654000, 'Chokwe'),
#  ('Mozambique', 19680000, 'Nyanja'),
#  ('Nigeria', 111506000, 'Bura'),
#  ('Sudan', 29490000, 'Lotuko'),
#  ('Tanzania', 33517000, 'Gogo'),
#  ('Uganda', 21778000, 'Rwanda'),
#  ('Russian Federation', 146934000, 'Mari'),
#  ('United States', 278357000, 'Vietnamese'),
#  ('South Africa', 40377000, 'Ndebele'),
#  ('India', 1013662000, 'Punjabi'),
#  ('Canada', 31147000, 'Dutch'),
#  ('China', 1277558000, 'Puyi'),
#  ('Tanzania', 33517000, 'Ha'),
#  ('Russian Federation', 146934000, 'Udmur'),
#  ('United States', 278357000, 'Japanese'),
#  ('India', 1013662000, 'Asami'),
#  ('Canada', 31147000, 'Eskimo Languages'),
#  ('China', 1277558000, 'Dong'),
#  ('Russian Federation', 146934000, 'Belorussian'),
#  ('United States', 278357000, 'Portuguese')]

# %% [markdown]
# Let's say we want to count the number of official languages in each country. We can write this query as:

# %%
# %%sql
#
# WITH my_cte AS (
#     SELECT
#         co.name, cl.language
#     FROM
#         country co
#     JOIN
#         countrylanguage cl
#     ON
#         cl.countrycode = co.code
#     WHERE
#         cl.isofficial = TRUE
# )
# SELECT
#     name, COUNT(language)
# FROM
#     my_cte
# GROUP BY
#     name
# ORDER BY
#     COUNT(language) DESC
# ;
# Out:
#    postgresql://postgres:***@localhost/imdb
#  * postgresql://postgres:***@localhost:5432/world
# 190 rows affected.
# [('Switzerland', 4),
#  ('South Africa', 4),
#  ('Singapore', 3),
#  ('Peru', 3),
#  ('Bolivia', 3),
#  ('Vanuatu', 3),
#  ('Belgium', 3),
#  ('Luxembourg', 3),
#  ('Seychelles', 2),
#  ('Cyprus', 2),
#  ('Netherlands Antilles', 2),
#  ('Romania', 2),
#  ('Kyrgyzstan', 2),
#  ('Burundi', 2),
#  ('Afghanistan', 2),
#  ('Guam', 2),
#  ('Togo', 2),
#  ('Israel', 2),
#  ('Faroe Islands', 2),
#  ('Nauru', 2),
#  ('Canada', 2),
#  ('Palau', 2),
#  ('Tonga', 2),
#  ('Madagascar', 2),
#  ('Greenland', 2),
#  ('Tuvalu', 2),
#  ('Samoa', 2),
#  ('Malta', 2),
#  ('Rwanda', 2),
#  ('Sri Lanka', 2),
#  ('Somalia', 2),
#  ('American Samoa', 2),
#  ('Marshall Islands', 2),
#  ('Belarus', 2),
#  ('Finland', 2),
#  ('Lesotho', 2),
#  ('Paraguay', 2),
#  ('Ireland', 2),
#  ('Uruguay', 1),
#  ('United Kingdom', 1),
#  ('Germany', 1),
#  ('Eritrea', 1),
#  ('Barbados', 1),
#  ('Saint Vincent and the Grenadines', 1),
#  ('Cook Islands', 1),
#  ('Slovenia', 1),
#  ('Azerbaijan', 1),
#  ('Greece', 1),
#  ('Egypt', 1),
#  ('Chad', 1),
#  ('Saint Kitts and Nevis', 1),
#  ('Chile', 1),
#  ('Norfolk Island', 1),
#  ('Yugoslavia', 1),
#  ('United States Minor Outlying Islands', 1),
#  ('Japan', 1),
#  ('Macao', 1),
#  ('Iraq', 1),
#  ('New Zealand', 1),
#  ('Ecuador', 1),
#  ('Norway', 1),
#  ('Pakistan', 1),
#  ('Brazil', 1),
#  ('Guatemala', 1),
#  ('Panama', 1),
#  ('Yemen', 1),
#  ('Tunisia', 1),
#  ('Sudan', 1),
#  ('Swaziland', 1),
#  ('Morocco', 1),
#  ('Christmas Island', 1),
#  ('Moldova', 1),
#  ('Myanmar', 1),
#  ('Mexico', 1),
#  ('Poland', 1),
#  ('Lebanon', 1),
#  ('Turks and Caicos Islands', 1),
#  ('Virgin Islands, U.S.', 1),
#  ('Indonesia', 1),
#  ('Kiribati', 1),
#  ('Virgin Islands, British', 1),
#  ('Jordan', 1),
#  ('Macedonia', 1),
#  ('Uzbekistan', 1),
#  ('Brunei', 1),
#  ('Fiji Islands', 1),
#  ('Cayman Islands', 1),
#  ('Cuba', 1),
#  ('Tokelau', 1),
#  ('France', 1),
#  ('Djibouti', 1),
#  ('Syria', 1),
#  ('Senegal', 1),
#  ('Iceland', 1),
#  ('Hong Kong', 1),
#  ('Philippines', 1),
#  ('Bangladesh', 1),
#  ('Turkey', 1),
#  ('Cocos (Keeling) Islands', 1),
#  ('Zimbabwe', 1),
#  ('Comoros', 1),
#  ('Saint Lucia', 1),
#  ('Netherlands', 1),
#  ('Bahrain', 1),
#  ('Spain', 1),
#  ('Saint Pierre and Miquelon', 1),
#  ('Falkland Islands', 1),
#  ('Malawi', 1),
#  ('Taiwan', 1),
#  ('Bhutan', 1),
#  ('Niue', 1),
#  ('Italy', 1),
#  ('Oman', 1),
#  ('South Korea', 1),
#  ('Anguilla', 1),
#  ('Svalbard and Jan Mayen', 1),
#  ('Bermuda', 1),
#  ('Argentina', 1),
#  ('Liechtenstein', 1),
#  ('Puerto Rico', 1),
#  ('India', 1),
#  ('Iran', 1),
#  ('French Polynesia', 1),
#  ('Estonia', 1),
#  ('Vietnam', 1),
#  ('Kazakstan', 1),
#  ('Guadeloupe', 1),
#  ('Denmark', 1),
#  ('Mongolia', 1),
#  ('Northern Mariana Islands', 1),
#  ('Hungary', 1),
#  ('Honduras', 1),
#  ('Belize', 1),
#  ('Russian Federation', 1),
#  ('Austria', 1),
#  ('Guinea-Bissau', 1),
#  ('Western Sahara', 1),
#  ('Lithuania', 1),
#  ('Bulgaria', 1),
#  ('Turkmenistan', 1),
#  ('Croatia', 1),
#  ('Libyan Arab Jamahiriya', 1),
#  ('Aruba', 1),
#  ('East Timor', 1),
#  ('Nicaragua', 1),
#  ('Nepal', 1),
#  ('Tanzania', 1),
#  ('Costa Rica', 1),
#  ('Haiti', 1),
#  ('Gibraltar', 1),
#  ('Antigua and Barbuda', 1),
#  ('Andorra', 1),
#  ('United States', 1),
#  ('Mayotte', 1),
#  ('Venezuela', 1),
#  ('Czech Republic', 1),
#  ('Sweden', 1),
#  ('Dominican Republic', 1),
#  ('Saint Helena', 1),
#  ('Cambodia', 1),
#  ('San Marino', 1),
#  ('Laos', 1),
#  ('Portugal', 1),
#  ('Colombia', 1),
#  ('Albania', 1),
#  ('Ukraine', 1),
#  ('Saudi Arabia', 1),
#  ('Latvia', 1),
#  ('North Korea', 1),
#  ('Holy See (Vatican City State)', 1),
#  ('Algeria', 1),
#  ('Cape Verde', 1),
#  ('Slovakia', 1),
#  ('Maldives', 1),
#  ('Malaysia', 1),
#  ('Kuwait', 1),
#  ('Bosnia and Herzegovina', 1),
#  ('Tajikistan', 1),
#  ('China', 1),
#  ('New Caledonia', 1),
#  ('Armenia', 1),
#  ('Qatar', 1),
#  ('Martinique', 1),
#  ('Australia', 1),
#  ('United Arab Emirates', 1),
#  ('Georgia', 1),
#  ('Monaco', 1),
#  ('Montserrat', 1),
#  ('Thailand', 1),
#  ('El Salvador', 1)]

# %% [markdown]
# We can also rewrite this query from the last lecture using a CTE:
#
# **Question:** Which countries speak at least one language that is not spoken in any other country on their continent?

# %%
# %%sql
#
# WITH ccl AS (
#     SELECT
#         co.name, co.continent, cl.language
#     FROM
#         country co
#     JOIN
#         countrylanguage cl
#     ON
#         co.code = cl.countrycode
# )
# SELECT
#     t1.*
# FROM
#     ccl t1
# WHERE
#     NOT EXISTS (
#         SELECT
#             *
#         FROM
#             ccl t2
#         WHERE
#             t1.name <> t2.name
#             AND
#             t1.continent = t2.continent
#             AND
#             t1.language = t2.language
#     )
# Out:
#    postgresql://postgres:***@localhost/imdb
#  * postgresql://postgres:***@localhost:5432/world
# 362 rows affected.
# [('Angola', 'Africa', 'Ovimbundu'),
#  ('Barbados', 'North America', 'Bajan'),
#  ('Benin', 'Africa', 'Fon'),
#  ('Bhutan', 'Asia', 'Dzongkha'),
#  ('Burundi', 'Africa', 'Kirundi'),
#  ('Ethiopia', 'Africa', 'Oromo'),
#  ('Falkland Islands', 'South America', 'English'),
#  ('Fiji Islands', 'Oceania', 'Fijian'),
#  ('Philippines', 'Asia', 'Pilipino'),
#  ('Faroe Islands', 'Europe', 'Faroese'),
#  ('Georgia', 'Asia', 'Georgiana'),
#  ('Greenland', 'North America', 'Greenlandic'),
#  ('Haiti', 'North America', 'Haiti Creole'),
#  ('Indonesia', 'Asia', 'Javanese'),
#  ('Iceland', 'Europe', 'Icelandic'),
#  ('Japan', 'Asia', 'Japanese'),
#  ('Kenya', 'Africa', 'Kikuyu'),
#  ('Central African Republic', 'Africa', 'Gbaya'),
#  ('Kyrgyzstan', 'Asia', 'Kirgiz'),
#  ('Congo, The Democratic Republic of the', 'Africa', 'Luba'),
#  ('Cocos (Keeling) Islands', 'Oceania', 'Malay'),
#  ('Cyprus', 'Asia', 'Greek'),
#  ('Latvia', 'Europe', 'Latvian'),
#  ('Lesotho', 'Africa', 'Sotho'),
#  ('Luxembourg', 'Europe', 'Luxembourgish'),
#  ('Malawi', 'Africa', 'Chichewa'),
#  ('Maldives', 'Asia', 'Dhivehi'),
#  ('Mali', 'Africa', 'Bambara'),
#  ('Malta', 'Europe', 'Maltese'),
#  ('Marshall Islands', 'Oceania', 'Marshallese'),
#  ('Mauritania', 'Africa', 'Hassaniya'),
#  ('Mayotte', 'Africa', 'Mahoré'),
#  ('Micronesia, Federated States of', 'Oceania', 'Trukese'),
#  ('Mozambique', 'Africa', 'Makua'),
#  ('Myanmar', 'Asia', 'Burmese'),
#  ('Namibia', 'Africa', 'Ovambo'),
#  ('Nauru', 'Oceania', 'Nauru'),
#  ('Niue', 'Oceania', 'Niue'),
#  ('Palau', 'Oceania', 'Palau'),
#  ('Pitcairn', 'Oceania', 'Pitcairnese'),
#  ('French Guiana', 'South America', 'Creole French'),
#  ('French Polynesia', 'Oceania', 'Tahitian'),
#  ('Zambia', 'Africa', 'Bemba'),
#  ('Samoa', 'Oceania', 'Samoan-English'),
#  ('Seychelles', 'Africa', 'Seselwa'),
#  ('Sierra Leone', 'Africa', 'Mende'),
#  ('Sri Lanka', 'Asia', 'Singali'),
#  ('Suriname', 'South America', 'Sranantonga'),
#  ('Taiwan', 'Asia', 'Min'),
#  ('Tanzania', 'Africa', 'Nyamwesi'),
#  ('Tokelau', 'Oceania', 'Tokelau'),
#  ('Uganda', 'Africa', 'Ganda'),
#  ('Wallis and Futuna', 'Oceania', 'Wallis'),
#  ('Vanuatu', 'Oceania', 'Bislama'),
#  ('Afghanistan', 'Asia', 'Dari'),
#  ('Netherlands', 'Europe', 'Fries'),
#  ('Angola', 'Africa', 'Mbundu'),
#  ('Australia', 'Oceania', 'Italian'),
#  ('Bangladesh', 'Asia', 'Chakma'),
#  ('United Kingdom', 'Europe', 'Kymri'),
#  ('Brunei', 'Asia', 'Malay-English'),
#  ('Chile', 'South America', 'Araucan'),
#  ('Egypt', 'Africa', 'Sinaberberi'),
#  ('El Salvador', 'North America', 'Nahua'),
#  ('Eritrea', 'Africa', 'Tigre'),
#  ('South Africa', 'Africa', 'Xhosa'),
#  ('Ethiopia', 'Africa', 'Amhara'),
#  ('Fiji Islands', 'Oceania', 'Hindi'),
#  ('Philippines', 'Asia', 'Cebuano'),
#  ('Gabon', 'Africa', 'Punu-sira-nzebi'),
#  ('Greenland', 'North America', 'Danish'),
#  ('Guatemala', 'North America', 'Quiché'),
#  ('Ireland', 'Europe', 'Irish'),
#  ('Italy', 'Europe', 'Sardinian'),
#  ('Yemen', 'Asia', 'Soqutri'),
#  ('Jordan', 'Asia', 'Circassian'),
#  ('Cameroon', 'Africa', 'Bamileke-bamum'),
#  ('Kenya', 'Africa', 'Luhya'),
#  ('Central African Republic', 'Africa', 'Banda'),
#  ('China', 'Asia', 'Zhuang'),
#  ('Colombia', 'South America', 'Chibcha'),
#  ('Comoros', 'Africa', 'Comorian-French'),
#  ('Laos', 'Asia', 'Mon-khmer'),
#  ('Liberia', 'Africa', 'Bassa'),
#  ('Mauritius', 'Africa', 'Bhojpuri'),
#  ('Mexico', 'North America', 'Náhuatl'),
#  ('Micronesia, Federated States of', 'Oceania', 'Pohnpei'),
#  ('Monaco', 'Europe', 'Monegasque'),
#  ('Myanmar', 'Asia', 'Shan'),
#  ('Namibia', 'Africa', 'Nama'),
#  ('Nepal', 'Asia', 'Maithili'),
#  ('Niger', 'Africa', 'Songhai-zerma'),
#  ('Côte d\x92Ivoire', 'Africa', 'Gur'),
#  ('Equatorial Guinea', 'Africa', 'Bubi'),
#  ('Réunion', 'Africa', 'Chinese'),
#  ('Zambia', 'Africa', 'Tongan'),
#  ('Sierra Leone', 'Africa', 'Temne'),
#  ('Sudan', 'Africa', 'Dinka'),
#  ('Suriname', 'South America', 'Hindi'),
#  ('Togo', 'Africa', 'Kabyé'),
#  ('Czech Republic', 'Europe', 'Moravian'),
#  ('Tunisia', 'Africa', 'Arabic-French'),
#  ('Uganda', 'Africa', 'Nkole'),
#  ('Wallis and Futuna', 'Oceania', 'Futuna'),
#  ('Venezuela', 'South America', 'Goajiro'),
#  ('Russian Federation', 'Europe', 'Tatar'),
#  ('Vietnam', 'Asia', 'Tho'),
#  ('Australia', 'Oceania', 'Greek'),
#  ('Azerbaijan', 'Asia', 'Lezgian'),
#  ('Bangladesh', 'Asia', 'Marma'),
#  ('Belize', 'North America', 'Maya Languages'),
#  ('Benin', 'Africa', 'Adja'),
#  ('United Kingdom', 'Europe', 'Gaeli'),
#  ('Costa Rica', 'North America', 'Chibcha'),
#  ('Spain', 'Europe', 'Galecian'),
#  ('Philippines', 'Asia', 'Ilocano'),
#  ('Gabon', 'Africa', 'Mpongwe'),
#  ('Guatemala', 'North America', 'Cakchiquel'),
#  ('Guinea', 'Africa', 'Susu'),
#  ('Guinea-Bissau', 'Africa', 'Balante'),
#  ('Hong Kong', 'Asia', 'Fukien'),
#  ('India', 'Asia', 'Telugu'),
#  ('Italy', 'Europe', 'Friuli'),
#  ('Cameroon', 'Africa', 'Duala'),
#  ('Kenya', 'Africa', 'Luo'),
#  ('Central African Republic', 'Africa', 'Mandjia'),
#  ('China', 'Asia', 'Mant\x9au'),
#  ('Comoros', 'Africa', 'Comorian-madagassi'),
#  ('Congo', 'Africa', 'Mboshi'),
#  ('Congo, The Democratic Republic of the', 'Africa', 'Mongo'),
#  ('Lebanon', 'Asia', 'French'),
#  ('Liberia', 'Africa', 'Grebo'),
#  ('Malawi', 'Africa', 'Yao'),
#  ('Mali', 'Africa', 'Senufo and Minianka'),
#  ('Mauritania', 'Africa', 'Tukulor'),
#  ('Mexico', 'North America', 'Yucatec'),
#  ('Micronesia, Federated States of', 'Oceania', 'Mortlock'),
#  ('Mongolia', 'Asia', 'Dorbet'),
#  ('Mozambique', 'Africa', 'Sena'),
#  ('Myanmar', 'Asia', 'Karen'),
#  ('Namibia', 'Africa', 'Kavango'),
#  ('Nepal', 'Asia', 'Bhojpuri'),
#  ('Nigeria', 'Africa', 'Ibo'),
#  ('Pakistan', 'Asia', 'Sindhi'),
#  ('Panama', 'North America', 'Guaymí'),
#  ('Senegal', 'Africa', 'Serer'),
#  ('Sierra Leone', 'Africa', 'Limba'),
#  ('Sri Lanka', 'Asia', 'Mixed Languages'),
#  ('Sudan', 'Africa', 'Nubian Languages'),
#  ('Tanzania', 'Africa', 'Hehet'),
#  ('Togo', 'Africa', 'Watyi'),
#  ('Chad', 'Africa', 'Mayo-kebbi'),
#  ('Tunisia', 'Africa', 'Arabic-French-English'),
#  ('Uganda', 'Africa', 'Kiga'),
#  ('Venezuela', 'South America', 'Warrau'),
#  ('Angola', 'Africa', 'Luimbe-nganguela'),
#  ('Australia', 'Oceania', 'Canton Chinese'),
#  ('Bangladesh', 'Asia', 'Garo'),
#  ('Benin', 'Africa', 'Aizo'),
#  ('Botswana', 'Africa', 'Khoekhoe'),
#  ('Brazil', 'South America', 'Japanese'),
#  ('Burkina Faso', 'Africa', 'Busansi'),
#  ('Chile', 'South America', 'Rapa nui'),
#  ('Eritrea', 'Africa', 'Hadareb'),
#  ('Spain', 'Europe', 'Basque'),
#  ('South Africa', 'Africa', 'Northsotho'),
#  ('Ethiopia', 'Africa', 'Gurage'),
#  ('Philippines', 'Asia', 'Hiligaynon'),
#  ('Ghana', 'Africa', 'Ga-adangme'),
#  ('Guatemala', 'North America', 'Kekchí'),
#  ('Guinea', 'Africa', 'Kissi'),
#  ('Indonesia', 'Asia', 'Madura'),
#  ('India', 'Asia', 'Marathi'),
#  ('Iraq', 'Asia', 'Assyrian'),
#  ('Iran', 'Asia', 'Gilaki'),
#  ('Cambodia', 'Asia', 'T\x9aam'),
#  ('Kazakstan', 'Asia', 'German'),
#  ('Kenya', 'Africa', 'Kamba'),
#  ('Central African Republic', 'Africa', 'Ngbaka'),
#  ('China', 'Asia', 'Hui'),
#  ('Comoros', 'Africa', 'Comorian-Arabic'),
#  ('Laos', 'Asia', 'Lao-Soung'),
#  ('Liberia', 'Africa', 'Gio'),
#  ('Malawi', 'Africa', 'Ngoni'),
#  ('Malaysia', 'Asia', 'Iban'),
#  ('Mauritius', 'Africa', 'Hindi'),
#  ('Mexico', 'North America', 'Zapotec'),
#  ('Micronesia, Federated States of', 'Oceania', 'Kosrean'),
#  ('Moldova', 'Europe', 'Gagauzi'),
#  ('Mongolia', 'Asia', 'Bajad'),
#  ('Myanmar', 'Asia', 'Rakhine'),
#  ('Nepal', 'Asia', 'Tharu'),
#  ('Nicaragua', 'North America', 'Sumo'),
#  ('Pakistan', 'Asia', 'Saraiki'),
#  ('Panama', 'North America', 'Cuna'),
#  ('Zambia', 'Africa', 'Lozi'),
#  ('Sierra Leone', 'Africa', 'Kono-vai'),
#  ('Slovakia', 'Europe', 'Czech and Moravian'),
#  ('Sudan', 'Africa', 'Beja'),
#  ('Switzerland', 'Europe', 'Romansh'),
#  ('Taiwan', 'Asia', 'Ami'),
#  ('Tanzania', 'Africa', 'Haya'),
#  ('Togo', 'Africa', 'Kotokoli'),
#  ('Chad', 'Africa', 'Kanem-bornu'),
#  ('Uganda', 'Africa', 'Soga'),
#  ('Russian Federation', 'Europe', 'Chuvash'),
#  ('Vietnam', 'Asia', 'Muong'),
#  ('Angola', 'Africa', 'Nyaneka-nkhumbi'),
#  ('Australia', 'Oceania', 'Arabic'),
#  ('Bangladesh', 'Asia', 'Khasi'),
#  ('Benin', 'Africa', 'Bariba'),
#  ('Burkina Faso', 'Africa', 'Dagara'),
#  ('Eritrea', 'Africa', 'Bilin'),
#  ('Philippines', 'Asia', 'Bicol'),
#  ('Georgia', 'Asia', 'Osseetti'),
#  ('Guam', 'Oceania', 'Japanese'),
#  ('Guatemala', 'North America', 'Mam'),
#  ('Hong Kong', 'Asia', 'Chiu chau'),
#  ('Indonesia', 'Asia', 'Minangkabau'),
#  ('Iran', 'Asia', 'Luri'),
#  ('Japan', 'Asia', 'Philippene Languages'),
#  ('Cameroon', 'Africa', 'Tikar'),
#  ('Kenya', 'Africa', 'Kalenjin'),
#  ('Comoros', 'Africa', 'Comorian-Swahili'),
#  ('Congo', 'Africa', 'Punu'),
#  ('Mexico', 'North America', 'Mixtec'),
#  ('Micronesia, Federated States of', 'Oceania', 'Yap'),
#  ('Mongolia', 'Asia', 'Buryat'),
#  ('Myanmar', 'Asia', 'Mon'),
#  ('Namibia', 'Africa', 'Herero'),
#  ('Nepal', 'Asia', 'Tamang'),
#  ('Nigeria', 'Africa', 'Ibibio'),
#  ('Côte d\x92Ivoire', 'Africa', '[South]Mande'),
#  ('Panama', 'North America', 'Embera'),
#  ('Zambia', 'Africa', 'Chewa'),
#  ('Sierra Leone', 'Africa', 'Bullom-sherbro'),
#  ('Slovakia', 'Europe', 'Ukrainian and Russian'),
#  ('Sudan', 'Africa', 'Nuer'),
#  ('Taiwan', 'Asia', 'Atayal'),
#  ('Tanzania', 'Africa', 'Makonde'),
#  ('Togo', 'Africa', 'Ane'),
#  ('Chad', 'Africa', 'Ouaddai'),
#  ('Uganda', 'Africa', 'Teso'),
#  ('Uzbekistan', 'Asia', 'Karakalpak'),
#  ('Russian Federation', 'Europe', 'Bashkir'),
#  ('Australia', 'Oceania', 'Vietnamese'),
#  ('Bangladesh', 'Asia', 'Santhali'),
#  ('Benin', 'Africa', 'Somba'),
#  ('Burkina Faso', 'Africa', 'Dyula'),
#  ('Eritrea', 'Africa', 'Saho'),
#  ('Ethiopia', 'Africa', 'Sidamo'),
#  ('Philippines', 'Asia', 'Waray-waray'),
#  ('Georgia', 'Asia', 'Abhyasi'),
#  ('Guinea-Bissau', 'Africa', 'Mandyako'),
#  ('Indonesia', 'Asia', 'Batakki'),
#  ('Iran', 'Asia', 'Mazandarani'),
#  ('Japan', 'Asia', 'Ainu'),
#  ('Cameroon', 'Africa', 'Mandara'),
#  ('Kenya', 'Africa', 'Gusii'),
#  ('Central African Republic', 'Africa', 'Mbum'),
#  ('China', 'Asia', 'Uighur'),
#  ('Congo', 'Africa', 'Sango'),
#  ('Congo, The Democratic Republic of the', 'Africa', 'Ngala and Bangi'),
#  ('Liberia', 'Africa', 'Mano'),
#  ('Malaysia', 'Asia', 'Dusun'),
#  ('Mali', 'Africa', 'Songhai'),
#  ('Mauritania', 'Africa', 'Zenaga'),
#  ('Mauritius', 'Africa', 'Marathi'),
#  ('Mexico', 'North America', 'Otomí'),
#  ('Micronesia, Federated States of', 'Oceania', 'Wolea'),
#  ('Mongolia', 'Asia', 'Dariganga'),
#  ('Mozambique', 'Africa', 'Tswa'),
#  ('Myanmar', 'Asia', 'Chin'),
#  ('Namibia', 'Africa', 'Caprivi'),
#  ('Nepal', 'Asia', 'Newari'),
#  ('Panama', 'North America', 'Arabic'),
#  ('Northern Mariana Islands', 'Oceania', 'Carolinian'),
#  ('Zambia', 'Africa', 'Nsenga'),
#  ('Taiwan', 'Asia', 'Paiwan'),
#  ('Tanzania', 'Africa', 'Nyakusa'),
#  ('Thailand', 'Asia', 'Kuy'),
#  ('Togo', 'Africa', 'Moba'),
#  ('Chad', 'Africa', 'Hadjarai'),
#  ('Czech Republic', 'Europe', 'Silesiana'),
#  ('Uganda', 'Africa', 'Lango'),
#  ('Russian Federation', 'Europe', 'Chechen'),
#  ('Angola', 'Africa', 'Luvale'),
#  ('Australia', 'Oceania', 'Serbo-Croatian'),
#  ('Bangladesh', 'Asia', 'Tripuri'),
#  ('South Africa', 'Africa', 'Southsotho'),
#  ('Ethiopia', 'Africa', 'Walaita'),
#  ('Philippines', 'Asia', 'Pampango'),
#  ('Indonesia', 'Asia', 'Bugi'),
#  ('India', 'Asia', 'Gujarati'),
#  ('Cameroon', 'Africa', 'Maka'),
#  ('Kenya', 'Africa', 'Meru'),
#  ('China', 'Asia', 'Yi'),
#  ('Congo, The Democratic Republic of the', 'Africa', 'Rundi'),
#  ('Mozambique', 'Africa', 'Chuabo'),
#  ('Myanmar', 'Asia', 'Kachin'),
#  ('Nigeria', 'Africa', 'Edo'),
#  ('Pakistan', 'Asia', 'Hindko'),
#  ('Sierra Leone', 'Africa', 'Kuranko'),
#  ('Sudan', 'Africa', 'Bari'),
#  ('Tanzania', 'Africa', 'Chaga and Pare'),
#  ('Togo', 'Africa', 'Naudemba'),
#  ('Chad', 'Africa', 'Tandjile'),
#  ('Uganda', 'Africa', 'Lugbara'),
#  ('Russian Federation', 'Europe', 'Mordva'),
#  ('Vietnam', 'Asia', 'Nung'),
#  ('United States', 'North America', 'Tagalog'),
#  ('Angola', 'Africa', 'Ambo'),
#  ('Australia', 'Oceania', 'German'),
#  ('Philippines', 'Asia', 'Pangasinan'),
#  ('Indonesia', 'Asia', 'Banja'),
#  ('India', 'Asia', 'Kannada'),
#  ('Cameroon', 'Africa', 'Masana'),
#  ('Kenya', 'Africa', 'Nyika'),
#  ('China', 'Asia', 'Tujia'),
#  ('Mozambique', 'Africa', 'Ronga'),
#  ('Myanmar', 'Asia', 'Kayah'),
#  ('Namibia', 'Africa', 'German'),
#  ('Nigeria', 'Africa', 'Tiv'),
#  ('Pakistan', 'Asia', 'Brahui'),
#  ('Sudan', 'Africa', 'Fur'),
#  ('Tanzania', 'Africa', 'Luguru'),
#  ('Chad', 'Africa', 'Gorane'),
#  ('Uganda', 'Africa', 'Gisu'),
#  ('Russian Federation', 'Europe', 'Kazakh'),
#  ('Angola', 'Africa', 'Luchazi'),
#  ('Philippines', 'Asia', 'Maguindanao'),
#  ('Indonesia', 'Asia', 'Bali'),
#  ('India', 'Asia', 'Malajalam'),
#  ('Iran', 'Asia', 'Bakhtyari'),
#  ('Canada', 'North America', 'Punjabi'),
#  ('Kenya', 'Africa', 'Masai'),
#  ('Congo, The Democratic Republic of the', 'Africa', 'Boa'),
#  ('Mozambique', 'Africa', 'Marendje'),
#  ('Nigeria', 'Africa', 'Ijo'),
#  ('Sudan', 'Africa', 'Chilluk'),
#  ('Tanzania', 'Africa', 'Shambala'),
#  ('Uganda', 'Africa', 'Acholi'),
#  ('Russian Federation', 'Europe', 'Avarian'),
#  ('Vietnam', 'Asia', 'Man'),
#  ('United States', 'North America', 'Korean'),
#  ('South Africa', 'Africa', 'Venda'),
#  ('Philippines', 'Asia', 'Maranao'),
#  ('India', 'Asia', 'Orija'),
#  ('Canada', 'North America', 'Ukrainian'),
#  ('Kenya', 'Africa', 'Turkana'),
#  ('China', 'Asia', 'Tibetan'),
#  ('Nigeria', 'Africa', 'Bura'),
#  ('Sudan', 'Africa', 'Lotuko'),
#  ('Tanzania', 'Africa', 'Gogo'),
#  ('Russian Federation', 'Europe', 'Mari'),
#  ('United States', 'North America', 'Vietnamese'),
#  ('China', 'Asia', 'Puyi'),
#  ('Tanzania', 'Africa', 'Ha'),
#  ('Russian Federation', 'Europe', 'Udmur'),
#  ('United States', 'North America', 'Japanese'),
#  ('Canada', 'North America', 'Eskimo Languages'),
#  ('China', 'Asia', 'Dong')]

# %% [markdown]
# <br><br><br>

# %% [markdown]
# ---
#
# **Question:** Can you think of two advantages of a temporary table over CTEs?
#
# ---

# %% [markdown]
# <br><br><br>

# %% [markdown]
# Besides simplifying long and complex queries and increase readability, we can do things with CTEs that are impossible otherwise. One example is with grouping and aggregation.
#
# Remember that when aggregate functions are used, only columns can be in the `SELECT` clause that are either aggregated (used inside an aggregate function) or appear also in the `GROUP BY` clause. Now, consider the following example:

# %% [markdown]
# <br><br><br>

# %% [markdown]
# ---
#
# **Example:** List city names, their country and region where they are located. Also in each row (i.e. for each city)
#
# - list the number of official languages and
# - number of cities with population over 1,000,000
#
# in their respective countries.
#
# ---

# %% [markdown]
# We can obviously join the three tables `country`, `city`, and `countrylanguage` and do grouping, but we won't be able to list city names for the reason just discussed. But we can actually do this using a CTE:

# %%
# %%sql
#
# WITH
#     ccl (code, country, region, "num_cities_over_1_mil", "num_off_lang")
# AS (
#     SELECT
#         co.code, co.name, co.region,
#         COUNT(DISTINCT ci.name),
#         COUNT(DISTINCT cl.language)
#     FROM
#         country co
#     JOIN
#         city ci
#     ON
#         co.code = ci.countrycode
#     JOIN
#         countrylanguage cl
#     ON
#         co.code = cl.countrycode
#     WHERE
#         ci.population > 1000000
#     GROUP BY
#         co.code, co.name, co.region
# )
# SELECT
#     ci.name, ccl.*
# FROM
#     ccl
# JOIN
#     city ci
# ON
#     ccl.code = ci.countrycode
# ;
# Out:
#    postgresql://postgres:***@localhost/imdb
#  * postgresql://postgres:***@localhost:5432/world
# 3671 rows affected.
# [('Kabul', 'AFG', 'Afghanistan', 'Southern and Central Asia', 1, 5),
#  ('Qandahar', 'AFG', 'Afghanistan', 'Southern and Central Asia', 1, 5),
#  ('Herat', 'AFG', 'Afghanistan', 'Southern and Central Asia', 1, 5),
#  ('Mazar-e-Sharif', 'AFG', 'Afghanistan', 'Southern and Central Asia', 1, 5),
#  ('Alger', 'DZA', 'Algeria', 'Northern Africa', 1, 2),
#  ('Oran', 'DZA', 'Algeria', 'Northern Africa', 1, 2),
#  ('Constantine', 'DZA', 'Algeria', 'Northern Africa', 1, 2),
#  ('Annaba', 'DZA', 'Algeria', 'Northern Africa', 1, 2),
#  ('Batna', 'DZA', 'Algeria', 'Northern Africa', 1, 2),
#  ('Sétif', 'DZA', 'Algeria', 'Northern Africa', 1, 2),
#  ('Sidi Bel Abbès', 'DZA', 'Algeria', 'Northern Africa', 1, 2),
#  ('Skikda', 'DZA', 'Algeria', 'Northern Africa', 1, 2),
#  ('Biskra', 'DZA', 'Algeria', 'Northern Africa', 1, 2),
#  ('Blida (el-Boulaida)', 'DZA', 'Algeria', 'Northern Africa', 1, 2),
#  ('Béjaïa', 'DZA', 'Algeria', 'Northern Africa', 1, 2),
#  ('Mostaganem', 'DZA', 'Algeria', 'Northern Africa', 1, 2),
#  ('Tébessa', 'DZA', 'Algeria', 'Northern Africa', 1, 2),
#  ('Tlemcen (Tilimsen)', 'DZA', 'Algeria', 'Northern Africa', 1, 2),
#  ('Béchar', 'DZA', 'Algeria', 'Northern Africa', 1, 2),
#  ('Tiaret', 'DZA', 'Algeria', 'Northern Africa', 1, 2),
#  ('Ech-Chleff (el-Asnam)', 'DZA', 'Algeria', 'Northern Africa', 1, 2),
#  ('Ghardaïa', 'DZA', 'Algeria', 'Northern Africa', 1, 2),
#  ('Luanda', 'AGO', 'Angola', 'Central Africa', 1, 9),
#  ('Huambo', 'AGO', 'Angola', 'Central Africa', 1, 9),
#  ('Lobito', 'AGO', 'Angola', 'Central Africa', 1, 9),
#  ('Benguela', 'AGO', 'Angola', 'Central Africa', 1, 9),
#  ('Namibe', 'AGO', 'Angola', 'Central Africa', 1, 9),
#  ('Buenos Aires', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('La Matanza', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Córdoba', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Rosario', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Lomas de Zamora', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Quilmes', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Almirante Brown', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('La Plata', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Mar del Plata', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('San Miguel de Tucumán', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Lanús', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Merlo', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('General San Martín', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Salta', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Moreno', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Santa Fé', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Avellaneda', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Tres de Febrero', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Morón', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Florencio Varela', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('San Isidro', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Tigre', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Malvinas Argentinas', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Vicente López', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Berazategui', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Corrientes', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('San Miguel', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Bahía Blanca', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Esteban Echeverría', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Resistencia', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('José C. Paz', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Paraná', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Godoy Cruz', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Posadas', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Guaymallén', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Santiago del Estero', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('San Salvador de Jujuy', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Hurlingham', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Neuquén', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Ituzaingó', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('San Fernando', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Formosa', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Las Heras', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('La Rioja', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('San Fernando del Valle de Cata', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Río Cuarto', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Comodoro Rivadavia', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Mendoza', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('San Nicolás de los Arroyos', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('San Juan', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Escobar', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Concordia', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Pilar', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('San Luis', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Ezeiza', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('San Rafael', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Tandil', 'ARG', 'Argentina', 'South America', 3, 3),
#  ('Yerevan', 'ARM', 'Armenia', 'Middle East', 1, 2),
#  ('Gjumri', 'ARM', 'Armenia', 'Middle East', 1, 2),
#  ('Vanadzor', 'ARM', 'Armenia', 'Middle East', 1, 2),
#  ('Sydney', 'AUS', 'Australia', 'Australia and New Zealand', 4, 8),
#  ('Melbourne', 'AUS', 'Australia', 'Australia and New Zealand', 4, 8),
#  ('Brisbane', 'AUS', 'Australia', 'Australia and New Zealand', 4, 8),
#  ('Perth', 'AUS', 'Australia', 'Australia and New Zealand', 4, 8),
#  ('Adelaide', 'AUS', 'Australia', 'Australia and New Zealand', 4, 8),
#  ('Canberra', 'AUS', 'Australia', 'Australia and New Zealand', 4, 8),
#  ('Gold Coast', 'AUS', 'Australia', 'Australia and New Zealand', 4, 8),
#  ('Newcastle', 'AUS', 'Australia', 'Australia and New Zealand', 4, 8),
#  ('Central Coast', 'AUS', 'Australia', 'Australia and New Zealand', 4, 8),
#  ('Wollongong', 'AUS', 'Australia', 'Australia and New Zealand', 4, 8),
#  ('Hobart', 'AUS', 'Australia', 'Australia and New Zealand', 4, 8),
#  ('Geelong', 'AUS', 'Australia', 'Australia and New Zealand', 4, 8),
#  ('Townsville', 'AUS', 'Australia', 'Australia and New Zealand', 4, 8),
#  ('Cairns', 'AUS', 'Australia', 'Australia and New Zealand', 4, 8),
#  ('Baku', 'AZE', 'Azerbaijan', 'Middle East', 1, 4),
#  ('Gäncä', 'AZE', 'Azerbaijan', 'Middle East', 1, 4),
#  ('Sumqayit', 'AZE', 'Azerbaijan', 'Middle East', 1, 4),
#  ('Mingäçevir', 'AZE', 'Azerbaijan', 'Middle East', 1, 4),
#  ('Dhaka', 'BGD', 'Bangladesh', 'Southern and Central Asia', 2, 7),
#  ('Chittagong', 'BGD', 'Bangladesh', 'Southern and Central Asia', 2, 7),
#  ('Khulna', 'BGD', 'Bangladesh', 'Southern and Central Asia', 2, 7),
#  ('Rajshahi', 'BGD', 'Bangladesh', 'Southern and Central Asia', 2, 7),
#  ('Narayanganj', 'BGD', 'Bangladesh', 'Southern and Central Asia', 2, 7),
#  ('Rangpur', 'BGD', 'Bangladesh', 'Southern and Central Asia', 2, 7),
#  ('Mymensingh', 'BGD', 'Bangladesh', 'Southern and Central Asia', 2, 7),
#  ('Barisal', 'BGD', 'Bangladesh', 'Southern and Central Asia', 2, 7),
#  ('Tungi', 'BGD', 'Bangladesh', 'Southern and Central Asia', 2, 7),
#  ('Jessore', 'BGD', 'Bangladesh', 'Southern and Central Asia', 2, 7),
#  ('Comilla', 'BGD', 'Bangladesh', 'Southern and Central Asia', 2, 7),
#  ('Nawabganj', 'BGD', 'Bangladesh', 'Southern and Central Asia', 2, 7),
#  ('Dinajpur', 'BGD', 'Bangladesh', 'Southern and Central Asia', 2, 7),
#  ('Bogra', 'BGD', 'Bangladesh', 'Southern and Central Asia', 2, 7),
#  ('Sylhet', 'BGD', 'Bangladesh', 'Southern and Central Asia', 2, 7),
#  ('Brahmanbaria', 'BGD', 'Bangladesh', 'Southern and Central Asia', 2, 7),
#  ('Tangail', 'BGD', 'Bangladesh', 'Southern and Central Asia', 2, 7),
#  ('Jamalpur', 'BGD', 'Bangladesh', 'Southern and Central Asia', 2, 7),
#  ('Pabna', 'BGD', 'Bangladesh', 'Southern and Central Asia', 2, 7),
#  ('Naogaon', 'BGD', 'Bangladesh', 'Southern and Central Asia', 2, 7),
#  ('Sirajganj', 'BGD', 'Bangladesh', 'Southern and Central Asia', 2, 7),
#  ('Narsinghdi', 'BGD', 'Bangladesh', 'Southern and Central Asia', 2, 7),
#  ('Saidpur', 'BGD', 'Bangladesh', 'Southern and Central Asia', 2, 7),
#  ('Gazipur', 'BGD', 'Bangladesh', 'Southern and Central Asia', 2, 7),
#  ('São Paulo', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Rio de Janeiro', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Salvador', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Belo Horizonte', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Fortaleza', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Brasília', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Curitiba', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Recife', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Porto Alegre', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Manaus', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Belém', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Guarulhos', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Goiânia', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Campinas', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('São Gonçalo', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Nova Iguaçu', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('São Luís', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Maceió', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Duque de Caxias', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('São Bernardo do Campo', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Teresina', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Natal', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Osasco', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Campo Grande', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Santo André', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('João Pessoa', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Jaboatão dos Guararapes', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Contagem', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('São José dos Campos', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Uberlândia', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Feira de Santana', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Ribeirão Preto', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Sorocaba', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Niterói', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Cuiabá', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Juiz de Fora', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Aracaju', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('São João de Meriti', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Londrina', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Joinville', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Belford Roxo', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Santos', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Ananindeua', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Campos dos Goytacazes', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Mauá', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Carapicuíba', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Olinda', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Campina Grande', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('São José do Rio Preto', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Caxias do Sul', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Moji das Cruzes', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Diadema', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Aparecida de Goiânia', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Piracicaba', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Cariacica', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Vila Velha', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Pelotas', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Bauru', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Porto Velho', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Serra', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Betim', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Jundíaí', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Canoas', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Franca', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('São Vicente', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Maringá', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Montes Claros', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Anápolis', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Florianópolis', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Petrópolis', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Itaquaquecetuba', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Vitória', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Ponta Grossa', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Rio Branco', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Foz do Iguaçu', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Macapá', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Ilhéus', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Vitória da Conquista', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Uberaba', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Paulista', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Limeira', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Blumenau', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Caruaru', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Santarém', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Volta Redonda', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Novo Hamburgo', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Caucaia', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Santa Maria', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Cascavel', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Guarujá', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Ribeirão das Neves', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Governador Valadares', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Taubaté', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Imperatriz', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Gravataí', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Embu', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Mossoró', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Várzea Grande', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Petrolina', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Barueri', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Viamão', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Ipatinga', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Juazeiro', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Juazeiro do Norte', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Taboão da Serra', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('São José dos Pinhais', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Magé', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Suzano', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('São Leopoldo', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Marília', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('São Carlos', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Sumaré', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Presidente Prudente', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Divinópolis', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Sete Lagoas', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Rio Grande', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Itabuna', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Jequié', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Arapiraca', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Colombo', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Americana', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Alvorada', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Araraquara', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Itaboraí', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Santa Bárbara d´Oeste', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Nova Friburgo', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Jacareí', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Araçatuba', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Barra Mansa', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Praia Grande', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Marabá', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Criciúma', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Boa Vista', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Passo Fundo', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Dourados', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Santa Luzia', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Rio Claro', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Maracanaú', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Guarapuava', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Rondonópolis', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('São José', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Cachoeiro de Itapemirim', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Nilópolis', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Itapevi', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Cabo de Santo Agostinho', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Camaçari', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Sobral', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Itajaí', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Chapecó', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Cotia', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Lages', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Ferraz de Vasconcelos', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Indaiatuba', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Hortolândia', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Caxias', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('São Caetano do Sul', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Itu', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Nossa Senhora do Socorro', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Parnaíba', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Poços de Caldas', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Teresópolis', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Barreiras', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Castanhal', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Alagoinhas', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Itapecerica da Serra', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Uruguaiana', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Paranaguá', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Ibirité', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Timon', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Luziânia', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Macaé', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Teófilo Otoni', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Moji-Guaçu', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Palmas', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Pindamonhangaba', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Francisco Morato', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Bagé', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Sapucaia do Sul', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Cabo Frio', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Itapetininga', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Patos de Minas', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Camaragibe', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Bragança Paulista', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Queimados', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Araguaína', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Garanhuns', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Vitória de Santo Antão', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Santa Rita', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Barbacena', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Abaetetuba', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Jaú', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Lauro de Freitas', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Franco da Rocha', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Teixeira de Freitas', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Varginha', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Ribeirão Pires', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Sabará', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Catanduva', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Rio Verde', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Botucatu', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Colatina', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Santa Cruz do Sul', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Linhares', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Apucarana', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Barretos', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Guaratinguetá', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Cachoeirinha', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Codó', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Jaraguá do Sul', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Cubatão', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Itabira', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Itaituba', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Araras', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Resende', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Atibaia', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Pouso Alegre', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Toledo', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Crato', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Passos', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Araguari', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('São José de Ribamar', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Pinhais', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Sertãozinho', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Conselheiro Lafaiete', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Paulo Afonso', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Angra dos Reis', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Eunápolis', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Salto', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Ourinhos', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Parnamirim', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Jacobina', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Coronel Fabriciano', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Birigui', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Tatuí', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Ji-Paraná', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Bacabal', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Cametá', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Guaíba', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('São Lourenço da Mata', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Santana do Livramento', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Votorantim', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Campo Largo', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Patos', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Ituiutaba', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Corumbá', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Palhoça', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Barra do Piraí', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Bento Gonçalves', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Poá', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('Águas Lindas de Goiás', 'BRA', 'Brazil', 'South America', 13, 5),
#  ('London', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Birmingham', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Glasgow', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Liverpool', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Edinburgh', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Sheffield', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Manchester', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Leeds', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Bristol', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Cardiff', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Coventry', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Leicester', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Bradford', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Belfast', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Nottingham', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Kingston upon Hull', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Plymouth', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Stoke-on-Trent', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Wolverhampton', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Derby', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Swansea', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Southampton', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Aberdeen', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Northampton', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Dudley', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Portsmouth', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Newcastle upon Tyne', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Sunderland', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Luton', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Swindon', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Southend-on-Sea', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Walsall', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Bournemouth', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Peterborough', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Brighton', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Blackpool', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Dundee', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('West Bromwich', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Reading', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Oldbury/Smethwick (Warley)', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Middlesbrough', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Huddersfield', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Oxford', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Poole', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Bolton', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Blackburn', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Newport', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Preston', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Stockport', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Norwich', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Rotherham', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Cambridge', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Watford', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Ipswich', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Slough', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Exeter', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Cheltenham', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Gloucester', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Saint Helens', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Sutton Coldfield', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('York', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Oldham', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Basildon', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Worthing', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Chelmsford', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Colchester', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Crawley', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Gillingham', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Solihull', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Rochdale', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Birkenhead', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Worcester', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Hartlepool', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Halifax', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Woking/Byfleet', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Southport', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Maidstone', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Eastbourne', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Grimsby', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Saint Helier', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Douglas', 'GBR', 'United Kingdom', 'British Islands', 2, 3),
#  ('Sofija', 'BGR', 'Bulgaria', 'Eastern Europe', 1, 4),
#  ('Plovdiv', 'BGR', 'Bulgaria', 'Eastern Europe', 1, 4),
#  ('Varna', 'BGR', 'Bulgaria', 'Eastern Europe', 1, 4),
#  ('Burgas', 'BGR', 'Bulgaria', 'Eastern Europe', 1, 4),
#  ('Ruse', 'BGR', 'Bulgaria', 'Eastern Europe', 1, 4),
#  ('Stara Zagora', 'BGR', 'Bulgaria', 'Eastern Europe', 1, 4),
#  ('Pleven', 'BGR', 'Bulgaria', 'Eastern Europe', 1, 4),
#  ('Sliven', 'BGR', 'Bulgaria', 'Eastern Europe', 1, 4),
#  ('Dobric', 'BGR', 'Bulgaria', 'Eastern Europe', 1, 4),
#  ('\x8aumen', 'BGR', 'Bulgaria', 'Eastern Europe', 1, 4),
#  ('Santiago de Chile', 'CHL', 'Chile', 'South America', 1, 4),
#  ('Puente Alto', 'CHL', 'Chile', 'South America', 1, 4),
#  ('Viña del Mar', 'CHL', 'Chile', 'South America', 1, 4),
#  ('Valparaíso', 'CHL', 'Chile', 'South America', 1, 4),
#  ('Talcahuano', 'CHL', 'Chile', 'South America', 1, 4),
#  ('Antofagasta', 'CHL', 'Chile', 'South America', 1, 4),
#  ('San Bernardo', 'CHL', 'Chile', 'South America', 1, 4),
#  ('Temuco', 'CHL', 'Chile', 'South America', 1, 4),
#  ('Concepción', 'CHL', 'Chile', 'South America', 1, 4),
#  ('Rancagua', 'CHL', 'Chile', 'South America', 1, 4),
#  ('Arica', 'CHL', 'Chile', 'South America', 1, 4),
#  ('Talca', 'CHL', 'Chile', 'South America', 1, 4),
#  ('Chillán', 'CHL', 'Chile', 'South America', 1, 4),
#  ('Iquique', 'CHL', 'Chile', 'South America', 1, 4),
#  ('Los Angeles', 'CHL', 'Chile', 'South America', 1, 4),
#  ('Puerto Montt', 'CHL', 'Chile', 'South America', 1, 4),
#  ('Coquimbo', 'CHL', 'Chile', 'South America', 1, 4),
#  ('Osorno', 'CHL', 'Chile', 'South America', 1, 4),
#  ('La Serena', 'CHL', 'Chile', 'South America', 1, 4),
#  ('Calama', 'CHL', 'Chile', 'South America', 1, 4),
#  ('Valdivia', 'CHL', 'Chile', 'South America', 1, 4),
#  ('Punta Arenas', 'CHL', 'Chile', 'South America', 1, 4),
#  ('Copiapó', 'CHL', 'Chile', 'South America', 1, 4),
#  ('Quilpué', 'CHL', 'Chile', 'South America', 1, 4),
#  ('Curicó', 'CHL', 'Chile', 'South America', 1, 4),
#  ('Ovalle', 'CHL', 'Chile', 'South America', 1, 4),
#  ('Coronel', 'CHL', 'Chile', 'South America', 1, 4),
#  ('San Pedro de la Paz', 'CHL', 'Chile', 'South America', 1, 4),
#  ('Melipilla', 'CHL', 'Chile', 'South America', 1, 4),
#  ('Santo Domingo de Guzmán', 'DOM', 'Dominican Republic', 'Caribbean', 1, 2),
#  ('Santiago de los Caballeros', 'DOM', 'Dominican Republic', 'Caribbean', 1, 2),
#  ('La Romana', 'DOM', 'Dominican Republic', 'Caribbean', 1, 2),
#  ('San Pedro de Macorís', 'DOM', 'Dominican Republic', 'Caribbean', 1, 2),
#  ('San Francisco de Macorís', 'DOM', 'Dominican Republic', 'Caribbean', 1, 2),
#  ('San Felipe de Puerto Plata', 'DOM', 'Dominican Republic', 'Caribbean', 1, 2),
#  ('Guayaquil', 'ECU', 'Ecuador', 'South America', 2, 2),
#  ('Quito', 'ECU', 'Ecuador', 'South America', 2, 2),
#  ('Cuenca', 'ECU', 'Ecuador', 'South America', 2, 2),
#  ('Machala', 'ECU', 'Ecuador', 'South America', 2, 2),
#  ('Santo Domingo de los Colorados', 'ECU', 'Ecuador', 'South America', 2, 2),
#  ('Portoviejo', 'ECU', 'Ecuador', 'South America', 2, 2),
#  ('Ambato', 'ECU', 'Ecuador', 'South America', 2, 2),
#  ('Manta', 'ECU', 'Ecuador', 'South America', 2, 2),
#  ('Duran [Eloy Alfaro]', 'ECU', 'Ecuador', 'South America', 2, 2),
#  ('Ibarra', 'ECU', 'Ecuador', 'South America', 2, 2),
#  ('Quevedo', 'ECU', 'Ecuador', 'South America', 2, 2),
#  ('Milagro', 'ECU', 'Ecuador', 'South America', 2, 2),
#  ('Loja', 'ECU', 'Ecuador', 'South America', 2, 2),
#  ('Ríobamba', 'ECU', 'Ecuador', 'South America', 2, 2),
#  ('Esmeraldas', 'ECU', 'Ecuador', 'South America', 2, 2),
#  ('Cairo', 'EGY', 'Egypt', 'Northern Africa', 3, 2),
#  ('Alexandria', 'EGY', 'Egypt', 'Northern Africa', 3, 2),
#  ('Giza', 'EGY', 'Egypt', 'Northern Africa', 3, 2),
#  ('Shubra al-Khayma', 'EGY', 'Egypt', 'Northern Africa', 3, 2),
#  ('Port Said', 'EGY', 'Egypt', 'Northern Africa', 3, 2),
#  ('Suez', 'EGY', 'Egypt', 'Northern Africa', 3, 2),
#  ('al-Mahallat al-Kubra', 'EGY', 'Egypt', 'Northern Africa', 3, 2),
#  ('Tanta', 'EGY', 'Egypt', 'Northern Africa', 3, 2),
#  ('al-Mansura', 'EGY', 'Egypt', 'Northern Africa', 3, 2),
#  ('Luxor', 'EGY', 'Egypt', 'Northern Africa', 3, 2),
#  ('Asyut', 'EGY', 'Egypt', 'Northern Africa', 3, 2),
#  ('Bahtim', 'EGY', 'Egypt', 'Northern Africa', 3, 2),
#  ('Zagazig', 'EGY', 'Egypt', 'Northern Africa', 3, 2),
#  ('al-Faiyum', 'EGY', 'Egypt', 'Northern Africa', 3, 2),
#  ('Ismailia', 'EGY', 'Egypt', 'Northern Africa', 3, 2),
#  ('Kafr al-Dawwar', 'EGY', 'Egypt', 'Northern Africa', 3, 2),
#  ('Assuan', 'EGY', 'Egypt', 'Northern Africa', 3, 2),
#  ('Damanhur', 'EGY', 'Egypt', 'Northern Africa', 3, 2),
#  ('al-Minya', 'EGY', 'Egypt', 'Northern Africa', 3, 2),
#  ('Bani Suwayf', 'EGY', 'Egypt', 'Northern Africa', 3, 2),
#  ('Qina', 'EGY', 'Egypt', 'Northern Africa', 3, 2),
#  ('Sawhaj', 'EGY', 'Egypt', 'Northern Africa', 3, 2),
#  ('Shibin al-Kawm', 'EGY', 'Egypt', 'Northern Africa', 3, 2),
#  ('Bulaq al-Dakrur', 'EGY', 'Egypt', 'Northern Africa', 3, 2),
#  ('Banha', 'EGY', 'Egypt', 'Northern Africa', 3, 2),
#  ('Warraq al-Arab', 'EGY', 'Egypt', 'Northern Africa', 3, 2),
#  ('Kafr al-Shaykh', 'EGY', 'Egypt', 'Northern Africa', 3, 2),
#  ('Mallawi', 'EGY', 'Egypt', 'Northern Africa', 3, 2),
#  ('Bilbays', 'EGY', 'Egypt', 'Northern Africa', 3, 2),
#  ('Mit Ghamr', 'EGY', 'Egypt', 'Northern Africa', 3, 2),
#  ('al-Arish', 'EGY', 'Egypt', 'Northern Africa', 3, 2),
#  ('Talkha', 'EGY', 'Egypt', 'Northern Africa', 3, 2),
#  ('Qalyub', 'EGY', 'Egypt', 'Northern Africa', 3, 2),
#  ('Jirja', 'EGY', 'Egypt', 'Northern Africa', 3, 2),
#  ('Idfu', 'EGY', 'Egypt', 'Northern Africa', 3, 2),
#  ('al-Hawamidiya', 'EGY', 'Egypt', 'Northern Africa', 3, 2),
#  ('Disuq', 'EGY', 'Egypt', 'Northern Africa', 3, 2),
#  ('Madrid', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Barcelona', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Valencia', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Sevilla', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Zaragoza', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Málaga', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Bilbao', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Las Palmas de Gran Canaria', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Murcia', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Palma de Mallorca', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Valladolid', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Córdoba', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Vigo', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Alicante [Alacant]', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Gijón', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('L´Hospitalet de Llobregat', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Granada', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('A Coruña (La Coruña)', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Vitoria-Gasteiz', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Santa Cruz de Tenerife', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Badalona', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Oviedo', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Móstoles', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Elche [Elx]', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Sabadell', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Santander', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Jerez de la Frontera', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Pamplona [Iruña]', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Donostia-San Sebastián', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Cartagena', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Leganés', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Fuenlabrada', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Almería', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Terrassa', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Alcalá de Henares', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Burgos', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Salamanca', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Albacete', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Getafe', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Cádiz', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Alcorcón', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Huelva', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('León', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Castellón de la Plana [Castell', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Badajoz', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('[San Cristóbal de] la Laguna', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Logroño', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Santa Coloma de Gramenet', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Tarragona', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Lleida (Lérida)', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Jaén', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Ourense (Orense)', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Mataró', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Algeciras', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Marbella', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Barakaldo', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Dos Hermanas', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Santiago de Compostela', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Torrejón de Ardoz', 'ESP', 'Spain', 'Southern Europe', 2, 4),
#  ('Cape Town', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Soweto', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Johannesburg', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Port Elizabeth', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Pretoria', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Inanda', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Durban', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Vanderbijlpark', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Kempton Park', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Alberton', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Pinetown', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Pietermaritzburg', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Benoni', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Randburg', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Umlazi', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Bloemfontein', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Vereeniging', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Wonderboom', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Roodepoort', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Boksburg', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Klerksdorp', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Soshanguve', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Newcastle', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('East London', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Welkom', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Kimberley', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Uitenhage', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Chatsworth', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Mdantsane', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Krugersdorp', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Botshabelo', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Brakpan', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Witbank', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Oberholzer', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Germiston', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Springs', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Westonaria', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Randfontein', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Paarl', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Potchefstroom', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Rustenburg', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Nigel', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('George', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Ladysmith', 'ZAF', 'South Africa', 'Southern Africa', 1, 11),
#  ('Addis Abeba', 'ETH', 'Ethiopia', 'Eastern Africa', 1, 7),
#  ('Dire Dawa', 'ETH', 'Ethiopia', 'Eastern Africa', 1, 7),
#  ('Nazret', 'ETH', 'Ethiopia', 'Eastern Africa', 1, 7),
#  ('Gonder', 'ETH', 'Ethiopia', 'Eastern Africa', 1, 7),
#  ('Dese', 'ETH', 'Ethiopia', 'Eastern Africa', 1, 7),
#  ('Mekele', 'ETH', 'Ethiopia', 'Eastern Africa', 1, 7),
#  ('Bahir Dar', 'ETH', 'Ethiopia', 'Eastern Africa', 1, 7),
#  ('Quezon', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Manila', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Kalookan', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Davao', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Cebu', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Zamboanga', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Pasig', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Valenzuela', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Las Piñas', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Antipolo', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Taguig', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Cagayan de Oro', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Parañaque', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Makati', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Bacolod', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('General Santos', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Marikina', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Dasmariñas', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Muntinlupa', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Iloilo', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Pasay', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Malabon', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('San José del Monte', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Bacoor', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Iligan', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Calamba', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Mandaluyong', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Butuan', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Angeles', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Tarlac', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Mandaue', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Baguio', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Batangas', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Cainta', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('San Pedro', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Navotas', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Cabanatuan', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('San Fernando', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Lipa', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Lapu-Lapu', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('San Pablo', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Biñan', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Taytay', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Lucena', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Imus', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Olongapo', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Binangonan', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Santa Rosa', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Tagum', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Tacloban', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Malolos', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Mabalacat', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Cotabato', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Meycauayan', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Puerto Princesa', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Legazpi', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Silang', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Ormoc', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('San Carlos', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Kabankalan', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Talisay', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Valencia', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Calbayog', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Santa Maria', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Pagadian', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Cadiz', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Bago', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Toledo', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Naga', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('San Mateo', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Panabo', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Koronadal', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Marawi', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Dagupan', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Sagay', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Roxas', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Lubao', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Digos', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('San Miguel', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Malaybalay', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Tuguegarao', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Ilagan', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Baliuag', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Surigao', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('San Carlos', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('San Juan del Monte', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Tanauan', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Concepcion', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Rodriguez (Montalban)', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Sariaya', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Malasiqui', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('General Mariano Alvarez', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Urdaneta', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Hagonoy', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('San Jose', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Polomolok', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Santiago', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Tanza', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Ozamis', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Mexico', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('San Jose', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Silay', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('General Trias', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Tabaco', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Cabuyao', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Calapan', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Mati', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Midsayap', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Cauayan', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Gingoog', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Dumaguete', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('San Fernando', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Arayat', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Bayawan (Tulong)', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Kidapawan', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Daraga (Locsin)', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Marilao', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Malita', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Dipolog', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Cavite', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Danao', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Bislig', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Talavera', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Guagua', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Bayambang', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Nasugbu', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Baybay', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Capas', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Sultan Kudarat', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Laoag', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Bayugan', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Malungon', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Santa Cruz', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Sorsogon', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Candelaria', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Ligao', 'PHL', 'Philippines', 'Southeast Asia', 4, 10),
#  ('Tbilisi', 'GEO', 'Georgia', 'Middle East', 1, 6),
#  ('Kutaisi', 'GEO', 'Georgia', 'Middle East', 1, 6),
#  ('Rustavi', 'GEO', 'Georgia', 'Middle East', 1, 6),
#  ('Batumi', 'GEO', 'Georgia', 'Middle East', 1, 6),
#  ('Sohumi', 'GEO', 'Georgia', 'Middle East', 1, 6),
#  ('Accra', 'GHA', 'Ghana', 'Western Africa', 1, 6),
#  ('Kumasi', 'GHA', 'Ghana', 'Western Africa', 1, 6),
#  ('Tamale', 'GHA', 'Ghana', 'Western Africa', 1, 6),
#  ('Tema', 'GHA', 'Ghana', 'Western Africa', 1, 6),
#  ('Sekondi-Takoradi', 'GHA', 'Ghana', 'Western Africa', 1, 6),
#  ('Conakry', 'GIN', 'Guinea', 'Western Africa', 1, 7),
#  ('Kowloon and New Kowloon', 'HKG', 'Hong Kong', 'Eastern Asia', 2, 5),
#  ('Victoria', 'HKG', 'Hong Kong', 'Eastern Asia', 2, 5),
#  ('Jakarta', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Surabaya', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Bandung', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Medan', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Palembang', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Tangerang', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Semarang', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Ujung Pandang', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Malang', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Bandar Lampung', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Bekasi', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Padang', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Surakarta', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Banjarmasin', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Pekan Baru', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Denpasar', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Yogyakarta', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Pontianak', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Samarinda', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Jambi', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Depok', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Cimahi', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Balikpapan', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Manado', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Mataram', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Pekalongan', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Tegal', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Bogor', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Ciputat', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Pondokgede', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Cirebon', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Kediri', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Ambon', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Jember', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Cilacap', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Cimanggis', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Pematang Siantar', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Purwokerto', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Ciomas', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Tasikmalaya', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Madiun', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Bengkulu', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Karawang', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Banda Aceh', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Palu', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Pasuruan', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Kupang', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Tebing Tinggi', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Percut Sei Tuan', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Binjai', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Sukabumi', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Waru', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Pangkal Pinang', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Magelang', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Blitar', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Serang', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Probolinggo', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Cilegon', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Cianjur', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Ciparay', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Lhokseumawe', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Taman', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Depok', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Citeureup', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Pemalang', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Klaten', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Salatiga', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Cibinong', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Palangka Raya', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Mojokerto', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Purwakarta', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Garut', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Kudus', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Kendari', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Jaya Pura', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Gorontalo', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Majalaya', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Pondok Aren', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Jombang', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Sunggal', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Batam', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Padang Sidempuan', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Sawangan', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Banyuwangi', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Tanjung Pinang', 'IDN', 'Indonesia', 'Southeast Asia', 8, 9),
#  ('Mumbai (Bombay)', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Delhi', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Calcutta [Kolkata]', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Chennai (Madras)', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Hyderabad', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Ahmedabad', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Bangalore', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Kanpur', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Nagpur', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Lucknow', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Pune', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Surat', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Jaipur', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Indore', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Bhopal', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Ludhiana', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Vadodara (Baroda)', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Kalyan', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Madurai', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Haora (Howrah)', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Varanasi (Benares)', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Patna', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Srinagar', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Agra', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Coimbatore', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Thane (Thana)', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Allahabad', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Meerut', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Vishakhapatnam', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Jabalpur', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Amritsar', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Faridabad', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Vijayawada', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Gwalior', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Jodhpur', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Nashik (Nasik)', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Hubli-Dharwad', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Solapur (Sholapur)', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Ranchi', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Bareilly', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Guwahati (Gauhati)', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Shambajinagar (Aurangabad)', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Cochin (Kochi)', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Rajkot', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Kota', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Thiruvananthapuram (Trivandrum', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Pimpri-Chinchwad', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Jalandhar (Jullundur)', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Gorakhpur', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Chandigarh', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Mysore', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Aligarh', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Guntur', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Jamshedpur', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Ghaziabad', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Warangal', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Raipur', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Moradabad', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Durgapur', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Amravati', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Calicut (Kozhikode)', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Bikaner', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Bhubaneswar', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Kolhapur', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Kataka (Cuttack)', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Ajmer', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Bhavnagar', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Tiruchirapalli', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Bhilai', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Bhiwandi', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Saharanpur', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Ulhasnagar', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Salem', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Ujjain', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Malegaon', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Jamnagar', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Bokaro Steel City', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Akola', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Belgaum', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Rajahmundry', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Nellore', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Udaipur', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('New Bombay', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Bhatpara', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Gulbarga', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('New Delhi', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Jhansi', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Gaya', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Kakinada', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Dhule (Dhulia)', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Panihati', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Nanded (Nander)', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Mangalore', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Dehra Dun', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Kamarhati', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Davangere', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Asansol', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Bhagalpur', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ('Bellary', 'IND', 'India', 'Southern and Central Asia', 18, 12),
#  ...]

# %% [markdown]
# <br><br><br>

# %% [markdown]
# ### (OPTIONAL) Data-modifying CTEs
#
# CTEs can also be used with `INSERT`, `DELETE`, and `UPDATE` to catch the rows modified by these statements via the `RETURNING` statement and use them for another purpose.

# %% [markdown]
# Let's connect to the `mds` database we created earlier and reload it with the original data:

# %%
# %sql postgresql://{username}:{password}@{host}:{port}/mds
# Out:
# 'Connected: postgres@mds'

# %%
# %%sql
#
# DROP TABLE IF EXISTS
#     instructor,
#     instructor_course,
#     course_cohort
# ;
#
# CREATE TABLE instructor (
#     id INTEGER PRIMARY KEY,
#     name TEXT,
#     email TEXT,
#     phone VARCHAR(12),
#     department VARCHAR(50)
#     )
# ;
#
# INSERT INTO
#     instructor (id, name, email, phone, department)
# VALUES
#     (1, 'Mike', 'mike@mds.ubc.ca', '605-332-2343', 'Computer Science'),
#     (2, 'Tiffany', 'tiff@mds.ubc.ca', '445-794-2233', 'Neuroscience'),
#     (3, 'Arman', 'arman@mds.ubc.ca', '935-738-5796', 'Physics'),
#     (4, 'Varada', 'varada@mds.ubc.ca', '243-924-4446', 'Computer Science'),
#     (5, 'Quan', 'quan@mds.ubc.ca', '644-818-0254', 'Economics'),
#     (6, 'Joel', 'joel@mds.ubc.ca', '773-432-7669', 'Biomedical Engineering'),
#     (7, 'Florencia', 'flor@mds.ubc.ca', '773-926-2837', 'Biology'),
#     (8, 'Alexi', 'alexiu@mds.ubc.ca', '421-888-4550', 'Statistics'),
#     (15, 'Vincenzo', 'vincenzo@mds.ubc.ca', '776-543-1212', 'Statistics'),
#     (19, 'Gittu', 'gittu@mds.ubc.ca', '776-334-1132', 'Biomedical Engineering'),
#     (16, 'Jessica', 'jessica@mds.ubc.ca', '211-990-1762', 'Computer Science')
# ;
#
#
# CREATE TABLE instructor_course (
#     id SERIAL PRIMARY KEY,
#     instructor_id INTEGER,
#     course TEXT,
#     enrollment INTEGER,
#     begins DATE
#     )
# ;
#
# INSERT INTO
#     instructor_course (instructor_id, course, enrollment, begins)
# VALUES
#     (8, 'Statistical Inference and Computation I', 125, '2021-10-01'),
#     (8, 'Regression II', 102, '2022-02-05'),
#     (1, 'Descriptive Statistics and Probability', 79, '2021-09-10'),
#     (1, 'Algorithms and Data Structures', 25, '2021-10-01'),
#     (3, 'Algorithms and Data Structures', 25, '2021-10-01'),
#     (3, 'Python Programming', 133, '2021-09-07'),
#     (3, 'Databases & Data Retrieval', 118, '2021-11-16'),
#     (6, 'Visualization I', 155, '2021-10-01'),
#     (6, 'Privacy, Ethics & Security', 148, '2022-03-01'),
#     (2, 'Programming for Data Manipulation', 160, '2021-09-08'),
#     (7, 'Data Science Workflows', 98, '2021-09-15'),
#     (2, 'Data Science Workflows', 98, '2021-09-15'),
#     (12, 'Web & Cloud Computing', 78, '2022-02-10'),
#     (10, 'Introduction to Optimization', NULL, '2022-09-01'),
#     (9, 'Parallel Computing', NULL, '2023-01-10'),
#     (13, 'Natural Language Processing', NULL, '2023-09-10')
# ;
#
# CREATE TABLE course_cohort (
#     id INTEGER,
#     cohort VARCHAR(7)
#     )
# ;
#
# INSERT INTO
#     course_cohort (id, cohort)
# VALUES
#     (13, 'MDS-CL'),
#     (8, 'MDS-CL'),
#     (1, 'MDS-CL'),
#     (3, 'MDS-CL'),
#     (1, 'MDS-V'),
#     (9, 'MDS-V'),
#     (9, 'MDS-V'),
#     (3, 'MDS-V')
# ;
# Out:
#    postgresql://postgres:***@localhost/imdb
#  * postgresql://postgres:***@localhost:5432/mds
#    postgresql://postgres:***@localhost:5432/world
# Done.
# Done.
# 11 rows affected.
# Done.
# 16 rows affected.
# Done.
# 8 rows affected.
# []

# %%
# %sql SELECT * FROM instructor;
# Out:
#    postgresql://postgres:***@localhost/imdb
#  * postgresql://postgres:***@localhost:5432/mds
#    postgresql://postgres:***@localhost:5432/world
# 11 rows affected.
# [(1, 'Mike', 'mike@mds.ubc.ca', '605-332-2343', 'Computer Science'),
#  (2, 'Tiffany', 'tiff@mds.ubc.ca', '445-794-2233', 'Neuroscience'),
#  (3, 'Arman', 'arman@mds.ubc.ca', '935-738-5796', 'Physics'),
#  (4, 'Varada', 'varada@mds.ubc.ca', '243-924-4446', 'Computer Science'),
#  (5, 'Quan', 'quan@mds.ubc.ca', '644-818-0254', 'Economics'),
#  (6, 'Joel', 'joel@mds.ubc.ca', '773-432-7669', 'Biomedical Engineering'),
#  (7, 'Florencia', 'flor@mds.ubc.ca', '773-926-2837', 'Biology'),
#  (8, 'Alexi', 'alexiu@mds.ubc.ca', '421-888-4550', 'Statistics'),
#  (15, 'Vincenzo', 'vincenzo@mds.ubc.ca', '776-543-1212', 'Statistics'),
#  (19, 'Gittu', 'gittu@mds.ubc.ca', '776-334-1132', 'Biomedical Engineering'),
#  (16, 'Jessica', 'jessica@mds.ubc.ca', '211-990-1762', 'Computer Science')]

# %%
# %%sql
#
# DROP TABLE IF EXISTS former_instructor;
#
# CREATE TABLE
#     former_instructor AS (
#     SELECT
#         *
#     FROM
#         instructor
#     WHERE
#         1 = 2
# )
# ;
# Out:
#    postgresql://postgres:***@localhost/imdb
#  * postgresql://postgres:***@localhost:5432/mds
#    postgresql://postgres:***@localhost:5432/world
# Done.
# 0 rows affected.
# []

# %%
# %sql SELECT * FROM former_instructor;
# Out:
#    postgresql://postgres:***@localhost/imdb
#  * postgresql://postgres:***@localhost:5432/mds
#    postgresql://postgres:***@localhost:5432/world
# 0 rows affected.
# []

# %% [markdown]
# Here I use the `RETURNING` statement to retrieve the results of deleting two rows using a CTE, and insert the deleted rows into another table, namely, `former_instructor`:

# %%
# %%sql
#
# WITH deleted_rows AS (
#     DELETE FROM
#         instructor
#     WHERE
#         name IN ('Arman', 'Mike')
#     RETURNING
#         *
# )
# INSERT INTO
#     former_instructor
# SELECT
#     *
# FROM
#     deleted_rows
# ;
# Out:
#    postgresql://postgres:***@localhost/imdb
#  * postgresql://postgres:***@localhost:5432/mds
#    postgresql://postgres:***@localhost:5432/world
# 2 rows affected.
# []

# %% [markdown]
# Let's check out the `former_instructor` table now:

# %%
# %sql SELECT * FROM former_instructor;
# Out:
#    postgresql://postgres:***@localhost/imdb
#  * postgresql://postgres:***@localhost:5432/mds
#    postgresql://postgres:***@localhost:5432/world
# 2 rows affected.
# [(1, 'Mike', 'mike@mds.ubc.ca', '605-332-2343', 'Computer Science'),
#  (3, 'Arman', 'arman@mds.ubc.ca', '935-738-5796', 'Physics')]

# %% [markdown]
# The two deleted rows have been successfully moved to the `former_instructor` table!

# %% [markdown]
# <br><br><br>

# %% [markdown]
# ## Window functions

# %% [markdown]
# We've been using aggregation and grouping quite a lot so far. But as you may recall, there are situations that aggregation and grouping alone cannot address, such as having aggregated and non-aggregated columns together.
#
# We know that aggregation functions perform calculations on groups of rows, and return a single value for all rows that take part in that calculation. They also collapse the participant rows into one single row with the the common column(s) values between all the collapsed rows and the aggregated value. For example, in the `instructor` table of the `mds` database, we can group rows by `department`, and apply `COUNT()` to find the number of instructors in each department, but we no longer see individual instructor rows. Instead, we will see a `COUNT()` number for each `department`.
#
# Window functions act in a similar fashion: they perform operations on groups of rows that are related in some way to the current row (like `GROUP BY` that bases the relatedness on common values in grouped columns), but these functions **do not collapse rows**! This is the most important difference between aggregation and window functions
#
# Let's take a look at an example first. The following query finds the maximum population of countries in each continent:

# %%
# %sql postgresql://{username}:{password}@{host}:{port}/world
# Out:
# 'Connected: postgres@world'

# %%
# %%sql
#
# SELECT
#     continent,
#     MAX(population)
# FROM
#     country
# GROUP BY
#     continent
# ;
# Out:
#    postgresql://postgres:***@localhost/imdb
#    postgresql://postgres:***@localhost:5432/mds
#  * postgresql://postgres:***@localhost:5432/world
# 7 rows affected.
# [('Asia', 1277558000),
#  ('South America', 170115000),
#  ('North America', 278357000),
#  ('Oceania', 18886000),
#  ('Antarctica', 0),
#  ('Africa', 111506000),
#  ('Europe', 146934000)]

# %% [markdown]
# <br><br><br>

# %% [markdown]
# However, what if we want each country to be listed along with its own population, as well as the maximum population in their respective continent? This is not possible with aggregation functions alone.
#
# In order to list country names, their population, and the maximum population in their continent we can use `MAX()` as a window function:

# %%
# %%sql
#
# SELECT
#     name,
#     population,
#     continent,
#     MAX(population)
#         OVER (PARTITION BY continent)
# FROM
#     country
# ;
# Out:
#    postgresql://postgres:***@localhost/imdb
#    postgresql://postgres:***@localhost:5432/mds
#  * postgresql://postgres:***@localhost:5432/world
# 239 rows affected.
# [('Algeria', 31471000, 'Africa', 111506000),
#  ('Western Sahara', 293000, 'Africa', 111506000),
#  ('Madagascar', 15942000, 'Africa', 111506000),
#  ('Uganda', 21778000, 'Africa', 111506000),
#  ('Malawi', 10925000, 'Africa', 111506000),
#  ('Mali', 11234000, 'Africa', 111506000),
#  ('Morocco', 28351000, 'Africa', 111506000),
#  ('Côte d\x92Ivoire', 14786000, 'Africa', 111506000),
#  ('Mauritania', 2670000, 'Africa', 111506000),
#  ('Mauritius', 1158000, 'Africa', 111506000),
#  ('Mayotte', 149000, 'Africa', 111506000),
#  ('Nigeria', 111506000, 'Africa', 111506000),
#  ('Niger', 10730000, 'Africa', 111506000),
#  ('Mozambique', 19680000, 'Africa', 111506000),
#  ('Namibia', 1726000, 'Africa', 111506000),
#  ('Botswana', 1622000, 'Africa', 111506000),
#  ('Tunisia', 9586000, 'Africa', 111506000),
#  ('Angola', 12878000, 'Africa', 111506000),
#  ('Burkina Faso', 11937000, 'Africa', 111506000),
#  ('Burundi', 6695000, 'Africa', 111506000),
#  ('Chad', 7651000, 'Africa', 111506000),
#  ('Togo', 4629000, 'Africa', 111506000),
#  ('Tanzania', 33517000, 'Africa', 111506000),
#  ('Djibouti', 638000, 'Africa', 111506000),
#  ('Egypt', 68470000, 'Africa', 111506000),
#  ('Swaziland', 1008000, 'Africa', 111506000),
#  ('Eritrea', 3850000, 'Africa', 111506000),
#  ('South Africa', 40377000, 'Africa', 111506000),
#  ('Ethiopia', 62565000, 'Africa', 111506000),
#  ('Sudan', 29490000, 'Africa', 111506000),
#  ('British Indian Ocean Territory', 0, 'Africa', 111506000),
#  ('Gabon', 1226000, 'Africa', 111506000),
#  ('Gambia', 1305000, 'Africa', 111506000),
#  ('Ghana', 20212000, 'Africa', 111506000),
#  ('Somalia', 10097000, 'Africa', 111506000),
#  ('Sierra Leone', 4854000, 'Africa', 111506000),
#  ('Seychelles', 77000, 'Africa', 111506000),
#  ('Senegal', 9481000, 'Africa', 111506000),
#  ('Guinea', 7430000, 'Africa', 111506000),
#  ('Guinea-Bissau', 1213000, 'Africa', 111506000),
#  ('Sao Tome and Principe', 147000, 'Africa', 111506000),
#  ('Zambia', 9169000, 'Africa', 111506000),
#  ('Saint Helena', 6000, 'Africa', 111506000),
#  ('Zimbabwe', 11669000, 'Africa', 111506000),
#  ('Cameroon', 15085000, 'Africa', 111506000),
#  ('Rwanda', 7733000, 'Africa', 111506000),
#  ('Cape Verde', 428000, 'Africa', 111506000),
#  ('Kenya', 30080000, 'Africa', 111506000),
#  ('Central African Republic', 3615000, 'Africa', 111506000),
#  ('Réunion', 699000, 'Africa', 111506000),
#  ('Comoros', 578000, 'Africa', 111506000),
#  ('Congo', 2943000, 'Africa', 111506000),
#  ('Congo, The Democratic Republic of the', 51654000, 'Africa', 111506000),
#  ('Equatorial Guinea', 453000, 'Africa', 111506000),
#  ('Lesotho', 2153000, 'Africa', 111506000),
#  ('Liberia', 3154000, 'Africa', 111506000),
#  ('Libyan Arab Jamahiriya', 5605000, 'Africa', 111506000),
#  ('Benin', 6097000, 'Africa', 111506000),
#  ('Heard Island and McDonald Islands', 0, 'Antarctica', 0),
#  ('Bouvet Island', 0, 'Antarctica', 0),
#  ('French Southern territories', 0, 'Antarctica', 0),
#  ('Antarctica', 0, 'Antarctica', 0),
#  ('South Georgia and the South Sandwich Islands', 0, 'Antarctica', 0),
#  ('Pakistan', 156483000, 'Asia', 1277558000),
#  ('China', 1277558000, 'Asia', 1277558000),
#  ('Maldives', 286000, 'Asia', 1277558000),
#  ('Malaysia', 22244000, 'Asia', 1277558000),
#  ('Kyrgyzstan', 4699000, 'Asia', 1277558000),
#  ('Bhutan', 2124000, 'Asia', 1277558000),
#  ('Kuwait', 1972000, 'Asia', 1277558000),
#  ('Oman', 2542000, 'Asia', 1277558000),
#  ('Qatar', 599000, 'Asia', 1277558000),
#  ('Saudi Arabia', 21607000, 'Asia', 1277558000),
#  ('Cyprus', 754700, 'Asia', 1277558000),
#  ('Afghanistan', 22720000, 'Asia', 1277558000),
#  ('Hong Kong', 6782000, 'Asia', 1277558000),
#  ('Turkmenistan', 4459000, 'Asia', 1277558000),
#  ('Mongolia', 2662000, 'Asia', 1277558000),
#  ('Nepal', 23930000, 'Asia', 1277558000),
#  ('Indonesia', 212107000, 'Asia', 1277558000),
#  ('Myanmar', 45611000, 'Asia', 1277558000),
#  ('India', 1013662000, 'Asia', 1277558000),
#  ('Iraq', 23115000, 'Asia', 1277558000),
#  ('Turkey', 66591000, 'Asia', 1277558000),
#  ('Iran', 67702000, 'Asia', 1277558000),
#  ('Brunei', 328000, 'Asia', 1277558000),
#  ('Armenia', 3520000, 'Asia', 1277558000),
#  ('Israel', 6217000, 'Asia', 1277558000),
#  ('Palestine', 3101000, 'Asia', 1277558000),
#  ('East Timor', 885000, 'Asia', 1277558000),
#  ('Thailand', 61399000, 'Asia', 1277558000),
#  ('Azerbaijan', 7734000, 'Asia', 1277558000),
#  ('Laos', 5433000, 'Asia', 1277558000),
#  ('Taiwan', 22256000, 'Asia', 1277558000),
#  ('Tajikistan', 6188000, 'Asia', 1277558000),
#  ('Syria', 16125000, 'Asia', 1277558000),
#  ('Japan', 126714000, 'Asia', 1277558000),
#  ('Yemen', 18112000, 'Asia', 1277558000),
#  ('Jordan', 5083000, 'Asia', 1277558000),
#  ('Vietnam', 79832000, 'Asia', 1277558000),
#  ('Lebanon', 3282000, 'Asia', 1277558000),
#  ('Cambodia', 11168000, 'Asia', 1277558000),
#  ('Sri Lanka', 18827000, 'Asia', 1277558000),
#  ('Philippines', 75967000, 'Asia', 1277558000),
#  ('North Korea', 24039000, 'Asia', 1277558000),
#  ('South Korea', 46844000, 'Asia', 1277558000),
#  ('Bahrain', 617000, 'Asia', 1277558000),
#  ('Georgia', 4968000, 'Asia', 1277558000),
#  ('Uzbekistan', 24318000, 'Asia', 1277558000),
#  ('Kazakstan', 16223000, 'Asia', 1277558000),
#  ('United Arab Emirates', 2441000, 'Asia', 1277558000),
#  ('Bangladesh', 129155000, 'Asia', 1277558000),
#  ('Macao', 473000, 'Asia', 1277558000),
#  ('Singapore', 3567000, 'Asia', 1277558000),
#  ('San Marino', 27000, 'Europe', 146934000),
#  ('Netherlands', 15864000, 'Europe', 146934000),
#  ('Albania', 3401200, 'Europe', 146934000),
#  ('Andorra', 78000, 'Europe', 146934000),
#  ('Belgium', 10239000, 'Europe', 146934000),
#  ('Bosnia and Herzegovina', 3972000, 'Europe', 146934000),
#  ('United Kingdom', 59623400, 'Europe', 146934000),
#  ('Bulgaria', 8190900, 'Europe', 146934000),
#  ('Spain', 39441700, 'Europe', 146934000),
#  ('Faroe Islands', 43000, 'Europe', 146934000),
#  ('Gibraltar', 25000, 'Europe', 146934000),
#  ('Svalbard and Jan Mayen', 3200, 'Europe', 146934000),
#  ('Ireland', 3775100, 'Europe', 146934000),
#  ('Iceland', 279000, 'Europe', 146934000),
#  ('Italy', 57680000, 'Europe', 146934000),
#  ('Austria', 8091800, 'Europe', 146934000),
#  ('Yugoslavia', 10640000, 'Europe', 146934000),
#  ('Greece', 10545700, 'Europe', 146934000),
#  ('Croatia', 4473000, 'Europe', 146934000),
#  ('Latvia', 2424200, 'Europe', 146934000),
#  ('Liechtenstein', 32300, 'Europe', 146934000),
#  ('Lithuania', 3698500, 'Europe', 146934000),
#  ('Luxembourg', 435700, 'Europe', 146934000),
#  ('Macedonia', 2024000, 'Europe', 146934000),
#  ('Malta', 380200, 'Europe', 146934000),
#  ('Moldova', 4380000, 'Europe', 146934000),
#  ('Monaco', 34000, 'Europe', 146934000),
#  ('Norway', 4478500, 'Europe', 146934000),
#  ('Portugal', 9997600, 'Europe', 146934000),
#  ('Poland', 38653600, 'Europe', 146934000),
#  ('France', 59225700, 'Europe', 146934000),
#  ('Romania', 22455500, 'Europe', 146934000),
#  ('Sweden', 8861400, 'Europe', 146934000),
#  ('Germany', 82164700, 'Europe', 146934000),
#  ('Slovakia', 5398700, 'Europe', 146934000),
#  ('Slovenia', 1987800, 'Europe', 146934000),
#  ('Finland', 5171300, 'Europe', 146934000),
#  ('Switzerland', 7160400, 'Europe', 146934000),
#  ('Denmark', 5330000, 'Europe', 146934000),
#  ('Czech Republic', 10278100, 'Europe', 146934000),
#  ('Ukraine', 50456000, 'Europe', 146934000),
#  ('Hungary', 10043200, 'Europe', 146934000),
#  ('Belarus', 10236000, 'Europe', 146934000),
#  ('Holy See (Vatican City State)', 1000, 'Europe', 146934000),
#  ('Russian Federation', 146934000, 'Europe', 146934000),
#  ('Estonia', 1439200, 'Europe', 146934000),
#  ('Jamaica', 2583000, 'North America', 278357000),
#  ('Canada', 31147000, 'North America', 278357000),
#  ('Netherlands Antilles', 217000, 'North America', 278357000),
#  ('Saint Kitts and Nevis', 38000, 'North America', 278357000),
#  ('Saint Lucia', 154000, 'North America', 278357000),
#  ('Saint Vincent and the Grenadines', 114000, 'North America', 278357000),
#  ('Saint Pierre and Miquelon', 7000, 'North America', 278357000),
#  ('Barbados', 270000, 'North America', 278357000),
#  ('Puerto Rico', 3869000, 'North America', 278357000),
#  ('Honduras', 6485000, 'North America', 278357000),
#  ('Haiti', 8222000, 'North America', 278357000),
#  ('Guatemala', 11385000, 'North America', 278357000),
#  ('Guadeloupe', 456000, 'North America', 278357000),
#  ('Greenland', 56000, 'North America', 278357000),
#  ('United States', 278357000, 'North America', 278357000),
#  ('Grenada', 94000, 'North America', 278357000),
#  ('Virgin Islands, U.S.', 93000, 'North America', 278357000),
#  ('El Salvador', 6276000, 'North America', 278357000),
#  ('Bahamas', 307000, 'North America', 278357000),
#  ('Dominican Republic', 8495000, 'North America', 278357000),
#  ('Dominica', 71000, 'North America', 278357000),
#  ('Costa Rica', 4023000, 'North America', 278357000),
#  ('Trinidad and Tobago', 1295000, 'North America', 278357000),
#  ('Cayman Islands', 38000, 'North America', 278357000),
#  ('Aruba', 103000, 'North America', 278357000),
#  ('Virgin Islands, British', 21000, 'North America', 278357000),
#  ('Turks and Caicos Islands', 17000, 'North America', 278357000),
#  ('Bermuda', 65000, 'North America', 278357000),
#  ('Antigua and Barbuda', 68000, 'North America', 278357000),
#  ('Belize', 241000, 'North America', 278357000),
#  ('Montserrat', 11000, 'North America', 278357000),
#  ('Nicaragua', 5074000, 'North America', 278357000),
#  ('Mexico', 98881000, 'North America', 278357000),
#  ('Anguilla', 8000, 'North America', 278357000),
#  ('Martinique', 395000, 'North America', 278357000),
#  ('Cuba', 11201000, 'North America', 278357000),
#  ('Panama', 2856000, 'North America', 278357000),
#  ('Marshall Islands', 64000, 'Oceania', 18886000),
#  ('Guam', 168000, 'Oceania', 18886000),
#  ('Australia', 18886000, 'Oceania', 18886000),
#  ('Northern Mariana Islands', 78000, 'Oceania', 18886000),
#  ('United States Minor Outlying Islands', 0, 'Oceania', 18886000),
#  ('French Polynesia', 235000, 'Oceania', 18886000),
#  ('New Caledonia', 214000, 'Oceania', 18886000),
#  ('Fiji Islands', 817000, 'Oceania', 18886000),
#  ('Kiribati', 83000, 'Oceania', 18886000),
#  ('New Zealand', 3862000, 'Oceania', 18886000),
#  ('Cook Islands', 20000, 'Oceania', 18886000),
#  ('Palau', 19000, 'Oceania', 18886000),
#  ('Nauru', 12000, 'Oceania', 18886000),
#  ('Wallis and Futuna', 15000, 'Oceania', 18886000),
#  ('Tokelau', 2000, 'Oceania', 18886000),
#  ('Tonga', 99000, 'Oceania', 18886000),
#  ('Christmas Island', 2500, 'Oceania', 18886000),
#  ('Papua New Guinea', 4807000, 'Oceania', 18886000),
#  ('Niue', 2000, 'Oceania', 18886000),
#  ('Norfolk Island', 2000, 'Oceania', 18886000),
#  ('Vanuatu', 190000, 'Oceania', 18886000),
#  ('Cocos (Keeling) Islands', 600, 'Oceania', 18886000),
#  ('Solomon Islands', 444000, 'Oceania', 18886000),
#  ('Micronesia, Federated States of', 119000, 'Oceania', 18886000),
#  ('Samoa', 180000, 'Oceania', 18886000),
#  ('Pitcairn', 50, 'Oceania', 18886000),
#  ('Tuvalu', 12000, 'Oceania', 18886000),
#  ('American Samoa', 68000, 'Oceania', 18886000),
#  ('Ecuador', 12646000, 'South America', 170115000),
#  ('Chile', 15211000, 'South America', 170115000),
#  ('Colombia', 42321000, 'South America', 170115000),
#  ('French Guiana', 181000, 'South America', 170115000),
#  ('Venezuela', 24170000, 'South America', 170115000),
#  ('Paraguay', 5496000, 'South America', 170115000),
#  ('Peru', 25662000, 'South America', 170115000),
#  ('Brazil', 170115000, 'South America', 170115000),
#  ('Bolivia', 8329000, 'South America', 170115000),
#  ('Guyana', 861000, 'South America', 170115000),
#  ('Argentina', 37032000, 'South America', 170115000),
#  ('Uruguay', 3337000, 'South America', 170115000),
#  ('Falkland Islands', 2000, 'South America', 170115000),
#  ('Suriname', 417000, 'South America', 170115000)]

# %% [markdown]
# <br><br><br>

# %% [markdown]
# ### Syntax
#
# A lot of new keywords appeared all at once here, so let me explain them all in detail. The syntax of a window function is:
# ‍‍‍
# ```sql
# SELECT
#     column,
#     .
#     .
#     .
#     window_function_name(expression) OVER (
#         PARTITION BY column
#         ORDER BY column
#         frame_clause
#     .
#     .
#     .
# FROM
#     table
# ;
# ```

# %% [markdown]
# - `window_function_name()` specifies which window function we want to use. I'll list the different types of window functions in a bit.
#
# - `OVER` is what tells the SQL engine that we are going to use a window function
#
# - `PARTITION BY` determines how or based on which column we want the window function to subdivide the rows into groups
#
# - `ORDER BY` specifies how we want the rows in each subgroup to be ordered
#
# - `frame_clause` gives us further control over which rows in each subgroup can participate in the window function calculations

# %% [markdown]
# <br><br><br>

# %% [markdown]
# > **Note:** Window functions in SQL are processed **after** `GROUP BY` and `HAVING`, and **before** `SELECT`. This is a crucial point to understand when using window functions in SQL.
#
# > **Note:** Window functions are only allowed in the `SELECT` and `ORDER BY` clauses.

# %% [markdown]
# <br><br><br>

# %% [markdown]
# ### Types of window functions

# %% [markdown]
# <br><br><br>

# %% [markdown]
# #### Aggregate functions
#
# These are the regular aggregate functions that we've learned about before, i.e. `AVG()`, `COUNT()`, `MAX()`, `MIN()`, and `SUM()`, which can also be used as window functions.

# %% [markdown]
# <br><br><br>

# %% [markdown]
# #### Ranking functions
#
# - `CUME_DIST()`: returns the cumulative distribution, i.e. the percentage of values less than or equal to the current value.
# - `NTILE()`: given a specified number of buckets, it tells us in which bucket each row goes among other rows in the partition.
# - `PERCENT_RANK()`: similar to `CUME_DIST()`, but considers only the percentage of values less than (and not equal to) the current value.
#
# - `DENSE_RANK()`: returns the rank of a row within a partition without jumps after duplicate ranks (e.g. 1, 2, 2, 3, ...)
# - `RANK()`: returns the rank of row within a partition but with jumps after duplicates ranks (e.g. 1, 2, 2, 4, ...)
# - `ROW_NUMBER()`: returns simply the number of a row in a partition, regardless of duplicate values

# %% [markdown]
# <br><br><br>

# %% [markdown]
# #### Value functions
#
# - `FIRST_VALUE()`: returns the first value of the ordered partition
#
# - `LAST_VALUE()`: returns the last value of the ordered partition
# - `LAG()`: returns value from the preceding row with a specified offset
# - `LEAD()`: returns value from the following row with a specified offset

# %% [markdown]
# <br><br><br>

# %% [markdown]
# **Differences with subqueries**
#
# - Subqueries can operate on multiple tables, window functions are limited to the current table
#
# - Subqueries are far more general (e.g. `WHERE` conditions including `EXITS`, etc.)
# - Window functions are more readable
# - Window functions offer functionalities such as `RANK()` or `LAG()` and `LEAD()` that are either very hard, if not impossible, to implement using subqueries
# - Window functions are generally faster than subqueries when used for a same purpose

# %% [markdown]
# <br><br><br>

# %% [markdown]
# ---
#
# **Example:** Using window functions, count the number of countries in which each language is officially spoken. Remove duplicates and sort the results in descending order by the count value.
#
# ---

# %%
# %%sql
#
# SELECT
#     DISTINCT language,
#     COUNT(*) OVER (PARTITION BY language) AS count
# FROM
#     countrylanguage
# WHERE
#     isofficial = TRUE
# ORDER BY
#     count DESC
# Out:
#    postgresql://postgres:***@localhost/imdb
#    postgresql://postgres:***@localhost:5432/mds
#  * postgresql://postgres:***@localhost:5432/world
# 102 rows affected.
# [('English', 44),
#  ('Arabic', 22),
#  ('Spanish', 20),
#  ('French', 18),
#  ('German', 6),
#  ('Portuguese', 6),
#  ('Dutch', 4),
#  ('Italian', 4),
#  ('Malay', 4),
#  ('Danish', 3),
#  ('Russian', 3),
#  ('Serbo-Croatian', 3),
#  ('Aimará', 2),
#  ('Chinese', 2),
#  ('Greek', 2),
#  ('Ket\x9aua', 2),
#  ('Korean', 2),
#  ('Norwegian', 2),
#  ('Romanian', 2),
#  ('Samoan', 2),
#  ('Swedish', 2),
#  ('Tamil', 2),
#  ('Turkish', 2),
#  ('Afrikaans', 1),
#  ('Albaniana', 1),
#  ('Armenian', 1),
#  ('Azerbaijani', 1),
#  ('Belorussian', 1),
#  ('Bengali', 1),
#  ('Bislama', 1),
#  ('Bulgariana', 1),
#  ('Burmese', 1),
#  ('Catalan', 1),
#  ('Chamorro', 1),
#  ('Chichewa', 1),
#  ('Comorian', 1),
#  ('Czech', 1),
#  ('Dari', 1),
#  ('Dhivehi', 1),
#  ('Dzongkha', 1),
#  ('Estonian', 1),
#  ('Ewe', 1),
#  ('Faroese', 1),
#  ('Fijian', 1),
#  ('Finnish', 1),
#  ('Georgiana', 1),
#  ('Greenlandic', 1),
#  ('Guaraní', 1),
#  ('Hebrew', 1),
#  ('Hindi', 1),
#  ('Hungarian', 1),
#  ('Icelandic', 1),
#  ('Irish', 1),
#  ('Japanese', 1),
#  ('Kabyé', 1),
#  ('Kazakh', 1),
#  ('Khmer', 1),
#  ('Kirgiz', 1),
#  ('Kiribati', 1),
#  ('Kirundi', 1),
#  ('Lao', 1),
#  ('Latvian', 1),
#  ('Lithuanian', 1),
#  ('Luxembourgish', 1),
#  ('Macedonian', 1),
#  ('Malagasy', 1),
#  ('Maltese', 1),
#  ('Mandarin Chinese', 1),
#  ('Maori', 1),
#  ('Marshallese', 1),
#  ('Mongolian', 1),
#  ('Nauru', 1),
#  ('Nepali', 1),
#  ('Palau', 1),
#  ('Papiamento', 1),
#  ('Pashto', 1),
#  ('Persian', 1),
#  ('Pilipino', 1),
#  ('Polish', 1),
#  ('Romani', 1),
#  ('Romansh', 1),
#  ('Rwanda', 1),
#  ('Singali', 1),
#  ('Slovak', 1),
#  ('Slovene', 1),
#  ('Somali', 1),
#  ('Sotho', 1),
#  ('Swahili', 1),
#  ('Swazi', 1),
#  ('Tadzhik', 1),
#  ('Thai', 1),
#  ('Tigrinja', 1),
#  ('Tongan', 1),
#  ('Turkmenian', 1),
#  ('Tuvalu', 1),
#  ('Ukrainian', 1),
#  ('Urdu', 1),
#  ('Uzbek', 1),
#  ('Vietnamese', 1),
#  ('Wolof', 1),
#  ('Xhosa', 1),
#  ('Zulu', 1)]

# %% [markdown]
# <br><br><br>

# %% [markdown]
# **Question:** In the above query, is it possible to use a `WHERE` clause to limit the results to languages which are spoken in more than one country?

# %% [markdown]
# <br><br><br>

# %% [markdown]
# In the following example, we rank countries by life expectancy in each continent, but we also create a column to retrieve the name of the country whose ranking follows the one in the current row:

# %%
# %%sql
#
# SELECT
#     name,
#     continent,
#     DENSE_RANK()
#         OVER (PARTITION BY continent ORDER BY lifeexpectancy DESC),
#     LEAD(name, 1)
#         OVER (PARTITION BY continent ORDER BY lifeexpectancy DESC)
# FROM
#     country
# WHERE
#     population > 10000000
# Out:
#    postgresql://postgres:***@localhost/imdb
#    postgresql://postgres:***@localhost:5432/mds
#  * postgresql://postgres:***@localhost:5432/world
# 78 rows affected.
# [('Algeria', 'Africa', 1, 'Morocco'),
#  ('Morocco', 'Africa', 2, 'Egypt'),
#  ('Egypt', 'Africa', 3, 'Ghana'),
#  ('Ghana', 'Africa', 4, 'Sudan'),
#  ('Sudan', 'Africa', 5, 'Madagascar'),
#  ('Madagascar', 'Africa', 6, 'Cameroon'),
#  ('Cameroon', 'Africa', 7, 'Tanzania'),
#  ('Tanzania', 'Africa', 8, 'Nigeria'),
#  ('Nigeria', 'Africa', 9, 'South Africa'),
#  ('South Africa', 'Africa', 10, 'Congo, The Democratic Republic of the'),
#  ('Congo, The Democratic Republic of the', 'Africa', 11, 'Kenya'),
#  ('Kenya', 'Africa', 12, 'Burkina Faso'),
#  ('Burkina Faso', 'Africa', 13, 'Mali'),
#  ('Mali', 'Africa', 13, 'Somalia'),
#  ('Somalia', 'Africa', 14, 'Ethiopia'),
#  ('Ethiopia', 'Africa', 15, 'Côte d\x92Ivoire'),
#  ('Côte d\x92Ivoire', 'Africa', 15, 'Uganda'),
#  ('Uganda', 'Africa', 16, 'Niger'),
#  ('Niger', 'Africa', 17, 'Angola'),
#  ('Angola', 'Africa', 18, 'Zimbabwe'),
#  ('Zimbabwe', 'Africa', 19, 'Malawi'),
#  ('Malawi', 'Africa', 20, 'Mozambique'),
#  ('Mozambique', 'Africa', 21, None),
#  ('Japan', 'Asia', 1, 'Taiwan'),
#  ('Taiwan', 'Asia', 2, 'South Korea'),
#  ('South Korea', 'Asia', 3, 'Sri Lanka'),
#  ('Sri Lanka', 'Asia', 4, 'China'),
#  ('China', 'Asia', 5, 'Turkey'),
#  ('Turkey', 'Asia', 6, 'Malaysia'),
#  ('Malaysia', 'Asia', 7, 'North Korea'),
#  ('North Korea', 'Asia', 8, 'Iran'),
#  ('Iran', 'Asia', 9, 'Vietnam'),
#  ('Vietnam', 'Asia', 10, 'Thailand'),
#  ('Thailand', 'Asia', 11, 'Syria'),
#  ('Syria', 'Asia', 12, 'Indonesia'),
#  ('Indonesia', 'Asia', 13, 'Saudi Arabia'),
#  ('Saudi Arabia', 'Asia', 14, 'Philippines'),
#  ('Philippines', 'Asia', 15, 'Iraq'),
#  ('Iraq', 'Asia', 16, 'Uzbekistan'),
#  ('Uzbekistan', 'Asia', 17, 'Kazakstan'),
#  ('Kazakstan', 'Asia', 18, 'India'),
#  ('India', 'Asia', 19, 'Pakistan'),
#  ('Pakistan', 'Asia', 20, 'Bangladesh'),
#  ('Bangladesh', 'Asia', 21, 'Yemen'),
#  ('Yemen', 'Asia', 22, 'Nepal'),
#  ('Nepal', 'Asia', 23, 'Cambodia'),
#  ('Cambodia', 'Asia', 24, 'Myanmar'),
#  ('Myanmar', 'Asia', 25, 'Afghanistan'),
#  ('Afghanistan', 'Asia', 26, None),
#  ('Italy', 'Europe', 1, 'France'),
#  ('France', 'Europe', 2, 'Spain'),
#  ('Spain', 'Europe', 2, 'Greece'),
#  ('Greece', 'Europe', 3, 'Netherlands'),
#  ('Netherlands', 'Europe', 4, 'Belgium'),
#  ('Belgium', 'Europe', 5, 'United Kingdom'),
#  ('United Kingdom', 'Europe', 6, 'Germany'),
#  ('Germany', 'Europe', 7, 'Czech Republic'),
#  ('Czech Republic', 'Europe', 8, 'Poland'),
#  ('Poland', 'Europe', 9, 'Yugoslavia'),
#  ('Yugoslavia', 'Europe', 10, 'Hungary'),
#  ('Hungary', 'Europe', 11, 'Romania'),
#  ('Romania', 'Europe', 12, 'Belarus'),
#  ('Belarus', 'Europe', 13, 'Russian Federation'),
#  ('Russian Federation', 'Europe', 14, 'Ukraine'),
#  ('Ukraine', 'Europe', 15, None),
#  ('Canada', 'North America', 1, 'United States'),
#  ('United States', 'North America', 2, 'Cuba'),
#  ('Cuba', 'North America', 3, 'Mexico'),
#  ('Mexico', 'North America', 4, 'Guatemala'),
#  ('Guatemala', 'North America', 5, None),
#  ('Australia', 'Oceania', 1, None),
#  ('Chile', 'South America', 1, 'Argentina'),
#  ('Argentina', 'South America', 2, 'Venezuela'),
#  ('Venezuela', 'South America', 3, 'Ecuador'),
#  ('Ecuador', 'South America', 4, 'Colombia'),
#  ('Colombia', 'South America', 5, 'Peru'),
#  ('Peru', 'South America', 6, 'Brazil'),
#  ('Brazil', 'South America', 7, None)]

# %% [markdown]
# <br><br><br>

# %%
# %%sql
#
# WITH cte(name, continent, rank, lead_rank) AS
# (
# SELECT
#     name,
#     continent,
#     DENSE_RANK()
#         OVER (PARTITION BY continent ORDER BY lifeexpectancy DESC),
#     LEAD(name, 1)
#         OVER (PARTITION BY continent ORDER BY lifeexpectancy DESC)
# FROM
#     country
# WHERE
#     population > 10000000
# )
# SELECT
#     *
# FROM
#     cte
# WHERE
#     rank = 1
# Out:
#    postgresql://postgres:***@localhost/imdb
#    postgresql://postgres:***@localhost:5432/mds
#  * postgresql://postgres:***@localhost:5432/world
# 6 rows affected.
# [('Algeria', 'Africa', 1, 'Morocco'),
#  ('Japan', 'Asia', 1, 'Taiwan'),
#  ('Italy', 'Europe', 1, 'France'),
#  ('Canada', 'North America', 1, 'United States'),
#  ('Australia', 'Oceania', 1, None),
#  ('Chile', 'South America', 1, 'Argentina')]

# %% [markdown]
# <br><br><br>

# %% [markdown]
# ---
#
# **Example:** Write a query that in each row returns each movie's name, production year (`start_year`), and its number of votes, for all movies produced in or after 2018. Your query should also return a column that ranks each movie in descending order, according to its number of votes in the year it was produced.
#
# - Sort your results according the rank value in ascending order
#
# - Retrieve only 20 rows
#
# ---

# %%
# %sql postgresql://{username}:{password}@{host}:{port}/imdb
# Out:
# 'Connected: postgres@imdb'

# %%
# %%sql
#
# SELECT
#     title,
#     start_year,
#     nvotes,
#     RANK()
#         OVER (PARTITION BY start_year ORDER BY nvotes DESC)
#             AS rank
# FROM
#     movies
# WHERE
#     start_year >= 2018
# ORDER BY
#     rank
# LIMIT
#     20
# ;
# Out:
#    postgresql://postgres:***@localhost/imdb
#  * postgresql://postgres:***@localhost:5432/imdb
#    postgresql://postgres:***@localhost:5432/mds
#    postgresql://postgres:***@localhost:5432/world
# 20 rows affected.
# [('Avengers: Infinity War', 2018, 711500, 1),
#  ('Avengers: Endgame', 2019, 567968, 1),
#  ('Black Panther', 2018, 543002, 2),
#  ('Captain Marvel', 2019, 362609, 2),
#  ('Once Upon a Time... in Hollywood', 2019, 204266, 3),
#  ('Deadpool 2', 2018, 416811, 3),
#  ('Bohemian Rhapsody', 2018, 382622, 4),
#  ('Spider-Man: Far from Home', 2019, 198519, 4),
#  ('A Quiet Place', 2018, 325428, 5),
#  ('Shazam!', 2019, 182200, 5),
#  ('John Wick: Chapter 3 - Parabellum', 2019, 172900, 6),
#  ('Ready Player One', 2018, 316326, 6),
#  ('Alita: Battle Angel', 2019, 162513, 7),
#  ('Venom', 2018, 305111, 7),
#  ('Glass', 2019, 159064, 8),
#  ('Aquaman', 2018, 300064, 8),
#  ('Us', 2019, 150951, 9),
#  ('A Star Is Born', 2018, 276484, 9),
#  ('Spider-Man: Into the Spider-Verse', 2018, 262505, 10),
#  ('Aladdin', 2019, 139370, 10)]

# %% [markdown]
# <br><br><br>

# %% [markdown]
# ---
#
# **Example:** We want to find out how movies are ranked in their respective genres. Write a query that in each row returns movie name, genre, and production year (`start_year`) for movies with more than 1,000,000 votes. Your query should also have a column that shows the ranking of each movie according to its rating in descending order.
#
# - Sort your results by genre and rank in ascending order
# - Limit your results to 50 rows
#
# ---

# %%
# %%sql
#
# SELECT
#     title,
#     genre,
#     start_year,
#     RANK()
#         OVER (PARTITION BY genre ORDER BY rating)
#             AS rank
# FROM
#     movies m
# JOIN
#     movie_genres mg
# ON
#     m.id = mg.movie_id
# WHERE
#     nvotes > 1000000
# ORDER BY
#     genre, rank
# LIMIT
#     50
# ;
# Out:
#    postgresql://postgres:***@localhost/imdb
#  * postgresql://postgres:***@localhost:5432/imdb
#    postgresql://postgres:***@localhost:5432/mds
#    postgresql://postgres:***@localhost:5432/world
# 50 rows affected.
# [('Avatar', 'action', 2009, 1),
#  ('The Avengers', 'action', 2012, 2),
#  ('Batman Begins', 'action', 2005, 3),
#  ('The Dark Knight Rises', 'action', 2012, 4),
#  ('Gladiator', 'action', 2000, 5),
#  ('Star Wars: Episode IV - A New Hope', 'action', 1977, 6),
#  ('The Matrix', 'action', 1999, 7),
#  ('Star Wars: Episode V - The Empire Strikes Back', 'action', 1980, 7),
#  ('Inception', 'action', 2010, 9),
#  ('The Dark Knight', 'action', 2008, 10),
#  ('Avatar', 'adventure', 2009, 1),
#  ('The Avengers', 'adventure', 2012, 2),
#  ('Batman Begins', 'adventure', 2005, 3),
#  ('Inglourious Basterds', 'adventure', 2009, 4),
#  ('Gladiator', 'adventure', 2000, 5),
#  ('Interstellar', 'adventure', 2014, 6),
#  ('Star Wars: Episode IV - A New Hope', 'adventure', 1977, 6),
#  ('Star Wars: Episode V - The Empire Strikes Back', 'adventure', 1980, 8),
#  ('The Lord of the Rings: The Two Towers', 'adventure', 2002, 8),
#  ('The Lord of the Rings: The Fellowship of the Ring', 'adventure', 2001, 10),
#  ('Inception', 'adventure', 2010, 10),
#  ('The Lord of the Rings: The Return of the King', 'adventure', 2003, 12),
#  ('The Wolf of Wall Street', 'biography', 2013, 1),
#  ("Schindler's List", 'biography', 1993, 2),
#  ('The Wolf of Wall Street', 'crime', 2013, 1),
#  ('The Departed', 'crime', 2006, 2),
#  ('Se7en', 'crime', 1995, 3),
#  ('The Green Mile', 'crime', 1999, 3),
#  ('The Silence of the Lambs', 'crime', 1991, 3),
#  ('Pulp Fiction', 'crime', 1994, 6),
#  ('The Godfather: Part II', 'crime', 1974, 7),
#  ('The Dark Knight', 'crime', 2008, 7),
#  ('The Godfather', 'crime', 1972, 9),
#  ('The Wolf of Wall Street', 'drama', 2013, 1),
#  ('Inglourious Basterds', 'drama', 2009, 2),
#  ('American Beauty', 'drama', 1999, 2),
#  ('Django Unchained', 'drama', 2012, 4),
#  ('Gladiator', 'drama', 2000, 5),
#  ('The Departed', 'drama', 2006, 5),
#  ('The Prestige', 'drama', 2006, 5),
#  ('The Green Mile', 'drama', 1999, 8),
#  ('Saving Private Ryan', 'drama', 1998, 8),
#  ('Se7en', 'drama', 1995, 8),
#  ('The Silence of the Lambs', 'drama', 1991, 8),
#  ('Interstellar', 'drama', 2014, 8),
#  ('The Lord of the Rings: The Two Towers', 'drama', 2002, 13),
#  ('Forrest Gump', 'drama', 1994, 14),
#  ('Fight Club', 'drama', 1999, 14),
#  ('The Lord of the Rings: The Fellowship of the Ring', 'drama', 2001, 14),
#  ('The Lord of the Rings: The Return of the King', 'drama', 2003, 17)]

# %% [markdown]
# <br><br><br>

# %% [markdown]
# It is also possible to define multiple windows over which multiple window functions may operate:

# %%
# %sql postgresql://{username}:{password}@{host}:{port}/world
# Out:
# 'Connected: postgres@world'

# %%
# %%sql
#
# SELECT
#     name,
#     RANK() OVER w1 AS region_rank,
#     RANK() OVER w2 AS continent_rank
# FROM
#     country
# WHERE
#     population > 1000000
# WINDOW
#     w1 AS (PARTITION BY region ORDER BY lifeexpectancy DESC),
#     w2 AS (PARTITION BY continent ORDER BY lifeexpectancy DESC)
# ORDER BY
#     region_rank
# Out:
#    postgresql://postgres:***@localhost/imdb
#    postgresql://postgres:***@localhost:5432/imdb
#    postgresql://postgres:***@localhost:5432/mds
#  * postgresql://postgres:***@localhost:5432/world
# 154 rows affected.
# [('Cameroon', 1, 12),
#  ('Czech Republic', 1, 18),
#  ('Israel', 1, 4),
#  ('Cuba', 1, 3),
#  ('Senegal', 1, 7),
#  ('Canada', 1, 1),
#  ('Mauritius', 1, 3),
#  ('Chile', 1, 1),
#  ('Sri Lanka', 1, 10),
#  ('South Africa', 1, 17),
#  ('Libyan Arab Jamahiriya', 1, 1),
#  ('Italy', 1, 3),
#  ('United Kingdom', 1, 10),
#  ('Papua New Guinea', 1, 3),
#  ('Sweden', 1, 1),
#  ('Estonia', 1, 29),
#  ('Switzerland', 1, 1),
#  ('Australia', 1, 1),
#  ('Singapore', 1, 2),
#  ('Japan', 1, 1),
#  ('Costa Rica', 1, 4),
#  ('Jordan', 2, 5),
#  ('Hong Kong', 2, 3),
#  ('Spain', 2, 4),
#  ('Malaysia', 2, 16),
#  ('Ireland', 2, 14),
#  ('Ghana', 2, 8),
#  ('Slovakia', 2, 20),
#  ('Chad', 2, 21),
#  ('Norway', 2, 6),
#  ('Panama', 2, 6),
#  ('Puerto Rico', 2, 5),
#  ('Lesotho', 2, 19),
#  ('Iran', 2, 18),
#  ('Lithuania', 2, 30),
#  ('Tunisia', 2, 2),
#  ('Eritrea', 2, 10),
#  ('Uruguay', 2, 2),
#  ('New Zealand', 2, 2),
#  ('France', 2, 4),
#  ('United States', 2, 2),
#  ('Tajikistan', 3, 29),
#  ('Kuwait', 3, 7),
#  ('Greece', 3, 7),
#  ('Gabon', 3, 23),
#  ('Namibia', 3, 38),
#  ('Jamaica', 3, 7),
#  ('Mexico', 3, 9),
#  ('Algeria', 3, 4),
#  ('Madagascar', 3, 11),
#  ('Latvia', 3, 31),
#  ('Netherlands', 3, 8),
#  ('Togo', 3, 13),
#  ('Taiwan', 3, 6),
#  ('Poland', 3, 22),
#  ('Vietnam', 3, 19),
#  ('Finland', 3, 12),
#  ('Argentina', 3, 3),
#  ('South Korea', 4, 8),
#  ('Dominican Republic', 4, 8),
#  ('Thailand', 4, 20),
#  ('Congo, The Democratic Republic of the', 4, 25),
#  ('Honduras', 4, 10),
#  ('Tanzania', 4, 15),
#  ('Belgium', 4, 9),
#  ('Gambia', 4, 14),
#  ('Paraguay', 4, 4),
#  ('Hungary', 4, 26),
#  ('Uzbekistan', 4, 30),
#  ('United Arab Emirates', 4, 9),
#  ('Portugal', 4, 16),
#  ('Swaziland', 4, 40),
#  ('Denmark', 4, 15),
#  ('Morocco', 4, 5),
#  ('Oman', 5, 10),
#  ('Kyrgyzstan', 5, 31),
#  ('Bulgaria', 5, 27),
#  ('Indonesia', 5, 22),
#  ('China', 5, 12),
#  ('Nigeria', 5, 16),
#  ('Kenya', 5, 26),
#  ('Austria', 5, 10),
#  ('El Salvador', 5, 11),
#  ('Venezuela', 5, 5),
#  ('Egypt', 5, 6),
#  ('Congo', 5, 27),
#  ('Slovenia', 5, 17),
#  ('Botswana', 5, 41),
#  ('Trinidad and Tobago', 5, 13),
#  ('Germany', 6, 12),
#  ('Haiti', 6, 15),
#  ('Central African Republic', 6, 36),
#  ('Nicaragua', 6, 12),
#  ('Burundi', 6, 30),
#  ('Somalia', 6, 30),
#  ('North Korea', 6, 17),
#  ('Romania', 6, 28),
#  ('Palestine', 6, 12),
#  ('Sudan', 6, 9),
#  ('Ecuador', 6, 6),
#  ('Philippines', 6, 24),
#  ('Macedonia', 6, 19),
#  ('Kazakstan', 6, 32),
#  ('Liberia', 6, 18),
#  ('Lebanon', 7, 14),
#  ('India', 7, 34),
#  ('Cambodia', 7, 40),
#  ('Mauritania', 7, 19),
#  ('Angola', 7, 43),
#  ('Mongolia', 7, 25),
#  ('Croatia', 7, 20),
#  ('Colombia', 7, 7),
#  ('Belarus', 7, 32),
#  ('Guatemala', 7, 14),
#  ('Myanmar', 8, 41),
#  ('Russian Federation', 8, 33),
#  ('Turkey', 8, 15),
#  ('Peru', 8, 8),
#  ('Ethiopia', 8, 34),
#  ('Benin', 8, 22),
#  ('Pakistan', 8, 35),
#  ('Yugoslavia', 8, 23),
#  ('Laos', 9, 42),
#  ('Bolivia', 9, 9),
#  ('Syria', 9, 21),
#  ('Albania', 9, 24),
#  ('Ukraine', 9, 34),
#  ('Turkmenistan', 9, 36),
#  ('Guinea-Bissau', 9, 24),
#  ('Uganda', 9, 37),
#  ('Bangladesh', 10, 37),
#  ('Bosnia and Herzegovina', 10, 25),
#  ('Saudi Arabia', 10, 23),
#  ('Burkina Faso', 10, 28),
#  ('Mali', 10, 28),
#  ('Rwanda', 10, 41),
#  ('Brazil', 10, 10),
#  ('Moldova', 10, 35),
#  ('Zimbabwe', 11, 44),
#  ('Nepal', 11, 39),
#  ('Iraq', 11, 26),
#  ('Malawi', 12, 45),
#  ('Armenia', 12, 27),
#  ('Guinea', 12, 32),
#  ('Bhutan', 12, 43),
#  ('Sierra Leone', 13, 33),
#  ('Georgia', 13, 28),
#  ('Afghanistan', 13, 44),
#  ('Mozambique', 13, 46),
#  ('Azerbaijan', 14, 33),
#  ('Côte d\x92Ivoire', 14, 34),
#  ('Zambia', 14, 47),
#  ('Niger', 15, 39),
#  ('Yemen', 15, 38)]

# %% [markdown]
# <br><br><br>

# %% [markdown]
# ## Indexing and performance (optional)
#
# Check the optional notebook if you want to learn more about indexing and performance.
